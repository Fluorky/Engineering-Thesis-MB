# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import glob
import os


##data = pd.read_csv('folder/dane_fco2_1godz_2013.txt', sep=';')
#data = pd.read_csv('folder/dane_fco2_1godz_2013.txt', delimiter=r"\s+")
#print(data)

# %%
#data.head()

# %%
#data2 = pd.read_csv('folder/dane_fco2_1godz_2014.txt', delimiter=r"\s+")
#print(data2)

# %%
#data3 = pd.read_csv('folder/dane_fco2_1godz_2014.txt', delimiter=r"\s+")
#print(data3)

# %%
#data3.head()

# %%
#data3.describe()

# %%
#data3.info()

# %%
#data3.hist(bins=50, figsize=(20,15))
#plt.show()

# %%
#data3.describe()

# %%
#list the files
test=os.getcwd()

print(test)
child = os.chdir(test)#os.listdir()

filelist=os.listdir()

print(filelist)
filenames = glob.glob(test+"/folder"+"/dane_fco2_1h" + "/*.txt")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, delimiter=r"\s+"))
big_frame = pd.concat(dfs)
# Out:
# /Users/maciej/my_env/dane_2013-17/test
# ['15_przetwarzanie_sekwencji_za_pomoc•_sieci_rnn_i_cnn-Copy2.ipynb', 'final_gru-Copy4.ipynb', 'readfiles.ipynb', '16_przetwarzanie_j�zyka_naturalnego_mech_uwagi.ipynb', '.DS_Store', 'readfiles-Copy1.ipynb', 'final_gru-Copy2.ipynb', 'final_gru-Copy5.ipynb', 'folder', '15_przetwarzanie_sekwencji_za_pomoc•_sieci_rnn_i_cnn-Copy1.ipynb', 'final_gru-Copy3.ipynb', 'final_gru-Copy1.ipynb', 'final_gru.ipynb', '.ipynb_checkpoints', '15_przetwarzanie_sekwencji_za_pomoc•_sieci_rnn_i_cnn.ipynb', 'Thesis.ipynb', 'rysunki']

# %%
big_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43824 entries, 0 to 8759
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rok       43824 non-null  int64
#  1   ms        43824 non-null  int64
#  2   dz        43824 non-null  int64
#  3   godz      43824 non-null  float64
#  4   fco2_HQ   9754 non-null   float64
#  5   fco2_MQ   23815 non-null  float64
#  6   fco2_raw  40342 non-null  float64
#  7   glwody    43824 non-null  float64
#  8   T50cm     43824 non-null  float64
#  9   T2m       43824 non-null  float64
#  10  Kd        43824 non-null  float64
#  11  Ku        43824 non-null  float64
#  12  Ld        43824 non-null  float64
#  13  Lu        43824 non-null  float64
#  14  ppp       43824 non-null  float64
#  15  v         43824 non-null  float64
#  16  vdir      43824 non-null  float64
#  17  Tgrunt    43824 non-null  float64
#  18  vwc       43824 non-null  float64
# ...

# %%
big_frame.hist(bins=50, figsize=(20,15))
plt.show()

# %%
big_frame.describe()
# Out:
#                 rok            ms            dz          godz      fco2_HQ  \
# count  43824.000000  43824.000000  43824.000000  43824.000000  9754.000000
# mean    2015.000548      6.523549     15.727820     12.000000    -1.993797
# std        1.414036      3.448572      8.799425      6.922266     5.357988
# min     2013.000000      1.000000      1.000000      0.500000   -25.170000
# 25%     2014.000000      4.000000      8.000000      6.250000    -5.180000
# 50%     2015.000000      7.000000     16.000000     12.000000     0.210000
# 75%     2016.000000     10.000000     23.000000     17.750000     1.100000
# max     2017.000000     12.000000     31.000000     23.500000    15.230000
#
#             fco2_MQ      fco2_raw        glwody         T50cm           T2m  \
# count  23815.000000  40342.000000  43824.000000  43824.000000  43824.000000
# mean      -1.357803     -0.431696     -9.699263      7.315644      7.274717
# ...

# %%
big_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43824 entries, 0 to 8759
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rok       43824 non-null  int64
#  1   ms        43824 non-null  int64
#  2   dz        43824 non-null  int64
#  3   godz      43824 non-null  float64
#  4   fco2_HQ   9754 non-null   float64
#  5   fco2_MQ   23815 non-null  float64
#  6   fco2_raw  40342 non-null  float64
#  7   glwody    43824 non-null  float64
#  8   T50cm     43824 non-null  float64
#  9   T2m       43824 non-null  float64
#  10  Kd        43824 non-null  float64
#  11  Ku        43824 non-null  float64
#  12  Ld        43824 non-null  float64
#  13  Lu        43824 non-null  float64
#  14  ppp       43824 non-null  float64
#  15  v         43824 non-null  float64
#  16  vdir      43824 non-null  float64
#  17  Tgrunt    43824 non-null  float64
#  18  vwc       43824 non-null  float64
# ...

# %%
os.makedirs('folder/subfolder', exist_ok=True) 
big_frame.to_csv('folder/subfolder/out2.csv',sep=';',index=False)

# %%
all_data = pd.read_csv('folder/subfolder/out2.csv', delimiter=';')

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43824 entries, 0 to 43823
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rok       43824 non-null  int64
#  1   ms        43824 non-null  int64
#  2   dz        43824 non-null  int64
#  3   godz      43824 non-null  float64
#  4   fco2_HQ   9754 non-null   float64
#  5   fco2_MQ   23815 non-null  float64
#  6   fco2_raw  40342 non-null  float64
#  7   glwody    43824 non-null  float64
#  8   T50cm     43824 non-null  float64
#  9   T2m       43824 non-null  float64
#  10  Kd        43824 non-null  float64
#  11  Ku        43824 non-null  float64
#  12  Ld        43824 non-null  float64
#  13  Lu        43824 non-null  float64
#  14  ppp       43824 non-null  float64
#  15  v         43824 non-null  float64
#  16  vdir      43824 non-null  float64
#  17  Tgrunt    43824 non-null  float64
#  18  vwc       43824 non-null  float64
# ...

# %%
big_frame.dropna()
# Out:
#        rok  ms  dz  godz  fco2_HQ  fco2_MQ  fco2_raw  glwody  T50cm   T2m  \
# 2196  2013   4   2  12.5    -0.49    -0.49     -0.49     1.2    1.4  -0.4
# 2198  2013   4   2  14.5    -0.51    -0.51     -0.51     1.2    1.0  -0.3
# 2217  2013   4   3   9.5    -0.08    -0.08     -0.08     1.1    1.3   0.2
# 2218  2013   4   3  10.5    -0.61    -0.61     -0.61     1.3    1.6   0.2
# 2219  2013   4   3  11.5    -0.58    -0.58     -0.58     1.3    2.3   0.9
# ...    ...  ..  ..   ...      ...      ...       ...     ...    ...   ...
# 8716  2014  12  30   4.5    -0.67    -0.67     -0.67    -8.9  -10.7 -10.7
# 8717  2014  12  30   5.5    -0.39    -0.39     -0.39    -9.0  -10.5 -10.6
# 8722  2014  12  30  10.5    -0.30    -0.30     -0.30    -9.2   -9.2 -10.1
# 8723  2014  12  30  11.5    -0.60    -0.60     -0.60    -9.5   -8.1  -9.6
# 8733  2014  12  30  21.5    -0.16    -0.16     -0.16   -10.3  -11.0 -11.1
#
#       ...    v   vdir  Tgrunt    vwc   PARd   PARu  fMOD_NN  fMOD_E0  fMODlut  \
# ...

# %%
P1=pd.DataFrame(data=all_data,columns=['rok','ms','dz','godz','fco2_MQ','fco2_HQ','fco2_raw','glwody','T50cm','T2m','Kd','Ku','Ld','Lu','ppp','v','vdir','Tgrunt','vwc','PARd','PARu'],copy=True)

# %%
print(P1)
# Out:
#         rok  ms  dz  godz  fco2_MQ  fco2_HQ  fco2_raw  glwody  T50cm  T2m  \
# 0      2013   1   1   0.5     0.15      NaN      0.15     5.2    1.2  1.5
# 1      2013   1   1   1.5    -0.60      NaN     -0.60     5.2    0.9  1.2
# 2      2013   1   1   2.5     0.57      NaN      0.57     5.4    0.7  1.0
# 3      2013   1   1   3.5     0.03      NaN      0.03     5.5    0.3  0.6
# 4      2013   1   1   4.5     0.03      NaN      0.03     5.5   -0.4 -0.0
# ...     ...  ..  ..   ...      ...      ...       ...     ...    ...  ...
# 43819  2014  12  31  19.5      NaN      NaN     -0.00   -10.5   -2.9 -2.9
# 43820  2014  12  31  20.5      NaN      NaN     -0.00   -10.3   -2.7 -2.7
# 43821  2014  12  31  21.5      NaN      NaN      0.01   -10.3   -2.4 -2.4
# 43822  2014  12  31  22.5      NaN      NaN     -0.02   -10.4   -2.0 -2.0
# 43823  2014  12  31  23.5      NaN      NaN    -25.25   -10.4   -1.7 -1.7
#
#        ...   Ku     Ld     Lu     ppp    v   vdir  Tgrunt    vwc  PARd  PARu
# ...

# %%
P1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43824 entries, 0 to 43823
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rok       43824 non-null  int64
#  1   ms        43824 non-null  int64
#  2   dz        43824 non-null  int64
#  3   godz      43824 non-null  float64
#  4   fco2_MQ   23815 non-null  float64
#  5   fco2_HQ   9754 non-null   float64
#  6   fco2_raw  40342 non-null  float64
#  7   glwody    43824 non-null  float64
#  8   T50cm     43824 non-null  float64
#  9   T2m       43824 non-null  float64
#  10  Kd        43824 non-null  float64
#  11  Ku        43824 non-null  float64
#  12  Ld        43824 non-null  float64
#  13  Lu        43824 non-null  float64
#  14  ppp       43824 non-null  float64
#  15  v         43824 non-null  float64
#  16  vdir      43824 non-null  float64
#  17  Tgrunt    43824 non-null  float64
#  18  vwc       43824 non-null  float64
# ...

# %%
P1=P1[~P1['fco2_raw'].isnull()]

# %%
P1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40342 entries, 0 to 43823
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rok       40342 non-null  int64
#  1   ms        40342 non-null  int64
#  2   dz        40342 non-null  int64
#  3   godz      40342 non-null  float64
#  4   fco2_MQ   23815 non-null  float64
#  5   fco2_HQ   9754 non-null   float64
#  6   fco2_raw  40342 non-null  float64
#  7   glwody    40342 non-null  float64
#  8   T50cm     40342 non-null  float64
#  9   T2m       40342 non-null  float64
#  10  Kd        40342 non-null  float64
#  11  Ku        40342 non-null  float64
#  12  Ld        40342 non-null  float64
#  13  Lu        40342 non-null  float64
#  14  ppp       40342 non-null  float64
#  15  v         40342 non-null  float64
#  16  vdir      40342 non-null  float64
#  17  Tgrunt    40342 non-null  float64
#  18  vwc       40342 non-null  float64
# ...

# %%
P1.to_csv('folder/subfolder/out_withoutnullsCO2.csv',sep=';',index=False)

# %%
dataToModel = pd.read_csv('folder/subfolder/out_withoutnullsco2.csv', delimiter=';')

# %%
dataToModel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40342 entries, 0 to 40341
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rok       40342 non-null  int64
#  1   ms        40342 non-null  int64
#  2   dz        40342 non-null  int64
#  3   godz      40342 non-null  float64
#  4   fco2_MQ   23815 non-null  float64
#  5   fco2_HQ   9754 non-null   float64
#  6   fco2_raw  40342 non-null  float64
#  7   glwody    40342 non-null  float64
#  8   T50cm     40342 non-null  float64
#  9   T2m       40342 non-null  float64
#  10  Kd        40342 non-null  float64
#  11  Ku        40342 non-null  float64
#  12  Ld        40342 non-null  float64
#  13  Lu        40342 non-null  float64
#  14  ppp       40342 non-null  float64
#  15  v         40342 non-null  float64
#  16  vdir      40342 non-null  float64
#  17  Tgrunt    40342 non-null  float64
#  18  vwc       40342 non-null  float64
# ...

# %%
co2HQ=pd.DataFrame(data=dataToModel,columns=['fco2_HQ'])

# %%
#dataToModel['fco2_HQBi'].loc[~dataToModel['fco2_HQ'].isnull()]=1
#dataToModel['fco2_HQBi'].loc[dataToModel['fco2_HQ'].isnull()]=0

# %%
dataToModel['fco2_HQ'].loc[~dataToModel['fco2_HQ'].isnull()]=1
dataToModel['fco2_HQ'].loc[dataToModel['fco2_HQ'].isnull()]=0
# Out:
# /var/folders/wy/7w1mlgcx4vjfgbpvhlk2y7m00000gn/T/ipykernel_4126/293000418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataToModel['fco2_HQ'].loc[~dataToModel['fco2_HQ'].isnull()]=1
# /var/folders/wy/7w1mlgcx4vjfgbpvhlk2y7m00000gn/T/ipykernel_4126/293000418.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataToModel['fco2_HQ'].loc[dataToModel['fco2_HQ'].isnull()]=0

# %%
#dataToModel['fco2_HQBi'] = dataToModel['fco2_HQ'].apply(lambda x: 1 if not pd.isnull(x) else np.nan)

# %%
dataToModel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40342 entries, 0 to 40341
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rok       40342 non-null  int64
#  1   ms        40342 non-null  int64
#  2   dz        40342 non-null  int64
#  3   godz      40342 non-null  float64
#  4   fco2_MQ   23815 non-null  float64
#  5   fco2_HQ   40342 non-null  float64
#  6   fco2_raw  40342 non-null  float64
#  7   glwody    40342 non-null  float64
#  8   T50cm     40342 non-null  float64
#  9   T2m       40342 non-null  float64
#  10  Kd        40342 non-null  float64
#  11  Ku        40342 non-null  float64
#  12  Ld        40342 non-null  float64
#  13  Lu        40342 non-null  float64
#  14  ppp       40342 non-null  float64
#  15  v         40342 non-null  float64
#  16  vdir      40342 non-null  float64
#  17  Tgrunt    40342 non-null  float64
#  18  vwc       40342 non-null  float64
# ...

# %%
#dataToModel = dataToModel.drop('fco2_MQ', axis=1)

# %%
dataToModel.describe()
# Out:
#                 rok            ms            dz          godz       fco2_MQ  \
# count  40342.000000  40342.000000  40342.000000  40342.000000  23815.000000
# mean    2015.023945      6.622651     15.764092     12.128204     -1.357803
# std        1.400748      3.433766      8.823814      6.849504      5.212825
# min     2013.000000      1.000000      1.000000      0.500000    -29.560000
# 25%     2014.000000      4.000000      8.000000      6.500000     -3.380000
# 50%     2015.000000      7.000000     16.000000     12.500000      0.080000
# 75%     2016.000000     10.000000     23.000000     18.500000      1.080000
# max     2017.000000     12.000000     31.000000     23.500000     20.040000
#
#             fco2_HQ      fco2_raw        glwody         T50cm           T2m  \
# count  40342.000000  40342.000000  40342.000000  40342.000000  40342.000000
# mean       0.241783     -0.431696     -9.874436      7.651522      7.597365
# ...

# %%
dataToModel.head()
# Out:
#     rok  ms  dz  godz  fco2_MQ  fco2_HQ  fco2_raw  glwody  T50cm  T2m  ...  \
# 0  2013   1   1   0.5     0.15      0.0      0.15     5.2    1.2  1.5  ...
# 1  2013   1   1   1.5    -0.60      0.0     -0.60     5.2    0.9  1.2  ...
# 2  2013   1   1   2.5     0.57      0.0      0.57     5.4    0.7  1.0  ...
# 3  2013   1   1   3.5     0.03      0.0      0.03     5.5    0.3  0.6  ...
# 4  2013   1   1   4.5     0.03      0.0      0.03     5.5   -0.4 -0.0  ...
#
#     Ku     Ld     Lu    ppp    v   vdir  Tgrunt    vwc  PARd  PARu
# 0  0.9  249.3  322.9  998.5  3.4  210.5     0.6  0.785   0.0   0.0
# 1  1.0  249.5  323.5  998.1  3.3  202.5     0.6  0.785   0.0   0.0
# 2  1.0  249.7  324.0  997.6  3.3  201.6     0.6  0.785   0.0   0.0
# 3  0.9  250.0  324.5  997.2  2.6  191.6     0.6  0.785   0.0   0.0
# 4  1.5  250.2  325.1  996.8  2.2  189.1     0.6  0.785   0.0   0.0
#
# [5 rows x 21 columns]

# %%
dataToModel.to_csv('folder/subfolder/dataToModel.csv',sep=';')#,index=False)

# %%
co2=pd.DataFrame(data=P1,columns=['fco2_raw'],copy=True)

# %%
co2_HQ=pd.DataFrame(data=P1,columns=['fco2_HQ'],copy=True)

# %%
co2_HQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40342 entries, 0 to 43823
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   fco2_HQ  9754 non-null   float64
# dtypes: float64(1)
# memory usage: 630.3 KB

# %%
co2_HQ=co2_HQ.dropna()

# %%
co2_HQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9754 entries, 2196 to 43797
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   fco2_HQ  9754 non-null   float64
# dtypes: float64(1)
# memory usage: 152.4 KB

# %%
co2_MQ=pd.DataFrame(data=P1,columns=['fco2_MQ'],copy=True)

# %%
co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40342 entries, 0 to 43823
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fco2_raw  40342 non-null  float64
# dtypes: float64(1)
# memory usage: 630.3 KB

# %%
co2.describe()
# Out:
#            fco2_raw
# count  40342.000000
# mean      -0.431696
# std       22.416585
# min     -832.700000
# 25%       -3.070000
# 50%        0.140000
# 75%        1.710000
# max      774.780000

# %%
print(co2)
# Out:
#        fco2_raw
# 0          0.15
# 1         -0.60
# 2          0.57
# 3          0.03
# 4          0.03
# ...         ...
# 43819     -0.00
# 43820     -0.00
# 43821      0.01
# 43822     -0.02
# 43823    -25.25
#
# [40342 rows x 1 columns]

# %%
co2_HQ=pd.DataFrame(data=P1,columns=['fco2_HQ'],copy=True)

# %%
co2_HQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40342 entries, 0 to 43823
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   fco2_HQ  9754 non-null   float64
# dtypes: float64(1)
# memory usage: 630.3 KB

# %%
co2_HQ=co2_HQ.dropna()
co2_HQ.reset_index(drop=True, inplace=True)

# %%
co2_HQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9754 entries, 0 to 9753
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   fco2_HQ  9754 non-null   float64
# dtypes: float64(1)
# memory usage: 76.3 KB

# %%
co2_HQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9754 entries, 0 to 9753
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   fco2_HQ  9754 non-null   float64
# dtypes: float64(1)
# memory usage: 76.3 KB

# %%
co2_HQ.notnull()
# Out:
#       fco2_HQ
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ...       ...
# 9749     True
# 9750     True
# 9751     True
# 9752     True
# 9753     True
#
# [9754 rows x 1 columns]

# %%
x = np.arange(40342)


#plt.plot(x,co2)
plt.scatter(x,co2)

plt.show()

# %%
co2_HQ.to_csv('folder/subfolder/co2_HQ_withoutnulls.csv',sep=';',index=False)

# %%
#x = np.arange(40342)
x = np.arange(9754)
plt.scatter(x,co2_HQ)

#plt.plot(co2_HQ,marker="o")


plt.show()

# %%
co2.hist(bins=50, figsize=(20,15))
plt.show()

# %%
co2_HQ.hist(bins=50, figsize=(20,15))
plt.show()

# %%
co2_MQ.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#list the files
test=os.getcwd()

print(test)
child = os.chdir(test)#os.listdir()

filelist=os.listdir()

print(filelist)
filenames = glob.glob(test+"/folder"+"/dane_fco2_5min" + "/*.txt")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, delimiter=r"\s+"))
big_frame = pd.concat(dfs)
# Out:
# /Users/maciej/my_env/dane_2013-17/test
# ['15_przetwarzanie_sekwencji_za_pomoc•_sieci_rnn_i_cnn-Copy2.ipynb', 'final_gru-Copy4.ipynb', 'readfiles.ipynb', '16_przetwarzanie_j�zyka_naturalnego_mech_uwagi.ipynb', '.DS_Store', 'readfiles-Copy1.ipynb', 'final_gru-Copy2.ipynb', 'final_gru-Copy5.ipynb', 'folder', '15_przetwarzanie_sekwencji_za_pomoc•_sieci_rnn_i_cnn-Copy1.ipynb', 'final_gru-Copy3.ipynb', 'final_gru-Copy1.ipynb', 'final_gru.ipynb', '.ipynb_checkpoints', '15_przetwarzanie_sekwencji_za_pomoc•_sieci_rnn_i_cnn.ipynb', 'Thesis.ipynb', 'rysunki']

# %%
big_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 525888 entries, 0 to 105407
# Data columns (total 22 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   rok       525888 non-null  int64
#  1   ms        525888 non-null  int64
#  2   dz        525888 non-null  int64
#  3   go        525888 non-null  int64
#  4   mi        525888 non-null  int64
#  5   fco2_HQ   122607 non-null  float64
#  6   fco2_MQ   298211 non-null  float64
#  7   fco2_raw  475336 non-null  float64
#  8   glwody    525881 non-null  float64
#  9   T50cm     525888 non-null  float64
#  10  T2m       525888 non-null  float64
#  11  Kd        525888 non-null  float64
#  12  Ku        525888 non-null  float64
#  13  Ld        525888 non-null  float64
#  14  Lu        525888 non-null  float64
#  15  ppp       525888 non-null  float64
#  16  v         525888 non-null  float64
#  17  vdir      525888 non-null  float64
#  18  Tgrunt    525888 non-null  float64
# ...

# %%
big_frame.describe()
# Out:
#                  rok             ms             dz             go  \
# count  525888.000000  525888.000000  525888.000000  525888.000000
# mean     2015.000548       6.523549      15.727820      11.500000
# std         1.414021       3.448536       8.799333       6.922193
# min      2013.000000       1.000000       1.000000       0.000000
# 25%      2014.000000       4.000000       8.000000       5.750000
# 50%      2015.000000       7.000000      16.000000      11.500000
# 75%      2016.000000      10.000000      23.000000      17.250000
# max      2017.000000      12.000000      31.000000      23.000000
#
#                   mi        fco2_HQ        fco2_MQ      fco2_raw  \
# count  525888.000000  122607.000000  298211.000000  475336.00000
# mean       31.500000      -1.015673      -1.243933      -0.25396
# std        17.260279       4.666485       4.993262      17.02511
# min         4.000000     -29.060000     -29.720000    -934.05000
# ...

# %%
os.makedirs('folder/subfolder', exist_ok=True) 
big_frame.to_csv('folder/subfolder/out_5min.csv',sep=';',index=False)

# %%
all_data = pd.read_csv('folder/subfolder/out_5min.csv', delimiter=';')

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525888 entries, 0 to 525887
# Data columns (total 22 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   rok       525888 non-null  int64
#  1   ms        525888 non-null  int64
#  2   dz        525888 non-null  int64
#  3   go        525888 non-null  int64
#  4   mi        525888 non-null  int64
#  5   fco2_HQ   122607 non-null  float64
#  6   fco2_MQ   298211 non-null  float64
#  7   fco2_raw  475336 non-null  float64
#  8   glwody    525881 non-null  float64
#  9   T50cm     525888 non-null  float64
#  10  T2m       525888 non-null  float64
#  11  Kd        525888 non-null  float64
#  12  Ku        525888 non-null  float64
#  13  Ld        525888 non-null  float64
#  14  Lu        525888 non-null  float64
#  15  ppp       525888 non-null  float64
#  16  v         525888 non-null  float64
#  17  vdir      525888 non-null  float64
#  18  Tgrunt    525888 non-null  float64
# ...

# %%
P2=pd.DataFrame(data=all_data,columns=['rok','ms','dz','go','fco2_MQ','fco2_HQ','fco2_raw','glwody','T50cm','T2m','Kd','Ku','Ld','Lu','ppp','v','vdir','Tgrunt','vwc','PARd','PARu'],copy=True)

# %%
P2=P2[~P2['fco2_raw'].isnull()]

# %%
P2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 475336 entries, 1308 to 525887
# Data columns (total 21 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   rok       475336 non-null  int64
#  1   ms        475336 non-null  int64
#  2   dz        475336 non-null  int64
#  3   go        475336 non-null  int64
#  4   fco2_MQ   298211 non-null  float64
#  5   fco2_HQ   122607 non-null  float64
#  6   fco2_raw  475336 non-null  float64
#  7   glwody    475336 non-null  float64
#  8   T50cm     475336 non-null  float64
#  9   T2m       475336 non-null  float64
#  10  Kd        475336 non-null  float64
#  11  Ku        475336 non-null  float64
#  12  Ld        475336 non-null  float64
#  13  Lu        475336 non-null  float64
#  14  ppp       475336 non-null  float64
#  15  v         475336 non-null  float64
#  16  vdir      475336 non-null  float64
#  17  Tgrunt    475336 non-null  float64
#  18  vwc       475336 non-null  float64
# ...

# %%
P2.to_csv('folder/subfolder/out_5min_withoutnulls.csv',sep=';',index=False)

# %%
co2=pd.DataFrame(data=P2,columns=['fco2_raw'],copy=True)

# %%
co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 475336 entries, 1308 to 525887
# Data columns (total 1 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   fco2_raw  475336 non-null  float64
# dtypes: float64(1)
# memory usage: 7.3 MB

# %%
co2.reset_index(drop=True, inplace=True)

# %%
co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475336 entries, 0 to 475335
# Data columns (total 1 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   fco2_raw  475336 non-null  float64
# dtypes: float64(1)
# memory usage: 3.6 MB

# %%
x = np.arange(475336)


#plt.plot(x,co2)
plt.scatter(x,co2)

plt.show()
