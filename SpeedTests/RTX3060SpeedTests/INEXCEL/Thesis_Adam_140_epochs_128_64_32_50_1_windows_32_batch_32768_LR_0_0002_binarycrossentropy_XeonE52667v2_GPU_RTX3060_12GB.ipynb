# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x21680009040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x21605020040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0002)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=32768)#, shuffle=False)
# Out:
# Epoch 1/140
# 12/12 [==============================] - 12s 416ms/step - loss: 0.6006 - accuracy: 0.7393 - val_loss: 0.5803 - val_accuracy: 0.7530
# Epoch 2/140
# 12/12 [==============================] - 4s 297ms/step - loss: 0.5824 - accuracy: 0.7393 - val_loss: 0.5632 - val_accuracy: 0.7530
# Epoch 3/140
# 12/12 [==============================] - 4s 297ms/step - loss: 0.5735 - accuracy: 0.7393 - val_loss: 0.5577 - val_accuracy: 0.7530
# Epoch 4/140
# 12/12 [==============================] - 4s 296ms/step - loss: 0.5721 - accuracy: 0.7393 - val_loss: 0.5564 - val_accuracy: 0.7530
# Epoch 5/140
# 12/12 [==============================] - 4s 297ms/step - loss: 0.5697 - accuracy: 0.7393 - val_loss: 0.5549 - val_accuracy: 0.7530
# Epoch 6/140
# 12/12 [==============================] - 4s 296ms/step - loss: 0.5660 - accuracy: 0.7393 - val_loss: 0.5496 - val_accuracy: 0.7530
# Epoch 7/140
# 12/12 [==============================] - 4s 296ms/step - loss: 0.5580 - accuracy: 0.7393 - val_loss: 0.5411 - val_accuracy: 0.7530
# Epoch 8/140
# 12/12 [==============================] - 4s 295ms/step - loss: 0.5471 - accuracy: 0.7391 - val_loss: 0.5326 - val_accuracy: 0.7476
# Epoch 9/140
# 12/12 [==============================] - 4s 296ms/step - loss: 0.5382 - accuracy: 0.7383 - val_loss: 0.5210 - val_accuracy: 0.7524
# Epoch 10/140
# 12/12 [==============================] - 4s 297ms/step - loss: 0.5282 - accuracy: 0.7409 - val_loss: 0.5122 - val_accuracy: 0.7537
# Epoch 11/140
# 12/12 [==============================] - 4s 299ms/step - loss: 0.5187 - accuracy: 0.7405 - val_loss: 0.5040 - val_accuracy: 0.7533
# Epoch 12/140
# 12/12 [==============================] - 4s 300ms/step - loss: 0.5138 - accuracy: 0.7389 - val_loss: 0.4980 - val_accuracy: 0.7523
# Epoch 13/140
# 12/12 [==============================] - 4s 298ms/step - loss: 0.5106 - accuracy: 0.7383 - val_loss: 0.4966 - val_accuracy: 0.7518
# Epoch 14/140
# 12/12 [==============================] - 4s 301ms/step - loss: 0.5082 - accuracy: 0.7384 - val_loss: 0.4942 - val_accuracy: 0.7516
# Epoch 15/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.5062 - accuracy: 0.7385 - val_loss: 0.4916 - val_accuracy: 0.7520
# Epoch 16/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.5044 - accuracy: 0.7393 - val_loss: 0.4904 - val_accuracy: 0.7526
# Epoch 17/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.5029 - accuracy: 0.7400 - val_loss: 0.4888 - val_accuracy: 0.7530
# Epoch 18/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.5013 - accuracy: 0.7406 - val_loss: 0.4872 - val_accuracy: 0.7530
# Epoch 19/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4999 - accuracy: 0.7413 - val_loss: 0.4858 - val_accuracy: 0.7536
# Epoch 20/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4987 - accuracy: 0.7422 - val_loss: 0.4848 - val_accuracy: 0.7537
# Epoch 21/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4974 - accuracy: 0.7432 - val_loss: 0.4853 - val_accuracy: 0.7536
# Epoch 22/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4962 - accuracy: 0.7443 - val_loss: 0.4837 - val_accuracy: 0.7543
# Epoch 23/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4946 - accuracy: 0.7452 - val_loss: 0.4827 - val_accuracy: 0.7542
# Epoch 24/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4929 - accuracy: 0.7464 - val_loss: 0.4811 - val_accuracy: 0.7544
# Epoch 25/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4913 - accuracy: 0.7473 - val_loss: 0.4798 - val_accuracy: 0.7540
# Epoch 26/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4897 - accuracy: 0.7476 - val_loss: 0.4783 - val_accuracy: 0.7535
# Epoch 27/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4878 - accuracy: 0.7479 - val_loss: 0.4779 - val_accuracy: 0.7532
# Epoch 28/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4862 - accuracy: 0.7482 - val_loss: 0.4771 - val_accuracy: 0.7533
# Epoch 29/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4844 - accuracy: 0.7485 - val_loss: 0.4772 - val_accuracy: 0.7524
# Epoch 30/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4835 - accuracy: 0.7492 - val_loss: 0.4772 - val_accuracy: 0.7517
# Epoch 31/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4821 - accuracy: 0.7498 - val_loss: 0.4750 - val_accuracy: 0.7534
# Epoch 32/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4802 - accuracy: 0.7508 - val_loss: 0.4723 - val_accuracy: 0.7537
# Epoch 33/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4788 - accuracy: 0.7517 - val_loss: 0.4705 - val_accuracy: 0.7557
# Epoch 34/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4774 - accuracy: 0.7525 - val_loss: 0.4701 - val_accuracy: 0.7569
# Epoch 35/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4759 - accuracy: 0.7539 - val_loss: 0.4679 - val_accuracy: 0.7583
# Epoch 36/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4743 - accuracy: 0.7547 - val_loss: 0.4664 - val_accuracy: 0.7582
# Epoch 37/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4725 - accuracy: 0.7563 - val_loss: 0.4650 - val_accuracy: 0.7606
# Epoch 38/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4709 - accuracy: 0.7572 - val_loss: 0.4627 - val_accuracy: 0.7600
# Epoch 39/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4692 - accuracy: 0.7579 - val_loss: 0.4605 - val_accuracy: 0.7619
# Epoch 40/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4672 - accuracy: 0.7587 - val_loss: 0.4596 - val_accuracy: 0.7608
# Epoch 41/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4664 - accuracy: 0.7586 - val_loss: 0.4580 - val_accuracy: 0.7625
# Epoch 42/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4658 - accuracy: 0.7588 - val_loss: 0.4569 - val_accuracy: 0.7648
# Epoch 43/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4648 - accuracy: 0.7589 - val_loss: 0.4587 - val_accuracy: 0.7623
# Epoch 44/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4643 - accuracy: 0.7589 - val_loss: 0.4566 - val_accuracy: 0.7634
# Epoch 45/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4630 - accuracy: 0.7596 - val_loss: 0.4547 - val_accuracy: 0.7648
# Epoch 46/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4631 - accuracy: 0.7595 - val_loss: 0.4550 - val_accuracy: 0.7645
# Epoch 47/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4618 - accuracy: 0.7598 - val_loss: 0.4533 - val_accuracy: 0.7645
# Epoch 48/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4614 - accuracy: 0.7602 - val_loss: 0.4534 - val_accuracy: 0.7647
# Epoch 49/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4615 - accuracy: 0.7599 - val_loss: 0.4537 - val_accuracy: 0.7649
# Epoch 50/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4604 - accuracy: 0.7604 - val_loss: 0.4527 - val_accuracy: 0.7651
# Epoch 51/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4605 - accuracy: 0.7606 - val_loss: 0.4524 - val_accuracy: 0.7652
# Epoch 52/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4601 - accuracy: 0.7606 - val_loss: 0.4527 - val_accuracy: 0.7650
# Epoch 53/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4596 - accuracy: 0.7607 - val_loss: 0.4515 - val_accuracy: 0.7656
# Epoch 54/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4592 - accuracy: 0.7612 - val_loss: 0.4524 - val_accuracy: 0.7664
# Epoch 55/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4597 - accuracy: 0.7608 - val_loss: 0.4526 - val_accuracy: 0.7656
# Epoch 56/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4592 - accuracy: 0.7614 - val_loss: 0.4537 - val_accuracy: 0.7668
# Epoch 57/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4584 - accuracy: 0.7616 - val_loss: 0.4514 - val_accuracy: 0.7660
# Epoch 58/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4581 - accuracy: 0.7618 - val_loss: 0.4507 - val_accuracy: 0.7660
# Epoch 59/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4578 - accuracy: 0.7618 - val_loss: 0.4501 - val_accuracy: 0.7658
# Epoch 60/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4573 - accuracy: 0.7621 - val_loss: 0.4510 - val_accuracy: 0.7655
# Epoch 61/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4569 - accuracy: 0.7623 - val_loss: 0.4502 - val_accuracy: 0.7667
# Epoch 62/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4567 - accuracy: 0.7625 - val_loss: 0.4493 - val_accuracy: 0.7660
# Epoch 63/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4568 - accuracy: 0.7626 - val_loss: 0.4494 - val_accuracy: 0.7667
# Epoch 64/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4567 - accuracy: 0.7627 - val_loss: 0.4493 - val_accuracy: 0.7670
# Epoch 65/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4570 - accuracy: 0.7629 - val_loss: 0.4493 - val_accuracy: 0.7670
# Epoch 66/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4562 - accuracy: 0.7630 - val_loss: 0.4487 - val_accuracy: 0.7665
# Epoch 67/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4558 - accuracy: 0.7631 - val_loss: 0.4491 - val_accuracy: 0.7660
# Epoch 68/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4554 - accuracy: 0.7630 - val_loss: 0.4482 - val_accuracy: 0.7671
# Epoch 69/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4558 - accuracy: 0.7632 - val_loss: 0.4493 - val_accuracy: 0.7668
# Epoch 70/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4559 - accuracy: 0.7634 - val_loss: 0.4505 - val_accuracy: 0.7675
# Epoch 71/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4554 - accuracy: 0.7637 - val_loss: 0.4483 - val_accuracy: 0.7665
# Epoch 72/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4545 - accuracy: 0.7636 - val_loss: 0.4480 - val_accuracy: 0.7668
# Epoch 73/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4542 - accuracy: 0.7638 - val_loss: 0.4473 - val_accuracy: 0.7675
# Epoch 74/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4548 - accuracy: 0.7638 - val_loss: 0.4485 - val_accuracy: 0.7679
# Epoch 75/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4542 - accuracy: 0.7640 - val_loss: 0.4476 - val_accuracy: 0.7674
# Epoch 76/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4540 - accuracy: 0.7640 - val_loss: 0.4482 - val_accuracy: 0.7671
# Epoch 77/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4543 - accuracy: 0.7639 - val_loss: 0.4477 - val_accuracy: 0.7674
# Epoch 78/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4546 - accuracy: 0.7644 - val_loss: 0.4479 - val_accuracy: 0.7683
# Epoch 79/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4538 - accuracy: 0.7645 - val_loss: 0.4471 - val_accuracy: 0.7682
# Epoch 80/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4533 - accuracy: 0.7644 - val_loss: 0.4460 - val_accuracy: 0.7678
# Epoch 81/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4530 - accuracy: 0.7645 - val_loss: 0.4475 - val_accuracy: 0.7682
# Epoch 82/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4529 - accuracy: 0.7646 - val_loss: 0.4470 - val_accuracy: 0.7676
# Epoch 83/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4529 - accuracy: 0.7648 - val_loss: 0.4456 - val_accuracy: 0.7685
# Epoch 84/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4526 - accuracy: 0.7649 - val_loss: 0.4457 - val_accuracy: 0.7684
# Epoch 85/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4533 - accuracy: 0.7648 - val_loss: 0.4461 - val_accuracy: 0.7684
# Epoch 86/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4528 - accuracy: 0.7649 - val_loss: 0.4453 - val_accuracy: 0.7685
# Epoch 87/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4528 - accuracy: 0.7649 - val_loss: 0.4464 - val_accuracy: 0.7683
# Epoch 88/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4520 - accuracy: 0.7649 - val_loss: 0.4452 - val_accuracy: 0.7685
# Epoch 89/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4517 - accuracy: 0.7653 - val_loss: 0.4456 - val_accuracy: 0.7688
# Epoch 90/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4513 - accuracy: 0.7654 - val_loss: 0.4458 - val_accuracy: 0.7687
# Epoch 91/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4515 - accuracy: 0.7653 - val_loss: 0.4445 - val_accuracy: 0.7693
# Epoch 92/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4515 - accuracy: 0.7655 - val_loss: 0.4452 - val_accuracy: 0.7691
# Epoch 93/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4520 - accuracy: 0.7654 - val_loss: 0.4454 - val_accuracy: 0.7688
# Epoch 94/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4512 - accuracy: 0.7656 - val_loss: 0.4458 - val_accuracy: 0.7693
# Epoch 95/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4510 - accuracy: 0.7656 - val_loss: 0.4440 - val_accuracy: 0.7696
# Epoch 96/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4511 - accuracy: 0.7656 - val_loss: 0.4438 - val_accuracy: 0.7697
# Epoch 97/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4506 - accuracy: 0.7658 - val_loss: 0.4454 - val_accuracy: 0.7697
# Epoch 98/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4505 - accuracy: 0.7659 - val_loss: 0.4453 - val_accuracy: 0.7695
# Epoch 99/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4505 - accuracy: 0.7657 - val_loss: 0.4442 - val_accuracy: 0.7694
# Epoch 100/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4503 - accuracy: 0.7657 - val_loss: 0.4459 - val_accuracy: 0.7697
# Epoch 101/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4501 - accuracy: 0.7659 - val_loss: 0.4446 - val_accuracy: 0.7702
# Epoch 102/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4498 - accuracy: 0.7659 - val_loss: 0.4444 - val_accuracy: 0.7694
# Epoch 103/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4500 - accuracy: 0.7660 - val_loss: 0.4437 - val_accuracy: 0.7702
# Epoch 104/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4501 - accuracy: 0.7662 - val_loss: 0.4464 - val_accuracy: 0.7700
# Epoch 105/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4512 - accuracy: 0.7660 - val_loss: 0.4432 - val_accuracy: 0.7703
# Epoch 106/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4501 - accuracy: 0.7661 - val_loss: 0.4436 - val_accuracy: 0.7700
# Epoch 107/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4493 - accuracy: 0.7660 - val_loss: 0.4438 - val_accuracy: 0.7694
# Epoch 108/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4493 - accuracy: 0.7663 - val_loss: 0.4434 - val_accuracy: 0.7707
# Epoch 109/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4491 - accuracy: 0.7662 - val_loss: 0.4441 - val_accuracy: 0.7697
# Epoch 110/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4496 - accuracy: 0.7662 - val_loss: 0.4438 - val_accuracy: 0.7712
# Epoch 111/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4489 - accuracy: 0.7664 - val_loss: 0.4428 - val_accuracy: 0.7709
# Epoch 112/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4490 - accuracy: 0.7666 - val_loss: 0.4426 - val_accuracy: 0.7703
# Epoch 113/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4485 - accuracy: 0.7665 - val_loss: 0.4425 - val_accuracy: 0.7712
# Epoch 114/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4488 - accuracy: 0.7666 - val_loss: 0.4421 - val_accuracy: 0.7711
# Epoch 115/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4495 - accuracy: 0.7667 - val_loss: 0.4449 - val_accuracy: 0.7706
# Epoch 116/140
# 12/12 [==============================] - 3s 286ms/step - loss: 0.4497 - accuracy: 0.7663 - val_loss: 0.4429 - val_accuracy: 0.7710
# Epoch 117/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4485 - accuracy: 0.7666 - val_loss: 0.4439 - val_accuracy: 0.7707
# Epoch 118/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4491 - accuracy: 0.7667 - val_loss: 0.4446 - val_accuracy: 0.7711
# Epoch 119/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4489 - accuracy: 0.7668 - val_loss: 0.4436 - val_accuracy: 0.7711
# Epoch 120/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4488 - accuracy: 0.7668 - val_loss: 0.4422 - val_accuracy: 0.7712
# Epoch 121/140
# 12/12 [==============================] - 3s 286ms/step - loss: 0.4491 - accuracy: 0.7668 - val_loss: 0.4436 - val_accuracy: 0.7713
# Epoch 122/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4487 - accuracy: 0.7667 - val_loss: 0.4434 - val_accuracy: 0.7715
# Epoch 123/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4477 - accuracy: 0.7670 - val_loss: 0.4421 - val_accuracy: 0.7715
# Epoch 124/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4477 - accuracy: 0.7671 - val_loss: 0.4421 - val_accuracy: 0.7716
# Epoch 125/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4474 - accuracy: 0.7671 - val_loss: 0.4424 - val_accuracy: 0.7717
# Epoch 126/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4475 - accuracy: 0.7673 - val_loss: 0.4415 - val_accuracy: 0.7716
# Epoch 127/140
# 12/12 [==============================] - 4s 296ms/step - loss: 0.4472 - accuracy: 0.7672 - val_loss: 0.4422 - val_accuracy: 0.7719
# Epoch 128/140
# 12/12 [==============================] - 4s 304ms/step - loss: 0.4473 - accuracy: 0.7672 - val_loss: 0.4427 - val_accuracy: 0.7710
# Epoch 129/140
# 12/12 [==============================] - 4s 303ms/step - loss: 0.4480 - accuracy: 0.7672 - val_loss: 0.4418 - val_accuracy: 0.7718
# Epoch 130/140
# 12/12 [==============================] - 4s 302ms/step - loss: 0.4470 - accuracy: 0.7675 - val_loss: 0.4413 - val_accuracy: 0.7719
# Epoch 131/140
# 12/12 [==============================] - 4s 294ms/step - loss: 0.4470 - accuracy: 0.7675 - val_loss: 0.4414 - val_accuracy: 0.7721
# Epoch 132/140
# 12/12 [==============================] - 4s 298ms/step - loss: 0.4473 - accuracy: 0.7673 - val_loss: 0.4439 - val_accuracy: 0.7725
# Epoch 133/140
# 12/12 [==============================] - 4s 294ms/step - loss: 0.4471 - accuracy: 0.7673 - val_loss: 0.4415 - val_accuracy: 0.7725
# Epoch 134/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4470 - accuracy: 0.7673 - val_loss: 0.4415 - val_accuracy: 0.7721
# Epoch 135/140
# 12/12 [==============================] - 4s 294ms/step - loss: 0.4468 - accuracy: 0.7676 - val_loss: 0.4412 - val_accuracy: 0.7719
# Epoch 136/140
# 12/12 [==============================] - 4s 294ms/step - loss: 0.4469 - accuracy: 0.7675 - val_loss: 0.4425 - val_accuracy: 0.7725
# Epoch 137/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4468 - accuracy: 0.7675 - val_loss: 0.4416 - val_accuracy: 0.7724
# Epoch 138/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4463 - accuracy: 0.7676 - val_loss: 0.4411 - val_accuracy: 0.7724
# Epoch 139/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4463 - accuracy: 0.7679 - val_loss: 0.4408 - val_accuracy: 0.7725
# Epoch 140/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4461 - accuracy: 0.7678 - val_loss: 0.4418 - val_accuracy: 0.7722

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 19s 6ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 516.3875617980957

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00627883],
#        [0.00752238],
#        [0.00903129],
#        ...,
#        [0.09079208],
#        [0.08191857],
#        [0.08074669]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14802216625371292
# 0.2040507411651563
# 0.38473648937124866
# 0.3002733832091258

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 91s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.57382881]
# [0.81100388]
# total acc [0.76850443]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 9512896768}
