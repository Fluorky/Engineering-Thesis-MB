# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x24f666e8040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x24fda7ab040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.002)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=32768)#, shuffle=False)
# Out:
# Epoch 1/140
# 12/12 [==============================] - 13s 472ms/step - loss: 0.5710 - accuracy: 0.7393 - val_loss: 0.5451 - val_accuracy: 0.7530
# Epoch 2/140
# 12/12 [==============================] - 4s 361ms/step - loss: 0.5404 - accuracy: 0.7389 - val_loss: 0.5087 - val_accuracy: 0.7530
# Epoch 3/140
# Epoch 121/140
# 12/12 [==============================] - 4s 298ms/step - loss: 0.4142 - accuracy: 0.7882 - val_loss: 0.4251 - val_accuracy: 0.7854
# Epoch 122/140
# 12/12 [==============================] - 4s 298ms/step - loss: 0.4140 - accuracy: 0.7878 - val_loss: 0.4322 - val_accuracy: 0.7863
# Epoch 123/140
# 12/12 [==============================] - 4s 300ms/step - loss: 0.4134 - accuracy: 0.7881 - val_loss: 0.4277 - val_accuracy: 0.7843
# Epoch 124/140
# 12/12 [==============================] - 4s 296ms/step - loss: 0.4132 - accuracy: 0.7885 - val_loss: 0.4251 - val_accuracy: 0.7846
# Epoch 125/140
# 12/12 [==============================] - 4s 299ms/step - loss: 0.4119 - accuracy: 0.7885 - val_loss: 0.4286 - val_accuracy: 0.7839
# Epoch 126/140
# 12/12 [==============================] - 4s 300ms/step - loss: 0.4134 - accuracy: 0.7882 - val_loss: 0.4263 - val_accuracy: 0.7841
# Epoch 127/140
# 12/12 [==============================] - 4s 300ms/step - loss: 0.4168 - accuracy: 0.7871 - val_loss: 0.4265 - val_accuracy: 0.7839
# Epoch 128/140
# 12/12 [==============================] - 4s 302ms/step - loss: 0.4136 - accuracy: 0.7883 - val_loss: 0.4288 - val_accuracy: 0.7842
# Epoch 129/140
# 12/12 [==============================] - 4s 310ms/step - loss: 0.4117 - accuracy: 0.7889 - val_loss: 0.4260 - val_accuracy: 0.7837
# Epoch 130/140
# 12/12 [==============================] - 4s 312ms/step - loss: 0.4109 - accuracy: 0.7889 - val_loss: 0.4318 - val_accuracy: 0.7844
# Epoch 131/140
# 12/12 [==============================] - 4s 310ms/step - loss: 0.4128 - accuracy: 0.7887 - val_loss: 0.4304 - val_accuracy: 0.7859
# Epoch 132/140
# 12/12 [==============================] - 4s 306ms/step - loss: 0.4123 - accuracy: 0.7888 - val_loss: 0.4448 - val_accuracy: 0.7855
# Epoch 133/140
# 12/12 [==============================] - 4s 302ms/step - loss: 0.4157 - accuracy: 0.7885 - val_loss: 0.4259 - val_accuracy: 0.7832
# Epoch 134/140
# 12/12 [==============================] - 4s 300ms/step - loss: 0.4125 - accuracy: 0.7890 - val_loss: 0.4346 - val_accuracy: 0.7849
# Epoch 135/140
# 12/12 [==============================] - 4s 301ms/step - loss: 0.4109 - accuracy: 0.7893 - val_loss: 0.4326 - val_accuracy: 0.7859
# Epoch 136/140
# 12/12 [==============================] - 4s 305ms/step - loss: 0.4107 - accuracy: 0.7894 - val_loss: 0.4313 - val_accuracy: 0.7852
# Epoch 137/140
# 12/12 [==============================] - 4s 306ms/step - loss: 0.4101 - accuracy: 0.7898 - val_loss: 0.4333 - val_accuracy: 0.7825
# Epoch 138/140
# 12/12 [==============================] - 4s 300ms/step - loss: 0.4103 - accuracy: 0.7900 - val_loss: 0.4270 - val_accuracy: 0.7856
# Epoch 139/140
# 12/12 [==============================] - 4s 307ms/step - loss: 0.4099 - accuracy: 0.7899 - val_loss: 0.4270 - val_accuracy: 0.7841
# Epoch 140/140
# 12/12 [==============================] - 4s 299ms/step - loss: 0.4107 - accuracy: 0.7896 - val_loss: 0.4268 - val_accuracy: 0.7847

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 21s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 652.0767650604248

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00052952],
#        [0.00189189],
#        [0.0005284 ],
#        ...,
#        [0.06847466],
#        [0.06531832],
#        [0.0724734 ]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14202052260567805
# 0.23632296048436507
# 0.37685610331488334
# 0.27957882798021594

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 98s 7ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.62263006]
# [0.82794503]
# total acc [0.78880298]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 9381751296}
