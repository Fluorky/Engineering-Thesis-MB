# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x22100000040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x22085a66040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.001)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=150,validation_data=(test_X, test_y),batch_size=32768)#, shuffle=False)
# Out:
# Epoch 1/150
# 12/12 [==============================] - 17s 772ms/step - loss: 0.5879 - accuracy: 0.7393 - val_loss: 0.5592 - val_accuracy: 0.7530
# Epoch 2/150
# 12/12 [==============================] - 7s 632ms/step - loss: 0.5722 - accuracy: 0.7393 - val_loss: 0.5553 - val_accuracy: 0.7530
# Epoch 3/150
# 12/12 [==============================] - 7s 568ms/step - loss: 0.5595 - accuracy: 0.7393 - val_loss: 0.5371 - val_accuracy: 0.7473
# Epoch 4/150
# 12/12 [==============================] - 6s 527ms/step - loss: 0.5389 - accuracy: 0.7330 - val_loss: 0.5143 - val_accuracy: 0.7530
# Epoch 5/150
# 12/12 [==============================] - 9s 721ms/step - loss: 0.5175 - accuracy: 0.7395 - val_loss: 0.4937 - val_accuracy: 0.7529
# Epoch 6/150
# 12/12 [==============================] - 12s 936ms/step - loss: 0.5067 - accuracy: 0.7380 - val_loss: 0.4903 - val_accuracy: 0.7528
# Epoch 7/150
# 12/12 [==============================] - 8s 638ms/step - loss: 0.5009 - accuracy: 0.7404 - val_loss: 0.4889 - val_accuracy: 0.7526
# Epoch 8/150
# 12/12 [==============================] - 8s 665ms/step - loss: 0.4979 - accuracy: 0.7435 - val_loss: 0.4847 - val_accuracy: 0.7531
# Epoch 9/150
# 12/12 [==============================] - 10s 795ms/step - loss: 0.4932 - accuracy: 0.7461 - val_loss: 0.4807 - val_accuracy: 0.7527
# Epoch 10/150
# 12/12 [==============================] - 7s 551ms/step - loss: 0.4890 - accuracy: 0.7480 - val_loss: 0.4779 - val_accuracy: 0.7525
# Epoch 11/150
# 12/12 [==============================] - 7s 549ms/step - loss: 0.4844 - accuracy: 0.7485 - val_loss: 0.4747 - val_accuracy: 0.7499
# Epoch 12/150
# 12/12 [==============================] - 6s 517ms/step - loss: 0.4788 - accuracy: 0.7503 - val_loss: 0.4696 - val_accuracy: 0.7553
# Epoch 13/150
# 12/12 [==============================] - 7s 560ms/step - loss: 0.4753 - accuracy: 0.7539 - val_loss: 0.4646 - val_accuracy: 0.7568
# Epoch 14/150
# 12/12 [==============================] - 6s 535ms/step - loss: 0.4735 - accuracy: 0.7550 - val_loss: 0.4631 - val_accuracy: 0.7612
# Epoch 15/150
# 12/12 [==============================] - 6s 524ms/step - loss: 0.4685 - accuracy: 0.7568 - val_loss: 0.4606 - val_accuracy: 0.7622
# Epoch 16/150
# 12/12 [==============================] - 6s 522ms/step - loss: 0.4646 - accuracy: 0.7586 - val_loss: 0.4573 - val_accuracy: 0.7602
# Epoch 17/150
# 12/12 [==============================] - 7s 597ms/step - loss: 0.4641 - accuracy: 0.7586 - val_loss: 0.4552 - val_accuracy: 0.7617
# Epoch 18/150
# 12/12 [==============================] - 10s 894ms/step - loss: 0.4659 - accuracy: 0.7581 - val_loss: 0.4584 - val_accuracy: 0.7600
# Epoch 19/150
# 12/12 [==============================] - 7s 621ms/step - loss: 0.4619 - accuracy: 0.7600 - val_loss: 0.4528 - val_accuracy: 0.7638
# Epoch 20/150
# 12/12 [==============================] - 15s 1s/step - loss: 0.4596 - accuracy: 0.7610 - val_loss: 0.4528 - val_accuracy: 0.7623
# Epoch 21/150
# 12/12 [==============================] - 9s 675ms/step - loss: 0.4567 - accuracy: 0.7615 - val_loss: 0.4494 - val_accuracy: 0.7649
# Epoch 22/150
# 12/12 [==============================] - 11s 980ms/step - loss: 0.4582 - accuracy: 0.7614 - val_loss: 0.4479 - val_accuracy: 0.7663
# Epoch 23/150
# 12/12 [==============================] - 7s 581ms/step - loss: 0.4601 - accuracy: 0.7615 - val_loss: 0.4488 - val_accuracy: 0.7673
# Epoch 24/150
# 12/12 [==============================] - 9s 674ms/step - loss: 0.4555 - accuracy: 0.7630 - val_loss: 0.4508 - val_accuracy: 0.7643
# Epoch 25/150
# 12/12 [==============================] - 11s 928ms/step - loss: 0.4586 - accuracy: 0.7631 - val_loss: 0.4495 - val_accuracy: 0.7677
# Epoch 26/150
# 12/12 [==============================] - 12s 989ms/step - loss: 0.4542 - accuracy: 0.7640 - val_loss: 0.4469 - val_accuracy: 0.7679
# Epoch 27/150
# 12/12 [==============================] - 11s 953ms/step - loss: 0.4521 - accuracy: 0.7645 - val_loss: 0.4452 - val_accuracy: 0.7688
# Epoch 28/150
# 12/12 [==============================] - 12s 992ms/step - loss: 0.4516 - accuracy: 0.7647 - val_loss: 0.4450 - val_accuracy: 0.7688
# Epoch 29/150
# 12/12 [==============================] - 9s 745ms/step - loss: 0.4518 - accuracy: 0.7653 - val_loss: 0.4491 - val_accuracy: 0.7661
# Epoch 30/150
# 12/12 [==============================] - 11s 950ms/step - loss: 0.4507 - accuracy: 0.7659 - val_loss: 0.4432 - val_accuracy: 0.7710
# Epoch 31/150
# 12/12 [==============================] - 10s 883ms/step - loss: 0.4498 - accuracy: 0.7663 - val_loss: 0.4427 - val_accuracy: 0.7706
# Epoch 32/150
# 12/12 [==============================] - 12s 970ms/step - loss: 0.4507 - accuracy: 0.7664 - val_loss: 0.4438 - val_accuracy: 0.7712
# Epoch 33/150
# 12/12 [==============================] - 7s 617ms/step - loss: 0.4503 - accuracy: 0.7663 - val_loss: 0.4438 - val_accuracy: 0.7713
# Epoch 34/150
# 12/12 [==============================] - 9s 764ms/step - loss: 0.4513 - accuracy: 0.7669 - val_loss: 0.4437 - val_accuracy: 0.7721
# Epoch 35/150
# 12/12 [==============================] - 12s 969ms/step - loss: 0.4482 - accuracy: 0.7669 - val_loss: 0.4419 - val_accuracy: 0.7725
# Epoch 36/150
# 12/12 [==============================] - 10s 812ms/step - loss: 0.4478 - accuracy: 0.7679 - val_loss: 0.4406 - val_accuracy: 0.7734
# Epoch 37/150
# 12/12 [==============================] - 14s 1s/step - loss: 0.4469 - accuracy: 0.7683 - val_loss: 0.4425 - val_accuracy: 0.7723
# Epoch 38/150
# 12/12 [==============================] - 8s 668ms/step - loss: 0.4477 - accuracy: 0.7682 - val_loss: 0.4423 - val_accuracy: 0.7740
# Epoch 39/150
# 12/12 [==============================] - 7s 549ms/step - loss: 0.4461 - accuracy: 0.7686 - val_loss: 0.4407 - val_accuracy: 0.7738
# Epoch 40/150
# 12/12 [==============================] - 9s 728ms/step - loss: 0.4467 - accuracy: 0.7689 - val_loss: 0.4396 - val_accuracy: 0.7749
# Epoch 41/150
# 12/12 [==============================] - 10s 865ms/step - loss: 0.4469 - accuracy: 0.7691 - val_loss: 0.4401 - val_accuracy: 0.7741
# Epoch 42/150
# 12/12 [==============================] - 12s 1s/step - loss: 0.4449 - accuracy: 0.7696 - val_loss: 0.4399 - val_accuracy: 0.7736
# Epoch 43/150
# 12/12 [==============================] - 7s 598ms/step - loss: 0.4440 - accuracy: 0.7704 - val_loss: 0.4377 - val_accuracy: 0.7757
# Epoch 44/150
# 12/12 [==============================] - 8s 711ms/step - loss: 0.4442 - accuracy: 0.7706 - val_loss: 0.4424 - val_accuracy: 0.7758
# Epoch 45/150
# 12/12 [==============================] - 9s 733ms/step - loss: 0.4454 - accuracy: 0.7707 - val_loss: 0.4383 - val_accuracy: 0.7764
# Epoch 46/150
# 12/12 [==============================] - 9s 807ms/step - loss: 0.4437 - accuracy: 0.7711 - val_loss: 0.4374 - val_accuracy: 0.7763
# Epoch 47/150
# 12/12 [==============================] - 8s 672ms/step - loss: 0.4440 - accuracy: 0.7718 - val_loss: 0.4385 - val_accuracy: 0.7762
# Epoch 48/150
# 12/12 [==============================] - 8s 706ms/step - loss: 0.4438 - accuracy: 0.7720 - val_loss: 0.4408 - val_accuracy: 0.7758
# Epoch 49/150
# 12/12 [==============================] - 12s 993ms/step - loss: 0.4420 - accuracy: 0.7724 - val_loss: 0.4357 - val_accuracy: 0.7775
# Epoch 50/150
# 12/12 [==============================] - 12s 911ms/step - loss: 0.4409 - accuracy: 0.7731 - val_loss: 0.4359 - val_accuracy: 0.7773
# Epoch 51/150
# 12/12 [==============================] - 11s 923ms/step - loss: 0.4403 - accuracy: 0.7734 - val_loss: 0.4346 - val_accuracy: 0.7774
# Epoch 52/150
# 12/12 [==============================] - 9s 704ms/step - loss: 0.4398 - accuracy: 0.7735 - val_loss: 0.4362 - val_accuracy: 0.7777
# Epoch 53/150
# 12/12 [==============================] - 9s 741ms/step - loss: 0.4404 - accuracy: 0.7737 - val_loss: 0.4377 - val_accuracy: 0.7782
# Epoch 54/150
# 12/12 [==============================] - 8s 672ms/step - loss: 0.4401 - accuracy: 0.7741 - val_loss: 0.4347 - val_accuracy: 0.7775
# Epoch 55/150
# 12/12 [==============================] - 8s 657ms/step - loss: 0.4411 - accuracy: 0.7743 - val_loss: 0.4336 - val_accuracy: 0.7787
# Epoch 56/150
# 12/12 [==============================] - 12s 1s/step - loss: 0.4390 - accuracy: 0.7745 - val_loss: 0.4336 - val_accuracy: 0.7777
# Epoch 57/150
# 12/12 [==============================] - 10s 745ms/step - loss: 0.4395 - accuracy: 0.7749 - val_loss: 0.4339 - val_accuracy: 0.7785
# Epoch 58/150
# 12/12 [==============================] - 8s 681ms/step - loss: 0.4393 - accuracy: 0.7750 - val_loss: 0.4351 - val_accuracy: 0.7778
# Epoch 59/150
# 12/12 [==============================] - 11s 960ms/step - loss: 0.4377 - accuracy: 0.7754 - val_loss: 0.4340 - val_accuracy: 0.7786
# Epoch 60/150
# 12/12 [==============================] - 13s 1s/step - loss: 0.4372 - accuracy: 0.7758 - val_loss: 0.4320 - val_accuracy: 0.7795
# Epoch 61/150
# 12/12 [==============================] - 10s 822ms/step - loss: 0.4374 - accuracy: 0.7758 - val_loss: 0.4331 - val_accuracy: 0.7786
# Epoch 62/150
# 12/12 [==============================] - 7s 536ms/step - loss: 0.4372 - accuracy: 0.7760 - val_loss: 0.4334 - val_accuracy: 0.7780
# Epoch 63/150
# 12/12 [==============================] - 9s 737ms/step - loss: 0.4365 - accuracy: 0.7765 - val_loss: 0.4382 - val_accuracy: 0.7775
# Epoch 64/150
# 12/12 [==============================] - 8s 644ms/step - loss: 0.4386 - accuracy: 0.7758 - val_loss: 0.4356 - val_accuracy: 0.7756
# Epoch 65/150
# 12/12 [==============================] - 11s 982ms/step - loss: 0.4370 - accuracy: 0.7762 - val_loss: 0.4349 - val_accuracy: 0.7762
# Epoch 66/150
# 12/12 [==============================] - 11s 903ms/step - loss: 0.4369 - accuracy: 0.7770 - val_loss: 0.4330 - val_accuracy: 0.7779
# Epoch 67/150
# 12/12 [==============================] - 13s 1s/step - loss: 0.4356 - accuracy: 0.7764 - val_loss: 0.4332 - val_accuracy: 0.7793
# Epoch 68/150
# 12/12 [==============================] - 16s 1s/step - loss: 0.4358 - accuracy: 0.7772 - val_loss: 0.4347 - val_accuracy: 0.7802
# Epoch 69/150
# 12/12 [==============================] - 9s 692ms/step - loss: 0.4352 - accuracy: 0.7771 - val_loss: 0.4334 - val_accuracy: 0.7766
# Epoch 70/150
# 12/12 [==============================] - 12s 1s/step - loss: 0.4347 - accuracy: 0.7770 - val_loss: 0.4305 - val_accuracy: 0.7786
# Epoch 71/150
# 12/12 [==============================] - 12s 995ms/step - loss: 0.4351 - accuracy: 0.7773 - val_loss: 0.4327 - val_accuracy: 0.7766
# Epoch 72/150
# 12/12 [==============================] - 10s 843ms/step - loss: 0.4350 - accuracy: 0.7777 - val_loss: 0.4315 - val_accuracy: 0.7792
# Epoch 73/150
# 12/12 [==============================] - 11s 911ms/step - loss: 0.4339 - accuracy: 0.7775 - val_loss: 0.4338 - val_accuracy: 0.7788
# Epoch 74/150
# 12/12 [==============================] - 8s 629ms/step - loss: 0.4346 - accuracy: 0.7778 - val_loss: 0.4307 - val_accuracy: 0.7778
# Epoch 75/150
# 12/12 [==============================] - 7s 605ms/step - loss: 0.4330 - accuracy: 0.7782 - val_loss: 0.4306 - val_accuracy: 0.7783
# Epoch 76/150
# 12/12 [==============================] - 8s 640ms/step - loss: 0.4328 - accuracy: 0.7780 - val_loss: 0.4300 - val_accuracy: 0.7802
# Epoch 77/150
# 12/12 [==============================] - 7s 609ms/step - loss: 0.4326 - accuracy: 0.7784 - val_loss: 0.4304 - val_accuracy: 0.7796
# Epoch 78/150
# 12/12 [==============================] - 8s 670ms/step - loss: 0.4326 - accuracy: 0.7784 - val_loss: 0.4316 - val_accuracy: 0.7803
# Epoch 79/150
# 12/12 [==============================] - 7s 597ms/step - loss: 0.4326 - accuracy: 0.7784 - val_loss: 0.4299 - val_accuracy: 0.7788
# Epoch 80/150
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4329 - accuracy: 0.7784 - val_loss: 0.4296 - val_accuracy: 0.7799
# Epoch 81/150
# 12/12 [==============================] - 7s 624ms/step - loss: 0.4332 - accuracy: 0.7782 - val_loss: 0.4323 - val_accuracy: 0.7767
# Epoch 82/150
# 12/12 [==============================] - 9s 730ms/step - loss: 0.4322 - accuracy: 0.7785 - val_loss: 0.4308 - val_accuracy: 0.7797
# Epoch 83/150
# 12/12 [==============================] - 13s 1s/step - loss: 0.4313 - accuracy: 0.7792 - val_loss: 0.4328 - val_accuracy: 0.7759
# Epoch 84/150
# 12/12 [==============================] - 10s 845ms/step - loss: 0.4355 - accuracy: 0.7782 - val_loss: 0.4333 - val_accuracy: 0.7767
# Epoch 85/150
# 12/12 [==============================] - 8s 659ms/step - loss: 0.4325 - accuracy: 0.7785 - val_loss: 0.4319 - val_accuracy: 0.7817
# Epoch 86/150
# 12/12 [==============================] - 9s 790ms/step - loss: 0.4312 - accuracy: 0.7789 - val_loss: 0.4301 - val_accuracy: 0.7796
# Epoch 87/150
# 12/12 [==============================] - 12s 987ms/step - loss: 0.4335 - accuracy: 0.7792 - val_loss: 0.4328 - val_accuracy: 0.7759
# Epoch 88/150
# 12/12 [==============================] - 11s 887ms/step - loss: 0.4325 - accuracy: 0.7788 - val_loss: 0.4306 - val_accuracy: 0.7814
# Epoch 89/150
# 12/12 [==============================] - 14s 1s/step - loss: 0.4311 - accuracy: 0.7792 - val_loss: 0.4287 - val_accuracy: 0.7807
# Epoch 90/150
# 12/12 [==============================] - 11s 975ms/step - loss: 0.4305 - accuracy: 0.7798 - val_loss: 0.4310 - val_accuracy: 0.7768
# Epoch 91/150
# 12/12 [==============================] - 13s 1s/step - loss: 0.4306 - accuracy: 0.7795 - val_loss: 0.4288 - val_accuracy: 0.7798
# Epoch 92/150
# 12/12 [==============================] - 13s 1s/step - loss: 0.4299 - accuracy: 0.7799 - val_loss: 0.4368 - val_accuracy: 0.7812
# Epoch 93/150
# 12/12 [==============================] - 12s 1s/step - loss: 0.4306 - accuracy: 0.7799 - val_loss: 0.4308 - val_accuracy: 0.7795
# Epoch 94/150
# 12/12 [==============================] - 11s 901ms/step - loss: 0.4304 - accuracy: 0.7800 - val_loss: 0.4306 - val_accuracy: 0.7781
# Epoch 95/150
# 12/12 [==============================] - 10s 813ms/step - loss: 0.4301 - accuracy: 0.7801 - val_loss: 0.4300 - val_accuracy: 0.7815
# Epoch 96/150
# 12/12 [==============================] - 9s 730ms/step - loss: 0.4296 - accuracy: 0.7801 - val_loss: 0.4299 - val_accuracy: 0.7808
# Epoch 97/150
# 12/12 [==============================] - 9s 760ms/step - loss: 0.4290 - accuracy: 0.7803 - val_loss: 0.4299 - val_accuracy: 0.7802
# Epoch 98/150
# 12/12 [==============================] - 10s 852ms/step - loss: 0.4287 - accuracy: 0.7802 - val_loss: 0.4296 - val_accuracy: 0.7817
# Epoch 99/150
# 12/12 [==============================] - 12s 1s/step - loss: 0.4291 - accuracy: 0.7804 - val_loss: 0.4325 - val_accuracy: 0.7770
# Epoch 100/150
# 12/12 [==============================] - 13s 1s/step - loss: 0.4297 - accuracy: 0.7800 - val_loss: 0.4355 - val_accuracy: 0.7820
# Epoch 101/150
# 12/12 [==============================] - 9s 718ms/step - loss: 0.4292 - accuracy: 0.7806 - val_loss: 0.4306 - val_accuracy: 0.7804
# Epoch 102/150
# 12/12 [==============================] - 12s 981ms/step - loss: 0.4282 - accuracy: 0.7807 - val_loss: 0.4326 - val_accuracy: 0.7787
# Epoch 103/150
# 12/12 [==============================] - 9s 777ms/step - loss: 0.4283 - accuracy: 0.7807 - val_loss: 0.4338 - val_accuracy: 0.7819
# Epoch 104/150
# 12/12 [==============================] - 12s 1s/step - loss: 0.4288 - accuracy: 0.7807 - val_loss: 0.4291 - val_accuracy: 0.7784
# Epoch 105/150
# 12/12 [==============================] - 12s 958ms/step - loss: 0.4287 - accuracy: 0.7807 - val_loss: 0.4285 - val_accuracy: 0.7817
# Epoch 106/150
# 12/12 [==============================] - 10s 813ms/step - loss: 0.4292 - accuracy: 0.7810 - val_loss: 0.4320 - val_accuracy: 0.7751
# Epoch 107/150
# 12/12 [==============================] - 8s 639ms/step - loss: 0.4279 - accuracy: 0.7808 - val_loss: 0.4298 - val_accuracy: 0.7800
# Epoch 108/150
# 12/12 [==============================] - 6s 528ms/step - loss: 0.4280 - accuracy: 0.7810 - val_loss: 0.4293 - val_accuracy: 0.7809
# Epoch 109/150
# 12/12 [==============================] - 7s 581ms/step - loss: 0.4280 - accuracy: 0.7812 - val_loss: 0.4285 - val_accuracy: 0.7797
# Epoch 110/150
# 12/12 [==============================] - 10s 819ms/step - loss: 0.4266 - accuracy: 0.7812 - val_loss: 0.4318 - val_accuracy: 0.7821
# Epoch 111/150
# 12/12 [==============================] - 11s 882ms/step - loss: 0.4272 - accuracy: 0.7812 - val_loss: 0.4319 - val_accuracy: 0.7812
# Epoch 112/150
# 12/12 [==============================] - 12s 1s/step - loss: 0.4289 - accuracy: 0.7808 - val_loss: 0.4443 - val_accuracy: 0.7803
# Epoch 113/150
# 12/12 [==============================] - 10s 806ms/step - loss: 0.4295 - accuracy: 0.7811 - val_loss: 0.4320 - val_accuracy: 0.7766
# Epoch 114/150
# 12/12 [==============================] - 12s 943ms/step - loss: 0.4278 - accuracy: 0.7813 - val_loss: 0.4296 - val_accuracy: 0.7798
# Epoch 115/150
# 12/12 [==============================] - 14s 1s/step - loss: 0.4269 - accuracy: 0.7818 - val_loss: 0.4294 - val_accuracy: 0.7807
# Epoch 116/150
# 12/12 [==============================] - 9s 799ms/step - loss: 0.4269 - accuracy: 0.7817 - val_loss: 0.4285 - val_accuracy: 0.7792
# Epoch 117/150
# 12/12 [==============================] - 9s 705ms/step - loss: 0.4269 - accuracy: 0.7821 - val_loss: 0.4295 - val_accuracy: 0.7821
# Epoch 118/150
# 12/12 [==============================] - 11s 907ms/step - loss: 0.4273 - accuracy: 0.7817 - val_loss: 0.4280 - val_accuracy: 0.7828
# Epoch 119/150
# 12/12 [==============================] - 8s 691ms/step - loss: 0.4262 - accuracy: 0.7821 - val_loss: 0.4302 - val_accuracy: 0.7762
# Epoch 120/150
# 12/12 [==============================] - 10s 820ms/step - loss: 0.4257 - accuracy: 0.7826 - val_loss: 0.4307 - val_accuracy: 0.7821
# Epoch 121/150
# 12/12 [==============================] - 10s 894ms/step - loss: 0.4251 - accuracy: 0.7830 - val_loss: 0.4293 - val_accuracy: 0.7822
# Epoch 122/150
# 12/12 [==============================] - 8s 733ms/step - loss: 0.4253 - accuracy: 0.7823 - val_loss: 0.4284 - val_accuracy: 0.7836
# Epoch 123/150
# 12/12 [==============================] - 10s 860ms/step - loss: 0.4256 - accuracy: 0.7823 - val_loss: 0.4272 - val_accuracy: 0.7826
# Epoch 124/150
# 12/12 [==============================] - 8s 630ms/step - loss: 0.4260 - accuracy: 0.7823 - val_loss: 0.4283 - val_accuracy: 0.7832
# Epoch 125/150
# 12/12 [==============================] - 7s 612ms/step - loss: 0.4241 - accuracy: 0.7830 - val_loss: 0.4331 - val_accuracy: 0.7745
# Epoch 126/150
# 12/12 [==============================] - 10s 839ms/step - loss: 0.4255 - accuracy: 0.7830 - val_loss: 0.4286 - val_accuracy: 0.7828
# Epoch 127/150
# 12/12 [==============================] - 10s 881ms/step - loss: 0.4239 - accuracy: 0.7833 - val_loss: 0.4315 - val_accuracy: 0.7835
# Epoch 128/150
# 12/12 [==============================] - 10s 838ms/step - loss: 0.4235 - accuracy: 0.7835 - val_loss: 0.4328 - val_accuracy: 0.7834
# Epoch 129/150
# 12/12 [==============================] - 11s 886ms/step - loss: 0.4240 - accuracy: 0.7837 - val_loss: 0.4311 - val_accuracy: 0.7830
# Epoch 130/150
# 12/12 [==============================] - 11s 952ms/step - loss: 0.4228 - accuracy: 0.7838 - val_loss: 0.4280 - val_accuracy: 0.7821
# Epoch 131/150
# 12/12 [==============================] - 13s 1s/step - loss: 0.4235 - accuracy: 0.7838 - val_loss: 0.4273 - val_accuracy: 0.7817
# Epoch 132/150
# 12/12 [==============================] - 11s 919ms/step - loss: 0.4229 - accuracy: 0.7836 - val_loss: 0.4286 - val_accuracy: 0.7815
# Epoch 133/150
# 12/12 [==============================] - 15s 1s/step - loss: 0.4232 - accuracy: 0.7839 - val_loss: 0.4298 - val_accuracy: 0.7774
# Epoch 134/150
# 12/12 [==============================] - 10s 875ms/step - loss: 0.4224 - accuracy: 0.7842 - val_loss: 0.4267 - val_accuracy: 0.7822
# Epoch 135/150
# 12/12 [==============================] - 9s 727ms/step - loss: 0.4219 - accuracy: 0.7842 - val_loss: 0.4317 - val_accuracy: 0.7829
# Epoch 136/150
# 12/12 [==============================] - 15s 1s/step - loss: 0.4224 - accuracy: 0.7843 - val_loss: 0.4278 - val_accuracy: 0.7797
# Epoch 137/150
# 12/12 [==============================] - 8s 545ms/step - loss: 0.4221 - accuracy: 0.7843 - val_loss: 0.4259 - val_accuracy: 0.7836
# Epoch 138/150
# 12/12 [==============================] - 6s 520ms/step - loss: 0.4219 - accuracy: 0.7846 - val_loss: 0.4353 - val_accuracy: 0.7835
# Epoch 139/150
# 12/12 [==============================] - 8s 654ms/step - loss: 0.4235 - accuracy: 0.7844 - val_loss: 0.4333 - val_accuracy: 0.7843
# Epoch 140/150
# 12/12 [==============================] - 7s 539ms/step - loss: 0.4213 - accuracy: 0.7845 - val_loss: 0.4275 - val_accuracy: 0.7821
# Epoch 141/150
# 12/12 [==============================] - 8s 666ms/step - loss: 0.4208 - accuracy: 0.7851 - val_loss: 0.4290 - val_accuracy: 0.7779
# Epoch 142/150
# 12/12 [==============================] - 5s 447ms/step - loss: 0.4225 - accuracy: 0.7846 - val_loss: 0.4248 - val_accuracy: 0.7825
# Epoch 143/150
# 12/12 [==============================] - 5s 450ms/step - loss: 0.4216 - accuracy: 0.7849 - val_loss: 0.4261 - val_accuracy: 0.7831
# Epoch 144/150
# 12/12 [==============================] - 5s 443ms/step - loss: 0.4211 - accuracy: 0.7848 - val_loss: 0.4328 - val_accuracy: 0.7836
# Epoch 145/150
# 12/12 [==============================] - 5s 458ms/step - loss: 0.4209 - accuracy: 0.7851 - val_loss: 0.4274 - val_accuracy: 0.7837
# Epoch 146/150
# 12/12 [==============================] - 5s 444ms/step - loss: 0.4205 - accuracy: 0.7852 - val_loss: 0.4264 - val_accuracy: 0.7828
# Epoch 147/150
# 12/12 [==============================] - 6s 461ms/step - loss: 0.4199 - accuracy: 0.7852 - val_loss: 0.4304 - val_accuracy: 0.7827
# Epoch 148/150
# 12/12 [==============================] - 5s 444ms/step - loss: 0.4210 - accuracy: 0.7851 - val_loss: 0.4265 - val_accuracy: 0.7821
# Epoch 149/150
# 12/12 [==============================] - 5s 441ms/step - loss: 0.4199 - accuracy: 0.7852 - val_loss: 0.4268 - val_accuracy: 0.7821
# Epoch 150/150
# 12/12 [==============================] - 6s 468ms/step - loss: 0.4193 - accuracy: 0.7857 - val_loss: 0.4272 - val_accuracy: 0.7830

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 22s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 1445.103768825531

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00066608],
#        [0.00097133],
#        [0.00094272],
#        ...,
#        [0.04376645],
#        [0.04716168],
#        [0.04916836]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14272064305030227
# 0.23255825170393396
# 0.377783857583013
# 0.27927818657399317

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 103s 7ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.61836941]
# [0.82294916]
# total acc [0.78544514]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 9512951040}
