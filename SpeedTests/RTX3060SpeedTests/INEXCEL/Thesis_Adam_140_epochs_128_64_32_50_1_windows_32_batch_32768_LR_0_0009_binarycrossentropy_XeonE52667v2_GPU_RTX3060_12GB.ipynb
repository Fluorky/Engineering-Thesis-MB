# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1d7bcd21040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1d830dd0040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0009)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=32768)#, shuffle=False)
# Out:
# Epoch 1/140
# 12/12 [==============================] - 12s 415ms/step - loss: 0.6117 - accuracy: 0.7290 - val_loss: 0.5616 - val_accuracy: 0.7530
# Epoch 2/140
# 12/12 [==============================] - 4s 306ms/step - loss: 0.5775 - accuracy: 0.7393 - val_loss: 0.5597 - val_accuracy: 0.7530
# Epoch 3/140
# 12/12 [==============================] - 4s 308ms/step - loss: 0.5739 - accuracy: 0.7393 - val_loss: 0.5589 - val_accuracy: 0.7530
# Epoch 4/140
# 12/12 [==============================] - 4s 304ms/step - loss: 0.5714 - accuracy: 0.7393 - val_loss: 0.5548 - val_accuracy: 0.7530
# Epoch 5/140
# 12/12 [==============================] - 4s 305ms/step - loss: 0.5594 - accuracy: 0.7390 - val_loss: 0.5443 - val_accuracy: 0.7351
# Epoch 6/140
# 12/12 [==============================] - 4s 308ms/step - loss: 0.5424 - accuracy: 0.7377 - val_loss: 0.5153 - val_accuracy: 0.7538
# Epoch 7/140
# 12/12 [==============================] - 4s 303ms/step - loss: 0.5202 - accuracy: 0.7399 - val_loss: 0.4963 - val_accuracy: 0.7521
# Epoch 8/140
# 12/12 [==============================] - 4s 307ms/step - loss: 0.5077 - accuracy: 0.7391 - val_loss: 0.4903 - val_accuracy: 0.7527
# Epoch 9/140
# 12/12 [==============================] - 4s 306ms/step - loss: 0.5026 - accuracy: 0.7408 - val_loss: 0.4945 - val_accuracy: 0.7532
# Epoch 10/140
# 12/12 [==============================] - 4s 306ms/step - loss: 0.4992 - accuracy: 0.7438 - val_loss: 0.4822 - val_accuracy: 0.7532
# Epoch 11/140
# 12/12 [==============================] - 4s 306ms/step - loss: 0.4948 - accuracy: 0.7459 - val_loss: 0.4807 - val_accuracy: 0.7532
# Epoch 12/140
# 12/12 [==============================] - 4s 314ms/step - loss: 0.4919 - accuracy: 0.7476 - val_loss: 0.4780 - val_accuracy: 0.7534
# Epoch 13/140
# 12/12 [==============================] - 4s 303ms/step - loss: 0.4863 - accuracy: 0.7487 - val_loss: 0.4743 - val_accuracy: 0.7535
# Epoch 14/140
# 12/12 [==============================] - 4s 303ms/step - loss: 0.4804 - accuracy: 0.7509 - val_loss: 0.4743 - val_accuracy: 0.7528
# Epoch 15/140
# 12/12 [==============================] - 4s 300ms/step - loss: 0.4766 - accuracy: 0.7539 - val_loss: 0.4693 - val_accuracy: 0.7595
# Epoch 16/140
# 12/12 [==============================] - 4s 300ms/step - loss: 0.4748 - accuracy: 0.7554 - val_loss: 0.4632 - val_accuracy: 0.7607
# Epoch 17/140
# 12/12 [==============================] - 4s 299ms/step - loss: 0.4700 - accuracy: 0.7574 - val_loss: 0.4607 - val_accuracy: 0.7622
# Epoch 18/140
# 12/12 [==============================] - 4s 299ms/step - loss: 0.4686 - accuracy: 0.7583 - val_loss: 0.4589 - val_accuracy: 0.7622
# Epoch 19/140
# 12/12 [==============================] - 4s 305ms/step - loss: 0.4656 - accuracy: 0.7593 - val_loss: 0.4575 - val_accuracy: 0.7652
# Epoch 20/140
# 12/12 [==============================] - 4s 308ms/step - loss: 0.4695 - accuracy: 0.7588 - val_loss: 0.4579 - val_accuracy: 0.7654
# Epoch 21/140
# 12/12 [==============================] - 4s 306ms/step - loss: 0.4652 - accuracy: 0.7592 - val_loss: 0.4585 - val_accuracy: 0.7626
# Epoch 41/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4509 - accuracy: 0.7672 - val_loss: 0.4419 - val_accuracy: 0.7728
# Epoch 42/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4485 - accuracy: 0.7675 - val_loss: 0.4411 - val_accuracy: 0.7729
# Epoch 43/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4487 - accuracy: 0.7681 - val_loss: 0.4416 - val_accuracy: 0.7739
# Epoch 44/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4485 - accuracy: 0.7681 - val_loss: 0.4416 - val_accuracy: 0.7735
# Epoch 45/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4475 - accuracy: 0.7685 - val_loss: 0.4426 - val_accuracy: 0.7712
# Epoch 46/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4470 - accuracy: 0.7685 - val_loss: 0.4402 - val_accuracy: 0.7739
# Epoch 47/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4460 - accuracy: 0.7689 - val_loss: 0.4402 - val_accuracy: 0.7743
# Epoch 48/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4468 - accuracy: 0.7694 - val_loss: 0.4418 - val_accuracy: 0.7745
# Epoch 49/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4466 - accuracy: 0.7694 - val_loss: 0.4410 - val_accuracy: 0.7747
# Epoch 50/140
# 12/12 [==============================] - 3s 293ms/step - loss: 0.4469 - accuracy: 0.7694 - val_loss: 0.4387 - val_accuracy: 0.7751
# Epoch 51/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4467 - accuracy: 0.7696 - val_loss: 0.4411 - val_accuracy: 0.7744
# Epoch 52/140
# 12/12 [==============================] - 3s 293ms/step - loss: 0.4451 - accuracy: 0.7700 - val_loss: 0.4393 - val_accuracy: 0.7755
# Epoch 53/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4440 - accuracy: 0.7703 - val_loss: 0.4384 - val_accuracy: 0.7761
# Epoch 54/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4439 - accuracy: 0.7709 - val_loss: 0.4378 - val_accuracy: 0.7757
# Epoch 55/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4444 - accuracy: 0.7708 - val_loss: 0.4394 - val_accuracy: 0.7755
# Epoch 56/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4459 - accuracy: 0.7710 - val_loss: 0.4392 - val_accuracy: 0.7742
# Epoch 57/140
# 12/12 [==============================] - 3s 293ms/step - loss: 0.4437 - accuracy: 0.7707 - val_loss: 0.4375 - val_accuracy: 0.7769
# Epoch 58/140
# 12/12 [==============================] - 3s 293ms/step - loss: 0.4424 - accuracy: 0.7715 - val_loss: 0.4377 - val_accuracy: 0.7751
# Epoch 59/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4423 - accuracy: 0.7719 - val_loss: 0.4361 - val_accuracy: 0.7768
# Epoch 60/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4451 - accuracy: 0.7715 - val_loss: 0.4392 - val_accuracy: 0.7752
140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4379 - accuracy: 0.7755 - val_loss: 0.4355 - val_accuracy: 0.7790
# Epoch 81/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4377 - accuracy: 0.7758 - val_loss: 0.4386 - val_accuracy: 0.7783
# Epoch 82/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4377 - accuracy: 0.7758 - val_loss: 0.4335 - val_accuracy: 0.7785
# Epoch 83/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4365 - accuracy: 0.7763 - val_loss: 0.4330 - val_accuracy: 0.7785
# Epoch 84/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4360 - accuracy: 0.7763 - val_loss: 0.4321 - val_accuracy: 0.7786
# Epoch 85/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4358 - accuracy: 0.7766 - val_loss: 0.4334 - val_accuracy: 0.7790
# Epoch 86/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4353 - accuracy: 0.7768 - val_loss: 0.4331 - val_accuracy: 0.7799
# Epoch 87/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4348 - accuracy: 0.7768 - val_loss: 0.4377 - val_accuracy: 0.7782
# Epoch 88/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4372 - accuracy: 0.7767 - val_loss: 0.4379 - val_accuracy: 0.7789
# Epoch 89/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4370 - accuracy: 0.7766 - val_loss: 0.4369 - val_accuracy: 0.7795
# Epoch 90/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4363 - accuracy: 0.7768 - val_loss: 0.4325 - val_accuracy: 0.7781
# Epoch 91/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4343 - accuracy: 0.7771 - val_loss: 0.4320 - val_accuracy: 0.7782
# Epoch 92/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4342 - accuracy: 0.7774 - val_loss: 0.4311 - val_accuracy: 0.7794
# Epoch 93/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4339 - accuracy: 0.7777 - val_loss: 0.4312 - val_accuracy: 0.7790
# Epoch 94/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4345 - accuracy: 0.7774 - val_loss: 0.4311 - val_accuracy: 0.7798
# Epoch 95/140
# 12/12 [==============================] - 4s 300ms/step - loss: 0.4333 - accuracy: 0.7778 - val_loss: 0.4318 - val_accuracy: 0.7808
# Epoch 96/140
# 12/12 [==============================] - 4s 306ms/step - loss: 0.4345 - accuracy: 0.7774 - val_loss: 0.4311 - val_accuracy: 0.7796
# Epoch 97/140
# 12/12 [==============================] - 4s 305ms/step - loss: 0.4344 - accuracy: 0.7774 - val_loss: 0.4340 - val_accuracy: 0.7790
# Epoch 98/140
# 12/12 [==============================] - 4s 298ms/step - loss: 0.4337 - accuracy: 0.7779 - val_loss: 0.4303 - val_accuracy: 0.7804
# Epoch 99/140
# 12/12 [==============================] - 4s 304ms/step - loss: 0.4326 - accuracy: 0.7783 - val_loss: 0.4306 - val_accuracy: 0.7794
# Epoch 100/140
# 12/12 [==============================] - 4s 306ms/step - loss: 0.4327 - accuracy: 0.7781 - val_loss: 0.4318 - val_accuracy: 0.7778
# Epoch 101/140
# 12/12 [==============================] - 4s 312ms/step - loss: 0.4257 - accuracy: 0.7818 - val_loss: 0.4308 - val_accuracy: 0.7765
# Epoch 140/140
# 12/12 [==============================] - 4s 316ms/step - loss: 0.4281 - accuracy: 0.7814 - val_loss: 0.4286 - val_accuracy: 0.7804

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 22s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 534.2223989963531

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00103583],
#        [0.00145832],
#        [0.00138994],
#        ...,
#        [0.05642628],
#        [0.06105421],
#        [0.06277987]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14337571933048676
# 0.2290357557637015
# 0.37864986376662907
# 0.2839114428461718

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 99s 7ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60885849]
# [0.81953402]
# total acc [0.78142666]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 9512897280}
