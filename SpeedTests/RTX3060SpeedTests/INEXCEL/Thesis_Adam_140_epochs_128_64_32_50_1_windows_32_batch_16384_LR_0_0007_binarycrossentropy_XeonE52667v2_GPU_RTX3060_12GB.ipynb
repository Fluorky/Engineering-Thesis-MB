# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2022d402040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x202a14b9040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 15s 201ms/step - loss: 0.8563 - accuracy: 0.4290 - val_loss: 0.5840 - val_accuracy: 0.7530
# Epoch 2/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.5771 - accuracy: 0.7393 - val_loss: 0.5591 - val_accuracy: 0.7530
# Epoch 3/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5745 - accuracy: 0.7393 - val_loss: 0.5592 - val_accuracy: 0.7530
# Epoch 4/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.5738 - accuracy: 0.7393 - val_loss: 0.5596 - val_accuracy: 0.7530
# Epoch 5/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5738 - accuracy: 0.7393 - val_loss: 0.5594 - val_accuracy: 0.7530
# Epoch 6/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5738 - accuracy: 0.7393 - val_loss: 0.5595 - val_accuracy: 0.7530
# Epoch 7/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5595 - val_accuracy: 0.7530
# Epoch 8/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5736 - accuracy: 0.7393 - val_loss: 0.5593 - val_accuracy: 0.7530
# Epoch 9/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5733 - accuracy: 0.7393 - val_loss: 0.5592 - val_accuracy: 0.7530
# Epoch 10/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5719 - accuracy: 0.7393 - val_loss: 0.5558 - val_accuracy: 0.7530
# Epoch 11/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5626 - accuracy: 0.7393 - val_loss: 0.5447 - val_accuracy: 0.7530
# Epoch 12/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5485 - accuracy: 0.7393 - val_loss: 0.5249 - val_accuracy: 0.7530
# Epoch 13/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.5301 - accuracy: 0.7393 - val_loss: 0.5058 - val_accuracy: 0.7530
# Epoch 14/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.5219 - accuracy: 0.7393 - val_loss: 0.5043 - val_accuracy: 0.7530
# Epoch 15/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.5106 - accuracy: 0.7392 - val_loss: 0.4931 - val_accuracy: 0.7531
# Epoch 16/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5054 - accuracy: 0.7392 - val_loss: 0.4883 - val_accuracy: 0.7530
# Epoch 17/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.5022 - accuracy: 0.7393 - val_loss: 0.4856 - val_accuracy: 0.7530
# Epoch 18/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.5003 - accuracy: 0.7393 - val_loss: 0.4888 - val_accuracy: 0.7530
# Epoch 19/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4996 - accuracy: 0.7393 - val_loss: 0.4827 - val_accuracy: 0.7530
# Epoch 20/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4973 - accuracy: 0.7393 - val_loss: 0.4812 - val_accuracy: 0.7530
# Epoch 21/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4957 - accuracy: 0.7393 - val_loss: 0.4820 - val_accuracy: 0.7530
# Epoch 22/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4950 - accuracy: 0.7393 - val_loss: 0.4815 - val_accuracy: 0.7529
# Epoch 23/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4938 - accuracy: 0.7394 - val_loss: 0.4801 - val_accuracy: 0.7531
# Epoch 24/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4929 - accuracy: 0.7397 - val_loss: 0.4773 - val_accuracy: 0.7531
# Epoch 25/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4919 - accuracy: 0.7418 - val_loss: 0.4777 - val_accuracy: 0.7549
# Epoch 26/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4885 - accuracy: 0.7454 - val_loss: 0.4794 - val_accuracy: 0.7521
# Epoch 27/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4854 - accuracy: 0.7479 - val_loss: 0.4741 - val_accuracy: 0.7554
# Epoch 28/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4826 - accuracy: 0.7491 - val_loss: 0.4723 - val_accuracy: 0.7510
# Epoch 29/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4787 - accuracy: 0.7506 - val_loss: 0.4728 - val_accuracy: 0.7572
# Epoch 30/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4778 - accuracy: 0.7524 - val_loss: 0.4676 - val_accuracy: 0.7599
# Epoch 31/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4734 - accuracy: 0.7548 - val_loss: 0.4757 - val_accuracy: 0.7417
# Epoch 32/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4718 - accuracy: 0.7554 - val_loss: 0.4689 - val_accuracy: 0.7608
# Epoch 33/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4709 - accuracy: 0.7564 - val_loss: 0.4605 - val_accuracy: 0.7619
# Epoch 34/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4676 - accuracy: 0.7579 - val_loss: 0.4590 - val_accuracy: 0.7637
# Epoch 35/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4687 - accuracy: 0.7575 - val_loss: 0.4566 - val_accuracy: 0.7639
# Epoch 36/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4647 - accuracy: 0.7598 - val_loss: 0.4544 - val_accuracy: 0.7656
# Epoch 37/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4630 - accuracy: 0.7602 - val_loss: 0.4560 - val_accuracy: 0.7643
# Epoch 38/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4624 - accuracy: 0.7612 - val_loss: 0.4642 - val_accuracy: 0.7571
# Epoch 39/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4665 - accuracy: 0.7590 - val_loss: 0.4541 - val_accuracy: 0.7663
# Epoch 40/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4614 - accuracy: 0.7619 - val_loss: 0.4520 - val_accuracy: 0.7673
# Epoch 41/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4586 - accuracy: 0.7625 - val_loss: 0.4513 - val_accuracy: 0.7658
# Epoch 42/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4585 - accuracy: 0.7626 - val_loss: 0.4497 - val_accuracy: 0.7685
# Epoch 43/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4596 - accuracy: 0.7626 - val_loss: 0.4542 - val_accuracy: 0.7654
# Epoch 44/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4581 - accuracy: 0.7633 - val_loss: 0.4484 - val_accuracy: 0.7689
# Epoch 45/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4561 - accuracy: 0.7640 - val_loss: 0.4465 - val_accuracy: 0.7692
# Epoch 46/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4546 - accuracy: 0.7642 - val_loss: 0.4494 - val_accuracy: 0.7693
# Epoch 47/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4593 - accuracy: 0.7631 - val_loss: 0.4505 - val_accuracy: 0.7672
# Epoch 48/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4543 - accuracy: 0.7651 - val_loss: 0.4487 - val_accuracy: 0.7712
# Epoch 49/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4534 - accuracy: 0.7655 - val_loss: 0.4446 - val_accuracy: 0.7705
# Epoch 50/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4524 - accuracy: 0.7658 - val_loss: 0.4484 - val_accuracy: 0.7717
# Epoch 51/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4521 - accuracy: 0.7662 - val_loss: 0.4436 - val_accuracy: 0.7717
# Epoch 52/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4513 - accuracy: 0.7664 - val_loss: 0.4430 - val_accuracy: 0.7720
# Epoch 53/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4508 - accuracy: 0.7671 - val_loss: 0.4435 - val_accuracy: 0.7727
# Epoch 54/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4526 - accuracy: 0.7669 - val_loss: 0.4462 - val_accuracy: 0.7728
# Epoch 55/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4532 - accuracy: 0.7670 - val_loss: 0.4434 - val_accuracy: 0.7730
# Epoch 56/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4494 - accuracy: 0.7678 - val_loss: 0.4425 - val_accuracy: 0.7738
# Epoch 57/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4476 - accuracy: 0.7686 - val_loss: 0.4424 - val_accuracy: 0.7741
# Epoch 58/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4528 - accuracy: 0.7680 - val_loss: 0.4424 - val_accuracy: 0.7733
# Epoch 59/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4477 - accuracy: 0.7692 - val_loss: 0.4414 - val_accuracy: 0.7739
# Epoch 60/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4465 - accuracy: 0.7694 - val_loss: 0.4393 - val_accuracy: 0.7756
# Epoch 61/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4458 - accuracy: 0.7696 - val_loss: 0.4392 - val_accuracy: 0.7767
# Epoch 62/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4475 - accuracy: 0.7701 - val_loss: 0.4396 - val_accuracy: 0.7760
# Epoch 63/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4462 - accuracy: 0.7703 - val_loss: 0.4382 - val_accuracy: 0.7763
# Epoch 64/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4448 - accuracy: 0.7708 - val_loss: 0.4379 - val_accuracy: 0.7765
# Epoch 65/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4438 - accuracy: 0.7715 - val_loss: 0.4372 - val_accuracy: 0.7771
# Epoch 66/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4435 - accuracy: 0.7719 - val_loss: 0.4490 - val_accuracy: 0.7775
# Epoch 67/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4474 - accuracy: 0.7713 - val_loss: 0.4388 - val_accuracy: 0.7767
# Epoch 68/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4429 - accuracy: 0.7723 - val_loss: 0.4358 - val_accuracy: 0.7777
# Epoch 69/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4429 - accuracy: 0.7726 - val_loss: 0.4388 - val_accuracy: 0.7776
# Epoch 70/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4424 - accuracy: 0.7726 - val_loss: 0.4456 - val_accuracy: 0.7771
# Epoch 71/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4427 - accuracy: 0.7732 - val_loss: 0.4377 - val_accuracy: 0.7762
# Epoch 72/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4410 - accuracy: 0.7734 - val_loss: 0.4369 - val_accuracy: 0.7758
# Epoch 73/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4405 - accuracy: 0.7736 - val_loss: 0.4353 - val_accuracy: 0.7769
# Epoch 74/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4406 - accuracy: 0.7739 - val_loss: 0.4346 - val_accuracy: 0.7775
# Epoch 75/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4412 - accuracy: 0.7739 - val_loss: 0.4403 - val_accuracy: 0.7769
# Epoch 76/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4402 - accuracy: 0.7746 - val_loss: 0.4348 - val_accuracy: 0.7768
# Epoch 77/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4390 - accuracy: 0.7746 - val_loss: 0.4518 - val_accuracy: 0.7662
# Epoch 78/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4449 - accuracy: 0.7733 - val_loss: 0.4359 - val_accuracy: 0.7787
# Epoch 79/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4405 - accuracy: 0.7749 - val_loss: 0.4390 - val_accuracy: 0.7770
# Epoch 80/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4411 - accuracy: 0.7745 - val_loss: 0.4384 - val_accuracy: 0.7782
# Epoch 81/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4382 - accuracy: 0.7755 - val_loss: 0.4375 - val_accuracy: 0.7779
# Epoch 82/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4376 - accuracy: 0.7760 - val_loss: 0.4345 - val_accuracy: 0.7792
# Epoch 83/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4369 - accuracy: 0.7757 - val_loss: 0.4323 - val_accuracy: 0.7790
# Epoch 84/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4367 - accuracy: 0.7763 - val_loss: 0.4338 - val_accuracy: 0.7786
# Epoch 85/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4383 - accuracy: 0.7761 - val_loss: 0.4349 - val_accuracy: 0.7771
# Epoch 86/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4370 - accuracy: 0.7764 - val_loss: 0.4320 - val_accuracy: 0.7782
# Epoch 87/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4362 - accuracy: 0.7766 - val_loss: 0.4329 - val_accuracy: 0.7783
# Epoch 88/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4361 - accuracy: 0.7764 - val_loss: 0.4356 - val_accuracy: 0.7798
# Epoch 89/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4387 - accuracy: 0.7766 - val_loss: 0.4328 - val_accuracy: 0.7780
# Epoch 90/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4367 - accuracy: 0.7768 - val_loss: 0.4399 - val_accuracy: 0.7785
# Epoch 91/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4365 - accuracy: 0.7769 - val_loss: 0.4318 - val_accuracy: 0.7792
# Epoch 92/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4352 - accuracy: 0.7772 - val_loss: 0.4389 - val_accuracy: 0.7756
# Epoch 93/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4388 - accuracy: 0.7759 - val_loss: 0.4377 - val_accuracy: 0.7773
# Epoch 94/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4362 - accuracy: 0.7770 - val_loss: 0.4308 - val_accuracy: 0.7800
# Epoch 95/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4351 - accuracy: 0.7777 - val_loss: 0.4375 - val_accuracy: 0.7783
# Epoch 96/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4359 - accuracy: 0.7770 - val_loss: 0.4362 - val_accuracy: 0.7775
# Epoch 97/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4359 - accuracy: 0.7772 - val_loss: 0.4377 - val_accuracy: 0.7781
# Epoch 98/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4349 - accuracy: 0.7775 - val_loss: 0.4333 - val_accuracy: 0.7787
# Epoch 99/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4337 - accuracy: 0.7776 - val_loss: 0.4325 - val_accuracy: 0.7782
# Epoch 100/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4340 - accuracy: 0.7779 - val_loss: 0.4351 - val_accuracy: 0.7782
# Epoch 101/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4331 - accuracy: 0.7784 - val_loss: 0.4325 - val_accuracy: 0.7782
# Epoch 102/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4332 - accuracy: 0.7781 - val_loss: 0.4322 - val_accuracy: 0.7800
# Epoch 103/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4326 - accuracy: 0.7784 - val_loss: 0.4301 - val_accuracy: 0.7808
# Epoch 104/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4331 - accuracy: 0.7785 - val_loss: 0.4405 - val_accuracy: 0.7795
# Epoch 105/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4332 - accuracy: 0.7784 - val_loss: 0.4292 - val_accuracy: 0.7807
# Epoch 106/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4322 - accuracy: 0.7787 - val_loss: 0.4355 - val_accuracy: 0.7770
# Epoch 107/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4337 - accuracy: 0.7785 - val_loss: 0.4365 - val_accuracy: 0.7802
# Epoch 108/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4326 - accuracy: 0.7781 - val_loss: 0.4319 - val_accuracy: 0.7800
# Epoch 109/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4319 - accuracy: 0.7784 - val_loss: 0.4311 - val_accuracy: 0.7810
# Epoch 110/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4317 - accuracy: 0.7789 - val_loss: 0.4315 - val_accuracy: 0.7806
# Epoch 111/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4326 - accuracy: 0.7786 - val_loss: 0.4298 - val_accuracy: 0.7805
# Epoch 112/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4318 - accuracy: 0.7787 - val_loss: 0.4355 - val_accuracy: 0.7792
# Epoch 113/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4323 - accuracy: 0.7786 - val_loss: 0.4329 - val_accuracy: 0.7801
# Epoch 114/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4312 - accuracy: 0.7792 - val_loss: 0.4305 - val_accuracy: 0.7805
# Epoch 115/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4305 - accuracy: 0.7794 - val_loss: 0.4313 - val_accuracy: 0.7792
# Epoch 116/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4323 - accuracy: 0.7786 - val_loss: 0.4287 - val_accuracy: 0.7806
# Epoch 117/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4311 - accuracy: 0.7792 - val_loss: 0.4329 - val_accuracy: 0.7799
# Epoch 118/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4307 - accuracy: 0.7792 - val_loss: 0.4313 - val_accuracy: 0.7798
# Epoch 119/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4313 - accuracy: 0.7791 - val_loss: 0.4312 - val_accuracy: 0.7797
# Epoch 120/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4310 - accuracy: 0.7793 - val_loss: 0.4336 - val_accuracy: 0.7770
# Epoch 121/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4312 - accuracy: 0.7791 - val_loss: 0.4277 - val_accuracy: 0.7813
# Epoch 122/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4309 - accuracy: 0.7795 - val_loss: 0.4305 - val_accuracy: 0.7808
# Epoch 123/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4296 - accuracy: 0.7800 - val_loss: 0.4296 - val_accuracy: 0.7801
# Epoch 124/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4300 - accuracy: 0.7796 - val_loss: 0.4303 - val_accuracy: 0.7808
# Epoch 125/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4299 - accuracy: 0.7796 - val_loss: 0.4282 - val_accuracy: 0.7807
# Epoch 126/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4297 - accuracy: 0.7799 - val_loss: 0.4290 - val_accuracy: 0.7815
# Epoch 127/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4290 - accuracy: 0.7801 - val_loss: 0.4289 - val_accuracy: 0.7821
# Epoch 128/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4293 - accuracy: 0.7801 - val_loss: 0.4294 - val_accuracy: 0.7803
# Epoch 129/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4304 - accuracy: 0.7797 - val_loss: 0.4303 - val_accuracy: 0.7818
# Epoch 130/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4292 - accuracy: 0.7798 - val_loss: 0.4332 - val_accuracy: 0.7811
# Epoch 131/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4285 - accuracy: 0.7803 - val_loss: 0.4296 - val_accuracy: 0.7826
# Epoch 132/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4289 - accuracy: 0.7802 - val_loss: 0.4309 - val_accuracy: 0.7811
# Epoch 133/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4291 - accuracy: 0.7802 - val_loss: 0.4311 - val_accuracy: 0.7816
# Epoch 134/140
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4287 - accuracy: 0.7803 - val_loss: 0.4289 - val_accuracy: 0.7823
# Epoch 135/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4285 - accuracy: 0.7806 - val_loss: 0.4295 - val_accuracy: 0.7814
# Epoch 136/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4285 - accuracy: 0.7803 - val_loss: 0.4305 - val_accuracy: 0.7796
# Epoch 137/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4279 - accuracy: 0.7803 - val_loss: 0.4290 - val_accuracy: 0.7807
# Epoch 138/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4274 - accuracy: 0.7805 - val_loss: 0.4322 - val_accuracy: 0.7806
# Epoch 139/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4279 - accuracy: 0.7804 - val_loss: 0.4296 - val_accuracy: 0.7806
# Epoch 140/140
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4276 - accuracy: 0.7807 - val_loss: 0.4311 - val_accuracy: 0.7817

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 19s 6ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 519.6804671287537

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00264058],
#        [0.00567891],
#        [0.00378109],
#        ...,
#        [0.04520768],
#        [0.04655509],
#        [0.04693081]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14380164568471648
# 0.22674545171973626
# 0.3792118743983586
# 0.28591983940507637

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 89s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.6082804]
# [0.81836094]
# total acc [0.78078287]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 5198026240}
