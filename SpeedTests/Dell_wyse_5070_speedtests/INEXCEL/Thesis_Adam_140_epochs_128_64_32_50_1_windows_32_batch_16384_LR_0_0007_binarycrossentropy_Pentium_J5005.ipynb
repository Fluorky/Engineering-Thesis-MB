# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1d8b7047040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1d92b102040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 529s 21s/step - loss: 0.6408 - accuracy: 0.6216 - val_loss: 0.5611 - val_accuracy: 0.7530
# Epoch 2/140
# 24/24 [==============================] - 489s 20s/step - loss: 0.5754 - accuracy: 0.7393 - val_loss: 0.5606 - val_accuracy: 0.7530
# Epoch 3/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.5738 - accuracy: 0.7393 - val_loss: 0.5592 - val_accuracy: 0.7530
# Epoch 4/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.5736 - accuracy: 0.7393 - val_loss: 0.5590 - val_accuracy: 0.7530
# Epoch 5/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.5730 - accuracy: 0.7393 - val_loss: 0.5577 - val_accuracy: 0.7530
# Epoch 6/140
# 24/24 [==============================] - 483s 20s/step - loss: 0.5642 - accuracy: 0.7393 - val_loss: 0.5450 - val_accuracy: 0.7530
# Epoch 7/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.5445 - accuracy: 0.7393 - val_loss: 0.5181 - val_accuracy: 0.7530
# Epoch 8/140
# 24/24 [==============================] - 489s 20s/step - loss: 0.5189 - accuracy: 0.7390 - val_loss: 0.4948 - val_accuracy: 0.7500
# Epoch 9/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.5057 - accuracy: 0.7375 - val_loss: 0.4974 - val_accuracy: 0.7520
# Epoch 10/140
# 24/24 [==============================] - 475s 20s/step - loss: 0.5012 - accuracy: 0.7394 - val_loss: 0.4835 - val_accuracy: 0.7529
# Epoch 11/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4971 - accuracy: 0.7416 - val_loss: 0.4836 - val_accuracy: 0.7537
# Epoch 12/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4942 - accuracy: 0.7447 - val_loss: 0.4822 - val_accuracy: 0.7528
# Epoch 13/140
# 24/24 [==============================] - 485s 20s/step - loss: 0.4918 - accuracy: 0.7470 - val_loss: 0.4788 - val_accuracy: 0.7524
# Epoch 14/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4880 - accuracy: 0.7485 - val_loss: 0.4753 - val_accuracy: 0.7558
# Epoch 15/140
# 24/24 [==============================] - 475s 20s/step - loss: 0.4840 - accuracy: 0.7492 - val_loss: 0.4730 - val_accuracy: 0.7533
# Epoch 16/140
# 24/24 [==============================] - 485s 20s/step - loss: 0.4808 - accuracy: 0.7511 - val_loss: 0.4699 - val_accuracy: 0.7581
# Epoch 17/140
# 24/24 [==============================] - 475s 20s/step - loss: 0.4753 - accuracy: 0.7543 - val_loss: 0.4651 - val_accuracy: 0.7597
# Epoch 18/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4713 - accuracy: 0.7561 - val_loss: 0.4616 - val_accuracy: 0.7632
# Epoch 19/140
# 24/24 [==============================] - 476s 20s/step - loss: 0.4688 - accuracy: 0.7574 - val_loss: 0.4621 - val_accuracy: 0.7619
# Epoch 20/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4663 - accuracy: 0.7585 - val_loss: 0.4596 - val_accuracy: 0.7615
# Epoch 21/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4653 - accuracy: 0.7589 - val_loss: 0.4571 - val_accuracy: 0.7647
# Epoch 22/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4620 - accuracy: 0.7600 - val_loss: 0.4539 - val_accuracy: 0.7656
# Epoch 23/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4613 - accuracy: 0.7607 - val_loss: 0.4552 - val_accuracy: 0.7622
# Epoch 24/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4602 - accuracy: 0.7616 - val_loss: 0.4496 - val_accuracy: 0.7671
# Epoch 25/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4594 - accuracy: 0.7617 - val_loss: 0.4546 - val_accuracy: 0.7672
# Epoch 26/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4616 - accuracy: 0.7621 - val_loss: 0.4533 - val_accuracy: 0.7680
# Epoch 27/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4578 - accuracy: 0.7631 - val_loss: 0.4493 - val_accuracy: 0.7672
# Epoch 28/140
# 24/24 [==============================] - 500s 21s/step - loss: 0.4550 - accuracy: 0.7642 - val_loss: 0.4487 - val_accuracy: 0.7686
# Epoch 29/140
# 24/24 [==============================] - 476s 20s/step - loss: 0.4554 - accuracy: 0.7645 - val_loss: 0.4453 - val_accuracy: 0.7684
# Epoch 30/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4533 - accuracy: 0.7657 - val_loss: 0.4437 - val_accuracy: 0.7711
# Epoch 31/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4533 - accuracy: 0.7664 - val_loss: 0.4461 - val_accuracy: 0.7713
# Epoch 32/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4543 - accuracy: 0.7665 - val_loss: 0.4449 - val_accuracy: 0.7718
# Epoch 33/140
# 24/24 [==============================] - 476s 20s/step - loss: 0.4516 - accuracy: 0.7671 - val_loss: 0.4427 - val_accuracy: 0.7719
# Epoch 34/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4495 - accuracy: 0.7678 - val_loss: 0.4432 - val_accuracy: 0.7715
# Epoch 35/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4515 - accuracy: 0.7677 - val_loss: 0.4451 - val_accuracy: 0.7731
# Epoch 36/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4497 - accuracy: 0.7687 - val_loss: 0.4436 - val_accuracy: 0.7747
# Epoch 37/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4477 - accuracy: 0.7689 - val_loss: 0.4394 - val_accuracy: 0.7752
# Epoch 38/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4465 - accuracy: 0.7694 - val_loss: 0.4500 - val_accuracy: 0.7743
# Epoch 39/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4475 - accuracy: 0.7695 - val_loss: 0.4389 - val_accuracy: 0.7746
# Epoch 40/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4453 - accuracy: 0.7699 - val_loss: 0.4461 - val_accuracy: 0.7751
# Epoch 41/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4472 - accuracy: 0.7700 - val_loss: 0.4389 - val_accuracy: 0.7760
# Epoch 42/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4447 - accuracy: 0.7704 - val_loss: 0.4381 - val_accuracy: 0.7780
# Epoch 43/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4462 - accuracy: 0.7708 - val_loss: 0.4461 - val_accuracy: 0.7753
# Epoch 44/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4458 - accuracy: 0.7711 - val_loss: 0.4385 - val_accuracy: 0.7775
# Epoch 45/140
# 24/24 [==============================] - 476s 20s/step - loss: 0.4438 - accuracy: 0.7713 - val_loss: 0.4378 - val_accuracy: 0.7768
# Epoch 46/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4435 - accuracy: 0.7715 - val_loss: 0.4397 - val_accuracy: 0.7765
# Epoch 47/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4429 - accuracy: 0.7722 - val_loss: 0.4391 - val_accuracy: 0.7766
# Epoch 48/140
# 24/24 [==============================] - 476s 20s/step - loss: 0.4448 - accuracy: 0.7716 - val_loss: 0.4368 - val_accuracy: 0.7777
# Epoch 49/140
# 24/24 [==============================] - 475s 20s/step - loss: 0.4422 - accuracy: 0.7723 - val_loss: 0.4356 - val_accuracy: 0.7777
# Epoch 50/140
# 24/24 [==============================] - 490s 20s/step - loss: 0.4415 - accuracy: 0.7726 - val_loss: 0.4361 - val_accuracy: 0.7771
# Epoch 51/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4429 - accuracy: 0.7726 - val_loss: 0.4362 - val_accuracy: 0.7773
# Epoch 52/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4434 - accuracy: 0.7727 - val_loss: 0.4401 - val_accuracy: 0.7774
# Epoch 53/140
# 24/24 [==============================] - 484s 20s/step - loss: 0.4416 - accuracy: 0.7731 - val_loss: 0.4348 - val_accuracy: 0.7781
# Epoch 54/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4400 - accuracy: 0.7735 - val_loss: 0.4378 - val_accuracy: 0.7767
# Epoch 55/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4406 - accuracy: 0.7735 - val_loss: 0.4353 - val_accuracy: 0.7781
# Epoch 56/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4403 - accuracy: 0.7736 - val_loss: 0.4411 - val_accuracy: 0.7767
# Epoch 57/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4402 - accuracy: 0.7743 - val_loss: 0.4375 - val_accuracy: 0.7763
# Epoch 58/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4395 - accuracy: 0.7740 - val_loss: 0.4340 - val_accuracy: 0.7771
# Epoch 59/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4404 - accuracy: 0.7742 - val_loss: 0.4328 - val_accuracy: 0.7791
# Epoch 60/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4387 - accuracy: 0.7744 - val_loss: 0.4342 - val_accuracy: 0.7778
# Epoch 61/140
# 24/24 [==============================] - 483s 20s/step - loss: 0.4386 - accuracy: 0.7751 - val_loss: 0.4442 - val_accuracy: 0.7766
# Epoch 62/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4411 - accuracy: 0.7741 - val_loss: 0.4348 - val_accuracy: 0.7770
# Epoch 63/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4383 - accuracy: 0.7752 - val_loss: 0.4362 - val_accuracy: 0.7759
# Epoch 64/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4389 - accuracy: 0.7753 - val_loss: 0.4344 - val_accuracy: 0.7789
# Epoch 65/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4380 - accuracy: 0.7754 - val_loss: 0.4341 - val_accuracy: 0.7778
# Epoch 66/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4375 - accuracy: 0.7755 - val_loss: 0.4320 - val_accuracy: 0.7795
# Epoch 67/140
# 24/24 [==============================] - 475s 20s/step - loss: 0.4368 - accuracy: 0.7759 - val_loss: 0.4332 - val_accuracy: 0.7779
# Epoch 68/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4372 - accuracy: 0.7761 - val_loss: 0.4355 - val_accuracy: 0.7768
# Epoch 69/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4366 - accuracy: 0.7759 - val_loss: 0.4331 - val_accuracy: 0.7780
# Epoch 70/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4361 - accuracy: 0.7765 - val_loss: 0.4399 - val_accuracy: 0.7773
# Epoch 71/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4366 - accuracy: 0.7766 - val_loss: 0.4348 - val_accuracy: 0.7777
# Epoch 72/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4361 - accuracy: 0.7763 - val_loss: 0.4334 - val_accuracy: 0.7804
# Epoch 73/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4369 - accuracy: 0.7765 - val_loss: 0.4368 - val_accuracy: 0.7772
# Epoch 74/140
# 24/24 [==============================] - 476s 20s/step - loss: 0.4360 - accuracy: 0.7767 - val_loss: 0.4339 - val_accuracy: 0.7769
# Epoch 75/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4361 - accuracy: 0.7765 - val_loss: 0.4320 - val_accuracy: 0.7775
# Epoch 76/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4353 - accuracy: 0.7769 - val_loss: 0.4303 - val_accuracy: 0.7795
# Epoch 77/140
# 24/24 [==============================] - 474s 20s/step - loss: 0.4359 - accuracy: 0.7769 - val_loss: 0.4329 - val_accuracy: 0.7802
# Epoch 78/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4350 - accuracy: 0.7768 - val_loss: 0.4338 - val_accuracy: 0.7800
# Epoch 79/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4362 - accuracy: 0.7769 - val_loss: 0.4307 - val_accuracy: 0.7799
# Epoch 80/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4344 - accuracy: 0.7773 - val_loss: 0.4308 - val_accuracy: 0.7800
# Epoch 81/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4347 - accuracy: 0.7773 - val_loss: 0.4367 - val_accuracy: 0.7793
# Epoch 82/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4343 - accuracy: 0.7776 - val_loss: 0.4326 - val_accuracy: 0.7789
# Epoch 83/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4347 - accuracy: 0.7778 - val_loss: 0.4300 - val_accuracy: 0.7801
# Epoch 84/140
# 24/24 [==============================] - 483s 20s/step - loss: 0.4332 - accuracy: 0.7777 - val_loss: 0.4301 - val_accuracy: 0.7792
# Epoch 85/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4341 - accuracy: 0.7775 - val_loss: 0.4350 - val_accuracy: 0.7762
# Epoch 86/140
# 24/24 [==============================] - 483s 20s/step - loss: 0.4346 - accuracy: 0.7774 - val_loss: 0.4313 - val_accuracy: 0.7797
# Epoch 87/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4333 - accuracy: 0.7779 - val_loss: 0.4315 - val_accuracy: 0.7770
# Epoch 88/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4327 - accuracy: 0.7782 - val_loss: 0.4317 - val_accuracy: 0.7783
# Epoch 89/140
# 24/24 [==============================] - 475s 20s/step - loss: 0.4331 - accuracy: 0.7777 - val_loss: 0.4331 - val_accuracy: 0.7777
# Epoch 90/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4340 - accuracy: 0.7775 - val_loss: 0.4295 - val_accuracy: 0.7808
# Epoch 91/140
# 24/24 [==============================] - 485s 20s/step - loss: 0.4333 - accuracy: 0.7782 - val_loss: 0.4321 - val_accuracy: 0.7794
# Epoch 92/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4340 - accuracy: 0.7782 - val_loss: 0.4322 - val_accuracy: 0.7789
# Epoch 93/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4328 - accuracy: 0.7785 - val_loss: 0.4348 - val_accuracy: 0.7806
# Epoch 94/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4330 - accuracy: 0.7782 - val_loss: 0.4334 - val_accuracy: 0.7797
# Epoch 95/140
# 24/24 [==============================] - 484s 20s/step - loss: 0.4328 - accuracy: 0.7784 - val_loss: 0.4287 - val_accuracy: 0.7815
# Epoch 96/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4321 - accuracy: 0.7783 - val_loss: 0.4319 - val_accuracy: 0.7795
# Epoch 97/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4316 - accuracy: 0.7786 - val_loss: 0.4303 - val_accuracy: 0.7807
# Epoch 98/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4313 - accuracy: 0.7788 - val_loss: 0.4311 - val_accuracy: 0.7812
# Epoch 99/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4313 - accuracy: 0.7789 - val_loss: 0.4324 - val_accuracy: 0.7778
# Epoch 100/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4314 - accuracy: 0.7792 - val_loss: 0.4381 - val_accuracy: 0.7808
# Epoch 101/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4315 - accuracy: 0.7790 - val_loss: 0.4291 - val_accuracy: 0.7814
# Epoch 102/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4312 - accuracy: 0.7792 - val_loss: 0.4285 - val_accuracy: 0.7803
# Epoch 103/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4308 - accuracy: 0.7792 - val_loss: 0.4354 - val_accuracy: 0.7810
# Epoch 104/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4321 - accuracy: 0.7791 - val_loss: 0.4349 - val_accuracy: 0.7806
# Epoch 105/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4320 - accuracy: 0.7788 - val_loss: 0.4303 - val_accuracy: 0.7797
# Epoch 106/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4297 - accuracy: 0.7793 - val_loss: 0.4279 - val_accuracy: 0.7803
# Epoch 107/140
# 24/24 [==============================] - 475s 20s/step - loss: 0.4297 - accuracy: 0.7796 - val_loss: 0.4292 - val_accuracy: 0.7784
# Epoch 108/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4297 - accuracy: 0.7795 - val_loss: 0.4316 - val_accuracy: 0.7802
# Epoch 109/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4296 - accuracy: 0.7798 - val_loss: 0.4288 - val_accuracy: 0.7826
# Epoch 110/140
# 24/24 [==============================] - 484s 20s/step - loss: 0.4288 - accuracy: 0.7797 - val_loss: 0.4320 - val_accuracy: 0.7821
# Epoch 111/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4294 - accuracy: 0.7794 - val_loss: 0.4280 - val_accuracy: 0.7805
# Epoch 112/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4296 - accuracy: 0.7797 - val_loss: 0.4297 - val_accuracy: 0.7800
# Epoch 113/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4284 - accuracy: 0.7800 - val_loss: 0.4377 - val_accuracy: 0.7737
# Epoch 114/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4314 - accuracy: 0.7791 - val_loss: 0.4304 - val_accuracy: 0.7814
# Epoch 115/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4294 - accuracy: 0.7795 - val_loss: 0.4320 - val_accuracy: 0.7782
# Epoch 116/140
# 24/24 [==============================] - 484s 20s/step - loss: 0.4282 - accuracy: 0.7800 - val_loss: 0.4309 - val_accuracy: 0.7786
# Epoch 117/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4281 - accuracy: 0.7800 - val_loss: 0.4304 - val_accuracy: 0.7767
# Epoch 118/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4283 - accuracy: 0.7800 - val_loss: 0.4282 - val_accuracy: 0.7813
# Epoch 119/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4275 - accuracy: 0.7807 - val_loss: 0.4297 - val_accuracy: 0.7776
# Epoch 120/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4271 - accuracy: 0.7805 - val_loss: 0.4277 - val_accuracy: 0.7808
# Epoch 121/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4288 - accuracy: 0.7805 - val_loss: 0.4286 - val_accuracy: 0.7788
# Epoch 122/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4280 - accuracy: 0.7804 - val_loss: 0.4303 - val_accuracy: 0.7822
# Epoch 123/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4272 - accuracy: 0.7810 - val_loss: 0.4342 - val_accuracy: 0.7745
# Epoch 124/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4285 - accuracy: 0.7803 - val_loss: 0.4302 - val_accuracy: 0.7779
# Epoch 125/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4274 - accuracy: 0.7808 - val_loss: 0.4299 - val_accuracy: 0.7835
# Epoch 126/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4267 - accuracy: 0.7812 - val_loss: 0.4359 - val_accuracy: 0.7710
# Epoch 127/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4283 - accuracy: 0.7804 - val_loss: 0.4291 - val_accuracy: 0.7791
# Epoch 128/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4277 - accuracy: 0.7808 - val_loss: 0.4282 - val_accuracy: 0.7813
# Epoch 129/140
# 24/24 [==============================] - 480s 20s/step - loss: 0.4258 - accuracy: 0.7814 - val_loss: 0.4291 - val_accuracy: 0.7809
# Epoch 130/140
# 24/24 [==============================] - 477s 20s/step - loss: 0.4256 - accuracy: 0.7815 - val_loss: 0.4293 - val_accuracy: 0.7787
# Epoch 131/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4253 - accuracy: 0.7816 - val_loss: 0.4289 - val_accuracy: 0.7796
# Epoch 132/140
# 24/24 [==============================] - 482s 20s/step - loss: 0.4261 - accuracy: 0.7820 - val_loss: 0.4295 - val_accuracy: 0.7786
# Epoch 133/140
# 24/24 [==============================] - 485s 20s/step - loss: 0.4254 - accuracy: 0.7821 - val_loss: 0.4301 - val_accuracy: 0.7793
# Epoch 134/140
# 24/24 [==============================] - 483s 20s/step - loss: 0.4254 - accuracy: 0.7822 - val_loss: 0.4333 - val_accuracy: 0.7746
# Epoch 135/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4258 - accuracy: 0.7819 - val_loss: 0.4288 - val_accuracy: 0.7799
# Epoch 136/140
# 24/24 [==============================] - 485s 20s/step - loss: 0.4248 - accuracy: 0.7825 - val_loss: 0.4320 - val_accuracy: 0.7759
# Epoch 137/140
# 24/24 [==============================] - 481s 20s/step - loss: 0.4268 - accuracy: 0.7818 - val_loss: 0.4311 - val_accuracy: 0.7802
# Epoch 138/140
# 24/24 [==============================] - 478s 20s/step - loss: 0.4247 - accuracy: 0.7823 - val_loss: 0.4334 - val_accuracy: 0.7810
# Epoch 139/140
# 24/24 [==============================] - 479s 20s/step - loss: 0.4246 - accuracy: 0.7825 - val_loss: 0.4334 - val_accuracy: 0.7797
# Epoch 140/140
# 24/24 [==============================] - 483s 20s/step - loss: 0.4251 - accuracy: 0.7818 - val_loss: 0.4312 - val_accuracy: 0.7787

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 87s 29ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 67348.75729346275

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00115994],
#        [0.00231777],
#        [0.00165169],
#        ...,
#        [0.03511126],
#        [0.03664754],
#        [0.03730243]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14449634537787742
# 0.22300989156764073
# 0.3801267490954529
# 0.28545640781665754

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 418s 28ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.59865347]
# [0.82788448]
# total acc [0.78175277]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14696\725781306.py in <module>
# ----> 1 tf.config.experimental.get_memory_info('GPU:0')
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\config.py in get_memory_info(device)
#     574     ValueError: Memory statistics not tracked, like '"CPU:0"'.
#     575   """
# --> 576   return context.context().get_memory_info(device)
#     577
#     578
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in get_memory_info(self, dev)
#    1605     self._initialize_physical_devices()
#    1606     self.ensure_initialized()
# -> 1607     return pywrap_tfe.TFE_GetMemoryInfo(self._context_handle, dev)
#    1608
#    1609   def reset_memory_stats(self, dev):
#
# ValueError: No matching devices found for 'GPU:0'
