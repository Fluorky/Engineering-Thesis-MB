# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x21f401da040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x21f7a243040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 52s 2s/step - loss: 0.6026 - accuracy: 0.7195 - val_loss: 0.5594 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5583 - val_accuracy: 0.7531
# Epoch 3/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.5664 - accuracy: 0.7393 - val_loss: 0.5416 - val_accuracy: 0.7436
# Epoch 4/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.5348 - accuracy: 0.7381 - val_loss: 0.5085 - val_accuracy: 0.7531
# Epoch 5/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.5116 - accuracy: 0.7386 - val_loss: 0.4926 - val_accuracy: 0.7522
# Epoch 6/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.5036 - accuracy: 0.7409 - val_loss: 0.4865 - val_accuracy: 0.7528
# Epoch 7/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4987 - accuracy: 0.7438 - val_loss: 0.4822 - val_accuracy: 0.7532
# Epoch 8/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4944 - accuracy: 0.7462 - val_loss: 0.4808 - val_accuracy: 0.7536
# Epoch 9/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4887 - accuracy: 0.7476 - val_loss: 0.4772 - val_accuracy: 0.7528
# Epoch 10/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.4826 - accuracy: 0.7495 - val_loss: 0.4715 - val_accuracy: 0.7573
# Epoch 11/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.4766 - accuracy: 0.7534 - val_loss: 0.4694 - val_accuracy: 0.7592
# Epoch 12/140
# 24/24 [==============================] - 51s 2s/step - loss: 0.4750 - accuracy: 0.7549 - val_loss: 0.4664 - val_accuracy: 0.7584
# Epoch 13/140
# 24/24 [==============================] - 52s 2s/step - loss: 0.4702 - accuracy: 0.7561 - val_loss: 0.4597 - val_accuracy: 0.7611
# Epoch 14/140
# 24/24 [==============================] - 51s 2s/step - loss: 0.4664 - accuracy: 0.7564 - val_loss: 0.4850 - val_accuracy: 0.7425
# Epoch 15/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.4762 - accuracy: 0.7511 - val_loss: 0.4620 - val_accuracy: 0.7583
# Epoch 16/140
# 24/24 [==============================] - 51s 2s/step - loss: 0.4656 - accuracy: 0.7570 - val_loss: 0.4562 - val_accuracy: 0.7612
# Epoch 17/140
# 24/24 [==============================] - 51s 2s/step - loss: 0.4615 - accuracy: 0.7586 - val_loss: 0.4597 - val_accuracy: 0.7592
# Epoch 18/140
# 24/24 [==============================] - 51s 2s/step - loss: 0.4646 - accuracy: 0.7577 - val_loss: 0.4596 - val_accuracy: 0.7627
# Epoch 19/140
# 24/24 [==============================] - 51s 2s/step - loss: 0.4597 - accuracy: 0.7594 - val_loss: 0.4563 - val_accuracy: 0.7641
# Epoch 20/140
# 24/24 [==============================] - 51s 2s/step - loss: 0.4598 - accuracy: 0.7595 - val_loss: 0.4531 - val_accuracy: 0.7641
# Epoch 21/140
# 24/24 [==============================] - 50s 2s/step - loss: 0.4584 - accuracy: 0.7599 - val_loss: 0.4501 - val_accuracy: 0.7655
# Epoch 22/140
# 24/24 [==============================] - 50s 2s/step - loss: 0.4571 - accuracy: 0.7615 - val_loss: 0.4519 - val_accuracy: 0.7634
# Epoch 23/140
# 24/24 [==============================] - 51s 2s/step - loss: 0.4562 - accuracy: 0.7625 - val_loss: 0.4468 - val_accuracy: 0.7669
# Epoch 24/140
# 24/24 [==============================] - 50s 2s/step - loss: 0.4535 - accuracy: 0.7636 - val_loss: 0.4471 - val_accuracy: 0.7698
# Epoch 25/140
# 24/24 [==============================] - 50s 2s/step - loss: 0.4526 - accuracy: 0.7647 - val_loss: 0.4467 - val_accuracy: 0.7692
# Epoch 26/140
# 24/24 [==============================] - 50s 2s/step - loss: 0.4530 - accuracy: 0.7651 - val_loss: 0.4588 - val_accuracy: 0.7717
# Epoch 27/140
# 24/24 [==============================] - 944s 41s/step - loss: 0.4524 - accuracy: 0.7661 - val_loss: 0.4451 - val_accuracy: 0.7697
# Epoch 28/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4502 - accuracy: 0.7672 - val_loss: 0.4442 - val_accuracy: 0.7719
# Epoch 29/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4488 - accuracy: 0.7676 - val_loss: 0.4495 - val_accuracy: 0.7729
# Epoch 30/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.4487 - accuracy: 0.7680 - val_loss: 0.4487 - val_accuracy: 0.7675
# Epoch 31/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.4490 - accuracy: 0.7685 - val_loss: 0.4436 - val_accuracy: 0.7746
# Epoch 32/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.4477 - accuracy: 0.7689 - val_loss: 0.4394 - val_accuracy: 0.7745
# Epoch 33/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.4464 - accuracy: 0.7691 - val_loss: 0.4418 - val_accuracy: 0.7735
# Epoch 34/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.4469 - accuracy: 0.7699 - val_loss: 0.4403 - val_accuracy: 0.7748
# Epoch 35/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4462 - accuracy: 0.7699 - val_loss: 0.4426 - val_accuracy: 0.7750
# Epoch 36/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4455 - accuracy: 0.7704 - val_loss: 0.4397 - val_accuracy: 0.7739
# Epoch 37/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4450 - accuracy: 0.7704 - val_loss: 0.4397 - val_accuracy: 0.7752
# Epoch 38/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4440 - accuracy: 0.7711 - val_loss: 0.4370 - val_accuracy: 0.7757
# Epoch 39/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4445 - accuracy: 0.7708 - val_loss: 0.4397 - val_accuracy: 0.7750
# Epoch 40/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4437 - accuracy: 0.7713 - val_loss: 0.4372 - val_accuracy: 0.7746
# Epoch 41/140
# 24/24 [==============================] - 49s 2s/step - loss: 0.4442 - accuracy: 0.7712 - val_loss: 0.4372 - val_accuracy: 0.7757
# Epoch 42/140
# 24/24 [==============================] - 50s 2s/step - loss: 0.4430 - accuracy: 0.7715 - val_loss: 0.4375 - val_accuracy: 0.7758
# Epoch 43/140
# 24/24 [==============================] - 50s 2s/step - loss: 0.4428 - accuracy: 0.7723 - val_loss: 0.4401 - val_accuracy: 0.7748
# Epoch 44/140
# 24/24 [==============================] - 51s 2s/step - loss: 0.4424 - accuracy: 0.7720 - val_loss: 0.4354 - val_accuracy: 0.7766
# Epoch 45/140
# 24/24 [==============================] - 50s 2s/step - loss: 0.4427 - accuracy: 0.7726 - val_loss: 0.4364 - val_accuracy: 0.7763
# Epoch 46/140
# 24/24 [==============================] - 50s 2s/step - loss: 0.4418 - accuracy: 0.7728 - val_loss: 0.4354 - val_accuracy: 0.7763
# Epoch 47/140
# 24/24 [==============================] - 50s 2s/step - loss: 0.4407 - accuracy: 0.7731 - val_loss: 0.4378 - val_accuracy: 0.7761
# Epoch 48/140
# 24/24 [==============================] - 1858s 2s/step - loss: 0.4414 - accuracy: 0.7732 - val_loss: 0.4369 - val_accuracy: 0.7764
# Epoch 49/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4412 - accuracy: 0.7736 - val_loss: 0.4405 - val_accuracy: 0.7772
# Epoch 50/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4402 - accuracy: 0.7737 - val_loss: 0.4356 - val_accuracy: 0.7759
# Epoch 51/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4401 - accuracy: 0.7739 - val_loss: 0.4348 - val_accuracy: 0.7760
# Epoch 52/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4411 - accuracy: 0.7735 - val_loss: 0.4341 - val_accuracy: 0.7773
# Epoch 53/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4396 - accuracy: 0.7740 - val_loss: 0.4350 - val_accuracy: 0.7786
# Epoch 54/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4387 - accuracy: 0.7744 - val_loss: 0.4377 - val_accuracy: 0.7756
# Epoch 55/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4405 - accuracy: 0.7741 - val_loss: 0.4376 - val_accuracy: 0.7764
# Epoch 56/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4399 - accuracy: 0.7744 - val_loss: 0.4339 - val_accuracy: 0.7771
# Epoch 57/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4394 - accuracy: 0.7746 - val_loss: 0.4335 - val_accuracy: 0.7780
# Epoch 58/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4376 - accuracy: 0.7747 - val_loss: 0.4380 - val_accuracy: 0.7781
# Epoch 59/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4392 - accuracy: 0.7751 - val_loss: 0.4351 - val_accuracy: 0.7773
# Epoch 60/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4389 - accuracy: 0.7751 - val_loss: 0.4341 - val_accuracy: 0.7776
# Epoch 61/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4371 - accuracy: 0.7757 - val_loss: 0.4353 - val_accuracy: 0.7784
# Epoch 62/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4369 - accuracy: 0.7754 - val_loss: 0.4364 - val_accuracy: 0.7793
# Epoch 63/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4371 - accuracy: 0.7758 - val_loss: 0.4318 - val_accuracy: 0.7797
# Epoch 64/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4373 - accuracy: 0.7760 - val_loss: 0.4375 - val_accuracy: 0.7776
# Epoch 65/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4367 - accuracy: 0.7758 - val_loss: 0.4328 - val_accuracy: 0.7784
# Epoch 66/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4364 - accuracy: 0.7760 - val_loss: 0.4335 - val_accuracy: 0.7795
# Epoch 67/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4358 - accuracy: 0.7764 - val_loss: 0.4342 - val_accuracy: 0.7768
# Epoch 68/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4360 - accuracy: 0.7767 - val_loss: 0.4357 - val_accuracy: 0.7791
# Epoch 69/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4368 - accuracy: 0.7762 - val_loss: 0.4331 - val_accuracy: 0.7788
# Epoch 70/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4358 - accuracy: 0.7765 - val_loss: 0.4326 - val_accuracy: 0.7804
# Epoch 71/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4362 - accuracy: 0.7767 - val_loss: 0.4367 - val_accuracy: 0.7786
# Epoch 72/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4356 - accuracy: 0.7766 - val_loss: 0.4334 - val_accuracy: 0.7794
# Epoch 73/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4356 - accuracy: 0.7767 - val_loss: 0.4324 - val_accuracy: 0.7788
# Epoch 74/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4367 - accuracy: 0.7768 - val_loss: 0.4314 - val_accuracy: 0.7794
# Epoch 75/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4350 - accuracy: 0.7775 - val_loss: 0.4329 - val_accuracy: 0.7785
# Epoch 76/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4339 - accuracy: 0.7776 - val_loss: 0.4335 - val_accuracy: 0.7774
# Epoch 77/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4346 - accuracy: 0.7778 - val_loss: 0.4304 - val_accuracy: 0.7796
# Epoch 78/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4338 - accuracy: 0.7781 - val_loss: 0.4312 - val_accuracy: 0.7808
# Epoch 79/140
# 24/24 [==============================] - 46s 2s/step - loss: 0.4343 - accuracy: 0.7775 - val_loss: 0.4301 - val_accuracy: 0.7799
# Epoch 80/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4334 - accuracy: 0.7779 - val_loss: 0.4291 - val_accuracy: 0.7806
# Epoch 81/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4336 - accuracy: 0.7780 - val_loss: 0.4301 - val_accuracy: 0.7802
# Epoch 82/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4333 - accuracy: 0.7782 - val_loss: 0.4305 - val_accuracy: 0.7802
# Epoch 83/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4331 - accuracy: 0.7784 - val_loss: 0.4293 - val_accuracy: 0.7802
# Epoch 84/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4343 - accuracy: 0.7783 - val_loss: 0.4321 - val_accuracy: 0.7803
# Epoch 85/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4333 - accuracy: 0.7782 - val_loss: 0.4308 - val_accuracy: 0.7795
# Epoch 86/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4316 - accuracy: 0.7789 - val_loss: 0.4281 - val_accuracy: 0.7817
# Epoch 87/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4319 - accuracy: 0.7789 - val_loss: 0.4293 - val_accuracy: 0.7809
# Epoch 88/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4314 - accuracy: 0.7791 - val_loss: 0.4288 - val_accuracy: 0.7817
# Epoch 89/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4312 - accuracy: 0.7793 - val_loss: 0.4368 - val_accuracy: 0.7810
# Epoch 90/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4319 - accuracy: 0.7794 - val_loss: 0.4282 - val_accuracy: 0.7823
# Epoch 91/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4309 - accuracy: 0.7793 - val_loss: 0.4294 - val_accuracy: 0.7825
# Epoch 92/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4309 - accuracy: 0.7794 - val_loss: 0.4352 - val_accuracy: 0.7806
# Epoch 93/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4310 - accuracy: 0.7795 - val_loss: 0.4289 - val_accuracy: 0.7810
# Epoch 94/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4303 - accuracy: 0.7797 - val_loss: 0.4296 - val_accuracy: 0.7811
# Epoch 95/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4313 - accuracy: 0.7797 - val_loss: 0.4302 - val_accuracy: 0.7802
# Epoch 96/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4314 - accuracy: 0.7798 - val_loss: 0.4301 - val_accuracy: 0.7818
# Epoch 97/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4297 - accuracy: 0.7803 - val_loss: 0.4320 - val_accuracy: 0.7826
# Epoch 98/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4296 - accuracy: 0.7801 - val_loss: 0.4276 - val_accuracy: 0.7818
# Epoch 99/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4301 - accuracy: 0.7800 - val_loss: 0.4317 - val_accuracy: 0.7793
# Epoch 100/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4301 - accuracy: 0.7806 - val_loss: 0.4309 - val_accuracy: 0.7822
# Epoch 101/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4290 - accuracy: 0.7805 - val_loss: 0.4273 - val_accuracy: 0.7827
# Epoch 102/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4285 - accuracy: 0.7811 - val_loss: 0.4275 - val_accuracy: 0.7837
# Epoch 103/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4290 - accuracy: 0.7809 - val_loss: 0.4294 - val_accuracy: 0.7813
# Epoch 104/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4282 - accuracy: 0.7810 - val_loss: 0.4261 - val_accuracy: 0.7838
# Epoch 105/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4286 - accuracy: 0.7808 - val_loss: 0.4289 - val_accuracy: 0.7824
# Epoch 106/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4294 - accuracy: 0.7808 - val_loss: 0.4280 - val_accuracy: 0.7835
# Epoch 107/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4278 - accuracy: 0.7813 - val_loss: 0.4319 - val_accuracy: 0.7814
# Epoch 108/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4278 - accuracy: 0.7814 - val_loss: 0.4285 - val_accuracy: 0.7806
# Epoch 109/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4275 - accuracy: 0.7817 - val_loss: 0.4297 - val_accuracy: 0.7819
# Epoch 110/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4273 - accuracy: 0.7814 - val_loss: 0.4282 - val_accuracy: 0.7828
# Epoch 111/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4267 - accuracy: 0.7818 - val_loss: 0.4265 - val_accuracy: 0.7834
# Epoch 112/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4265 - accuracy: 0.7823 - val_loss: 0.4284 - val_accuracy: 0.7829
# Epoch 113/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4278 - accuracy: 0.7812 - val_loss: 0.4296 - val_accuracy: 0.7821
# Epoch 114/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4271 - accuracy: 0.7817 - val_loss: 0.4274 - val_accuracy: 0.7841
# Epoch 115/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4264 - accuracy: 0.7824 - val_loss: 0.4339 - val_accuracy: 0.7831
# Epoch 116/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4271 - accuracy: 0.7818 - val_loss: 0.4274 - val_accuracy: 0.7822
# Epoch 117/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4263 - accuracy: 0.7821 - val_loss: 0.4277 - val_accuracy: 0.7810
# Epoch 118/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4263 - accuracy: 0.7825 - val_loss: 0.4287 - val_accuracy: 0.7826
# Epoch 119/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4259 - accuracy: 0.7824 - val_loss: 0.4276 - val_accuracy: 0.7842
# Epoch 120/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4263 - accuracy: 0.7823 - val_loss: 0.4305 - val_accuracy: 0.7777
# Epoch 121/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4270 - accuracy: 0.7823 - val_loss: 0.4282 - val_accuracy: 0.7807
# Epoch 122/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4256 - accuracy: 0.7826 - val_loss: 0.4272 - val_accuracy: 0.7843
# Epoch 123/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4251 - accuracy: 0.7827 - val_loss: 0.4292 - val_accuracy: 0.7810
# Epoch 124/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4250 - accuracy: 0.7826 - val_loss: 0.4325 - val_accuracy: 0.7841
# Epoch 125/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4248 - accuracy: 0.7831 - val_loss: 0.4291 - val_accuracy: 0.7815
# Epoch 126/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4248 - accuracy: 0.7828 - val_loss: 0.4301 - val_accuracy: 0.7831
# Epoch 127/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4249 - accuracy: 0.7830 - val_loss: 0.4300 - val_accuracy: 0.7824
# Epoch 128/140
# 24/24 [==============================] - 48s 2s/step - loss: 0.4243 - accuracy: 0.7831 - val_loss: 0.4298 - val_accuracy: 0.7838
# Epoch 129/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4239 - accuracy: 0.7828 - val_loss: 0.4289 - val_accuracy: 0.7840
# Epoch 130/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4237 - accuracy: 0.7832 - val_loss: 0.4263 - val_accuracy: 0.7848
# Epoch 131/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4247 - accuracy: 0.7827 - val_loss: 0.4265 - val_accuracy: 0.7829
# Epoch 132/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4251 - accuracy: 0.7829 - val_loss: 0.4368 - val_accuracy: 0.7833
# Epoch 133/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4266 - accuracy: 0.7825 - val_loss: 0.4258 - val_accuracy: 0.7838
# Epoch 134/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4233 - accuracy: 0.7836 - val_loss: 0.4259 - val_accuracy: 0.7847
# Epoch 135/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4231 - accuracy: 0.7836 - val_loss: 0.4269 - val_accuracy: 0.7831
# Epoch 136/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4227 - accuracy: 0.7838 - val_loss: 0.4260 - val_accuracy: 0.7847
# Epoch 137/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4226 - accuracy: 0.7838 - val_loss: 0.4267 - val_accuracy: 0.7844
# Epoch 138/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4226 - accuracy: 0.7839 - val_loss: 0.4405 - val_accuracy: 0.7766
# Epoch 139/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4238 - accuracy: 0.7833 - val_loss: 0.4350 - val_accuracy: 0.7838
# Epoch 140/140
# 24/24 [==============================] - 47s 2s/step - loss: 0.4230 - accuracy: 0.7840 - val_loss: 0.4314 - val_accuracy: 0.7836

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 12s 4ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 9434.373173475266

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.0039482 ],
#        [0.0032834 ],
#        [0.00173407],
#        ...,
#        [0.04076348],
#        [0.04314525],
#        [0.04449807]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1436620110919214
# 0.2274744533936084
# 0.3790277181050502
# 0.27654724390280716

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 62s 4ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.62358064]
# [0.81493425]
# total acc [0.78313182]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6392\725781306.py in <module>
# ----> 1 tf.config.experimental.get_memory_info('GPU:0')
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\config.py in get_memory_info(device)
#     574     ValueError: Memory statistics not tracked, like '"CPU:0"'.
#     575   """
# --> 576   return context.context().get_memory_info(device)
#     577
#     578
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\context.py in get_memory_info(self, dev)
#    1628     self._initialize_physical_devices()
#    1629     self.ensure_initialized()
# -> 1630     return pywrap_tfe.TFE_GetMemoryInfo(self._context_handle, dev)
#    1631
#    1632   def reset_memory_stats(self, dev):
#
# ValueError: No matching devices found for 'GPU:0'
