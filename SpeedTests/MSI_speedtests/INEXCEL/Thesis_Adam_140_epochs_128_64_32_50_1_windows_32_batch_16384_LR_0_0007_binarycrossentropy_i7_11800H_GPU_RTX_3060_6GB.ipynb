# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
config = tf.compat.v1.ConfigProto()
#config.gpu_options.allow_growth=True
config.gpu_options.per_process_gpu_memory_fraction= 0.97
sess = tf.compat.v1.Session(config=config)

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2007ff45040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2001af94040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 8s 174ms/step - loss: 0.6255 - accuracy: 0.6526 - val_loss: 0.5619 - val_accuracy: 0.7530
# Epoch 2/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.5749 - accuracy: 0.7393 - val_loss: 0.5588 - val_accuracy: 0.7530
# Epoch 3/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.5721 - accuracy: 0.7393 - val_loss: 0.5565 - val_accuracy: 0.7530
# Epoch 4/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.5560 - accuracy: 0.7375 - val_loss: 0.5273 - val_accuracy: 0.7531
# Epoch 5/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.5242 - accuracy: 0.7400 - val_loss: 0.4973 - val_accuracy: 0.7517
# Epoch 6/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.5070 - accuracy: 0.7380 - val_loss: 0.4877 - val_accuracy: 0.7532
# Epoch 7/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4993 - accuracy: 0.7418 - val_loss: 0.4828 - val_accuracy: 0.7539
# Epoch 8/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4948 - accuracy: 0.7456 - val_loss: 0.4798 - val_accuracy: 0.7536
# Epoch 9/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4907 - accuracy: 0.7472 - val_loss: 0.4824 - val_accuracy: 0.7522
# Epoch 10/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4843 - accuracy: 0.7488 - val_loss: 0.4727 - val_accuracy: 0.7548
# Epoch 11/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4773 - accuracy: 0.7533 - val_loss: 0.4659 - val_accuracy: 0.7606
# Epoch 12/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4719 - accuracy: 0.7565 - val_loss: 0.4602 - val_accuracy: 0.7633
# Epoch 13/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4685 - accuracy: 0.7583 - val_loss: 0.4574 - val_accuracy: 0.7643
# Epoch 14/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4649 - accuracy: 0.7598 - val_loss: 0.4695 - val_accuracy: 0.7573
# Epoch 15/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4675 - accuracy: 0.7594 - val_loss: 0.4524 - val_accuracy: 0.7668
# Epoch 16/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4611 - accuracy: 0.7616 - val_loss: 0.4540 - val_accuracy: 0.7672
# Epoch 17/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4634 - accuracy: 0.7610 - val_loss: 0.4558 - val_accuracy: 0.7652
# Epoch 18/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4597 - accuracy: 0.7628 - val_loss: 0.4510 - val_accuracy: 0.7668
# Epoch 19/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4565 - accuracy: 0.7638 - val_loss: 0.4483 - val_accuracy: 0.7685
# Epoch 20/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4558 - accuracy: 0.7641 - val_loss: 0.4470 - val_accuracy: 0.7691
# Epoch 21/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4550 - accuracy: 0.7643 - val_loss: 0.4486 - val_accuracy: 0.7696
# Epoch 22/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4553 - accuracy: 0.7649 - val_loss: 0.4477 - val_accuracy: 0.7697
# Epoch 23/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4533 - accuracy: 0.7656 - val_loss: 0.4515 - val_accuracy: 0.7702
# Epoch 24/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4519 - accuracy: 0.7663 - val_loss: 0.4453 - val_accuracy: 0.7714
# Epoch 25/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4522 - accuracy: 0.7666 - val_loss: 0.4441 - val_accuracy: 0.7698
# Epoch 26/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4499 - accuracy: 0.7674 - val_loss: 0.4490 - val_accuracy: 0.7716
# Epoch 27/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4513 - accuracy: 0.7671 - val_loss: 0.4435 - val_accuracy: 0.7725
# Epoch 28/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4489 - accuracy: 0.7678 - val_loss: 0.4422 - val_accuracy: 0.7737
# Epoch 29/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4483 - accuracy: 0.7685 - val_loss: 0.4442 - val_accuracy: 0.7715
# Epoch 30/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4479 - accuracy: 0.7690 - val_loss: 0.4400 - val_accuracy: 0.7737
# Epoch 31/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4477 - accuracy: 0.7695 - val_loss: 0.4423 - val_accuracy: 0.7740
# Epoch 32/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4468 - accuracy: 0.7697 - val_loss: 0.4394 - val_accuracy: 0.7758
# Epoch 33/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4457 - accuracy: 0.7705 - val_loss: 0.4409 - val_accuracy: 0.7757
# Epoch 34/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4456 - accuracy: 0.7706 - val_loss: 0.4400 - val_accuracy: 0.7754
# Epoch 35/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4444 - accuracy: 0.7717 - val_loss: 0.4390 - val_accuracy: 0.7755
# Epoch 36/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4431 - accuracy: 0.7722 - val_loss: 0.4366 - val_accuracy: 0.7763
# Epoch 37/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4430 - accuracy: 0.7727 - val_loss: 0.4371 - val_accuracy: 0.7770
# Epoch 38/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4422 - accuracy: 0.7733 - val_loss: 0.4489 - val_accuracy: 0.7706
# Epoch 39/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4442 - accuracy: 0.7724 - val_loss: 0.4362 - val_accuracy: 0.7778
# Epoch 40/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4414 - accuracy: 0.7738 - val_loss: 0.4387 - val_accuracy: 0.7755
# Epoch 41/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4424 - accuracy: 0.7740 - val_loss: 0.4368 - val_accuracy: 0.7773
# Epoch 42/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4401 - accuracy: 0.7745 - val_loss: 0.4411 - val_accuracy: 0.7773
# Epoch 43/140
# 24/24 [==============================] - 4s 149ms/step - loss: 0.4408 - accuracy: 0.7748 - val_loss: 0.4398 - val_accuracy: 0.7772
# Epoch 44/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4401 - accuracy: 0.7752 - val_loss: 0.4328 - val_accuracy: 0.7792
# Epoch 45/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4393 - accuracy: 0.7755 - val_loss: 0.4336 - val_accuracy: 0.7787
# Epoch 46/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4387 - accuracy: 0.7755 - val_loss: 0.4383 - val_accuracy: 0.7775
# Epoch 47/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4379 - accuracy: 0.7760 - val_loss: 0.4347 - val_accuracy: 0.7768
# Epoch 48/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4378 - accuracy: 0.7762 - val_loss: 0.4337 - val_accuracy: 0.7797
# Epoch 49/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4377 - accuracy: 0.7760 - val_loss: 0.4333 - val_accuracy: 0.7780
# Epoch 50/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4377 - accuracy: 0.7766 - val_loss: 0.4318 - val_accuracy: 0.7786
# Epoch 51/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4376 - accuracy: 0.7761 - val_loss: 0.4314 - val_accuracy: 0.7794
# Epoch 52/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4366 - accuracy: 0.7766 - val_loss: 0.4340 - val_accuracy: 0.7776
# Epoch 53/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4361 - accuracy: 0.7774 - val_loss: 0.4368 - val_accuracy: 0.7768
# Epoch 54/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4367 - accuracy: 0.7770 - val_loss: 0.4352 - val_accuracy: 0.7769
# Epoch 55/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4352 - accuracy: 0.7775 - val_loss: 0.4332 - val_accuracy: 0.7792
# Epoch 56/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4351 - accuracy: 0.7775 - val_loss: 0.4334 - val_accuracy: 0.7803
# Epoch 57/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4348 - accuracy: 0.7774 - val_loss: 0.4307 - val_accuracy: 0.7809
# Epoch 58/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4367 - accuracy: 0.7775 - val_loss: 0.4318 - val_accuracy: 0.7811
# Epoch 59/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4344 - accuracy: 0.7777 - val_loss: 0.4322 - val_accuracy: 0.7794
# Epoch 60/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4339 - accuracy: 0.7780 - val_loss: 0.4295 - val_accuracy: 0.7807
# Epoch 61/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4348 - accuracy: 0.7776 - val_loss: 0.4336 - val_accuracy: 0.7802
# Epoch 62/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4335 - accuracy: 0.7780 - val_loss: 0.4302 - val_accuracy: 0.7801
# Epoch 63/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4330 - accuracy: 0.7784 - val_loss: 0.4326 - val_accuracy: 0.7799
# Epoch 64/140
# 24/24 [==============================] - 4s 149ms/step - loss: 0.4338 - accuracy: 0.7778 - val_loss: 0.4296 - val_accuracy: 0.7814
# Epoch 65/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4320 - accuracy: 0.7787 - val_loss: 0.4289 - val_accuracy: 0.7811
# Epoch 66/140
# 24/24 [==============================] - 4s 149ms/step - loss: 0.4327 - accuracy: 0.7784 - val_loss: 0.4331 - val_accuracy: 0.7790
# Epoch 67/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4328 - accuracy: 0.7783 - val_loss: 0.4297 - val_accuracy: 0.7798
# Epoch 68/140
# 24/24 [==============================] - 4s 149ms/step - loss: 0.4316 - accuracy: 0.7787 - val_loss: 0.4302 - val_accuracy: 0.7784
# Epoch 69/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4318 - accuracy: 0.7785 - val_loss: 0.4296 - val_accuracy: 0.7797
# Epoch 70/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4321 - accuracy: 0.7787 - val_loss: 0.4353 - val_accuracy: 0.7756
# Epoch 71/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4326 - accuracy: 0.7785 - val_loss: 0.4310 - val_accuracy: 0.7793
# Epoch 72/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4315 - accuracy: 0.7784 - val_loss: 0.4286 - val_accuracy: 0.7808
# Epoch 73/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4311 - accuracy: 0.7789 - val_loss: 0.4311 - val_accuracy: 0.7808
# Epoch 74/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4309 - accuracy: 0.7790 - val_loss: 0.4406 - val_accuracy: 0.7801
# Epoch 75/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4323 - accuracy: 0.7787 - val_loss: 0.4287 - val_accuracy: 0.7806
# Epoch 76/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4301 - accuracy: 0.7793 - val_loss: 0.4319 - val_accuracy: 0.7812
# Epoch 77/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4305 - accuracy: 0.7796 - val_loss: 0.4289 - val_accuracy: 0.7802
# Epoch 78/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4298 - accuracy: 0.7795 - val_loss: 0.4284 - val_accuracy: 0.7815
# Epoch 79/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4308 - accuracy: 0.7794 - val_loss: 0.4280 - val_accuracy: 0.7819
# Epoch 80/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4293 - accuracy: 0.7797 - val_loss: 0.4288 - val_accuracy: 0.7811
# Epoch 81/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4295 - accuracy: 0.7798 - val_loss: 0.4318 - val_accuracy: 0.7799
# Epoch 82/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4298 - accuracy: 0.7794 - val_loss: 0.4297 - val_accuracy: 0.7808
# Epoch 83/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4300 - accuracy: 0.7798 - val_loss: 0.4296 - val_accuracy: 0.7791
# Epoch 84/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4296 - accuracy: 0.7800 - val_loss: 0.4294 - val_accuracy: 0.7806
# Epoch 85/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4297 - accuracy: 0.7797 - val_loss: 0.4321 - val_accuracy: 0.7777
# Epoch 86/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4293 - accuracy: 0.7796 - val_loss: 0.4321 - val_accuracy: 0.7803
# Epoch 87/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4287 - accuracy: 0.7800 - val_loss: 0.4286 - val_accuracy: 0.7812
# Epoch 88/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4286 - accuracy: 0.7801 - val_loss: 0.4289 - val_accuracy: 0.7809
# Epoch 89/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4283 - accuracy: 0.7803 - val_loss: 0.4332 - val_accuracy: 0.7807
# Epoch 90/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4294 - accuracy: 0.7797 - val_loss: 0.4316 - val_accuracy: 0.7792
# Epoch 91/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4292 - accuracy: 0.7802 - val_loss: 0.4371 - val_accuracy: 0.7817
# Epoch 92/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4283 - accuracy: 0.7805 - val_loss: 0.4284 - val_accuracy: 0.7822
# Epoch 93/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4271 - accuracy: 0.7809 - val_loss: 0.4307 - val_accuracy: 0.7797
# Epoch 94/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4276 - accuracy: 0.7804 - val_loss: 0.4328 - val_accuracy: 0.7812
# Epoch 95/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4269 - accuracy: 0.7810 - val_loss: 0.4307 - val_accuracy: 0.7797
# Epoch 96/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4275 - accuracy: 0.7807 - val_loss: 0.4289 - val_accuracy: 0.7808
# Epoch 97/140
# 24/24 [==============================] - 4s 150ms/step - loss: 0.4275 - accuracy: 0.7811 - val_loss: 0.4291 - val_accuracy: 0.7822
# Epoch 98/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4276 - accuracy: 0.7810 - val_loss: 0.4281 - val_accuracy: 0.7815
# Epoch 99/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4270 - accuracy: 0.7810 - val_loss: 0.4307 - val_accuracy: 0.7811
# Epoch 100/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4264 - accuracy: 0.7814 - val_loss: 0.4272 - val_accuracy: 0.7836
# Epoch 101/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4263 - accuracy: 0.7814 - val_loss: 0.4300 - val_accuracy: 0.7834
# Epoch 102/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4265 - accuracy: 0.7814 - val_loss: 0.4384 - val_accuracy: 0.7822
# Epoch 103/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4265 - accuracy: 0.7813 - val_loss: 0.4277 - val_accuracy: 0.7823
# Epoch 104/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4253 - accuracy: 0.7818 - val_loss: 0.4287 - val_accuracy: 0.7814
# Epoch 105/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4251 - accuracy: 0.7817 - val_loss: 0.4276 - val_accuracy: 0.7819
# Epoch 106/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4253 - accuracy: 0.7818 - val_loss: 0.4292 - val_accuracy: 0.7822
# Epoch 107/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4251 - accuracy: 0.7818 - val_loss: 0.4324 - val_accuracy: 0.7816
# Epoch 108/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4247 - accuracy: 0.7823 - val_loss: 0.4298 - val_accuracy: 0.7815
# Epoch 109/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4249 - accuracy: 0.7822 - val_loss: 0.4356 - val_accuracy: 0.7823
# Epoch 110/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4254 - accuracy: 0.7826 - val_loss: 0.4282 - val_accuracy: 0.7833
# Epoch 111/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4244 - accuracy: 0.7828 - val_loss: 0.4279 - val_accuracy: 0.7827
# Epoch 112/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4238 - accuracy: 0.7828 - val_loss: 0.4297 - val_accuracy: 0.7840
# Epoch 113/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4245 - accuracy: 0.7829 - val_loss: 0.4269 - val_accuracy: 0.7818
# Epoch 114/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4232 - accuracy: 0.7833 - val_loss: 0.4291 - val_accuracy: 0.7828
# Epoch 115/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4250 - accuracy: 0.7827 - val_loss: 0.4302 - val_accuracy: 0.7786
# Epoch 116/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4259 - accuracy: 0.7829 - val_loss: 0.4290 - val_accuracy: 0.7820
# Epoch 117/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4258 - accuracy: 0.7827 - val_loss: 0.4356 - val_accuracy: 0.7827
# Epoch 118/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4232 - accuracy: 0.7833 - val_loss: 0.4307 - val_accuracy: 0.7838
# Epoch 119/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4222 - accuracy: 0.7839 - val_loss: 0.4284 - val_accuracy: 0.7831
# Epoch 120/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4221 - accuracy: 0.7836 - val_loss: 0.4291 - val_accuracy: 0.7820
# Epoch 121/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4224 - accuracy: 0.7838 - val_loss: 0.4287 - val_accuracy: 0.7828
# Epoch 122/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4228 - accuracy: 0.7836 - val_loss: 0.4294 - val_accuracy: 0.7852
# Epoch 123/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4232 - accuracy: 0.7836 - val_loss: 0.4340 - val_accuracy: 0.7843
# Epoch 124/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4223 - accuracy: 0.7844 - val_loss: 0.4306 - val_accuracy: 0.7832
# Epoch 125/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4215 - accuracy: 0.7844 - val_loss: 0.4311 - val_accuracy: 0.7849
# Epoch 126/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4217 - accuracy: 0.7845 - val_loss: 0.4260 - val_accuracy: 0.7830
# Epoch 127/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4215 - accuracy: 0.7846 - val_loss: 0.4352 - val_accuracy: 0.7845
# Epoch 128/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4212 - accuracy: 0.7844 - val_loss: 0.4274 - val_accuracy: 0.7849
# Epoch 129/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4210 - accuracy: 0.7849 - val_loss: 0.4261 - val_accuracy: 0.7845
# Epoch 130/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4212 - accuracy: 0.7846 - val_loss: 0.4298 - val_accuracy: 0.7800
# Epoch 131/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4218 - accuracy: 0.7851 - val_loss: 0.4265 - val_accuracy: 0.7839
# Epoch 132/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4219 - accuracy: 0.7845 - val_loss: 0.4289 - val_accuracy: 0.7828
# Epoch 133/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4200 - accuracy: 0.7854 - val_loss: 0.4263 - val_accuracy: 0.7826
# Epoch 134/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4202 - accuracy: 0.7854 - val_loss: 0.4293 - val_accuracy: 0.7854
# Epoch 135/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4200 - accuracy: 0.7854 - val_loss: 0.4302 - val_accuracy: 0.7814
# Epoch 136/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4197 - accuracy: 0.7851 - val_loss: 0.4266 - val_accuracy: 0.7851
# Epoch 137/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4192 - accuracy: 0.7856 - val_loss: 0.4394 - val_accuracy: 0.7822
# Epoch 138/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4214 - accuracy: 0.7848 - val_loss: 0.4245 - val_accuracy: 0.7845
# Epoch 139/140
# 24/24 [==============================] - 4s 148ms/step - loss: 0.4193 - accuracy: 0.7856 - val_loss: 0.4314 - val_accuracy: 0.7831
# Epoch 140/140
# 24/24 [==============================] - 4s 147ms/step - loss: 0.4194 - accuracy: 0.7860 - val_loss: 0.4327 - val_accuracy: 0.7850

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 12s 4ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 514.4871640205383

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00083871],
#        [0.00112496],
#        [0.00098114],
#        ...,
#        [0.03585603],
#        [0.03862926],
#        [0.04134221]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1431122796975902
# 0.23045233130680187
# 0.3783018367621154
# 0.2778829911008971

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 56s 4ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.62412451]
# [0.82011078]
# total acc [0.78567025]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 5257622272}
