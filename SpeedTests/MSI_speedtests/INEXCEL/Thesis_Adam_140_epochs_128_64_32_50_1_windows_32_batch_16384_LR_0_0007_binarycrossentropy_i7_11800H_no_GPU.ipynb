# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x161445bc040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x161b8671040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 100s 4s/step - loss: 0.6872 - accuracy: 0.5573 - val_loss: 0.5594 - val_accuracy: 0.7530
# Epoch 2/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.5760 - accuracy: 0.7393 - val_loss: 0.5597 - val_accuracy: 0.7530
# Epoch 3/140
# 24/24 [==============================] - 99s 4s/step - loss: 0.5739 - accuracy: 0.7393 - val_loss: 0.5594 - val_accuracy: 0.7530
# Epoch 4/140
# 24/24 [==============================] - 99s 4s/step - loss: 0.5738 - accuracy: 0.7393 - val_loss: 0.5596 - val_accuracy: 0.7530
# Epoch 5/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5593 - val_accuracy: 0.7530
# Epoch 6/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.5733 - accuracy: 0.7393 - val_loss: 0.5589 - val_accuracy: 0.7530
# Epoch 7/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.5714 - accuracy: 0.7393 - val_loss: 0.5538 - val_accuracy: 0.7530
# Epoch 8/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.5573 - accuracy: 0.7393 - val_loss: 0.5331 - val_accuracy: 0.7530
# Epoch 9/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.5371 - accuracy: 0.7393 - val_loss: 0.5104 - val_accuracy: 0.7530
# Epoch 10/140
# 24/24 [==============================] - 97s 4s/step - loss: 0.5171 - accuracy: 0.7392 - val_loss: 0.4932 - val_accuracy: 0.7530
# Epoch 11/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.5048 - accuracy: 0.7389 - val_loss: 0.4971 - val_accuracy: 0.7532
# Epoch 12/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.5012 - accuracy: 0.7391 - val_loss: 0.4848 - val_accuracy: 0.7532
# Epoch 13/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4982 - accuracy: 0.7388 - val_loss: 0.4882 - val_accuracy: 0.7531
# Epoch 14/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4968 - accuracy: 0.7392 - val_loss: 0.4881 - val_accuracy: 0.7538
# Epoch 15/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4948 - accuracy: 0.7400 - val_loss: 0.4818 - val_accuracy: 0.7534
# Epoch 16/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4933 - accuracy: 0.7427 - val_loss: 0.4770 - val_accuracy: 0.7534
# Epoch 17/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4881 - accuracy: 0.7470 - val_loss: 0.4744 - val_accuracy: 0.7550
# Epoch 18/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4825 - accuracy: 0.7497 - val_loss: 0.4720 - val_accuracy: 0.7542
# Epoch 19/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4784 - accuracy: 0.7522 - val_loss: 0.4679 - val_accuracy: 0.7574
# Epoch 20/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4737 - accuracy: 0.7552 - val_loss: 0.4641 - val_accuracy: 0.7603
# Epoch 21/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4694 - accuracy: 0.7579 - val_loss: 0.4729 - val_accuracy: 0.7624
# Epoch 22/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4715 - accuracy: 0.7576 - val_loss: 0.4591 - val_accuracy: 0.7639
# Epoch 23/140
# 24/24 [==============================] - 94s 4s/step - loss: 0.4653 - accuracy: 0.7600 - val_loss: 0.4578 - val_accuracy: 0.7634
# Epoch 24/140
# 24/24 [==============================] - 94s 4s/step - loss: 0.4655 - accuracy: 0.7602 - val_loss: 0.4644 - val_accuracy: 0.7644
# Epoch 25/140
# 24/24 [==============================] - 94s 4s/step - loss: 0.4632 - accuracy: 0.7606 - val_loss: 0.4541 - val_accuracy: 0.7659
# Epoch 26/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4606 - accuracy: 0.7612 - val_loss: 0.4598 - val_accuracy: 0.7660
# Epoch 27/140
# 24/24 [==============================] - 94s 4s/step - loss: 0.4614 - accuracy: 0.7616 - val_loss: 0.4534 - val_accuracy: 0.7675
# Epoch 28/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4591 - accuracy: 0.7619 - val_loss: 0.4500 - val_accuracy: 0.7669
# Epoch 29/140
# 24/24 [==============================] - 94s 4s/step - loss: 0.4576 - accuracy: 0.7627 - val_loss: 0.4713 - val_accuracy: 0.7684
# Epoch 30/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4635 - accuracy: 0.7615 - val_loss: 0.4517 - val_accuracy: 0.7671
# Epoch 31/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4566 - accuracy: 0.7638 - val_loss: 0.4488 - val_accuracy: 0.7688
# Epoch 32/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4553 - accuracy: 0.7637 - val_loss: 0.4474 - val_accuracy: 0.7687
# Epoch 33/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4538 - accuracy: 0.7643 - val_loss: 0.4460 - val_accuracy: 0.7692
# Epoch 34/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4532 - accuracy: 0.7647 - val_loss: 0.4459 - val_accuracy: 0.7701
# Epoch 35/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4533 - accuracy: 0.7653 - val_loss: 0.4460 - val_accuracy: 0.7696
# Epoch 36/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4515 - accuracy: 0.7661 - val_loss: 0.4445 - val_accuracy: 0.7705
# Epoch 37/140
# 24/24 [==============================] - 94s 4s/step - loss: 0.4506 - accuracy: 0.7663 - val_loss: 0.4450 - val_accuracy: 0.7716
# Epoch 38/140
# 24/24 [==============================] - 94s 4s/step - loss: 0.4523 - accuracy: 0.7669 - val_loss: 0.4430 - val_accuracy: 0.7724
# Epoch 39/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4493 - accuracy: 0.7670 - val_loss: 0.4462 - val_accuracy: 0.7718
# Epoch 40/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4505 - accuracy: 0.7671 - val_loss: 0.4425 - val_accuracy: 0.7733
# Epoch 41/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4494 - accuracy: 0.7683 - val_loss: 0.4468 - val_accuracy: 0.7706
# Epoch 42/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4483 - accuracy: 0.7686 - val_loss: 0.4400 - val_accuracy: 0.7752
# Epoch 43/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4486 - accuracy: 0.7692 - val_loss: 0.4404 - val_accuracy: 0.7739
# Epoch 44/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4464 - accuracy: 0.7696 - val_loss: 0.4433 - val_accuracy: 0.7747
# Epoch 45/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4459 - accuracy: 0.7704 - val_loss: 0.4412 - val_accuracy: 0.7754
# Epoch 46/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4467 - accuracy: 0.7704 - val_loss: 0.4429 - val_accuracy: 0.7733
# Epoch 47/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4462 - accuracy: 0.7707 - val_loss: 0.4402 - val_accuracy: 0.7751
# Epoch 48/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4439 - accuracy: 0.7719 - val_loss: 0.4387 - val_accuracy: 0.7752
# Epoch 49/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4430 - accuracy: 0.7727 - val_loss: 0.4362 - val_accuracy: 0.7779
# Epoch 50/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4427 - accuracy: 0.7728 - val_loss: 0.4365 - val_accuracy: 0.7781
# Epoch 51/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4426 - accuracy: 0.7730 - val_loss: 0.4385 - val_accuracy: 0.7773
# Epoch 52/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4425 - accuracy: 0.7732 - val_loss: 0.4382 - val_accuracy: 0.7761
# Epoch 53/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4418 - accuracy: 0.7739 - val_loss: 0.4362 - val_accuracy: 0.7768
# Epoch 54/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4396 - accuracy: 0.7747 - val_loss: 0.4386 - val_accuracy: 0.7781
# Epoch 55/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4409 - accuracy: 0.7743 - val_loss: 0.4360 - val_accuracy: 0.7772
# Epoch 56/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4400 - accuracy: 0.7751 - val_loss: 0.4356 - val_accuracy: 0.7789
# Epoch 57/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4399 - accuracy: 0.7754 - val_loss: 0.4402 - val_accuracy: 0.7748
# Epoch 58/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4393 - accuracy: 0.7753 - val_loss: 0.4369 - val_accuracy: 0.7792
# Epoch 59/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4381 - accuracy: 0.7761 - val_loss: 0.4339 - val_accuracy: 0.7775
# Epoch 60/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4375 - accuracy: 0.7763 - val_loss: 0.4358 - val_accuracy: 0.7768
# Epoch 61/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4376 - accuracy: 0.7763 - val_loss: 0.4336 - val_accuracy: 0.7780
# Epoch 62/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4379 - accuracy: 0.7767 - val_loss: 0.4342 - val_accuracy: 0.7781
# Epoch 63/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4375 - accuracy: 0.7766 - val_loss: 0.4357 - val_accuracy: 0.7790
# Epoch 64/140
# 24/24 [==============================] - 93s 4s/step - loss: 0.4367 - accuracy: 0.7770 - val_loss: 0.4391 - val_accuracy: 0.7781
# Epoch 65/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4363 - accuracy: 0.7773 - val_loss: 0.4322 - val_accuracy: 0.7803
# Epoch 66/140
# 24/24 [==============================] - 94s 4s/step - loss: 0.4360 - accuracy: 0.7773 - val_loss: 0.4437 - val_accuracy: 0.7713
# Epoch 67/140
# 24/24 [==============================] - 93s 4s/step - loss: 0.4389 - accuracy: 0.7765 - val_loss: 0.4324 - val_accuracy: 0.7786
# Epoch 68/140
# 24/24 [==============================] - 93s 4s/step - loss: 0.4357 - accuracy: 0.7778 - val_loss: 0.4308 - val_accuracy: 0.7780
# Epoch 69/140
# 24/24 [==============================] - 94s 4s/step - loss: 0.4347 - accuracy: 0.7784 - val_loss: 0.4350 - val_accuracy: 0.7792
# Epoch 70/140
# 24/24 [==============================] - 548s 24s/step - loss: 0.4344 - accuracy: 0.7781 - val_loss: 0.4310 - val_accuracy: 0.7779
# Epoch 71/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4338 - accuracy: 0.7780 - val_loss: 0.4324 - val_accuracy: 0.7809
# Epoch 72/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4336 - accuracy: 0.7785 - val_loss: 0.4312 - val_accuracy: 0.7791
# Epoch 73/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4339 - accuracy: 0.7781 - val_loss: 0.4332 - val_accuracy: 0.7797
# Epoch 74/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4335 - accuracy: 0.7787 - val_loss: 0.4308 - val_accuracy: 0.7783
# Epoch 75/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4324 - accuracy: 0.7790 - val_loss: 0.4347 - val_accuracy: 0.7764
# Epoch 76/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4328 - accuracy: 0.7788 - val_loss: 0.4299 - val_accuracy: 0.7790
# Epoch 77/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4324 - accuracy: 0.7789 - val_loss: 0.4297 - val_accuracy: 0.7804
# Epoch 78/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4315 - accuracy: 0.7795 - val_loss: 0.4328 - val_accuracy: 0.7806
# Epoch 79/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4320 - accuracy: 0.7792 - val_loss: 0.4365 - val_accuracy: 0.7791
# Epoch 80/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4334 - accuracy: 0.7788 - val_loss: 0.4295 - val_accuracy: 0.7800
# Epoch 81/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4327 - accuracy: 0.7793 - val_loss: 0.4380 - val_accuracy: 0.7786
# Epoch 82/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4316 - accuracy: 0.7794 - val_loss: 0.4279 - val_accuracy: 0.7816
# Epoch 83/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4309 - accuracy: 0.7799 - val_loss: 0.4332 - val_accuracy: 0.7799
# Epoch 84/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4312 - accuracy: 0.7796 - val_loss: 0.4288 - val_accuracy: 0.7811
# Epoch 85/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4323 - accuracy: 0.7795 - val_loss: 0.4298 - val_accuracy: 0.7821
# Epoch 86/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4318 - accuracy: 0.7801 - val_loss: 0.4292 - val_accuracy: 0.7813
# Epoch 87/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4302 - accuracy: 0.7802 - val_loss: 0.4297 - val_accuracy: 0.7788
# Epoch 88/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4306 - accuracy: 0.7804 - val_loss: 0.4296 - val_accuracy: 0.7812
# Epoch 89/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4297 - accuracy: 0.7806 - val_loss: 0.4300 - val_accuracy: 0.7781
# Epoch 90/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4293 - accuracy: 0.7806 - val_loss: 0.4300 - val_accuracy: 0.7809
# Epoch 91/140
# 24/24 [==============================] - 99s 4s/step - loss: 0.4301 - accuracy: 0.7804 - val_loss: 0.4325 - val_accuracy: 0.7787
# Epoch 92/140
# 24/24 [==============================] - 101s 4s/step - loss: 0.4299 - accuracy: 0.7803 - val_loss: 0.4285 - val_accuracy: 0.7815
# Epoch 93/140
# 24/24 [==============================] - 103s 4s/step - loss: 0.4288 - accuracy: 0.7814 - val_loss: 0.4339 - val_accuracy: 0.7786
# Epoch 94/140
# 24/24 [==============================] - 102s 4s/step - loss: 0.4288 - accuracy: 0.7807 - val_loss: 0.4304 - val_accuracy: 0.7792
# Epoch 95/140
# 24/24 [==============================] - 101s 4s/step - loss: 0.4285 - accuracy: 0.7808 - val_loss: 0.4364 - val_accuracy: 0.7721
# Epoch 96/140
# 24/24 [==============================] - 99s 4s/step - loss: 0.4297 - accuracy: 0.7809 - val_loss: 0.4298 - val_accuracy: 0.7822
# Epoch 97/140
# 24/24 [==============================] - 99s 4s/step - loss: 0.4287 - accuracy: 0.7810 - val_loss: 0.4323 - val_accuracy: 0.7796
# Epoch 98/140
# 24/24 [==============================] - 98s 4s/step - loss: 0.4303 - accuracy: 0.7805 - val_loss: 0.4273 - val_accuracy: 0.7825
# Epoch 99/140
# 24/24 [==============================] - 99s 4s/step - loss: 0.4276 - accuracy: 0.7812 - val_loss: 0.4288 - val_accuracy: 0.7805
# Epoch 100/140
# 24/24 [==============================] - 98s 4s/step - loss: 0.4276 - accuracy: 0.7815 - val_loss: 0.4310 - val_accuracy: 0.7771
# Epoch 101/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4294 - accuracy: 0.7810 - val_loss: 0.4330 - val_accuracy: 0.7806
# Epoch 102/140
# 24/24 [==============================] - 94s 4s/step - loss: 0.4276 - accuracy: 0.7818 - val_loss: 0.4313 - val_accuracy: 0.7820
# Epoch 103/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4269 - accuracy: 0.7814 - val_loss: 0.4276 - val_accuracy: 0.7796
# Epoch 104/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4269 - accuracy: 0.7819 - val_loss: 0.4339 - val_accuracy: 0.7750
# Epoch 105/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4285 - accuracy: 0.7816 - val_loss: 0.4328 - val_accuracy: 0.7833
# Epoch 106/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4291 - accuracy: 0.7813 - val_loss: 0.4321 - val_accuracy: 0.7822
# Epoch 107/140
# 24/24 [==============================] - 97s 4s/step - loss: 0.4270 - accuracy: 0.7818 - val_loss: 0.4277 - val_accuracy: 0.7832
# Epoch 108/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4284 - accuracy: 0.7816 - val_loss: 0.4271 - val_accuracy: 0.7814
# Epoch 109/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4263 - accuracy: 0.7821 - val_loss: 0.4333 - val_accuracy: 0.7747
# Epoch 110/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4274 - accuracy: 0.7821 - val_loss: 0.4283 - val_accuracy: 0.7798
# Epoch 111/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4255 - accuracy: 0.7824 - val_loss: 0.4289 - val_accuracy: 0.7825
# Epoch 112/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4254 - accuracy: 0.7827 - val_loss: 0.4297 - val_accuracy: 0.7806
# Epoch 113/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4254 - accuracy: 0.7821 - val_loss: 0.4328 - val_accuracy: 0.7799
# Epoch 114/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4251 - accuracy: 0.7826 - val_loss: 0.4301 - val_accuracy: 0.7810
# Epoch 115/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4265 - accuracy: 0.7824 - val_loss: 0.4298 - val_accuracy: 0.7766
# Epoch 116/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4251 - accuracy: 0.7827 - val_loss: 0.4377 - val_accuracy: 0.7805
# Epoch 117/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4250 - accuracy: 0.7825 - val_loss: 0.4283 - val_accuracy: 0.7781
# Epoch 118/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4250 - accuracy: 0.7829 - val_loss: 0.4273 - val_accuracy: 0.7810
# Epoch 119/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4247 - accuracy: 0.7829 - val_loss: 0.4322 - val_accuracy: 0.7812
# Epoch 120/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4239 - accuracy: 0.7834 - val_loss: 0.4273 - val_accuracy: 0.7807
# Epoch 121/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4237 - accuracy: 0.7831 - val_loss: 0.4310 - val_accuracy: 0.7825
# Epoch 122/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4246 - accuracy: 0.7833 - val_loss: 0.4286 - val_accuracy: 0.7796
# Epoch 123/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4228 - accuracy: 0.7834 - val_loss: 0.4294 - val_accuracy: 0.7832
# Epoch 124/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4231 - accuracy: 0.7836 - val_loss: 0.4285 - val_accuracy: 0.7783
# Epoch 125/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4234 - accuracy: 0.7836 - val_loss: 0.4315 - val_accuracy: 0.7833
# Epoch 126/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4224 - accuracy: 0.7838 - val_loss: 0.4292 - val_accuracy: 0.7830
# Epoch 127/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4218 - accuracy: 0.7841 - val_loss: 0.4282 - val_accuracy: 0.7838
# Epoch 128/140
# 24/24 [==============================] - 97s 4s/step - loss: 0.4221 - accuracy: 0.7841 - val_loss: 0.4287 - val_accuracy: 0.7851
# Epoch 129/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4224 - accuracy: 0.7841 - val_loss: 0.4322 - val_accuracy: 0.7839
# Epoch 130/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4220 - accuracy: 0.7841 - val_loss: 0.4281 - val_accuracy: 0.7804
# Epoch 131/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4211 - accuracy: 0.7845 - val_loss: 0.4286 - val_accuracy: 0.7817
# Epoch 132/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4212 - accuracy: 0.7842 - val_loss: 0.4289 - val_accuracy: 0.7778
# Epoch 133/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4226 - accuracy: 0.7840 - val_loss: 0.4273 - val_accuracy: 0.7823
# Epoch 134/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4220 - accuracy: 0.7842 - val_loss: 0.4353 - val_accuracy: 0.7835
# Epoch 135/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4209 - accuracy: 0.7848 - val_loss: 0.4276 - val_accuracy: 0.7806
# Epoch 136/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4202 - accuracy: 0.7850 - val_loss: 0.4259 - val_accuracy: 0.7842
# Epoch 137/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4195 - accuracy: 0.7849 - val_loss: 0.4268 - val_accuracy: 0.7855
# Epoch 138/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4195 - accuracy: 0.7851 - val_loss: 0.4312 - val_accuracy: 0.7823
# Epoch 139/140
# 24/24 [==============================] - 95s 4s/step - loss: 0.4197 - accuracy: 0.7854 - val_loss: 0.4351 - val_accuracy: 0.7839
# Epoch 140/140
# 24/24 [==============================] - 96s 4s/step - loss: 0.4197 - accuracy: 0.7853 - val_loss: 0.4300 - val_accuracy: 0.7807

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 29s 10ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 13881.877894163132

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00182912],
#        [0.00356774],
#        [0.00291342],
#        ...,
#        [0.03465332],
#        [0.03571424],
#        [0.03606896]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1435753428757963
# 0.22796233401237564
# 0.3789133712021737
# 0.2835535650774451

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 135s 9ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.59906787]
# [0.83490452]
# total acc [0.78444157]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8992\725781306.py in <module>
# ----> 1 tf.config.experimental.get_memory_info('GPU:0')
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\config.py in get_memory_info(device)
#     574     ValueError: Memory statistics not tracked, like '"CPU:0"'.
#     575   """
# --> 576   return context.context().get_memory_info(device)
#     577
#     578
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\context.py in get_memory_info(self, dev)
#    1628     self._initialize_physical_devices()
#    1629     self.ensure_initialized()
# -> 1630     return pywrap_tfe.TFE_GetMemoryInfo(self._context_handle, dev)
#    1631
#    1632   def reset_memory_stats(self, dev):
#
# ValueError: No matching devices found for 'GPU:0'
