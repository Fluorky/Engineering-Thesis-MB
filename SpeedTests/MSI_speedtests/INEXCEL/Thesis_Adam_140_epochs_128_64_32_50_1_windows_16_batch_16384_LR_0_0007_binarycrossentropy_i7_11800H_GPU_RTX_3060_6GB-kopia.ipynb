# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1d502384040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1d53c3fc040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 7s 108ms/step - loss: 0.6399 - accuracy: 0.6158 - val_loss: 0.5595 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.5751 - accuracy: 0.7393 - val_loss: 0.5601 - val_accuracy: 0.7531
# Epoch 3/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.5738 - accuracy: 0.7393 - val_loss: 0.5592 - val_accuracy: 0.7531
# Epoch 4/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5594 - val_accuracy: 0.7531
# Epoch 5/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5593 - val_accuracy: 0.7531
# Epoch 6/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.5734 - accuracy: 0.7393 - val_loss: 0.5587 - val_accuracy: 0.7531
# Epoch 7/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.5708 - accuracy: 0.7393 - val_loss: 0.5512 - val_accuracy: 0.7531
# Epoch 8/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.5499 - accuracy: 0.7393 - val_loss: 0.5207 - val_accuracy: 0.7531
# Epoch 9/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.5248 - accuracy: 0.7393 - val_loss: 0.5052 - val_accuracy: 0.7531
# Epoch 10/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.5105 - accuracy: 0.7388 - val_loss: 0.4945 - val_accuracy: 0.7532
# Epoch 11/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.5059 - accuracy: 0.7389 - val_loss: 0.4891 - val_accuracy: 0.7534
# Epoch 12/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.5019 - accuracy: 0.7390 - val_loss: 0.4861 - val_accuracy: 0.7531
# Epoch 13/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4987 - accuracy: 0.7398 - val_loss: 0.4843 - val_accuracy: 0.7535
# Epoch 14/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4962 - accuracy: 0.7413 - val_loss: 0.4800 - val_accuracy: 0.7546
# Epoch 15/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4936 - accuracy: 0.7449 - val_loss: 0.4784 - val_accuracy: 0.7541
# Epoch 16/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4920 - accuracy: 0.7471 - val_loss: 0.4776 - val_accuracy: 0.7530
# Epoch 17/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4873 - accuracy: 0.7485 - val_loss: 0.4785 - val_accuracy: 0.7510
# Epoch 18/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4820 - accuracy: 0.7499 - val_loss: 0.4743 - val_accuracy: 0.7572
# Epoch 19/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4771 - accuracy: 0.7533 - val_loss: 0.4664 - val_accuracy: 0.7596
# Epoch 20/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4718 - accuracy: 0.7564 - val_loss: 0.4635 - val_accuracy: 0.7630
# Epoch 21/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4688 - accuracy: 0.7573 - val_loss: 0.4577 - val_accuracy: 0.7614
# Epoch 22/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4648 - accuracy: 0.7587 - val_loss: 0.4545 - val_accuracy: 0.7648
# Epoch 23/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4673 - accuracy: 0.7582 - val_loss: 0.4563 - val_accuracy: 0.7650
# Epoch 24/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4638 - accuracy: 0.7593 - val_loss: 0.4547 - val_accuracy: 0.7634
# Epoch 25/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4598 - accuracy: 0.7607 - val_loss: 0.4509 - val_accuracy: 0.7661
# Epoch 26/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4591 - accuracy: 0.7616 - val_loss: 0.4508 - val_accuracy: 0.7657
# Epoch 27/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4620 - accuracy: 0.7612 - val_loss: 0.4504 - val_accuracy: 0.7672
# Epoch 28/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4573 - accuracy: 0.7626 - val_loss: 0.4494 - val_accuracy: 0.7661
# Epoch 29/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4562 - accuracy: 0.7635 - val_loss: 0.4519 - val_accuracy: 0.7677
# Epoch 30/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4558 - accuracy: 0.7639 - val_loss: 0.4509 - val_accuracy: 0.7685
# Epoch 31/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4537 - accuracy: 0.7646 - val_loss: 0.4451 - val_accuracy: 0.7705
# Epoch 32/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4524 - accuracy: 0.7653 - val_loss: 0.4480 - val_accuracy: 0.7681
# Epoch 33/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4526 - accuracy: 0.7657 - val_loss: 0.4458 - val_accuracy: 0.7703
# Epoch 34/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4523 - accuracy: 0.7661 - val_loss: 0.4484 - val_accuracy: 0.7685
# Epoch 35/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4509 - accuracy: 0.7671 - val_loss: 0.4449 - val_accuracy: 0.7694
# Epoch 36/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4518 - accuracy: 0.7669 - val_loss: 0.4469 - val_accuracy: 0.7722
# Epoch 37/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4505 - accuracy: 0.7679 - val_loss: 0.4457 - val_accuracy: 0.7729
# Epoch 38/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4503 - accuracy: 0.7682 - val_loss: 0.4437 - val_accuracy: 0.7720
# Epoch 39/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4513 - accuracy: 0.7683 - val_loss: 0.4436 - val_accuracy: 0.7728
# Epoch 40/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4484 - accuracy: 0.7689 - val_loss: 0.4409 - val_accuracy: 0.7746
# Epoch 41/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4468 - accuracy: 0.7696 - val_loss: 0.4410 - val_accuracy: 0.7736
# Epoch 42/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4474 - accuracy: 0.7698 - val_loss: 0.4398 - val_accuracy: 0.7756
# Epoch 43/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4466 - accuracy: 0.7699 - val_loss: 0.4433 - val_accuracy: 0.7746
# Epoch 44/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4456 - accuracy: 0.7701 - val_loss: 0.4441 - val_accuracy: 0.7728
# Epoch 45/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4478 - accuracy: 0.7703 - val_loss: 0.4404 - val_accuracy: 0.7745
# Epoch 46/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4447 - accuracy: 0.7711 - val_loss: 0.4389 - val_accuracy: 0.7752
# Epoch 47/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4458 - accuracy: 0.7714 - val_loss: 0.4424 - val_accuracy: 0.7744
# Epoch 48/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4446 - accuracy: 0.7710 - val_loss: 0.4379 - val_accuracy: 0.7750
# Epoch 49/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4446 - accuracy: 0.7716 - val_loss: 0.4385 - val_accuracy: 0.7746
# Epoch 50/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4440 - accuracy: 0.7720 - val_loss: 0.4384 - val_accuracy: 0.7758
# Epoch 51/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4425 - accuracy: 0.7726 - val_loss: 0.4369 - val_accuracy: 0.7761
# Epoch 52/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4438 - accuracy: 0.7724 - val_loss: 0.4388 - val_accuracy: 0.7768
# Epoch 53/140
# 24/24 [==============================] - 2s 76ms/step - loss: 0.4419 - accuracy: 0.7730 - val_loss: 0.4366 - val_accuracy: 0.7767
# Epoch 54/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4415 - accuracy: 0.7737 - val_loss: 0.4394 - val_accuracy: 0.7758
# Epoch 55/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4412 - accuracy: 0.7735 - val_loss: 0.4374 - val_accuracy: 0.7774
# Epoch 56/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4403 - accuracy: 0.7742 - val_loss: 0.4364 - val_accuracy: 0.7768
# Epoch 57/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4408 - accuracy: 0.7745 - val_loss: 0.4380 - val_accuracy: 0.7755
# Epoch 58/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4401 - accuracy: 0.7742 - val_loss: 0.4416 - val_accuracy: 0.7768
# Epoch 59/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4402 - accuracy: 0.7744 - val_loss: 0.4347 - val_accuracy: 0.7771
# Epoch 60/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4401 - accuracy: 0.7744 - val_loss: 0.4333 - val_accuracy: 0.7772
# Epoch 61/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4400 - accuracy: 0.7749 - val_loss: 0.4364 - val_accuracy: 0.7769
# Epoch 62/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4403 - accuracy: 0.7748 - val_loss: 0.4416 - val_accuracy: 0.7783
# Epoch 63/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4400 - accuracy: 0.7749 - val_loss: 0.4323 - val_accuracy: 0.7778
# Epoch 64/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4383 - accuracy: 0.7757 - val_loss: 0.4343 - val_accuracy: 0.7778
# Epoch 65/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4379 - accuracy: 0.7759 - val_loss: 0.4343 - val_accuracy: 0.7757
# Epoch 66/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4378 - accuracy: 0.7757 - val_loss: 0.4389 - val_accuracy: 0.7784
# Epoch 67/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4402 - accuracy: 0.7758 - val_loss: 0.4350 - val_accuracy: 0.7769
# Epoch 68/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4373 - accuracy: 0.7759 - val_loss: 0.4320 - val_accuracy: 0.7780
# Epoch 69/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4372 - accuracy: 0.7763 - val_loss: 0.4339 - val_accuracy: 0.7772
# Epoch 70/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4368 - accuracy: 0.7764 - val_loss: 0.4307 - val_accuracy: 0.7801
# Epoch 71/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4360 - accuracy: 0.7764 - val_loss: 0.4326 - val_accuracy: 0.7786
# Epoch 72/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4375 - accuracy: 0.7764 - val_loss: 0.4325 - val_accuracy: 0.7778
# Epoch 73/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4366 - accuracy: 0.7766 - val_loss: 0.4328 - val_accuracy: 0.7788
# Epoch 74/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4357 - accuracy: 0.7767 - val_loss: 0.4323 - val_accuracy: 0.7794
# Epoch 75/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4360 - accuracy: 0.7768 - val_loss: 0.4378 - val_accuracy: 0.7784
# Epoch 76/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4354 - accuracy: 0.7772 - val_loss: 0.4302 - val_accuracy: 0.7792
# Epoch 77/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4348 - accuracy: 0.7774 - val_loss: 0.4309 - val_accuracy: 0.7788
# Epoch 78/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4349 - accuracy: 0.7776 - val_loss: 0.4298 - val_accuracy: 0.7797
# Epoch 79/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4337 - accuracy: 0.7777 - val_loss: 0.4312 - val_accuracy: 0.7788
# Epoch 80/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4337 - accuracy: 0.7777 - val_loss: 0.4316 - val_accuracy: 0.7808
# Epoch 81/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4339 - accuracy: 0.7778 - val_loss: 0.4302 - val_accuracy: 0.7792
# Epoch 82/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4331 - accuracy: 0.7785 - val_loss: 0.4288 - val_accuracy: 0.7800
# Epoch 83/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4341 - accuracy: 0.7784 - val_loss: 0.4306 - val_accuracy: 0.7801
# Epoch 84/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4351 - accuracy: 0.7782 - val_loss: 0.4331 - val_accuracy: 0.7813
# Epoch 85/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4337 - accuracy: 0.7784 - val_loss: 0.4373 - val_accuracy: 0.7753
# Epoch 86/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4351 - accuracy: 0.7788 - val_loss: 0.4320 - val_accuracy: 0.7790
# Epoch 87/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4330 - accuracy: 0.7791 - val_loss: 0.4314 - val_accuracy: 0.7784
# Epoch 88/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4322 - accuracy: 0.7793 - val_loss: 0.4308 - val_accuracy: 0.7806
# Epoch 89/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4317 - accuracy: 0.7798 - val_loss: 0.4296 - val_accuracy: 0.7815
# Epoch 90/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4311 - accuracy: 0.7798 - val_loss: 0.4285 - val_accuracy: 0.7816
# Epoch 91/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4302 - accuracy: 0.7804 - val_loss: 0.4285 - val_accuracy: 0.7809
# Epoch 92/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4312 - accuracy: 0.7802 - val_loss: 0.4286 - val_accuracy: 0.7808
# Epoch 93/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4300 - accuracy: 0.7806 - val_loss: 0.4278 - val_accuracy: 0.7822
# Epoch 94/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4301 - accuracy: 0.7805 - val_loss: 0.4290 - val_accuracy: 0.7815
# Epoch 95/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4292 - accuracy: 0.7809 - val_loss: 0.4262 - val_accuracy: 0.7812
# Epoch 96/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4289 - accuracy: 0.7811 - val_loss: 0.4283 - val_accuracy: 0.7812
# Epoch 97/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4295 - accuracy: 0.7807 - val_loss: 0.4314 - val_accuracy: 0.7807
# Epoch 98/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4290 - accuracy: 0.7806 - val_loss: 0.4272 - val_accuracy: 0.7813
# Epoch 99/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4286 - accuracy: 0.7814 - val_loss: 0.4321 - val_accuracy: 0.7809
# Epoch 100/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4281 - accuracy: 0.7813 - val_loss: 0.4274 - val_accuracy: 0.7811
# Epoch 101/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4279 - accuracy: 0.7813 - val_loss: 0.4275 - val_accuracy: 0.7817
# Epoch 102/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4281 - accuracy: 0.7812 - val_loss: 0.4277 - val_accuracy: 0.7821
# Epoch 103/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4274 - accuracy: 0.7817 - val_loss: 0.4359 - val_accuracy: 0.7816
# Epoch 104/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4279 - accuracy: 0.7819 - val_loss: 0.4258 - val_accuracy: 0.7826
# Epoch 105/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4275 - accuracy: 0.7818 - val_loss: 0.4277 - val_accuracy: 0.7806
# Epoch 106/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4266 - accuracy: 0.7822 - val_loss: 0.4254 - val_accuracy: 0.7823
# Epoch 107/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4272 - accuracy: 0.7820 - val_loss: 0.4275 - val_accuracy: 0.7815
# Epoch 108/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4274 - accuracy: 0.7821 - val_loss: 0.4319 - val_accuracy: 0.7784
# Epoch 109/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4271 - accuracy: 0.7819 - val_loss: 0.4333 - val_accuracy: 0.7798
# Epoch 110/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4277 - accuracy: 0.7818 - val_loss: 0.4324 - val_accuracy: 0.7815
# Epoch 111/140
# 24/24 [==============================] - 2s 76ms/step - loss: 0.4267 - accuracy: 0.7822 - val_loss: 0.4284 - val_accuracy: 0.7807
# Epoch 112/140
# 24/24 [==============================] - 2s 76ms/step - loss: 0.4280 - accuracy: 0.7819 - val_loss: 0.4271 - val_accuracy: 0.7815
# Epoch 113/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4257 - accuracy: 0.7822 - val_loss: 0.4276 - val_accuracy: 0.7819
# Epoch 114/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4256 - accuracy: 0.7824 - val_loss: 0.4319 - val_accuracy: 0.7772
# Epoch 115/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4257 - accuracy: 0.7823 - val_loss: 0.4283 - val_accuracy: 0.7825
# Epoch 116/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4256 - accuracy: 0.7822 - val_loss: 0.4257 - val_accuracy: 0.7827
# Epoch 117/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4253 - accuracy: 0.7826 - val_loss: 0.4275 - val_accuracy: 0.7816
# Epoch 118/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4260 - accuracy: 0.7824 - val_loss: 0.4256 - val_accuracy: 0.7831
# Epoch 119/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4251 - accuracy: 0.7825 - val_loss: 0.4315 - val_accuracy: 0.7835
# Epoch 120/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4256 - accuracy: 0.7825 - val_loss: 0.4256 - val_accuracy: 0.7838
# Epoch 121/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4250 - accuracy: 0.7827 - val_loss: 0.4274 - val_accuracy: 0.7840
# Epoch 122/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4251 - accuracy: 0.7826 - val_loss: 0.4312 - val_accuracy: 0.7826
# Epoch 123/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4263 - accuracy: 0.7825 - val_loss: 0.4264 - val_accuracy: 0.7815
# Epoch 124/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4245 - accuracy: 0.7826 - val_loss: 0.4326 - val_accuracy: 0.7796
# Epoch 125/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4249 - accuracy: 0.7830 - val_loss: 0.4267 - val_accuracy: 0.7834
# Epoch 126/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4248 - accuracy: 0.7827 - val_loss: 0.4270 - val_accuracy: 0.7808
# Epoch 127/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4250 - accuracy: 0.7827 - val_loss: 0.4250 - val_accuracy: 0.7834
# Epoch 128/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4235 - accuracy: 0.7833 - val_loss: 0.4266 - val_accuracy: 0.7824
# Epoch 129/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4234 - accuracy: 0.7833 - val_loss: 0.4282 - val_accuracy: 0.7829
# Epoch 130/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4236 - accuracy: 0.7835 - val_loss: 0.4269 - val_accuracy: 0.7820
# Epoch 131/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4235 - accuracy: 0.7832 - val_loss: 0.4288 - val_accuracy: 0.7833
# Epoch 132/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4250 - accuracy: 0.7830 - val_loss: 0.4273 - val_accuracy: 0.7852
# Epoch 133/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4235 - accuracy: 0.7831 - val_loss: 0.4299 - val_accuracy: 0.7840
# Epoch 134/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4233 - accuracy: 0.7829 - val_loss: 0.4278 - val_accuracy: 0.7832
# Epoch 135/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4227 - accuracy: 0.7837 - val_loss: 0.4302 - val_accuracy: 0.7792
# Epoch 136/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4225 - accuracy: 0.7838 - val_loss: 0.4250 - val_accuracy: 0.7841
# Epoch 137/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4219 - accuracy: 0.7840 - val_loss: 0.4255 - val_accuracy: 0.7825
# Epoch 138/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4221 - accuracy: 0.7839 - val_loss: 0.4282 - val_accuracy: 0.7841
# Epoch 139/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4232 - accuracy: 0.7836 - val_loss: 0.4295 - val_accuracy: 0.7831
# Epoch 140/140
# 24/24 [==============================] - 2s 76ms/step - loss: 0.4241 - accuracy: 0.7834 - val_loss: 0.4275 - val_accuracy: 0.7799

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 10s 3ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 276.00858879089355

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00722182],
#        [0.00492047],
#        [0.00204421],
#        ...,
#        [0.06820071],
#        [0.07325246],
#        [0.07548071]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14329727802147382
# 0.22943576252795328
# 0.3785462693271112
# 0.28759679940080246

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 54s 4ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60004081]
# [0.83092238]
# total acc [0.78331275]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 548989184, 'peak': 2744457472}
