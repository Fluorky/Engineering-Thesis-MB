# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x25343a3d040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2537daa6040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 13s 112ms/step - loss: 0.5831 - accuracy: 0.7393 - val_loss: 0.5589 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.5682 - accuracy: 0.7393 - val_loss: 0.5421 - val_accuracy: 0.7531
# Epoch 3/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.5361 - accuracy: 0.7369 - val_loss: 0.5073 - val_accuracy: 0.7531
# Epoch 4/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.5095 - accuracy: 0.7386 - val_loss: 0.4919 - val_accuracy: 0.7534
# Epoch 5/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.5002 - accuracy: 0.7412 - val_loss: 0.4823 - val_accuracy: 0.7538
# Epoch 6/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4939 - accuracy: 0.7454 - val_loss: 0.4784 - val_accuracy: 0.7531
# Epoch 7/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4881 - accuracy: 0.7481 - val_loss: 0.4796 - val_accuracy: 0.7482
# Epoch 8/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4815 - accuracy: 0.7489 - val_loss: 0.4703 - val_accuracy: 0.7556
# Epoch 9/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4763 - accuracy: 0.7524 - val_loss: 0.4701 - val_accuracy: 0.7550
# Epoch 10/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4710 - accuracy: 0.7547 - val_loss: 0.4621 - val_accuracy: 0.7574
# Epoch 11/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4681 - accuracy: 0.7565 - val_loss: 0.4566 - val_accuracy: 0.7608
# Epoch 12/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4648 - accuracy: 0.7566 - val_loss: 0.4542 - val_accuracy: 0.7617
# Epoch 13/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4619 - accuracy: 0.7576 - val_loss: 0.4544 - val_accuracy: 0.7619
# Epoch 14/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4624 - accuracy: 0.7584 - val_loss: 0.4597 - val_accuracy: 0.7639
# Epoch 15/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4598 - accuracy: 0.7590 - val_loss: 0.4527 - val_accuracy: 0.7635
# Epoch 16/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4568 - accuracy: 0.7603 - val_loss: 0.4534 - val_accuracy: 0.7664
# Epoch 17/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4587 - accuracy: 0.7613 - val_loss: 0.4503 - val_accuracy: 0.7674
# Epoch 18/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4553 - accuracy: 0.7623 - val_loss: 0.4482 - val_accuracy: 0.7659
# Epoch 19/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4529 - accuracy: 0.7642 - val_loss: 0.4461 - val_accuracy: 0.7683
# Epoch 20/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4531 - accuracy: 0.7651 - val_loss: 0.4443 - val_accuracy: 0.7698
# Epoch 21/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4518 - accuracy: 0.7665 - val_loss: 0.4460 - val_accuracy: 0.7728
# Epoch 22/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4499 - accuracy: 0.7671 - val_loss: 0.4409 - val_accuracy: 0.7736
# Epoch 23/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4488 - accuracy: 0.7680 - val_loss: 0.4418 - val_accuracy: 0.7731
# Epoch 24/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4485 - accuracy: 0.7684 - val_loss: 0.4402 - val_accuracy: 0.7747
# Epoch 25/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4468 - accuracy: 0.7687 - val_loss: 0.4405 - val_accuracy: 0.7744
# Epoch 26/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4472 - accuracy: 0.7697 - val_loss: 0.4381 - val_accuracy: 0.7751
# Epoch 27/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4457 - accuracy: 0.7694 - val_loss: 0.4394 - val_accuracy: 0.7753
# Epoch 28/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4462 - accuracy: 0.7701 - val_loss: 0.4381 - val_accuracy: 0.7754
# Epoch 29/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4441 - accuracy: 0.7702 - val_loss: 0.4375 - val_accuracy: 0.7760
# Epoch 30/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4458 - accuracy: 0.7700 - val_loss: 0.4373 - val_accuracy: 0.7756
# Epoch 31/140
# 24/24 [==============================] - 2s 76ms/step - loss: 0.4443 - accuracy: 0.7705 - val_loss: 0.4383 - val_accuracy: 0.7772
# Epoch 32/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4441 - accuracy: 0.7709 - val_loss: 0.4401 - val_accuracy: 0.7754
# Epoch 33/140
# 24/24 [==============================] - 2s 76ms/step - loss: 0.4436 - accuracy: 0.7715 - val_loss: 0.4366 - val_accuracy: 0.7771
# Epoch 34/140
# 24/24 [==============================] - 2s 76ms/step - loss: 0.4420 - accuracy: 0.7715 - val_loss: 0.4355 - val_accuracy: 0.7772
# Epoch 35/140
# 24/24 [==============================] - 2s 76ms/step - loss: 0.4426 - accuracy: 0.7718 - val_loss: 0.4381 - val_accuracy: 0.7768
# Epoch 36/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4445 - accuracy: 0.7716 - val_loss: 0.4372 - val_accuracy: 0.7747
# Epoch 37/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4423 - accuracy: 0.7716 - val_loss: 0.4378 - val_accuracy: 0.7773
# Epoch 38/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4414 - accuracy: 0.7721 - val_loss: 0.4352 - val_accuracy: 0.7764
# Epoch 39/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4414 - accuracy: 0.7724 - val_loss: 0.4351 - val_accuracy: 0.7774
# Epoch 40/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4409 - accuracy: 0.7729 - val_loss: 0.4361 - val_accuracy: 0.7772
# Epoch 41/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4412 - accuracy: 0.7730 - val_loss: 0.4354 - val_accuracy: 0.7766
# Epoch 42/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4404 - accuracy: 0.7733 - val_loss: 0.4450 - val_accuracy: 0.7733
# Epoch 43/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4421 - accuracy: 0.7732 - val_loss: 0.4423 - val_accuracy: 0.7767
# Epoch 44/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4438 - accuracy: 0.7729 - val_loss: 0.4417 - val_accuracy: 0.7749
# Epoch 45/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4421 - accuracy: 0.7733 - val_loss: 0.4351 - val_accuracy: 0.7771
# Epoch 46/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4392 - accuracy: 0.7741 - val_loss: 0.4339 - val_accuracy: 0.7776
# Epoch 47/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4384 - accuracy: 0.7746 - val_loss: 0.4362 - val_accuracy: 0.7778
# Epoch 48/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4424 - accuracy: 0.7742 - val_loss: 0.4338 - val_accuracy: 0.7778
# Epoch 49/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4400 - accuracy: 0.7748 - val_loss: 0.4341 - val_accuracy: 0.7776
# Epoch 50/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4381 - accuracy: 0.7750 - val_loss: 0.4333 - val_accuracy: 0.7776
# Epoch 51/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4373 - accuracy: 0.7757 - val_loss: 0.4340 - val_accuracy: 0.7780
# Epoch 52/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4373 - accuracy: 0.7760 - val_loss: 0.4347 - val_accuracy: 0.7776
# Epoch 53/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4384 - accuracy: 0.7756 - val_loss: 0.4484 - val_accuracy: 0.7778
# Epoch 54/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4398 - accuracy: 0.7754 - val_loss: 0.4334 - val_accuracy: 0.7778
# Epoch 55/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4376 - accuracy: 0.7762 - val_loss: 0.4323 - val_accuracy: 0.7779
# Epoch 56/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4378 - accuracy: 0.7763 - val_loss: 0.4434 - val_accuracy: 0.7783
# Epoch 57/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4369 - accuracy: 0.7766 - val_loss: 0.4322 - val_accuracy: 0.7784
# Epoch 58/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4355 - accuracy: 0.7770 - val_loss: 0.4340 - val_accuracy: 0.7791
# Epoch 59/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4357 - accuracy: 0.7771 - val_loss: 0.4322 - val_accuracy: 0.7794
# Epoch 60/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4352 - accuracy: 0.7774 - val_loss: 0.4342 - val_accuracy: 0.7775
# Epoch 61/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4348 - accuracy: 0.7775 - val_loss: 0.4316 - val_accuracy: 0.7802
# Epoch 62/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4340 - accuracy: 0.7781 - val_loss: 0.4336 - val_accuracy: 0.7774
# Epoch 63/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4338 - accuracy: 0.7781 - val_loss: 0.4401 - val_accuracy: 0.7797
# Epoch 64/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4363 - accuracy: 0.7776 - val_loss: 0.4400 - val_accuracy: 0.7790
# Epoch 65/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4351 - accuracy: 0.7778 - val_loss: 0.4339 - val_accuracy: 0.7783
# Epoch 66/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4345 - accuracy: 0.7784 - val_loss: 0.4319 - val_accuracy: 0.7796
# Epoch 67/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4329 - accuracy: 0.7786 - val_loss: 0.4313 - val_accuracy: 0.7796
# Epoch 68/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4324 - accuracy: 0.7789 - val_loss: 0.4296 - val_accuracy: 0.7798
# Epoch 69/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4321 - accuracy: 0.7789 - val_loss: 0.4304 - val_accuracy: 0.7816
# Epoch 70/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4327 - accuracy: 0.7789 - val_loss: 0.4289 - val_accuracy: 0.7799
# Epoch 71/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4326 - accuracy: 0.7790 - val_loss: 0.4287 - val_accuracy: 0.7810
# Epoch 72/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4316 - accuracy: 0.7793 - val_loss: 0.4297 - val_accuracy: 0.7815
# Epoch 73/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4315 - accuracy: 0.7793 - val_loss: 0.4272 - val_accuracy: 0.7821
# Epoch 74/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4319 - accuracy: 0.7794 - val_loss: 0.4290 - val_accuracy: 0.7814
# Epoch 75/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4319 - accuracy: 0.7797 - val_loss: 0.4316 - val_accuracy: 0.7806
# Epoch 76/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4321 - accuracy: 0.7795 - val_loss: 0.4274 - val_accuracy: 0.7814
# Epoch 77/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4304 - accuracy: 0.7800 - val_loss: 0.4311 - val_accuracy: 0.7814
# Epoch 78/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4306 - accuracy: 0.7798 - val_loss: 0.4310 - val_accuracy: 0.7808
# Epoch 79/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4313 - accuracy: 0.7795 - val_loss: 0.4287 - val_accuracy: 0.7821
# Epoch 80/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4301 - accuracy: 0.7803 - val_loss: 0.4322 - val_accuracy: 0.7809
# Epoch 81/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4309 - accuracy: 0.7803 - val_loss: 0.4261 - val_accuracy: 0.7822
# Epoch 82/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4293 - accuracy: 0.7805 - val_loss: 0.4278 - val_accuracy: 0.7822
# Epoch 83/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4290 - accuracy: 0.7805 - val_loss: 0.4275 - val_accuracy: 0.7813
# Epoch 84/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4285 - accuracy: 0.7808 - val_loss: 0.4307 - val_accuracy: 0.7824
# Epoch 85/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4292 - accuracy: 0.7809 - val_loss: 0.4296 - val_accuracy: 0.7827
# Epoch 86/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4282 - accuracy: 0.7811 - val_loss: 0.4308 - val_accuracy: 0.7809
# Epoch 87/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4287 - accuracy: 0.7808 - val_loss: 0.4291 - val_accuracy: 0.7830
# Epoch 88/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4293 - accuracy: 0.7811 - val_loss: 0.4323 - val_accuracy: 0.7796
# Epoch 89/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4299 - accuracy: 0.7808 - val_loss: 0.4268 - val_accuracy: 0.7829
# Epoch 90/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4292 - accuracy: 0.7804 - val_loss: 0.4244 - val_accuracy: 0.7841
# Epoch 91/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4278 - accuracy: 0.7816 - val_loss: 0.4334 - val_accuracy: 0.7829
# Epoch 92/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4280 - accuracy: 0.7814 - val_loss: 0.4331 - val_accuracy: 0.7821
# Epoch 93/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4274 - accuracy: 0.7813 - val_loss: 0.4306 - val_accuracy: 0.7834
# Epoch 94/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4277 - accuracy: 0.7815 - val_loss: 0.4254 - val_accuracy: 0.7843
# Epoch 95/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4263 - accuracy: 0.7817 - val_loss: 0.4262 - val_accuracy: 0.7839
# Epoch 96/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4267 - accuracy: 0.7815 - val_loss: 0.4272 - val_accuracy: 0.7833
# Epoch 97/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4267 - accuracy: 0.7821 - val_loss: 0.4266 - val_accuracy: 0.7829
# Epoch 98/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4270 - accuracy: 0.7819 - val_loss: 0.4247 - val_accuracy: 0.7849
# Epoch 99/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4257 - accuracy: 0.7820 - val_loss: 0.4266 - val_accuracy: 0.7834
# Epoch 100/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4264 - accuracy: 0.7816 - val_loss: 0.4284 - val_accuracy: 0.7844
# Epoch 101/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4259 - accuracy: 0.7819 - val_loss: 0.4250 - val_accuracy: 0.7840
# Epoch 102/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4250 - accuracy: 0.7825 - val_loss: 0.4272 - val_accuracy: 0.7815
# Epoch 103/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4253 - accuracy: 0.7822 - val_loss: 0.4294 - val_accuracy: 0.7837
# Epoch 104/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4243 - accuracy: 0.7826 - val_loss: 0.4233 - val_accuracy: 0.7842
# Epoch 105/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4243 - accuracy: 0.7827 - val_loss: 0.4287 - val_accuracy: 0.7841
# Epoch 106/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4237 - accuracy: 0.7826 - val_loss: 0.4267 - val_accuracy: 0.7840
# Epoch 107/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4241 - accuracy: 0.7831 - val_loss: 0.4276 - val_accuracy: 0.7835
# Epoch 108/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4234 - accuracy: 0.7831 - val_loss: 0.4232 - val_accuracy: 0.7846
# Epoch 109/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4249 - accuracy: 0.7829 - val_loss: 0.4248 - val_accuracy: 0.7848
# Epoch 110/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4235 - accuracy: 0.7834 - val_loss: 0.4232 - val_accuracy: 0.7854
# Epoch 111/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4231 - accuracy: 0.7834 - val_loss: 0.4257 - val_accuracy: 0.7841
# Epoch 112/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4241 - accuracy: 0.7834 - val_loss: 0.4270 - val_accuracy: 0.7834
# Epoch 113/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4232 - accuracy: 0.7831 - val_loss: 0.4288 - val_accuracy: 0.7837
# Epoch 114/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4224 - accuracy: 0.7836 - val_loss: 0.4251 - val_accuracy: 0.7821
# Epoch 115/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4226 - accuracy: 0.7833 - val_loss: 0.4274 - val_accuracy: 0.7840
# Epoch 116/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4230 - accuracy: 0.7838 - val_loss: 0.4366 - val_accuracy: 0.7845
# Epoch 117/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4228 - accuracy: 0.7838 - val_loss: 0.4229 - val_accuracy: 0.7857
# Epoch 118/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4220 - accuracy: 0.7842 - val_loss: 0.4267 - val_accuracy: 0.7847
# Epoch 119/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4217 - accuracy: 0.7842 - val_loss: 0.4251 - val_accuracy: 0.7850
# Epoch 120/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4210 - accuracy: 0.7843 - val_loss: 0.4239 - val_accuracy: 0.7845
# Epoch 121/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4211 - accuracy: 0.7844 - val_loss: 0.4257 - val_accuracy: 0.7842
# Epoch 122/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4211 - accuracy: 0.7844 - val_loss: 0.4301 - val_accuracy: 0.7782
# Epoch 123/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4213 - accuracy: 0.7844 - val_loss: 0.4242 - val_accuracy: 0.7851
# Epoch 124/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4214 - accuracy: 0.7847 - val_loss: 0.4241 - val_accuracy: 0.7848
# Epoch 125/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4205 - accuracy: 0.7842 - val_loss: 0.4248 - val_accuracy: 0.7827
# Epoch 126/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4206 - accuracy: 0.7847 - val_loss: 0.4240 - val_accuracy: 0.7849
# Epoch 127/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4203 - accuracy: 0.7850 - val_loss: 0.4251 - val_accuracy: 0.7848
# Epoch 128/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4205 - accuracy: 0.7844 - val_loss: 0.4287 - val_accuracy: 0.7826
# Epoch 129/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4216 - accuracy: 0.7847 - val_loss: 0.4252 - val_accuracy: 0.7843
# Epoch 130/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4206 - accuracy: 0.7849 - val_loss: 0.4255 - val_accuracy: 0.7849
# Epoch 131/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4201 - accuracy: 0.7849 - val_loss: 0.4239 - val_accuracy: 0.7836
# Epoch 132/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4228 - accuracy: 0.7845 - val_loss: 0.4281 - val_accuracy: 0.7813
# Epoch 133/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4210 - accuracy: 0.7849 - val_loss: 0.4254 - val_accuracy: 0.7843
# Epoch 134/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4199 - accuracy: 0.7850 - val_loss: 0.4343 - val_accuracy: 0.7836
# Epoch 135/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4201 - accuracy: 0.7854 - val_loss: 0.4261 - val_accuracy: 0.7831
# Epoch 136/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4195 - accuracy: 0.7853 - val_loss: 0.4271 - val_accuracy: 0.7804
# Epoch 137/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4193 - accuracy: 0.7854 - val_loss: 0.4244 - val_accuracy: 0.7847
# Epoch 138/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4190 - accuracy: 0.7856 - val_loss: 0.4237 - val_accuracy: 0.7852
# Epoch 139/140
# 24/24 [==============================] - 2s 78ms/step - loss: 0.4185 - accuracy: 0.7857 - val_loss: 0.4286 - val_accuracy: 0.7788
# Epoch 140/140
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4200 - accuracy: 0.7855 - val_loss: 0.4260 - val_accuracy: 0.7838

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 11s 3ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 283.04779410362244

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00093048],
#        [0.00087463],
#        [0.00055901],
#        ...,
#        [0.05858653],
#        [0.06028119],
#        [0.06011391]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14258558614881545
# 0.23326280176234726
# 0.37760506637069297
# 0.2840311918893676

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 51s 3ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.608251]
# [0.82971795]
# total acc [0.78538924]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 548989184, 'peak': 2741374208}
