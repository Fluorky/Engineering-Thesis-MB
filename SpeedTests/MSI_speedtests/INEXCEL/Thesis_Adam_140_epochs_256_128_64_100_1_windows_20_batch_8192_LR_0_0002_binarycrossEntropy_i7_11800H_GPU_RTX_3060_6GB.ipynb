# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=20

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475317, 20, 16)
# strides:  (2560, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x165998bb040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475317,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x165e2134040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380253

# %%
training_sample
# Out:
# 380253

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380253, 20, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380253,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380253, 20, 15) (380253, 1) (95064, 20, 15) (95064, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0002)
model_gru.compile(loss='BinaryCrossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 20, 256)           209664
#
#  gru_1 (GRU)                 (None, 20, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=8192)#, shuffle=False)
# Out:
# Epoch 1/140
# 47/47 [==============================] - 9s 119ms/step - loss: 0.5842 - accuracy: 0.7393 - val_loss: 0.5527 - val_accuracy: 0.7531
# Epoch 2/140
# 47/47 [==============================] - 5s 105ms/step - loss: 0.5462 - accuracy: 0.7380 - val_loss: 0.5103 - val_accuracy: 0.7458
# Epoch 3/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.5107 - accuracy: 0.7367 - val_loss: 0.4892 - val_accuracy: 0.7523
# Epoch 4/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.5018 - accuracy: 0.7390 - val_loss: 0.4842 - val_accuracy: 0.7528
# Epoch 5/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4962 - accuracy: 0.7420 - val_loss: 0.4796 - val_accuracy: 0.7533
# Epoch 6/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4907 - accuracy: 0.7459 - val_loss: 0.4772 - val_accuracy: 0.7534
# Epoch 7/140
# 47/47 [==============================] - 5s 105ms/step - loss: 0.4834 - accuracy: 0.7483 - val_loss: 0.4716 - val_accuracy: 0.7537
# Epoch 8/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4766 - accuracy: 0.7527 - val_loss: 0.4752 - val_accuracy: 0.7533
# Epoch 9/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4735 - accuracy: 0.7547 - val_loss: 0.4658 - val_accuracy: 0.7596
# Epoch 10/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4702 - accuracy: 0.7564 - val_loss: 0.4616 - val_accuracy: 0.7600
# Epoch 11/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4669 - accuracy: 0.7574 - val_loss: 0.4583 - val_accuracy: 0.7618
# Epoch 12/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4647 - accuracy: 0.7580 - val_loss: 0.4550 - val_accuracy: 0.7639
# Epoch 13/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4621 - accuracy: 0.7583 - val_loss: 0.4605 - val_accuracy: 0.7628
# Epoch 14/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4615 - accuracy: 0.7591 - val_loss: 0.4523 - val_accuracy: 0.7631
# Epoch 15/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4598 - accuracy: 0.7601 - val_loss: 0.4494 - val_accuracy: 0.7670
# Epoch 16/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4580 - accuracy: 0.7614 - val_loss: 0.4483 - val_accuracy: 0.7663
# Epoch 17/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4561 - accuracy: 0.7625 - val_loss: 0.4530 - val_accuracy: 0.7674
# Epoch 18/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4554 - accuracy: 0.7634 - val_loss: 0.4481 - val_accuracy: 0.7690
# Epoch 19/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4537 - accuracy: 0.7645 - val_loss: 0.4470 - val_accuracy: 0.7685
# Epoch 20/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4538 - accuracy: 0.7647 - val_loss: 0.4475 - val_accuracy: 0.7697
# Epoch 21/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4534 - accuracy: 0.7653 - val_loss: 0.4454 - val_accuracy: 0.7707
# Epoch 22/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4516 - accuracy: 0.7660 - val_loss: 0.4447 - val_accuracy: 0.7708
# Epoch 23/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4521 - accuracy: 0.7663 - val_loss: 0.4451 - val_accuracy: 0.7716
# Epoch 24/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4510 - accuracy: 0.7669 - val_loss: 0.4428 - val_accuracy: 0.7714
# Epoch 25/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4490 - accuracy: 0.7674 - val_loss: 0.4416 - val_accuracy: 0.7730
# Epoch 26/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4486 - accuracy: 0.7677 - val_loss: 0.4431 - val_accuracy: 0.7726
# Epoch 27/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4477 - accuracy: 0.7688 - val_loss: 0.4402 - val_accuracy: 0.7734
# Epoch 28/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4469 - accuracy: 0.7689 - val_loss: 0.4415 - val_accuracy: 0.7742
# Epoch 29/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4463 - accuracy: 0.7693 - val_loss: 0.4396 - val_accuracy: 0.7749
# Epoch 30/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4457 - accuracy: 0.7697 - val_loss: 0.4427 - val_accuracy: 0.7746
# Epoch 31/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4455 - accuracy: 0.7701 - val_loss: 0.4437 - val_accuracy: 0.7742
# Epoch 32/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4451 - accuracy: 0.7704 - val_loss: 0.4406 - val_accuracy: 0.7747
# Epoch 33/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4448 - accuracy: 0.7706 - val_loss: 0.4414 - val_accuracy: 0.7743
# Epoch 34/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4444 - accuracy: 0.7711 - val_loss: 0.4406 - val_accuracy: 0.7749
# Epoch 35/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4453 - accuracy: 0.7710 - val_loss: 0.4439 - val_accuracy: 0.7761
# Epoch 36/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4449 - accuracy: 0.7713 - val_loss: 0.4394 - val_accuracy: 0.7747
# Epoch 37/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4432 - accuracy: 0.7720 - val_loss: 0.4379 - val_accuracy: 0.7768
# Epoch 38/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4429 - accuracy: 0.7724 - val_loss: 0.4370 - val_accuracy: 0.7764
# Epoch 39/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4431 - accuracy: 0.7721 - val_loss: 0.4398 - val_accuracy: 0.7757
# Epoch 40/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4418 - accuracy: 0.7727 - val_loss: 0.4404 - val_accuracy: 0.7739
# Epoch 41/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4426 - accuracy: 0.7728 - val_loss: 0.4367 - val_accuracy: 0.7761
# Epoch 42/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4408 - accuracy: 0.7730 - val_loss: 0.4382 - val_accuracy: 0.7763
# Epoch 43/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4414 - accuracy: 0.7731 - val_loss: 0.4364 - val_accuracy: 0.7776
# Epoch 44/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4403 - accuracy: 0.7739 - val_loss: 0.4367 - val_accuracy: 0.7770
# Epoch 45/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4397 - accuracy: 0.7740 - val_loss: 0.4365 - val_accuracy: 0.7761
# Epoch 46/140
# 47/47 [==============================] - 5s 106ms/step - loss: 0.4405 - accuracy: 0.7741 - val_loss: 0.4355 - val_accuracy: 0.7774
# Epoch 47/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4400 - accuracy: 0.7745 - val_loss: 0.4371 - val_accuracy: 0.7771
# Epoch 48/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4401 - accuracy: 0.7743 - val_loss: 0.4390 - val_accuracy: 0.7774
# Epoch 49/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4389 - accuracy: 0.7750 - val_loss: 0.4338 - val_accuracy: 0.7779
# Epoch 50/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4384 - accuracy: 0.7752 - val_loss: 0.4341 - val_accuracy: 0.7780
# Epoch 51/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4381 - accuracy: 0.7754 - val_loss: 0.4350 - val_accuracy: 0.7778
# Epoch 52/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4384 - accuracy: 0.7754 - val_loss: 0.4352 - val_accuracy: 0.7785
# Epoch 53/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4388 - accuracy: 0.7755 - val_loss: 0.4336 - val_accuracy: 0.7779
# Epoch 54/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4373 - accuracy: 0.7762 - val_loss: 0.4353 - val_accuracy: 0.7774
# Epoch 55/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4370 - accuracy: 0.7759 - val_loss: 0.4333 - val_accuracy: 0.7794
# Epoch 56/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4372 - accuracy: 0.7760 - val_loss: 0.4402 - val_accuracy: 0.7775
# Epoch 57/140
# 47/47 [==============================] - 5s 117ms/step - loss: 0.4373 - accuracy: 0.7761 - val_loss: 0.4320 - val_accuracy: 0.7790
# Epoch 58/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4364 - accuracy: 0.7765 - val_loss: 0.4365 - val_accuracy: 0.7790
# Epoch 59/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4362 - accuracy: 0.7766 - val_loss: 0.4326 - val_accuracy: 0.7782
# Epoch 60/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4362 - accuracy: 0.7768 - val_loss: 0.4367 - val_accuracy: 0.7769
# Epoch 61/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4361 - accuracy: 0.7767 - val_loss: 0.4325 - val_accuracy: 0.7786
# Epoch 62/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4351 - accuracy: 0.7768 - val_loss: 0.4327 - val_accuracy: 0.7786
# Epoch 63/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4354 - accuracy: 0.7764 - val_loss: 0.4315 - val_accuracy: 0.7790
# Epoch 64/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4355 - accuracy: 0.7770 - val_loss: 0.4310 - val_accuracy: 0.7804
# Epoch 65/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4345 - accuracy: 0.7774 - val_loss: 0.4317 - val_accuracy: 0.7797
# Epoch 66/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4352 - accuracy: 0.7773 - val_loss: 0.4314 - val_accuracy: 0.7806
# Epoch 67/140
# 47/47 [==============================] - 5s 108ms/step - loss: 0.4345 - accuracy: 0.7774 - val_loss: 0.4330 - val_accuracy: 0.7775
# Epoch 68/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4342 - accuracy: 0.7775 - val_loss: 0.4365 - val_accuracy: 0.7788
# Epoch 69/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4345 - accuracy: 0.7774 - val_loss: 0.4301 - val_accuracy: 0.7804
# Epoch 70/140
# 47/47 [==============================] - 5s 108ms/step - loss: 0.4337 - accuracy: 0.7777 - val_loss: 0.4302 - val_accuracy: 0.7809
# Epoch 71/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4343 - accuracy: 0.7775 - val_loss: 0.4298 - val_accuracy: 0.7799
# Epoch 72/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4338 - accuracy: 0.7778 - val_loss: 0.4319 - val_accuracy: 0.7793
# Epoch 73/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4327 - accuracy: 0.7776 - val_loss: 0.4290 - val_accuracy: 0.7802
# Epoch 74/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4329 - accuracy: 0.7780 - val_loss: 0.4296 - val_accuracy: 0.7801
# Epoch 75/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4327 - accuracy: 0.7779 - val_loss: 0.4306 - val_accuracy: 0.7808
# Epoch 76/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4323 - accuracy: 0.7781 - val_loss: 0.4296 - val_accuracy: 0.7801
# Epoch 77/140
# 47/47 [==============================] - 5s 108ms/step - loss: 0.4331 - accuracy: 0.7779 - val_loss: 0.4311 - val_accuracy: 0.7802
# Epoch 78/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4321 - accuracy: 0.7783 - val_loss: 0.4301 - val_accuracy: 0.7808
# Epoch 79/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4322 - accuracy: 0.7783 - val_loss: 0.4315 - val_accuracy: 0.7768
# Epoch 80/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4318 - accuracy: 0.7782 - val_loss: 0.4326 - val_accuracy: 0.7784
# Epoch 81/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4333 - accuracy: 0.7781 - val_loss: 0.4312 - val_accuracy: 0.7767
# Epoch 82/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4321 - accuracy: 0.7786 - val_loss: 0.4310 - val_accuracy: 0.7810
# Epoch 83/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4320 - accuracy: 0.7786 - val_loss: 0.4301 - val_accuracy: 0.7792
# Epoch 84/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4311 - accuracy: 0.7787 - val_loss: 0.4361 - val_accuracy: 0.7792
# Epoch 85/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4308 - accuracy: 0.7790 - val_loss: 0.4287 - val_accuracy: 0.7818
# Epoch 86/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4308 - accuracy: 0.7790 - val_loss: 0.4282 - val_accuracy: 0.7815
# Epoch 87/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4308 - accuracy: 0.7791 - val_loss: 0.4324 - val_accuracy: 0.7796
# Epoch 88/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4307 - accuracy: 0.7790 - val_loss: 0.4327 - val_accuracy: 0.7815
# Epoch 89/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4305 - accuracy: 0.7793 - val_loss: 0.4298 - val_accuracy: 0.7797
# Epoch 90/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4306 - accuracy: 0.7790 - val_loss: 0.4328 - val_accuracy: 0.7809
# Epoch 91/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4303 - accuracy: 0.7791 - val_loss: 0.4292 - val_accuracy: 0.7819
# Epoch 92/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4298 - accuracy: 0.7794 - val_loss: 0.4271 - val_accuracy: 0.7815
# Epoch 93/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4300 - accuracy: 0.7797 - val_loss: 0.4279 - val_accuracy: 0.7817
# Epoch 94/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4298 - accuracy: 0.7796 - val_loss: 0.4288 - val_accuracy: 0.7813
# Epoch 95/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4295 - accuracy: 0.7797 - val_loss: 0.4284 - val_accuracy: 0.7819
# Epoch 96/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4311 - accuracy: 0.7794 - val_loss: 0.4306 - val_accuracy: 0.7780
# Epoch 97/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4290 - accuracy: 0.7802 - val_loss: 0.4293 - val_accuracy: 0.7820
# Epoch 98/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4291 - accuracy: 0.7802 - val_loss: 0.4290 - val_accuracy: 0.7777
# Epoch 99/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4291 - accuracy: 0.7801 - val_loss: 0.4269 - val_accuracy: 0.7811
# Epoch 100/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4291 - accuracy: 0.7801 - val_loss: 0.4277 - val_accuracy: 0.7798
# Epoch 101/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4294 - accuracy: 0.7805 - val_loss: 0.4320 - val_accuracy: 0.7824
# Epoch 102/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4286 - accuracy: 0.7802 - val_loss: 0.4283 - val_accuracy: 0.7785
# Epoch 103/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4283 - accuracy: 0.7803 - val_loss: 0.4277 - val_accuracy: 0.7815
# Epoch 104/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4284 - accuracy: 0.7807 - val_loss: 0.4270 - val_accuracy: 0.7812
# Epoch 105/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4293 - accuracy: 0.7802 - val_loss: 0.4315 - val_accuracy: 0.7807
# Epoch 106/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4277 - accuracy: 0.7807 - val_loss: 0.4330 - val_accuracy: 0.7774
# Epoch 107/140
# 47/47 [==============================] - 5s 107ms/step - loss: 0.4278 - accuracy: 0.7806 - val_loss: 0.4373 - val_accuracy: 0.7826
# Epoch 108/140
# 47/47 [==============================] - 5s 108ms/step - loss: 0.4291 - accuracy: 0.7805 - val_loss: 0.4288 - val_accuracy: 0.7787
# Epoch 109/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4271 - accuracy: 0.7813 - val_loss: 0.4270 - val_accuracy: 0.7818
# Epoch 110/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4269 - accuracy: 0.7810 - val_loss: 0.4302 - val_accuracy: 0.7804
# Epoch 111/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4273 - accuracy: 0.7810 - val_loss: 0.4320 - val_accuracy: 0.7825
# Epoch 112/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4274 - accuracy: 0.7812 - val_loss: 0.4295 - val_accuracy: 0.7818
# Epoch 113/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4266 - accuracy: 0.7818 - val_loss: 0.4298 - val_accuracy: 0.7832
# Epoch 114/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4266 - accuracy: 0.7816 - val_loss: 0.4290 - val_accuracy: 0.7813
# Epoch 115/140
# 47/47 [==============================] - 5s 112ms/step - loss: 0.4280 - accuracy: 0.7811 - val_loss: 0.4274 - val_accuracy: 0.7816
# Epoch 116/140
# 47/47 [==============================] - 5s 112ms/step - loss: 0.4273 - accuracy: 0.7821 - val_loss: 0.4329 - val_accuracy: 0.7838
# Epoch 117/140
# 47/47 [==============================] - 5s 112ms/step - loss: 0.4260 - accuracy: 0.7816 - val_loss: 0.4316 - val_accuracy: 0.7822
# Epoch 118/140
# 47/47 [==============================] - 5s 112ms/step - loss: 0.4263 - accuracy: 0.7819 - val_loss: 0.4283 - val_accuracy: 0.7791
# Epoch 119/140
# 47/47 [==============================] - 5s 117ms/step - loss: 0.4258 - accuracy: 0.7821 - val_loss: 0.4279 - val_accuracy: 0.7783
# Epoch 120/140
# 47/47 [==============================] - 5s 112ms/step - loss: 0.4258 - accuracy: 0.7823 - val_loss: 0.4294 - val_accuracy: 0.7806
# Epoch 121/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4261 - accuracy: 0.7820 - val_loss: 0.4266 - val_accuracy: 0.7821
# Epoch 122/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4258 - accuracy: 0.7825 - val_loss: 0.4268 - val_accuracy: 0.7815
# Epoch 123/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4255 - accuracy: 0.7826 - val_loss: 0.4265 - val_accuracy: 0.7812
# Epoch 124/140
# 47/47 [==============================] - 5s 111ms/step - loss: 0.4255 - accuracy: 0.7827 - val_loss: 0.4302 - val_accuracy: 0.7826
# Epoch 125/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4245 - accuracy: 0.7828 - val_loss: 0.4314 - val_accuracy: 0.7790
# Epoch 126/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4244 - accuracy: 0.7832 - val_loss: 0.4295 - val_accuracy: 0.7841
# Epoch 127/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4256 - accuracy: 0.7827 - val_loss: 0.4272 - val_accuracy: 0.7799
# Epoch 128/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4246 - accuracy: 0.7829 - val_loss: 0.4266 - val_accuracy: 0.7806
# Epoch 129/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4245 - accuracy: 0.7833 - val_loss: 0.4320 - val_accuracy: 0.7825
# Epoch 130/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4241 - accuracy: 0.7834 - val_loss: 0.4291 - val_accuracy: 0.7803
# Epoch 131/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4235 - accuracy: 0.7835 - val_loss: 0.4313 - val_accuracy: 0.7789
# Epoch 132/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4245 - accuracy: 0.7831 - val_loss: 0.4306 - val_accuracy: 0.7813
# Epoch 133/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4228 - accuracy: 0.7838 - val_loss: 0.4287 - val_accuracy: 0.7801
# Epoch 134/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4240 - accuracy: 0.7836 - val_loss: 0.4288 - val_accuracy: 0.7834
# Epoch 135/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4237 - accuracy: 0.7833 - val_loss: 0.4322 - val_accuracy: 0.7744
# Epoch 136/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4234 - accuracy: 0.7836 - val_loss: 0.4327 - val_accuracy: 0.7816
# Epoch 137/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4224 - accuracy: 0.7840 - val_loss: 0.4284 - val_accuracy: 0.7783
# Epoch 138/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4221 - accuracy: 0.7842 - val_loss: 0.4271 - val_accuracy: 0.7813
# Epoch 139/140
# 47/47 [==============================] - 5s 110ms/step - loss: 0.4217 - accuracy: 0.7845 - val_loss: 0.4292 - val_accuracy: 0.7771
# Epoch 140/140
# 47/47 [==============================] - 5s 109ms/step - loss: 0.4223 - accuracy: 0.7840 - val_loss: 0.4277 - val_accuracy: 0.7803

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 14s 4ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 729.9889848232269

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95064, 1)

# %%
pred_y
# Out:
# array([[0.00139554],
#        [0.00053161],
#        [0.00027936],
#        ...,
#        [0.06485824],
#        [0.06757126],
#        [0.06828493]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95064)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14335626310590374
# 0.22912402700493173
# 0.37862417131755305
# 0.2828162741963866

# %%
np.shape(train_X)
# Out:
# (380253, 20, 15)

# %%
np.shape(train_y)
# Out:
# (380253, 1)

# %%
np.shape(test_X)
# Out:
# (95064, 20, 15)

# %%
np.shape(test_y)
# Out:
# (95064, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 65s 4ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794785]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60981494]
# [0.82371818]
# total acc [0.78342454]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 689931520, 'peak': 3363362048}
