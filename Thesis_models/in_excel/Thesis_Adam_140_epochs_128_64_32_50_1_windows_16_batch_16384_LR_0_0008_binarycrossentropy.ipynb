# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1bdae1e3040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1bde825f040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0008)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 10s 136ms/step - loss: 0.5936 - accuracy: 0.7393 - val_loss: 0.5583 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.5709 - accuracy: 0.7393 - val_loss: 0.5525 - val_accuracy: 0.7531
# Epoch 3/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.5482 - accuracy: 0.7381 - val_loss: 0.5194 - val_accuracy: 0.7531
# Epoch 4/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.5172 - accuracy: 0.7395 - val_loss: 0.4976 - val_accuracy: 0.7507
# Epoch 5/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.5029 - accuracy: 0.7382 - val_loss: 0.4850 - val_accuracy: 0.7530
# Epoch 6/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4970 - accuracy: 0.7410 - val_loss: 0.4802 - val_accuracy: 0.7536
# Epoch 7/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4920 - accuracy: 0.7452 - val_loss: 0.4773 - val_accuracy: 0.7534
# Epoch 8/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4859 - accuracy: 0.7485 - val_loss: 0.4749 - val_accuracy: 0.7523
# Epoch 9/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4781 - accuracy: 0.7519 - val_loss: 0.4675 - val_accuracy: 0.7581
# Epoch 10/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4721 - accuracy: 0.7551 - val_loss: 0.4612 - val_accuracy: 0.7598
# Epoch 11/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4686 - accuracy: 0.7567 - val_loss: 0.4654 - val_accuracy: 0.7552
# Epoch 12/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4660 - accuracy: 0.7573 - val_loss: 0.4611 - val_accuracy: 0.7630
# Epoch 13/140
# 24/24 [==============================] - 2s 86ms/step - loss: 0.4643 - accuracy: 0.7580 - val_loss: 0.4555 - val_accuracy: 0.7622
# Epoch 14/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4610 - accuracy: 0.7585 - val_loss: 0.4679 - val_accuracy: 0.7645
# Epoch 15/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4639 - accuracy: 0.7583 - val_loss: 0.4534 - val_accuracy: 0.7643
# Epoch 16/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4582 - accuracy: 0.7602 - val_loss: 0.4520 - val_accuracy: 0.7649
# Epoch 17/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4592 - accuracy: 0.7606 - val_loss: 0.4552 - val_accuracy: 0.7633
# Epoch 18/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4574 - accuracy: 0.7616 - val_loss: 0.4477 - val_accuracy: 0.7654
# Epoch 19/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4557 - accuracy: 0.7625 - val_loss: 0.4466 - val_accuracy: 0.7686
# Epoch 20/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4548 - accuracy: 0.7634 - val_loss: 0.4523 - val_accuracy: 0.7694
# Epoch 21/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4541 - accuracy: 0.7646 - val_loss: 0.4451 - val_accuracy: 0.7693
# Epoch 22/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4514 - accuracy: 0.7654 - val_loss: 0.4435 - val_accuracy: 0.7703
# Epoch 23/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4505 - accuracy: 0.7661 - val_loss: 0.4463 - val_accuracy: 0.7713
# Epoch 24/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4500 - accuracy: 0.7671 - val_loss: 0.4432 - val_accuracy: 0.7705
# Epoch 25/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4484 - accuracy: 0.7677 - val_loss: 0.4434 - val_accuracy: 0.7728
# Epoch 26/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4477 - accuracy: 0.7687 - val_loss: 0.4426 - val_accuracy: 0.7731
# Epoch 27/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4462 - accuracy: 0.7696 - val_loss: 0.4410 - val_accuracy: 0.7738
# Epoch 28/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4462 - accuracy: 0.7699 - val_loss: 0.4400 - val_accuracy: 0.7742
# Epoch 29/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4460 - accuracy: 0.7703 - val_loss: 0.4414 - val_accuracy: 0.7725
# Epoch 30/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4456 - accuracy: 0.7708 - val_loss: 0.4400 - val_accuracy: 0.7750
# Epoch 31/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4439 - accuracy: 0.7711 - val_loss: 0.4363 - val_accuracy: 0.7764
# Epoch 32/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4444 - accuracy: 0.7717 - val_loss: 0.4386 - val_accuracy: 0.7740
# Epoch 33/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4434 - accuracy: 0.7719 - val_loss: 0.4364 - val_accuracy: 0.7755
# Epoch 34/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4434 - accuracy: 0.7718 - val_loss: 0.4366 - val_accuracy: 0.7763
# Epoch 35/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4425 - accuracy: 0.7725 - val_loss: 0.4412 - val_accuracy: 0.7767
# Epoch 36/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4425 - accuracy: 0.7728 - val_loss: 0.4394 - val_accuracy: 0.7761
# Epoch 37/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4404 - accuracy: 0.7738 - val_loss: 0.4356 - val_accuracy: 0.7773
# Epoch 38/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4400 - accuracy: 0.7738 - val_loss: 0.4374 - val_accuracy: 0.7758
# Epoch 39/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4403 - accuracy: 0.7743 - val_loss: 0.4406 - val_accuracy: 0.7750
# Epoch 40/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4401 - accuracy: 0.7742 - val_loss: 0.4377 - val_accuracy: 0.7759
# Epoch 41/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4404 - accuracy: 0.7746 - val_loss: 0.4363 - val_accuracy: 0.7775
# Epoch 42/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4396 - accuracy: 0.7747 - val_loss: 0.4401 - val_accuracy: 0.7764
# Epoch 43/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4403 - accuracy: 0.7746 - val_loss: 0.4343 - val_accuracy: 0.7773
# Epoch 44/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4393 - accuracy: 0.7755 - val_loss: 0.4355 - val_accuracy: 0.7768
# Epoch 45/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4380 - accuracy: 0.7752 - val_loss: 0.4332 - val_accuracy: 0.7789
# Epoch 46/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4381 - accuracy: 0.7756 - val_loss: 0.4388 - val_accuracy: 0.7769
# Epoch 47/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4389 - accuracy: 0.7754 - val_loss: 0.4320 - val_accuracy: 0.7790
# Epoch 48/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4378 - accuracy: 0.7758 - val_loss: 0.4331 - val_accuracy: 0.7784
# Epoch 49/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4380 - accuracy: 0.7760 - val_loss: 0.4355 - val_accuracy: 0.7777
# Epoch 50/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4365 - accuracy: 0.7763 - val_loss: 0.4320 - val_accuracy: 0.7789
# Epoch 51/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4368 - accuracy: 0.7762 - val_loss: 0.4346 - val_accuracy: 0.7787
# Epoch 52/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4372 - accuracy: 0.7766 - val_loss: 0.4437 - val_accuracy: 0.7775
# Epoch 53/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4367 - accuracy: 0.7768 - val_loss: 0.4314 - val_accuracy: 0.7786
# Epoch 54/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4366 - accuracy: 0.7772 - val_loss: 0.4305 - val_accuracy: 0.7809
# Epoch 55/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4384 - accuracy: 0.7760 - val_loss: 0.4393 - val_accuracy: 0.7781
# Epoch 56/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4350 - accuracy: 0.7773 - val_loss: 0.4328 - val_accuracy: 0.7790
# Epoch 57/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4342 - accuracy: 0.7781 - val_loss: 0.4302 - val_accuracy: 0.7793
# Epoch 58/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4337 - accuracy: 0.7780 - val_loss: 0.4314 - val_accuracy: 0.7785
# Epoch 59/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4339 - accuracy: 0.7779 - val_loss: 0.4381 - val_accuracy: 0.7782
# Epoch 60/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4337 - accuracy: 0.7780 - val_loss: 0.4300 - val_accuracy: 0.7795
# Epoch 61/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4345 - accuracy: 0.7782 - val_loss: 0.4334 - val_accuracy: 0.7788
# Epoch 62/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4328 - accuracy: 0.7785 - val_loss: 0.4335 - val_accuracy: 0.7779
# Epoch 63/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4338 - accuracy: 0.7782 - val_loss: 0.4320 - val_accuracy: 0.7778
# Epoch 64/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4334 - accuracy: 0.7781 - val_loss: 0.4304 - val_accuracy: 0.7796
# Epoch 65/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4325 - accuracy: 0.7789 - val_loss: 0.4333 - val_accuracy: 0.7805
# Epoch 66/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4328 - accuracy: 0.7788 - val_loss: 0.4288 - val_accuracy: 0.7802
# Epoch 67/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4315 - accuracy: 0.7791 - val_loss: 0.4283 - val_accuracy: 0.7808
# Epoch 68/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4315 - accuracy: 0.7790 - val_loss: 0.4387 - val_accuracy: 0.7787
# Epoch 69/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4326 - accuracy: 0.7791 - val_loss: 0.4305 - val_accuracy: 0.7797
# Epoch 70/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4314 - accuracy: 0.7793 - val_loss: 0.4307 - val_accuracy: 0.7823
# Epoch 71/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4311 - accuracy: 0.7797 - val_loss: 0.4293 - val_accuracy: 0.7804
# Epoch 72/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4308 - accuracy: 0.7798 - val_loss: 0.4308 - val_accuracy: 0.7795
# Epoch 73/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4303 - accuracy: 0.7801 - val_loss: 0.4296 - val_accuracy: 0.7809
# Epoch 74/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4314 - accuracy: 0.7795 - val_loss: 0.4285 - val_accuracy: 0.7805
# Epoch 75/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4307 - accuracy: 0.7800 - val_loss: 0.4292 - val_accuracy: 0.7817
# Epoch 76/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4299 - accuracy: 0.7804 - val_loss: 0.4284 - val_accuracy: 0.7811
# Epoch 77/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4290 - accuracy: 0.7809 - val_loss: 0.4309 - val_accuracy: 0.7815
# Epoch 78/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4309 - accuracy: 0.7804 - val_loss: 0.4321 - val_accuracy: 0.7770
# Epoch 79/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4292 - accuracy: 0.7813 - val_loss: 0.4319 - val_accuracy: 0.7772
# Epoch 80/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4302 - accuracy: 0.7808 - val_loss: 0.4318 - val_accuracy: 0.7770
# Epoch 81/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4301 - accuracy: 0.7810 - val_loss: 0.4297 - val_accuracy: 0.7814
# Epoch 82/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4274 - accuracy: 0.7816 - val_loss: 0.4292 - val_accuracy: 0.7784
# Epoch 83/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4279 - accuracy: 0.7817 - val_loss: 0.4268 - val_accuracy: 0.7808
# Epoch 84/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4270 - accuracy: 0.7819 - val_loss: 0.4303 - val_accuracy: 0.7777
# Epoch 85/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4270 - accuracy: 0.7818 - val_loss: 0.4273 - val_accuracy: 0.7806
# Epoch 86/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4261 - accuracy: 0.7822 - val_loss: 0.4299 - val_accuracy: 0.7824
# Epoch 87/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4265 - accuracy: 0.7822 - val_loss: 0.4278 - val_accuracy: 0.7824
# Epoch 88/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4261 - accuracy: 0.7820 - val_loss: 0.4266 - val_accuracy: 0.7831
# Epoch 89/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4260 - accuracy: 0.7821 - val_loss: 0.4275 - val_accuracy: 0.7812
# Epoch 90/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4258 - accuracy: 0.7822 - val_loss: 0.4295 - val_accuracy: 0.7831
# Epoch 91/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4257 - accuracy: 0.7823 - val_loss: 0.4288 - val_accuracy: 0.7815
# Epoch 92/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4254 - accuracy: 0.7825 - val_loss: 0.4377 - val_accuracy: 0.7719
# Epoch 93/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4265 - accuracy: 0.7822 - val_loss: 0.4325 - val_accuracy: 0.7837
# Epoch 94/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4256 - accuracy: 0.7824 - val_loss: 0.4310 - val_accuracy: 0.7811
# Epoch 95/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4257 - accuracy: 0.7823 - val_loss: 0.4264 - val_accuracy: 0.7806
# Epoch 96/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4242 - accuracy: 0.7829 - val_loss: 0.4293 - val_accuracy: 0.7794
# Epoch 97/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4254 - accuracy: 0.7826 - val_loss: 0.4454 - val_accuracy: 0.7823
# Epoch 98/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4256 - accuracy: 0.7827 - val_loss: 0.4271 - val_accuracy: 0.7791
# Epoch 99/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4236 - accuracy: 0.7837 - val_loss: 0.4270 - val_accuracy: 0.7835
# Epoch 100/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4237 - accuracy: 0.7833 - val_loss: 0.4307 - val_accuracy: 0.7828
# Epoch 101/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4237 - accuracy: 0.7833 - val_loss: 0.4288 - val_accuracy: 0.7783
# Epoch 102/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4243 - accuracy: 0.7832 - val_loss: 0.4327 - val_accuracy: 0.7835
# Epoch 103/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4231 - accuracy: 0.7836 - val_loss: 0.4277 - val_accuracy: 0.7804
# Epoch 104/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4225 - accuracy: 0.7840 - val_loss: 0.4273 - val_accuracy: 0.7840
# Epoch 105/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4236 - accuracy: 0.7838 - val_loss: 0.4268 - val_accuracy: 0.7830
# Epoch 106/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4233 - accuracy: 0.7839 - val_loss: 0.4279 - val_accuracy: 0.7830
# Epoch 107/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4220 - accuracy: 0.7842 - val_loss: 0.4319 - val_accuracy: 0.7833
# Epoch 108/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4220 - accuracy: 0.7839 - val_loss: 0.4271 - val_accuracy: 0.7831
# Epoch 109/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4224 - accuracy: 0.7839 - val_loss: 0.4326 - val_accuracy: 0.7822
# Epoch 110/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4226 - accuracy: 0.7839 - val_loss: 0.4267 - val_accuracy: 0.7848
# Epoch 111/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4223 - accuracy: 0.7843 - val_loss: 0.4263 - val_accuracy: 0.7840
# Epoch 112/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4209 - accuracy: 0.7851 - val_loss: 0.4263 - val_accuracy: 0.7823
# Epoch 113/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4223 - accuracy: 0.7842 - val_loss: 0.4241 - val_accuracy: 0.7839
# Epoch 114/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4211 - accuracy: 0.7847 - val_loss: 0.4254 - val_accuracy: 0.7820
# Epoch 115/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4209 - accuracy: 0.7847 - val_loss: 0.4270 - val_accuracy: 0.7842
# Epoch 116/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4201 - accuracy: 0.7851 - val_loss: 0.4305 - val_accuracy: 0.7837
# Epoch 117/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4215 - accuracy: 0.7846 - val_loss: 0.4291 - val_accuracy: 0.7842
# Epoch 118/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4222 - accuracy: 0.7848 - val_loss: 0.4282 - val_accuracy: 0.7806
# Epoch 119/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4207 - accuracy: 0.7853 - val_loss: 0.4286 - val_accuracy: 0.7778
# Epoch 120/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4213 - accuracy: 0.7848 - val_loss: 0.4255 - val_accuracy: 0.7826
# Epoch 121/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4197 - accuracy: 0.7851 - val_loss: 0.4297 - val_accuracy: 0.7839
# Epoch 122/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4203 - accuracy: 0.7855 - val_loss: 0.4270 - val_accuracy: 0.7817
# Epoch 123/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4198 - accuracy: 0.7853 - val_loss: 0.4271 - val_accuracy: 0.7817
# Epoch 124/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4189 - accuracy: 0.7858 - val_loss: 0.4283 - val_accuracy: 0.7837
# Epoch 125/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4191 - accuracy: 0.7858 - val_loss: 0.4270 - val_accuracy: 0.7817
# Epoch 126/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4192 - accuracy: 0.7856 - val_loss: 0.4274 - val_accuracy: 0.7832
# Epoch 127/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4191 - accuracy: 0.7861 - val_loss: 0.4287 - val_accuracy: 0.7784
# Epoch 128/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4189 - accuracy: 0.7859 - val_loss: 0.4271 - val_accuracy: 0.7824
# Epoch 129/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4189 - accuracy: 0.7862 - val_loss: 0.4282 - val_accuracy: 0.7791
# Epoch 130/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4198 - accuracy: 0.7857 - val_loss: 0.4249 - val_accuracy: 0.7848
# Epoch 131/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4190 - accuracy: 0.7856 - val_loss: 0.4317 - val_accuracy: 0.7837
# Epoch 132/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4180 - accuracy: 0.7863 - val_loss: 0.4272 - val_accuracy: 0.7807
# Epoch 133/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4178 - accuracy: 0.7863 - val_loss: 0.4278 - val_accuracy: 0.7801
# Epoch 134/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4185 - accuracy: 0.7863 - val_loss: 0.4299 - val_accuracy: 0.7798
# Epoch 135/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4194 - accuracy: 0.7859 - val_loss: 0.4273 - val_accuracy: 0.7829
# Epoch 136/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4174 - accuracy: 0.7863 - val_loss: 0.4296 - val_accuracy: 0.7834
# Epoch 137/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4176 - accuracy: 0.7866 - val_loss: 0.4272 - val_accuracy: 0.7800
# Epoch 138/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4171 - accuracy: 0.7867 - val_loss: 0.4257 - val_accuracy: 0.7811
# Epoch 139/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4172 - accuracy: 0.7865 - val_loss: 0.4276 - val_accuracy: 0.7835
# Epoch 140/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4170 - accuracy: 0.7869 - val_loss: 0.4285 - val_accuracy: 0.7832

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 301.47051906585693

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00289501],
#        [0.0017794 ],
#        [0.00076081],
#        ...,
#        [0.06353488],
#        [0.07052971],
#        [0.07198296]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14302884327846885
# 0.23087923874683602
# 0.3781915431080775
# 0.2816972650788019

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 83s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.61253088]
# [0.82796076]
# total acc [0.78594676]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 548989184, 'peak': 2733980672}
