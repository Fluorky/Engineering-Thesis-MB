# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2bf00003040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2bf610a3040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=256)#, shuffle=False)
# Out:
# Epoch 1/140
# 1486/1486 [==============================] - 36s 20ms/step - loss: 0.5748 - accuracy: 0.7364 - val_loss: 0.5573 - val_accuracy: 0.7531
# Epoch 2/140
# 1486/1486 [==============================] - 29s 20ms/step - loss: 0.5690 - accuracy: 0.7393 - val_loss: 0.5529 - val_accuracy: 0.7531
# Epoch 3/140
# 1486/1486 [==============================] - 29s 19ms/step - loss: 0.5589 - accuracy: 0.7393 - val_loss: 0.5381 - val_accuracy: 0.7531
# Epoch 4/140
# 1486/1486 [==============================] - 28s 19ms/step - loss: 0.5360 - accuracy: 0.7403 - val_loss: 0.5113 - val_accuracy: 0.7536
# Epoch 5/140
# 1486/1486 [==============================] - 26s 17ms/step - loss: 0.5158 - accuracy: 0.7401 - val_loss: 0.5030 - val_accuracy: 0.7506
# Epoch 6/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.5062 - accuracy: 0.7371 - val_loss: 0.4890 - val_accuracy: 0.7525
# Epoch 7/140
# 1486/1486 [==============================] - 26s 17ms/step - loss: 0.5032 - accuracy: 0.7364 - val_loss: 0.4884 - val_accuracy: 0.7529
# Epoch 8/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.5017 - accuracy: 0.7375 - val_loss: 0.4878 - val_accuracy: 0.7531
# Epoch 9/140
# 1486/1486 [==============================] - 26s 17ms/step - loss: 0.5007 - accuracy: 0.7381 - val_loss: 0.4857 - val_accuracy: 0.7532
# Epoch 10/140
# 1486/1486 [==============================] - 26s 17ms/step - loss: 0.4998 - accuracy: 0.7385 - val_loss: 0.4842 - val_accuracy: 0.7533
# Epoch 11/140
# 1486/1486 [==============================] - 26s 18ms/step - loss: 0.4990 - accuracy: 0.7387 - val_loss: 0.4837 - val_accuracy: 0.7532
# Epoch 12/140
# 1486/1486 [==============================] - 26s 18ms/step - loss: 0.4984 - accuracy: 0.7388 - val_loss: 0.4828 - val_accuracy: 0.7531
# Epoch 13/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4976 - accuracy: 0.7391 - val_loss: 0.4862 - val_accuracy: 0.7531
# Epoch 14/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4968 - accuracy: 0.7392 - val_loss: 0.4830 - val_accuracy: 0.7531
# Epoch 15/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4959 - accuracy: 0.7394 - val_loss: 0.4821 - val_accuracy: 0.7531
# Epoch 16/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4949 - accuracy: 0.7399 - val_loss: 0.4803 - val_accuracy: 0.7533
# Epoch 17/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4938 - accuracy: 0.7408 - val_loss: 0.4836 - val_accuracy: 0.7530
# Epoch 18/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4924 - accuracy: 0.7427 - val_loss: 0.4783 - val_accuracy: 0.7530
# Epoch 19/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4907 - accuracy: 0.7447 - val_loss: 0.4825 - val_accuracy: 0.7526
# Epoch 20/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4889 - accuracy: 0.7464 - val_loss: 0.4765 - val_accuracy: 0.7529
# Epoch 21/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4869 - accuracy: 0.7476 - val_loss: 0.4758 - val_accuracy: 0.7529
# Epoch 22/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4849 - accuracy: 0.7477 - val_loss: 0.4742 - val_accuracy: 0.7529
# Epoch 23/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4827 - accuracy: 0.7479 - val_loss: 0.4731 - val_accuracy: 0.7530
# Epoch 24/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4806 - accuracy: 0.7479 - val_loss: 0.4772 - val_accuracy: 0.7495
# Epoch 25/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4785 - accuracy: 0.7494 - val_loss: 0.4725 - val_accuracy: 0.7516
# Epoch 26/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4767 - accuracy: 0.7506 - val_loss: 0.4748 - val_accuracy: 0.7533
# Epoch 27/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4749 - accuracy: 0.7516 - val_loss: 0.4681 - val_accuracy: 0.7563
# Epoch 28/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4734 - accuracy: 0.7523 - val_loss: 0.4666 - val_accuracy: 0.7568
# Epoch 29/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4719 - accuracy: 0.7532 - val_loss: 0.4649 - val_accuracy: 0.7577
# Epoch 30/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4707 - accuracy: 0.7536 - val_loss: 0.4636 - val_accuracy: 0.7594
# Epoch 31/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4694 - accuracy: 0.7543 - val_loss: 0.4645 - val_accuracy: 0.7556
# Epoch 32/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4685 - accuracy: 0.7542 - val_loss: 0.4594 - val_accuracy: 0.7586
# Epoch 33/140
# 1486/1486 [==============================] - 25s 16ms/step - loss: 0.4676 - accuracy: 0.7548 - val_loss: 0.4607 - val_accuracy: 0.7585
# Epoch 34/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4666 - accuracy: 0.7550 - val_loss: 0.4629 - val_accuracy: 0.7569
# Epoch 35/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4659 - accuracy: 0.7549 - val_loss: 0.4574 - val_accuracy: 0.7602
# Epoch 36/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4653 - accuracy: 0.7553 - val_loss: 0.4581 - val_accuracy: 0.7613
# Epoch 37/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4644 - accuracy: 0.7556 - val_loss: 0.4593 - val_accuracy: 0.7601
# Epoch 38/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4639 - accuracy: 0.7558 - val_loss: 0.4546 - val_accuracy: 0.7614
# Epoch 39/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4633 - accuracy: 0.7560 - val_loss: 0.4567 - val_accuracy: 0.7616
# Epoch 40/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4628 - accuracy: 0.7563 - val_loss: 0.4557 - val_accuracy: 0.7602
# Epoch 41/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4622 - accuracy: 0.7566 - val_loss: 0.4568 - val_accuracy: 0.7620
# Epoch 42/140
# 1486/1486 [==============================] - 24s 16ms/step - loss: 0.4617 - accuracy: 0.7570 - val_loss: 0.4537 - val_accuracy: 0.7610
# Epoch 43/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4613 - accuracy: 0.7570 - val_loss: 0.4529 - val_accuracy: 0.7611
# Epoch 44/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4609 - accuracy: 0.7569 - val_loss: 0.4540 - val_accuracy: 0.7629
# Epoch 45/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4606 - accuracy: 0.7573 - val_loss: 0.4527 - val_accuracy: 0.7625
# Epoch 46/140
# 1486/1486 [==============================] - 25s 16ms/step - loss: 0.4599 - accuracy: 0.7575 - val_loss: 0.4535 - val_accuracy: 0.7636
# Epoch 47/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4595 - accuracy: 0.7579 - val_loss: 0.4577 - val_accuracy: 0.7636
# Epoch 48/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4592 - accuracy: 0.7585 - val_loss: 0.4503 - val_accuracy: 0.7636
# Epoch 49/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4589 - accuracy: 0.7584 - val_loss: 0.4538 - val_accuracy: 0.7632
# Epoch 50/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4584 - accuracy: 0.7583 - val_loss: 0.4514 - val_accuracy: 0.7624
# Epoch 51/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4580 - accuracy: 0.7586 - val_loss: 0.4499 - val_accuracy: 0.7629
# Epoch 52/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4575 - accuracy: 0.7591 - val_loss: 0.4493 - val_accuracy: 0.7635
# Epoch 53/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4572 - accuracy: 0.7592 - val_loss: 0.4496 - val_accuracy: 0.7646
# Epoch 54/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4570 - accuracy: 0.7593 - val_loss: 0.4503 - val_accuracy: 0.7650
# Epoch 55/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4565 - accuracy: 0.7598 - val_loss: 0.4480 - val_accuracy: 0.7634
# Epoch 56/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4562 - accuracy: 0.7603 - val_loss: 0.4517 - val_accuracy: 0.7627
# Epoch 57/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4557 - accuracy: 0.7601 - val_loss: 0.4498 - val_accuracy: 0.7642
# Epoch 58/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4553 - accuracy: 0.7606 - val_loss: 0.4542 - val_accuracy: 0.7623
# Epoch 59/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4552 - accuracy: 0.7604 - val_loss: 0.4478 - val_accuracy: 0.7666
# Epoch 60/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4547 - accuracy: 0.7611 - val_loss: 0.4489 - val_accuracy: 0.7646
# Epoch 61/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4544 - accuracy: 0.7613 - val_loss: 0.4465 - val_accuracy: 0.7664
# Epoch 62/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4540 - accuracy: 0.7618 - val_loss: 0.4448 - val_accuracy: 0.7667
# Epoch 63/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4537 - accuracy: 0.7620 - val_loss: 0.4585 - val_accuracy: 0.7667
# Epoch 64/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4533 - accuracy: 0.7623 - val_loss: 0.4508 - val_accuracy: 0.7649
# Epoch 65/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4529 - accuracy: 0.7629 - val_loss: 0.4436 - val_accuracy: 0.7671
# Epoch 66/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4526 - accuracy: 0.7630 - val_loss: 0.4465 - val_accuracy: 0.7679
# Epoch 67/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4520 - accuracy: 0.7632 - val_loss: 0.4439 - val_accuracy: 0.7674
# Epoch 68/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4518 - accuracy: 0.7637 - val_loss: 0.4483 - val_accuracy: 0.7661
# Epoch 69/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4516 - accuracy: 0.7636 - val_loss: 0.4558 - val_accuracy: 0.7645
# Epoch 70/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4509 - accuracy: 0.7644 - val_loss: 0.4660 - val_accuracy: 0.7672
# Epoch 71/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4506 - accuracy: 0.7647 - val_loss: 0.4423 - val_accuracy: 0.7705
# Epoch 72/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4504 - accuracy: 0.7648 - val_loss: 0.4546 - val_accuracy: 0.7640
# Epoch 73/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4499 - accuracy: 0.7651 - val_loss: 0.4410 - val_accuracy: 0.7704
# Epoch 74/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4495 - accuracy: 0.7651 - val_loss: 0.4413 - val_accuracy: 0.7690
# Epoch 75/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4492 - accuracy: 0.7655 - val_loss: 0.4523 - val_accuracy: 0.7711
# Epoch 76/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4489 - accuracy: 0.7657 - val_loss: 0.4398 - val_accuracy: 0.7715
# Epoch 77/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4486 - accuracy: 0.7662 - val_loss: 0.4525 - val_accuracy: 0.7696
# Epoch 78/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4484 - accuracy: 0.7666 - val_loss: 0.4396 - val_accuracy: 0.7719
# Epoch 79/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4480 - accuracy: 0.7665 - val_loss: 0.4422 - val_accuracy: 0.7717
# Epoch 80/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4476 - accuracy: 0.7667 - val_loss: 0.4471 - val_accuracy: 0.7708
# Epoch 81/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4476 - accuracy: 0.7668 - val_loss: 0.4409 - val_accuracy: 0.7711
# Epoch 82/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4472 - accuracy: 0.7675 - val_loss: 0.4397 - val_accuracy: 0.7712
# Epoch 83/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4470 - accuracy: 0.7669 - val_loss: 0.4389 - val_accuracy: 0.7724
# Epoch 84/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4467 - accuracy: 0.7675 - val_loss: 0.4447 - val_accuracy: 0.7703
# Epoch 85/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4462 - accuracy: 0.7679 - val_loss: 0.4403 - val_accuracy: 0.7731
# Epoch 86/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4463 - accuracy: 0.7678 - val_loss: 0.4536 - val_accuracy: 0.7735
# Epoch 87/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4458 - accuracy: 0.7683 - val_loss: 0.4380 - val_accuracy: 0.7738
# Epoch 88/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4456 - accuracy: 0.7685 - val_loss: 0.4382 - val_accuracy: 0.7733
# Epoch 89/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4455 - accuracy: 0.7683 - val_loss: 0.4389 - val_accuracy: 0.7737
# Epoch 90/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4453 - accuracy: 0.7689 - val_loss: 0.4411 - val_accuracy: 0.7729
# Epoch 91/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4450 - accuracy: 0.7691 - val_loss: 0.4394 - val_accuracy: 0.7727
# Epoch 92/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4446 - accuracy: 0.7693 - val_loss: 0.4638 - val_accuracy: 0.7729
# Epoch 93/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4446 - accuracy: 0.7694 - val_loss: 0.4402 - val_accuracy: 0.7727
# Epoch 94/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4442 - accuracy: 0.7695 - val_loss: 0.4523 - val_accuracy: 0.7660
# Epoch 95/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4441 - accuracy: 0.7696 - val_loss: 0.4455 - val_accuracy: 0.7726
# Epoch 96/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4437 - accuracy: 0.7704 - val_loss: 0.4565 - val_accuracy: 0.7726
# Epoch 97/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4434 - accuracy: 0.7703 - val_loss: 0.4378 - val_accuracy: 0.7751
# Epoch 98/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4433 - accuracy: 0.7704 - val_loss: 0.4399 - val_accuracy: 0.7748
# Epoch 99/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4432 - accuracy: 0.7705 - val_loss: 0.4374 - val_accuracy: 0.7741
# Epoch 100/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4429 - accuracy: 0.7710 - val_loss: 0.4360 - val_accuracy: 0.7748
# Epoch 101/140
# 1486/1486 [==============================] - 25s 16ms/step - loss: 0.4427 - accuracy: 0.7713 - val_loss: 0.4408 - val_accuracy: 0.7751
# Epoch 102/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4424 - accuracy: 0.7714 - val_loss: 0.4398 - val_accuracy: 0.7745
# Epoch 103/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4424 - accuracy: 0.7713 - val_loss: 0.4394 - val_accuracy: 0.7747
# Epoch 104/140
# 1486/1486 [==============================] - 24s 16ms/step - loss: 0.4421 - accuracy: 0.7714 - val_loss: 0.4436 - val_accuracy: 0.7715
# Epoch 105/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4419 - accuracy: 0.7720 - val_loss: 0.4374 - val_accuracy: 0.7751
# Epoch 106/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4418 - accuracy: 0.7717 - val_loss: 0.4395 - val_accuracy: 0.7742
# Epoch 107/140
# 1486/1486 [==============================] - 24s 16ms/step - loss: 0.4415 - accuracy: 0.7722 - val_loss: 0.4352 - val_accuracy: 0.7750
# Epoch 108/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4415 - accuracy: 0.7726 - val_loss: 0.4359 - val_accuracy: 0.7760
# Epoch 109/140
# 1486/1486 [==============================] - 24s 16ms/step - loss: 0.4412 - accuracy: 0.7729 - val_loss: 0.4359 - val_accuracy: 0.7754
# Epoch 110/140
# 1486/1486 [==============================] - 24s 16ms/step - loss: 0.4411 - accuracy: 0.7726 - val_loss: 0.4372 - val_accuracy: 0.7751
# Epoch 111/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4412 - accuracy: 0.7729 - val_loss: 0.4357 - val_accuracy: 0.7759
# Epoch 112/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4407 - accuracy: 0.7726 - val_loss: 0.4361 - val_accuracy: 0.7748
# Epoch 113/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4406 - accuracy: 0.7731 - val_loss: 0.4401 - val_accuracy: 0.7751
# Epoch 114/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4404 - accuracy: 0.7732 - val_loss: 0.4426 - val_accuracy: 0.7732
# Epoch 115/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4402 - accuracy: 0.7731 - val_loss: 0.4448 - val_accuracy: 0.7723
# Epoch 116/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4400 - accuracy: 0.7736 - val_loss: 0.4417 - val_accuracy: 0.7757
# Epoch 117/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4398 - accuracy: 0.7739 - val_loss: 0.4393 - val_accuracy: 0.7741
# Epoch 118/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4397 - accuracy: 0.7735 - val_loss: 0.4363 - val_accuracy: 0.7762
# Epoch 119/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4395 - accuracy: 0.7737 - val_loss: 0.4412 - val_accuracy: 0.7728
# Epoch 120/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4391 - accuracy: 0.7739 - val_loss: 0.4362 - val_accuracy: 0.7754
# Epoch 121/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4391 - accuracy: 0.7745 - val_loss: 0.4343 - val_accuracy: 0.7763
# Epoch 122/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4387 - accuracy: 0.7742 - val_loss: 0.4365 - val_accuracy: 0.7761
# Epoch 123/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4385 - accuracy: 0.7742 - val_loss: 0.4340 - val_accuracy: 0.7762
# Epoch 124/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4383 - accuracy: 0.7748 - val_loss: 0.4343 - val_accuracy: 0.7761
# Epoch 125/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4379 - accuracy: 0.7752 - val_loss: 0.4345 - val_accuracy: 0.7762
# Epoch 126/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4375 - accuracy: 0.7753 - val_loss: 0.4339 - val_accuracy: 0.7766
# Epoch 127/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4371 - accuracy: 0.7757 - val_loss: 0.4328 - val_accuracy: 0.7769
# Epoch 128/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4370 - accuracy: 0.7761 - val_loss: 0.4335 - val_accuracy: 0.7766
# Epoch 129/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4365 - accuracy: 0.7760 - val_loss: 0.4315 - val_accuracy: 0.7764
# Epoch 130/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4363 - accuracy: 0.7762 - val_loss: 0.4433 - val_accuracy: 0.7766
# Epoch 131/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4360 - accuracy: 0.7764 - val_loss: 0.4370 - val_accuracy: 0.7770
# Epoch 132/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4358 - accuracy: 0.7763 - val_loss: 0.4406 - val_accuracy: 0.7761
# Epoch 133/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4357 - accuracy: 0.7764 - val_loss: 0.4364 - val_accuracy: 0.7776
# Epoch 134/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4355 - accuracy: 0.7764 - val_loss: 0.4391 - val_accuracy: 0.7752
# Epoch 135/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4353 - accuracy: 0.7767 - val_loss: 0.4317 - val_accuracy: 0.7777
# Epoch 136/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4351 - accuracy: 0.7766 - val_loss: 0.4338 - val_accuracy: 0.7774
# Epoch 137/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4348 - accuracy: 0.7768 - val_loss: 0.4315 - val_accuracy: 0.7778
# Epoch 138/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4348 - accuracy: 0.7770 - val_loss: 0.4367 - val_accuracy: 0.7784
# Epoch 139/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4348 - accuracy: 0.7769 - val_loss: 0.4303 - val_accuracy: 0.7780
# Epoch 140/140
# 1486/1486 [==============================] - 25s 17ms/step - loss: 0.4345 - accuracy: 0.7770 - val_loss: 0.4296 - val_accuracy: 0.7784

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 3502.736466407776

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00229003],
#        [0.00133623],
#        [0.00042221],
#        ...,
#        [0.07594746],
#        [0.07368009],
#        [0.07381287]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1440460979636061
# 0.22540907147226863
# 0.37953405376014165
# 0.290483594916902

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 74s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60350445]
# [0.8140469]
# total acc [0.77774599]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
