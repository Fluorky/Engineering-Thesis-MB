# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1f6243ad040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1f65e415040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 256)           209664
#
#  gru_1 (GRU)                 (None, 16, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=233)#, shuffle=False)
# Out:
# Epoch 1/140
# 1632/1632 [==============================] - 39s 19ms/step - loss: 0.5731 - accuracy: 0.7393 - val_loss: 0.5576 - val_accuracy: 0.7531
# Epoch 2/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.5699 - accuracy: 0.7393 - val_loss: 0.5536 - val_accuracy: 0.7531
# Epoch 3/140
# 1632/1632 [==============================] - 32s 19ms/step - loss: 0.5619 - accuracy: 0.7393 - val_loss: 0.5409 - val_accuracy: 0.7531
# Epoch 100/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4437 - accuracy: 0.7705 - val_loss: 0.4396 - val_accuracy: 0.7723
# Epoch 101/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4435 - accuracy: 0.7707 - val_loss: 0.4411 - val_accuracy: 0.7730
# Epoch 102/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4433 - accuracy: 0.7708 - val_loss: 0.4366 - val_accuracy: 0.7752
# Epoch 103/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4432 - accuracy: 0.7711 - val_loss: 0.4381 - val_accuracy: 0.7741
# Epoch 104/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4430 - accuracy: 0.7710 - val_loss: 0.4388 - val_accuracy: 0.7746
# Epoch 105/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4428 - accuracy: 0.7713 - val_loss: 0.4357 - val_accuracy: 0.7741
# Epoch 106/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4428 - accuracy: 0.7714 - val_loss: 0.4359 - val_accuracy: 0.7742
# Epoch 107/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4425 - accuracy: 0.7712 - val_loss: 0.4355 - val_accuracy: 0.7749
# Epoch 108/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4422 - accuracy: 0.7716 - val_loss: 0.4359 - val_accuracy: 0.7747
# Epoch 109/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4424 - accuracy: 0.7717 - val_loss: 0.4355 - val_accuracy: 0.7745
# Epoch 110/140
# 1632/1632 [==============================] - 30s 18ms/step - loss: 0.4420 - accuracy: 0.7718 - val_loss: 0.4358 - val_accuracy: 0.7754
# Epoch 111/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4418 - accuracy: 0.7720 - val_loss: 0.4393 - val_accuracy: 0.7743
# Epoch 112/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4418 - accuracy: 0.7721 - val_loss: 0.4370 - val_accuracy: 0.7748
# Epoch 113/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4418 - accuracy: 0.7720 - val_loss: 0.4393 - val_accuracy: 0.7725
# Epoch 114/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4416 - accuracy: 0.7724 - val_loss: 0.4353 - val_accuracy: 0.7757
# Epoch 115/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4413 - accuracy: 0.7723 - val_loss: 0.4350 - val_accuracy: 0.7749
# Epoch 116/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4412 - accuracy: 0.7725 - val_loss: 0.4372 - val_accuracy: 0.7751
# Epoch 117/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4412 - accuracy: 0.7726 - val_loss: 0.4361 - val_accuracy: 0.7745
# Epoch 118/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4409 - accuracy: 0.7728 - val_loss: 0.4345 - val_accuracy: 0.7763
# 1632/1632 [==============================] - 35s 21ms/step - loss: 0.4389 - accuracy: 0.7742 - val_loss: 0.4340 - val_accuracy: 0.7763
# Epoch 139/140
# 1632/1632 [==============================] - 33s 20ms/step - loss: 0.4387 - accuracy: 0.7748 - val_loss: 0.4366 - val_accuracy: 0.7776
# Epoch 140/140
# 1632/1632 [==============================] - 32s 20ms/step - loss: 0.4387 - accuracy: 0.7742 - val_loss: 0.4379 - val_accuracy: 0.7746

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 21s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 4339.936662197113

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00278039],
#        [0.00216841],
#        [0.00079722],
#        ...,
#        [0.08574321],
#        [0.0826963 ],
#        [0.08369596]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14694532915692798
# 0.2098187971517581
# 0.383334487304401
# 0.30102475384097077

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 107s 7ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.57333956]
# [0.8267494]
# total acc [0.77310491]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
print("204 to podzielnik 380256")
# Out:
# 204 to podzielnik 380256
