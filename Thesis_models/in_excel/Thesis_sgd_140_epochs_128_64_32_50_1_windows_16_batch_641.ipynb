# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x17736505040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1777057e040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=64)#, shuffle=False)
# Out:
# Epoch 1/140
# 5942/5942 [==============================] - 115s 18ms/step - loss: 0.5614 - accuracy: 0.7385 - val_loss: 0.5178 - val_accuracy: 0.7526
# Epoch 2/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.5095 - accuracy: 0.7385 - val_loss: 0.4873 - val_accuracy: 0.7527
# Epoch 3/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.5008 - accuracy: 0.7376 - val_loss: 0.4861 - val_accuracy: 0.7531
# Epoch 4/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.4976 - accuracy: 0.7393 - val_loss: 0.4799 - val_accuracy: 0.7529
# Epoch 5/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4930 - accuracy: 0.7431 - val_loss: 0.4762 - val_accuracy: 0.7551
# Epoch 6/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4854 - accuracy: 0.7473 - val_loss: 0.4730 - val_accuracy: 0.7510
# Epoch 7/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4770 - accuracy: 0.7509 - val_loss: 0.4657 - val_accuracy: 0.7568
# Epoch 8/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4720 - accuracy: 0.7527 - val_loss: 0.4637 - val_accuracy: 0.7566
# Epoch 9/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4688 - accuracy: 0.7541 - val_loss: 0.4617 - val_accuracy: 0.7578
# Epoch 10/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4665 - accuracy: 0.7545 - val_loss: 0.4575 - val_accuracy: 0.7606
# Epoch 11/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4644 - accuracy: 0.7558 - val_loss: 0.4541 - val_accuracy: 0.7603
# Epoch 12/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4626 - accuracy: 0.7565 - val_loss: 0.4582 - val_accuracy: 0.7597
# Epoch 13/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4612 - accuracy: 0.7574 - val_loss: 0.4534 - val_accuracy: 0.7631
# Epoch 14/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4598 - accuracy: 0.7583 - val_loss: 0.4508 - val_accuracy: 0.7633
# Epoch 15/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4581 - accuracy: 0.7594 - val_loss: 0.4553 - val_accuracy: 0.7637
# Epoch 16/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4569 - accuracy: 0.7605 - val_loss: 0.4483 - val_accuracy: 0.7672
# Epoch 17/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4551 - accuracy: 0.7622 - val_loss: 0.4461 - val_accuracy: 0.7685
# Epoch 18/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4534 - accuracy: 0.7640 - val_loss: 0.4469 - val_accuracy: 0.7661
# Epoch 19/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4521 - accuracy: 0.7652 - val_loss: 0.4434 - val_accuracy: 0.7699
# Epoch 20/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4506 - accuracy: 0.7655 - val_loss: 0.4401 - val_accuracy: 0.7721
# Epoch 21/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4494 - accuracy: 0.7671 - val_loss: 0.4448 - val_accuracy: 0.7715
# Epoch 22/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4484 - accuracy: 0.7678 - val_loss: 0.4384 - val_accuracy: 0.7731
# Epoch 23/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4472 - accuracy: 0.7685 - val_loss: 0.4372 - val_accuracy: 0.7738
# Epoch 24/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4463 - accuracy: 0.7696 - val_loss: 0.4562 - val_accuracy: 0.7731
# Epoch 25/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4456 - accuracy: 0.7697 - val_loss: 0.4388 - val_accuracy: 0.7725
# Epoch 26/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4449 - accuracy: 0.7706 - val_loss: 0.4398 - val_accuracy: 0.7749
# Epoch 27/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4442 - accuracy: 0.7711 - val_loss: 0.4376 - val_accuracy: 0.7746
# Epoch 28/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4436 - accuracy: 0.7713 - val_loss: 0.4400 - val_accuracy: 0.7713
# Epoch 29/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4431 - accuracy: 0.7719 - val_loss: 0.4382 - val_accuracy: 0.7764
# Epoch 30/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4426 - accuracy: 0.7725 - val_loss: 0.4364 - val_accuracy: 0.7741
# Epoch 31/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4422 - accuracy: 0.7725 - val_loss: 0.4378 - val_accuracy: 0.7745
# Epoch 32/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4417 - accuracy: 0.7730 - val_loss: 0.4372 - val_accuracy: 0.7766
# Epoch 33/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4413 - accuracy: 0.7734 - val_loss: 0.4349 - val_accuracy: 0.7758
# Epoch 34/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4407 - accuracy: 0.7733 - val_loss: 0.4347 - val_accuracy: 0.7751
# Epoch 35/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4406 - accuracy: 0.7739 - val_loss: 0.4347 - val_accuracy: 0.7770
# Epoch 36/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4400 - accuracy: 0.7742 - val_loss: 0.4381 - val_accuracy: 0.7767
# Epoch 37/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4398 - accuracy: 0.7743 - val_loss: 0.4332 - val_accuracy: 0.7757
# Epoch 38/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4393 - accuracy: 0.7743 - val_loss: 0.4365 - val_accuracy: 0.7756
# Epoch 39/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4386 - accuracy: 0.7745 - val_loss: 0.4319 - val_accuracy: 0.7778
# Epoch 40/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4381 - accuracy: 0.7750 - val_loss: 0.4360 - val_accuracy: 0.7775
# Epoch 41/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4373 - accuracy: 0.7761 - val_loss: 0.4365 - val_accuracy: 0.7756
# Epoch 42/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4362 - accuracy: 0.7764 - val_loss: 0.4292 - val_accuracy: 0.7799
# Epoch 43/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4355 - accuracy: 0.7767 - val_loss: 0.4335 - val_accuracy: 0.7792
# Epoch 44/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4351 - accuracy: 0.7773 - val_loss: 0.4379 - val_accuracy: 0.7784
# Epoch 45/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4346 - accuracy: 0.7778 - val_loss: 0.4322 - val_accuracy: 0.7789
# Epoch 46/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4340 - accuracy: 0.7774 - val_loss: 0.4345 - val_accuracy: 0.7763
# Epoch 47/140
# 5942/5942 [==============================] - 94s 16ms/step - loss: 0.4336 - accuracy: 0.7778 - val_loss: 0.4283 - val_accuracy: 0.7787
# Epoch 48/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4332 - accuracy: 0.7777 - val_loss: 0.4302 - val_accuracy: 0.7798
# Epoch 49/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4331 - accuracy: 0.7779 - val_loss: 0.4288 - val_accuracy: 0.7798
# Epoch 50/140
# 5942/5942 [==============================] - 94s 16ms/step - loss: 0.4326 - accuracy: 0.7788 - val_loss: 0.4291 - val_accuracy: 0.7798
# Epoch 51/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4322 - accuracy: 0.7784 - val_loss: 0.4363 - val_accuracy: 0.7799
# Epoch 52/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4318 - accuracy: 0.7785 - val_loss: 0.4299 - val_accuracy: 0.7791
# Epoch 53/140
# 5942/5942 [==============================] - 94s 16ms/step - loss: 0.4315 - accuracy: 0.7789 - val_loss: 0.4296 - val_accuracy: 0.7806
# Epoch 54/140
# 5942/5942 [==============================] - 94s 16ms/step - loss: 0.4312 - accuracy: 0.7790 - val_loss: 0.4277 - val_accuracy: 0.7810
# Epoch 55/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4310 - accuracy: 0.7787 - val_loss: 0.4293 - val_accuracy: 0.7815
# Epoch 56/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4308 - accuracy: 0.7791 - val_loss: 0.4292 - val_accuracy: 0.7789
# Epoch 57/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4305 - accuracy: 0.7791 - val_loss: 0.4300 - val_accuracy: 0.7809
# Epoch 58/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4301 - accuracy: 0.7796 - val_loss: 0.4273 - val_accuracy: 0.7814
# Epoch 59/140
# 5942/5942 [==============================] - 104s 18ms/step - loss: 0.4299 - accuracy: 0.7799 - val_loss: 0.4283 - val_accuracy: 0.7810
# Epoch 60/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4297 - accuracy: 0.7800 - val_loss: 0.4295 - val_accuracy: 0.7821
# Epoch 61/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4294 - accuracy: 0.7798 - val_loss: 0.4283 - val_accuracy: 0.7821
# Epoch 62/140
# 5942/5942 [==============================] - 104s 17ms/step - loss: 0.4291 - accuracy: 0.7801 - val_loss: 0.4294 - val_accuracy: 0.7780
# Epoch 63/140
# 5942/5942 [==============================] - 106s 18ms/step - loss: 0.4290 - accuracy: 0.7803 - val_loss: 0.4272 - val_accuracy: 0.7811
# Epoch 64/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.4287 - accuracy: 0.7803 - val_loss: 0.4250 - val_accuracy: 0.7829
# Epoch 65/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.4285 - accuracy: 0.7809 - val_loss: 0.4303 - val_accuracy: 0.7827
# Epoch 66/140
# 5942/5942 [==============================] - 104s 18ms/step - loss: 0.4281 - accuracy: 0.7806 - val_loss: 0.4383 - val_accuracy: 0.7806
# Epoch 67/140
# 5942/5942 [==============================] - 103s 17ms/step - loss: 0.4280 - accuracy: 0.7806 - val_loss: 0.4268 - val_accuracy: 0.7819
# Epoch 68/140
# 5942/5942 [==============================] - 103s 17ms/step - loss: 0.4277 - accuracy: 0.7812 - val_loss: 0.4324 - val_accuracy: 0.7818
# Epoch 69/140
# 5942/5942 [==============================] - 103s 17ms/step - loss: 0.4275 - accuracy: 0.7814 - val_loss: 0.4304 - val_accuracy: 0.7830
# Epoch 70/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.4274 - accuracy: 0.7812 - val_loss: 0.4253 - val_accuracy: 0.7828
# Epoch 71/140
# 5942/5942 [==============================] - 103s 17ms/step - loss: 0.4271 - accuracy: 0.7813 - val_loss: 0.4278 - val_accuracy: 0.7828
# Epoch 72/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.4269 - accuracy: 0.7817 - val_loss: 0.4278 - val_accuracy: 0.7823
# Epoch 73/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4268 - accuracy: 0.7817 - val_loss: 0.4249 - val_accuracy: 0.7826
# Epoch 74/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4264 - accuracy: 0.7817 - val_loss: 0.4276 - val_accuracy: 0.7825
# Epoch 75/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4262 - accuracy: 0.7817 - val_loss: 0.4233 - val_accuracy: 0.7838
# Epoch 76/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4260 - accuracy: 0.7814 - val_loss: 0.4293 - val_accuracy: 0.7826
# Epoch 77/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4259 - accuracy: 0.7818 - val_loss: 0.4250 - val_accuracy: 0.7841
# Epoch 78/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4256 - accuracy: 0.7819 - val_loss: 0.4294 - val_accuracy: 0.7795
# Epoch 79/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4254 - accuracy: 0.7822 - val_loss: 0.4274 - val_accuracy: 0.7835
# Epoch 80/140
# 5942/5942 [==============================] - 94s 16ms/step - loss: 0.4252 - accuracy: 0.7821 - val_loss: 0.4276 - val_accuracy: 0.7839
# Epoch 81/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4250 - accuracy: 0.7821 - val_loss: 0.4240 - val_accuracy: 0.7841
# Epoch 82/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4247 - accuracy: 0.7825 - val_loss: 0.4270 - val_accuracy: 0.7800
# Epoch 83/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4245 - accuracy: 0.7824 - val_loss: 0.4307 - val_accuracy: 0.7783
# Epoch 84/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4245 - accuracy: 0.7826 - val_loss: 0.4276 - val_accuracy: 0.7807
# Epoch 85/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4241 - accuracy: 0.7825 - val_loss: 0.4257 - val_accuracy: 0.7830
# Epoch 86/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4238 - accuracy: 0.7830 - val_loss: 0.4281 - val_accuracy: 0.7816
# Epoch 87/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4237 - accuracy: 0.7828 - val_loss: 0.4279 - val_accuracy: 0.7795
# Epoch 88/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4236 - accuracy: 0.7828 - val_loss: 0.4268 - val_accuracy: 0.7807
# Epoch 89/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4234 - accuracy: 0.7830 - val_loss: 0.4234 - val_accuracy: 0.7845
# Epoch 90/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4230 - accuracy: 0.7831 - val_loss: 0.4276 - val_accuracy: 0.7831
# Epoch 91/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4229 - accuracy: 0.7835 - val_loss: 0.4248 - val_accuracy: 0.7826
# Epoch 92/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4228 - accuracy: 0.7831 - val_loss: 0.4246 - val_accuracy: 0.7849
# Epoch 93/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4225 - accuracy: 0.7836 - val_loss: 0.4256 - val_accuracy: 0.7841
# Epoch 94/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4224 - accuracy: 0.7835 - val_loss: 0.4247 - val_accuracy: 0.7836
# Epoch 95/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4221 - accuracy: 0.7837 - val_loss: 0.4242 - val_accuracy: 0.7847
# Epoch 96/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4220 - accuracy: 0.7840 - val_loss: 0.4271 - val_accuracy: 0.7829
# Epoch 97/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4218 - accuracy: 0.7839 - val_loss: 0.4271 - val_accuracy: 0.7848
# Epoch 98/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4217 - accuracy: 0.7843 - val_loss: 0.4365 - val_accuracy: 0.7850
# Epoch 99/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4215 - accuracy: 0.7838 - val_loss: 0.4265 - val_accuracy: 0.7832
# Epoch 100/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4212 - accuracy: 0.7841 - val_loss: 0.4283 - val_accuracy: 0.7827
# Epoch 101/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4211 - accuracy: 0.7838 - val_loss: 0.4279 - val_accuracy: 0.7843
# Epoch 102/140
# 5942/5942 [==============================] - 94s 16ms/step - loss: 0.4209 - accuracy: 0.7845 - val_loss: 0.4291 - val_accuracy: 0.7850
# Epoch 103/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4208 - accuracy: 0.7842 - val_loss: 0.4335 - val_accuracy: 0.7839
# Epoch 104/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4205 - accuracy: 0.7846 - val_loss: 0.4264 - val_accuracy: 0.7848
# Epoch 105/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4204 - accuracy: 0.7843 - val_loss: 0.4269 - val_accuracy: 0.7830
# Epoch 106/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4203 - accuracy: 0.7843 - val_loss: 0.4282 - val_accuracy: 0.7813
# Epoch 107/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4201 - accuracy: 0.7846 - val_loss: 0.4281 - val_accuracy: 0.7797
# Epoch 108/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4199 - accuracy: 0.7844 - val_loss: 0.4285 - val_accuracy: 0.7840
# Epoch 109/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4197 - accuracy: 0.7844 - val_loss: 0.4296 - val_accuracy: 0.7838
# Epoch 110/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4197 - accuracy: 0.7847 - val_loss: 0.4273 - val_accuracy: 0.7821
# Epoch 111/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4194 - accuracy: 0.7846 - val_loss: 0.4276 - val_accuracy: 0.7794
# Epoch 112/140
# 5942/5942 [==============================] - 96s 16ms/step - loss: 0.4192 - accuracy: 0.7849 - val_loss: 0.4272 - val_accuracy: 0.7807
# Epoch 113/140
# 5942/5942 [==============================] - 98s 17ms/step - loss: 0.4189 - accuracy: 0.7849 - val_loss: 0.4266 - val_accuracy: 0.7819
# Epoch 114/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4189 - accuracy: 0.7850 - val_loss: 0.4258 - val_accuracy: 0.7800
# Epoch 115/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4186 - accuracy: 0.7851 - val_loss: 0.4258 - val_accuracy: 0.7842
# Epoch 116/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4186 - accuracy: 0.7850 - val_loss: 0.4315 - val_accuracy: 0.7786
# Epoch 117/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4183 - accuracy: 0.7851 - val_loss: 0.4331 - val_accuracy: 0.7845
# Epoch 118/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4182 - accuracy: 0.7852 - val_loss: 0.4259 - val_accuracy: 0.7817
# Epoch 119/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4180 - accuracy: 0.7856 - val_loss: 0.4297 - val_accuracy: 0.7820
# Epoch 120/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4180 - accuracy: 0.7854 - val_loss: 0.4262 - val_accuracy: 0.7844
# Epoch 121/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4178 - accuracy: 0.7856 - val_loss: 0.4251 - val_accuracy: 0.7854
# Epoch 122/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4176 - accuracy: 0.7859 - val_loss: 0.4270 - val_accuracy: 0.7796
# Epoch 123/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4174 - accuracy: 0.7860 - val_loss: 0.4246 - val_accuracy: 0.7847
# Epoch 124/140
# 5942/5942 [==============================] - 94s 16ms/step - loss: 0.4174 - accuracy: 0.7858 - val_loss: 0.4242 - val_accuracy: 0.7830
# Epoch 125/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4170 - accuracy: 0.7860 - val_loss: 0.4285 - val_accuracy: 0.7832
# Epoch 126/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4169 - accuracy: 0.7859 - val_loss: 0.4326 - val_accuracy: 0.7842
# Epoch 127/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4169 - accuracy: 0.7861 - val_loss: 0.4278 - val_accuracy: 0.7829
# Epoch 128/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4167 - accuracy: 0.7864 - val_loss: 0.4240 - val_accuracy: 0.7847
# Epoch 129/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4166 - accuracy: 0.7860 - val_loss: 0.4228 - val_accuracy: 0.7838
# Epoch 130/140
# 5942/5942 [==============================] - 95s 16ms/step - loss: 0.4163 - accuracy: 0.7862 - val_loss: 0.4273 - val_accuracy: 0.7854
# Epoch 131/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4163 - accuracy: 0.7865 - val_loss: 0.4234 - val_accuracy: 0.7833
# Epoch 132/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4160 - accuracy: 0.7866 - val_loss: 0.4385 - val_accuracy: 0.7805
# Epoch 133/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4158 - accuracy: 0.7865 - val_loss: 0.4322 - val_accuracy: 0.7846
# Epoch 134/140
# 5942/5942 [==============================] - 94s 16ms/step - loss: 0.4158 - accuracy: 0.7864 - val_loss: 0.4338 - val_accuracy: 0.7837
# Epoch 135/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4156 - accuracy: 0.7868 - val_loss: 0.4285 - val_accuracy: 0.7809
# Epoch 136/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4155 - accuracy: 0.7868 - val_loss: 0.4288 - val_accuracy: 0.7849
# Epoch 137/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4154 - accuracy: 0.7866 - val_loss: 0.4262 - val_accuracy: 0.7822
# Epoch 138/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4153 - accuracy: 0.7865 - val_loss: 0.4365 - val_accuracy: 0.7829
# Epoch 139/140
# 5942/5942 [==============================] - 94s 16ms/step - loss: 0.4152 - accuracy: 0.7868 - val_loss: 0.4237 - val_accuracy: 0.7851
# Epoch 140/140
# 5942/5942 [==============================] - 93s 16ms/step - loss: 0.4149 - accuracy: 0.7873 - val_loss: 0.4226 - val_accuracy: 0.7846

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 13346.483330011368

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00241968],
#        [0.00211671],
#        [0.00024257],
#        ...,
#        [0.06947581],
#        [0.07303138],
#        [0.07600606]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14130162082368355
# 0.24016717409489463
# 0.375901078508274
# 0.28125525365850096

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 73s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.6173657]
# [0.82757965]
# total acc [0.7871733]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
