# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1e9604dc040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1e9d4592040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2]),activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True,activation='relu'),
    keras.layers.GRU(units=64,activation='relu'),
    keras.layers.Dense(units=32,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='MeanSquaredError', optimizer='sgd',metrics=['AUC'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           209664
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 397,249
# Trainable params: 397,249
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 1371s 459ms/step - loss: 0.1976 - auc: 0.5232 - val_loss: 0.1859 - val_auc: 0.5726
# Epoch 2/140
# 2971/2971 [==============================] - 1361s 458ms/step - loss: 0.1923 - auc: 0.5783 - val_loss: 0.1857 - val_auc: 0.6218
# Epoch 3/140
# 2971/2971 [==============================] - 1349s 454ms/step - loss: 0.1920 - auc: 0.6191 - val_loss: 0.1853 - val_auc: 0.6485
# Epoch 4/140
# 2971/2971 [==============================] - 1421s 478ms/step - loss: 0.1915 - auc: 0.6395 - val_loss: 0.1847 - val_auc: 0.6598
# Epoch 5/140
# 2971/2971 [==============================] - 1351s 455ms/step - loss: 0.1907 - auc: 0.6623 - val_loss: 0.1838 - val_auc: 0.6718
# Epoch 6/140
# 2971/2971 [==============================] - 1356s 456ms/step - loss: 0.1893 - auc: 0.6725 - val_loss: 0.1820 - val_auc: 0.6776
# Epoch 7/140
# 2971/2971 [==============================] - 1352s 455ms/step - loss: 0.1862 - auc: 0.6796 - val_loss: 0.1783 - val_auc: 0.6840
# Epoch 8/140
# 2971/2971 [==============================] - 1353s 455ms/step - loss: 0.1811 - auc: 0.6886 - val_loss: 0.1732 - val_auc: 0.6962
# Epoch 9/140
# 2971/2971 [==============================] - 1353s 456ms/step - loss: 0.1763 - auc: 0.7037 - val_loss: 0.1688 - val_auc: 0.7146
# Epoch 10/140
# 2971/2971 [==============================] - 1353s 456ms/step - loss: 0.1721 - auc: 0.7219 - val_loss: 0.1655 - val_auc: 0.7313
# Epoch 11/140
# 2971/2971 [==============================] - 1354s 456ms/step - loss: 0.1694 - auc: 0.7320 - val_loss: 0.1640 - val_auc: 0.7364
# Epoch 12/140
# 2971/2971 [==============================] - 1356s 457ms/step - loss: 0.1684 - auc: 0.7350 - val_loss: 0.1629 - val_auc: 0.7382
# Epoch 13/140
# 2971/2971 [==============================] - 1357s 457ms/step - loss: 0.1679 - auc: 0.7373 - val_loss: 0.1624 - val_auc: 0.7394
# Epoch 14/140
# 2971/2971 [==============================] - 1364s 459ms/step - loss: 0.1673 - auc: 0.7399 - val_loss: 0.1630 - val_auc: 0.7410
# Epoch 15/140
# 2971/2971 [==============================] - 1357s 457ms/step - loss: 0.1666 - auc: 0.7429 - val_loss: 0.1617 - val_auc: 0.7437
# Epoch 16/140
# 2971/2971 [==============================] - 1360s 458ms/step - loss: 0.1658 - auc: 0.7462 - val_loss: 0.1611 - val_auc: 0.7460
# Epoch 17/140
# 2971/2971 [==============================] - 1362s 458ms/step - loss: 0.1649 - auc: 0.7500 - val_loss: 0.1609 - val_auc: 0.7485
# Epoch 18/140
# 2971/2971 [==============================] - 1363s 459ms/step - loss: 0.1639 - auc: 0.7542 - val_loss: 0.1605 - val_auc: 0.7512
# Epoch 19/140
# 2971/2971 [==============================] - 1363s 459ms/step - loss: 0.1627 - auc: 0.7590 - val_loss: 0.1594 - val_auc: 0.7546
# Epoch 20/140
# 2971/2971 [==============================] - 1363s 459ms/step - loss: 0.1616 - auc: 0.7634 - val_loss: 0.1596 - val_auc: 0.7564
# Epoch 21/140
# 2971/2971 [==============================] - 1364s 459ms/step - loss: 0.1604 - auc: 0.7680 - val_loss: 0.1593 - val_auc: 0.7622
# Epoch 22/140
# 2971/2971 [==============================] - 1367s 460ms/step - loss: 0.1594 - auc: 0.7720 - val_loss: 0.1577 - val_auc: 0.7653
# Epoch 23/140
# 2971/2971 [==============================] - 1366s 460ms/step - loss: 0.1586 - auc: 0.7753 - val_loss: 0.1559 - val_auc: 0.7698
# Epoch 24/140
# 2971/2971 [==============================] - 1369s 461ms/step - loss: 0.1578 - auc: 0.7782 - val_loss: 0.1552 - val_auc: 0.7733
# Epoch 25/140
# 2971/2971 [==============================] - 1374s 462ms/step - loss: 0.1571 - auc: 0.7806 - val_loss: 0.1538 - val_auc: 0.7770
# Epoch 26/140
# 2971/2971 [==============================] - 1370s 461ms/step - loss: 0.1565 - auc: 0.7832 - val_loss: 0.1547 - val_auc: 0.7797
# Epoch 27/140
# 2971/2971 [==============================] - 1372s 462ms/step - loss: 0.1559 - auc: 0.7850 - val_loss: 0.1531 - val_auc: 0.7803
# Epoch 28/140
# 2971/2971 [==============================] - 1375s 463ms/step - loss: 0.1554 - auc: 0.7868 - val_loss: 0.1537 - val_auc: 0.7839
# Epoch 29/140
# 2971/2971 [==============================] - 1381s 465ms/step - loss: 0.1549 - auc: 0.7886 - val_loss: 0.1565 - val_auc: 0.7814
# Epoch 30/140
# 2971/2971 [==============================] - 1379s 464ms/step - loss: 0.1544 - auc: 0.7901 - val_loss: 0.1530 - val_auc: 0.7876
# Epoch 31/140
# 2971/2971 [==============================] - 1375s 463ms/step - loss: 0.1539 - auc: 0.7919 - val_loss: 0.1525 - val_auc: 0.7890
# Epoch 32/140
# 2971/2971 [==============================] - 1376s 463ms/step - loss: 0.1536 - auc: 0.7930 - val_loss: 0.1508 - val_auc: 0.7905
# Epoch 33/140
# 2971/2971 [==============================] - 1377s 464ms/step - loss: 0.1533 - auc: 0.7938 - val_loss: 0.1503 - val_auc: 0.7916
# Epoch 34/140
# 2971/2971 [==============================] - 1378s 464ms/step - loss: 0.1530 - auc: 0.7949 - val_loss: 0.1545 - val_auc: 0.7879
# Epoch 35/140
# 2971/2971 [==============================] - 1387s 467ms/step - loss: 0.1527 - auc: 0.7960 - val_loss: 0.1500 - val_auc: 0.7919
# Epoch 36/140
# 2971/2971 [==============================] - 1429s 481ms/step - loss: 0.1524 - auc: 0.7968 - val_loss: 0.1513 - val_auc: 0.7872
# Epoch 37/140
# 2971/2971 [==============================] - 1445s 486ms/step - loss: 0.1521 - auc: 0.7979 - val_loss: 0.1492 - val_auc: 0.7953
# Epoch 38/140
# 2971/2971 [==============================] - 1445s 486ms/step - loss: 0.1519 - auc: 0.7988 - val_loss: 0.1592 - val_auc: 0.7919
# Epoch 39/140
# 2971/2971 [==============================] - 1446s 487ms/step - loss: 0.1517 - auc: 0.7992 - val_loss: 0.1520 - val_auc: 0.7911
# Epoch 40/140
# 2971/2971 [==============================] - 1418s 477ms/step - loss: 0.1513 - auc: 0.8005 - val_loss: 0.1485 - val_auc: 0.7969
# Epoch 41/140
# 2971/2971 [==============================] - 1386s 466ms/step - loss: 0.1512 - auc: 0.8009 - val_loss: 0.1492 - val_auc: 0.7966
# Epoch 42/140
# 2971/2971 [==============================] - 1392s 468ms/step - loss: 0.1510 - auc: 0.8017 - val_loss: 0.1482 - val_auc: 0.7982
# Epoch 43/140
# 2971/2971 [==============================] - 1389s 467ms/step - loss: 0.1509 - auc: 0.8021 - val_loss: 0.1493 - val_auc: 0.7982
# Epoch 44/140
# 2971/2971 [==============================] - 1389s 468ms/step - loss: 0.1506 - auc: 0.8030 - val_loss: 0.1485 - val_auc: 0.7971
# Epoch 45/140
# 2971/2971 [==============================] - 1394s 469ms/step - loss: 0.1504 - auc: 0.8036 - val_loss: 0.1485 - val_auc: 0.7984
# Epoch 46/140
# 2971/2971 [==============================] - 1393s 469ms/step - loss: 0.1502 - auc: 0.8044 - val_loss: 0.1505 - val_auc: 0.7972
# Epoch 47/140
# 2971/2971 [==============================] - 1395s 470ms/step - loss: 0.1501 - auc: 0.8048 - val_loss: 0.1479 - val_auc: 0.7993
# Epoch 48/140
# 2971/2971 [==============================] - 1396s 470ms/step - loss: 0.1498 - auc: 0.8055 - val_loss: 0.1480 - val_auc: 0.7999
# Epoch 49/140
# 2971/2971 [==============================] - 1415s 476ms/step - loss: 0.1497 - auc: 0.8060 - val_loss: 0.1484 - val_auc: 0.7993
# Epoch 50/140
# 2971/2971 [==============================] - 1398s 470ms/step - loss: 0.1495 - auc: 0.8067 - val_loss: 0.1469 - val_auc: 0.8020
# Epoch 51/140
# 2971/2971 [==============================] - 1402s 472ms/step - loss: 0.1494 - auc: 0.8069 - val_loss: 0.1488 - val_auc: 0.8001
# Epoch 52/140
# 2971/2971 [==============================] - 1402s 472ms/step - loss: 0.1492 - auc: 0.8076 - val_loss: 0.1477 - val_auc: 0.8031
# Epoch 53/140
# 2971/2971 [==============================] - 1400s 471ms/step - loss: 0.1490 - auc: 0.8083 - val_loss: 0.1490 - val_auc: 0.7965
# Epoch 54/140
# 2971/2971 [==============================] - 1400s 471ms/step - loss: 0.1489 - auc: 0.8086 - val_loss: 0.1469 - val_auc: 0.8033
# Epoch 55/140
# 2971/2971 [==============================] - 1401s 472ms/step - loss: 0.1487 - auc: 0.8092 - val_loss: 0.1467 - val_auc: 0.8031
# Epoch 56/140
# 2971/2971 [==============================] - 1411s 475ms/step - loss: 0.1486 - auc: 0.8097 - val_loss: 0.1481 - val_auc: 0.8005
# Epoch 57/140
# 2971/2971 [==============================] - 1411s 475ms/step - loss: 0.1485 - auc: 0.8100 - val_loss: 0.1481 - val_auc: 0.7998
# Epoch 58/140
# 2971/2971 [==============================] - 1412s 475ms/step - loss: 0.1483 - auc: 0.8104 - val_loss: 0.1465 - val_auc: 0.8052
# Epoch 59/140
# 2971/2971 [==============================] - 1430s 481ms/step - loss: 0.1483 - auc: 0.8107 - val_loss: 0.1468 - val_auc: 0.8055
# Epoch 60/140
# 2971/2971 [==============================] - 1421s 478ms/step - loss: 0.1481 - auc: 0.8113 - val_loss: 0.1485 - val_auc: 0.7999
# Epoch 61/140
# 2971/2971 [==============================] - 1424s 479ms/step - loss: 0.1478 - auc: 0.8121 - val_loss: 0.1467 - val_auc: 0.8055
# Epoch 62/140
# 2971/2971 [==============================] - 1431s 482ms/step - loss: 0.1478 - auc: 0.8121 - val_loss: 0.1459 - val_auc: 0.8056
# Epoch 63/140
# 2971/2971 [==============================] - 1424s 479ms/step - loss: 0.1476 - auc: 0.8127 - val_loss: 0.1462 - val_auc: 0.8052
# Epoch 64/140
# 2971/2971 [==============================] - 1430s 481ms/step - loss: 0.1476 - auc: 0.8129 - val_loss: 0.1457 - val_auc: 0.8067
# Epoch 65/140
# 2971/2971 [==============================] - 1435s 483ms/step - loss: 0.1474 - auc: 0.8135 - val_loss: 0.1483 - val_auc: 0.8061
# Epoch 66/140
# 2971/2971 [==============================] - 1428s 481ms/step - loss: 0.1473 - auc: 0.8137 - val_loss: 0.1469 - val_auc: 0.8056
# Epoch 67/140
# 2971/2971 [==============================] - 1428s 481ms/step - loss: 0.1471 - auc: 0.8143 - val_loss: 0.1456 - val_auc: 0.8069
# Epoch 68/140
# 2971/2971 [==============================] - 1442s 485ms/step - loss: 0.1470 - auc: 0.8146 - val_loss: 0.1460 - val_auc: 0.8065
# Epoch 69/140
# 2971/2971 [==============================] - 1442s 485ms/step - loss: 0.1470 - auc: 0.8147 - val_loss: 0.1476 - val_auc: 0.8086
# Epoch 70/140
# 2971/2971 [==============================] - 1438s 484ms/step - loss: 0.1468 - auc: 0.8152 - val_loss: 0.1483 - val_auc: 0.7986
# Epoch 71/140
# 2971/2971 [==============================] - 1438s 484ms/step - loss: 0.1468 - auc: 0.8154 - val_loss: 0.1484 - val_auc: 0.8086
# Epoch 72/140
# 2971/2971 [==============================] - 1446s 487ms/step - loss: 0.1466 - auc: 0.8159 - val_loss: 0.1471 - val_auc: 0.8061
# Epoch 73/140
# 2971/2971 [==============================] - 1469s 495ms/step - loss: 0.1465 - auc: 0.8163 - val_loss: 0.1454 - val_auc: 0.8083
# Epoch 74/140
# 2971/2971 [==============================] - 1488s 501ms/step - loss: 0.1465 - auc: 0.8163 - val_loss: 0.1464 - val_auc: 0.8106
# Epoch 75/140
# 2971/2971 [==============================] - 1510s 508ms/step - loss: 0.1463 - auc: 0.8170 - val_loss: 0.1469 - val_auc: 0.8085
# Epoch 76/140
# 2971/2971 [==============================] - 1495s 503ms/step - loss: 0.1462 - auc: 0.8171 - val_loss: 0.1477 - val_auc: 0.8096
# Epoch 77/140
# 2971/2971 [==============================] - 1499s 504ms/step - loss: 0.1460 - auc: 0.8176 - val_loss: 0.1447 - val_auc: 0.8109
# Epoch 78/140
# 2971/2971 [==============================] - 1503s 506ms/step - loss: 0.1460 - auc: 0.8178 - val_loss: 0.1443 - val_auc: 0.8114
# Epoch 79/140
# 2971/2971 [==============================] - 1513s 509ms/step - loss: 0.1459 - auc: 0.8182 - val_loss: 0.1443 - val_auc: 0.8114
# Epoch 80/140
# 2971/2971 [==============================] - 1504s 506ms/step - loss: 0.1457 - auc: 0.8187 - val_loss: 0.1444 - val_auc: 0.8117
# Epoch 81/140
# 2971/2971 [==============================] - 1510s 508ms/step - loss: 0.1456 - auc: 0.8191 - val_loss: 0.1454 - val_auc: 0.8085
# Epoch 82/140
# 2971/2971 [==============================] - 1511s 509ms/step - loss: 0.1456 - auc: 0.8192 - val_loss: 0.1449 - val_auc: 0.8114
# Epoch 83/140
# 2971/2971 [==============================] - 1519s 511ms/step - loss: 0.1455 - auc: 0.8194 - val_loss: 0.1460 - val_auc: 0.8104
# Epoch 84/140
# 2971/2971 [==============================] - 1523s 513ms/step - loss: 0.1454 - auc: 0.8198 - val_loss: 0.1449 - val_auc: 0.8098
# Epoch 85/140
# 2971/2971 [==============================] - 1517s 511ms/step - loss: 0.1453 - auc: 0.8201 - val_loss: 0.1442 - val_auc: 0.8129
# Epoch 86/140
# 2971/2971 [==============================] - 1545s 520ms/step - loss: 0.1452 - auc: 0.8203 - val_loss: 0.1452 - val_auc: 0.8097
# Epoch 87/140
# 2971/2971 [==============================] - 1530s 515ms/step - loss: 0.1451 - auc: 0.8205 - val_loss: 0.1451 - val_auc: 0.8109
# Epoch 88/140
# 2971/2971 [==============================] - 1527s 514ms/step - loss: 0.1450 - auc: 0.8209 - val_loss: 0.1449 - val_auc: 0.8136
# Epoch 89/140
# 2971/2971 [==============================] - 1534s 516ms/step - loss: 0.1449 - auc: 0.8211 - val_loss: 0.1438 - val_auc: 0.8133
# Epoch 90/140
# 2971/2971 [==============================] - 1546s 520ms/step - loss: 0.1448 - auc: 0.8215 - val_loss: 0.1441 - val_auc: 0.8128
# Epoch 91/140
# 2971/2971 [==============================] - 1552s 522ms/step - loss: 0.1447 - auc: 0.8218 - val_loss: 0.1457 - val_auc: 0.8112
# Epoch 92/140
# 2971/2971 [==============================] - 1550s 522ms/step - loss: 0.1447 - auc: 0.8218 - val_loss: 0.1441 - val_auc: 0.8139
# Epoch 93/140
# 2971/2971 [==============================] - 1551s 522ms/step - loss: 0.1446 - auc: 0.8221 - val_loss: 0.1443 - val_auc: 0.8138
# Epoch 94/140
# 2971/2971 [==============================] - 1552s 522ms/step - loss: 0.1445 - auc: 0.8223 - val_loss: 0.1451 - val_auc: 0.8124
# Epoch 95/140
# 2971/2971 [==============================] - 1557s 524ms/step - loss: 0.1445 - auc: 0.8226 - val_loss: 0.1467 - val_auc: 0.8130
# Epoch 96/140
# 2971/2971 [==============================] - 1562s 526ms/step - loss: 0.1444 - auc: 0.8228 - val_loss: 0.1480 - val_auc: 0.8059
# Epoch 97/140
# 2971/2971 [==============================] - 1576s 530ms/step - loss: 0.1443 - auc: 0.8232 - val_loss: 0.1474 - val_auc: 0.8138
# Epoch 98/140
# 2971/2971 [==============================] - 1566s 527ms/step - loss: 0.1442 - auc: 0.8233 - val_loss: 0.1447 - val_auc: 0.8142
# Epoch 99/140
# 2971/2971 [==============================] - 1568s 528ms/step - loss: 0.1441 - auc: 0.8237 - val_loss: 0.1438 - val_auc: 0.8140
# Epoch 100/140
# 2971/2971 [==============================] - 1597s 537ms/step - loss: 0.1441 - auc: 0.8236 - val_loss: 0.1434 - val_auc: 0.8150
# Epoch 101/140
# 2971/2971 [==============================] - 1643s 553ms/step - loss: 0.1440 - auc: 0.8241 - val_loss: 0.1447 - val_auc: 0.8169
# Epoch 102/140
# 2971/2971 [==============================] - 1640s 552ms/step - loss: 0.1439 - auc: 0.8244 - val_loss: 0.1435 - val_auc: 0.8144
# Epoch 103/140
# 2971/2971 [==============================] - 1646s 554ms/step - loss: 0.1439 - auc: 0.8243 - val_loss: 0.1433 - val_auc: 0.8161
# Epoch 104/140
# 2971/2971 [==============================] - 1651s 556ms/step - loss: 0.1438 - auc: 0.8245 - val_loss: 0.1443 - val_auc: 0.8146
# Epoch 105/140
# 2971/2971 [==============================] - 1658s 558ms/step - loss: 0.1437 - auc: 0.8249 - val_loss: 0.1443 - val_auc: 0.8159
# Epoch 106/140
# 2971/2971 [==============================] - 1656s 557ms/step - loss: 0.1437 - auc: 0.8250 - val_loss: 0.1432 - val_auc: 0.8153
# Epoch 107/140
# 2971/2971 [==============================] - 1659s 558ms/step - loss: 0.1436 - auc: 0.8251 - val_loss: 0.1430 - val_auc: 0.8160
# Epoch 108/140
# 2971/2971 [==============================] - 1663s 560ms/step - loss: 0.1436 - auc: 0.8254 - val_loss: 0.1438 - val_auc: 0.8150
# Epoch 109/140
# 2971/2971 [==============================] - 1659s 559ms/step - loss: 0.1434 - auc: 0.8257 - val_loss: 0.1492 - val_auc: 0.8144
# Epoch 110/140
# 2971/2971 [==============================] - 1653s 557ms/step - loss: 0.1434 - auc: 0.8257 - val_loss: 0.1448 - val_auc: 0.8115
# Epoch 111/140
# 2971/2971 [==============================] - 1640s 552ms/step - loss: 0.1434 - auc: 0.8258 - val_loss: 0.1432 - val_auc: 0.8159
# Epoch 112/140
# 2971/2971 [==============================] - 1582s 532ms/step - loss: 0.1434 - auc: 0.8260 - val_loss: 0.1443 - val_auc: 0.8149
# Epoch 113/140
# 2971/2971 [==============================] - 1585s 534ms/step - loss: 0.1433 - auc: 0.8262 - val_loss: 0.1451 - val_auc: 0.8149
# Epoch 114/140
# 2971/2971 [==============================] - 1590s 535ms/step - loss: 0.1432 - auc: 0.8264 - val_loss: 0.1435 - val_auc: 0.8156
# Epoch 115/140
# 2971/2971 [==============================] - 1589s 535ms/step - loss: 0.1432 - auc: 0.8266 - val_loss: 0.1487 - val_auc: 0.8162
# Epoch 116/140
# 2971/2971 [==============================] - 1612s 543ms/step - loss: 0.1431 - auc: 0.8266 - val_loss: 0.1459 - val_auc: 0.8111
# Epoch 117/140
# 2971/2971 [==============================] - 1599s 538ms/step - loss: 0.1430 - auc: 0.8269 - val_loss: 0.1437 - val_auc: 0.8141
# Epoch 118/140
# 2971/2971 [==============================] - 1605s 540ms/step - loss: 0.1431 - auc: 0.8268 - val_loss: 0.1441 - val_auc: 0.8142
# Epoch 119/140
# 2971/2971 [==============================] - 1613s 543ms/step - loss: 0.1429 - auc: 0.8274 - val_loss: 0.1443 - val_auc: 0.8132
# Epoch 120/140
# 2971/2971 [==============================] - 1615s 544ms/step - loss: 0.1429 - auc: 0.8273 - val_loss: 0.1439 - val_auc: 0.8156
# Epoch 121/140
# 2971/2971 [==============================] - 1607s 541ms/step - loss: 0.1428 - auc: 0.8276 - val_loss: 0.1430 - val_auc: 0.8163
# Epoch 122/140
# 2971/2971 [==============================] - 1611s 542ms/step - loss: 0.1428 - auc: 0.8275 - val_loss: 0.1431 - val_auc: 0.8163
# Epoch 123/140
# 2971/2971 [==============================] - 1615s 544ms/step - loss: 0.1428 - auc: 0.8277 - val_loss: 0.1431 - val_auc: 0.8166
# Epoch 124/140
# 2971/2971 [==============================] - 1613s 543ms/step - loss: 0.1426 - auc: 0.8281 - val_loss: 0.1438 - val_auc: 0.8167
# Epoch 125/140
# 2971/2971 [==============================] - 1612s 543ms/step - loss: 0.1427 - auc: 0.8280 - val_loss: 0.1451 - val_auc: 0.8147
# Epoch 126/140
# 2971/2971 [==============================] - 1612s 542ms/step - loss: 0.1427 - auc: 0.8280 - val_loss: 0.1435 - val_auc: 0.8173
# Epoch 127/140
# 2971/2971 [==============================] - 1620s 545ms/step - loss: 0.1426 - auc: 0.8284 - val_loss: 0.1435 - val_auc: 0.8164
# Epoch 128/140
# 2971/2971 [==============================] - 1620s 545ms/step - loss: 0.1425 - auc: 0.8284 - val_loss: 0.1428 - val_auc: 0.8172
# Epoch 129/140
# 2971/2971 [==============================] - 1626s 547ms/step - loss: 0.1424 - auc: 0.8287 - val_loss: 0.1443 - val_auc: 0.8164
# Epoch 130/140
# 2971/2971 [==============================] - 1631s 549ms/step - loss: 0.1424 - auc: 0.8288 - val_loss: 0.1431 - val_auc: 0.8162
# Epoch 131/140
# 2971/2971 [==============================] - 1637s 551ms/step - loss: 0.1424 - auc: 0.8287 - val_loss: 0.1439 - val_auc: 0.8164
# Epoch 132/140
# 2971/2971 [==============================] - 1640s 552ms/step - loss: 0.1424 - auc: 0.8288 - val_loss: 0.1427 - val_auc: 0.8178
# Epoch 133/140
# 2971/2971 [==============================] - 1641s 552ms/step - loss: 0.1423 - auc: 0.8292 - val_loss: 0.1436 - val_auc: 0.8161
# Epoch 134/140
# 2971/2971 [==============================] - 1638s 551ms/step - loss: 0.1423 - auc: 0.8292 - val_loss: 0.1433 - val_auc: 0.8168
# Epoch 135/140
# 2971/2971 [==============================] - 1671s 562ms/step - loss: 0.1423 - auc: 0.8292 - val_loss: 0.1454 - val_auc: 0.8116
# Epoch 136/140
# 2971/2971 [==============================] - 1701s 573ms/step - loss: 0.1422 - auc: 0.8293 - val_loss: 0.1468 - val_auc: 0.8152
# Epoch 137/140
# 2971/2971 [==============================] - 1653s 556ms/step - loss: 0.1421 - auc: 0.8296 - val_loss: 0.1428 - val_auc: 0.8179
# Epoch 138/140
# 2971/2971 [==============================] - 1648s 555ms/step - loss: 0.1421 - auc: 0.8297 - val_loss: 0.1454 - val_auc: 0.8175
# Epoch 139/140
# 2971/2971 [==============================] - 1650s 555ms/step - loss: 0.1421 - auc: 0.8297 - val_loss: 0.1434 - val_auc: 0.8152
# Epoch 140/140
# 2971/2971 [==============================] - 1652s 556ms/step - loss: 0.1421 - auc: 0.8297 - val_loss: 0.1452 - val_auc: 0.8162

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 215s 72ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 208608.03220438957

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00584793],
#        [0.00792779],
#        [0.00599538],
#        ...,
#        [0.10026583],
#        [0.10041922],
#        [0.10167819]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1451938374090113
# 0.2192593163715404
# 0.38104309127579167
# 0.2940158580821818

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 1078s 73ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.57973028]
# [0.84241193]
# total acc [0.77995813]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
