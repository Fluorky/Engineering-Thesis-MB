# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x21497611040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x214d167d040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 58s 17ms/step - loss: 0.5696 - accuracy: 0.7393 - val_loss: 0.5529 - val_accuracy: 0.7531
# Epoch 2/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.5480 - accuracy: 0.7397 - val_loss: 0.5451 - val_accuracy: 0.7346
# Epoch 3/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.5191 - accuracy: 0.7422 - val_loss: 0.5187 - val_accuracy: 0.7539
# Epoch 4/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.5051 - accuracy: 0.7417 - val_loss: 0.5066 - val_accuracy: 0.7532
# Epoch 5/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.5010 - accuracy: 0.7403 - val_loss: 0.5029 - val_accuracy: 0.7531
# Epoch 6/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4991 - accuracy: 0.7398 - val_loss: 0.4997 - val_accuracy: 0.7531
# Epoch 7/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4977 - accuracy: 0.7399 - val_loss: 0.4968 - val_accuracy: 0.7531
# Epoch 8/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4965 - accuracy: 0.7400 - val_loss: 0.4942 - val_accuracy: 0.7531
# Epoch 9/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4954 - accuracy: 0.7401 - val_loss: 0.4920 - val_accuracy: 0.7531
# Epoch 10/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4942 - accuracy: 0.7405 - val_loss: 0.4898 - val_accuracy: 0.7531
# Epoch 11/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4928 - accuracy: 0.7413 - val_loss: 0.4876 - val_accuracy: 0.7531
# Epoch 12/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4909 - accuracy: 0.7426 - val_loss: 0.4852 - val_accuracy: 0.7531
# Epoch 13/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4883 - accuracy: 0.7455 - val_loss: 0.4822 - val_accuracy: 0.7540
# Epoch 14/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4846 - accuracy: 0.7493 - val_loss: 0.4796 - val_accuracy: 0.7547
# Epoch 15/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4809 - accuracy: 0.7513 - val_loss: 0.4786 - val_accuracy: 0.7543
# Epoch 16/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4779 - accuracy: 0.7520 - val_loss: 0.4776 - val_accuracy: 0.7546
# Epoch 17/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4754 - accuracy: 0.7527 - val_loss: 0.4752 - val_accuracy: 0.7553
# Epoch 18/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4733 - accuracy: 0.7535 - val_loss: 0.4717 - val_accuracy: 0.7558
# Epoch 19/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4716 - accuracy: 0.7539 - val_loss: 0.4684 - val_accuracy: 0.7571
# Epoch 20/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4701 - accuracy: 0.7543 - val_loss: 0.4665 - val_accuracy: 0.7567
# Epoch 21/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4688 - accuracy: 0.7547 - val_loss: 0.4662 - val_accuracy: 0.7555
# Epoch 22/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4676 - accuracy: 0.7550 - val_loss: 0.4669 - val_accuracy: 0.7543
# Epoch 23/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4666 - accuracy: 0.7555 - val_loss: 0.4681 - val_accuracy: 0.7532
# Epoch 24/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4656 - accuracy: 0.7558 - val_loss: 0.4693 - val_accuracy: 0.7529
# Epoch 25/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4647 - accuracy: 0.7561 - val_loss: 0.4703 - val_accuracy: 0.7529
# Epoch 26/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4638 - accuracy: 0.7566 - val_loss: 0.4712 - val_accuracy: 0.7523
# Epoch 27/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4630 - accuracy: 0.7569 - val_loss: 0.4717 - val_accuracy: 0.7525
# Epoch 28/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4622 - accuracy: 0.7571 - val_loss: 0.4720 - val_accuracy: 0.7522
# Epoch 29/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4615 - accuracy: 0.7574 - val_loss: 0.4720 - val_accuracy: 0.7519
# Epoch 30/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4607 - accuracy: 0.7578 - val_loss: 0.4719 - val_accuracy: 0.7519
# Epoch 31/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4600 - accuracy: 0.7580 - val_loss: 0.4716 - val_accuracy: 0.7522
# Epoch 32/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4594 - accuracy: 0.7584 - val_loss: 0.4712 - val_accuracy: 0.7528
# Epoch 33/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4587 - accuracy: 0.7587 - val_loss: 0.4707 - val_accuracy: 0.7536
# Epoch 34/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4581 - accuracy: 0.7592 - val_loss: 0.4701 - val_accuracy: 0.7545
# Epoch 35/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4574 - accuracy: 0.7598 - val_loss: 0.4696 - val_accuracy: 0.7547
# Epoch 36/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4568 - accuracy: 0.7602 - val_loss: 0.4690 - val_accuracy: 0.7547
# Epoch 37/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4562 - accuracy: 0.7608 - val_loss: 0.4685 - val_accuracy: 0.7549
# Epoch 38/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4555 - accuracy: 0.7614 - val_loss: 0.4682 - val_accuracy: 0.7552
# Epoch 39/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4549 - accuracy: 0.7619 - val_loss: 0.4679 - val_accuracy: 0.7551
# Epoch 40/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4542 - accuracy: 0.7626 - val_loss: 0.4678 - val_accuracy: 0.7550
# Epoch 41/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4535 - accuracy: 0.7632 - val_loss: 0.4678 - val_accuracy: 0.7546
# Epoch 42/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4528 - accuracy: 0.7640 - val_loss: 0.4679 - val_accuracy: 0.7538
# Epoch 43/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4522 - accuracy: 0.7647 - val_loss: 0.4681 - val_accuracy: 0.7529
# Epoch 44/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4515 - accuracy: 0.7654 - val_loss: 0.4683 - val_accuracy: 0.7520
# Epoch 45/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4508 - accuracy: 0.7658 - val_loss: 0.4685 - val_accuracy: 0.7512
# Epoch 46/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4502 - accuracy: 0.7663 - val_loss: 0.4688 - val_accuracy: 0.7504
# Epoch 47/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4497 - accuracy: 0.7670 - val_loss: 0.4692 - val_accuracy: 0.7495
# Epoch 48/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4492 - accuracy: 0.7675 - val_loss: 0.4697 - val_accuracy: 0.7488
# Epoch 49/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4487 - accuracy: 0.7679 - val_loss: 0.4704 - val_accuracy: 0.7477
# Epoch 50/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4483 - accuracy: 0.7681 - val_loss: 0.4712 - val_accuracy: 0.7466
# Epoch 51/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4479 - accuracy: 0.7687 - val_loss: 0.4721 - val_accuracy: 0.7448
# Epoch 52/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4475 - accuracy: 0.7691 - val_loss: 0.4729 - val_accuracy: 0.7436
# Epoch 53/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4472 - accuracy: 0.7693 - val_loss: 0.4737 - val_accuracy: 0.7427
# Epoch 54/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4468 - accuracy: 0.7695 - val_loss: 0.4744 - val_accuracy: 0.7417
# Epoch 55/140
# 2971/2971 [==============================] - 49s 17ms/step - loss: 0.4465 - accuracy: 0.7697 - val_loss: 0.4749 - val_accuracy: 0.7408
# Epoch 56/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4462 - accuracy: 0.7701 - val_loss: 0.4753 - val_accuracy: 0.7403
# Epoch 57/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4460 - accuracy: 0.7705 - val_loss: 0.4756 - val_accuracy: 0.7395
# Epoch 58/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4457 - accuracy: 0.7708 - val_loss: 0.4757 - val_accuracy: 0.7393
# Epoch 59/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4454 - accuracy: 0.7710 - val_loss: 0.4756 - val_accuracy: 0.7398
# Epoch 60/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4452 - accuracy: 0.7713 - val_loss: 0.4754 - val_accuracy: 0.7401
# Epoch 61/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4449 - accuracy: 0.7714 - val_loss: 0.4752 - val_accuracy: 0.7404
# Epoch 62/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4447 - accuracy: 0.7716 - val_loss: 0.4748 - val_accuracy: 0.7410
# Epoch 63/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4445 - accuracy: 0.7717 - val_loss: 0.4744 - val_accuracy: 0.7413
# Epoch 64/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4443 - accuracy: 0.7719 - val_loss: 0.4740 - val_accuracy: 0.7420
# Epoch 65/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4440 - accuracy: 0.7720 - val_loss: 0.4735 - val_accuracy: 0.7427
# Epoch 66/140
# 2971/2971 [==============================] - 49s 17ms/step - loss: 0.4438 - accuracy: 0.7722 - val_loss: 0.4730 - val_accuracy: 0.7435
# Epoch 67/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4436 - accuracy: 0.7725 - val_loss: 0.4725 - val_accuracy: 0.7443
# Epoch 68/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4434 - accuracy: 0.7726 - val_loss: 0.4720 - val_accuracy: 0.7448
# Epoch 69/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4432 - accuracy: 0.7726 - val_loss: 0.4715 - val_accuracy: 0.7452
# Epoch 70/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4430 - accuracy: 0.7728 - val_loss: 0.4710 - val_accuracy: 0.7461
# Epoch 71/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4428 - accuracy: 0.7728 - val_loss: 0.4705 - val_accuracy: 0.7463
# Epoch 72/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4426 - accuracy: 0.7731 - val_loss: 0.4701 - val_accuracy: 0.7469
# Epoch 73/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4424 - accuracy: 0.7734 - val_loss: 0.4696 - val_accuracy: 0.7470
# Epoch 74/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4423 - accuracy: 0.7735 - val_loss: 0.4691 - val_accuracy: 0.7476
# Epoch 75/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4421 - accuracy: 0.7736 - val_loss: 0.4687 - val_accuracy: 0.7479
# Epoch 76/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4419 - accuracy: 0.7737 - val_loss: 0.4682 - val_accuracy: 0.7484
# Epoch 77/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4417 - accuracy: 0.7739 - val_loss: 0.4678 - val_accuracy: 0.7489
# Epoch 78/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4416 - accuracy: 0.7741 - val_loss: 0.4673 - val_accuracy: 0.7492
# Epoch 79/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4414 - accuracy: 0.7743 - val_loss: 0.4669 - val_accuracy: 0.7497
# Epoch 80/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4412 - accuracy: 0.7744 - val_loss: 0.4665 - val_accuracy: 0.7503
# Epoch 81/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4411 - accuracy: 0.7745 - val_loss: 0.4661 - val_accuracy: 0.7503
# Epoch 82/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4409 - accuracy: 0.7746 - val_loss: 0.4656 - val_accuracy: 0.7505
# Epoch 83/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4408 - accuracy: 0.7748 - val_loss: 0.4652 - val_accuracy: 0.7507
# Epoch 84/140
# 2971/2971 [==============================] - 49s 17ms/step - loss: 0.4406 - accuracy: 0.7749 - val_loss: 0.4648 - val_accuracy: 0.7511
# Epoch 85/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4405 - accuracy: 0.7751 - val_loss: 0.4644 - val_accuracy: 0.7514
# Epoch 86/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4403 - accuracy: 0.7753 - val_loss: 0.4640 - val_accuracy: 0.7517
# Epoch 87/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4402 - accuracy: 0.7754 - val_loss: 0.4636 - val_accuracy: 0.7522
# Epoch 88/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4401 - accuracy: 0.7756 - val_loss: 0.4633 - val_accuracy: 0.7525
# Epoch 89/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4399 - accuracy: 0.7757 - val_loss: 0.4629 - val_accuracy: 0.7527
# Epoch 90/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4398 - accuracy: 0.7759 - val_loss: 0.4625 - val_accuracy: 0.7530
# Epoch 91/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4396 - accuracy: 0.7760 - val_loss: 0.4621 - val_accuracy: 0.7532
# Epoch 92/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4395 - accuracy: 0.7760 - val_loss: 0.4617 - val_accuracy: 0.7536
# Epoch 93/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4394 - accuracy: 0.7762 - val_loss: 0.4613 - val_accuracy: 0.7539
# Epoch 94/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4393 - accuracy: 0.7763 - val_loss: 0.4609 - val_accuracy: 0.7544
# Epoch 95/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4391 - accuracy: 0.7763 - val_loss: 0.4604 - val_accuracy: 0.7548
# Epoch 96/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4390 - accuracy: 0.7764 - val_loss: 0.4600 - val_accuracy: 0.7551
# Epoch 97/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4389 - accuracy: 0.7766 - val_loss: 0.4596 - val_accuracy: 0.7555
# Epoch 98/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4388 - accuracy: 0.7767 - val_loss: 0.4591 - val_accuracy: 0.7557
# Epoch 99/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4387 - accuracy: 0.7767 - val_loss: 0.4587 - val_accuracy: 0.7559
# Epoch 100/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4386 - accuracy: 0.7768 - val_loss: 0.4582 - val_accuracy: 0.7562
# Epoch 101/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4385 - accuracy: 0.7768 - val_loss: 0.4577 - val_accuracy: 0.7564
# Epoch 102/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4384 - accuracy: 0.7769 - val_loss: 0.4572 - val_accuracy: 0.7569
# Epoch 103/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4382 - accuracy: 0.7770 - val_loss: 0.4567 - val_accuracy: 0.7573
# Epoch 104/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4381 - accuracy: 0.7772 - val_loss: 0.4562 - val_accuracy: 0.7578
# Epoch 105/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4380 - accuracy: 0.7773 - val_loss: 0.4557 - val_accuracy: 0.7583
# Epoch 106/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4379 - accuracy: 0.7773 - val_loss: 0.4552 - val_accuracy: 0.7586
# Epoch 107/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4378 - accuracy: 0.7774 - val_loss: 0.4547 - val_accuracy: 0.7589
# Epoch 108/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4377 - accuracy: 0.7775 - val_loss: 0.4541 - val_accuracy: 0.7593
# Epoch 109/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4376 - accuracy: 0.7776 - val_loss: 0.4536 - val_accuracy: 0.7596
# Epoch 110/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4375 - accuracy: 0.7776 - val_loss: 0.4531 - val_accuracy: 0.7598
# Epoch 111/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4374 - accuracy: 0.7777 - val_loss: 0.4525 - val_accuracy: 0.7601
# Epoch 112/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4373 - accuracy: 0.7778 - val_loss: 0.4520 - val_accuracy: 0.7603
# Epoch 113/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4372 - accuracy: 0.7779 - val_loss: 0.4515 - val_accuracy: 0.7605
# Epoch 114/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4371 - accuracy: 0.7779 - val_loss: 0.4509 - val_accuracy: 0.7610
# Epoch 115/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4370 - accuracy: 0.7779 - val_loss: 0.4504 - val_accuracy: 0.7615
# Epoch 116/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4370 - accuracy: 0.7780 - val_loss: 0.4499 - val_accuracy: 0.7618
# Epoch 117/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4369 - accuracy: 0.7781 - val_loss: 0.4494 - val_accuracy: 0.7623
# Epoch 118/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4368 - accuracy: 0.7782 - val_loss: 0.4489 - val_accuracy: 0.7626
# Epoch 119/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4367 - accuracy: 0.7782 - val_loss: 0.4485 - val_accuracy: 0.7629
# Epoch 120/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4366 - accuracy: 0.7783 - val_loss: 0.4480 - val_accuracy: 0.7633
# Epoch 121/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4365 - accuracy: 0.7783 - val_loss: 0.4475 - val_accuracy: 0.7635
# Epoch 122/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4364 - accuracy: 0.7784 - val_loss: 0.4471 - val_accuracy: 0.7637
# Epoch 123/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4363 - accuracy: 0.7784 - val_loss: 0.4467 - val_accuracy: 0.7642
# Epoch 124/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4362 - accuracy: 0.7785 - val_loss: 0.4463 - val_accuracy: 0.7644
# Epoch 125/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4361 - accuracy: 0.7786 - val_loss: 0.4459 - val_accuracy: 0.7650
# Epoch 126/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4360 - accuracy: 0.7786 - val_loss: 0.4455 - val_accuracy: 0.7652
# Epoch 127/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4359 - accuracy: 0.7787 - val_loss: 0.4451 - val_accuracy: 0.7653
# Epoch 128/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4358 - accuracy: 0.7787 - val_loss: 0.4447 - val_accuracy: 0.7657
# Epoch 129/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4357 - accuracy: 0.7788 - val_loss: 0.4442 - val_accuracy: 0.7662
# Epoch 130/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4356 - accuracy: 0.7788 - val_loss: 0.4438 - val_accuracy: 0.7666
# Epoch 131/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4355 - accuracy: 0.7790 - val_loss: 0.4434 - val_accuracy: 0.7670
# Epoch 132/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4354 - accuracy: 0.7790 - val_loss: 0.4430 - val_accuracy: 0.7675
# Epoch 133/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4352 - accuracy: 0.7791 - val_loss: 0.4426 - val_accuracy: 0.7681
# Epoch 134/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4351 - accuracy: 0.7792 - val_loss: 0.4421 - val_accuracy: 0.7692
# Epoch 135/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4349 - accuracy: 0.7793 - val_loss: 0.4416 - val_accuracy: 0.7697
# Epoch 136/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4347 - accuracy: 0.7793 - val_loss: 0.4411 - val_accuracy: 0.7706
# Epoch 137/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4345 - accuracy: 0.7794 - val_loss: 0.4406 - val_accuracy: 0.7712
# Epoch 138/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4343 - accuracy: 0.7795 - val_loss: 0.4400 - val_accuracy: 0.7719
# Epoch 139/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4340 - accuracy: 0.7797 - val_loss: 0.4394 - val_accuracy: 0.7728
# Epoch 140/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4338 - accuracy: 0.7799 - val_loss: 0.4389 - val_accuracy: 0.7739

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 6957.775552988052

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00129228],
#        [0.00085882],
#        [0.00030751],
#        ...,
#        [0.1432989 ],
#        [0.14332172],
#        [0.14418004]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1476210914261414
# 0.20618496512871864
# 0.38421490266014074
# 0.29969828992684094

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 74s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.57262956]
# [0.82809662]
# total acc [0.77324377]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
