# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1ff0dc7e040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1ff47cef040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 62s 18ms/step - loss: 0.4690 - accuracy: 0.7603 - val_loss: 0.4370 - val_accuracy: 0.7755
# Epoch 2/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4439 - accuracy: 0.7752 - val_loss: 0.4329 - val_accuracy: 0.7801
# Epoch 3/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4361 - accuracy: 0.7786 - val_loss: 0.4268 - val_accuracy: 0.7840
# Epoch 4/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4317 - accuracy: 0.7805 - val_loss: 0.4336 - val_accuracy: 0.7824
# Epoch 5/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4281 - accuracy: 0.7827 - val_loss: 0.4248 - val_accuracy: 0.7851
# Epoch 6/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4250 - accuracy: 0.7838 - val_loss: 0.4357 - val_accuracy: 0.7816
# Epoch 7/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4226 - accuracy: 0.7849 - val_loss: 0.4285 - val_accuracy: 0.7849
# Epoch 8/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4200 - accuracy: 0.7863 - val_loss: 0.4306 - val_accuracy: 0.7840
# Epoch 9/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4180 - accuracy: 0.7868 - val_loss: 0.4271 - val_accuracy: 0.7811
# Epoch 10/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4161 - accuracy: 0.7873 - val_loss: 0.4249 - val_accuracy: 0.7813
# Epoch 11/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4136 - accuracy: 0.7893 - val_loss: 0.4290 - val_accuracy: 0.7852
# Epoch 12/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4116 - accuracy: 0.7896 - val_loss: 0.4363 - val_accuracy: 0.7851
# Epoch 13/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4101 - accuracy: 0.7904 - val_loss: 0.4308 - val_accuracy: 0.7846
# Epoch 14/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4079 - accuracy: 0.7913 - val_loss: 0.4369 - val_accuracy: 0.7814
# Epoch 15/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4061 - accuracy: 0.7925 - val_loss: 0.4342 - val_accuracy: 0.7847
# Epoch 16/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4040 - accuracy: 0.7933 - val_loss: 0.4291 - val_accuracy: 0.7843
# Epoch 17/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4026 - accuracy: 0.7938 - val_loss: 0.4309 - val_accuracy: 0.7814
# Epoch 18/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4008 - accuracy: 0.7949 - val_loss: 0.4388 - val_accuracy: 0.7772
# Epoch 19/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3986 - accuracy: 0.7962 - val_loss: 0.4331 - val_accuracy: 0.7773
# Epoch 20/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.3969 - accuracy: 0.7968 - val_loss: 0.4426 - val_accuracy: 0.7826
# Epoch 21/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3953 - accuracy: 0.7980 - val_loss: 0.4394 - val_accuracy: 0.7816
# Epoch 22/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3934 - accuracy: 0.7982 - val_loss: 0.4393 - val_accuracy: 0.7803
# Epoch 23/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3921 - accuracy: 0.7992 - val_loss: 0.4463 - val_accuracy: 0.7779
# Epoch 24/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.3904 - accuracy: 0.7999 - val_loss: 0.4487 - val_accuracy: 0.7809
# Epoch 25/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3893 - accuracy: 0.8007 - val_loss: 0.4384 - val_accuracy: 0.7795
# Epoch 26/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3877 - accuracy: 0.8015 - val_loss: 0.4496 - val_accuracy: 0.7807
# Epoch 27/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3862 - accuracy: 0.8023 - val_loss: 0.4429 - val_accuracy: 0.7745
# Epoch 28/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3850 - accuracy: 0.8028 - val_loss: 0.4495 - val_accuracy: 0.7787
# Epoch 29/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3837 - accuracy: 0.8036 - val_loss: 0.4443 - val_accuracy: 0.7720
# Epoch 30/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3825 - accuracy: 0.8045 - val_loss: 0.4618 - val_accuracy: 0.7772
# Epoch 31/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3808 - accuracy: 0.8051 - val_loss: 0.4461 - val_accuracy: 0.7706
# Epoch 32/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.3802 - accuracy: 0.8053 - val_loss: 0.4478 - val_accuracy: 0.7753
# Epoch 33/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3788 - accuracy: 0.8058 - val_loss: 0.4478 - val_accuracy: 0.7734
# Epoch 34/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3773 - accuracy: 0.8067 - val_loss: 0.4531 - val_accuracy: 0.7771
# Epoch 35/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3763 - accuracy: 0.8071 - val_loss: 0.4490 - val_accuracy: 0.7713
# Epoch 36/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3755 - accuracy: 0.8079 - val_loss: 0.4551 - val_accuracy: 0.7742
# Epoch 37/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3744 - accuracy: 0.8085 - val_loss: 0.4469 - val_accuracy: 0.7727
# Epoch 38/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3731 - accuracy: 0.8093 - val_loss: 0.4587 - val_accuracy: 0.7661
# Epoch 39/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3724 - accuracy: 0.8099 - val_loss: 0.4535 - val_accuracy: 0.7781
# Epoch 40/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3717 - accuracy: 0.8099 - val_loss: 0.4525 - val_accuracy: 0.7757
# Epoch 41/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.3703 - accuracy: 0.8109 - val_loss: 0.4637 - val_accuracy: 0.7667
# Epoch 42/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3704 - accuracy: 0.8110 - val_loss: 0.4615 - val_accuracy: 0.7635
# Epoch 43/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3696 - accuracy: 0.8110 - val_loss: 0.4578 - val_accuracy: 0.7689
# Epoch 44/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3679 - accuracy: 0.8117 - val_loss: 0.4565 - val_accuracy: 0.7703
# Epoch 45/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3668 - accuracy: 0.8131 - val_loss: 0.4639 - val_accuracy: 0.7691
# Epoch 46/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3666 - accuracy: 0.8131 - val_loss: 0.4621 - val_accuracy: 0.7676
# Epoch 47/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.3660 - accuracy: 0.8129 - val_loss: 0.4527 - val_accuracy: 0.7711
# Epoch 48/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3658 - accuracy: 0.8138 - val_loss: 0.4611 - val_accuracy: 0.7698
# Epoch 49/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3644 - accuracy: 0.8141 - val_loss: 0.4615 - val_accuracy: 0.7632
# Epoch 50/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3636 - accuracy: 0.8147 - val_loss: 0.4684 - val_accuracy: 0.7636
# Epoch 51/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3628 - accuracy: 0.8150 - val_loss: 0.4652 - val_accuracy: 0.7682
# Epoch 52/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3622 - accuracy: 0.8157 - val_loss: 0.4706 - val_accuracy: 0.7683
# Epoch 53/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3615 - accuracy: 0.8157 - val_loss: 0.4704 - val_accuracy: 0.7587
# Epoch 54/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3606 - accuracy: 0.8165 - val_loss: 0.4658 - val_accuracy: 0.7669
# Epoch 55/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3604 - accuracy: 0.8161 - val_loss: 0.4785 - val_accuracy: 0.7685
# Epoch 56/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3600 - accuracy: 0.8168 - val_loss: 0.4695 - val_accuracy: 0.7653
# Epoch 57/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3590 - accuracy: 0.8168 - val_loss: 0.4842 - val_accuracy: 0.7661
# Epoch 58/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3587 - accuracy: 0.8174 - val_loss: 0.4799 - val_accuracy: 0.7622
# Epoch 59/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3578 - accuracy: 0.8181 - val_loss: 0.4930 - val_accuracy: 0.7734
# Epoch 60/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3577 - accuracy: 0.8180 - val_loss: 0.4863 - val_accuracy: 0.7687
# Epoch 61/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3570 - accuracy: 0.8185 - val_loss: 0.4831 - val_accuracy: 0.7723
# Epoch 62/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3564 - accuracy: 0.8183 - val_loss: 0.4717 - val_accuracy: 0.7626
# Epoch 63/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3560 - accuracy: 0.8180 - val_loss: 0.4745 - val_accuracy: 0.7643
# Epoch 64/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3553 - accuracy: 0.8197 - val_loss: 0.4736 - val_accuracy: 0.7673
# Epoch 65/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3547 - accuracy: 0.8194 - val_loss: 0.4879 - val_accuracy: 0.7703
# Epoch 66/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3542 - accuracy: 0.8202 - val_loss: 0.4721 - val_accuracy: 0.7693
# Epoch 67/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3536 - accuracy: 0.8198 - val_loss: 0.4823 - val_accuracy: 0.7710
# Epoch 68/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3527 - accuracy: 0.8209 - val_loss: 0.4840 - val_accuracy: 0.7638
# Epoch 69/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3531 - accuracy: 0.8208 - val_loss: 0.4915 - val_accuracy: 0.7704
# Epoch 70/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3519 - accuracy: 0.8211 - val_loss: 0.4796 - val_accuracy: 0.7631
# Epoch 71/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3521 - accuracy: 0.8211 - val_loss: 0.4869 - val_accuracy: 0.7685
# Epoch 72/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3511 - accuracy: 0.8219 - val_loss: 0.4935 - val_accuracy: 0.7668
# Epoch 73/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3513 - accuracy: 0.8219 - val_loss: 0.4759 - val_accuracy: 0.7672
# Epoch 74/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3511 - accuracy: 0.8222 - val_loss: 0.5025 - val_accuracy: 0.7702
# Epoch 75/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.3499 - accuracy: 0.8228 - val_loss: 0.4908 - val_accuracy: 0.7642
# Epoch 76/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3501 - accuracy: 0.8225 - val_loss: 0.4887 - val_accuracy: 0.7653
# Epoch 77/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3494 - accuracy: 0.8231 - val_loss: 0.4861 - val_accuracy: 0.7629
# Epoch 78/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3498 - accuracy: 0.8227 - val_loss: 0.5019 - val_accuracy: 0.7619
# Epoch 79/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3492 - accuracy: 0.8230 - val_loss: 0.4763 - val_accuracy: 0.7637
# Epoch 80/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3495 - accuracy: 0.8224 - val_loss: 0.4908 - val_accuracy: 0.7617
# Epoch 81/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.3478 - accuracy: 0.8240 - val_loss: 0.4833 - val_accuracy: 0.7569
# Epoch 82/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3476 - accuracy: 0.8233 - val_loss: 0.4849 - val_accuracy: 0.7605
# Epoch 83/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3463 - accuracy: 0.8250 - val_loss: 0.4873 - val_accuracy: 0.7678
# Epoch 84/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3471 - accuracy: 0.8243 - val_loss: 0.4910 - val_accuracy: 0.7658
# Epoch 85/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3473 - accuracy: 0.8240 - val_loss: 0.4964 - val_accuracy: 0.7656
# Epoch 86/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.3466 - accuracy: 0.8244 - val_loss: 0.4857 - val_accuracy: 0.7634
# Epoch 87/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3463 - accuracy: 0.8247 - val_loss: 0.4972 - val_accuracy: 0.7607
# Epoch 88/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.3448 - accuracy: 0.8258 - val_loss: 0.4963 - val_accuracy: 0.7647
# Epoch 89/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3452 - accuracy: 0.8257 - val_loss: 0.4909 - val_accuracy: 0.7658
# Epoch 90/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3440 - accuracy: 0.8257 - val_loss: 0.4931 - val_accuracy: 0.7646
# Epoch 91/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3448 - accuracy: 0.8253 - val_loss: 0.4879 - val_accuracy: 0.7610
# Epoch 92/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3436 - accuracy: 0.8264 - val_loss: 0.4993 - val_accuracy: 0.7633
# Epoch 93/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3437 - accuracy: 0.8256 - val_loss: 0.4937 - val_accuracy: 0.7655
# Epoch 94/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.3429 - accuracy: 0.8266 - val_loss: 0.4979 - val_accuracy: 0.7630
# Epoch 95/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3419 - accuracy: 0.8268 - val_loss: 0.4986 - val_accuracy: 0.7576
# Epoch 96/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3425 - accuracy: 0.8268 - val_loss: 0.5033 - val_accuracy: 0.7608
# Epoch 97/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3422 - accuracy: 0.8272 - val_loss: 0.5071 - val_accuracy: 0.7659
# Epoch 98/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3403 - accuracy: 0.8286 - val_loss: 0.5125 - val_accuracy: 0.7642
# Epoch 99/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3411 - accuracy: 0.8278 - val_loss: 0.5089 - val_accuracy: 0.7661
# Epoch 100/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3409 - accuracy: 0.8279 - val_loss: 0.4957 - val_accuracy: 0.7630
# Epoch 101/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3416 - accuracy: 0.8275 - val_loss: 0.5037 - val_accuracy: 0.7674
# Epoch 102/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.3414 - accuracy: 0.8278 - val_loss: 0.4952 - val_accuracy: 0.7589
# Epoch 103/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3409 - accuracy: 0.8282 - val_loss: 0.5122 - val_accuracy: 0.7600
# Epoch 104/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.3397 - accuracy: 0.8284 - val_loss: 0.5008 - val_accuracy: 0.7610
# Epoch 105/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3392 - accuracy: 0.8290 - val_loss: 0.5091 - val_accuracy: 0.7647
# Epoch 106/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3393 - accuracy: 0.8288 - val_loss: 0.4864 - val_accuracy: 0.7632
# Epoch 107/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3401 - accuracy: 0.8280 - val_loss: 0.5212 - val_accuracy: 0.7651
# Epoch 108/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3406 - accuracy: 0.8285 - val_loss: 0.5065 - val_accuracy: 0.7640
# Epoch 109/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3400 - accuracy: 0.8286 - val_loss: 0.5022 - val_accuracy: 0.7602
# Epoch 110/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3394 - accuracy: 0.8291 - val_loss: 0.5132 - val_accuracy: 0.7632
# Epoch 111/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3383 - accuracy: 0.8295 - val_loss: 0.5039 - val_accuracy: 0.7590
# Epoch 112/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3393 - accuracy: 0.8297 - val_loss: 0.5148 - val_accuracy: 0.7631
# Epoch 113/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3374 - accuracy: 0.8302 - val_loss: 0.5047 - val_accuracy: 0.7634
# Epoch 114/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3382 - accuracy: 0.8298 - val_loss: 0.5073 - val_accuracy: 0.7640
# Epoch 115/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3372 - accuracy: 0.8300 - val_loss: 0.5020 - val_accuracy: 0.7634
# Epoch 116/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3378 - accuracy: 0.8296 - val_loss: 0.5080 - val_accuracy: 0.7618
# Epoch 117/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3373 - accuracy: 0.8299 - val_loss: 0.5185 - val_accuracy: 0.7611
# Epoch 118/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3375 - accuracy: 0.8300 - val_loss: 0.5054 - val_accuracy: 0.7551
# Epoch 119/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3368 - accuracy: 0.8303 - val_loss: 0.5128 - val_accuracy: 0.7613
# Epoch 120/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3367 - accuracy: 0.8306 - val_loss: 0.5058 - val_accuracy: 0.7607
# Epoch 121/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.3360 - accuracy: 0.8312 - val_loss: 0.5131 - val_accuracy: 0.7627
# Epoch 122/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3365 - accuracy: 0.8301 - val_loss: 0.5287 - val_accuracy: 0.7662
# Epoch 123/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3369 - accuracy: 0.8305 - val_loss: 0.5082 - val_accuracy: 0.7588
# Epoch 124/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3354 - accuracy: 0.8313 - val_loss: 0.5072 - val_accuracy: 0.7601
# Epoch 125/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3350 - accuracy: 0.8317 - val_loss: 0.5134 - val_accuracy: 0.7638
# Epoch 126/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3364 - accuracy: 0.8310 - val_loss: 0.5109 - val_accuracy: 0.7635
# Epoch 127/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3355 - accuracy: 0.8313 - val_loss: 0.5152 - val_accuracy: 0.7612
# Epoch 128/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3360 - accuracy: 0.8306 - val_loss: 0.5199 - val_accuracy: 0.7666
# Epoch 129/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3350 - accuracy: 0.8320 - val_loss: 0.5190 - val_accuracy: 0.7636
# Epoch 130/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3353 - accuracy: 0.8308 - val_loss: 0.5130 - val_accuracy: 0.7664
# Epoch 131/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3343 - accuracy: 0.8320 - val_loss: 0.5158 - val_accuracy: 0.7608
# Epoch 132/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3344 - accuracy: 0.8316 - val_loss: 0.5117 - val_accuracy: 0.7577
# Epoch 133/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3343 - accuracy: 0.8318 - val_loss: 0.5239 - val_accuracy: 0.7626
# Epoch 134/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3352 - accuracy: 0.8315 - val_loss: 0.5119 - val_accuracy: 0.7643
# Epoch 135/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3346 - accuracy: 0.8318 - val_loss: 0.5227 - val_accuracy: 0.7660
# Epoch 136/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3346 - accuracy: 0.8317 - val_loss: 0.5329 - val_accuracy: 0.7628
# Epoch 137/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3329 - accuracy: 0.8328 - val_loss: 0.5142 - val_accuracy: 0.7614
# Epoch 138/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3324 - accuracy: 0.8333 - val_loss: 0.5164 - val_accuracy: 0.7593
# Epoch 139/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.3336 - accuracy: 0.8320 - val_loss: 0.5090 - val_accuracy: 0.7556
# Epoch 140/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.3327 - accuracy: 0.8328 - val_loss: 0.5325 - val_accuracy: 0.7648

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 7430.165167570114

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[4.3015751e-07],
#        [9.6192927e-08],
#        [1.4993309e-07],
#        ...,
#        [6.2612228e-02],
#        [1.1937667e-01],
#        [2.6826417e-01]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1606583557917413
# 0.13607861130743737
# 0.4008220999293094
# 0.26596631106256335

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 76s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.68023531]
# [0.8656233]
# total acc [0.82365601]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
