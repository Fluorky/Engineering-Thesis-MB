# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=4

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475333, 4, 16)
# strides:  (512, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1beea3e8040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475333,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1bef8c19040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380266

# %%
training_sample
# Out:
# 380266

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380266, 4, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380266,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380266, 4, 15) (380266, 1) (95067, 4, 15) (95067, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#activation='relu'),
    keras.layers.GRU(units=64),#activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 4, 256)            209664
#
#  gru_1 (GRU)                 (None, 4, 128)            148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 54s 15ms/step - loss: 0.5728 - accuracy: 0.7393 - val_loss: 0.5573 - val_accuracy: 0.7531
# Epoch 2/140
# 2971/2971 [==============================] - 44s 15ms/step - loss: 0.5690 - accuracy: 0.7393 - val_loss: 0.5515 - val_accuracy: 0.7531
# Epoch 3/140
# 2971/2971 [==============================] - 44s 15ms/step - loss: 0.5571 - accuracy: 0.7393 - val_loss: 0.5328 - val_accuracy: 0.7530
# Epoch 4/140
# 2971/2971 [==============================] - 43s 15ms/step - loss: 0.5341 - accuracy: 0.7412 - val_loss: 0.5100 - val_accuracy: 0.7532
# Epoch 5/140
# 2971/2971 [==============================] - 43s 15ms/step - loss: 0.5160 - accuracy: 0.7404 - val_loss: 0.4961 - val_accuracy: 0.7508
# Epoch 6/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.5074 - accuracy: 0.7386 - val_loss: 0.4915 - val_accuracy: 0.7483
# Epoch 7/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.5041 - accuracy: 0.7382 - val_loss: 0.4889 - val_accuracy: 0.7480
# Epoch 8/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.5018 - accuracy: 0.7377 - val_loss: 0.4869 - val_accuracy: 0.7465
# Epoch 9/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.5000 - accuracy: 0.7367 - val_loss: 0.4853 - val_accuracy: 0.7472
# Epoch 10/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4984 - accuracy: 0.7361 - val_loss: 0.4832 - val_accuracy: 0.7487
# Epoch 11/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4969 - accuracy: 0.7357 - val_loss: 0.4829 - val_accuracy: 0.7482
# Epoch 12/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4957 - accuracy: 0.7357 - val_loss: 0.4819 - val_accuracy: 0.7480
# Epoch 13/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4946 - accuracy: 0.7360 - val_loss: 0.4795 - val_accuracy: 0.7509
# Epoch 14/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4936 - accuracy: 0.7366 - val_loss: 0.4777 - val_accuracy: 0.7521
# Epoch 15/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4928 - accuracy: 0.7378 - val_loss: 0.4773 - val_accuracy: 0.7529
# Epoch 16/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4920 - accuracy: 0.7387 - val_loss: 0.4770 - val_accuracy: 0.7531
# Epoch 17/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4913 - accuracy: 0.7393 - val_loss: 0.4771 - val_accuracy: 0.7532
# Epoch 18/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4907 - accuracy: 0.7393 - val_loss: 0.4758 - val_accuracy: 0.7531
# Epoch 19/140
# 2971/2971 [==============================] - 43s 15ms/step - loss: 0.4899 - accuracy: 0.7394 - val_loss: 0.4750 - val_accuracy: 0.7531
# Epoch 20/140
# 2971/2971 [==============================] - 43s 15ms/step - loss: 0.4890 - accuracy: 0.7395 - val_loss: 0.4763 - val_accuracy: 0.7531
# Epoch 21/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4877 - accuracy: 0.7403 - val_loss: 0.4748 - val_accuracy: 0.7539
# Epoch 22/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4862 - accuracy: 0.7426 - val_loss: 0.4768 - val_accuracy: 0.7549
# Epoch 23/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4844 - accuracy: 0.7452 - val_loss: 0.4731 - val_accuracy: 0.7529
# Epoch 24/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0
# 2971/2971 [==============================] - 44s 15ms/step - loss: 0.4346 - accuracy: 0.7773 - val_loss: 0.4277 - val_accuracy: 0.7808
# Epoch 139/140
# 2971/2971 [==============================] - 43s 15ms/step - loss: 0.4343 - accuracy: 0.7774 - val_loss: 0.4294 - val_accuracy: 0.7804
# Epoch 140/140
# 2971/2971 [==============================] - 43s 14ms/step - loss: 0.4340 - accuracy: 0.7774 - val_loss: 0.4293 - val_accuracy: 0.7802

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 14s 4ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 6174.961032867432

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95067, 1)

# %%
pred_y
# Out:
# array([[0.00079181],
#        [0.00135523],
#        [0.0035381 ],
#        ...,
#        [0.05803512],
#        [0.05899524],
#        [0.06084617]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95067)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1437543620535129
# 0.22696691700525862
# 0.37914952466475926
# 0.2912167120595344

# %%
np.shape(train_X)
# Out:
# (380266, 4, 15)

# %%
np.shape(train_y)
# Out:
# (380266, 1)

# %%
np.shape(test_X)
# Out:
# (95067, 4, 15)

# %%
np.shape(test_y)
# Out:
# (95067, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14855/14855 [==============================] - 68s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25793917]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.594454]
# [0.82207362]
# total acc [0.77834907]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
