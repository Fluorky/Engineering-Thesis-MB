# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x24201253040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2423b2cc040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(64,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=32,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=16),#,activation='relu'),
    keras.layers.Dense(units=25,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 64)            15552
#
#  gru_1 (GRU)                 (None, 16, 32)            9408
#
#  gru_2 (GRU)                 (None, 16)                2400
#
#  dense (Dense)               (None, 25)                425
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 27,811
# Trainable params: 27,811
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 56s 16ms/step - loss: 0.5792 - accuracy: 0.7315 - val_loss: 0.5556 - val_accuracy: 0.7531
# Epoch 2/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.5566 - accuracy: 0.7393 - val_loss: 0.5225 - val_accuracy: 0.7531
# Epoch 3/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.5174 - accuracy: 0.7391 - val_loss: 0.4923 - val_accuracy: 0.7534
# Epoch 4/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.5045 - accuracy: 0.7383 - val_loss: 0.4871 - val_accuracy: 0.7534
# Epoch 5/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.5014 - accuracy: 0.7386 - val_loss: 0.4850 - val_accuracy: 0.7530
# Epoch 6/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4994 - accuracy: 0.7388 - val_loss: 0.4878 - val_accuracy: 0.7533
# Epoch 7/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4977 - accuracy: 0.7388 - val_loss: 0.4815 - val_accuracy: 0.7533
# Epoch 8/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4960 - accuracy: 0.7393 - val_loss: 0.4805 - val_accuracy: 0.7525
# Epoch 9/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4939 - accuracy: 0.7411 - val_loss: 0.4809 - val_accuracy: 0.7527
# Epoch 10/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4912 - accuracy: 0.7445 - val_loss: 0.4768 - val_accuracy: 0.7527
# Epoch 11/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4878 - accuracy: 0.7470 - val_loss: 0.4747 - val_accuracy: 0.7532
# Epoch 12/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4835 - accuracy: 0.7484 - val_loss: 0.4727 - val_accuracy: 0.7528
# Epoch 13/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4793 - accuracy: 0.7490 - val_loss: 0.4725 - val_accuracy: 0.7518
# Epoch 14/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4751 - accuracy: 0.7518 - val_loss: 0.4646 - val_accuracy: 0.7567
# Epoch 15/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4715 - accuracy: 0.7532 - val_loss: 0.4699 - val_accuracy: 0.7535
# Epoch 16/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4686 - accuracy: 0.7546 - val_loss: 0.4601 - val_accuracy: 0.7586
# Epoch 17/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4667 - accuracy: 0.7550 - val_loss: 0.4590 - val_accuracy: 0.7585
# Epoch 18/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4653 - accuracy: 0.7554 - val_loss: 0.4552 - val_accuracy: 0.7602
# Epoch 19/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4641 - accuracy: 0.7561 - val_loss: 0.4548 - val_accuracy: 0.7587
# Epoch 20/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4632 - accuracy: 0.7564 - val_loss: 0.4574 - val_accuracy: 0.7580
# Epoch 21/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4621 - accuracy: 0.7569 - val_loss: 0.4566 - val_accuracy: 0.7606
# Epoch 22/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4611 - accuracy: 0.7570 - val_loss: 0.4521 - val_accuracy: 0.7610
# Epoch 23/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4603 - accuracy: 0.7578 - val_loss: 0.4553 - val_accuracy: 0.7630
# Epoch 24/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4595 - accuracy: 0.7581 - val_loss: 0.4540 - val_accuracy: 0.7611
# Epoch 25/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4588 - accuracy: 0.7589 - val_loss: 0.4501 - val_accuracy: 0.7620
# Epoch 26/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4580 - accuracy: 0.7588 - val_loss: 0.4548 - val_accuracy: 0.7624
# Epoch 27/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4571 - accuracy: 0.7600 - val_loss: 0.4605 - val_accuracy: 0.7648
# Epoch 28/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4564 - accuracy: 0.7601 - val_loss: 0.4461 - val_accuracy: 0.7655
# Epoch 29/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4556 - accuracy: 0.7608 - val_loss: 0.4488 - val_accuracy: 0.7643
# Epoch 30/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4551 - accuracy: 0.7610 - val_loss: 0.4446 - val_accuracy: 0.7666
# Epoch 31/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4543 - accuracy: 0.7619 - val_loss: 0.4476 - val_accuracy: 0.7660
# Epoch 32/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4535 - accuracy: 0.7625 - val_loss: 0.4456 - val_accuracy: 0.7669
# Epoch 33/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4528 - accuracy: 0.7633 - val_loss: 0.4473 - val_accuracy: 0.7680
# Epoch 34/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4519 - accuracy: 0.7639 - val_loss: 0.4489 - val_accuracy: 0.7663
# Epoch 35/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4514 - accuracy: 0.7643 - val_loss: 0.4418 - val_accuracy: 0.7695
# Epoch 36/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4505 - accuracy: 0.7647 - val_loss: 0.4433 - val_accuracy: 0.7703
# Epoch 37/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4497 - accuracy: 0.7652 - val_loss: 0.4495 - val_accuracy: 0.7671
# Epoch 38/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4490 - accuracy: 0.7655 - val_loss: 0.4426 - val_accuracy: 0.7708
# Epoch 39/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4482 - accuracy: 0.7667 - val_loss: 0.4467 - val_accuracy: 0.7689
# Epoch 40/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4474 - accuracy: 0.7667 - val_loss: 0.4420 - val_accuracy: 0.7724
# Epoch 41/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4470 - accuracy: 0.7672 - val_loss: 0.4397 - val_accuracy: 0.7720
# Epoch 42/140
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4465 - accuracy: 0.7681 - val_loss: 0.4380 - val_accuracy: 0.7724
# Epoch 43/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4461 - accuracy: 0.7682 - val_loss: 0.4413 - val_accuracy: 0.7723
# Epoch 44/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4459 - accuracy: 0.7679 - val_loss: 0.4375 - val_accuracy: 0.7737
# Epoch 45/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4452 - accuracy: 0.7684 - val_loss: 0.4377 - val_accuracy: 0.7730
# Epoch 46/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4448 - accuracy: 0.7690 - val_loss: 0.4367 - val_accuracy: 0.7737
# Epoch 47/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4442 - accuracy: 0.7691 - val_loss: 0.4441 - val_accuracy: 0.7718
# Epoch 48/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4442 - accuracy: 0.7695 - val_loss: 0.4388 - val_accuracy: 0.7737
# Epoch 49/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4437 - accuracy: 0.7698 - val_loss: 0.4367 - val_accuracy: 0.7733
# Epoch 50/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4434 - accuracy: 0.7702 - val_loss: 0.4365 - val_accuracy: 0.7750
# Epoch 51/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4430 - accuracy: 0.7705 - val_loss: 0.4361 - val_accuracy: 0.7742
# Epoch 52/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4426 - accuracy: 0.7710 - val_loss: 0.4369 - val_accuracy: 0.7748
# Epoch 53/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4423 - accuracy: 0.7710 - val_loss: 0.4373 - val_accuracy: 0.7745
# Epoch 54/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4422 - accuracy: 0.7716 - val_loss: 0.4380 - val_accuracy: 0.7744
# Epoch 55/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4417 - accuracy: 0.7719 - val_loss: 0.4387 - val_accuracy: 0.7757
# Epoch 56/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4415 - accuracy: 0.7720 - val_loss: 0.4364 - val_accuracy: 0.7765
# Epoch 57/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4412 - accuracy: 0.7719 - val_loss: 0.4371 - val_accuracy: 0.7761
# Epoch 58/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4410 - accuracy: 0.7723 - val_loss: 0.4363 - val_accuracy: 0.7762
# Epoch 59/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4407 - accuracy: 0.7729 - val_loss: 0.4352 - val_accuracy: 0.7752
# Epoch 60/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4403 - accuracy: 0.7734 - val_loss: 0.4340 - val_accuracy: 0.7761
# Epoch 61/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4398 - accuracy: 0.7735 - val_loss: 0.4367 - val_accuracy: 0.7758
# Epoch 62/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4396 - accuracy: 0.7734 - val_loss: 0.4403 - val_accuracy: 0.7754
# Epoch 63/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4393 - accuracy: 0.7737 - val_loss: 0.4376 - val_accuracy: 0.7764
# Epoch 64/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4391 - accuracy: 0.7741 - val_loss: 0.4326 - val_accuracy: 0.7767
# Epoch 65/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4385 - accuracy: 0.7745 - val_loss: 0.4319 - val_accuracy: 0.7776
# Epoch 66/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4381 - accuracy: 0.7750 - val_loss: 0.4397 - val_accuracy: 0.7757
# Epoch 67/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4376 - accuracy: 0.7752 - val_loss: 0.4346 - val_accuracy: 0.7772
# Epoch 68/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4372 - accuracy: 0.7756 - val_loss: 0.4345 - val_accuracy: 0.7771
# Epoch 69/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4368 - accuracy: 0.7756 - val_loss: 0.4312 - val_accuracy: 0.7786
# Epoch 70/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4365 - accuracy: 0.7760 - val_loss: 0.4308 - val_accuracy: 0.7788
# Epoch 71/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4362 - accuracy: 0.7760 - val_loss: 0.4344 - val_accuracy: 0.7782
# Epoch 72/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4359 - accuracy: 0.7762 - val_loss: 0.4307 - val_accuracy: 0.7790
# Epoch 73/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4357 - accuracy: 0.7761 - val_loss: 0.4320 - val_accuracy: 0.7782
# Epoch 74/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4354 - accuracy: 0.7764 - val_loss: 0.4308 - val_accuracy: 0.7785
# Epoch 75/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4351 - accuracy: 0.7765 - val_loss: 0.4308 - val_accuracy: 0.7792
# Epoch 76/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4348 - accuracy: 0.7770 - val_loss: 0.4331 - val_accuracy: 0.7776
# Epoch 77/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4347 - accuracy: 0.7770 - val_loss: 0.4306 - val_accuracy: 0.7800
# Epoch 78/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4345 - accuracy: 0.7770 - val_loss: 0.4318 - val_accuracy: 0.7796
# Epoch 79/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4343 - accuracy: 0.7774 - val_loss: 0.4292 - val_accuracy: 0.7798
# Epoch 80/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4338 - accuracy: 0.7773 - val_loss: 0.4316 - val_accuracy: 0.7791
# Epoch 81/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4338 - accuracy: 0.7774 - val_loss: 0.4287 - val_accuracy: 0.7800
# Epoch 82/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4335 - accuracy: 0.7774 - val_loss: 0.4294 - val_accuracy: 0.7803
# Epoch 83/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4334 - accuracy: 0.7777 - val_loss: 0.4294 - val_accuracy: 0.7781
# Epoch 84/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4331 - accuracy: 0.7779 - val_loss: 0.4343 - val_accuracy: 0.7780
# Epoch 85/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4329 - accuracy: 0.7780 - val_loss: 0.4310 - val_accuracy: 0.7792
# Epoch 86/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4328 - accuracy: 0.7778 - val_loss: 0.4322 - val_accuracy: 0.7778
# Epoch 87/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4327 - accuracy: 0.7782 - val_loss: 0.4309 - val_accuracy: 0.7806
# Epoch 88/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4323 - accuracy: 0.7782 - val_loss: 0.4316 - val_accuracy: 0.7799
# Epoch 89/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4323 - accuracy: 0.7782 - val_loss: 0.4300 - val_accuracy: 0.7791
# Epoch 90/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4321 - accuracy: 0.7783 - val_loss: 0.4296 - val_accuracy: 0.7799
# Epoch 91/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4317 - accuracy: 0.7784 - val_loss: 0.4307 - val_accuracy: 0.7797
# Epoch 92/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4317 - accuracy: 0.7786 - val_loss: 0.4329 - val_accuracy: 0.7780
# Epoch 93/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4315 - accuracy: 0.7786 - val_loss: 0.4277 - val_accuracy: 0.7815
# Epoch 94/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4313 - accuracy: 0.7788 - val_loss: 0.4318 - val_accuracy: 0.7787
# Epoch 95/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4312 - accuracy: 0.7793 - val_loss: 0.4294 - val_accuracy: 0.7806
# Epoch 96/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4312 - accuracy: 0.7787 - val_loss: 0.4293 - val_accuracy: 0.7805
# Epoch 97/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4311 - accuracy: 0.7788 - val_loss: 0.4312 - val_accuracy: 0.7798
# Epoch 98/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4308 - accuracy: 0.7792 - val_loss: 0.4289 - val_accuracy: 0.7790
# Epoch 99/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4306 - accuracy: 0.7792 - val_loss: 0.4308 - val_accuracy: 0.7803
# Epoch 100/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4305 - accuracy: 0.7792 - val_loss: 0.4300 - val_accuracy: 0.7799
# Epoch 101/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4303 - accuracy: 0.7790 - val_loss: 0.4262 - val_accuracy: 0.7813
# Epoch 102/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4302 - accuracy: 0.7796 - val_loss: 0.4315 - val_accuracy: 0.7791
# Epoch 103/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4302 - accuracy: 0.7795 - val_loss: 0.4281 - val_accuracy: 0.7818
# Epoch 104/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4299 - accuracy: 0.7792 - val_loss: 0.4271 - val_accuracy: 0.7812
# Epoch 105/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4298 - accuracy: 0.7794 - val_loss: 0.4267 - val_accuracy: 0.7806
# Epoch 106/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4296 - accuracy: 0.7795 - val_loss: 0.4273 - val_accuracy: 0.7807
# Epoch 107/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4295 - accuracy: 0.7797 - val_loss: 0.4266 - val_accuracy: 0.7825
# Epoch 108/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4293 - accuracy: 0.7798 - val_loss: 0.4266 - val_accuracy: 0.7824
# Epoch 109/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4292 - accuracy: 0.7801 - val_loss: 0.4261 - val_accuracy: 0.7831
# Epoch 110/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4290 - accuracy: 0.7798 - val_loss: 0.4268 - val_accuracy: 0.7809
# Epoch 111/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4290 - accuracy: 0.7798 - val_loss: 0.4263 - val_accuracy: 0.7816
# Epoch 112/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4289 - accuracy: 0.7801 - val_loss: 0.4318 - val_accuracy: 0.7798
# Epoch 113/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4288 - accuracy: 0.7798 - val_loss: 0.4272 - val_accuracy: 0.7823
# Epoch 114/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4286 - accuracy: 0.7799 - val_loss: 0.4286 - val_accuracy: 0.7809
# Epoch 115/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4284 - accuracy: 0.7800 - val_loss: 0.4269 - val_accuracy: 0.7822
# Epoch 116/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4284 - accuracy: 0.7800 - val_loss: 0.4267 - val_accuracy: 0.7820
# Epoch 117/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4283 - accuracy: 0.7801 - val_loss: 0.4295 - val_accuracy: 0.7790
# Epoch 118/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4281 - accuracy: 0.7808 - val_loss: 0.4263 - val_accuracy: 0.7802
# Epoch 119/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4281 - accuracy: 0.7805 - val_loss: 0.4290 - val_accuracy: 0.7787
# Epoch 120/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4278 - accuracy: 0.7805 - val_loss: 0.4251 - val_accuracy: 0.7821
# Epoch 121/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4278 - accuracy: 0.7803 - val_loss: 0.4270 - val_accuracy: 0.7816
# Epoch 122/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4277 - accuracy: 0.7804 - val_loss: 0.4267 - val_accuracy: 0.7815
# Epoch 123/140
# 2971/2971 [==============================] - 55s 18ms/step - loss: 0.4274 - accuracy: 0.7805 - val_loss: 0.4305 - val_accuracy: 0.7796
# Epoch 124/140
# 2971/2971 [==============================] - 56s 19ms/step - loss: 0.4274 - accuracy: 0.7807 - val_loss: 0.4315 - val_accuracy: 0.7823
# Epoch 125/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4272 - accuracy: 0.7809 - val_loss: 0.4262 - val_accuracy: 0.7827
# Epoch 126/140
# 2971/2971 [==============================] - 55s 19ms/step - loss: 0.4271 - accuracy: 0.7807 - val_loss: 0.4263 - val_accuracy: 0.7835
# Epoch 127/140
# 2971/2971 [==============================] - 55s 18ms/step - loss: 0.4270 - accuracy: 0.7813 - val_loss: 0.4270 - val_accuracy: 0.7826
# Epoch 128/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4270 - accuracy: 0.7809 - val_loss: 0.4265 - val_accuracy: 0.7813
# Epoch 129/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4269 - accuracy: 0.7815 - val_loss: 0.4261 - val_accuracy: 0.7827
# Epoch 130/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4267 - accuracy: 0.7813 - val_loss: 0.4271 - val_accuracy: 0.7826
# Epoch 131/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4266 - accuracy: 0.7814 - val_loss: 0.4271 - val_accuracy: 0.7835
# Epoch 132/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4265 - accuracy: 0.7812 - val_loss: 0.4270 - val_accuracy: 0.7830
# Epoch 133/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4264 - accuracy: 0.7815 - val_loss: 0.4284 - val_accuracy: 0.7827
# Epoch 134/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4264 - accuracy: 0.7814 - val_loss: 0.4328 - val_accuracy: 0.7745
# Epoch 135/140
# 2971/2971 [==============================] - 57s 19ms/step - loss: 0.4263 - accuracy: 0.7811 - val_loss: 0.4283 - val_accuracy: 0.7827
# Epoch 136/140
# 2971/2971 [==============================] - 55s 18ms/step - loss: 0.4262 - accuracy: 0.7816 - val_loss: 0.4263 - val_accuracy: 0.7820
# Epoch 137/140
# 2971/2971 [==============================] - 55s 19ms/step - loss: 0.4260 - accuracy: 0.7817 - val_loss: 0.4256 - val_accuracy: 0.7822
# Epoch 138/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4259 - accuracy: 0.7815 - val_loss: 0.4263 - val_accuracy: 0.7806
# Epoch 139/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4258 - accuracy: 0.7812 - val_loss: 0.4248 - val_accuracy: 0.7825
# Epoch 140/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4256 - accuracy: 0.7821 - val_loss: 0.4255 - val_accuracy: 0.7821

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 17s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 6688.620250225067

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00094028],
#        [0.00096054],
#        [0.00029563],
#        ...,
#        [0.08176034],
#        [0.08622895],
#        [0.0889257 ]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.142700224795809
# 0.23264634593830746
# 0.3777568328909604
# 0.28932862088537004

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 78s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.59650495]
# [0.8305324]
# total acc [0.78204413]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
