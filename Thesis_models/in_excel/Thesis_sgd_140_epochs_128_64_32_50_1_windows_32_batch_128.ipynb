# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x23000003040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x22f8c13f040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#activation='relu'),
    keras.layers.GRU(units=32),#activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 79s 22ms/step - loss: 0.5740 - accuracy: 0.7383 - val_loss: 0.5571 - val_accuracy: 0.7530
# Epoch 2/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.5660 - accuracy: 0.7393 - val_loss: 0.5448 - val_accuracy: 0.7530
# Epoch 3/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.5362 - accuracy: 0.7402 - val_loss: 0.5044 - val_accuracy: 0.7537
140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4309 - accuracy: 0.7792 - val_loss: 0.4430 - val_accuracy: 0.7794
# Epoch 92/140
# 2971/2971 [==============================] - 61s 21ms/step - loss: 0.4307 - accuracy: 0.7792 - val_loss: 0.4294 - val_accuracy: 0.7787
# Epoch 93/140
# 2971/2971 [==============================] - 60s 20ms/step - loss: 0.4305 - accuracy: 0.7793 - val_loss: 0.4285 - val_accuracy: 0.7813
# Epoch 94/140
# 2971/2971 [==============================] - 61s 20ms/step - loss: 0.4302 - accuracy: 0.7796 - val_loss: 0.4282 - val_accuracy: 0.7811
# Epoch 95/140
# 2971/2971 [==============================] - 61s 21ms/step - loss: 0.4299 - accuracy: 0.7796 - val_loss: 0.4293 - val_accuracy: 0.7799
# Epoch 96/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4297 - accuracy: 0.7798 - val_loss: 0.4301 - val_accuracy: 0.7795
# Epoch 97/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4296 - accuracy: 0.7798 - val_loss: 0.4273 - val_accuracy: 0.7814
# Epoch 98/140
# 2971/2971 [==============================] - 61s 21ms/step - loss: 0.4294 - accuracy: 0.7798 - val_loss: 0.4356 - val_accuracy: 0.7738
# Epoch 99/140
# 2971/2971 [==============================] - 60s 20ms/step - loss: 0.4292 - accuracy: 0.7800 - val_loss: 0.4279 - val_accuracy: 0.7802
# Epoch 100/140
# 2971/2971 [==============================] - 61s 20ms/step - loss: 0.4290 - accuracy: 0.7797 - val_loss: 0.4285 - val_accuracy: 0.7804
# Epoch 101/140
# 2971/2971 [==============================] - 60s 20ms/step - loss: 0.4288 - accuracy: 0.7803 - val_loss: 0.4313 - val_accuracy: 0.7775
# Epoch 102/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4287 - accuracy: 0.7805 - val_loss: 0.4265 - val_accuracy: 0.7822
# Epoch 103/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4283 - accuracy: 0.7803 - val_loss: 0.4328 - val_accuracy: 0.7822
# Epoch 104/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4282 - accuracy: 0.7803 - val_loss: 0.4274 - val_accuracy: 0.7803
# Epoch 105/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4280 - accuracy: 0.7804 - val_loss: 0.4325 - val_accuracy: 0.7814
# Epoch 106/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4278 - accuracy: 0.7807 - val_loss: 0.4302 - val_accuracy: 0.7825
# Epoch 107/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4276 - accuracy: 0.7808 - val_loss: 0.4342 - val_accuracy: 0.7817
# Epoch 108/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4273 - accuracy: 0.7809 - val_loss: 0.4267 - val_accuracy: 0.7833
# Epoch 109/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4271 - accuracy: 0.7808 - val_loss: 0.4259 - val_accuracy: 0.7819
# Epoch 110/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4271 - accuracy: 0.7813 - val_loss: 0.4271 - val_accuracy: 0.7803
# Epoch 111/140
# 2971/2971 [==============================] - 60s 20ms/step - loss: 0.4267 - accuracy: 0.7810 - val_loss: 0.4264 - val_accuracy: 0.7832
# Epoch 112/140
# 2971/2971 [==============================] - 61s 21ms/step - loss: 0.4265 - accuracy: 0.7811 - val_loss: 0.4257 - val_accuracy: 0.7824
# Epoch 113/140
# 2971/2971 [==============================] - 61s 21ms/step - loss: 0.4264 - accuracy: 0.7812 - val_loss: 0.4266 - val_accuracy: 0.7816
# Epoch 114/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.4261 - accuracy: 0.7818 - val_loss: 0.4309 - val_accuracy: 0.7769
# Epoch 115/140
# 2971/2971 [==============================] - 64s 22ms/step - loss: 0.4262 - accuracy: 0.7818 - val_loss: 0.4250 - val_accuracy: 0.7825
# Epoch 116/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0
140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4229 - accuracy: 0.7830 - val_loss: 0.4266 - val_accuracy: 0.7842
# Epoch 138/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.4228 - accuracy: 0.7833 - val_loss: 0.4310 - val_accuracy: 0.7837
# Epoch 139/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.4227 - accuracy: 0.7837 - val_loss: 0.4277 - val_accuracy: 0.7833
# Epoch 140/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4225 - accuracy: 0.7837 - val_loss: 0.4307 - val_accuracy: 0.7829

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 21s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 8681.499318599701

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.0023145 ],
#        [0.01111389],
#        [0.00351905],
#        ...,
#        [0.0380477 ],
#        [0.03937908],
#        [0.0413217 ]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14333871214994473
# 0.22923475189157538
# 0.37860099332931596
# 0.28217467006584535

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 98s 7ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60902969]
# [0.8235439]
# total acc [0.78312873]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
