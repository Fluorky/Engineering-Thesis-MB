# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1a58000d040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1a5df817040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 10s 136ms/step - loss: 0.5997 - accuracy: 0.7182 - val_loss: 0.5586 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.5733 - accuracy: 0.7393 - val_loss: 0.5571 - val_accuracy: 0.7531
# Epoch 3/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.5632 - accuracy: 0.7392 - val_loss: 0.5348 - val_accuracy: 0.7365
# Epoch 4/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.5293 - accuracy: 0.7368 - val_loss: 0.4987 - val_accuracy: 0.7531
# Epoch 5/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.5069 - accuracy: 0.7387 - val_loss: 0.4882 - val_accuracy: 0.7535
# Epoch 6/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.5002 - accuracy: 0.7403 - val_loss: 0.4864 - val_accuracy: 0.7541
# Epoch 7/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4956 - accuracy: 0.7439 - val_loss: 0.4816 - val_accuracy: 0.7529
# Epoch 8/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4917 - accuracy: 0.7467 - val_loss: 0.4794 - val_accuracy: 0.7514
# Epoch 9/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4881 - accuracy: 0.7478 - val_loss: 0.4811 - val_accuracy: 0.7505
# Epoch 10/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4842 - accuracy: 0.7482 - val_loss: 0.4757 - val_accuracy: 0.7496
# Epoch 11/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4786 - accuracy: 0.7509 - val_loss: 0.4703 - val_accuracy: 0.7511
# Epoch 12/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4731 - accuracy: 0.7544 - val_loss: 0.4657 - val_accuracy: 0.7604
# Epoch 13/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4686 - accuracy: 0.7568 - val_loss: 0.4559 - val_accuracy: 0.7628
# Epoch 14/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4672 - accuracy: 0.7572 - val_loss: 0.4557 - val_accuracy: 0.7641
# Epoch 15/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4646 - accuracy: 0.7585 - val_loss: 0.4547 - val_accuracy: 0.7646
# Epoch 16/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4599 - accuracy: 0.7602 - val_loss: 0.4667 - val_accuracy: 0.7658
# Epoch 17/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4606 - accuracy: 0.7608 - val_loss: 0.4489 - val_accuracy: 0.7652
# Epoch 18/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4571 - accuracy: 0.7615 - val_loss: 0.4500 - val_accuracy: 0.7679
# Epoch 19/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4557 - accuracy: 0.7629 - val_loss: 0.4489 - val_accuracy: 0.7682
# Epoch 20/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4565 - accuracy: 0.7634 - val_loss: 0.4485 - val_accuracy: 0.7676
# Epoch 21/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4536 - accuracy: 0.7649 - val_loss: 0.4437 - val_accuracy: 0.7710
# Epoch 22/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4526 - accuracy: 0.7653 - val_loss: 0.4431 - val_accuracy: 0.7709
# Epoch 23/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4517 - accuracy: 0.7659 - val_loss: 0.4459 - val_accuracy: 0.7713
# Epoch 24/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4509 - accuracy: 0.7667 - val_loss: 0.4441 - val_accuracy: 0.7720
# Epoch 25/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4495 - accuracy: 0.7673 - val_loss: 0.4465 - val_accuracy: 0.7713
# Epoch 26/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4495 - accuracy: 0.7672 - val_loss: 0.4437 - val_accuracy: 0.7724
# Epoch 27/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4486 - accuracy: 0.7680 - val_loss: 0.4424 - val_accuracy: 0.7731
# Epoch 28/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4484 - accuracy: 0.7685 - val_loss: 0.4410 - val_accuracy: 0.7745
# Epoch 29/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4471 - accuracy: 0.7690 - val_loss: 0.4413 - val_accuracy: 0.7733
# Epoch 30/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4472 - accuracy: 0.7687 - val_loss: 0.4397 - val_accuracy: 0.7742
# Epoch 31/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4468 - accuracy: 0.7692 - val_loss: 0.4411 - val_accuracy: 0.7735
# Epoch 32/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4469 - accuracy: 0.7694 - val_loss: 0.4412 - val_accuracy: 0.7749
# Epoch 33/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4462 - accuracy: 0.7700 - val_loss: 0.4383 - val_accuracy: 0.7750
# Epoch 34/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4449 - accuracy: 0.7700 - val_loss: 0.4388 - val_accuracy: 0.7748
# Epoch 35/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4449 - accuracy: 0.7704 - val_loss: 0.4405 - val_accuracy: 0.7757
# Epoch 36/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4439 - accuracy: 0.7702 - val_loss: 0.4430 - val_accuracy: 0.7740
# Epoch 37/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4448 - accuracy: 0.7704 - val_loss: 0.4372 - val_accuracy: 0.7762
# Epoch 38/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4434 - accuracy: 0.7708 - val_loss: 0.4369 - val_accuracy: 0.7763
# Epoch 39/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4423 - accuracy: 0.7711 - val_loss: 0.4366 - val_accuracy: 0.7758
# Epoch 40/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4444 - accuracy: 0.7709 - val_loss: 0.4408 - val_accuracy: 0.7744
# Epoch 41/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4428 - accuracy: 0.7710 - val_loss: 0.4380 - val_accuracy: 0.7763
# Epoch 42/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4424 - accuracy: 0.7716 - val_loss: 0.4406 - val_accuracy: 0.7750
# Epoch 43/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4418 - accuracy: 0.7719 - val_loss: 0.4436 - val_accuracy: 0.7763
# Epoch 44/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4419 - accuracy: 0.7720 - val_loss: 0.4366 - val_accuracy: 0.7770
# Epoch 45/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4411 - accuracy: 0.7722 - val_loss: 0.4380 - val_accuracy: 0.7770
# Epoch 46/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4401 - accuracy: 0.7724 - val_loss: 0.4385 - val_accuracy: 0.7754
# Epoch 47/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4411 - accuracy: 0.7725 - val_loss: 0.4387 - val_accuracy: 0.7760
# Epoch 48/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4403 - accuracy: 0.7732 - val_loss: 0.4388 - val_accuracy: 0.7777
# Epoch 49/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4425 - accuracy: 0.7726 - val_loss: 0.4363 - val_accuracy: 0.7768
# Epoch 50/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4398 - accuracy: 0.7734 - val_loss: 0.4379 - val_accuracy: 0.7762
# Epoch 51/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4395 - accuracy: 0.7736 - val_loss: 0.4374 - val_accuracy: 0.7776
# Epoch 52/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4390 - accuracy: 0.7741 - val_loss: 0.4397 - val_accuracy: 0.7764
# Epoch 53/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4394 - accuracy: 0.7740 - val_loss: 0.4429 - val_accuracy: 0.7763
# Epoch 54/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4390 - accuracy: 0.7740 - val_loss: 0.4363 - val_accuracy: 0.7766
# Epoch 55/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4380 - accuracy: 0.7748 - val_loss: 0.4368 - val_accuracy: 0.7775
# Epoch 56/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4432 - accuracy: 0.7737 - val_loss: 0.4368 - val_accuracy: 0.7785
# Epoch 57/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4383 - accuracy: 0.7751 - val_loss: 0.4361 - val_accuracy: 0.7761
# Epoch 58/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4368 - accuracy: 0.7755 - val_loss: 0.4351 - val_accuracy: 0.7774
# Epoch 59/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4384 - accuracy: 0.7755 - val_loss: 0.4341 - val_accuracy: 0.7786
# Epoch 60/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4365 - accuracy: 0.7755 - val_loss: 0.4322 - val_accuracy: 0.7798
# Epoch 61/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4358 - accuracy: 0.7762 - val_loss: 0.4326 - val_accuracy: 0.7794
# Epoch 62/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4360 - accuracy: 0.7758 - val_loss: 0.4330 - val_accuracy: 0.7796
# Epoch 63/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4363 - accuracy: 0.7766 - val_loss: 0.4416 - val_accuracy: 0.7772
# Epoch 64/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4364 - accuracy: 0.7760 - val_loss: 0.4333 - val_accuracy: 0.7793
# Epoch 65/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4348 - accuracy: 0.7769 - val_loss: 0.4326 - val_accuracy: 0.7791
# Epoch 66/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4342 - accuracy: 0.7771 - val_loss: 0.4315 - val_accuracy: 0.7804
# Epoch 67/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4339 - accuracy: 0.7773 - val_loss: 0.4307 - val_accuracy: 0.7810
# Epoch 68/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4338 - accuracy: 0.7772 - val_loss: 0.4309 - val_accuracy: 0.7810
# Epoch 69/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4336 - accuracy: 0.7776 - val_loss: 0.4365 - val_accuracy: 0.7792
# Epoch 70/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4341 - accuracy: 0.7775 - val_loss: 0.4390 - val_accuracy: 0.7797
# Epoch 71/140
# 24/24 [==============================] - 2s 86ms/step - loss: 0.4339 - accuracy: 0.7778 - val_loss: 0.4323 - val_accuracy: 0.7808
# Epoch 72/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4326 - accuracy: 0.7780 - val_loss: 0.4401 - val_accuracy: 0.7777
# Epoch 73/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4337 - accuracy: 0.7775 - val_loss: 0.4288 - val_accuracy: 0.7809
# Epoch 74/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4343 - accuracy: 0.7781 - val_loss: 0.4334 - val_accuracy: 0.7792
# Epoch 75/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4330 - accuracy: 0.7779 - val_loss: 0.4324 - val_accuracy: 0.7805
# Epoch 76/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4348 - accuracy: 0.7774 - val_loss: 0.4289 - val_accuracy: 0.7806
# Epoch 77/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4322 - accuracy: 0.7783 - val_loss: 0.4312 - val_accuracy: 0.7815
# Epoch 78/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4315 - accuracy: 0.7788 - val_loss: 0.4355 - val_accuracy: 0.7814
# Epoch 79/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4348 - accuracy: 0.7777 - val_loss: 0.4292 - val_accuracy: 0.7809
# Epoch 80/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4327 - accuracy: 0.7786 - val_loss: 0.4311 - val_accuracy: 0.7809
# Epoch 81/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4311 - accuracy: 0.7794 - val_loss: 0.4287 - val_accuracy: 0.7816
# Epoch 82/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4306 - accuracy: 0.7792 - val_loss: 0.4330 - val_accuracy: 0.7752
# Epoch 83/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4321 - accuracy: 0.7790 - val_loss: 0.4309 - val_accuracy: 0.7813
# Epoch 84/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4311 - accuracy: 0.7792 - val_loss: 0.4306 - val_accuracy: 0.7811
# Epoch 85/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4307 - accuracy: 0.7794 - val_loss: 0.4296 - val_accuracy: 0.7823
# Epoch 86/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4303 - accuracy: 0.7798 - val_loss: 0.4287 - val_accuracy: 0.7813
# Epoch 87/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4300 - accuracy: 0.7799 - val_loss: 0.4274 - val_accuracy: 0.7816
# Epoch 88/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4301 - accuracy: 0.7799 - val_loss: 0.4335 - val_accuracy: 0.7816
# Epoch 89/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4299 - accuracy: 0.7800 - val_loss: 0.4272 - val_accuracy: 0.7825
# Epoch 90/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4290 - accuracy: 0.7801 - val_loss: 0.4335 - val_accuracy: 0.7780
# Epoch 91/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4303 - accuracy: 0.7795 - val_loss: 0.4332 - val_accuracy: 0.7792
# Epoch 92/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4304 - accuracy: 0.7793 - val_loss: 0.4296 - val_accuracy: 0.7826
# Epoch 93/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4284 - accuracy: 0.7801 - val_loss: 0.4292 - val_accuracy: 0.7810
# Epoch 94/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4282 - accuracy: 0.7808 - val_loss: 0.4311 - val_accuracy: 0.7831
# Epoch 95/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4287 - accuracy: 0.7805 - val_loss: 0.4265 - val_accuracy: 0.7824
# Epoch 96/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4294 - accuracy: 0.7800 - val_loss: 0.4303 - val_accuracy: 0.7833
# Epoch 97/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4281 - accuracy: 0.7803 - val_loss: 0.4285 - val_accuracy: 0.7831
# Epoch 98/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4298 - accuracy: 0.7803 - val_loss: 0.4293 - val_accuracy: 0.7806
# Epoch 99/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4280 - accuracy: 0.7809 - val_loss: 0.4287 - val_accuracy: 0.7823
# Epoch 100/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4271 - accuracy: 0.7811 - val_loss: 0.4302 - val_accuracy: 0.7821
# Epoch 101/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4272 - accuracy: 0.7810 - val_loss: 0.4285 - val_accuracy: 0.7809
# Epoch 102/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4267 - accuracy: 0.7811 - val_loss: 0.4297 - val_accuracy: 0.7821
# Epoch 103/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4269 - accuracy: 0.7812 - val_loss: 0.4306 - val_accuracy: 0.7834
# Epoch 104/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4263 - accuracy: 0.7815 - val_loss: 0.4264 - val_accuracy: 0.7832
# Epoch 105/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4269 - accuracy: 0.7816 - val_loss: 0.4345 - val_accuracy: 0.7817
# Epoch 106/140
# 24/24 [==============================] - 2s 87ms/step - loss: 0.4290 - accuracy: 0.7811 - val_loss: 0.4360 - val_accuracy: 0.7820
# Epoch 107/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4272 - accuracy: 0.7816 - val_loss: 0.4338 - val_accuracy: 0.7824
# Epoch 108/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4272 - accuracy: 0.7812 - val_loss: 0.4295 - val_accuracy: 0.7822
# Epoch 109/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4259 - accuracy: 0.7820 - val_loss: 0.4271 - val_accuracy: 0.7829
# Epoch 110/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4258 - accuracy: 0.7819 - val_loss: 0.4265 - val_accuracy: 0.7829
# Epoch 111/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4264 - accuracy: 0.7817 - val_loss: 0.4264 - val_accuracy: 0.7833
# Epoch 112/140
# 24/24 [==============================] - 2s 86ms/step - loss: 0.4271 - accuracy: 0.7812 - val_loss: 0.4248 - val_accuracy: 0.7830
# Epoch 113/140
# 24/24 [==============================] - 2s 87ms/step - loss: 0.4259 - accuracy: 0.7816 - val_loss: 0.4280 - val_accuracy: 0.7816
# Epoch 114/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4261 - accuracy: 0.7818 - val_loss: 0.4259 - val_accuracy: 0.7829
# Epoch 115/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4252 - accuracy: 0.7818 - val_loss: 0.4269 - val_accuracy: 0.7838
# Epoch 116/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4248 - accuracy: 0.7822 - val_loss: 0.4270 - val_accuracy: 0.7834
# Epoch 117/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4242 - accuracy: 0.7822 - val_loss: 0.4257 - val_accuracy: 0.7833
# Epoch 118/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4250 - accuracy: 0.7823 - val_loss: 0.4263 - val_accuracy: 0.7834
# Epoch 119/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4251 - accuracy: 0.7823 - val_loss: 0.4305 - val_accuracy: 0.7835
# Epoch 120/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4240 - accuracy: 0.7827 - val_loss: 0.4307 - val_accuracy: 0.7836
# Epoch 121/140
# 24/24 [==============================] - 2s 86ms/step - loss: 0.4246 - accuracy: 0.7823 - val_loss: 0.4291 - val_accuracy: 0.7818
# Epoch 122/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4283 - accuracy: 0.7815 - val_loss: 0.4251 - val_accuracy: 0.7839
# Epoch 123/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4247 - accuracy: 0.7826 - val_loss: 0.4256 - val_accuracy: 0.7835
# Epoch 124/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4237 - accuracy: 0.7830 - val_loss: 0.4305 - val_accuracy: 0.7835
# Epoch 125/140
# 24/24 [==============================] - 2s 86ms/step - loss: 0.4229 - accuracy: 0.7831 - val_loss: 0.4272 - val_accuracy: 0.7840
# Epoch 126/140
# 24/24 [==============================] - 2s 87ms/step - loss: 0.4237 - accuracy: 0.7826 - val_loss: 0.4248 - val_accuracy: 0.7839
# Epoch 127/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4232 - accuracy: 0.7833 - val_loss: 0.4264 - val_accuracy: 0.7839
# Epoch 128/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4235 - accuracy: 0.7829 - val_loss: 0.4257 - val_accuracy: 0.7828
# Epoch 129/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4253 - accuracy: 0.7830 - val_loss: 0.4286 - val_accuracy: 0.7823
# Epoch 130/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4244 - accuracy: 0.7831 - val_loss: 0.4248 - val_accuracy: 0.7824
# Epoch 131/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4228 - accuracy: 0.7833 - val_loss: 0.4265 - val_accuracy: 0.7831
# Epoch 132/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4222 - accuracy: 0.7838 - val_loss: 0.4232 - val_accuracy: 0.7838
# Epoch 133/140
# 24/24 [==============================] - 2s 87ms/step - loss: 0.4219 - accuracy: 0.7839 - val_loss: 0.4255 - val_accuracy: 0.7829
# Epoch 134/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4218 - accuracy: 0.7837 - val_loss: 0.4250 - val_accuracy: 0.7843
# Epoch 135/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4221 - accuracy: 0.7839 - val_loss: 0.4264 - val_accuracy: 0.7842
# Epoch 136/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4230 - accuracy: 0.7835 - val_loss: 0.4281 - val_accuracy: 0.7818
# Epoch 137/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4224 - accuracy: 0.7839 - val_loss: 0.4318 - val_accuracy: 0.7840
# Epoch 138/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4223 - accuracy: 0.7840 - val_loss: 0.4270 - val_accuracy: 0.7835
# Epoch 139/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4218 - accuracy: 0.7839 - val_loss: 0.4270 - val_accuracy: 0.7839
# Epoch 140/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4212 - accuracy: 0.7841 - val_loss: 0.4319 - val_accuracy: 0.7838

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 305.7612552642822

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00431565],
#        [0.00332201],
#        [0.00146006],
#        ...,
#        [0.03017806],
#        [0.03162671],
#        [0.03192004]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14347397358751293
# 0.22848560292974218
# 0.37877958443864546
# 0.2801878856920931

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 83s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.6210065]
# [0.81841932]
# total acc [0.78411221]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 548989184, 'peak': 2741075456}
