# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2050000d040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2057c6fb040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='MeanSquaredError', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 131s 38ms/step - loss: 0.1927 - accuracy: 0.7393 - val_loss: 0.1857 - val_accuracy: 0.7531
# Epoch 2/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.1919 - accuracy: 0.7393 - val_loss: 0.1849 - val_accuracy: 0.7531
# Epoch 3/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.1905 - accuracy: 0.7393 - val_loss: 0.1830 - val_accuracy: 0.7531
# Epoch 4/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1874 - accuracy: 0.7393 - val_loss: 0.1790 - val_accuracy: 0.7531
# Epoch 5/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1818 - accuracy: 0.7395 - val_loss: 0.1737 - val_accuracy: 0.7531
# Epoch 6/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1769 - accuracy: 0.7414 - val_loss: 0.1698 - val_accuracy: 0.7535
# Epoch 7/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1728 - accuracy: 0.7419 - val_loss: 0.1658 - val_accuracy: 0.7542
# Epoch 8/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1704 - accuracy: 0.7403 - val_loss: 0.1644 - val_accuracy: 0.7525
# Epoch 9/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.1695 - accuracy: 0.7394 - val_loss: 0.1638 - val_accuracy: 0.7528
# Epoch 10/140
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.1692 - accuracy: 0.7392 - val_loss: 0.1634 - val_accuracy: 0.7531
# Epoch 11/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.1690 - accuracy: 0.7392 - val_loss: 0.1633 - val_accuracy: 0.7530
# Epoch 12/140
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.1689 - accuracy: 0.7390 - val_loss: 0.1632 - val_accuracy: 0.7529
# Epoch 13/140
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.1688 - accuracy: 0.7391 - val_loss: 0.1634 - val_accuracy: 0.7527
# Epoch 14/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1687 - accuracy: 0.7389 - val_loss: 0.1633 - val_accuracy: 0.7528
# Epoch 15/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1686 - accuracy: 0.7391 - val_loss: 0.1628 - val_accuracy: 0.7526
# Epoch 16/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1685 - accuracy: 0.7393 - val_loss: 0.1632 - val_accuracy: 0.7528
# Epoch 17/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1684 - accuracy: 0.7395 - val_loss: 0.1630 - val_accuracy: 0.7528
# Epoch 18/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1683 - accuracy: 0.7399 - val_loss: 0.1627 - val_accuracy: 0.7525
# Epoch 19/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1681 - accuracy: 0.7400 - val_loss: 0.1624 - val_accuracy: 0.7529
# Epoch 20/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1680 - accuracy: 0.7405 - val_loss: 0.1622 - val_accuracy: 0.7534
# Epoch 21/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1678 - accuracy: 0.7410 - val_loss: 0.1621 - val_accuracy: 0.7529
# Epoch 22/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1676 - accuracy: 0.7416 - val_loss: 0.1619 - val_accuracy: 0.7528
# Epoch 23/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1674 - accuracy: 0.7422 - val_loss: 0.1618 - val_accuracy: 0.7531
# Epoch 24/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1672 - accuracy: 0.7432 - val_loss: 0.1624 - val_accuracy: 0.7527
# Epoch 25/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1668 - accuracy: 0.7443 - val_loss: 0.1620 - val_accuracy: 0.7526
# Epoch 26/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1665 - accuracy: 0.7448 - val_loss: 0.1615 - val_accuracy: 0.7525
# Epoch 27/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1660 - accuracy: 0.7458 - val_loss: 0.1615 - val_accuracy: 0.7529
# Epoch 28/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1655 - accuracy: 0.7467 - val_loss: 0.1609 - val_accuracy: 0.7531
# Epoch 29/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1648 - accuracy: 0.7474 - val_loss: 0.1606 - val_accuracy: 0.7533
# Epoch 30/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1642 - accuracy: 0.7477 - val_loss: 0.1611 - val_accuracy: 0.7518
# Epoch 31/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1635 - accuracy: 0.7478 - val_loss: 0.1610 - val_accuracy: 0.7514
# Epoch 32/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1630 - accuracy: 0.7479 - val_loss: 0.1610 - val_accuracy: 0.7517
# Epoch 33/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1624 - accuracy: 0.7485 - val_loss: 0.1603 - val_accuracy: 0.7522
# Epoch 34/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1619 - accuracy: 0.7490 - val_loss: 0.1592 - val_accuracy: 0.7532
# Epoch 35/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1614 - accuracy: 0.7500 - val_loss: 0.1595 - val_accuracy: 0.7520
# Epoch 36/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1609 - accuracy: 0.7508 - val_loss: 0.1585 - val_accuracy: 0.7550
# Epoch 37/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1604 - accuracy: 0.7516 - val_loss: 0.1575 - val_accuracy: 0.7575
# Epoch 38/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1600 - accuracy: 0.7526 - val_loss: 0.1572 - val_accuracy: 0.7579
# Epoch 39/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1595 - accuracy: 0.7529 - val_loss: 0.1568 - val_accuracy: 0.7577
# Epoch 40/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1592 - accuracy: 0.7536 - val_loss: 0.1567 - val_accuracy: 0.7573
# Epoch 41/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1588 - accuracy: 0.7541 - val_loss: 0.1560 - val_accuracy: 0.7595
# Epoch 42/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1585 - accuracy: 0.7543 - val_loss: 0.1571 - val_accuracy: 0.7568
# Epoch 43/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1583 - accuracy: 0.7543 - val_loss: 0.1553 - val_accuracy: 0.7590
# Epoch 44/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1581 - accuracy: 0.7550 - val_loss: 0.1556 - val_accuracy: 0.7585
# Epoch 45/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1578 - accuracy: 0.7548 - val_loss: 0.1562 - val_accuracy: 0.7586
# Epoch 46/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1576 - accuracy: 0.7551 - val_loss: 0.1546 - val_accuracy: 0.7603
# Epoch 47/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1575 - accuracy: 0.7553 - val_loss: 0.1547 - val_accuracy: 0.7595
# Epoch 48/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1573 - accuracy: 0.7553 - val_loss: 0.1547 - val_accuracy: 0.7597
# Epoch 49/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1571 - accuracy: 0.7556 - val_loss: 0.1539 - val_accuracy: 0.7600
# Epoch 50/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1569 - accuracy: 0.7557 - val_loss: 0.1550 - val_accuracy: 0.7584
# Epoch 51/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1568 - accuracy: 0.7560 - val_loss: 0.1538 - val_accuracy: 0.7608
# Epoch 52/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1566 - accuracy: 0.7559 - val_loss: 0.1534 - val_accuracy: 0.7611
# Epoch 53/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1564 - accuracy: 0.7564 - val_loss: 0.1534 - val_accuracy: 0.7622
# Epoch 54/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1563 - accuracy: 0.7567 - val_loss: 0.1537 - val_accuracy: 0.7618
# Epoch 55/140
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.1561 - accuracy: 0.7572 - val_loss: 0.1531 - val_accuracy: 0.7613
# Epoch 56/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1560 - accuracy: 0.7573 - val_loss: 0.1541 - val_accuracy: 0.7603
# Epoch 57/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1558 - accuracy: 0.7573 - val_loss: 0.1549 - val_accuracy: 0.7622
# Epoch 58/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1557 - accuracy: 0.7577 - val_loss: 0.1523 - val_accuracy: 0.7637
# Epoch 59/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1556 - accuracy: 0.7579 - val_loss: 0.1534 - val_accuracy: 0.7640
# Epoch 60/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1554 - accuracy: 0.7576 - val_loss: 0.1526 - val_accuracy: 0.7641
# Epoch 61/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1553 - accuracy: 0.7581 - val_loss: 0.1525 - val_accuracy: 0.7626
# Epoch 62/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1552 - accuracy: 0.7579 - val_loss: 0.1525 - val_accuracy: 0.7623
# Epoch 63/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1551 - accuracy: 0.7583 - val_loss: 0.1523 - val_accuracy: 0.7650
# Epoch 64/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1550 - accuracy: 0.7587 - val_loss: 0.1518 - val_accuracy: 0.7633
# Epoch 65/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1548 - accuracy: 0.7588 - val_loss: 0.1522 - val_accuracy: 0.7630
# Epoch 66/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1547 - accuracy: 0.7588 - val_loss: 0.1516 - val_accuracy: 0.7637
# Epoch 67/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1547 - accuracy: 0.7589 - val_loss: 0.1513 - val_accuracy: 0.7645
# Epoch 68/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1545 - accuracy: 0.7590 - val_loss: 0.1517 - val_accuracy: 0.7648
# Epoch 69/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1545 - accuracy: 0.7596 - val_loss: 0.1513 - val_accuracy: 0.7646
# Epoch 70/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1544 - accuracy: 0.7599 - val_loss: 0.1515 - val_accuracy: 0.7639
# Epoch 71/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1542 - accuracy: 0.7602 - val_loss: 0.1521 - val_accuracy: 0.7646
# Epoch 72/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1541 - accuracy: 0.7598 - val_loss: 0.1511 - val_accuracy: 0.7662
# Epoch 73/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1540 - accuracy: 0.7602 - val_loss: 0.1512 - val_accuracy: 0.7646
# Epoch 74/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1539 - accuracy: 0.7604 - val_loss: 0.1515 - val_accuracy: 0.7645
# Epoch 75/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1538 - accuracy: 0.7605 - val_loss: 0.1519 - val_accuracy: 0.7648
# Epoch 76/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1537 - accuracy: 0.7608 - val_loss: 0.1506 - val_accuracy: 0.7662
# Epoch 77/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1536 - accuracy: 0.7613 - val_loss: 0.1507 - val_accuracy: 0.7662
# Epoch 78/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1536 - accuracy: 0.7609 - val_loss: 0.1510 - val_accuracy: 0.7669
# Epoch 79/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1534 - accuracy: 0.7614 - val_loss: 0.1503 - val_accuracy: 0.7663
# Epoch 80/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1533 - accuracy: 0.7618 - val_loss: 0.1502 - val_accuracy: 0.7669
# Epoch 81/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1532 - accuracy: 0.7620 - val_loss: 0.1505 - val_accuracy: 0.7676
# Epoch 82/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1531 - accuracy: 0.7625 - val_loss: 0.1497 - val_accuracy: 0.7683
# Epoch 83/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1530 - accuracy: 0.7628 - val_loss: 0.1496 - val_accuracy: 0.7688
# Epoch 84/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1529 - accuracy: 0.7627 - val_loss: 0.1509 - val_accuracy: 0.7676
# Epoch 85/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1528 - accuracy: 0.7631 - val_loss: 0.1504 - val_accuracy: 0.7685
# Epoch 86/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1527 - accuracy: 0.7635 - val_loss: 0.1499 - val_accuracy: 0.7689
# Epoch 87/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1525 - accuracy: 0.7640 - val_loss: 0.1508 - val_accuracy: 0.7683
# Epoch 88/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1524 - accuracy: 0.7640 - val_loss: 0.1493 - val_accuracy: 0.7696
# Epoch 89/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1523 - accuracy: 0.7643 - val_loss: 0.1493 - val_accuracy: 0.7692
# Epoch 90/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1522 - accuracy: 0.7644 - val_loss: 0.1494 - val_accuracy: 0.7698
# Epoch 91/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1521 - accuracy: 0.7648 - val_loss: 0.1490 - val_accuracy: 0.7694
# Epoch 92/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1520 - accuracy: 0.7653 - val_loss: 0.1489 - val_accuracy: 0.7701
# Epoch 93/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1519 - accuracy: 0.7655 - val_loss: 0.1520 - val_accuracy: 0.7674
# Epoch 94/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1518 - accuracy: 0.7659 - val_loss: 0.1488 - val_accuracy: 0.7700
# Epoch 95/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1517 - accuracy: 0.7660 - val_loss: 0.1486 - val_accuracy: 0.7699
# Epoch 96/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1516 - accuracy: 0.7661 - val_loss: 0.1481 - val_accuracy: 0.7711
# Epoch 97/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1515 - accuracy: 0.7665 - val_loss: 0.1491 - val_accuracy: 0.7705
# Epoch 98/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1514 - accuracy: 0.7667 - val_loss: 0.1480 - val_accuracy: 0.7715
# Epoch 99/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1513 - accuracy: 0.7668 - val_loss: 0.1484 - val_accuracy: 0.7713
# Epoch 100/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1512 - accuracy: 0.7674 - val_loss: 0.1485 - val_accuracy: 0.7709
# Epoch 101/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1511 - accuracy: 0.7679 - val_loss: 0.1489 - val_accuracy: 0.7712
# Epoch 102/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1510 - accuracy: 0.7676 - val_loss: 0.1496 - val_accuracy: 0.7707
# Epoch 103/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1509 - accuracy: 0.7679 - val_loss: 0.1487 - val_accuracy: 0.7719
# Epoch 104/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1508 - accuracy: 0.7683 - val_loss: 0.1481 - val_accuracy: 0.7719
# Epoch 105/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1507 - accuracy: 0.7678 - val_loss: 0.1489 - val_accuracy: 0.7730
# Epoch 106/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1506 - accuracy: 0.7683 - val_loss: 0.1497 - val_accuracy: 0.7725
# Epoch 107/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1505 - accuracy: 0.7683 - val_loss: 0.1489 - val_accuracy: 0.7715
# Epoch 108/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1505 - accuracy: 0.7684 - val_loss: 0.1493 - val_accuracy: 0.7729
# Epoch 109/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1504 - accuracy: 0.7691 - val_loss: 0.1485 - val_accuracy: 0.7726
# Epoch 110/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1504 - accuracy: 0.7688 - val_loss: 0.1483 - val_accuracy: 0.7736
# Epoch 111/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1503 - accuracy: 0.7690 - val_loss: 0.1481 - val_accuracy: 0.7733
# Epoch 112/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1502 - accuracy: 0.7691 - val_loss: 0.1491 - val_accuracy: 0.7721
# Epoch 113/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1501 - accuracy: 0.7695 - val_loss: 0.1473 - val_accuracy: 0.7740
# Epoch 114/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1501 - accuracy: 0.7695 - val_loss: 0.1477 - val_accuracy: 0.7735
# Epoch 115/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1500 - accuracy: 0.7694 - val_loss: 0.1471 - val_accuracy: 0.7744
# Epoch 116/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1499 - accuracy: 0.7696 - val_loss: 0.1477 - val_accuracy: 0.7743
# Epoch 117/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1498 - accuracy: 0.7701 - val_loss: 0.1477 - val_accuracy: 0.7744
# Epoch 118/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1497 - accuracy: 0.7700 - val_loss: 0.1480 - val_accuracy: 0.7741
# Epoch 119/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1497 - accuracy: 0.7701 - val_loss: 0.1471 - val_accuracy: 0.7742
# Epoch 120/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1496 - accuracy: 0.7703 - val_loss: 0.1475 - val_accuracy: 0.7750
# Epoch 121/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1496 - accuracy: 0.7706 - val_loss: 0.1479 - val_accuracy: 0.7751
# Epoch 122/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1495 - accuracy: 0.7703 - val_loss: 0.1473 - val_accuracy: 0.7745
# Epoch 123/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1495 - accuracy: 0.7706 - val_loss: 0.1483 - val_accuracy: 0.7741
# Epoch 124/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1494 - accuracy: 0.7707 - val_loss: 0.1475 - val_accuracy: 0.7745
# Epoch 125/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1493 - accuracy: 0.7710 - val_loss: 0.1487 - val_accuracy: 0.7738
# Epoch 126/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1493 - accuracy: 0.7710 - val_loss: 0.1467 - val_accuracy: 0.7750
# Epoch 127/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1492 - accuracy: 0.7708 - val_loss: 0.1473 - val_accuracy: 0.7748
# Epoch 128/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1491 - accuracy: 0.7713 - val_loss: 0.1470 - val_accuracy: 0.7755
# Epoch 129/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1491 - accuracy: 0.7712 - val_loss: 0.1473 - val_accuracy: 0.7748
# Epoch 130/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1491 - accuracy: 0.7712 - val_loss: 0.1474 - val_accuracy: 0.7749
# Epoch 131/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1490 - accuracy: 0.7713 - val_loss: 0.1471 - val_accuracy: 0.7755
# Epoch 132/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1490 - accuracy: 0.7718 - val_loss: 0.1468 - val_accuracy: 0.7754
# Epoch 133/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1489 - accuracy: 0.7715 - val_loss: 0.1467 - val_accuracy: 0.7752
# Epoch 134/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1488 - accuracy: 0.7716 - val_loss: 0.1466 - val_accuracy: 0.7759
# Epoch 135/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1488 - accuracy: 0.7718 - val_loss: 0.1467 - val_accuracy: 0.7755
# Epoch 136/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1487 - accuracy: 0.7721 - val_loss: 0.1466 - val_accuracy: 0.7755
# Epoch 137/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1487 - accuracy: 0.7720 - val_loss: 0.1475 - val_accuracy: 0.7754
# Epoch 138/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1486 - accuracy: 0.7719 - val_loss: 0.1465 - val_accuracy: 0.7763
# Epoch 139/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1485 - accuracy: 0.7723 - val_loss: 0.1464 - val_accuracy: 0.7753
# Epoch 140/140
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.1485 - accuracy: 0.7725 - val_loss: 0.1467 - val_accuracy: 0.7754

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 6549.556109189987

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00360549],
#        [0.00347302],
#        [0.00237612],
#        ...,
#        [0.09683187],
#        [0.09237725],
#        [0.09040265]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14669848432492236
# 0.21114617616673015
# 0.38301238142509486
# 0.2978948460377651

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 74s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.59131492]
# [0.81096945]
# total acc [0.77334054]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
