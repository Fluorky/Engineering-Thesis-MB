# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x22914226040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2294e297040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 467s 152ms/step - loss: 0.5730 - accuracy: 0.7393 - val_loss: 0.5567 - val_accuracy: 0.7531
# Epoch 2/140
# 2971/2971 [==============================] - 451s 152ms/step - loss: 0.5654 - accuracy: 0.7393 - val_loss: 0.5428 - val_accuracy: 0.7531
# Epoch 3/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.5351 - accuracy: 0.7402 - val_loss: 0.5026 - val_accuracy: 0.7534
# Epoch 4/140
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.5081 - accuracy: 0.7386 - val_loss: 0.4894 - val_accuracy: 0.7501
# Epoch 5/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.5026 - accuracy: 0.7368 - val_loss: 0.4882 - val_accuracy: 0.7509
# Epoch 6/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.5002 - accuracy: 0.7376 - val_loss: 0.4870 - val_accuracy: 0.7520
# Epoch 7/140
# 2971/2971 [==============================] - 440s 148ms/step - loss: 0.4974 - accuracy: 0.7397 - val_loss: 0.4829 - val_accuracy: 0.7540
# Epoch 8/140
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4931 - accuracy: 0.7441 - val_loss: 0.4776 - val_accuracy: 0.7532
# Epoch 9/140
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4872 - accuracy: 0.7474 - val_loss: 0.4762 - val_accuracy: 0.7505
# Epoch 10/140
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4819 - accuracy: 0.7486 - val_loss: 0.4729 - val_accuracy: 0.7555
# Epoch 11/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4773 - accuracy: 0.7510 - val_loss: 0.4676 - val_accuracy: 0.7565
# Epoch 12/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4738 - accuracy: 0.7528 - val_loss: 0.4667 - val_accuracy: 0.7587
# Epoch 13/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4719 - accuracy: 0.7538 - val_loss: 0.4654 - val_accuracy: 0.7566
# Epoch 14/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4702 - accuracy: 0.7545 - val_loss: 0.4604 - val_accuracy: 0.7601
# Epoch 15/140
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4687 - accuracy: 0.7544 - val_loss: 0.4581 - val_accuracy: 0.7604
# Epoch 16/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4672 - accuracy: 0.7552 - val_loss: 0.4662 - val_accuracy: 0.7606
# Epoch 17/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4658 - accuracy: 0.7557 - val_loss: 0.4653 - val_accuracy: 0.7574
# Epoch 18/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4644 - accuracy: 0.7566 - val_loss: 0.4580 - val_accuracy: 0.7607
# Epoch 19/140
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4629 - accuracy: 0.7572 - val_loss: 0.4557 - val_accuracy: 0.7603
# Epoch 20/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4619 - accuracy: 0.7578 - val_loss: 0.4542 - val_accuracy: 0.7628
# Epoch 21/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4608 - accuracy: 0.7585 - val_loss: 0.4545 - val_accuracy: 0.7635
# Epoch 22/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4599 - accuracy: 0.7590 - val_loss: 0.4513 - val_accuracy: 0.7643
# Epoch 23/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4589 - accuracy: 0.7598 - val_loss: 0.4510 - val_accuracy: 0.7646
# Epoch 24/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4580 - accuracy: 0.7611 - val_loss: 0.4558 - val_accuracy: 0.7621
# Epoch 25/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4567 - accuracy: 0.7616 - val_loss: 0.4539 - val_accuracy: 0.7670
# Epoch 26/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4559 - accuracy: 0.7628 - val_loss: 0.4465 - val_accuracy: 0.7666
# Epoch 27/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4551 - accuracy: 0.7632 - val_loss: 0.4464 - val_accuracy: 0.7679
# Epoch 28/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4542 - accuracy: 0.7643 - val_loss: 0.4480 - val_accuracy: 0.7689
# Epoch 29/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4532 - accuracy: 0.7652 - val_loss: 0.4473 - val_accuracy: 0.7691
# Epoch 30/140
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4525 - accuracy: 0.7655 - val_loss: 0.4517 - val_accuracy: 0.7688
# Epoch 31/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4515 - accuracy: 0.7666 - val_loss: 0.4427 - val_accuracy: 0.7717
# Epoch 32/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4505 - accuracy: 0.7671 - val_loss: 0.4415 - val_accuracy: 0.7695
# Epoch 33/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4498 - accuracy: 0.7681 - val_loss: 0.4412 - val_accuracy: 0.7727
# Epoch 34/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4489 - accuracy: 0.7687 - val_loss: 0.4437 - val_accuracy: 0.7711
# Epoch 35/140
# 2971/2971 [==============================] - 440s 148ms/step - loss: 0.4481 - accuracy: 0.7690 - val_loss: 0.4460 - val_accuracy: 0.7719
# Epoch 36/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4476 - accuracy: 0.7695 - val_loss: 0.4397 - val_accuracy: 0.7740
# Epoch 37/140
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4467 - accuracy: 0.7700 - val_loss: 0.4428 - val_accuracy: 0.7714
# Epoch 38/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4460 - accuracy: 0.7705 - val_loss: 0.4411 - val_accuracy: 0.7743
# Epoch 39/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4455 - accuracy: 0.7709 - val_loss: 0.4446 - val_accuracy: 0.7729
# Epoch 40/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4447 - accuracy: 0.7717 - val_loss: 0.4444 - val_accuracy: 0.7737
# Epoch 41/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4444 - accuracy: 0.7715 - val_loss: 0.4451 - val_accuracy: 0.7734
# Epoch 42/140
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4438 - accuracy: 0.7722 - val_loss: 0.4373 - val_accuracy: 0.7748
# Epoch 43/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4433 - accuracy: 0.7720 - val_loss: 0.4366 - val_accuracy: 0.7761
# Epoch 44/140
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4431 - accuracy: 0.7727 - val_loss: 0.4400 - val_accuracy: 0.7742
# Epoch 45/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4426 - accuracy: 0.7729 - val_loss: 0.4383 - val_accuracy: 0.7745
# Epoch 46/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4424 - accuracy: 0.7733 - val_loss: 0.4398 - val_accuracy: 0.7738
# Epoch 47/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4422 - accuracy: 0.7730 - val_loss: 0.4471 - val_accuracy: 0.7749
# Epoch 48/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4418 - accuracy: 0.7729 - val_loss: 0.4398 - val_accuracy: 0.7714
# Epoch 49/140
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4415 - accuracy: 0.7733 - val_loss: 0.4369 - val_accuracy: 0.7764
# Epoch 50/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4413 - accuracy: 0.7734 - val_loss: 0.4376 - val_accuracy: 0.7741
# Epoch 51/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4408 - accuracy: 0.7736 - val_loss: 0.4370 - val_accuracy: 0.7748
# Epoch 52/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4409 - accuracy: 0.7741 - val_loss: 0.4348 - val_accuracy: 0.7751
# Epoch 53/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4405 - accuracy: 0.7738 - val_loss: 0.4335 - val_accuracy: 0.7771
# Epoch 54/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4402 - accuracy: 0.7743 - val_loss: 0.4416 - val_accuracy: 0.7751
# Epoch 55/140
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4400 - accuracy: 0.7744 - val_loss: 0.4370 - val_accuracy: 0.7775
# Epoch 56/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4398 - accuracy: 0.7745 - val_loss: 0.4394 - val_accuracy: 0.7729
# Epoch 57/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4394 - accuracy: 0.7746 - val_loss: 0.4347 - val_accuracy: 0.7777
# Epoch 58/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4392 - accuracy: 0.7749 - val_loss: 0.4364 - val_accuracy: 0.7772
# Epoch 59/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4388 - accuracy: 0.7750 - val_loss: 0.4335 - val_accuracy: 0.7783
# Epoch 60/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4385 - accuracy: 0.7755 - val_loss: 0.4370 - val_accuracy: 0.7762
# Epoch 61/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4382 - accuracy: 0.7755 - val_loss: 0.4318 - val_accuracy: 0.7793
# Epoch 62/140
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4379 - accuracy: 0.7756 - val_loss: 0.4333 - val_accuracy: 0.7780
# Epoch 63/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4374 - accuracy: 0.7759 - val_loss: 0.4377 - val_accuracy: 0.7778
# Epoch 64/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4370 - accuracy: 0.7766 - val_loss: 0.4327 - val_accuracy: 0.7780
# Epoch 65/140
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4364 - accuracy: 0.7765 - val_loss: 0.4327 - val_accuracy: 0.7787
# Epoch 66/140
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4360 - accuracy: 0.7768 - val_loss: 0.4366 - val_accuracy: 0.7772
# Epoch 67/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4355 - accuracy: 0.7770 - val_loss: 0.4359 - val_accuracy: 0.7767
# Epoch 68/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4352 - accuracy: 0.7772 - val_loss: 0.4314 - val_accuracy: 0.7785
# Epoch 69/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4346 - accuracy: 0.7774 - val_loss: 0.4293 - val_accuracy: 0.7804
# Epoch 70/140
# 2971/2971 [==============================] - 440s 148ms/step - loss: 0.4344 - accuracy: 0.7777 - val_loss: 0.4365 - val_accuracy: 0.7785
# Epoch 71/140
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4342 - accuracy: 0.7782 - val_loss: 0.4326 - val_accuracy: 0.7795
# Epoch 72/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4340 - accuracy: 0.7779 - val_loss: 0.4288 - val_accuracy: 0.7809
# Epoch 73/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4335 - accuracy: 0.7783 - val_loss: 0.4305 - val_accuracy: 0.7801
# Epoch 74/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4335 - accuracy: 0.7782 - val_loss: 0.4281 - val_accuracy: 0.7805
# Epoch 75/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4332 - accuracy: 0.7779 - val_loss: 0.4329 - val_accuracy: 0.7795
# Epoch 76/140
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4329 - accuracy: 0.7786 - val_loss: 0.4301 - val_accuracy: 0.7809
# Epoch 77/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4328 - accuracy: 0.7785 - val_loss: 0.4346 - val_accuracy: 0.7789
# Epoch 78/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4327 - accuracy: 0.7787 - val_loss: 0.4301 - val_accuracy: 0.7816
# Epoch 79/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4324 - accuracy: 0.7787 - val_loss: 0.4289 - val_accuracy: 0.7820
# Epoch 80/140
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4323 - accuracy: 0.7788 - val_loss: 0.4299 - val_accuracy: 0.7811
# Epoch 81/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4320 - accuracy: 0.7787 - val_loss: 0.4300 - val_accuracy: 0.7798
# Epoch 82/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4318 - accuracy: 0.7790 - val_loss: 0.4257 - val_accuracy: 0.7817
# Epoch 83/140
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4316 - accuracy: 0.7791 - val_loss: 0.4320 - val_accuracy: 0.7804
# Epoch 84/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4314 - accuracy: 0.7791 - val_loss: 0.4309 - val_accuracy: 0.7810
# Epoch 85/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4313 - accuracy: 0.7793 - val_loss: 0.4269 - val_accuracy: 0.7811
# Epoch 86/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4312 - accuracy: 0.7793 - val_loss: 0.4252 - val_accuracy: 0.7817
# Epoch 87/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4310 - accuracy: 0.7792 - val_loss: 0.4336 - val_accuracy: 0.7802
# Epoch 88/140
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4307 - accuracy: 0.7793 - val_loss: 0.4256 - val_accuracy: 0.7816
# Epoch 89/140
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4306 - accuracy: 0.7795 - val_loss: 0.4316 - val_accuracy: 0.7781
# Epoch 90/140
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4304 - accuracy: 0.7796 - val_loss: 0.4287 - val_accuracy: 0.7825
# Epoch 91/140
# 2971/2971 [==============================] - 463s 156ms/step - loss: 0.4303 - accuracy: 0.7795 - val_loss: 0.4291 - val_accuracy: 0.7824
# Epoch 92/140
# 2971/2971 [==============================] - 468s 158ms/step - loss: 0.4301 - accuracy: 0.7795 - val_loss: 0.4264 - val_accuracy: 0.7806
# Epoch 93/140
# 2971/2971 [==============================] - 446s 150ms/step - loss: 0.4300 - accuracy: 0.7800 - val_loss: 0.4268 - val_accuracy: 0.7821
# Epoch 94/140
# 2971/2971 [==============================] - 443s 149ms/step - loss: 0.4297 - accuracy: 0.7800 - val_loss: 0.4278 - val_accuracy: 0.7822
# Epoch 95/140
# 2971/2971 [==============================] - 444s 149ms/step - loss: 0.4295 - accuracy: 0.7798 - val_loss: 0.4255 - val_accuracy: 0.7828
# Epoch 96/140
# 2971/2971 [==============================] - 445s 150ms/step - loss: 0.4295 - accuracy: 0.7802 - val_loss: 0.4286 - val_accuracy: 0.7826
# Epoch 97/140
# 2971/2971 [==============================] - 443s 149ms/step - loss: 0.4292 - accuracy: 0.7799 - val_loss: 0.4267 - val_accuracy: 0.7814
# Epoch 98/140
# 2971/2971 [==============================] - 442s 149ms/step - loss: 0.4291 - accuracy: 0.7800 - val_loss: 0.4330 - val_accuracy: 0.7789
# Epoch 99/140
# 2971/2971 [==============================] - 443s 149ms/step - loss: 0.4289 - accuracy: 0.7800 - val_loss: 0.4330 - val_accuracy: 0.7818
# Epoch 100/140
# 2971/2971 [==============================] - 441s 148ms/step - loss: 0.4287 - accuracy: 0.7798 - val_loss: 0.4272 - val_accuracy: 0.7811
# Epoch 101/140
# 2971/2971 [==============================] - 445s 150ms/step - loss: 0.4286 - accuracy: 0.7803 - val_loss: 0.4253 - val_accuracy: 0.7826
# Epoch 102/140
# 2971/2971 [==============================] - 473s 159ms/step - loss: 0.4286 - accuracy: 0.7803 - val_loss: 0.4321 - val_accuracy: 0.7821
# Epoch 103/140
# 2971/2971 [==============================] - 462s 155ms/step - loss: 0.4283 - accuracy: 0.7804 - val_loss: 0.4291 - val_accuracy: 0.7799
# Epoch 104/140
# 2971/2971 [==============================] - 452s 152ms/step - loss: 0.4281 - accuracy: 0.7809 - val_loss: 0.4263 - val_accuracy: 0.7827
# Epoch 105/140
# 2971/2971 [==============================] - 441s 148ms/step - loss: 0.4280 - accuracy: 0.7803 - val_loss: 0.4262 - val_accuracy: 0.7807
# Epoch 106/140
# 2971/2971 [==============================] - 443s 149ms/step - loss: 0.4279 - accuracy: 0.7807 - val_loss: 0.4263 - val_accuracy: 0.7821
# Epoch 107/140
# 2971/2971 [==============================] - 444s 149ms/step - loss: 0.4276 - accuracy: 0.7810 - val_loss: 0.4252 - val_accuracy: 0.7821
# Epoch 108/140
# 2971/2971 [==============================] - 442s 149ms/step - loss: 0.4275 - accuracy: 0.7807 - val_loss: 0.4329 - val_accuracy: 0.7773
# Epoch 109/140
# 2971/2971 [==============================] - 443s 149ms/step - loss: 0.4275 - accuracy: 0.7810 - val_loss: 0.4243 - val_accuracy: 0.7825
# Epoch 110/140
# 2971/2971 [==============================] - 442s 149ms/step - loss: 0.4272 - accuracy: 0.7808 - val_loss: 0.4249 - val_accuracy: 0.7821
# Epoch 111/140
# 2971/2971 [==============================] - 440s 148ms/step - loss: 0.4271 - accuracy: 0.7810 - val_loss: 0.4261 - val_accuracy: 0.7816
# Epoch 112/140
# 2971/2971 [==============================] - 440s 148ms/step - loss: 0.4268 - accuracy: 0.7813 - val_loss: 0.4304 - val_accuracy: 0.7774
# Epoch 113/140
# 2971/2971 [==============================] - 453s 153ms/step - loss: 0.4267 - accuracy: 0.7811 - val_loss: 0.4255 - val_accuracy: 0.7834
# Epoch 114/140
# 2971/2971 [==============================] - 465s 157ms/step - loss: 0.4266 - accuracy: 0.7812 - val_loss: 0.4250 - val_accuracy: 0.7814
# Epoch 115/140
# 2971/2971 [==============================] - 461s 155ms/step - loss: 0.4264 - accuracy: 0.7816 - val_loss: 0.4264 - val_accuracy: 0.7812
# Epoch 116/140
# 2971/2971 [==============================] - 451s 152ms/step - loss: 0.4260 - accuracy: 0.7816 - val_loss: 0.4293 - val_accuracy: 0.7813
# Epoch 117/140
# 2971/2971 [==============================] - 451s 152ms/step - loss: 0.4261 - accuracy: 0.7815 - val_loss: 0.4247 - val_accuracy: 0.7815
# Epoch 118/140
# 2971/2971 [==============================] - 448s 151ms/step - loss: 0.4259 - accuracy: 0.7814 - val_loss: 0.4320 - val_accuracy: 0.7823
# Epoch 119/140
# 2971/2971 [==============================] - 448s 151ms/step - loss: 0.4258 - accuracy: 0.7817 - val_loss: 0.4259 - val_accuracy: 0.7828
# Epoch 120/140
# 2971/2971 [==============================] - 449s 151ms/step - loss: 0.4256 - accuracy: 0.7816 - val_loss: 0.4282 - val_accuracy: 0.7797
# Epoch 121/140
# 2971/2971 [==============================] - 447s 151ms/step - loss: 0.4255 - accuracy: 0.7819 - val_loss: 0.4262 - val_accuracy: 0.7811
# Epoch 122/140
# 2971/2971 [==============================] - 451s 152ms/step - loss: 0.4254 - accuracy: 0.7818 - val_loss: 0.4294 - val_accuracy: 0.7829
# Epoch 123/140
# 2971/2971 [==============================] - 447s 151ms/step - loss: 0.4253 - accuracy: 0.7817 - val_loss: 0.4326 - val_accuracy: 0.7799
# Epoch 124/140
# 2971/2971 [==============================] - 449s 151ms/step - loss: 0.4252 - accuracy: 0.7825 - val_loss: 0.4241 - val_accuracy: 0.7822
# Epoch 125/140
# 2971/2971 [==============================] - 448s 151ms/step - loss: 0.4250 - accuracy: 0.7824 - val_loss: 0.4255 - val_accuracy: 0.7829
# Epoch 126/140
# 2971/2971 [==============================] - 448s 151ms/step - loss: 0.4249 - accuracy: 0.7819 - val_loss: 0.4336 - val_accuracy: 0.7829
# Epoch 127/140
# 2971/2971 [==============================] - 449s 151ms/step - loss: 0.4247 - accuracy: 0.7823 - val_loss: 0.4247 - val_accuracy: 0.7817
# Epoch 128/140
# 2971/2971 [==============================] - 448s 151ms/step - loss: 0.4246 - accuracy: 0.7827 - val_loss: 0.4341 - val_accuracy: 0.7824
# Epoch 129/140
# 2971/2971 [==============================] - 448s 151ms/step - loss: 0.4244 - accuracy: 0.7826 - val_loss: 0.4248 - val_accuracy: 0.7814
# Epoch 130/140
# 2971/2971 [==============================] - 448s 151ms/step - loss: 0.4244 - accuracy: 0.7823 - val_loss: 0.4245 - val_accuracy: 0.7827
# Epoch 131/140
# 2971/2971 [==============================] - 449s 151ms/step - loss: 0.4243 - accuracy: 0.7825 - val_loss: 0.4244 - val_accuracy: 0.7816
# Epoch 132/140
# 2971/2971 [==============================] - 448s 151ms/step - loss: 0.4241 - accuracy: 0.7826 - val_loss: 0.4264 - val_accuracy: 0.7811
# Epoch 133/140
# 2971/2971 [==============================] - 450s 151ms/step - loss: 0.4239 - accuracy: 0.7825 - val_loss: 0.4254 - val_accuracy: 0.7828
# Epoch 134/140
# 2971/2971 [==============================] - 450s 152ms/step - loss: 0.4238 - accuracy: 0.7829 - val_loss: 0.4249 - val_accuracy: 0.7831
# Epoch 135/140
# 2971/2971 [==============================] - 449s 151ms/step - loss: 0.4237 - accuracy: 0.7828 - val_loss: 0.4279 - val_accuracy: 0.7825
# Epoch 136/140
# 2971/2971 [==============================] - 451s 152ms/step - loss: 0.4236 - accuracy: 0.7831 - val_loss: 0.4319 - val_accuracy: 0.7834
# Epoch 137/140
# 2971/2971 [==============================] - 448s 151ms/step - loss: 0.4235 - accuracy: 0.7829 - val_loss: 0.4248 - val_accuracy: 0.7821
# Epoch 138/140
# 2971/2971 [==============================] - 447s 151ms/step - loss: 0.4232 - accuracy: 0.7826 - val_loss: 0.4260 - val_accuracy: 0.7827
# Epoch 139/140
# 2971/2971 [==============================] - 449s 151ms/step - loss: 0.4233 - accuracy: 0.7831 - val_loss: 0.4245 - val_accuracy: 0.7820
# Epoch 140/140
# 2971/2971 [==============================] - 449s 151ms/step - loss: 0.4230 - accuracy: 0.7833 - val_loss: 0.4243 - val_accuracy: 0.7821

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 50s 17ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 61897.24483513832

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00082332],
#        [0.00102114],
#        [0.00040191],
#        ...,
#        [0.0601212 ],
#        [0.06283622],
#        [0.06445695]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14200798039901144
# 0.23636880866144894
# 0.37683946236960303
# 0.28090971226770844

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 239s 16ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.62159064]
# [0.81592856]
# total acc [0.78311499]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
