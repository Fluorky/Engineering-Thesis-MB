# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x212920f0040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x212cc154040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 73s 19ms/step - loss: 0.5701 - accuracy: 0.7393 - val_loss: 0.5498 - val_accuracy: 0.7531
# Epoch 2/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.5446 - accuracy: 0.7398 - val_loss: 0.5107 - val_accuracy: 0.7535
# Epoch 3/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.5121 - accuracy: 0.7388 - val_loss: 0.4904 - val_accuracy: 0.7510
# Epoch 4/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.5032 - accuracy: 0.7367 - val_loss: 0.4927 - val_accuracy: 0.7524
# Epoch 5/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.5010 - accuracy: 0.7379 - val_loss: 0.4842 - val_accuracy: 0.7531
# Epoch 6/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4997 - accuracy: 0.7388 - val_loss: 0.4834 - val_accuracy: 0.7531
# Epoch 7/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4987 - accuracy: 0.7392 - val_loss: 0.4822 - val_accuracy: 0.7531
# Epoch 8/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4977 - accuracy: 0.7393 - val_loss: 0.4817 - val_accuracy: 0.7531
# Epoch 9/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4968 - accuracy: 0.7393 - val_loss: 0.4809 - val_accuracy: 0.7531
# Epoch 10/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4959 - accuracy: 0.7393 - val_loss: 0.4812 - val_accuracy: 0.7531
# Epoch 11/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4949 - accuracy: 0.7393 - val_loss: 0.4788 - val_accuracy: 0.7531
# Epoch 12/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4936 - accuracy: 0.7394 - val_loss: 0.4786 - val_accuracy: 0.7531
# Epoch 13/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4919 - accuracy: 0.7402 - val_loss: 0.4768 - val_accuracy: 0.7545
# Epoch 14/140
# 2971/2971 [==============================] - 55s 18ms/step - loss: 0.4898 - accuracy: 0.7432 - val_loss: 0.4758 - val_accuracy: 0.7556
# Epoch 15/140
# 2971/2971 [==============================] - 64s 22ms/step - loss: 0.4868 - accuracy: 0.7464 - val_loss: 0.4758 - val_accuracy: 0.7537
# Epoch 16/140
# 2971/2971 [==============================] - 66s 22ms/step - loss: 0.4827 - accuracy: 0.7481 - val_loss: 0.4717 - val_accuracy: 0.7550
# Epoch 17/140
# 2971/2971 [==============================] - 66s 22ms/step - loss: 0.4782 - accuracy: 0.7484 - val_loss: 0.4725 - val_accuracy: 0.7498
# Epoch 18/140
# 2971/2971 [==============================] - 66s 22ms/step - loss: 0.4740 - accuracy: 0.7504 - val_loss: 0.4634 - val_accuracy: 0.7570
# Epoch 19/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.4704 - accuracy: 0.7525 - val_loss: 0.4616 - val_accuracy: 0.7582
# Epoch 20/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4679 - accuracy: 0.7529 - val_loss: 0.4586 - val_accuracy: 0.7582
# Epoch 21/140
# 2971/2971 [==============================] - 55s 19ms/step - loss: 0.4664 - accuracy: 0.7538 - val_loss: 0.4595 - val_accuracy: 0.7575
# Epoch 22/140
# 2971/2971 [==============================] - 55s 19ms/step - loss: 0.4651 - accuracy: 0.7546 - val_loss: 0.4551 - val_accuracy: 0.7591
# Epoch 23/140
# 2971/2971 [==============================] - 55s 19ms/step - loss: 0.4642 - accuracy: 0.7551 - val_loss: 0.4574 - val_accuracy: 0.7595
# Epoch 24/140
# 2971/2971 [==============================] - 55s 19ms/step - loss: 0.4632 - accuracy: 0.7558 - val_loss: 0.4550 - val_accuracy: 0.7598
# Epoch 25/140
140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4280 - accuracy: 0.7804 - val_loss: 0.4339 - val_accuracy: 0.7795
# Epoch 114/140
# 2971/2971 [==============================] - 55s 19ms/step - loss: 0.4277 - accuracy: 0.7805 - val_loss: 0.4277 - val_accuracy: 0.7827
# Epoch 115/140
# 2971/2971 [==============================] - 55s 19ms/step - loss: 0.4276 - accuracy: 0.7807 - val_loss: 0.4261 - val_accuracy: 0.7835
# Epoch 116/140
# 2971/2971 [==============================] - 57s 19ms/step - loss: 0.4276 - accuracy: 0.7806 - val_loss: 0.4270 - val_accuracy: 0.7829
# Epoch 117/140
# 2971/2971 [==============================] - 56s 19ms/step - loss: 0.4274 - accuracy: 0.7810 - val_loss: 0.4268 - val_accuracy: 0.7823
# Epoch 118/140
# 2971/2971 [==============================] - 56s 19ms/step - loss: 0.4271 - accuracy: 0.7810 - val_loss: 0.4285 - val_accuracy: 0.7784
# Epoch 119/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4269 - accuracy: 0.7811 - val_loss: 0.4268 - val_accuracy: 0.7824
# Epoch 120/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4268 - accuracy: 0.7812 - val_loss: 0.4330 - val_accuracy: 0.7812
# Epoch 121/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4266 - accuracy: 0.7813 - val_loss: 0.4263 - val_accuracy: 0.7823
# Epoch 122/140
# 2971/2971 [==============================] - 55s 18ms/step - loss: 0.4264 - accuracy: 0.7814 - val_loss: 0.4239 - val_accuracy: 0.7826
# Epoch 123/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4263 - accuracy: 0.7811 - val_loss: 0.4291 - val_accuracy: 0.7824
# Epoch 124/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4261 - accuracy: 0.7818 - val_loss: 0.4304 - val_accuracy: 0.7829
# Epoch 125/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4261 - accuracy: 0.7817 - val_loss: 0.4258 - val_accuracy: 0.7834
# Epoch 126/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4259 - accuracy: 0.7815 - val_loss: 0.4292 - val_accuracy: 0.7835
# Epoch 127/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4256 - accuracy: 0.7818 - val_loss: 0.4257 - val_accuracy: 0.7802
# Epoch 128/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4255 - accuracy: 0.7818 - val_loss: 0.4262 - val_accuracy: 0.7822
# Epoch 129/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4255 - accuracy: 0.7820 - val_loss: 0.4276 - val_accuracy: 0.7835
# Epoch 130/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4253 - accuracy: 0.7819 - val_loss: 0.4238 - val_accuracy: 0.7831
# Epoch 131/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4251 - accuracy: 0.7823 - val_loss: 0.4239 - val_accuracy: 0.7834
# Epoch 132/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4250 - accuracy: 0.7818 - val_loss: 0.4255 - val_accuracy: 0.7818
# Epoch 133/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4248 - accuracy: 0.7825 - val_loss: 0.4281 - val_accuracy: 0.7814
# Epoch 134/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4247 - accuracy: 0.7824 - val_loss: 0.4265 - val_accuracy: 0.7808
# Epoch 135/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4245 - accuracy: 0.7823 - val_loss: 0.4244 - val_accuracy: 0.7830
# Epoch 136/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4246 - accuracy: 0.7822 - val_loss: 0.4236 - val_accuracy: 0.7837
# Epoch 137/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4244 - accuracy: 0.7825 - val_loss: 0.4263 - val_accuracy: 0.7813
# Epoch 138/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4242 - accuracy: 0.7825 - val_loss: 0.4282 - val_accuracy: 0.7793
# Epoch 139/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4241 - accuracy: 0.7825 - val_loss: 0.4260 - val_accuracy: 0.7834
# Epoch 140/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4241 - accuracy: 0.7829 - val_loss: 0.4251 - val_accuracy: 0.7833

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 17s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 7851.5560693740845

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00218606],
#        [0.00300844],
#        [0.0011482 ],
#        ...,
#        [0.05562229],
#        [0.05750019],
#        [0.05935339]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1422724668740381
# 0.23494656378866052
# 0.37719022637660976
# 0.2848943882350048

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 83s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.61159453]
# [0.82295369]
# total acc [0.78360518]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
