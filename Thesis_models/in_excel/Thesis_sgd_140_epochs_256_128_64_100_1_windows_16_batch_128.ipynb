# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x27f28bf3040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x27f62c69040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 256)           209664
#
#  gru_1 (GRU)                 (None, 16, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 61s 18ms/step - loss: 0.5735 - accuracy: 0.7374 - val_loss: 0.5544 - val_accuracy: 0.7531
# Epoch 2/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.5569 - accuracy: 0.7395 - val_loss: 0.5252 - val_accuracy: 0.7532
# Epoch 3/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.5229 - accuracy: 0.7400 - val_loss: 0.4967 - val_accuracy: 0.7486
# Epoch 4/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.5065 - accuracy: 0.7368 - val_loss: 0.4884 - val_accuracy: 0.7507
# Epoch 5/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5029 - accuracy: 0.7363 - val_loss: 0.4870 - val_accuracy: 0.7525
# Epoch 6/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.5013 - accuracy: 0.7364 - val_loss: 0.4848 - val_accuracy: 0.7530
# Epoch 7/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.5001 - accuracy: 0.7375 - val_loss: 0.4865 - val_accuracy: 0.7532
# Epoch 8/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4992 - accuracy: 0.7382 - val_loss: 0.4833 - val_accuracy: 0.7531
# Epoch 9/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4983 - accuracy: 0.7387 - val_loss: 0.4849 - val_accuracy: 0.7530
# Epoch 10/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4974 - accuracy: 0.7389 - val_loss: 0.4816 - val_accuracy: 0.7532
# Epoch 11/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4962 - accuracy: 0.7392 - val_loss: 0.4835 - val_accuracy: 0.7531
# Epoch 12/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4949 - accuracy: 0.7396 - val_loss: 0.4799 - val_accuracy: 0.7530
# Epoch 13/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4927 - accuracy: 0.7414 - val_loss: 0.4820 - val_accuracy: 0.7547
# Epoch 14/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4895 - accuracy: 0.7452 - val_loss: 0.4759 - val_accuracy: 0.7538
# Epoch 15/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4856 - accuracy: 0.7474 - val_loss: 0.4765 - val_accuracy: 0.7514
# Epoch 16/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4817 - accuracy: 0.7482 - val_loss: 0.4712 - val_accuracy: 0.7541
# Epoch 17/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4781 - accuracy: 0.7495 - val_loss: 0.4712 - val_accuracy: 0.7537
# Epoch 18/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4749 - accuracy: 0.7514 - val_loss: 0.4651 - val_accuracy: 0.7579
# Epoch 19/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4725 - accuracy: 0.7526 - val_loss: 0.4639 - val_accuracy: 0.7578
# Epoch 20/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4706 - accuracy: 0.7536 - val_loss: 0.4660 - val_accuracy: 0.7551
# Epoch 21/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4691 - accuracy: 0.7540 - val_loss: 0.4603 - val_accuracy: 0.7594
# Epoch 22/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4678 - accuracy: 0.7545 - val_loss: 0.4589 - val_accuracy: 0.7588
# Epoch 23/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4664 - accuracy: 0.7548 - val_loss: 0.4587 - val_accuracy: 0.7576
# Epoch 24/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4654 - accuracy: 0.7551 - val_loss: 0.4565 - val_accuracy: 0.7597
# Epoch 25/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4642 - accuracy: 0.7555 - val_loss: 0.4628 - val_accuracy: 0.7559
# Epoch 26/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4635 - accuracy: 0.7558 - val_loss: 0.4536 - val_accuracy: 0.7615
# Epoch 27/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4625 - accuracy: 0.7561 - val_loss: 0.4607 - val_accuracy: 0.7571
# Epoch 28/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4618 - accuracy: 0.7563 - val_loss: 0.4523 - val_accuracy: 0.7622
# Epoch 29/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4610 - accuracy: 0.7571 - val_loss: 0.4561 - val_accuracy: 0.7628
# Epoch 30/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4605 - accuracy: 0.7574 - val_loss: 0.4526 - val_accuracy: 0.7632
# Epoch 31/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4598 - accuracy: 0.7580 - val_loss: 0.4513 - val_accuracy: 0.7630
# Epoch 32/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4591 - accuracy: 0.7584 - val_loss: 0.4492 - val_accuracy: 0.7644
# Epoch 33/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4582 - accuracy: 0.7589 - val_loss: 0.4618 - val_accuracy: 0.7640
# Epoch 34/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4576 - accuracy: 0.7599 - val_loss: 0.4498 - val_accuracy: 0.7651
# Epoch 35/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4570 - accuracy: 0.7602 - val_loss: 0.4481 - val_accuracy: 0.7644
# Epoch 36/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4561 - accuracy: 0.7609 - val_loss: 0.4500 - val_accuracy: 0.7639
# Epoch 37/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4554 - accuracy: 0.7618 - val_loss: 0.4483 - val_accuracy: 0.7653
# Epoch 38/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4546 - accuracy: 0.7625 - val_loss: 0.4496 - val_accuracy: 0.7674
# Epoch 39/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4537 - accuracy: 0.7635 - val_loss: 0.4498 - val_accuracy: 0.7693
# Epoch 40/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4530 - accuracy: 0.7638 - val_loss: 0.4436 - val_accuracy: 0.7688
# Epoch 41/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4524 - accuracy: 0.7647 - val_loss: 0.4451 - val_accuracy: 0.7709
# Epoch 42/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4516 - accuracy: 0.7651 - val_loss: 0.4425 - val_accuracy: 0.7696
# Epoch 43/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4508 - accuracy: 0.7659 - val_loss: 0.4461 - val_accuracy: 0.7681
# Epoch 44/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4501 - accuracy: 0.7665 - val_loss: 0.4423 - val_accuracy: 0.7707
# Epoch 45/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4495 - accuracy: 0.7668 - val_loss: 0.4397 - val_accuracy: 0.7726
# Epoch 46/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4490 - accuracy: 0.7676 - val_loss: 0.4411 - val_accuracy: 0.7715
# Epoch 47/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4484 - accuracy: 0.7680 - val_loss: 0.4388 - val_accuracy: 0.7737
# Epoch 48/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4478 - accuracy: 0.7686 - val_loss: 0.4407 - val_accuracy: 0.7730
# Epoch 49/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4474 - accuracy: 0.7685 - val_loss: 0.4418 - val_accuracy: 0.7734
# Epoch 50/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4467 - accuracy: 0.7692 - val_loss: 0.4387 - val_accuracy: 0.7739
# Epoch 51/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4463 - accuracy: 0.7696 - val_loss: 0.4386 - val_accuracy: 0.7727
# Epoch 52/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4460 - accuracy: 0.7698 - val_loss: 0.4401 - val_accuracy: 0.7735
# Epoch 53/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4455 - accuracy: 0.7702 - val_loss: 0.4370 - val_accuracy: 0.7740
# Epoch 54/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4450 - accuracy: 0.7706 - val_loss: 0.4406 - val_accuracy: 0.7745
# Epoch 55/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4447 - accuracy: 0.7707 - val_loss: 0.4384 - val_accuracy: 0.7746
# Epoch 56/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4443 - accuracy: 0.7709 - val_loss: 0.4362 - val_accuracy: 0.7746
# Epoch 57/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4441 - accuracy: 0.7714 - val_loss: 0.4415 - val_accuracy: 0.7738
# Epoch 58/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4434 - accuracy: 0.7716 - val_loss: 0.4357 - val_accuracy: 0.7752
# Epoch 59/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4432 - accuracy: 0.7717 - val_loss: 0.4363 - val_accuracy: 0.7748
# Epoch 60/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4429 - accuracy: 0.7721 - val_loss: 0.4538 - val_accuracy: 0.7621
# Epoch 61/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4426 - accuracy: 0.7721 - val_loss: 0.4377 - val_accuracy: 0.7750
# Epoch 62/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4425 - accuracy: 0.7723 - val_loss: 0.4475 - val_accuracy: 0.7726
# Epoch 63/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4421 - accuracy: 0.7724 - val_loss: 0.4360 - val_accuracy: 0.7756
# Epoch 64/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4419 - accuracy: 0.7726 - val_loss: 0.4365 - val_accuracy: 0.7752
# Epoch 65/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4416 - accuracy: 0.7730 - val_loss: 0.4377 - val_accuracy: 0.7746
# Epoch 66/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4413 - accuracy: 0.7731 - val_loss: 0.4350 - val_accuracy: 0.7755
# Epoch 67/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4411 - accuracy: 0.7733 - val_loss: 0.4350 - val_accuracy: 0.7761
# Epoch 68/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4408 - accuracy: 0.7734 - val_loss: 0.4383 - val_accuracy: 0.7754
# Epoch 69/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4408 - accuracy: 0.7738 - val_loss: 0.4334 - val_accuracy: 0.7768
# Epoch 70/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4403 - accuracy: 0.7737 - val_loss: 0.4339 - val_accuracy: 0.7759
# Epoch 71/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4403 - accuracy: 0.7739 - val_loss: 0.4408 - val_accuracy: 0.7748
# Epoch 72/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4399 - accuracy: 0.7738 - val_loss: 0.4338 - val_accuracy: 0.7769
# Epoch 73/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4398 - accuracy: 0.7743 - val_loss: 0.4338 - val_accuracy: 0.7773
# Epoch 74/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4395 - accuracy: 0.7742 - val_loss: 0.4332 - val_accuracy: 0.7752
# Epoch 75/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4392 - accuracy: 0.7749 - val_loss: 0.4337 - val_accuracy: 0.7774
# Epoch 76/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4392 - accuracy: 0.7748 - val_loss: 0.4331 - val_accuracy: 0.7774
# Epoch 77/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4388 - accuracy: 0.7746 - val_loss: 0.4355 - val_accuracy: 0.7764
# Epoch 78/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4384 - accuracy: 0.7753 - val_loss: 0.4322 - val_accuracy: 0.7777
# Epoch 79/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4381 - accuracy: 0.7755 - val_loss: 0.4349 - val_accuracy: 0.7777
# Epoch 80/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4377 - accuracy: 0.7756 - val_loss: 0.4339 - val_accuracy: 0.7775
# Epoch 81/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4370 - accuracy: 0.7761 - val_loss: 0.4301 - val_accuracy: 0.7792
# Epoch 82/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4364 - accuracy: 0.7762 - val_loss: 0.4304 - val_accuracy: 0.7793
# Epoch 83/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4360 - accuracy: 0.7765 - val_loss: 0.4352 - val_accuracy: 0.7788
# Epoch 84/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4357 - accuracy: 0.7767 - val_loss: 0.4322 - val_accuracy: 0.7783
# Epoch 85/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4352 - accuracy: 0.7771 - val_loss: 0.4329 - val_accuracy: 0.7785
# Epoch 86/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4350 - accuracy: 0.7767 - val_loss: 0.4322 - val_accuracy: 0.7784
# Epoch 87/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4347 - accuracy: 0.7773 - val_loss: 0.4322 - val_accuracy: 0.7784
# Epoch 88/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4345 - accuracy: 0.7769 - val_loss: 0.4280 - val_accuracy: 0.7794
# Epoch 89/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4342 - accuracy: 0.7772 - val_loss: 0.4291 - val_accuracy: 0.7795
# Epoch 90/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4341 - accuracy: 0.7772 - val_loss: 0.4306 - val_accuracy: 0.7799
# Epoch 91/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4338 - accuracy: 0.7772 - val_loss: 0.4318 - val_accuracy: 0.7797
# Epoch 92/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4337 - accuracy: 0.7774 - val_loss: 0.4283 - val_accuracy: 0.7801
# Epoch 93/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4335 - accuracy: 0.7776 - val_loss: 0.4336 - val_accuracy: 0.7781
# Epoch 94/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4332 - accuracy: 0.7772 - val_loss: 0.4288 - val_accuracy: 0.7796
# Epoch 95/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4330 - accuracy: 0.7776 - val_loss: 0.4352 - val_accuracy: 0.7792
# Epoch 96/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4328 - accuracy: 0.7780 - val_loss: 0.4283 - val_accuracy: 0.7797
# Epoch 97/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4327 - accuracy: 0.7778 - val_loss: 0.4346 - val_accuracy: 0.7795
# Epoch 98/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4325 - accuracy: 0.7777 - val_loss: 0.4279 - val_accuracy: 0.7807
# Epoch 99/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4323 - accuracy: 0.7782 - val_loss: 0.4325 - val_accuracy: 0.7804
# Epoch 100/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4321 - accuracy: 0.7782 - val_loss: 0.4333 - val_accuracy: 0.7788
# Epoch 101/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4319 - accuracy: 0.7786 - val_loss: 0.4320 - val_accuracy: 0.7795
# Epoch 102/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4318 - accuracy: 0.7781 - val_loss: 0.4344 - val_accuracy: 0.7788
# Epoch 103/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4316 - accuracy: 0.7783 - val_loss: 0.4298 - val_accuracy: 0.7795
# Epoch 104/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4315 - accuracy: 0.7786 - val_loss: 0.4309 - val_accuracy: 0.7809
# Epoch 105/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4312 - accuracy: 0.7783 - val_loss: 0.4261 - val_accuracy: 0.7817
# Epoch 106/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4309 - accuracy: 0.7784 - val_loss: 0.4279 - val_accuracy: 0.7805
# Epoch 107/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4309 - accuracy: 0.7786 - val_loss: 0.4276 - val_accuracy: 0.7811
# Epoch 108/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4306 - accuracy: 0.7786 - val_loss: 0.4268 - val_accuracy: 0.7816
# Epoch 109/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4306 - accuracy: 0.7789 - val_loss: 0.4280 - val_accuracy: 0.7822
# Epoch 110/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4304 - accuracy: 0.7790 - val_loss: 0.4371 - val_accuracy: 0.7812
# Epoch 111/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4300 - accuracy: 0.7791 - val_loss: 0.4270 - val_accuracy: 0.7822
# Epoch 112/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4302 - accuracy: 0.7793 - val_loss: 0.4305 - val_accuracy: 0.7777
# Epoch 113/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4299 - accuracy: 0.7795 - val_loss: 0.4268 - val_accuracy: 0.7810
# Epoch 114/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4297 - accuracy: 0.7792 - val_loss: 0.4291 - val_accuracy: 0.7790
# Epoch 115/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4296 - accuracy: 0.7792 - val_loss: 0.4284 - val_accuracy: 0.7799
# Epoch 116/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4295 - accuracy: 0.7796 - val_loss: 0.4314 - val_accuracy: 0.7817
# Epoch 117/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4293 - accuracy: 0.7793 - val_loss: 0.4322 - val_accuracy: 0.7768
# Epoch 118/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4291 - accuracy: 0.7797 - val_loss: 0.4287 - val_accuracy: 0.7788
# Epoch 119/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4290 - accuracy: 0.7797 - val_loss: 0.4317 - val_accuracy: 0.7811
# Epoch 120/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4288 - accuracy: 0.7795 - val_loss: 0.4297 - val_accuracy: 0.7790
# Epoch 121/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4286 - accuracy: 0.7799 - val_loss: 0.4266 - val_accuracy: 0.7815
# Epoch 122/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4284 - accuracy: 0.7801 - val_loss: 0.4282 - val_accuracy: 0.7802
# Epoch 123/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4283 - accuracy: 0.7801 - val_loss: 0.4372 - val_accuracy: 0.7816
# Epoch 124/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4281 - accuracy: 0.7798 - val_loss: 0.4243 - val_accuracy: 0.7833
# Epoch 125/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4281 - accuracy: 0.7800 - val_loss: 0.4293 - val_accuracy: 0.7808
# Epoch 126/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4280 - accuracy: 0.7801 - val_loss: 0.4275 - val_accuracy: 0.7811
# Epoch 127/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4277 - accuracy: 0.7801 - val_loss: 0.4271 - val_accuracy: 0.7822
# Epoch 128/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4275 - accuracy: 0.7800 - val_loss: 0.4339 - val_accuracy: 0.7774
# Epoch 129/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4275 - accuracy: 0.7807 - val_loss: 0.4264 - val_accuracy: 0.7831
# Epoch 130/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4272 - accuracy: 0.7804 - val_loss: 0.4274 - val_accuracy: 0.7808
# Epoch 131/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4271 - accuracy: 0.7807 - val_loss: 0.4257 - val_accuracy: 0.7831
# Epoch 132/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4271 - accuracy: 0.7807 - val_loss: 0.4314 - val_accuracy: 0.7820
# Epoch 133/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4270 - accuracy: 0.7809 - val_loss: 0.4297 - val_accuracy: 0.7788
# Epoch 134/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4268 - accuracy: 0.7808 - val_loss: 0.4251 - val_accuracy: 0.7831
# Epoch 135/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4266 - accuracy: 0.7808 - val_loss: 0.4255 - val_accuracy: 0.7834
# Epoch 136/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4267 - accuracy: 0.7808 - val_loss: 0.4256 - val_accuracy: 0.7823
# Epoch 137/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4266 - accuracy: 0.7811 - val_loss: 0.4261 - val_accuracy: 0.7829
# Epoch 138/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4264 - accuracy: 0.7811 - val_loss: 0.4319 - val_accuracy: 0.7822
# Epoch 139/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4261 - accuracy: 0.7815 - val_loss: 0.4289 - val_accuracy: 0.7827
# Epoch 140/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4260 - accuracy: 0.7809 - val_loss: 0.4263 - val_accuracy: 0.7831

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 18s 6ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 7378.030325174332

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00188659],
#        [0.00344471],
#        [0.00130691],
#        ...,
#        [0.05184415],
#        [0.0537101 ],
#        [0.05575103]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14264131452058804
# 0.23296312900586913
# 0.37767885103694654
# 0.2825355570688802

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 83s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60941809]
# [0.8208253]
# total acc [0.78211987]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
