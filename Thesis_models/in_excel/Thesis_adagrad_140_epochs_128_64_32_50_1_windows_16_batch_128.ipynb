# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x28280003040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x282ea760040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='adagrad',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 62s 19ms/step - loss: 0.5832 - accuracy: 0.7336 - val_loss: 0.5596 - val_accuracy: 0.7531
# Epoch 2/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5736 - accuracy: 0.7393 - val_loss: 0.5587 - val_accuracy: 0.7531
# Epoch 3/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.5726 - accuracy: 0.7393 - val_loss: 0.5577 - val_accuracy: 0.7531
# Epoch 4/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.5713 - accuracy: 0.7393 - val_loss: 0.5565 - val_accuracy: 0.7531
# Epoch 5/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5693 - accuracy: 0.7393 - val_loss: 0.5541 - val_accuracy: 0.7531
# Epoch 6/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.5656 - accuracy: 0.7393 - val_loss: 0.5495 - val_accuracy: 0.7531
# Epoch 7/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.5587 - accuracy: 0.7393 - val_loss: 0.5414 - val_accuracy: 0.7531
# Epoch 8/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.5478 - accuracy: 0.7393 - val_loss: 0.5300 - val_accuracy: 0.7532
# Epoch 9/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5366 - accuracy: 0.7407 - val_loss: 0.5193 - val_accuracy: 0.7527
# Epoch 10/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.5272 - accuracy: 0.7413 - val_loss: 0.5099 - val_accuracy: 0.7532
# Epoch 11/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5192 - accuracy: 0.7403 - val_loss: 0.5027 - val_accuracy: 0.7521
# Epoch 12/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5136 - accuracy: 0.7379 - val_loss: 0.4988 - val_accuracy: 0.7477
# Epoch 13/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5106 - accuracy: 0.7363 - val_loss: 0.4956 - val_accuracy: 0.7472
# Epoch 14/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.5088 - accuracy: 0.7356 - val_loss: 0.4944 - val_accuracy: 0.7462
# Epoch 15/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.5074 - accuracy: 0.7355 - val_loss: 0.4927 - val_accuracy: 0.7475
# Epoch 16/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.5064 - accuracy: 0.7353 - val_loss: 0.4920 - val_accuracy: 0.7482
# Epoch 17/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.5055 - accuracy: 0.7355 - val_loss: 0.4905 - val_accuracy: 0.7505
# Epoch 18/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5048 - accuracy: 0.7357 - val_loss: 0.4900 - val_accuracy: 0.7509
# Epoch 19/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.5042 - accuracy: 0.7361 - val_loss: 0.4904 - val_accuracy: 0.7506
# Epoch 20/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5037 - accuracy: 0.7362 - val_loss: 0.4891 - val_accuracy: 0.7509
# Epoch 21/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5032 - accuracy: 0.7366 - val_loss: 0.4886 - val_accuracy: 0.7511
# Epoch 22/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.5028 - accuracy: 0.7366 - val_loss: 0.4886 - val_accuracy: 0.7515
# Epoch 23/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5024 - accuracy: 0.7368 - val_loss: 0.4885 - val_accuracy: 0.7521
# Epoch 24/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5020 - accuracy: 0.7369 - val_loss: 0.4873 - val_accuracy: 0.7523
# Epoch 25/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.5017 - accuracy: 0.7372 - val_loss: 0.4876 - val_accuracy: 0.7524
# Epoch 26/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.5014 - accuracy: 0.7373 - val_loss: 0.4868 - val_accuracy: 0.7530
# Epoch 27/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5011 - accuracy: 0.7376 - val_loss: 0.4872 - val_accuracy: 0.7525
# Epoch 28/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.5008 - accuracy: 0.7377 - val_loss: 0.4861 - val_accuracy: 0.7530
# Epoch 29/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.5005 - accuracy: 0.7378 - val_loss: 0.4859 - val_accuracy: 0.7531
# Epoch 30/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.5002 - accuracy: 0.7380 - val_loss: 0.4853 - val_accuracy: 0.7533
# Epoch 31/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.5000 - accuracy: 0.7381 - val_loss: 0.4858 - val_accuracy: 0.7528
# Epoch 32/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4997 - accuracy: 0.7380 - val_loss: 0.4848 - val_accuracy: 0.7532
# Epoch 33/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4994 - accuracy: 0.7382 - val_loss: 0.4848 - val_accuracy: 0.7532
# Epoch 34/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4992 - accuracy: 0.7383 - val_loss: 0.4845 - val_accuracy: 0.7532
# Epoch 35/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4989 - accuracy: 0.7385 - val_loss: 0.4849 - val_accuracy: 0.7530
# Epoch 36/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4987 - accuracy: 0.7387 - val_loss: 0.4841 - val_accuracy: 0.7530
# Epoch 37/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4984 - accuracy: 0.7388 - val_loss: 0.4840 - val_accuracy: 0.7529
# Epoch 38/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4981 - accuracy: 0.7390 - val_loss: 0.4837 - val_accuracy: 0.7528
# Epoch 39/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4979 - accuracy: 0.7391 - val_loss: 0.4837 - val_accuracy: 0.7527
# Epoch 40/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4976 - accuracy: 0.7394 - val_loss: 0.4832 - val_accuracy: 0.7527
# Epoch 41/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4974 - accuracy: 0.7395 - val_loss: 0.4833 - val_accuracy: 0.7527
# Epoch 42/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4971 - accuracy: 0.7397 - val_loss: 0.4832 - val_accuracy: 0.7527
# Epoch 43/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4968 - accuracy: 0.7398 - val_loss: 0.4836 - val_accuracy: 0.7526
# Epoch 44/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4966 - accuracy: 0.7402 - val_loss: 0.4823 - val_accuracy: 0.7528
# Epoch 45/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4963 - accuracy: 0.7404 - val_loss: 0.4825 - val_accuracy: 0.7528
# Epoch 46/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4960 - accuracy: 0.7407 - val_loss: 0.4824 - val_accuracy: 0.7529
# Epoch 47/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4957 - accuracy: 0.7410 - val_loss: 0.4822 - val_accuracy: 0.7530
# Epoch 48/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4954 - accuracy: 0.7412 - val_loss: 0.4820 - val_accuracy: 0.7527
# Epoch 49/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4951 - accuracy: 0.7417 - val_loss: 0.4815 - val_accuracy: 0.7530
# Epoch 50/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4948 - accuracy: 0.7419 - val_loss: 0.4811 - val_accuracy: 0.7529
# Epoch 51/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4945 - accuracy: 0.7422 - val_loss: 0.4808 - val_accuracy: 0.7528
# Epoch 52/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4941 - accuracy: 0.7427 - val_loss: 0.4809 - val_accuracy: 0.7530
# Epoch 53/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4938 - accuracy: 0.7431 - val_loss: 0.4809 - val_accuracy: 0.7533
# Epoch 54/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4935 - accuracy: 0.7434 - val_loss: 0.4803 - val_accuracy: 0.7533
# Epoch 55/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4931 - accuracy: 0.7438 - val_loss: 0.4801 - val_accuracy: 0.7529
# Epoch 56/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4928 - accuracy: 0.7441 - val_loss: 0.4801 - val_accuracy: 0.7530
# Epoch 57/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4924 - accuracy: 0.7446 - val_loss: 0.4795 - val_accuracy: 0.7531
# Epoch 58/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4920 - accuracy: 0.7449 - val_loss: 0.4793 - val_accuracy: 0.7531
# Epoch 59/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4917 - accuracy: 0.7451 - val_loss: 0.4794 - val_accuracy: 0.7529
# Epoch 60/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4913 - accuracy: 0.7454 - val_loss: 0.4790 - val_accuracy: 0.7528
# Epoch 61/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4909 - accuracy: 0.7454 - val_loss: 0.4791 - val_accuracy: 0.7520
# Epoch 62/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4906 - accuracy: 0.7458 - val_loss: 0.4788 - val_accuracy: 0.7522
# Epoch 63/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4901 - accuracy: 0.7460 - val_loss: 0.4786 - val_accuracy: 0.7522
# Epoch 64/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4898 - accuracy: 0.7465 - val_loss: 0.4782 - val_accuracy: 0.7526
# Epoch 65/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4894 - accuracy: 0.7467 - val_loss: 0.4778 - val_accuracy: 0.7523
# Epoch 66/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4889 - accuracy: 0.7470 - val_loss: 0.4785 - val_accuracy: 0.7518
# Epoch 67/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4885 - accuracy: 0.7472 - val_loss: 0.4775 - val_accuracy: 0.7522
# Epoch 68/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4881 - accuracy: 0.7475 - val_loss: 0.4771 - val_accuracy: 0.7523
# Epoch 69/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4876 - accuracy: 0.7478 - val_loss: 0.4771 - val_accuracy: 0.7526
# Epoch 70/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4872 - accuracy: 0.7482 - val_loss: 0.4771 - val_accuracy: 0.7529
# Epoch 71/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4867 - accuracy: 0.7483 - val_loss: 0.4764 - val_accuracy: 0.7532
# Epoch 72/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4862 - accuracy: 0.7482 - val_loss: 0.4769 - val_accuracy: 0.7528
# Epoch 73/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4856 - accuracy: 0.7483 - val_loss: 0.4756 - val_accuracy: 0.7533
# Epoch 74/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4851 - accuracy: 0.7484 - val_loss: 0.4754 - val_accuracy: 0.7530
# Epoch 75/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4845 - accuracy: 0.7483 - val_loss: 0.4752 - val_accuracy: 0.7532
# Epoch 76/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4840 - accuracy: 0.7484 - val_loss: 0.4755 - val_accuracy: 0.7519
# Epoch 77/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4834 - accuracy: 0.7483 - val_loss: 0.4742 - val_accuracy: 0.7530
# Epoch 78/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4828 - accuracy: 0.7483 - val_loss: 0.4744 - val_accuracy: 0.7526
# Epoch 79/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4822 - accuracy: 0.7485 - val_loss: 0.4735 - val_accuracy: 0.7529
# Epoch 80/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4816 - accuracy: 0.7484 - val_loss: 0.4734 - val_accuracy: 0.7530
# Epoch 81/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4811 - accuracy: 0.7489 - val_loss: 0.4730 - val_accuracy: 0.7529
# Epoch 82/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4805 - accuracy: 0.7491 - val_loss: 0.4732 - val_accuracy: 0.7530
# Epoch 83/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4800 - accuracy: 0.7495 - val_loss: 0.4725 - val_accuracy: 0.7528
# Epoch 84/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4794 - accuracy: 0.7495 - val_loss: 0.4725 - val_accuracy: 0.7531
# Epoch 85/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4789 - accuracy: 0.7497 - val_loss: 0.4721 - val_accuracy: 0.7530
# Epoch 86/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4784 - accuracy: 0.7500 - val_loss: 0.4713 - val_accuracy: 0.7533
# Epoch 87/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4779 - accuracy: 0.7506 - val_loss: 0.4711 - val_accuracy: 0.7529
# Epoch 88/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4774 - accuracy: 0.7506 - val_loss: 0.4707 - val_accuracy: 0.7533
# Epoch 89/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4769 - accuracy: 0.7511 - val_loss: 0.4701 - val_accuracy: 0.7533
# Epoch 90/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4765 - accuracy: 0.7515 - val_loss: 0.4695 - val_accuracy: 0.7541
# Epoch 91/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4760 - accuracy: 0.7518 - val_loss: 0.4695 - val_accuracy: 0.7540
# Epoch 92/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4755 - accuracy: 0.7519 - val_loss: 0.4689 - val_accuracy: 0.7546
# Epoch 93/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4751 - accuracy: 0.7520 - val_loss: 0.4683 - val_accuracy: 0.7546
# Epoch 94/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4746 - accuracy: 0.7522 - val_loss: 0.4681 - val_accuracy: 0.7552
# Epoch 95/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4742 - accuracy: 0.7526 - val_loss: 0.4672 - val_accuracy: 0.7558
# Epoch 96/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4738 - accuracy: 0.7526 - val_loss: 0.4666 - val_accuracy: 0.7560
# Epoch 97/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4733 - accuracy: 0.7530 - val_loss: 0.4667 - val_accuracy: 0.7567
# Epoch 98/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4729 - accuracy: 0.7531 - val_loss: 0.4665 - val_accuracy: 0.7570
# Epoch 99/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4725 - accuracy: 0.7532 - val_loss: 0.4655 - val_accuracy: 0.7573
# Epoch 100/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4721 - accuracy: 0.7535 - val_loss: 0.4652 - val_accuracy: 0.7576
# Epoch 101/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4717 - accuracy: 0.7537 - val_loss: 0.4645 - val_accuracy: 0.7579
# Epoch 102/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4713 - accuracy: 0.7537 - val_loss: 0.4647 - val_accuracy: 0.7575
# Epoch 103/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4709 - accuracy: 0.7539 - val_loss: 0.4644 - val_accuracy: 0.7584
# Epoch 104/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4706 - accuracy: 0.7541 - val_loss: 0.4637 - val_accuracy: 0.7578
# Epoch 105/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4702 - accuracy: 0.7540 - val_loss: 0.4631 - val_accuracy: 0.7582
# Epoch 106/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4699 - accuracy: 0.7542 - val_loss: 0.4626 - val_accuracy: 0.7588
# Epoch 107/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4695 - accuracy: 0.7542 - val_loss: 0.4632 - val_accuracy: 0.7581
# Epoch 108/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4692 - accuracy: 0.7541 - val_loss: 0.4622 - val_accuracy: 0.7583
# Epoch 109/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4689 - accuracy: 0.7543 - val_loss: 0.4615 - val_accuracy: 0.7586
# Epoch 110/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4685 - accuracy: 0.7543 - val_loss: 0.4611 - val_accuracy: 0.7587
# Epoch 111/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4683 - accuracy: 0.7543 - val_loss: 0.4610 - val_accuracy: 0.7585
# Epoch 112/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4680 - accuracy: 0.7544 - val_loss: 0.4608 - val_accuracy: 0.7591
# Epoch 113/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4677 - accuracy: 0.7545 - val_loss: 0.4606 - val_accuracy: 0.7589
# Epoch 114/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4674 - accuracy: 0.7546 - val_loss: 0.4600 - val_accuracy: 0.7593
# Epoch 115/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4672 - accuracy: 0.7547 - val_loss: 0.4597 - val_accuracy: 0.7590
# Epoch 116/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4669 - accuracy: 0.7548 - val_loss: 0.4593 - val_accuracy: 0.7593
# Epoch 117/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4667 - accuracy: 0.7548 - val_loss: 0.4591 - val_accuracy: 0.7594
# Epoch 118/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4664 - accuracy: 0.7547 - val_loss: 0.4586 - val_accuracy: 0.7597
# Epoch 119/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4662 - accuracy: 0.7549 - val_loss: 0.4588 - val_accuracy: 0.7590
# Epoch 120/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4660 - accuracy: 0.7548 - val_loss: 0.4590 - val_accuracy: 0.7596
# Epoch 121/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4658 - accuracy: 0.7550 - val_loss: 0.4580 - val_accuracy: 0.7588
# Epoch 122/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4656 - accuracy: 0.7552 - val_loss: 0.4582 - val_accuracy: 0.7592
# Epoch 123/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4654 - accuracy: 0.7553 - val_loss: 0.4584 - val_accuracy: 0.7593
# Epoch 124/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4652 - accuracy: 0.7556 - val_loss: 0.4578 - val_accuracy: 0.7593
# Epoch 125/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4651 - accuracy: 0.7553 - val_loss: 0.4579 - val_accuracy: 0.7596
# Epoch 126/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4649 - accuracy: 0.7555 - val_loss: 0.4571 - val_accuracy: 0.7594
# Epoch 127/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4647 - accuracy: 0.7555 - val_loss: 0.4575 - val_accuracy: 0.7594
# Epoch 128/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4646 - accuracy: 0.7556 - val_loss: 0.4571 - val_accuracy: 0.7598
# Epoch 129/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4645 - accuracy: 0.7557 - val_loss: 0.4564 - val_accuracy: 0.7596
# Epoch 130/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4643 - accuracy: 0.7558 - val_loss: 0.4571 - val_accuracy: 0.7599
# Epoch 131/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4642 - accuracy: 0.7559 - val_loss: 0.4561 - val_accuracy: 0.7597
# Epoch 132/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4640 - accuracy: 0.7559 - val_loss: 0.4565 - val_accuracy: 0.7598
# Epoch 133/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4639 - accuracy: 0.7557 - val_loss: 0.4559 - val_accuracy: 0.7604
# Epoch 134/140
# 2971/2971 [==============================] - 55s 18ms/step - loss: 0.4638 - accuracy: 0.7558 - val_loss: 0.4555 - val_accuracy: 0.7603
# Epoch 135/140
# 2971/2971 [==============================] - 55s 18ms/step - loss: 0.4636 - accuracy: 0.7560 - val_loss: 0.4553 - val_accuracy: 0.7600
# Epoch 136/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4635 - accuracy: 0.7561 - val_loss: 0.4564 - val_accuracy: 0.7600
# Epoch 137/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4634 - accuracy: 0.7562 - val_loss: 0.4560 - val_accuracy: 0.7602
# Epoch 138/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4633 - accuracy: 0.7563 - val_loss: 0.4557 - val_accuracy: 0.7603
# Epoch 139/140
# 2971/2971 [==============================] - 56s 19ms/step - loss: 0.4632 - accuracy: 0.7562 - val_loss: 0.4560 - val_accuracy: 0.7603
# Epoch 140/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4631 - accuracy: 0.7564 - val_loss: 0.4559 - val_accuracy: 0.7600

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 17s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 7375.119804620743

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.01648226],
#        [0.01479793],
#        [0.0127729 ],
#        ...,
#        [0.14058447],
#        [0.14034095],
#        [0.13914111]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.15288220323825125
# 0.17789395592234636
# 0.39100153866481296
# 0.31169931386580896

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 79s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.55100018]
# [0.79320655]
# total acc [0.75721249]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
