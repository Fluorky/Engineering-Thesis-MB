# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1aeaf409040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1aee9471040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=80,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/80
# 2971/2971 [==============================] - 59s 18ms/step - loss: 0.5714 - accuracy: 0.7393 - val_loss: 0.5529 - val_accuracy: 0.7531
# Epoch 2/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.5509 - accuracy: 0.7398 - val_loss: 0.5210 - val_accuracy: 0.7508
# Epoch 3/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.5150 - accuracy: 0.7396 - val_loss: 0.4937 - val_accuracy: 0.7509
# Epoch 4/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.5036 - accuracy: 0.7370 - val_loss: 0.4869 - val_accuracy: 0.7534
# Epoch 5/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.5011 - accuracy: 0.7384 - val_loss: 0.4877 - val_accuracy: 0.7533
# Epoch 6/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4997 - accuracy: 0.7392 - val_loss: 0.4834 - val_accuracy: 0.7531
# Epoch 7/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4984 - accuracy: 0.7392 - val_loss: 0.4827 - val_accuracy: 0.7531
# Epoch 8/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4972 - accuracy: 0.7393 - val_loss: 0.4816 - val_accuracy: 0.7531
# Epoch 9/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4958 - accuracy: 0.7395 - val_loss: 0.4798 - val_accuracy: 0.7530
# Epoch 10/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4938 - accuracy: 0.7408 - val_loss: 0.4819 - val_accuracy: 0.7546
# Epoch 11/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4913 - accuracy: 0.7443 - val_loss: 0.4770 - val_accuracy: 0.7546
# Epoch 12/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4882 - accuracy: 0.7469 - val_loss: 0.4754 - val_accuracy: 0.7532
# Epoch 13/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4846 - accuracy: 0.7482 - val_loss: 0.4781 - val_accuracy: 0.7483
# Epoch 14/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4807 - accuracy: 0.7485 - val_loss: 0.4703 - val_accuracy: 0.7534
# Epoch 15/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4768 - accuracy: 0.7501 - val_loss: 0.4731 - val_accuracy: 0.7533
# Epoch 16/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4732 - accuracy: 0.7520 - val_loss: 0.4627 - val_accuracy: 0.7580
# Epoch 17/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4705 - accuracy: 0.7533 - val_loss: 0.4625 - val_accuracy: 0.7566
# Epoch 18/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4684 - accuracy: 0.7542 - val_loss: 0.4582 - val_accuracy: 0.7581
# Epoch 19/80
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4668 - accuracy: 0.7549 - val_loss: 0.4595 - val_accuracy: 0.7578
# Epoch 20/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4655 - accuracy: 0.7553 - val_loss: 0.4559 - val_accuracy: 0.7588
# Epoch 21/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4645 - accuracy: 0.7557 - val_loss: 0.4552 - val_accuracy: 0.7593
# Epoch 22/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4635 - accuracy: 0.7560 - val_loss: 0.4541 - val_accuracy: 0.7593
# Epoch 23/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4625 - accuracy: 0.7563 - val_loss: 0.4639 - val_accuracy: 0.7619
# Epoch 24/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4617 - accuracy: 0.7571 - val_loss: 0.4531 - val_accuracy: 0.7609
# Epoch 25/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4608 - accuracy: 0.7572 - val_loss: 0.4517 - val_accuracy: 0.7622
# Epoch 26/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4599 - accuracy: 0.7577 - val_loss: 0.4555 - val_accuracy: 0.7624
# Epoch 27/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4591 - accuracy: 0.7581 - val_loss: 0.4503 - val_accuracy: 0.7620
# Epoch 28/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4585 - accuracy: 0.7584 - val_loss: 0.4513 - val_accuracy: 0.7607
# Epoch 29/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4577 - accuracy: 0.7590 - val_loss: 0.4481 - val_accuracy: 0.7644
# Epoch 30/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4569 - accuracy: 0.7598 - val_loss: 0.4476 - val_accuracy: 0.7636
# Epoch 31/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4559 - accuracy: 0.7603 - val_loss: 0.4475 - val_accuracy: 0.7638
# Epoch 32/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4554 - accuracy: 0.7605 - val_loss: 0.4465 - val_accuracy: 0.7667
# Epoch 33/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4546 - accuracy: 0.7613 - val_loss: 0.4578 - val_accuracy: 0.7671
# Epoch 34/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4541 - accuracy: 0.7620 - val_loss: 0.4563 - val_accuracy: 0.7630
# Epoch 35/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4532 - accuracy: 0.7628 - val_loss: 0.4523 - val_accuracy: 0.7650
# Epoch 36/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4524 - accuracy: 0.7632 - val_loss: 0.4479 - val_accuracy: 0.7674
# Epoch 37/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4519 - accuracy: 0.7641 - val_loss: 0.4475 - val_accuracy: 0.7671
# Epoch 38/80
# 2971/2971 [==============================] - 45s 15ms/step - loss: 0.4511 - accuracy: 0.7641 - val_loss: 0.4442 - val_accuracy: 0.7704
# Epoch 39/80
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4504 - accuracy: 0.7654 - val_loss: 0.4416 - val_accuracy: 0.7696
# Epoch 40/80
# 2971/2971 [==============================] - 49s 17ms/step - loss: 0.4499 - accuracy: 0.7653 - val_loss: 0.4483 - val_accuracy: 0.7672
# Epoch 41/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4491 - accuracy: 0.7657 - val_loss: 0.4398 - val_accuracy: 0.7715
# Epoch 42/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4485 - accuracy: 0.7659 - val_loss: 0.4407 - val_accuracy: 0.7705
# Epoch 43/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4480 - accuracy: 0.7662 - val_loss: 0.4396 - val_accuracy: 0.7721
# Epoch 44/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4478 - accuracy: 0.7667 - val_loss: 0.4397 - val_accuracy: 0.7718
# Epoch 45/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4471 - accuracy: 0.7669 - val_loss: 0.4429 - val_accuracy: 0.7716
# Epoch 46/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4468 - accuracy: 0.7674 - val_loss: 0.4398 - val_accuracy: 0.7716
# Epoch 47/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4464 - accuracy: 0.7678 - val_loss: 0.4385 - val_accuracy: 0.7729
# Epoch 48/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4457 - accuracy: 0.7680 - val_loss: 0.4394 - val_accuracy: 0.7728
# Epoch 49/80
# 2971/2971 [==============================] - 49s 17ms/step - loss: 0.4453 - accuracy: 0.7685 - val_loss: 0.4386 - val_accuracy: 0.7713
# Epoch 50/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4450 - accuracy: 0.7685 - val_loss: 0.4372 - val_accuracy: 0.7729
# Epoch 51/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4446 - accuracy: 0.7690 - val_loss: 0.4413 - val_accuracy: 0.7739
# Epoch 52/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4443 - accuracy: 0.7695 - val_loss: 0.4387 - val_accuracy: 0.7742
# Epoch 53/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4438 - accuracy: 0.7700 - val_loss: 0.4387 - val_accuracy: 0.7729
# Epoch 54/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4437 - accuracy: 0.7699 - val_loss: 0.4354 - val_accuracy: 0.7733
# Epoch 55/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4432 - accuracy: 0.7703 - val_loss: 0.4360 - val_accuracy: 0.7741
# Epoch 56/80
# 2971/2971 [==============================] - 49s 16ms/step - loss: 0.4428 - accuracy: 0.7707 - val_loss: 0.4392 - val_accuracy: 0.7746
# Epoch 57/80
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4424 - accuracy: 0.7709 - val_loss: 0.4414 - val_accuracy: 0.7726
# Epoch 58/80
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4422 - accuracy: 0.7715 - val_loss: 0.4353 - val_accuracy: 0.7754
# Epoch 59/80
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4419 - accuracy: 0.7718 - val_loss: 0.4396 - val_accuracy: 0.7752
# Epoch 60/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4417 - accuracy: 0.7720 - val_loss: 0.4380 - val_accuracy: 0.7743
# Epoch 61/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4416 - accuracy: 0.7720 - val_loss: 0.4431 - val_accuracy: 0.7732
# Epoch 62/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4412 - accuracy: 0.7721 - val_loss: 0.4375 - val_accuracy: 0.7750
# Epoch 63/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4411 - accuracy: 0.7725 - val_loss: 0.4339 - val_accuracy: 0.7763
# Epoch 64/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4407 - accuracy: 0.7727 - val_loss: 0.4377 - val_accuracy: 0.7743
# Epoch 65/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4403 - accuracy: 0.7727 - val_loss: 0.4391 - val_accuracy: 0.7760
# Epoch 66/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4402 - accuracy: 0.7732 - val_loss: 0.4339 - val_accuracy: 0.7759
# Epoch 67/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4399 - accuracy: 0.7730 - val_loss: 0.4372 - val_accuracy: 0.7751
# Epoch 68/80
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4398 - accuracy: 0.7737 - val_loss: 0.4359 - val_accuracy: 0.7752
# Epoch 69/80
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4394 - accuracy: 0.7734 - val_loss: 0.4415 - val_accuracy: 0.7752
# Epoch 70/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4392 - accuracy: 0.7739 - val_loss: 0.4344 - val_accuracy: 0.7763
# Epoch 71/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4392 - accuracy: 0.7737 - val_loss: 0.4350 - val_accuracy: 0.7758
# Epoch 72/80
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4389 - accuracy: 0.7742 - val_loss: 0.4335 - val_accuracy: 0.7772
# Epoch 73/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4388 - accuracy: 0.7741 - val_loss: 0.4369 - val_accuracy: 0.7767
# Epoch 74/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4385 - accuracy: 0.7740 - val_loss: 0.4323 - val_accuracy: 0.7780
# Epoch 75/80
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4383 - accuracy: 0.7743 - val_loss: 0.4312 - val_accuracy: 0.7777
# Epoch 76/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4381 - accuracy: 0.7749 - val_loss: 0.4351 - val_accuracy: 0.7779
# Epoch 77/80
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4379 - accuracy: 0.7747 - val_loss: 0.4352 - val_accuracy: 0.7775
# Epoch 78/80
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4378 - accuracy: 0.7752 - val_loss: 0.4385 - val_accuracy: 0.7773
# Epoch 79/80
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4375 - accuracy: 0.7750 - val_loss: 0.4418 - val_accuracy: 0.7779
# Epoch 80/80
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4371 - accuracy: 0.7752 - val_loss: 0.4361 - val_accuracy: 0.7762

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 3797.263174057007

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00303351],
#        [0.00256693],
#        [0.00094412],
#        ...,
#        [0.0624157 ],
#        [0.06134135],
#        [0.06221454]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1461301622164348
# 0.2142022613779203
# 0.38226975059038454
# 0.2982099707577078

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 75s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.58391269]
# [0.82202462]
# total acc [0.77511618]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
