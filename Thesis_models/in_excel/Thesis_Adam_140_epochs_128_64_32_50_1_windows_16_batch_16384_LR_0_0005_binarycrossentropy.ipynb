# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x22900006040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x229751c5040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0005)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 12s 137ms/step - loss: 0.6222 - accuracy: 0.6701 - val_loss: 0.5610 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.5753 - accuracy: 0.7393 - val_loss: 0.5608 - val_accuracy: 0.7531
# Epoch 3/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.5731 - accuracy: 0.7393 - val_loss: 0.5579 - val_accuracy: 0.7531
# Epoch 4/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.5689 - accuracy: 0.7393 - val_loss: 0.5491 - val_accuracy: 0.7531
# Epoch 5/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.5477 - accuracy: 0.7388 - val_loss: 0.5196 - val_accuracy: 0.7531
# Epoch 6/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.5217 - accuracy: 0.7396 - val_loss: 0.4973 - val_accuracy: 0.7524
# Epoch 7/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.5096 - accuracy: 0.7379 - val_loss: 0.4912 - val_accuracy: 0.7531
# Epoch 8/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.5045 - accuracy: 0.7392 - val_loss: 0.4869 - val_accuracy: 0.7536
# Epoch 9/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.5002 - accuracy: 0.7407 - val_loss: 0.4851 - val_accuracy: 0.7543
# Epoch 10/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4979 - accuracy: 0.7430 - val_loss: 0.4862 - val_accuracy: 0.7541
# Epoch 11/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4952 - accuracy: 0.7451 - val_loss: 0.4818 - val_accuracy: 0.7540
# Epoch 12/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4911 - accuracy: 0.7473 - val_loss: 0.4795 - val_accuracy: 0.7533
# Epoch 13/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4873 - accuracy: 0.7483 - val_loss: 0.4773 - val_accuracy: 0.7519
# Epoch 14/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4820 - accuracy: 0.7501 - val_loss: 0.4716 - val_accuracy: 0.7543
# Epoch 15/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4773 - accuracy: 0.7533 - val_loss: 0.4719 - val_accuracy: 0.7549
# Epoch 16/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4739 - accuracy: 0.7551 - val_loss: 0.4653 - val_accuracy: 0.7578
# Epoch 17/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4705 - accuracy: 0.7566 - val_loss: 0.4628 - val_accuracy: 0.7587
# Epoch 18/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4680 - accuracy: 0.7576 - val_loss: 0.4599 - val_accuracy: 0.7633
# Epoch 19/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4683 - accuracy: 0.7574 - val_loss: 0.4587 - val_accuracy: 0.7640
# Epoch 20/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4658 - accuracy: 0.7579 - val_loss: 0.4563 - val_accuracy: 0.7623
# Epoch 21/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4630 - accuracy: 0.7589 - val_loss: 0.4644 - val_accuracy: 0.7649
# Epoch 22/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4634 - accuracy: 0.7592 - val_loss: 0.4546 - val_accuracy: 0.7642
# Epoch 23/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4623 - accuracy: 0.7595 - val_loss: 0.4550 - val_accuracy: 0.7654
# Epoch 24/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4604 - accuracy: 0.7603 - val_loss: 0.4562 - val_accuracy: 0.7624
# Epoch 25/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4590 - accuracy: 0.7610 - val_loss: 0.4510 - val_accuracy: 0.7668
# Epoch 26/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4582 - accuracy: 0.7618 - val_loss: 0.4514 - val_accuracy: 0.7675
# Epoch 27/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4567 - accuracy: 0.7623 - val_loss: 0.4483 - val_accuracy: 0.7681
# Epoch 28/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4559 - accuracy: 0.7629 - val_loss: 0.4487 - val_accuracy: 0.7685
# Epoch 29/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4567 - accuracy: 0.7633 - val_loss: 0.4519 - val_accuracy: 0.7698
# Epoch 30/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4548 - accuracy: 0.7644 - val_loss: 0.4455 - val_accuracy: 0.7696
# Epoch 31/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4535 - accuracy: 0.7645 - val_loss: 0.4465 - val_accuracy: 0.7702
# Epoch 32/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4539 - accuracy: 0.7653 - val_loss: 0.4444 - val_accuracy: 0.7708
# Epoch 33/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4530 - accuracy: 0.7649 - val_loss: 0.4543 - val_accuracy: 0.7714
# Epoch 34/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4542 - accuracy: 0.7652 - val_loss: 0.4497 - val_accuracy: 0.7683
# Epoch 35/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4526 - accuracy: 0.7659 - val_loss: 0.4451 - val_accuracy: 0.7715
# Epoch 36/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4509 - accuracy: 0.7663 - val_loss: 0.4437 - val_accuracy: 0.7726
# Epoch 37/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4505 - accuracy: 0.7668 - val_loss: 0.4428 - val_accuracy: 0.7723
# Epoch 38/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4506 - accuracy: 0.7664 - val_loss: 0.4432 - val_accuracy: 0.7728
# Epoch 39/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4499 - accuracy: 0.7674 - val_loss: 0.4510 - val_accuracy: 0.7728
# Epoch 40/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4509 - accuracy: 0.7675 - val_loss: 0.4427 - val_accuracy: 0.7723
# Epoch 41/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4484 - accuracy: 0.7679 - val_loss: 0.4420 - val_accuracy: 0.7727
# Epoch 42/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4478 - accuracy: 0.7686 - val_loss: 0.4423 - val_accuracy: 0.7733
# Epoch 43/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4477 - accuracy: 0.7687 - val_loss: 0.4402 - val_accuracy: 0.7742
# Epoch 44/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4470 - accuracy: 0.7689 - val_loss: 0.4435 - val_accuracy: 0.7731
# Epoch 45/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4476 - accuracy: 0.7690 - val_loss: 0.4417 - val_accuracy: 0.7733
# Epoch 46/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4475 - accuracy: 0.7692 - val_loss: 0.4438 - val_accuracy: 0.7744
# Epoch 47/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4469 - accuracy: 0.7694 - val_loss: 0.4397 - val_accuracy: 0.7757
# Epoch 48/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4463 - accuracy: 0.7700 - val_loss: 0.4401 - val_accuracy: 0.7747
# Epoch 49/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4474 - accuracy: 0.7697 - val_loss: 0.4437 - val_accuracy: 0.7744
# Epoch 50/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4456 - accuracy: 0.7704 - val_loss: 0.4391 - val_accuracy: 0.7757
# Epoch 51/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4453 - accuracy: 0.7705 - val_loss: 0.4388 - val_accuracy: 0.7756
# Epoch 52/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4450 - accuracy: 0.7707 - val_loss: 0.4383 - val_accuracy: 0.7755
# Epoch 53/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4450 - accuracy: 0.7706 - val_loss: 0.4389 - val_accuracy: 0.7757
# Epoch 54/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4441 - accuracy: 0.7709 - val_loss: 0.4389 - val_accuracy: 0.7754
# Epoch 55/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4452 - accuracy: 0.7707 - val_loss: 0.4389 - val_accuracy: 0.7762
# Epoch 56/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4437 - accuracy: 0.7711 - val_loss: 0.4412 - val_accuracy: 0.7762
# Epoch 57/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4437 - accuracy: 0.7713 - val_loss: 0.4386 - val_accuracy: 0.7765
# Epoch 58/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4446 - accuracy: 0.7713 - val_loss: 0.4390 - val_accuracy: 0.7769
# Epoch 59/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4425 - accuracy: 0.7718 - val_loss: 0.4374 - val_accuracy: 0.7768
# Epoch 60/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4426 - accuracy: 0.7719 - val_loss: 0.4397 - val_accuracy: 0.7761
# Epoch 61/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4428 - accuracy: 0.7722 - val_loss: 0.4366 - val_accuracy: 0.7767
# Epoch 62/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4422 - accuracy: 0.7720 - val_loss: 0.4365 - val_accuracy: 0.7767
# Epoch 63/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4418 - accuracy: 0.7723 - val_loss: 0.4383 - val_accuracy: 0.7761
# Epoch 64/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4413 - accuracy: 0.7730 - val_loss: 0.4357 - val_accuracy: 0.7766
# Epoch 65/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4423 - accuracy: 0.7730 - val_loss: 0.4363 - val_accuracy: 0.7764
# Epoch 66/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4422 - accuracy: 0.7737 - val_loss: 0.4374 - val_accuracy: 0.7775
# Epoch 67/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4408 - accuracy: 0.7737 - val_loss: 0.4363 - val_accuracy: 0.7767
# Epoch 68/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4400 - accuracy: 0.7734 - val_loss: 0.4376 - val_accuracy: 0.7762
# Epoch 69/140
# 24/24 [==============================] - 2s 86ms/step - loss: 0.4408 - accuracy: 0.7735 - val_loss: 0.4359 - val_accuracy: 0.7772
# Epoch 70/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4412 - accuracy: 0.7734 - val_loss: 0.4347 - val_accuracy: 0.7770
# Epoch 71/140
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4423 - accuracy: 0.7737 - val_loss: 0.4361 - val_accuracy: 0.7772
# Epoch 72/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4408 - accuracy: 0.7740 - val_loss: 0.4393 - val_accuracy: 0.7774
# Epoch 73/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4399 - accuracy: 0.7742 - val_loss: 0.4361 - val_accuracy: 0.7776
# Epoch 74/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4397 - accuracy: 0.7743 - val_loss: 0.4352 - val_accuracy: 0.7776
# Epoch 75/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4402 - accuracy: 0.7743 - val_loss: 0.4358 - val_accuracy: 0.7770
# Epoch 76/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4388 - accuracy: 0.7749 - val_loss: 0.4359 - val_accuracy: 0.7780
# Epoch 77/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4397 - accuracy: 0.7744 - val_loss: 0.4358 - val_accuracy: 0.7773
# Epoch 78/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4389 - accuracy: 0.7748 - val_loss: 0.4361 - val_accuracy: 0.7770
# Epoch 79/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4394 - accuracy: 0.7747 - val_loss: 0.4333 - val_accuracy: 0.7790
# Epoch 80/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4388 - accuracy: 0.7747 - val_loss: 0.4367 - val_accuracy: 0.7785
# Epoch 81/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4378 - accuracy: 0.7751 - val_loss: 0.4355 - val_accuracy: 0.7777
# Epoch 82/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4381 - accuracy: 0.7750 - val_loss: 0.4341 - val_accuracy: 0.7783
# Epoch 83/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4377 - accuracy: 0.7751 - val_loss: 0.4432 - val_accuracy: 0.7781
# Epoch 84/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4385 - accuracy: 0.7751 - val_loss: 0.4454 - val_accuracy: 0.7776
# Epoch 85/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4383 - accuracy: 0.7751 - val_loss: 0.4347 - val_accuracy: 0.7783
# Epoch 86/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4373 - accuracy: 0.7752 - val_loss: 0.4341 - val_accuracy: 0.7775
# Epoch 87/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4371 - accuracy: 0.7755 - val_loss: 0.4343 - val_accuracy: 0.7775
# Epoch 88/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4372 - accuracy: 0.7757 - val_loss: 0.4347 - val_accuracy: 0.7782
# Epoch 89/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4376 - accuracy: 0.7756 - val_loss: 0.4350 - val_accuracy: 0.7778
# Epoch 90/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4365 - accuracy: 0.7760 - val_loss: 0.4360 - val_accuracy: 0.7783
# Epoch 91/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4369 - accuracy: 0.7757 - val_loss: 0.4358 - val_accuracy: 0.7778
# Epoch 92/140
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4369 - accuracy: 0.7756 - val_loss: 0.4326 - val_accuracy: 0.7781
# Epoch 93/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4362 - accuracy: 0.7761 - val_loss: 0.4340 - val_accuracy: 0.7784
# Epoch 94/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4361 - accuracy: 0.7761 - val_loss: 0.4322 - val_accuracy: 0.7794
# Epoch 95/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4362 - accuracy: 0.7758 - val_loss: 0.4350 - val_accuracy: 0.7780
# Epoch 96/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4371 - accuracy: 0.7760 - val_loss: 0.4346 - val_accuracy: 0.7791
# Epoch 97/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4363 - accuracy: 0.7761 - val_loss: 0.4322 - val_accuracy: 0.7788
# Epoch 98/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4366 - accuracy: 0.7762 - val_loss: 0.4357 - val_accuracy: 0.7788
# Epoch 99/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4370 - accuracy: 0.7763 - val_loss: 0.4321 - val_accuracy: 0.7790
# Epoch 100/140
# 24/24 [==============================] - 2s 81ms/step - loss: 0.4364 - accuracy: 0.7760 - val_loss: 0.4318 - val_accuracy: 0.7783
# Epoch 101/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4360 - accuracy: 0.7761 - val_loss: 0.4376 - val_accuracy: 0.7753
# Epoch 102/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4368 - accuracy: 0.7763 - val_loss: 0.4343 - val_accuracy: 0.7778
# Epoch 103/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4361 - accuracy: 0.7762 - val_loss: 0.4319 - val_accuracy: 0.7788
# Epoch 104/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4348 - accuracy: 0.7768 - val_loss: 0.4314 - val_accuracy: 0.7791
# Epoch 105/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4353 - accuracy: 0.7768 - val_loss: 0.4327 - val_accuracy: 0.7782
# Epoch 106/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4346 - accuracy: 0.7772 - val_loss: 0.4328 - val_accuracy: 0.7789
# Epoch 107/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4350 - accuracy: 0.7766 - val_loss: 0.4345 - val_accuracy: 0.7773
# Epoch 108/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4351 - accuracy: 0.7771 - val_loss: 0.4321 - val_accuracy: 0.7789
# Epoch 109/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4368 - accuracy: 0.7762 - val_loss: 0.4358 - val_accuracy: 0.7768
# Epoch 110/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4364 - accuracy: 0.7767 - val_loss: 0.4326 - val_accuracy: 0.7781
# Epoch 111/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4341 - accuracy: 0.7770 - val_loss: 0.4345 - val_accuracy: 0.7783
# Epoch 112/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4340 - accuracy: 0.7771 - val_loss: 0.4312 - val_accuracy: 0.7790
# Epoch 113/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4340 - accuracy: 0.7773 - val_loss: 0.4333 - val_accuracy: 0.7800
# Epoch 114/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4337 - accuracy: 0.7773 - val_loss: 0.4306 - val_accuracy: 0.7797
# Epoch 115/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4346 - accuracy: 0.7774 - val_loss: 0.4314 - val_accuracy: 0.7790
# Epoch 116/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4342 - accuracy: 0.7769 - val_loss: 0.4356 - val_accuracy: 0.7770
# Epoch 117/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4335 - accuracy: 0.7773 - val_loss: 0.4345 - val_accuracy: 0.7766
# Epoch 118/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4340 - accuracy: 0.7775 - val_loss: 0.4340 - val_accuracy: 0.7790
# Epoch 119/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4333 - accuracy: 0.7776 - val_loss: 0.4312 - val_accuracy: 0.7789
# Epoch 120/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4327 - accuracy: 0.7778 - val_loss: 0.4326 - val_accuracy: 0.7770
# Epoch 121/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4329 - accuracy: 0.7776 - val_loss: 0.4292 - val_accuracy: 0.7799
# Epoch 122/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4332 - accuracy: 0.7778 - val_loss: 0.4308 - val_accuracy: 0.7791
# Epoch 123/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4327 - accuracy: 0.7781 - val_loss: 0.4345 - val_accuracy: 0.7771
# Epoch 124/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4338 - accuracy: 0.7775 - val_loss: 0.4346 - val_accuracy: 0.7791
# Epoch 125/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4325 - accuracy: 0.7781 - val_loss: 0.4325 - val_accuracy: 0.7801
# Epoch 126/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4324 - accuracy: 0.7784 - val_loss: 0.4300 - val_accuracy: 0.7793
# Epoch 127/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4332 - accuracy: 0.7784 - val_loss: 0.4410 - val_accuracy: 0.7775
# Epoch 128/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4334 - accuracy: 0.7780 - val_loss: 0.4299 - val_accuracy: 0.7804
# Epoch 129/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4318 - accuracy: 0.7782 - val_loss: 0.4306 - val_accuracy: 0.7801
# Epoch 130/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4319 - accuracy: 0.7787 - val_loss: 0.4290 - val_accuracy: 0.7803
# Epoch 131/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4312 - accuracy: 0.7790 - val_loss: 0.4286 - val_accuracy: 0.7801
# Epoch 132/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4309 - accuracy: 0.7787 - val_loss: 0.4292 - val_accuracy: 0.7797
# Epoch 133/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4318 - accuracy: 0.7788 - val_loss: 0.4413 - val_accuracy: 0.7783
# Epoch 134/140
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4330 - accuracy: 0.7784 - val_loss: 0.4310 - val_accuracy: 0.7809
# Epoch 135/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4312 - accuracy: 0.7786 - val_loss: 0.4373 - val_accuracy: 0.7792
# Epoch 136/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4325 - accuracy: 0.7786 - val_loss: 0.4310 - val_accuracy: 0.7810
# Epoch 137/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4305 - accuracy: 0.7792 - val_loss: 0.4294 - val_accuracy: 0.7806
# Epoch 138/140
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4301 - accuracy: 0.7792 - val_loss: 0.4291 - val_accuracy: 0.7804
# Epoch 139/140
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4305 - accuracy: 0.7793 - val_loss: 0.4317 - val_accuracy: 0.7792
# Epoch 140/140
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4304 - accuracy: 0.7793 - val_loss: 0.4280 - val_accuracy: 0.7806

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 17s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 302.05291986465454

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00503592],
#        [0.00350413],
#        [0.00188818],
#        ...,
#        [0.06964084],
#        [0.07268853],
#        [0.07387591]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14325312680130334
# 0.22967318051504892
# 0.37848794802649044
# 0.28818577775513743

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 80s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60841795]
# [0.81600925]
# total acc [0.7798372]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 548989184, 'peak': 2858681856}
