# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1a58000a040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1a5f2573040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=150,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/150
# 2971/2971 [==============================] - 63s 19ms/step - loss: 0.5724 - accuracy: 0.7393 - val_loss: 0.5547 - val_accuracy: 0.7531
# Epoch 2/150
# 2971/2971 [==============================] - 49s 17ms/step - loss: 0.5558 - accuracy: 0.7393 - val_loss: 0.5210 - val_accuracy: 0.7533
# Epoch 3/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.5183 - accuracy: 0.7398 - val_loss: 0.4922 - val_accuracy: 0.7500
# Epoch 4/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.5040 - accuracy: 0.7362 - val_loss: 0.4861 - val_accuracy: 0.7529
# Epoch 5/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.5011 - accuracy: 0.7372 - val_loss: 0.4867 - val_accuracy: 0.7530
# Epoch 6/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4994 - accuracy: 0.7383 - val_loss: 0.4834 - val_accuracy: 0.7531
# Epoch 7/150
# 2971/2971 [==============================] - 49s 17ms/step - loss: 0.4980 - accuracy: 0.7389 - val_loss: 0.4846 - val_accuracy: 0.7531
# Epoch 8/150
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4963 - accuracy: 0.7402 - val_loss: 0.4835 - val_accuracy: 0.7537
# Epoch 9/150
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4941 - accuracy: 0.7425 - val_loss: 0.4831 - val_accuracy: 0.7544
# Epoch 10/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4914 - accuracy: 0.7454 - val_loss: 0.4861 - val_accuracy: 0.7496
# Epoch 11/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4879 - accuracy: 0.7474 - val_loss: 0.4769 - val_accuracy: 0.7538
# Epoch 12/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4839 - accuracy: 0.7477 - val_loss: 0.4747 - val_accuracy: 0.7530
# Epoch 13/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4800 - accuracy: 0.7486 - val_loss: 0.4699 - val_accuracy: 0.7549
# Epoch 14/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4763 - accuracy: 0.7506 - val_loss: 0.4666 - val_accuracy: 0.7557
# Epoch 15/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4731 - accuracy: 0.7523 - val_loss: 0.4631 - val_accuracy: 0.7588
# Epoch 16/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4705 - accuracy: 0.7538 - val_loss: 0.4613 - val_accuracy: 0.7569
# Epoch 17/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4684 - accuracy: 0.7540 - val_loss: 0.4610 - val_accuracy: 0.7568
# Epoch 18/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4668 - accuracy: 0.7548 - val_loss: 0.4573 - val_accuracy: 0.7585
# Epoch 19/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4654 - accuracy: 0.7549 - val_loss: 0.4554 - val_accuracy: 0.7602
# Epoch 20/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4644 - accuracy: 0.7555 - val_loss: 0.4604 - val_accuracy: 0.7609
# Epoch 21/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4634 - accuracy: 0.7563 - val_loss: 0.4552 - val_accuracy: 0.7616
# Epoch 22/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4627 - accuracy: 0.7563 - val_loss: 0.4528 - val_accuracy: 0.7615
# Epoch 23/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4616 - accuracy: 0.7567 - val_loss: 0.4545 - val_accuracy: 0.7613
# Epoch 24/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4608 - accuracy: 0.7572 - val_loss: 0.4509 - val_accuracy: 0.7617
# Epoch 25/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4601 - accuracy: 0.7579 - val_loss: 0.4555 - val_accuracy: 0.7639
# Epoch 26/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4592 - accuracy: 0.7585 - val_loss: 0.4491 - val_accuracy: 0.7628
# Epoch 27/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4586 - accuracy: 0.7591 - val_loss: 0.4503 - val_accuracy: 0.7631
# Epoch 28/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4576 - accuracy: 0.7600 - val_loss: 0.4489 - val_accuracy: 0.7650
# Epoch 29/150
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4571 - accuracy: 0.7603 - val_loss: 0.4546 - val_accuracy: 0.7655
# Epoch 30/150
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4560 - accuracy: 0.7612 - val_loss: 0.4479 - val_accuracy: 0.7670
# Epoch 31/150
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4553 - accuracy: 0.7619 - val_loss: 0.4477 - val_accuracy: 0.7665
# Epoch 32/150
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4544 - accuracy: 0.7629 - val_loss: 0.4436 - val_accuracy: 0.7689
# Epoch 33/150
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4536 - accuracy: 0.7635 - val_loss: 0.4476 - val_accuracy: 0.7694
# Epoch 34/150
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4529 - accuracy: 0.7640 - val_loss: 0.4423 - val_accuracy: 0.7706
# Epoch 35/150
# 2971/2971 [==============================] - 46s 16ms/step - loss: 0.4520 - accuracy: 0.7644 - val_loss: 0.4451 - val_accuracy: 0.7697
# Epoch 36/150
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4512 - accuracy: 0.7655 - val_loss: 0.4504 - val_accuracy: 0.7647
# Epoch 37/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4504 - accuracy: 0.7656 - val_loss: 0.4404 - val_accuracy: 0.7718
# Epoch 38/150
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4498 - accuracy: 0.7663 - val_loss: 0.4402 - val_accuracy: 0.7701
# Epoch 39/150
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.4491 - accuracy: 0.7671 - val_loss: 0.4397 - val_accuracy: 0.7726
# Epoch 40/150
# 2971/2971 [==============================] - 56s 19ms/step - loss: 0.4483 - accuracy: 0.7670 - val_loss: 0.4447 - val_accuracy: 0.7706
# Epoch 41/150
# 2971/2971 [==============================] - 57s 19ms/step - loss: 0.4477 - accuracy: 0.7678 - val_loss: 0.4388 - val_accuracy: 0.7736
# Epoch 42/150
# 2971/2971 [==============================] - 57s 19ms/step - loss: 0.4471 - accuracy: 0.7681 - val_loss: 0.4395 - val_accuracy: 0.7731
# Epoch 43/150
# 2971/2971 [==============================] - 55s 19ms/step - loss: 0.4466 - accuracy: 0.7686 - val_loss: 0.4417 - val_accuracy: 0.7745
# Epoch 44/150
# 2971/2971 [==============================] - 59s 20ms/step - loss: 0.4461 - accuracy: 0.7689 - val_loss: 0.4389 - val_accuracy: 0.7731
# Epoch 45/150
# 2971/2971 [==============================] - 59s 20ms/step - loss: 0.4456 - accuracy: 0.7697 - val_loss: 0.4477 - val_accuracy: 0.7727
# Epoch 46/150
# 2971/2971 [==============================] - 60s 20ms/step - loss: 0.4452 - accuracy: 0.7697 - val_loss: 0.4418 - val_accuracy: 0.7709
# Epoch 47/150
# 2971/2971 [==============================] - 56s 19ms/step - loss: 0.4447 - accuracy: 0.7701 - val_loss: 0.4389 - val_accuracy: 0.7737
# Epoch 48/150
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4443 - accuracy: 0.7702 - val_loss: 0.4355 - val_accuracy: 0.7744
# Epoch 49/150
# 2971/2971 [==============================] - 56s 19ms/step - loss: 0.4441 - accuracy: 0.7711 - val_loss: 0.4380 - val_accuracy: 0.7738
# Epoch 50/150
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4437 - accuracy: 0.7712 - val_loss: 0.4362 - val_accuracy: 0.7736
# Epoch 51/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4434 - accuracy: 0.7714 - val_loss: 0.4378 - val_accuracy: 0.7741
# Epoch 52/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4430 - accuracy: 0.7716 - val_loss: 0.4375 - val_accuracy: 0.7750
# Epoch 53/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4430 - accuracy: 0.7716 - val_loss: 0.4465 - val_accuracy: 0.7737
# Epoch 54/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4425 - accuracy: 0.7718 - val_loss: 0.4350 - val_accuracy: 0.7761
# Epoch 55/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4423 - accuracy: 0.7721 - val_loss: 0.4349 - val_accuracy: 0.7751
# Epoch 56/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4422 - accuracy: 0.7722 - val_loss: 0.4436 - val_accuracy: 0.7729
# Epoch 57/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4418 - accuracy: 0.7728 - val_loss: 0.4357 - val_accuracy: 0.7758
# Epoch 58/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4415 - accuracy: 0.7727 - val_loss: 0.4392 - val_accuracy: 0.7735
# Epoch 59/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4414 - accuracy: 0.7730 - val_loss: 0.4373 - val_accuracy: 0.7752
# Epoch 60/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4412 - accuracy: 0.7728 - val_loss: 0.4336 - val_accuracy: 0.7770
# Epoch 61/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4409 - accuracy: 0.7734 - val_loss: 0.4368 - val_accuracy: 0.7761
# Epoch 62/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4407 - accuracy: 0.7732 - val_loss: 0.4383 - val_accuracy: 0.7754
# Epoch 63/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4405 - accuracy: 0.7733 - val_loss: 0.4357 - val_accuracy: 0.7756
# Epoch 64/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4404 - accuracy: 0.7736 - val_loss: 0.4438 - val_accuracy: 0.7742
# Epoch 65/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4402 - accuracy: 0.7736 - val_loss: 0.4362 - val_accuracy: 0.7750
# Epoch 66/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4401 - accuracy: 0.7738 - val_loss: 0.4358 - val_accuracy: 0.7758
# Epoch 67/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4399 - accuracy: 0.7741 - val_loss: 0.4417 - val_accuracy: 0.7761
# Epoch 68/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4396 - accuracy: 0.7742 - val_loss: 0.4322 - val_accuracy: 0.7768
# Epoch 69/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4396 - accuracy: 0.7745 - val_loss: 0.4335 - val_accuracy: 0.7766
# Epoch 70/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4392 - accuracy: 0.7749 - val_loss: 0.4367 - val_accuracy: 0.7746
# Epoch 71/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4390 - accuracy: 0.7748 - val_loss: 0.4354 - val_accuracy: 0.7773
# Epoch 72/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4389 - accuracy: 0.7744 - val_loss: 0.4345 - val_accuracy: 0.7772
# Epoch 73/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4386 - accuracy: 0.7748 - val_loss: 0.4376 - val_accuracy: 0.7749
# Epoch 74/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4384 - accuracy: 0.7751 - val_loss: 0.4381 - val_accuracy: 0.7762
# Epoch 75/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4382 - accuracy: 0.7754 - val_loss: 0.4328 - val_accuracy: 0.7776
# Epoch 76/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4379 - accuracy: 0.7756 - val_loss: 0.4362 - val_accuracy: 0.7751
# Epoch 77/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4375 - accuracy: 0.7756 - val_loss: 0.4383 - val_accuracy: 0.7750
# Epoch 78/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4370 - accuracy: 0.7758 - val_loss: 0.4406 - val_accuracy: 0.7750
# Epoch 79/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4366 - accuracy: 0.7762 - val_loss: 0.4368 - val_accuracy: 0.7774
# Epoch 80/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4360 - accuracy: 0.7766 - val_loss: 0.4368 - val_accuracy: 0.7774
# Epoch 81/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4355 - accuracy: 0.7770 - val_loss: 0.4412 - val_accuracy: 0.7768
# Epoch 82/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4351 - accuracy: 0.7770 - val_loss: 0.4402 - val_accuracy: 0.7778
# Epoch 83/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4349 - accuracy: 0.7775 - val_loss: 0.4281 - val_accuracy: 0.7794
# Epoch 84/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4346 - accuracy: 0.7774 - val_loss: 0.4305 - val_accuracy: 0.7782
# Epoch 85/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4343 - accuracy: 0.7776 - val_loss: 0.4293 - val_accuracy: 0.7797
# Epoch 86/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4340 - accuracy: 0.7777 - val_loss: 0.4306 - val_accuracy: 0.7794
# Epoch 87/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4337 - accuracy: 0.7780 - val_loss: 0.4332 - val_accuracy: 0.7778
# Epoch 88/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4335 - accuracy: 0.7780 - val_loss: 0.4343 - val_accuracy: 0.7791
# Epoch 89/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4333 - accuracy: 0.7783 - val_loss: 0.4293 - val_accuracy: 0.7800
# Epoch 90/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4333 - accuracy: 0.7780 - val_loss: 0.4293 - val_accuracy: 0.7803
# Epoch 91/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4330 - accuracy: 0.7782 - val_loss: 0.4298 - val_accuracy: 0.7795
# Epoch 92/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4327 - accuracy: 0.7783 - val_loss: 0.4273 - val_accuracy: 0.7808
# Epoch 93/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4326 - accuracy: 0.7781 - val_loss: 0.4274 - val_accuracy: 0.7802
# Epoch 94/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4324 - accuracy: 0.7782 - val_loss: 0.4266 - val_accuracy: 0.7813
# Epoch 95/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4322 - accuracy: 0.7785 - val_loss: 0.4283 - val_accuracy: 0.7803
# Epoch 96/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4321 - accuracy: 0.7785 - val_loss: 0.4330 - val_accuracy: 0.7791
# Epoch 97/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4319 - accuracy: 0.7785 - val_loss: 0.4289 - val_accuracy: 0.7804
# Epoch 98/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4320 - accuracy: 0.7785 - val_loss: 0.4286 - val_accuracy: 0.7804
# Epoch 99/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4316 - accuracy: 0.7787 - val_loss: 0.4279 - val_accuracy: 0.7804
# Epoch 100/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4315 - accuracy: 0.7788 - val_loss: 0.4314 - val_accuracy: 0.7793
# Epoch 101/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4313 - accuracy: 0.7790 - val_loss: 0.4272 - val_accuracy: 0.7808
# Epoch 102/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4312 - accuracy: 0.7789 - val_loss: 0.4305 - val_accuracy: 0.7804
# Epoch 103/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4309 - accuracy: 0.7788 - val_loss: 0.4269 - val_accuracy: 0.7814
# Epoch 104/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4309 - accuracy: 0.7790 - val_loss: 0.4254 - val_accuracy: 0.7814
# Epoch 105/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4306 - accuracy: 0.7790 - val_loss: 0.4295 - val_accuracy: 0.7797
# Epoch 106/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4306 - accuracy: 0.7796 - val_loss: 0.4360 - val_accuracy: 0.7754
# Epoch 107/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4305 - accuracy: 0.7791 - val_loss: 0.4287 - val_accuracy: 0.7816
# Epoch 108/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4302 - accuracy: 0.7793 - val_loss: 0.4282 - val_accuracy: 0.7809
# Epoch 109/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4302 - accuracy: 0.7792 - val_loss: 0.4279 - val_accuracy: 0.7814
# Epoch 110/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4300 - accuracy: 0.7795 - val_loss: 0.4262 - val_accuracy: 0.7811
# Epoch 111/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4300 - accuracy: 0.7796 - val_loss: 0.4284 - val_accuracy: 0.7812
# Epoch 112/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4297 - accuracy: 0.7798 - val_loss: 0.4273 - val_accuracy: 0.7806
# Epoch 113/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4296 - accuracy: 0.7794 - val_loss: 0.4266 - val_accuracy: 0.7820
# Epoch 114/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4295 - accuracy: 0.7795 - val_loss: 0.4289 - val_accuracy: 0.7787
# Epoch 115/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4293 - accuracy: 0.7797 - val_loss: 0.4291 - val_accuracy: 0.7821
# Epoch 116/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4291 - accuracy: 0.7797 - val_loss: 0.4297 - val_accuracy: 0.7787
# Epoch 117/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4292 - accuracy: 0.7799 - val_loss: 0.4250 - val_accuracy: 0.7815
# Epoch 118/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4290 - accuracy: 0.7798 - val_loss: 0.4245 - val_accuracy: 0.7828
# Epoch 119/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4288 - accuracy: 0.7801 - val_loss: 0.4326 - val_accuracy: 0.7802
# Epoch 120/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4288 - accuracy: 0.7799 - val_loss: 0.4316 - val_accuracy: 0.7816
# Epoch 121/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4286 - accuracy: 0.7801 - val_loss: 0.4322 - val_accuracy: 0.7810
# Epoch 122/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4285 - accuracy: 0.7799 - val_loss: 0.4247 - val_accuracy: 0.7815
# Epoch 123/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4283 - accuracy: 0.7805 - val_loss: 0.4273 - val_accuracy: 0.7823
# Epoch 124/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4282 - accuracy: 0.7805 - val_loss: 0.4270 - val_accuracy: 0.7813
# Epoch 125/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4280 - accuracy: 0.7803 - val_loss: 0.4280 - val_accuracy: 0.7811
# Epoch 126/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4279 - accuracy: 0.7806 - val_loss: 0.4290 - val_accuracy: 0.7815
# Epoch 127/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4277 - accuracy: 0.7810 - val_loss: 0.4262 - val_accuracy: 0.7823
# Epoch 128/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4278 - accuracy: 0.7810 - val_loss: 0.4263 - val_accuracy: 0.7834
# Epoch 129/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4276 - accuracy: 0.7805 - val_loss: 0.4276 - val_accuracy: 0.7818
# Epoch 130/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4276 - accuracy: 0.7809 - val_loss: 0.4294 - val_accuracy: 0.7780
# Epoch 131/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4273 - accuracy: 0.7806 - val_loss: 0.4274 - val_accuracy: 0.7823
# Epoch 132/150
# 2971/2971 [==============================] - 48s 16ms/step - loss: 0.4272 - accuracy: 0.7807 - val_loss: 0.4255 - val_accuracy: 0.7819
# Epoch 133/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4269 - accuracy: 0.7810 - val_loss: 0.4290 - val_accuracy: 0.7821
# Epoch 134/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4270 - accuracy: 0.7809 - val_loss: 0.4293 - val_accuracy: 0.7827
# Epoch 135/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4269 - accuracy: 0.7808 - val_loss: 0.4267 - val_accuracy: 0.7823
# Epoch 136/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4267 - accuracy: 0.7811 - val_loss: 0.4262 - val_accuracy: 0.7812
# Epoch 137/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4264 - accuracy: 0.7811 - val_loss: 0.4251 - val_accuracy: 0.7830
# Epoch 138/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4265 - accuracy: 0.7808 - val_loss: 0.4226 - val_accuracy: 0.7838
# Epoch 139/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4263 - accuracy: 0.7813 - val_loss: 0.4310 - val_accuracy: 0.7781
# Epoch 140/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4263 - accuracy: 0.7814 - val_loss: 0.4264 - val_accuracy: 0.7829
# Epoch 141/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4261 - accuracy: 0.7813 - val_loss: 0.4247 - val_accuracy: 0.7825
# Epoch 142/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4258 - accuracy: 0.7815 - val_loss: 0.4256 - val_accuracy: 0.7824
# Epoch 143/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4258 - accuracy: 0.7810 - val_loss: 0.4244 - val_accuracy: 0.7832
# Epoch 144/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4255 - accuracy: 0.7818 - val_loss: 0.4271 - val_accuracy: 0.7832
# Epoch 145/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4255 - accuracy: 0.7815 - val_loss: 0.4264 - val_accuracy: 0.7813
# Epoch 146/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4254 - accuracy: 0.7818 - val_loss: 0.4305 - val_accuracy: 0.7816
# Epoch 147/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4253 - accuracy: 0.7817 - val_loss: 0.4288 - val_accuracy: 0.7806
# Epoch 148/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4253 - accuracy: 0.7815 - val_loss: 0.4291 - val_accuracy: 0.7833
# Epoch 149/150
# 2971/2971 [==============================] - 47s 16ms/step - loss: 0.4249 - accuracy: 0.7822 - val_loss: 0.4263 - val_accuracy: 0.7815
# Epoch 150/150
# 2971/2971 [==============================] - 46s 15ms/step - loss: 0.4249 - accuracy: 0.7821 - val_loss: 0.4283 - val_accuracy: 0.7833

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 17s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 7240.819009780884

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00389548],
#        [0.00414535],
#        [0.00105538],
#        ...,
#        [0.03898776],
#        [0.04010113],
#        [0.04092526]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1429978397536018
# 0.23104595655074667
# 0.37815055170342116
# 0.2803284852711153

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 77s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.62187236]
# [0.81377702]
# total acc [0.78218299]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
