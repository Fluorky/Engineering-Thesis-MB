# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2440000d040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x244638a6040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=32)#, shuffle=False)
# Out:
# Epoch 1/140
# 11883/11883 [==============================] - 173s 14ms/step - loss: 0.5352 - accuracy: 0.7389 - val_loss: 0.4861 - val_accuracy: 0.7532
# Epoch 2/140
# 11883/11883 [==============================] - 164s 14ms/step - loss: 0.5008 - accuracy: 0.7388 - val_loss: 0.4816 - val_accuracy: 0.7534
# Epoch 3/140
# 11883/11883 [==============================] - 165s 14ms/step - loss: 0.4937 - accuracy: 0.7428 - val_loss: 0.4870 - val_accuracy: 0.7481
# Epoch 4/140
# 11883/11883 [==============================] - 164s 14ms/step - loss: 0.4816 - accuracy: 0.7487 - val_loss: 0.4661 - val_accuracy: 0.7559
# Epoch 5/140
# 11883/11883 [==============================] - 165s 14ms/step - loss: 0.4716 - accuracy: 0.7533 - val_loss: 0.4610 - val_accuracy: 0.7578
# Epoch 6/140
# 11883/11883 [==============================] - 164s 14ms/step - loss: 0.4663 - accuracy: 0.7551 - val_loss: 0.4577 - val_accuracy: 0.7575
# Epoch 7/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4631 - accuracy: 0.7563 - val_loss: 0.4514 - val_accuracy: 0.7613
# Epoch 8/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4599 - accuracy: 0.7595 - val_loss: 0.4523 - val_accuracy: 0.7662
# Epoch 9/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4568 - accuracy: 0.7620 - val_loss: 0.4437 - val_accuracy: 0.7689
# Epoch 10/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4538 - accuracy: 0.7641 - val_loss: 0.4444 - val_accuracy: 0.7705
# Epoch 11/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4515 - accuracy: 0.7661 - val_loss: 0.4428 - val_accuracy: 0.7698
# Epoch 12/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4494 - accuracy: 0.7683 - val_loss: 0.4440 - val_accuracy: 0.7728
# Epoch 13/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4474 - accuracy: 0.7697 - val_loss: 0.4370 - val_accuracy: 0.7742
# Epoch 14/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4462 - accuracy: 0.7701 - val_loss: 0.4434 - val_accuracy: 0.7730
# Epoch 15/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4446 - accuracy: 0.7717 - val_loss: 0.4390 - val_accuracy: 0.7738
# Epoch 16/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4437 - accuracy: 0.7724 - val_loss: 0.4343 - val_accuracy: 0.7769
# Epoch 17/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4428 - accuracy: 0.7732 - val_loss: 0.4362 - val_accuracy: 0.7756
# Epoch 18/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4417 - accuracy: 0.7740 - val_loss: 0.4323 - val_accuracy: 0.7775
# Epoch 19/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4402 - accuracy: 0.7752 - val_loss: 0.4336 - val_accuracy: 0.7759
# Epoch 20/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4386 - accuracy: 0.7758 - val_loss: 0.4355 - val_accuracy: 0.7782
# Epoch 21/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4376 - accuracy: 0.7762 - val_loss: 0.4378 - val_accuracy: 0.7770
# Epoch 22/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4368 - accuracy: 0.7768 - val_loss: 0.4295 - val_accuracy: 0.7807
# Epoch 23/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4360 - accuracy: 0.7773 - val_loss: 0.4316 - val_accuracy: 0.7787
# Epoch 24/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4353 - accuracy: 0.7776 - val_loss: 0.4270 - val_accuracy: 0.7808
# Epoch 25/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4346 - accuracy: 0.7777 - val_loss: 0.4292 - val_accuracy: 0.7809
# Epoch 26/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4341 - accuracy: 0.7782 - val_loss: 0.4332 - val_accuracy: 0.7794
# Epoch 27/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4335 - accuracy: 0.7780 - val_loss: 0.4280 - val_accuracy: 0.7793
# Epoch 28/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4330 - accuracy: 0.7787 - val_loss: 0.4317 - val_accuracy: 0.7780
# Epoch 29/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4324 - accuracy: 0.7789 - val_loss: 0.4315 - val_accuracy: 0.7801
# Epoch 30/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4321 - accuracy: 0.7794 - val_loss: 0.4296 - val_accuracy: 0.7807
# Epoch 31/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4316 - accuracy: 0.7795 - val_loss: 0.4304 - val_accuracy: 0.7808
# Epoch 32/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4310 - accuracy: 0.7798 - val_loss: 0.4333 - val_accuracy: 0.7783
# Epoch 33/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4307 - accuracy: 0.7801 - val_loss: 0.4326 - val_accuracy: 0.7788
# Epoch 34/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4302 - accuracy: 0.7799 - val_loss: 0.4343 - val_accuracy: 0.7754
# Epoch 35/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4299 - accuracy: 0.7801 - val_loss: 0.4326 - val_accuracy: 0.7786
# Epoch 36/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4295 - accuracy: 0.7806 - val_loss: 0.4249 - val_accuracy: 0.7826
# Epoch 37/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4292 - accuracy: 0.7804 - val_loss: 0.4271 - val_accuracy: 0.7825
# Epoch 38/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4289 - accuracy: 0.7807 - val_loss: 0.4316 - val_accuracy: 0.7809
# Epoch 39/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4285 - accuracy: 0.7813 - val_loss: 0.4244 - val_accuracy: 0.7830
# Epoch 40/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4280 - accuracy: 0.7810 - val_loss: 0.4271 - val_accuracy: 0.7797
# Epoch 41/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4276 - accuracy: 0.7812 - val_loss: 0.4242 - val_accuracy: 0.7844
# Epoch 42/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4272 - accuracy: 0.7818 - val_loss: 0.4268 - val_accuracy: 0.7803
# Epoch 43/140
# 11883/11883 [==============================] - 160s 14ms/step - loss: 0.4270 - accuracy: 0.7817 - val_loss: 0.4340 - val_accuracy: 0.7735
# Epoch 44/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4267 - accuracy: 0.7819 - val_loss: 0.4264 - val_accuracy: 0.7829
# Epoch 45/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4263 - accuracy: 0.7819 - val_loss: 0.4234 - val_accuracy: 0.7839
# Epoch 46/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4260 - accuracy: 0.7823 - val_loss: 0.4257 - val_accuracy: 0.7813
# Epoch 47/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4257 - accuracy: 0.7823 - val_loss: 0.4274 - val_accuracy: 0.7821
# Epoch 48/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4255 - accuracy: 0.7818 - val_loss: 0.4244 - val_accuracy: 0.7848
# Epoch 49/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4252 - accuracy: 0.7824 - val_loss: 0.4269 - val_accuracy: 0.7799
# Epoch 50/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4247 - accuracy: 0.7826 - val_loss: 0.4262 - val_accuracy: 0.7833
# Epoch 51/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4245 - accuracy: 0.7830 - val_loss: 0.4267 - val_accuracy: 0.7848
# Epoch 52/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4243 - accuracy: 0.7832 - val_loss: 0.4245 - val_accuracy: 0.7840
# Epoch 53/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4238 - accuracy: 0.7830 - val_loss: 0.4238 - val_accuracy: 0.7846
# Epoch 54/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4236 - accuracy: 0.7831 - val_loss: 0.4261 - val_accuracy: 0.7848
# Epoch 55/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4234 - accuracy: 0.7833 - val_loss: 0.4224 - val_accuracy: 0.7849
# Epoch 56/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4232 - accuracy: 0.7837 - val_loss: 0.4233 - val_accuracy: 0.7840
# Epoch 57/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4228 - accuracy: 0.7835 - val_loss: 0.4230 - val_accuracy: 0.7855
# Epoch 58/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4226 - accuracy: 0.7834 - val_loss: 0.4275 - val_accuracy: 0.7811
# Epoch 59/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4223 - accuracy: 0.7840 - val_loss: 0.4247 - val_accuracy: 0.7802
# Epoch 60/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4219 - accuracy: 0.7847 - val_loss: 0.4231 - val_accuracy: 0.7829
# Epoch 61/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4217 - accuracy: 0.7842 - val_loss: 0.4288 - val_accuracy: 0.7842
# Epoch 62/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4214 - accuracy: 0.7845 - val_loss: 0.4277 - val_accuracy: 0.7853
# Epoch 63/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4209 - accuracy: 0.7850 - val_loss: 0.4233 - val_accuracy: 0.7852
# Epoch 64/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4207 - accuracy: 0.7847 - val_loss: 0.4230 - val_accuracy: 0.7844
# Epoch 65/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4205 - accuracy: 0.7849 - val_loss: 0.4230 - val_accuracy: 0.7845
# Epoch 66/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4202 - accuracy: 0.7849 - val_loss: 0.4274 - val_accuracy: 0.7814
# Epoch 67/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4199 - accuracy: 0.7853 - val_loss: 0.4298 - val_accuracy: 0.7820
# Epoch 68/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4196 - accuracy: 0.7854 - val_loss: 0.4223 - val_accuracy: 0.7861
# Epoch 69/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4194 - accuracy: 0.7857 - val_loss: 0.4239 - val_accuracy: 0.7857
# Epoch 70/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4191 - accuracy: 0.7860 - val_loss: 0.4244 - val_accuracy: 0.7838
# Epoch 71/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4188 - accuracy: 0.7860 - val_loss: 0.4270 - val_accuracy: 0.7862
# Epoch 72/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4185 - accuracy: 0.7858 - val_loss: 0.4253 - val_accuracy: 0.7862
# Epoch 73/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4182 - accuracy: 0.7862 - val_loss: 0.4317 - val_accuracy: 0.7853
# Epoch 74/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4181 - accuracy: 0.7861 - val_loss: 0.4278 - val_accuracy: 0.7842
# Epoch 75/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4178 - accuracy: 0.7866 - val_loss: 0.4254 - val_accuracy: 0.7830
# Epoch 76/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4175 - accuracy: 0.7862 - val_loss: 0.4350 - val_accuracy: 0.7827
# Epoch 77/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4171 - accuracy: 0.7867 - val_loss: 0.4237 - val_accuracy: 0.7837
# Epoch 78/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4169 - accuracy: 0.7867 - val_loss: 0.4250 - val_accuracy: 0.7834
# Epoch 79/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4166 - accuracy: 0.7866 - val_loss: 0.4251 - val_accuracy: 0.7841
# Epoch 80/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4165 - accuracy: 0.7873 - val_loss: 0.4272 - val_accuracy: 0.7841
# Epoch 81/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4162 - accuracy: 0.7873 - val_loss: 0.4258 - val_accuracy: 0.7840
# Epoch 82/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4159 - accuracy: 0.7871 - val_loss: 0.4305 - val_accuracy: 0.7832
# Epoch 83/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4157 - accuracy: 0.7871 - val_loss: 0.4240 - val_accuracy: 0.7868
# Epoch 84/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4153 - accuracy: 0.7873 - val_loss: 0.4259 - val_accuracy: 0.7844
# Epoch 85/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4151 - accuracy: 0.7876 - val_loss: 0.4263 - val_accuracy: 0.7851
# Epoch 86/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4150 - accuracy: 0.7879 - val_loss: 0.4297 - val_accuracy: 0.7850
# Epoch 87/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4147 - accuracy: 0.7874 - val_loss: 0.4282 - val_accuracy: 0.7806
# Epoch 88/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4143 - accuracy: 0.7882 - val_loss: 0.4250 - val_accuracy: 0.7841
# Epoch 89/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4141 - accuracy: 0.7878 - val_loss: 0.4286 - val_accuracy: 0.7825
# Epoch 90/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4137 - accuracy: 0.7887 - val_loss: 0.4262 - val_accuracy: 0.7839
# Epoch 91/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4136 - accuracy: 0.7881 - val_loss: 0.4297 - val_accuracy: 0.7851
# Epoch 92/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4133 - accuracy: 0.7883 - val_loss: 0.4302 - val_accuracy: 0.7818
# Epoch 93/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4131 - accuracy: 0.7885 - val_loss: 0.4321 - val_accuracy: 0.7838
# Epoch 94/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4128 - accuracy: 0.7889 - val_loss: 0.4288 - val_accuracy: 0.7829
# Epoch 95/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4127 - accuracy: 0.7887 - val_loss: 0.4324 - val_accuracy: 0.7861
# Epoch 96/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4123 - accuracy: 0.7888 - val_loss: 0.4307 - val_accuracy: 0.7836
# Epoch 97/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4120 - accuracy: 0.7891 - val_loss: 0.4317 - val_accuracy: 0.7854
# Epoch 98/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4118 - accuracy: 0.7890 - val_loss: 0.4281 - val_accuracy: 0.7820
# Epoch 99/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4116 - accuracy: 0.7895 - val_loss: 0.4263 - val_accuracy: 0.7836
# Epoch 100/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4112 - accuracy: 0.7895 - val_loss: 0.4279 - val_accuracy: 0.7836
# Epoch 101/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4111 - accuracy: 0.7892 - val_loss: 0.4288 - val_accuracy: 0.7837
# Epoch 102/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4108 - accuracy: 0.7895 - val_loss: 0.4350 - val_accuracy: 0.7859
# Epoch 103/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4105 - accuracy: 0.7894 - val_loss: 0.4350 - val_accuracy: 0.7835
# Epoch 104/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4103 - accuracy: 0.7896 - val_loss: 0.4282 - val_accuracy: 0.7805
# Epoch 105/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4102 - accuracy: 0.7898 - val_loss: 0.4314 - val_accuracy: 0.7806
# Epoch 106/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4098 - accuracy: 0.7900 - val_loss: 0.4368 - val_accuracy: 0.7816
# Epoch 107/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4097 - accuracy: 0.7901 - val_loss: 0.4296 - val_accuracy: 0.7850
# Epoch 108/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4093 - accuracy: 0.7902 - val_loss: 0.4432 - val_accuracy: 0.7831
# Epoch 109/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4092 - accuracy: 0.7904 - val_loss: 0.4345 - val_accuracy: 0.7824
# Epoch 110/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4088 - accuracy: 0.7905 - val_loss: 0.4276 - val_accuracy: 0.7798
# Epoch 111/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4086 - accuracy: 0.7903 - val_loss: 0.4284 - val_accuracy: 0.7820
# Epoch 112/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4085 - accuracy: 0.7909 - val_loss: 0.4343 - val_accuracy: 0.7834
# Epoch 113/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4082 - accuracy: 0.7908 - val_loss: 0.4438 - val_accuracy: 0.7862
# Epoch 114/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4079 - accuracy: 0.7908 - val_loss: 0.4385 - val_accuracy: 0.7763
# Epoch 115/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4077 - accuracy: 0.7914 - val_loss: 0.4279 - val_accuracy: 0.7847
# Epoch 116/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4074 - accuracy: 0.7911 - val_loss: 0.4342 - val_accuracy: 0.7808
# Epoch 117/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4072 - accuracy: 0.7911 - val_loss: 0.4332 - val_accuracy: 0.7785
# Epoch 118/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4070 - accuracy: 0.7914 - val_loss: 0.4383 - val_accuracy: 0.7761
# Epoch 119/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4068 - accuracy: 0.7915 - val_loss: 0.4453 - val_accuracy: 0.7852
# Epoch 120/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4066 - accuracy: 0.7915 - val_loss: 0.4342 - val_accuracy: 0.7809
# Epoch 121/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4063 - accuracy: 0.7919 - val_loss: 0.4341 - val_accuracy: 0.7820
# Epoch 122/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4061 - accuracy: 0.7915 - val_loss: 0.4331 - val_accuracy: 0.7791
# Epoch 123/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4059 - accuracy: 0.7921 - val_loss: 0.4349 - val_accuracy: 0.7829
# Epoch 124/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4056 - accuracy: 0.7922 - val_loss: 0.4307 - val_accuracy: 0.7820
# Epoch 125/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4053 - accuracy: 0.7922 - val_loss: 0.4400 - val_accuracy: 0.7836
# Epoch 126/140
# 11883/11883 [==============================] - 158s 13ms/step - loss: 0.4052 - accuracy: 0.7919 - val_loss: 0.4412 - val_accuracy: 0.7835
# Epoch 127/140
# 11883/11883 [==============================] - 165s 14ms/step - loss: 0.4050 - accuracy: 0.7925 - val_loss: 0.4361 - val_accuracy: 0.7852
# Epoch 128/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4046 - accuracy: 0.7925 - val_loss: 0.4397 - val_accuracy: 0.7821
# Epoch 129/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4043 - accuracy: 0.7928 - val_loss: 0.4393 - val_accuracy: 0.7751
# Epoch 130/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4042 - accuracy: 0.7927 - val_loss: 0.4373 - val_accuracy: 0.7821
# Epoch 131/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4040 - accuracy: 0.7927 - val_loss: 0.4359 - val_accuracy: 0.7831
# Epoch 132/140
# 11883/11883 [==============================] - 162s 14ms/step - loss: 0.4038 - accuracy: 0.7930 - val_loss: 0.4435 - val_accuracy: 0.7859
# Epoch 133/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4035 - accuracy: 0.7933 - val_loss: 0.4328 - val_accuracy: 0.7795
# Epoch 134/140
# 11883/11883 [==============================] - 160s 13ms/step - loss: 0.4033 - accuracy: 0.7933 - val_loss: 0.4352 - val_accuracy: 0.7796
# Epoch 135/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4030 - accuracy: 0.7932 - val_loss: 0.4384 - val_accuracy: 0.7817
# Epoch 136/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4029 - accuracy: 0.7935 - val_loss: 0.4410 - val_accuracy: 0.7783
# Epoch 137/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4026 - accuracy: 0.7941 - val_loss: 0.4442 - val_accuracy: 0.7840
# Epoch 138/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4023 - accuracy: 0.7937 - val_loss: 0.4341 - val_accuracy: 0.7833
# Epoch 139/140
# 11883/11883 [==============================] - 161s 14ms/step - loss: 0.4021 - accuracy: 0.7941 - val_loss: 0.4398 - val_accuracy: 0.7795
# Epoch 140/140
# 11883/11883 [==============================] - 159s 13ms/step - loss: 0.4018 - accuracy: 0.7937 - val_loss: 0.4455 - val_accuracy: 0.7776

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 22399.556223154068

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00261643],
#        [0.00215731],
#        [0.00016711],
#        ...,
#        [0.0197772 ],
#        [0.01985649],
#        [0.01867505]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14689331740180128
# 0.21009848423990218
# 0.38326664008468214
# 0.285236933212573

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 74s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.59334294]
# [0.85271446]
# total acc [0.78836828]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
