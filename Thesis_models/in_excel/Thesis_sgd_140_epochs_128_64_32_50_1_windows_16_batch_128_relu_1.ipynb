# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1da0000a040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1da7ebaf040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2]),activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 385s 127ms/step - loss: 0.5718 - accuracy: 0.7393 - val_loss: 0.5540 - val_accuracy: 0.7531
# Epoch 2/140
# 2971/2971 [==============================] - 375s 126ms/step - loss: 0.5571 - accuracy: 0.7394 - val_loss: 0.5265 - val_accuracy: 0.7531
# Epoch 3/140
# 2971/2971 [==============================] - 387s 130ms/step - loss: 0.5216 - accuracy: 0.7408 - val_loss: 0.4918 - val_accuracy: 0.7526
# Epoch 4/140
# 2971/2971 [==============================] - 411s 138ms/step - loss: 0.5023 - accuracy: 0.7391 - val_loss: 0.4844 - val_accuracy: 0.7535
# Epoch 5/140
# 2971/2971 [==============================] - 415s 140ms/step - loss: 0.4971 - accuracy: 0.7411 - val_loss: 0.4841 - val_accuracy: 0.7518
# Epoch 6/140
# 2971/2971 [==============================] - 368s 124ms/step - loss: 0.4924 - accuracy: 0.7442 - val_loss: 0.4784 - val_accuracy: 0.7532
# Epoch 7/140
# 2971/2971 [==============================] - 371s 125ms/step - loss: 0.4868 - accuracy: 0.7469 - val_loss: 0.4741 - val_accuracy: 0.7542
# Epoch 8/140
# 2971/2971 [==============================] - 371s 125ms/step - loss: 0.4806 - accuracy: 0.7506 - val_loss: 0.4731 - val_accuracy: 0.7585
# Epoch 9/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4758 - accuracy: 0.7540 - val_loss: 0.4647 - val_accuracy: 0.7606
# Epoch 10/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4721 - accuracy: 0.7559 - val_loss: 0.4622 - val_accuracy: 0.7605
# Epoch 11/140
# 2971/2971 [==============================] - 358s 121ms/step - loss: 0.4689 - accuracy: 0.7578 - val_loss: 0.4629 - val_accuracy: 0.7596
# Epoch 12/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4666 - accuracy: 0.7587 - val_loss: 0.4588 - val_accuracy: 0.7626
# Epoch 13/140
# 2971/2971 [==============================] - 358s 121ms/step - loss: 0.4639 - accuracy: 0.7607 - val_loss: 0.4601 - val_accuracy: 0.7646
# Epoch 14/140
# 2971/2971 [==============================] - 355s 119ms/step - loss: 0.4620 - accuracy: 0.7615 - val_loss: 0.4512 - val_accuracy: 0.7678
# Epoch 15/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4597 - accuracy: 0.7630 - val_loss: 0.4572 - val_accuracy: 0.7656
# Epoch 16/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4580 - accuracy: 0.7645 - val_loss: 0.4506 - val_accuracy: 0.7717
# Epoch 17/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4563 - accuracy: 0.7653 - val_loss: 0.4488 - val_accuracy: 0.7702
# Epoch 18/140
# 2971/2971 [==============================] - 359s 121ms/step - loss: 0.4545 - accuracy: 0.7667 - val_loss: 0.4450 - val_accuracy: 0.7720
# Epoch 19/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4529 - accuracy: 0.7676 - val_loss: 0.4469 - val_accuracy: 0.7739
# Epoch 20/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4515 - accuracy: 0.7682 - val_loss: 0.4537 - val_accuracy: 0.7715
# Epoch 21/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4501 - accuracy: 0.7689 - val_loss: 0.4489 - val_accuracy: 0.7710
# Epoch 22/140
# 2971/2971 [==============================] - 355s 119ms/step - loss: 0.4488 - accuracy: 0.7701 - val_loss: 0.4700 - val_accuracy: 0.7720
# Epoch 23/140
# 2971/2971 [==============================] - 355s 120ms/step - loss: 0.4479 - accuracy: 0.7707 - val_loss: 0.4400 - val_accuracy: 0.7745
# Epoch 24/140
# 2971/2971 [==============================] - 361s 122ms/step - loss: 0.4467 - accuracy: 0.7709 - val_loss: 0.4399 - val_accuracy: 0.7756
# Epoch 25/140
# 2971/2971 [==============================] - 354s 119ms/step - loss: 0.4456 - accuracy: 0.7717 - val_loss: 0.4386 - val_accuracy: 0.7755
# Epoch 26/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4447 - accuracy: 0.7725 - val_loss: 0.4446 - val_accuracy: 0.7762
# Epoch 27/140
# 2971/2971 [==============================] - 355s 120ms/step - loss: 0.4434 - accuracy: 0.7728 - val_loss: 0.4408 - val_accuracy: 0.7757
# Epoch 28/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4428 - accuracy: 0.7735 - val_loss: 0.4355 - val_accuracy: 0.7784
# Epoch 29/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4418 - accuracy: 0.7740 - val_loss: 0.4346 - val_accuracy: 0.7787
# Epoch 30/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4411 - accuracy: 0.7741 - val_loss: 0.4365 - val_accuracy: 0.7773
# Epoch 31/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4403 - accuracy: 0.7751 - val_loss: 0.4356 - val_accuracy: 0.7766
# Epoch 32/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4392 - accuracy: 0.7752 - val_loss: 0.4459 - val_accuracy: 0.7771
# Epoch 33/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4384 - accuracy: 0.7760 - val_loss: 0.4342 - val_accuracy: 0.7783
# Epoch 34/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4381 - accuracy: 0.7759 - val_loss: 0.4351 - val_accuracy: 0.7783
# Epoch 35/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4374 - accuracy: 0.7766 - val_loss: 0.4314 - val_accuracy: 0.7804
# Epoch 36/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4365 - accuracy: 0.7770 - val_loss: 0.4410 - val_accuracy: 0.7789
# Epoch 37/140
# 2971/2971 [==============================] - 353s 119ms/step - loss: 0.4360 - accuracy: 0.7771 - val_loss: 0.4311 - val_accuracy: 0.7806
# Epoch 38/140
# 2971/2971 [==============================] - 355s 120ms/step - loss: 0.4353 - accuracy: 0.7779 - val_loss: 0.4391 - val_accuracy: 0.7724
# Epoch 39/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4349 - accuracy: 0.7779 - val_loss: 0.4313 - val_accuracy: 0.7792
# Epoch 40/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4343 - accuracy: 0.7780 - val_loss: 0.4306 - val_accuracy: 0.7802
# Epoch 41/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4337 - accuracy: 0.7782 - val_loss: 0.4334 - val_accuracy: 0.7801
# Epoch 42/140
# 2971/2971 [==============================] - 355s 120ms/step - loss: 0.4333 - accuracy: 0.7788 - val_loss: 0.4321 - val_accuracy: 0.7783
# Epoch 43/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4328 - accuracy: 0.7788 - val_loss: 0.4332 - val_accuracy: 0.7804
# Epoch 44/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4325 - accuracy: 0.7781 - val_loss: 0.4324 - val_accuracy: 0.7791
# Epoch 45/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4322 - accuracy: 0.7792 - val_loss: 0.4319 - val_accuracy: 0.7806
# Epoch 46/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4319 - accuracy: 0.7793 - val_loss: 0.4326 - val_accuracy: 0.7800
# Epoch 47/140
# 2971/2971 [==============================] - 359s 121ms/step - loss: 0.4314 - accuracy: 0.7792 - val_loss: 0.4398 - val_accuracy: 0.7795
# Epoch 48/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4310 - accuracy: 0.7794 - val_loss: 0.4312 - val_accuracy: 0.7804
# Epoch 49/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4306 - accuracy: 0.7794 - val_loss: 0.4274 - val_accuracy: 0.7812
# Epoch 50/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4303 - accuracy: 0.7796 - val_loss: 0.4268 - val_accuracy: 0.7808
# Epoch 51/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4299 - accuracy: 0.7800 - val_loss: 0.4366 - val_accuracy: 0.7793
# Epoch 52/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4297 - accuracy: 0.7798 - val_loss: 0.4263 - val_accuracy: 0.7819
# Epoch 53/140
# 2971/2971 [==============================] - 359s 121ms/step - loss: 0.4294 - accuracy: 0.7799 - val_loss: 0.4366 - val_accuracy: 0.7780
# Epoch 54/140
# 2971/2971 [==============================] - 355s 119ms/step - loss: 0.4293 - accuracy: 0.7799 - val_loss: 0.4274 - val_accuracy: 0.7813
# Epoch 55/140
# 2971/2971 [==============================] - 355s 120ms/step - loss: 0.4290 - accuracy: 0.7805 - val_loss: 0.4289 - val_accuracy: 0.7790
# Epoch 56/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4287 - accuracy: 0.7798 - val_loss: 0.4295 - val_accuracy: 0.7812
# Epoch 57/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4283 - accuracy: 0.7801 - val_loss: 0.4295 - val_accuracy: 0.7795
# Epoch 58/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4283 - accuracy: 0.7807 - val_loss: 0.4266 - val_accuracy: 0.7830
# Epoch 59/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4279 - accuracy: 0.7799 - val_loss: 0.4355 - val_accuracy: 0.7765
# Epoch 60/140
# 2971/2971 [==============================] - 359s 121ms/step - loss: 0.4279 - accuracy: 0.7802 - val_loss: 0.4284 - val_accuracy: 0.7802
# Epoch 61/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4275 - accuracy: 0.7804 - val_loss: 0.4343 - val_accuracy: 0.7744
# Epoch 62/140
# 2971/2971 [==============================] - 353s 119ms/step - loss: 0.4273 - accuracy: 0.7810 - val_loss: 0.4409 - val_accuracy: 0.7709
# Epoch 63/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4272 - accuracy: 0.7808 - val_loss: 0.4301 - val_accuracy: 0.7808
# Epoch 64/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4271 - accuracy: 0.7812 - val_loss: 0.4291 - val_accuracy: 0.7801
# Epoch 65/140
# 2971/2971 [==============================] - 361s 122ms/step - loss: 0.4269 - accuracy: 0.7811 - val_loss: 0.4256 - val_accuracy: 0.7822
# Epoch 66/140
# 2971/2971 [==============================] - 389s 131ms/step - loss: 0.4266 - accuracy: 0.7812 - val_loss: 0.4323 - val_accuracy: 0.7790
# Epoch 67/140
# 2971/2971 [==============================] - 380s 128ms/step - loss: 0.4265 - accuracy: 0.7811 - val_loss: 0.4390 - val_accuracy: 0.7802
# Epoch 68/140
# 2971/2971 [==============================] - 369s 124ms/step - loss: 0.4264 - accuracy: 0.7811 - val_loss: 0.4293 - val_accuracy: 0.7784
# Epoch 69/140
# 2971/2971 [==============================] - 359s 121ms/step - loss: 0.4259 - accuracy: 0.7820 - val_loss: 0.4303 - val_accuracy: 0.7822
# Epoch 70/140
# 2971/2971 [==============================] - 385s 130ms/step - loss: 0.4260 - accuracy: 0.7820 - val_loss: 0.4254 - val_accuracy: 0.7808
# Epoch 71/140
# 2971/2971 [==============================] - 424s 143ms/step - loss: 0.4257 - accuracy: 0.7821 - val_loss: 0.4261 - val_accuracy: 0.7803
# Epoch 72/140
# 2971/2971 [==============================] - 429s 144ms/step - loss: 0.4254 - accuracy: 0.7814 - val_loss: 0.4240 - val_accuracy: 0.7817
# Epoch 73/140
# 2971/2971 [==============================] - 431s 145ms/step - loss: 0.4257 - accuracy: 0.7815 - val_loss: 0.4290 - val_accuracy: 0.7809
# Epoch 74/140
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.4252 - accuracy: 0.7821 - val_loss: 0.4279 - val_accuracy: 0.7794
# Epoch 75/140
# 2971/2971 [==============================] - 427s 144ms/step - loss: 0.4253 - accuracy: 0.7820 - val_loss: 0.4238 - val_accuracy: 0.7819
# Epoch 76/140
# 2971/2971 [==============================] - 378s 127ms/step - loss: 0.4248 - accuracy: 0.7818 - val_loss: 0.4403 - val_accuracy: 0.7716
# Epoch 77/140
# 2971/2971 [==============================] - 379s 128ms/step - loss: 0.4247 - accuracy: 0.7820 - val_loss: 0.4261 - val_accuracy: 0.7823
# Epoch 78/140
# 2971/2971 [==============================] - 360s 121ms/step - loss: 0.4248 - accuracy: 0.7823 - val_loss: 0.4238 - val_accuracy: 0.7820
# Epoch 79/140
# 2971/2971 [==============================] - 354s 119ms/step - loss: 0.4246 - accuracy: 0.7821 - val_loss: 0.4273 - val_accuracy: 0.7808
# Epoch 80/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4243 - accuracy: 0.7827 - val_loss: 0.4278 - val_accuracy: 0.7809
# Epoch 81/140
# 2971/2971 [==============================] - 355s 120ms/step - loss: 0.4242 - accuracy: 0.7823 - val_loss: 0.4244 - val_accuracy: 0.7834
# Epoch 82/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4243 - accuracy: 0.7822 - val_loss: 0.4248 - val_accuracy: 0.7805
# Epoch 83/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4239 - accuracy: 0.7828 - val_loss: 0.4251 - val_accuracy: 0.7808
# Epoch 84/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4238 - accuracy: 0.7820 - val_loss: 0.4258 - val_accuracy: 0.7819
# Epoch 85/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4236 - accuracy: 0.7828 - val_loss: 0.4286 - val_accuracy: 0.7797
# Epoch 86/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4234 - accuracy: 0.7825 - val_loss: 0.4257 - val_accuracy: 0.7822
# Epoch 87/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4232 - accuracy: 0.7831 - val_loss: 0.4274 - val_accuracy: 0.7826
# Epoch 88/140
# 2971/2971 [==============================] - 359s 121ms/step - loss: 0.4231 - accuracy: 0.7834 - val_loss: 0.4351 - val_accuracy: 0.7816
# Epoch 89/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4230 - accuracy: 0.7831 - val_loss: 0.4268 - val_accuracy: 0.7841
# Epoch 90/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4230 - accuracy: 0.7830 - val_loss: 0.4286 - val_accuracy: 0.7790
# Epoch 91/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4228 - accuracy: 0.7830 - val_loss: 0.4243 - val_accuracy: 0.7834
# Epoch 92/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4227 - accuracy: 0.7834 - val_loss: 0.4260 - val_accuracy: 0.7796
# Epoch 93/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4223 - accuracy: 0.7835 - val_loss: 0.4227 - val_accuracy: 0.7822
# Epoch 94/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4224 - accuracy: 0.7835 - val_loss: 0.4231 - val_accuracy: 0.7833
# Epoch 95/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4223 - accuracy: 0.7838 - val_loss: 0.4266 - val_accuracy: 0.7824
# Epoch 96/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4220 - accuracy: 0.7838 - val_loss: 0.4271 - val_accuracy: 0.7818
# Epoch 97/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4219 - accuracy: 0.7838 - val_loss: 0.4267 - val_accuracy: 0.7781
# Epoch 98/140
# 2971/2971 [==============================] - 355s 120ms/step - loss: 0.4217 - accuracy: 0.7836 - val_loss: 0.4242 - val_accuracy: 0.7809
# Epoch 99/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4216 - accuracy: 0.7837 - val_loss: 0.4228 - val_accuracy: 0.7813
# Epoch 100/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4214 - accuracy: 0.7841 - val_loss: 0.4365 - val_accuracy: 0.7768
# Epoch 101/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4215 - accuracy: 0.7842 - val_loss: 0.4257 - val_accuracy: 0.7793
# Epoch 102/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4215 - accuracy: 0.7842 - val_loss: 0.4247 - val_accuracy: 0.7843
# Epoch 103/140
# 2971/2971 [==============================] - 358s 121ms/step - loss: 0.4212 - accuracy: 0.7840 - val_loss: 0.4269 - val_accuracy: 0.7818
# Epoch 104/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4209 - accuracy: 0.7843 - val_loss: 0.4262 - val_accuracy: 0.7816
# Epoch 105/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4209 - accuracy: 0.7843 - val_loss: 0.4333 - val_accuracy: 0.7808
# Epoch 106/140
# 2971/2971 [==============================] - 355s 120ms/step - loss: 0.4208 - accuracy: 0.7841 - val_loss: 0.4289 - val_accuracy: 0.7836
# Epoch 107/140
# 2971/2971 [==============================] - 363s 122ms/step - loss: 0.4208 - accuracy: 0.7847 - val_loss: 0.4282 - val_accuracy: 0.7789
# Epoch 108/140
# 2971/2971 [==============================] - 363s 122ms/step - loss: 0.4206 - accuracy: 0.7844 - val_loss: 0.4233 - val_accuracy: 0.7815
# Epoch 109/140
# 2971/2971 [==============================] - 362s 122ms/step - loss: 0.4205 - accuracy: 0.7850 - val_loss: 0.4278 - val_accuracy: 0.7779
# Epoch 110/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4202 - accuracy: 0.7846 - val_loss: 0.4229 - val_accuracy: 0.7818
# Epoch 111/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4203 - accuracy: 0.7843 - val_loss: 0.4275 - val_accuracy: 0.7813
# Epoch 112/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4201 - accuracy: 0.7850 - val_loss: 0.4245 - val_accuracy: 0.7808
# Epoch 113/140
# 2971/2971 [==============================] - 359s 121ms/step - loss: 0.4198 - accuracy: 0.7849 - val_loss: 0.4240 - val_accuracy: 0.7815
# Epoch 114/140
# 2971/2971 [==============================] - 359s 121ms/step - loss: 0.4199 - accuracy: 0.7849 - val_loss: 0.4247 - val_accuracy: 0.7816
# Epoch 115/140
# 2971/2971 [==============================] - 359s 121ms/step - loss: 0.4198 - accuracy: 0.7851 - val_loss: 0.4269 - val_accuracy: 0.7786
# Epoch 116/140
# 2971/2971 [==============================] - 353s 119ms/step - loss: 0.4196 - accuracy: 0.7852 - val_loss: 0.4286 - val_accuracy: 0.7822
# Epoch 117/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4198 - accuracy: 0.7850 - val_loss: 0.4269 - val_accuracy: 0.7811
# Epoch 118/140
# 2971/2971 [==============================] - 381s 128ms/step - loss: 0.4196 - accuracy: 0.7853 - val_loss: 0.4285 - val_accuracy: 0.7823
# Epoch 119/140
# 2971/2971 [==============================] - 379s 128ms/step - loss: 0.4195 - accuracy: 0.7853 - val_loss: 0.4265 - val_accuracy: 0.7824
# Epoch 120/140
# 2971/2971 [==============================] - 381s 128ms/step - loss: 0.4193 - accuracy: 0.7854 - val_loss: 0.4230 - val_accuracy: 0.7836
# Epoch 121/140
# 2971/2971 [==============================] - 360s 121ms/step - loss: 0.4193 - accuracy: 0.7856 - val_loss: 0.4274 - val_accuracy: 0.7813
# Epoch 122/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4190 - accuracy: 0.7855 - val_loss: 0.4242 - val_accuracy: 0.7817
# Epoch 123/140
# 2971/2971 [==============================] - 353s 119ms/step - loss: 0.4190 - accuracy: 0.7856 - val_loss: 0.4258 - val_accuracy: 0.7810
# Epoch 124/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4188 - accuracy: 0.7855 - val_loss: 0.4250 - val_accuracy: 0.7835
# Epoch 125/140
# 2971/2971 [==============================] - 353s 119ms/step - loss: 0.4188 - accuracy: 0.7852 - val_loss: 0.4257 - val_accuracy: 0.7824
# Epoch 126/140
# 2971/2971 [==============================] - 358s 121ms/step - loss: 0.4185 - accuracy: 0.7856 - val_loss: 0.4317 - val_accuracy: 0.7789
# Epoch 127/140
# 2971/2971 [==============================] - 355s 120ms/step - loss: 0.4186 - accuracy: 0.7859 - val_loss: 0.4246 - val_accuracy: 0.7808
# Epoch 128/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4186 - accuracy: 0.7859 - val_loss: 0.4239 - val_accuracy: 0.7831
# Epoch 129/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4184 - accuracy: 0.7858 - val_loss: 0.4312 - val_accuracy: 0.7784
# Epoch 130/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4182 - accuracy: 0.7861 - val_loss: 0.4253 - val_accuracy: 0.7808
# Epoch 131/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4183 - accuracy: 0.7858 - val_loss: 0.4225 - val_accuracy: 0.7835
# Epoch 132/140
# 2971/2971 [==============================] - 358s 121ms/step - loss: 0.4181 - accuracy: 0.7861 - val_loss: 0.4277 - val_accuracy: 0.7785
# Epoch 133/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4179 - accuracy: 0.7858 - val_loss: 0.4255 - val_accuracy: 0.7787
# Epoch 134/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4179 - accuracy: 0.7868 - val_loss: 0.4235 - val_accuracy: 0.7828
# Epoch 135/140
# 2971/2971 [==============================] - 360s 121ms/step - loss: 0.4177 - accuracy: 0.7857 - val_loss: 0.4233 - val_accuracy: 0.7825
# Epoch 136/140
# 2971/2971 [==============================] - 356s 120ms/step - loss: 0.4178 - accuracy: 0.7860 - val_loss: 0.4285 - val_accuracy: 0.7763
# Epoch 137/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4176 - accuracy: 0.7862 - val_loss: 0.4240 - val_accuracy: 0.7844
# Epoch 138/140
# 2971/2971 [==============================] - 358s 120ms/step - loss: 0.4177 - accuracy: 0.7862 - val_loss: 0.4257 - val_accuracy: 0.7800
# Epoch 139/140
# 2971/2971 [==============================] - 357s 120ms/step - loss: 0.4174 - accuracy: 0.7860 - val_loss: 0.4259 - val_accuracy: 0.7821
# Epoch 140/140
# 2971/2971 [==============================] - 355s 120ms/step - loss: 0.4174 - accuracy: 0.7862 - val_loss: 0.4326 - val_accuracy: 0.7818

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 50s 16ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 50803.21199440956

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00213622],
#        [0.00146255],
#        [0.00049128],
#        ...,
#        [0.02001511],
#        [0.02021439],
#        [0.02027087]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1438655381485932
# 0.22638001061427138
# 0.37929610879706266
# 0.2739312238734802

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 223s 15ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.6291562]
# [0.8158895]
# total acc [0.78490957]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
