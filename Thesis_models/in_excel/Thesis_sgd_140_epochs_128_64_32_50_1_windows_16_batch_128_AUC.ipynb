# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2a2983f9040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2a2d2465040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['AUC'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 63s 18ms/step - loss: 0.5740 - auc: 0.5686 - val_loss: 0.5548 - val_auc: 0.6683
# Epoch 2/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.5568 - auc: 0.6617 - val_loss: 0.5250 - val_auc: 0.6931
# Epoch 3/140
# 2971/2971 [==============================] - 55s 19ms/step - loss: 0.5206 - auc: 0.7116 - val_loss: 0.4959 - val_auc: 0.7322
# Epoch 4/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.5041 - auc: 0.7293 - val_loss: 0.4862 - val_auc: 0.7348
# Epoch 5/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.5010 - auc: 0.7296 - val_loss: 0.4854 - val_auc: 0.7349
# Epoch 6/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4995 - auc: 0.7295 - val_loss: 0.4856 - val_auc: 0.7352
# Epoch 7/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4981 - auc: 0.7301 - val_loss: 0.4928 - val_auc: 0.7356
# Epoch 8/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4969 - auc: 0.7309 - val_loss: 0.4820 - val_auc: 0.7368
# Epoch 9/140
# 2971/2971 [==============================] - 56s 19ms/step - loss: 0.4957 - auc: 0.7329 - val_loss: 0.4800 - val_auc: 0.7378
# Epoch 10/140
# 2971/2971 [==============================] - 54s 18ms/step - loss: 0.4943 - auc: 0.7356 - val_loss: 0.4805 - val_auc: 0.7401
# Epoch 11/140
# 2971/2971 [==============================] - 59s 20ms/step - loss: 0.4923 - auc: 0.7395 - val_loss: 0.4776 - val_auc: 0.7417
# Epoch 12/140
# 2971/2971 [==============================] - 58s 20ms/step - loss: 0.4900 - auc: 0.7444 - val_loss: 0.4760 - val_auc: 0.7440
# Epoch 13/140
# 2971/2971 [==============================] - 58s 20ms/step - loss: 0.4866 - auc: 0.7511 - val_loss: 0.4774 - val_auc: 0.7473
# Epoch 14/140
# 2971/2971 [==============================] - 56s 19ms/step - loss: 0.4827 - auc: 0.7588 - val_loss: 0.4721 - val_auc: 0.7534
# Epoch 15/140
# 2971/2971 [==============================] - 56s 19ms/step - loss: 0.4787 - auc: 0.7658 - val_loss: 0.4726 - val_auc: 0.7592
# Epoch 16/140
# 2971/2971 [==============================] - 57s 19ms/step - loss: 0.4749 - auc: 0.7719 - val_loss: 0.4656 - val_auc: 0.7661
# Epoch 17/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4715 - auc: 0.7770 - val_loss: 0.4723 - val_auc: 0.7683
# Epoch 18/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4691 - auc: 0.7801 - val_loss: 0.4599 - val_auc: 0.7758
# Epoch 19/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4672 - auc: 0.7824 - val_loss: 0.4578 - val_auc: 0.7780
# Epoch 20/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4656 - auc: 0.7841 - val_loss: 0.4583 - val_auc: 0.7814
# Epoch 21/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4645 - auc: 0.7852 - val_loss: 0.4581 - val_auc: 0.7792
# Epoch 22/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.4635 - auc: 0.7864 - val_loss: 0.4564 - val_auc: 0.7845
# Epoch 23/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4625 - auc: 0.7875 - val_loss: 0.4596 - val_auc: 0.7832
# Epoch 24/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4616 - auc: 0.7886 - val_loss: 0.4523 - val_auc: 0.7849
# Epoch 25/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4610 - auc: 0.7892 - val_loss: 0.4553 - val_auc: 0.7833
# Epoch 26/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4600 - auc: 0.7904 - val_loss: 0.4527 - val_auc: 0.7888
# Epoch 27/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4592 - auc: 0.7913 - val_loss: 0.4522 - val_auc: 0.7876
# Epoch 28/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4585 - auc: 0.7922 - val_loss: 0.4504 - val_auc: 0.7879
# Epoch 29/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4579 - auc: 0.7928 - val_loss: 0.4577 - val_auc: 0.7839
# Epoch 30/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4572 - auc: 0.7937 - val_loss: 0.4483 - val_auc: 0.7919
# Epoch 31/140
# 2971/2971 [==============================] - 84s 28ms/step - loss: 0.4565 - auc: 0.7946 - val_loss: 0.4471 - val_auc: 0.7912
# Epoch 32/140
# 2971/2971 [==============================] - 61s 21ms/step - loss: 0.4556 - auc: 0.7956 - val_loss: 0.4470 - val_auc: 0.7922
# Epoch 33/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4551 - auc: 0.7961 - val_loss: 0.4446 - val_auc: 0.7945
# Epoch 34/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4543 - auc: 0.7971 - val_loss: 0.4441 - val_auc: 0.7949
# Epoch 35/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4537 - auc: 0.7978 - val_loss: 0.4451 - val_auc: 0.7966
# Epoch 36/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4529 - auc: 0.7988 - val_loss: 0.4498 - val_auc: 0.7898
# Epoch 37/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4522 - auc: 0.7996 - val_loss: 0.4439 - val_auc: 0.7959
# Epoch 38/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4517 - auc: 0.8002 - val_loss: 0.4429 - val_auc: 0.7968
# Epoch 39/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4510 - auc: 0.8010 - val_loss: 0.4432 - val_auc: 0.7976
# Epoch 40/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4504 - auc: 0.8017 - val_loss: 0.4408 - val_auc: 0.8013
# Epoch 41/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4498 - auc: 0.8023 - val_loss: 0.4394 - val_auc: 0.8011
# Epoch 42/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4490 - auc: 0.8032 - val_loss: 0.4419 - val_auc: 0.8009
# Epoch 43/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4487 - auc: 0.8036 - val_loss: 0.4389 - val_auc: 0.8020
# Epoch 44/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4482 - auc: 0.8041 - val_loss: 0.4382 - val_auc: 0.8022
# Epoch 45/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4476 - auc: 0.8049 - val_loss: 0.4422 - val_auc: 0.8014
# Epoch 46/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4474 - auc: 0.8051 - val_loss: 0.4386 - val_auc: 0.8031
# Epoch 47/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4467 - auc: 0.8059 - val_loss: 0.4400 - val_auc: 0.8008
# Epoch 48/140
# 2971/2971 [==============================] - 53s 18ms/step - loss: 0.4464 - auc: 0.8062 - val_loss: 0.4421 - val_auc: 0.8042
# Epoch 49/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4461 - auc: 0.8067 - val_loss: 0.4415 - val_auc: 0.8028
# Epoch 50/140
# 2971/2971 [==============================] - 52s 18ms/step - loss: 0.4455 - auc: 0.8073 - val_loss: 0.4434 - val_auc: 0.7971
# Epoch 51/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4453 - auc: 0.8075 - val_loss: 0.4414 - val_auc: 0.7997
# Epoch 52/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4449 - auc: 0.8079 - val_loss: 0.4388 - val_auc: 0.8031
# Epoch 53/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4446 - auc: 0.8083 - val_loss: 0.4356 - val_auc: 0.8055
# Epoch 54/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4442 - auc: 0.8087 - val_loss: 0.4360 - val_auc: 0.8051
# Epoch 55/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4439 - auc: 0.8090 - val_loss: 0.4387 - val_auc: 0.8031
# Epoch 56/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4434 - auc: 0.8097 - val_loss: 0.4492 - val_auc: 0.7936
# Epoch 57/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4429 - auc: 0.8103 - val_loss: 0.4481 - val_auc: 0.7940
# Epoch 58/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4428 - auc: 0.8104 - val_loss: 0.4399 - val_auc: 0.8022
# Epoch 59/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4424 - auc: 0.8109 - val_loss: 0.4501 - val_auc: 0.8038
# Epoch 60/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4420 - auc: 0.8114 - val_loss: 0.4379 - val_auc: 0.8072
# Epoch 61/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4419 - auc: 0.8116 - val_loss: 0.4396 - val_auc: 0.8053
# Epoch 62/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4416 - auc: 0.8119 - val_loss: 0.4398 - val_auc: 0.8026
# Epoch 63/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4416 - auc: 0.8119 - val_loss: 0.4432 - val_auc: 0.7991
# Epoch 64/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4411 - auc: 0.8124 - val_loss: 0.4350 - val_auc: 0.8073
# Epoch 65/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4410 - auc: 0.8126 - val_loss: 0.4350 - val_auc: 0.8088
# Epoch 66/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4407 - auc: 0.8130 - val_loss: 0.4395 - val_auc: 0.8077
# Epoch 67/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4405 - auc: 0.8131 - val_loss: 0.4326 - val_auc: 0.8095
# Epoch 68/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4403 - auc: 0.8133 - val_loss: 0.4435 - val_auc: 0.8015
# Epoch 69/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4400 - auc: 0.8136 - val_loss: 0.4328 - val_auc: 0.8091
# Epoch 70/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4398 - auc: 0.8139 - val_loss: 0.4358 - val_auc: 0.8092
# Epoch 71/140
# 2971/2971 [==============================] - 52s 17ms/step - loss: 0.4396 - auc: 0.8142 - val_loss: 0.4475 - val_auc: 0.7977
# Epoch 72/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4393 - auc: 0.8144 - val_loss: 0.4362 - val_auc: 0.8070
# Epoch 73/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4391 - auc: 0.8146 - val_loss: 0.4343 - val_auc: 0.8091
# Epoch 74/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4390 - auc: 0.8148 - val_loss: 0.4395 - val_auc: 0.8040
# Epoch 75/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4387 - auc: 0.8151 - val_loss: 0.4354 - val_auc: 0.8099
# Epoch 76/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4384 - auc: 0.8155 - val_loss: 0.4325 - val_auc: 0.8103
# Epoch 77/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4381 - auc: 0.8156 - val_loss: 0.4316 - val_auc: 0.8116
# Epoch 78/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4378 - auc: 0.8161 - val_loss: 0.4315 - val_auc: 0.8111
# Epoch 79/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4375 - auc: 0.8164 - val_loss: 0.4319 - val_auc: 0.8122
# Epoch 80/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4371 - auc: 0.8168 - val_loss: 0.4317 - val_auc: 0.8116
# Epoch 81/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4369 - auc: 0.8170 - val_loss: 0.4397 - val_auc: 0.8090
# Epoch 82/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4365 - auc: 0.8175 - val_loss: 0.4315 - val_auc: 0.8119
# Epoch 83/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4358 - auc: 0.8183 - val_loss: 0.4313 - val_auc: 0.8118
# Epoch 84/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4353 - auc: 0.8189 - val_loss: 0.4411 - val_auc: 0.8081
# Epoch 85/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4350 - auc: 0.8193 - val_loss: 0.4304 - val_auc: 0.8143
# Epoch 86/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4345 - auc: 0.8197 - val_loss: 0.4294 - val_auc: 0.8138
# Epoch 87/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4341 - auc: 0.8201 - val_loss: 0.4283 - val_auc: 0.8146
# Epoch 88/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4340 - auc: 0.8203 - val_loss: 0.4291 - val_auc: 0.8158
# Epoch 89/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4335 - auc: 0.8208 - val_loss: 0.4324 - val_auc: 0.8151
# Epoch 90/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4333 - auc: 0.8210 - val_loss: 0.4284 - val_auc: 0.8157
# Epoch 91/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4331 - auc: 0.8212 - val_loss: 0.4273 - val_auc: 0.8159
# Epoch 92/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4328 - auc: 0.8216 - val_loss: 0.4292 - val_auc: 0.8153
# Epoch 93/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4326 - auc: 0.8217 - val_loss: 0.4265 - val_auc: 0.8166
# Epoch 94/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4323 - auc: 0.8220 - val_loss: 0.4344 - val_auc: 0.8120
# Epoch 95/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4319 - auc: 0.8224 - val_loss: 0.4268 - val_auc: 0.8163
# Epoch 96/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4319 - auc: 0.8224 - val_loss: 0.4331 - val_auc: 0.8113
# Epoch 97/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4316 - auc: 0.8227 - val_loss: 0.4288 - val_auc: 0.8152
# Epoch 98/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4314 - auc: 0.8229 - val_loss: 0.4318 - val_auc: 0.8135
# Epoch 99/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4315 - auc: 0.8228 - val_loss: 0.4312 - val_auc: 0.8129
# Epoch 100/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4312 - auc: 0.8232 - val_loss: 0.4262 - val_auc: 0.8173
# Epoch 101/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4308 - auc: 0.8236 - val_loss: 0.4384 - val_auc: 0.8123
# Epoch 102/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4307 - auc: 0.8236 - val_loss: 0.4272 - val_auc: 0.8161
# Epoch 103/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4305 - auc: 0.8238 - val_loss: 0.4306 - val_auc: 0.8170
# Epoch 104/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4305 - auc: 0.8238 - val_loss: 0.4283 - val_auc: 0.8162
# Epoch 105/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4302 - auc: 0.8241 - val_loss: 0.4382 - val_auc: 0.8103
# Epoch 106/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4300 - auc: 0.8244 - val_loss: 0.4265 - val_auc: 0.8174
# Epoch 107/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4299 - auc: 0.8245 - val_loss: 0.4272 - val_auc: 0.8168
# Epoch 108/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4296 - auc: 0.8248 - val_loss: 0.4306 - val_auc: 0.8135
# Epoch 109/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4296 - auc: 0.8248 - val_loss: 0.4261 - val_auc: 0.8178
# Epoch 110/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4293 - auc: 0.8251 - val_loss: 0.4368 - val_auc: 0.8078
# Epoch 111/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4291 - auc: 0.8253 - val_loss: 0.4306 - val_auc: 0.8135
# Epoch 112/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4290 - auc: 0.8254 - val_loss: 0.4256 - val_auc: 0.8178
# Epoch 113/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4290 - auc: 0.8253 - val_loss: 0.4270 - val_auc: 0.8171
# Epoch 114/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4288 - auc: 0.8255 - val_loss: 0.4270 - val_auc: 0.8171
# Epoch 115/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4286 - auc: 0.8258 - val_loss: 0.4265 - val_auc: 0.8179
# Epoch 116/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4285 - auc: 0.8259 - val_loss: 0.4260 - val_auc: 0.8177
# Epoch 117/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4284 - auc: 0.8259 - val_loss: 0.4256 - val_auc: 0.8176
# Epoch 118/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4282 - auc: 0.8262 - val_loss: 0.4274 - val_auc: 0.8178
# Epoch 119/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4280 - auc: 0.8264 - val_loss: 0.4262 - val_auc: 0.8170
# Epoch 120/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4278 - auc: 0.8266 - val_loss: 0.4243 - val_auc: 0.8195
# Epoch 121/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4279 - auc: 0.8266 - val_loss: 0.4252 - val_auc: 0.8196
# Epoch 122/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4276 - auc: 0.8268 - val_loss: 0.4265 - val_auc: 0.8182
# Epoch 123/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4274 - auc: 0.8269 - val_loss: 0.4277 - val_auc: 0.8180
# Epoch 124/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4273 - auc: 0.8271 - val_loss: 0.4312 - val_auc: 0.8148
# Epoch 125/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4273 - auc: 0.8271 - val_loss: 0.4314 - val_auc: 0.8150
# Epoch 126/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4271 - auc: 0.8273 - val_loss: 0.4323 - val_auc: 0.8138
# Epoch 127/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4271 - auc: 0.8273 - val_loss: 0.4276 - val_auc: 0.8171
# Epoch 128/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4267 - auc: 0.8277 - val_loss: 0.4241 - val_auc: 0.8194
# Epoch 129/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4267 - auc: 0.8278 - val_loss: 0.4251 - val_auc: 0.8186
# Epoch 130/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4267 - auc: 0.8278 - val_loss: 0.4257 - val_auc: 0.8191
# Epoch 131/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4265 - auc: 0.8280 - val_loss: 0.4259 - val_auc: 0.8179
# Epoch 132/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4265 - auc: 0.8280 - val_loss: 0.4270 - val_auc: 0.8174
# Epoch 133/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4263 - auc: 0.8282 - val_loss: 0.4250 - val_auc: 0.8185
# Epoch 134/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4262 - auc: 0.8283 - val_loss: 0.4295 - val_auc: 0.8165
# Epoch 135/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4261 - auc: 0.8283 - val_loss: 0.4245 - val_auc: 0.8193
# Epoch 136/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4259 - auc: 0.8286 - val_loss: 0.4268 - val_auc: 0.8181
# Epoch 137/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4258 - auc: 0.8286 - val_loss: 0.4376 - val_auc: 0.8164
# Epoch 138/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4257 - auc: 0.8287 - val_loss: 0.4288 - val_auc: 0.8189
# Epoch 139/140
# 2971/2971 [==============================] - 50s 17ms/step - loss: 0.4256 - auc: 0.8288 - val_loss: 0.4243 - val_auc: 0.8193
# Epoch 140/140
# 2971/2971 [==============================] - 51s 17ms/step - loss: 0.4256 - auc: 0.8288 - val_loss: 0.4251 - val_auc: 0.8190

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 7259.997807264328

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.0007739 ],
#        [0.00071238],
#        [0.00021897],
#        ...,
#        [0.08013012],
#        [0.08603146],
#        [0.08994619]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14258285319972874
# 0.23327749787422136
# 0.37760144756042546
# 0.2845526840834871

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 74s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60261805]
# [0.82500816]
# total acc [0.78186741]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
