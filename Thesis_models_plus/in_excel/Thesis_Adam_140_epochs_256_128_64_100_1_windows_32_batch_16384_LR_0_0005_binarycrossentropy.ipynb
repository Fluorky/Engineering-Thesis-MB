# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x251b364f040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2522770e040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0005)
model_gru.compile(loss='BinaryCrossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           209664
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 19s 348ms/step - loss: 0.5660 - accuracy: 0.7391 - val_loss: 0.5334 - val_accuracy: 0.7352
# Epoch 2/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.5256 - accuracy: 0.7361 - val_loss: 0.4935 - val_accuracy: 0.7467
# Epoch 3/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.5041 - accuracy: 0.7372 - val_loss: 0.4844 - val_accuracy: 0.7532
# Epoch 4/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4970 - accuracy: 0.7411 - val_loss: 0.4798 - val_accuracy: 0.7545
# Epoch 5/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4885 - accuracy: 0.7471 - val_loss: 0.4759 - val_accuracy: 0.7519
# Epoch 6/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4796 - accuracy: 0.7501 - val_loss: 0.4675 - val_accuracy: 0.7548
# Epoch 7/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4732 - accuracy: 0.7539 - val_loss: 0.4635 - val_accuracy: 0.7603
# Epoch 8/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4677 - accuracy: 0.7574 - val_loss: 0.4652 - val_accuracy: 0.7607
# Epoch 9/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4694 - accuracy: 0.7565 - val_loss: 0.4582 - val_accuracy: 0.7640
# Epoch 10/140
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4622 - accuracy: 0.7597 - val_loss: 0.4573 - val_accuracy: 0.7609
# Epoch 11/140
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4601 - accuracy: 0.7605 - val_loss: 0.4543 - val_accuracy: 0.7667
# Epoch 12/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4576 - accuracy: 0.7616 - val_loss: 0.4480 - val_accuracy: 0.7670
# Epoch 13/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4568 - accuracy: 0.7630 - val_loss: 0.4467 - val_accuracy: 0.7685
# Epoch 14/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4552 - accuracy: 0.7639 - val_loss: 0.4469 - val_accuracy: 0.7693
# Epoch 15/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4524 - accuracy: 0.7654 - val_loss: 0.4554 - val_accuracy: 0.7713
# Epoch 16/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4520 - accuracy: 0.7665 - val_loss: 0.4476 - val_accuracy: 0.7729
# Epoch 17/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4501 - accuracy: 0.7671 - val_loss: 0.4447 - val_accuracy: 0.7683
# Epoch 18/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4490 - accuracy: 0.7678 - val_loss: 0.4435 - val_accuracy: 0.7732
# Epoch 19/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4491 - accuracy: 0.7683 - val_loss: 0.4453 - val_accuracy: 0.7718
# Epoch 20/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4468 - accuracy: 0.7687 - val_loss: 0.4407 - val_accuracy: 0.7738
# Epoch 21/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4469 - accuracy: 0.7692 - val_loss: 0.4404 - val_accuracy: 0.7735
# Epoch 22/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4472 - accuracy: 0.7694 - val_loss: 0.4422 - val_accuracy: 0.7729
# Epoch 23/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4447 - accuracy: 0.7698 - val_loss: 0.4379 - val_accuracy: 0.7744
# Epoch 24/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4434 - accuracy: 0.7706 - val_loss: 0.4380 - val_accuracy: 0.7748
# Epoch 25/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4443 - accuracy: 0.7704 - val_loss: 0.4392 - val_accuracy: 0.7739
# Epoch 26/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4427 - accuracy: 0.7713 - val_loss: 0.4392 - val_accuracy: 0.7762
# Epoch 27/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4428 - accuracy: 0.7715 - val_loss: 0.4392 - val_accuracy: 0.7767
# Epoch 28/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4440 - accuracy: 0.7716 - val_loss: 0.4397 - val_accuracy: 0.7766
# Epoch 29/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.4426 - accuracy: 0.7722 - val_loss: 0.4406 - val_accuracy: 0.7726
# Epoch 30/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4414 - accuracy: 0.7727 - val_loss: 0.4342 - val_accuracy: 0.7777
# Epoch 31/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4394 - accuracy: 0.7734 - val_loss: 0.4346 - val_accuracy: 0.7777
# Epoch 32/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4399 - accuracy: 0.7734 - val_loss: 0.4426 - val_accuracy: 0.7759
# Epoch 33/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4399 - accuracy: 0.7733 - val_loss: 0.4486 - val_accuracy: 0.7763
# Epoch 34/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4413 - accuracy: 0.7739 - val_loss: 0.4342 - val_accuracy: 0.7784
# Epoch 35/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4389 - accuracy: 0.7742 - val_loss: 0.4353 - val_accuracy: 0.7775
# Epoch 36/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4370 - accuracy: 0.7750 - val_loss: 0.4343 - val_accuracy: 0.7772
# Epoch 37/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4375 - accuracy: 0.7751 - val_loss: 0.4363 - val_accuracy: 0.7780
# Epoch 38/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4371 - accuracy: 0.7753 - val_loss: 0.4308 - val_accuracy: 0.7806
# Epoch 39/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4367 - accuracy: 0.7755 - val_loss: 0.4319 - val_accuracy: 0.7800
# Epoch 40/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4359 - accuracy: 0.7755 - val_loss: 0.4342 - val_accuracy: 0.7748
# Epoch 41/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4361 - accuracy: 0.7762 - val_loss: 0.4341 - val_accuracy: 0.7751
# Epoch 42/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4349 - accuracy: 0.7761 - val_loss: 0.4344 - val_accuracy: 0.7801
# Epoch 43/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4349 - accuracy: 0.7765 - val_loss: 0.4336 - val_accuracy: 0.7796
# Epoch 44/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.4351 - accuracy: 0.7766 - val_loss: 0.4343 - val_accuracy: 0.7782
# Epoch 45/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4355 - accuracy: 0.7767 - val_loss: 0.4341 - val_accuracy: 0.7780
# Epoch 46/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4336 - accuracy: 0.7774 - val_loss: 0.4311 - val_accuracy: 0.7774
# Epoch 47/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4331 - accuracy: 0.7773 - val_loss: 0.4305 - val_accuracy: 0.7805
# Epoch 48/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4334 - accuracy: 0.7774 - val_loss: 0.4318 - val_accuracy: 0.7796
# Epoch 49/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4325 - accuracy: 0.7775 - val_loss: 0.4324 - val_accuracy: 0.7797
# Epoch 50/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4325 - accuracy: 0.7778 - val_loss: 0.4319 - val_accuracy: 0.7781
# Epoch 51/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4325 - accuracy: 0.7775 - val_loss: 0.4314 - val_accuracy: 0.7819
# Epoch 52/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4317 - accuracy: 0.7782 - val_loss: 0.4312 - val_accuracy: 0.7792
# Epoch 53/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4315 - accuracy: 0.7784 - val_loss: 0.4303 - val_accuracy: 0.7807
# Epoch 54/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4319 - accuracy: 0.7779 - val_loss: 0.4313 - val_accuracy: 0.7778
# Epoch 55/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4314 - accuracy: 0.7783 - val_loss: 0.4318 - val_accuracy: 0.7763
# Epoch 56/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4324 - accuracy: 0.7782 - val_loss: 0.4323 - val_accuracy: 0.7808
# Epoch 57/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.4305 - accuracy: 0.7791 - val_loss: 0.4311 - val_accuracy: 0.7797
# Epoch 58/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.4306 - accuracy: 0.7787 - val_loss: 0.4300 - val_accuracy: 0.7775
# Epoch 59/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4316 - accuracy: 0.7787 - val_loss: 0.4321 - val_accuracy: 0.7781
# Epoch 60/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4306 - accuracy: 0.7793 - val_loss: 0.4299 - val_accuracy: 0.7808
# Epoch 61/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4294 - accuracy: 0.7795 - val_loss: 0.4298 - val_accuracy: 0.7787
# Epoch 62/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4295 - accuracy: 0.7798 - val_loss: 0.4351 - val_accuracy: 0.7814
# Epoch 63/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4304 - accuracy: 0.7792 - val_loss: 0.4301 - val_accuracy: 0.7824
# Epoch 64/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4293 - accuracy: 0.7795 - val_loss: 0.4337 - val_accuracy: 0.7796
# Epoch 65/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4285 - accuracy: 0.7800 - val_loss: 0.4304 - val_accuracy: 0.7778
# Epoch 66/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4312 - accuracy: 0.7797 - val_loss: 0.4312 - val_accuracy: 0.7815
# Epoch 67/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4313 - accuracy: 0.7792 - val_loss: 0.4332 - val_accuracy: 0.7789
# Epoch 68/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4280 - accuracy: 0.7801 - val_loss: 0.4287 - val_accuracy: 0.7807
# Epoch 69/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4263 - accuracy: 0.7809 - val_loss: 0.4299 - val_accuracy: 0.7811
# Epoch 70/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4266 - accuracy: 0.7808 - val_loss: 0.4281 - val_accuracy: 0.7792
# Epoch 71/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4270 - accuracy: 0.7809 - val_loss: 0.4297 - val_accuracy: 0.7823
# Epoch 72/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4259 - accuracy: 0.7810 - val_loss: 0.4292 - val_accuracy: 0.7801
# Epoch 73/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4270 - accuracy: 0.7808 - val_loss: 0.4281 - val_accuracy: 0.7826
# Epoch 74/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4257 - accuracy: 0.7810 - val_loss: 0.4306 - val_accuracy: 0.7812
# Epoch 75/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4276 - accuracy: 0.7814 - val_loss: 0.4261 - val_accuracy: 0.7821
# Epoch 76/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4252 - accuracy: 0.7811 - val_loss: 0.4318 - val_accuracy: 0.7812
# Epoch 77/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4255 - accuracy: 0.7813 - val_loss: 0.4309 - val_accuracy: 0.7820
# Epoch 78/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4254 - accuracy: 0.7815 - val_loss: 0.4264 - val_accuracy: 0.7823
# Epoch 79/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4249 - accuracy: 0.7814 - val_loss: 0.4311 - val_accuracy: 0.7767
# Epoch 80/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4248 - accuracy: 0.7816 - val_loss: 0.4316 - val_accuracy: 0.7828
# Epoch 81/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4240 - accuracy: 0.7819 - val_loss: 0.4267 - val_accuracy: 0.7812
# Epoch 82/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4245 - accuracy: 0.7812 - val_loss: 0.4290 - val_accuracy: 0.7826
# Epoch 83/140
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4244 - accuracy: 0.7821 - val_loss: 0.4293 - val_accuracy: 0.7831
# Epoch 84/140
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4248 - accuracy: 0.7818 - val_loss: 0.4259 - val_accuracy: 0.7830
# Epoch 85/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4240 - accuracy: 0.7828 - val_loss: 0.4319 - val_accuracy: 0.7836
# Epoch 86/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4230 - accuracy: 0.7827 - val_loss: 0.4257 - val_accuracy: 0.7826
# Epoch 87/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4232 - accuracy: 0.7828 - val_loss: 0.4326 - val_accuracy: 0.7818
# Epoch 88/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4240 - accuracy: 0.7828 - val_loss: 0.4245 - val_accuracy: 0.7841
# Epoch 89/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4219 - accuracy: 0.7831 - val_loss: 0.4284 - val_accuracy: 0.7831
# Epoch 90/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4219 - accuracy: 0.7833 - val_loss: 0.4292 - val_accuracy: 0.7774
# Epoch 91/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4234 - accuracy: 0.7834 - val_loss: 0.4291 - val_accuracy: 0.7830
# Epoch 92/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4228 - accuracy: 0.7829 - val_loss: 0.4294 - val_accuracy: 0.7844
# Epoch 93/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4220 - accuracy: 0.7836 - val_loss: 0.4250 - val_accuracy: 0.7823
# Epoch 94/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4221 - accuracy: 0.7837 - val_loss: 0.4366 - val_accuracy: 0.7824
# Epoch 95/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4217 - accuracy: 0.7840 - val_loss: 0.4301 - val_accuracy: 0.7836
# Epoch 96/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4211 - accuracy: 0.7841 - val_loss: 0.4251 - val_accuracy: 0.7833
# Epoch 97/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4202 - accuracy: 0.7843 - val_loss: 0.4301 - val_accuracy: 0.7841
# Epoch 98/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4203 - accuracy: 0.7848 - val_loss: 0.4259 - val_accuracy: 0.7824
# Epoch 99/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4199 - accuracy: 0.7849 - val_loss: 0.4268 - val_accuracy: 0.7801
# Epoch 100/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4209 - accuracy: 0.7844 - val_loss: 0.4297 - val_accuracy: 0.7816
# Epoch 101/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4194 - accuracy: 0.7853 - val_loss: 0.4316 - val_accuracy: 0.7848
# Epoch 102/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4195 - accuracy: 0.7850 - val_loss: 0.4252 - val_accuracy: 0.7843
# Epoch 103/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4201 - accuracy: 0.7848 - val_loss: 0.4273 - val_accuracy: 0.7837
# Epoch 104/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4186 - accuracy: 0.7849 - val_loss: 0.4306 - val_accuracy: 0.7841
# Epoch 105/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4188 - accuracy: 0.7852 - val_loss: 0.4278 - val_accuracy: 0.7849
# Epoch 106/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4190 - accuracy: 0.7854 - val_loss: 0.4272 - val_accuracy: 0.7807
# Epoch 107/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4204 - accuracy: 0.7850 - val_loss: 0.4286 - val_accuracy: 0.7797
# Epoch 108/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4172 - accuracy: 0.7863 - val_loss: 0.4270 - val_accuracy: 0.7817
# Epoch 109/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4182 - accuracy: 0.7856 - val_loss: 0.4274 - val_accuracy: 0.7833
# Epoch 110/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4174 - accuracy: 0.7861 - val_loss: 0.4249 - val_accuracy: 0.7850
# Epoch 111/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4172 - accuracy: 0.7859 - val_loss: 0.4244 - val_accuracy: 0.7844
# Epoch 112/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4181 - accuracy: 0.7860 - val_loss: 0.4262 - val_accuracy: 0.7826
# Epoch 113/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4170 - accuracy: 0.7864 - val_loss: 0.4262 - val_accuracy: 0.7810
# Epoch 114/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4170 - accuracy: 0.7866 - val_loss: 0.4320 - val_accuracy: 0.7847
# Epoch 115/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4173 - accuracy: 0.7865 - val_loss: 0.4309 - val_accuracy: 0.7837
# Epoch 116/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4161 - accuracy: 0.7867 - val_loss: 0.4274 - val_accuracy: 0.7808
# Epoch 117/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4155 - accuracy: 0.7868 - val_loss: 0.4263 - val_accuracy: 0.7821
# Epoch 118/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4158 - accuracy: 0.7869 - val_loss: 0.4309 - val_accuracy: 0.7838
# Epoch 119/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4159 - accuracy: 0.7864 - val_loss: 0.4311 - val_accuracy: 0.7841
# Epoch 120/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4160 - accuracy: 0.7867 - val_loss: 0.4307 - val_accuracy: 0.7842
# Epoch 121/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4147 - accuracy: 0.7874 - val_loss: 0.4303 - val_accuracy: 0.7842
# Epoch 122/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4157 - accuracy: 0.7875 - val_loss: 0.4280 - val_accuracy: 0.7854
# Epoch 123/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4158 - accuracy: 0.7873 - val_loss: 0.4362 - val_accuracy: 0.7841
# Epoch 124/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4152 - accuracy: 0.7875 - val_loss: 0.4323 - val_accuracy: 0.7847
# Epoch 125/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4154 - accuracy: 0.7876 - val_loss: 0.4246 - val_accuracy: 0.7846
# Epoch 126/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4158 - accuracy: 0.7873 - val_loss: 0.4323 - val_accuracy: 0.7836
# Epoch 127/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4153 - accuracy: 0.7878 - val_loss: 0.4309 - val_accuracy: 0.7851
# Epoch 128/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4137 - accuracy: 0.7883 - val_loss: 0.4322 - val_accuracy: 0.7847
# Epoch 129/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4138 - accuracy: 0.7882 - val_loss: 0.4252 - val_accuracy: 0.7819
# Epoch 130/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4152 - accuracy: 0.7878 - val_loss: 0.4262 - val_accuracy: 0.7823
# Epoch 131/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4150 - accuracy: 0.7879 - val_loss: 0.4340 - val_accuracy: 0.7850
# Epoch 132/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4140 - accuracy: 0.7881 - val_loss: 0.4295 - val_accuracy: 0.7830
# Epoch 133/140
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4138 - accuracy: 0.7885 - val_loss: 0.4400 - val_accuracy: 0.7844
# Epoch 134/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4166 - accuracy: 0.7874 - val_loss: 0.4263 - val_accuracy: 0.7826
# Epoch 135/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4127 - accuracy: 0.7882 - val_loss: 0.4268 - val_accuracy: 0.7839
# Epoch 136/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4131 - accuracy: 0.7884 - val_loss: 0.4373 - val_accuracy: 0.7854
# Epoch 137/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4152 - accuracy: 0.7880 - val_loss: 0.4258 - val_accuracy: 0.7827
# Epoch 138/140
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4114 - accuracy: 0.7890 - val_loss: 0.4334 - val_accuracy: 0.7840
# Epoch 139/140
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4123 - accuracy: 0.7887 - val_loss: 0.4269 - val_accuracy: 0.7840
# Epoch 140/140
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4113 - accuracy: 0.7895 - val_loss: 0.4329 - val_accuracy: 0.7830

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 24s 8ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 1027.0566663742065

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00020538],
#        [0.0007841 ],
#        [0.00037733],
#        ...,
#        [0.01998167],
#        [0.02040716],
#        [0.02211319]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1438243108335158
# 0.2266235759977091
# 0.37924175776609276
# 0.27793689988098697

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 114s 8ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60828532]
# [0.83617291]
# total acc [0.78791092]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1100577024, 'peak': 9509416192}
