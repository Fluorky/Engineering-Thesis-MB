# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x27e9516c040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x27f09220040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0004)
model_gru.compile(loss='BinaryCrossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=4096)#, shuffle=False)
# Out:
# Epoch 1/140
# 93/93 [==============================] - 23s 187ms/step - loss: 0.6210 - accuracy: 0.6588 - val_loss: 0.5596 - val_accuracy: 0.7530
# Epoch 2/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.5736 - accuracy: 0.7393 - val_loss: 0.5590 - val_accuracy: 0.7530
# Epoch 3/140
# 93/93 [==============================] - 17s 178ms/step - loss: 0.5593 - accuracy: 0.7393 - val_loss: 0.5188 - val_accuracy: 0.7530
# Epoch 4/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.5143 - accuracy: 0.7391 - val_loss: 0.4891 - val_accuracy: 0.7530
# Epoch 5/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.5016 - accuracy: 0.7391 - val_loss: 0.4837 - val_accuracy: 0.7530
# Epoch 6/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4973 - accuracy: 0.7393 - val_loss: 0.4820 - val_accuracy: 0.7530
# Epoch 7/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4950 - accuracy: 0.7393 - val_loss: 0.4787 - val_accuracy: 0.7538
# Epoch 8/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4929 - accuracy: 0.7412 - val_loss: 0.4762 - val_accuracy: 0.7562
# Epoch 9/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4881 - accuracy: 0.7468 - val_loss: 0.4729 - val_accuracy: 0.7541
# Epoch 10/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4788 - accuracy: 0.7514 - val_loss: 0.4660 - val_accuracy: 0.7558
# Epoch 11/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4702 - accuracy: 0.7572 - val_loss: 0.4567 - val_accuracy: 0.7647
# Epoch 12/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4648 - accuracy: 0.7593 - val_loss: 0.4558 - val_accuracy: 0.7663
# Epoch 13/140
# 93/93 [==============================] - 17s 178ms/step - loss: 0.4625 - accuracy: 0.7604 - val_loss: 0.4519 - val_accuracy: 0.7662
# Epoch 14/140
# 93/93 [==============================] - 17s 178ms/step - loss: 0.4592 - accuracy: 0.7615 - val_loss: 0.4498 - val_accuracy: 0.7677
# Epoch 15/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4576 - accuracy: 0.7625 - val_loss: 0.4473 - val_accuracy: 0.7680
# Epoch 16/140
# 93/93 [==============================] - 18s 189ms/step - loss: 0.4556 - accuracy: 0.7630 - val_loss: 0.4478 - val_accuracy: 0.7683
# Epoch 17/140
# 93/93 [==============================] - 17s 178ms/step - loss: 0.4537 - accuracy: 0.7641 - val_loss: 0.4463 - val_accuracy: 0.7673
# Epoch 18/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4527 - accuracy: 0.7648 - val_loss: 0.4430 - val_accuracy: 0.7702
# Epoch 19/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4506 - accuracy: 0.7661 - val_loss: 0.4487 - val_accuracy: 0.7693
# Epoch 20/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4499 - accuracy: 0.7667 - val_loss: 0.4454 - val_accuracy: 0.7689
# Epoch 21/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4498 - accuracy: 0.7670 - val_loss: 0.4404 - val_accuracy: 0.7733
# Epoch 22/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4482 - accuracy: 0.7681 - val_loss: 0.4423 - val_accuracy: 0.7737
# Epoch 23/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4469 - accuracy: 0.7686 - val_loss: 0.4385 - val_accuracy: 0.7739
# Epoch 24/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4450 - accuracy: 0.7691 - val_loss: 0.4414 - val_accuracy: 0.7750
# Epoch 25/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4453 - accuracy: 0.7701 - val_loss: 0.4448 - val_accuracy: 0.7756
# Epoch 26/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4441 - accuracy: 0.7706 - val_loss: 0.4368 - val_accuracy: 0.7755
# Epoch 27/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4425 - accuracy: 0.7715 - val_loss: 0.4361 - val_accuracy: 0.7760
# Epoch 28/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4412 - accuracy: 0.7722 - val_loss: 0.4362 - val_accuracy: 0.7772
# Epoch 29/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4413 - accuracy: 0.7730 - val_loss: 0.4368 - val_accuracy: 0.7764
# Epoch 30/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4406 - accuracy: 0.7738 - val_loss: 0.4338 - val_accuracy: 0.7781
# Epoch 31/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4388 - accuracy: 0.7745 - val_loss: 0.4337 - val_accuracy: 0.7766
# Epoch 32/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4385 - accuracy: 0.7751 - val_loss: 0.4365 - val_accuracy: 0.7759
# Epoch 33/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4384 - accuracy: 0.7755 - val_loss: 0.4346 - val_accuracy: 0.7766
# Epoch 34/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4382 - accuracy: 0.7753 - val_loss: 0.4329 - val_accuracy: 0.7783
# Epoch 35/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4371 - accuracy: 0.7756 - val_loss: 0.4344 - val_accuracy: 0.7774
# Epoch 36/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4376 - accuracy: 0.7757 - val_loss: 0.4330 - val_accuracy: 0.7769
# Epoch 37/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4358 - accuracy: 0.7763 - val_loss: 0.4304 - val_accuracy: 0.7794
# Epoch 38/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4356 - accuracy: 0.7762 - val_loss: 0.4305 - val_accuracy: 0.7791
# Epoch 39/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4352 - accuracy: 0.7769 - val_loss: 0.4303 - val_accuracy: 0.7806
# Epoch 40/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4351 - accuracy: 0.7765 - val_loss: 0.4319 - val_accuracy: 0.7782
# Epoch 41/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4339 - accuracy: 0.7770 - val_loss: 0.4341 - val_accuracy: 0.7776
# Epoch 42/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4341 - accuracy: 0.7770 - val_loss: 0.4307 - val_accuracy: 0.7803
# Epoch 43/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4347 - accuracy: 0.7772 - val_loss: 0.4371 - val_accuracy: 0.7793
# Epoch 44/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4334 - accuracy: 0.7777 - val_loss: 0.4306 - val_accuracy: 0.7786
# Epoch 45/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4334 - accuracy: 0.7780 - val_loss: 0.4295 - val_accuracy: 0.7785
# Epoch 46/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4323 - accuracy: 0.7779 - val_loss: 0.4338 - val_accuracy: 0.7784
# Epoch 47/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4318 - accuracy: 0.7786 - val_loss: 0.4303 - val_accuracy: 0.7789
# Epoch 48/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4319 - accuracy: 0.7786 - val_loss: 0.4285 - val_accuracy: 0.7803
# Epoch 49/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4320 - accuracy: 0.7787 - val_loss: 0.4294 - val_accuracy: 0.7806
# Epoch 50/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4324 - accuracy: 0.7787 - val_loss: 0.4281 - val_accuracy: 0.7807
# Epoch 51/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4316 - accuracy: 0.7791 - val_loss: 0.4323 - val_accuracy: 0.7777
# Epoch 52/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4307 - accuracy: 0.7793 - val_loss: 0.4284 - val_accuracy: 0.7798
# Epoch 53/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4311 - accuracy: 0.7798 - val_loss: 0.4313 - val_accuracy: 0.7780
# Epoch 54/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4298 - accuracy: 0.7799 - val_loss: 0.4278 - val_accuracy: 0.7811
# Epoch 55/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4301 - accuracy: 0.7802 - val_loss: 0.4284 - val_accuracy: 0.7808
# Epoch 56/140
# 93/93 [==============================] - 16s 177ms/step - loss: 0.4294 - accuracy: 0.7804 - val_loss: 0.4309 - val_accuracy: 0.7815
# Epoch 57/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4285 - accuracy: 0.7809 - val_loss: 0.4299 - val_accuracy: 0.7801
# Epoch 58/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4285 - accuracy: 0.7808 - val_loss: 0.4289 - val_accuracy: 0.7816
# Epoch 59/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4280 - accuracy: 0.7812 - val_loss: 0.4317 - val_accuracy: 0.7816
# Epoch 60/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4279 - accuracy: 0.7814 - val_loss: 0.4282 - val_accuracy: 0.7803
# Epoch 61/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4273 - accuracy: 0.7818 - val_loss: 0.4256 - val_accuracy: 0.7835
# Epoch 62/140
# 93/93 [==============================] - 16s 173ms/step - loss: 0.4272 - accuracy: 0.7817 - val_loss: 0.4267 - val_accuracy: 0.7817
# Epoch 63/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4268 - accuracy: 0.7818 - val_loss: 0.4275 - val_accuracy: 0.7823
# Epoch 64/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4266 - accuracy: 0.7818 - val_loss: 0.4263 - val_accuracy: 0.7836
# Epoch 65/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4265 - accuracy: 0.7821 - val_loss: 0.4284 - val_accuracy: 0.7815
# Epoch 66/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4264 - accuracy: 0.7822 - val_loss: 0.4261 - val_accuracy: 0.7824
# Epoch 67/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4254 - accuracy: 0.7828 - val_loss: 0.4280 - val_accuracy: 0.7839
# Epoch 68/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4251 - accuracy: 0.7829 - val_loss: 0.4251 - val_accuracy: 0.7832
# Epoch 69/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4247 - accuracy: 0.7832 - val_loss: 0.4256 - val_accuracy: 0.7843
# Epoch 70/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4242 - accuracy: 0.7836 - val_loss: 0.4265 - val_accuracy: 0.7823
# Epoch 71/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4244 - accuracy: 0.7833 - val_loss: 0.4281 - val_accuracy: 0.7826
# Epoch 72/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4247 - accuracy: 0.7833 - val_loss: 0.4297 - val_accuracy: 0.7833
# Epoch 73/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4239 - accuracy: 0.7833 - val_loss: 0.4255 - val_accuracy: 0.7847
# Epoch 74/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4230 - accuracy: 0.7842 - val_loss: 0.4245 - val_accuracy: 0.7840
# Epoch 75/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4232 - accuracy: 0.7834 - val_loss: 0.4230 - val_accuracy: 0.7839
# Epoch 76/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4226 - accuracy: 0.7842 - val_loss: 0.4296 - val_accuracy: 0.7781
# Epoch 77/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4230 - accuracy: 0.7839 - val_loss: 0.4261 - val_accuracy: 0.7823
# Epoch 78/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4223 - accuracy: 0.7844 - val_loss: 0.4278 - val_accuracy: 0.7853
# Epoch 79/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4222 - accuracy: 0.7838 - val_loss: 0.4257 - val_accuracy: 0.7847
# Epoch 80/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4217 - accuracy: 0.7845 - val_loss: 0.4308 - val_accuracy: 0.7825
# Epoch 81/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4213 - accuracy: 0.7846 - val_loss: 0.4265 - val_accuracy: 0.7857
# Epoch 82/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4216 - accuracy: 0.7842 - val_loss: 0.4287 - val_accuracy: 0.7840
# Epoch 83/140
# 93/93 [==============================] - 16s 173ms/step - loss: 0.4215 - accuracy: 0.7847 - val_loss: 0.4225 - val_accuracy: 0.7853
# Epoch 84/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4206 - accuracy: 0.7847 - val_loss: 0.4260 - val_accuracy: 0.7829
# Epoch 85/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4204 - accuracy: 0.7848 - val_loss: 0.4231 - val_accuracy: 0.7857
# Epoch 86/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4197 - accuracy: 0.7852 - val_loss: 0.4242 - val_accuracy: 0.7863
# Epoch 87/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4196 - accuracy: 0.7852 - val_loss: 0.4248 - val_accuracy: 0.7841
# Epoch 88/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4192 - accuracy: 0.7853 - val_loss: 0.4225 - val_accuracy: 0.7858
# Epoch 89/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4192 - accuracy: 0.7856 - val_loss: 0.4249 - val_accuracy: 0.7819
# Epoch 90/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4189 - accuracy: 0.7857 - val_loss: 0.4228 - val_accuracy: 0.7849
# Epoch 91/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4181 - accuracy: 0.7857 - val_loss: 0.4246 - val_accuracy: 0.7831
# Epoch 92/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4188 - accuracy: 0.7852 - val_loss: 0.4236 - val_accuracy: 0.7852
# Epoch 93/140
# 93/93 [==============================] - 16s 176ms/step - loss: 0.4183 - accuracy: 0.7859 - val_loss: 0.4262 - val_accuracy: 0.7834
# Epoch 94/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4175 - accuracy: 0.7861 - val_loss: 0.4253 - val_accuracy: 0.7867
# Epoch 95/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4176 - accuracy: 0.7859 - val_loss: 0.4297 - val_accuracy: 0.7837
# Epoch 96/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4176 - accuracy: 0.7865 - val_loss: 0.4242 - val_accuracy: 0.7853
# Epoch 97/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4167 - accuracy: 0.7864 - val_loss: 0.4256 - val_accuracy: 0.7853
# Epoch 98/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4169 - accuracy: 0.7862 - val_loss: 0.4230 - val_accuracy: 0.7835
# Epoch 99/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4173 - accuracy: 0.7863 - val_loss: 0.4250 - val_accuracy: 0.7846
# Epoch 100/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4169 - accuracy: 0.7865 - val_loss: 0.4275 - val_accuracy: 0.7859
# Epoch 101/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4166 - accuracy: 0.7863 - val_loss: 0.4283 - val_accuracy: 0.7845
# Epoch 102/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4163 - accuracy: 0.7864 - val_loss: 0.4234 - val_accuracy: 0.7842
# Epoch 103/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4158 - accuracy: 0.7868 - val_loss: 0.4228 - val_accuracy: 0.7840
# Epoch 104/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4154 - accuracy: 0.7871 - val_loss: 0.4233 - val_accuracy: 0.7852
# Epoch 105/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4151 - accuracy: 0.7870 - val_loss: 0.4242 - val_accuracy: 0.7865
# Epoch 106/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4157 - accuracy: 0.7869 - val_loss: 0.4227 - val_accuracy: 0.7847
# Epoch 107/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4149 - accuracy: 0.7871 - val_loss: 0.4243 - val_accuracy: 0.7850
# Epoch 108/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4161 - accuracy: 0.7867 - val_loss: 0.4261 - val_accuracy: 0.7852
# Epoch 109/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4148 - accuracy: 0.7871 - val_loss: 0.4238 - val_accuracy: 0.7868
# Epoch 110/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4153 - accuracy: 0.7869 - val_loss: 0.4218 - val_accuracy: 0.7873
# Epoch 111/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4146 - accuracy: 0.7871 - val_loss: 0.4267 - val_accuracy: 0.7848
# Epoch 112/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4140 - accuracy: 0.7873 - val_loss: 0.4243 - val_accuracy: 0.7849
# Epoch 113/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4142 - accuracy: 0.7875 - val_loss: 0.4231 - val_accuracy: 0.7861
# Epoch 114/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4137 - accuracy: 0.7877 - val_loss: 0.4228 - val_accuracy: 0.7866
# Epoch 115/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4146 - accuracy: 0.7871 - val_loss: 0.4294 - val_accuracy: 0.7856
# Epoch 116/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4133 - accuracy: 0.7879 - val_loss: 0.4265 - val_accuracy: 0.7863
# Epoch 117/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4134 - accuracy: 0.7874 - val_loss: 0.4234 - val_accuracy: 0.7833
# Epoch 118/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4130 - accuracy: 0.7877 - val_loss: 0.4218 - val_accuracy: 0.7872
# Epoch 119/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4134 - accuracy: 0.7876 - val_loss: 0.4229 - val_accuracy: 0.7857
# Epoch 120/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4134 - accuracy: 0.7879 - val_loss: 0.4292 - val_accuracy: 0.7862
# Epoch 121/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4130 - accuracy: 0.7880 - val_loss: 0.4247 - val_accuracy: 0.7840
# Epoch 122/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4132 - accuracy: 0.7880 - val_loss: 0.4259 - val_accuracy: 0.7837
# Epoch 123/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4129 - accuracy: 0.7884 - val_loss: 0.4248 - val_accuracy: 0.7830
# Epoch 124/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4126 - accuracy: 0.7882 - val_loss: 0.4251 - val_accuracy: 0.7863
# Epoch 125/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4120 - accuracy: 0.7883 - val_loss: 0.4251 - val_accuracy: 0.7851
# Epoch 126/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4122 - accuracy: 0.7884 - val_loss: 0.4236 - val_accuracy: 0.7867
# Epoch 127/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4115 - accuracy: 0.7883 - val_loss: 0.4247 - val_accuracy: 0.7854
# Epoch 128/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4122 - accuracy: 0.7880 - val_loss: 0.4297 - val_accuracy: 0.7835
# Epoch 129/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4129 - accuracy: 0.7883 - val_loss: 0.4238 - val_accuracy: 0.7828
# Epoch 130/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4115 - accuracy: 0.7885 - val_loss: 0.4291 - val_accuracy: 0.7871
# Epoch 131/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4118 - accuracy: 0.7887 - val_loss: 0.4257 - val_accuracy: 0.7808
# Epoch 132/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4120 - accuracy: 0.7882 - val_loss: 0.4247 - val_accuracy: 0.7831
# Epoch 133/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4107 - accuracy: 0.7887 - val_loss: 0.4278 - val_accuracy: 0.7859
# Epoch 134/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4110 - accuracy: 0.7882 - val_loss: 0.4255 - val_accuracy: 0.7848
# Epoch 135/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4111 - accuracy: 0.7892 - val_loss: 0.4233 - val_accuracy: 0.7864
# Epoch 136/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4114 - accuracy: 0.7891 - val_loss: 0.4235 - val_accuracy: 0.7845
# Epoch 137/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4107 - accuracy: 0.7888 - val_loss: 0.4239 - val_accuracy: 0.7835
# Epoch 138/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4103 - accuracy: 0.7895 - val_loss: 0.4228 - val_accuracy: 0.7850
# Epoch 139/140
# 93/93 [==============================] - 16s 175ms/step - loss: 0.4097 - accuracy: 0.7891 - val_loss: 0.4240 - val_accuracy: 0.7853
# Epoch 140/140
# 93/93 [==============================] - 16s 174ms/step - loss: 0.4103 - accuracy: 0.7892 - val_loss: 0.4245 - val_accuracy: 0.7829

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 27s 9ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 2319.007066488266

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00077151],
#        [0.00347795],
#        [0.00093831],
#        ...,
#        [0.12640522],
#        [0.1304226 ],
#        [0.13272999]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14225875575193295
# 0.23504192602182072
# 0.3771720505975131
# 0.2893129382411065

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 124s 8ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60735352]
# [0.83718029]
# total acc [0.78799508]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 2023095296}
