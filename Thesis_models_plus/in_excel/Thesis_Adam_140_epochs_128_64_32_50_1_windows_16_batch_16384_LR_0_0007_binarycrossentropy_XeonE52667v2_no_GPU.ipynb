# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1900000c040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x19063a41040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 63s 2s/step - loss: 0.6533 - accuracy: 0.5967 - val_loss: 0.5592 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 56s 2s/step - loss: 0.5752 - accuracy: 0.7393 - val_loss: 0.5596 - val_accuracy: 0.7531
# Epoch 3/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.5739 - accuracy: 0.7393 - val_loss: 0.5593 - val_accuracy: 0.7531
# Epoch 4/140
# 24/24 [==============================] - 62s 3s/step - loss: 0.5738 - accuracy: 0.7393 - val_loss: 0.5595 - val_accuracy: 0.7531
# Epoch 5/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5594 - val_accuracy: 0.7531
# Epoch 6/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.5736 - accuracy: 0.7393 - val_loss: 0.5593 - val_accuracy: 0.7531
# Epoch 7/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.5726 - accuracy: 0.7393 - val_loss: 0.5564 - val_accuracy: 0.7531
# Epoch 8/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.5583 - accuracy: 0.7393 - val_loss: 0.5359 - val_accuracy: 0.7531
# Epoch 9/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.5354 - accuracy: 0.7393 - val_loss: 0.5085 - val_accuracy: 0.7531
# Epoch 10/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.5155 - accuracy: 0.7384 - val_loss: 0.4960 - val_accuracy: 0.7534
# Epoch 11/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.5087 - accuracy: 0.7393 - val_loss: 0.4909 - val_accuracy: 0.7530
# Epoch 12/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.5043 - accuracy: 0.7410 - val_loss: 0.4874 - val_accuracy: 0.7533
# Epoch 13/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.5001 - accuracy: 0.7438 - val_loss: 0.4863 - val_accuracy: 0.7536
# Epoch 14/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4967 - accuracy: 0.7466 - val_loss: 0.4855 - val_accuracy: 0.7535
# Epoch 15/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4919 - accuracy: 0.7481 - val_loss: 0.4790 - val_accuracy: 0.7534
# Epoch 16/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4863 - accuracy: 0.7491 - val_loss: 0.4803 - val_accuracy: 0.7507
# Epoch 17/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4809 - accuracy: 0.7515 - val_loss: 0.4721 - val_accuracy: 0.7563
# Epoch 18/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4754 - accuracy: 0.7542 - val_loss: 0.4645 - val_accuracy: 0.7603
# Epoch 19/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4716 - accuracy: 0.7559 - val_loss: 0.4614 - val_accuracy: 0.7623
# Epoch 20/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4702 - accuracy: 0.7561 - val_loss: 0.4616 - val_accuracy: 0.7615
# Epoch 21/140
# 24/24 [==============================] - 60s 3s/step - loss: 0.4659 - accuracy: 0.7577 - val_loss: 0.4566 - val_accuracy: 0.7614
# Epoch 22/140
# 24/24 [==============================] - 60s 3s/step - loss: 0.4697 - accuracy: 0.7563 - val_loss: 0.4584 - val_accuracy: 0.7622
# Epoch 23/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4642 - accuracy: 0.7581 - val_loss: 0.4562 - val_accuracy: 0.7649
# Epoch 24/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4652 - accuracy: 0.7577 - val_loss: 0.4566 - val_accuracy: 0.7634
# Epoch 25/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4613 - accuracy: 0.7591 - val_loss: 0.4542 - val_accuracy: 0.7638
# Epoch 26/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4595 - accuracy: 0.7597 - val_loss: 0.4554 - val_accuracy: 0.7659
# Epoch 27/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4614 - accuracy: 0.7599 - val_loss: 0.4609 - val_accuracy: 0.7667
# Epoch 28/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4606 - accuracy: 0.7610 - val_loss: 0.4511 - val_accuracy: 0.7648
# Epoch 29/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4569 - accuracy: 0.7618 - val_loss: 0.4494 - val_accuracy: 0.7682
# Epoch 30/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4566 - accuracy: 0.7626 - val_loss: 0.4483 - val_accuracy: 0.7666
# Epoch 31/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4558 - accuracy: 0.7630 - val_loss: 0.4465 - val_accuracy: 0.7697
# Epoch 32/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4555 - accuracy: 0.7639 - val_loss: 0.4507 - val_accuracy: 0.7675
# Epoch 33/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4553 - accuracy: 0.7644 - val_loss: 0.4527 - val_accuracy: 0.7706
# Epoch 34/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4539 - accuracy: 0.7649 - val_loss: 0.4462 - val_accuracy: 0.7710
# Epoch 35/140
# 24/24 [==============================] - 60s 3s/step - loss: 0.4528 - accuracy: 0.7654 - val_loss: 0.4460 - val_accuracy: 0.7707
# Epoch 36/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4512 - accuracy: 0.7665 - val_loss: 0.4445 - val_accuracy: 0.7717
# Epoch 37/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4514 - accuracy: 0.7663 - val_loss: 0.4429 - val_accuracy: 0.7728
# Epoch 38/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4498 - accuracy: 0.7667 - val_loss: 0.4438 - val_accuracy: 0.7724
# Epoch 39/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4504 - accuracy: 0.7675 - val_loss: 0.4422 - val_accuracy: 0.7721
# Epoch 40/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4493 - accuracy: 0.7673 - val_loss: 0.4424 - val_accuracy: 0.7738
# Epoch 41/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4478 - accuracy: 0.7684 - val_loss: 0.4413 - val_accuracy: 0.7736
# Epoch 42/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4470 - accuracy: 0.7689 - val_loss: 0.4394 - val_accuracy: 0.7747
# Epoch 43/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4477 - accuracy: 0.7691 - val_loss: 0.4421 - val_accuracy: 0.7729
# Epoch 44/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4483 - accuracy: 0.7687 - val_loss: 0.4407 - val_accuracy: 0.7740
# Epoch 45/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4458 - accuracy: 0.7698 - val_loss: 0.4424 - val_accuracy: 0.7743
# Epoch 46/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4454 - accuracy: 0.7698 - val_loss: 0.4394 - val_accuracy: 0.7754
# Epoch 47/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4454 - accuracy: 0.7705 - val_loss: 0.4379 - val_accuracy: 0.7754
# Epoch 48/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4455 - accuracy: 0.7707 - val_loss: 0.4395 - val_accuracy: 0.7748
# Epoch 49/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4451 - accuracy: 0.7710 - val_loss: 0.4418 - val_accuracy: 0.7749
# Epoch 50/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4436 - accuracy: 0.7713 - val_loss: 0.4375 - val_accuracy: 0.7758
# Epoch 51/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4434 - accuracy: 0.7721 - val_loss: 0.4431 - val_accuracy: 0.7745
# Epoch 52/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4437 - accuracy: 0.7718 - val_loss: 0.4456 - val_accuracy: 0.7755
# Epoch 53/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4439 - accuracy: 0.7720 - val_loss: 0.4404 - val_accuracy: 0.7741
# Epoch 54/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4431 - accuracy: 0.7724 - val_loss: 0.4383 - val_accuracy: 0.7766
# Epoch 55/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4439 - accuracy: 0.7722 - val_loss: 0.4375 - val_accuracy: 0.7760
# Epoch 56/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4413 - accuracy: 0.7727 - val_loss: 0.4361 - val_accuracy: 0.7770
# Epoch 57/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4413 - accuracy: 0.7733 - val_loss: 0.4382 - val_accuracy: 0.7758
# Epoch 58/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4412 - accuracy: 0.7732 - val_loss: 0.4357 - val_accuracy: 0.7763
# Epoch 59/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4408 - accuracy: 0.7736 - val_loss: 0.4340 - val_accuracy: 0.7769
# Epoch 60/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4412 - accuracy: 0.7737 - val_loss: 0.4386 - val_accuracy: 0.7742
# Epoch 61/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4410 - accuracy: 0.7736 - val_loss: 0.4365 - val_accuracy: 0.7757
# Epoch 62/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4409 - accuracy: 0.7739 - val_loss: 0.4334 - val_accuracy: 0.7774
# Epoch 63/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4405 - accuracy: 0.7742 - val_loss: 0.4328 - val_accuracy: 0.7783
# Epoch 64/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4387 - accuracy: 0.7746 - val_loss: 0.4348 - val_accuracy: 0.7768
# Epoch 65/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4392 - accuracy: 0.7748 - val_loss: 0.4361 - val_accuracy: 0.7767
# Epoch 66/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4407 - accuracy: 0.7746 - val_loss: 0.4398 - val_accuracy: 0.7759
# Epoch 67/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4399 - accuracy: 0.7747 - val_loss: 0.4374 - val_accuracy: 0.7771
# Epoch 68/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4380 - accuracy: 0.7751 - val_loss: 0.4334 - val_accuracy: 0.7779
# Epoch 69/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4375 - accuracy: 0.7756 - val_loss: 0.4344 - val_accuracy: 0.7772
# Epoch 70/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4384 - accuracy: 0.7754 - val_loss: 0.4315 - val_accuracy: 0.7786
# Epoch 71/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4373 - accuracy: 0.7757 - val_loss: 0.4328 - val_accuracy: 0.7785
# Epoch 72/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4375 - accuracy: 0.7757 - val_loss: 0.4357 - val_accuracy: 0.7765
# Epoch 73/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4389 - accuracy: 0.7756 - val_loss: 0.4363 - val_accuracy: 0.7775
# Epoch 74/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4370 - accuracy: 0.7761 - val_loss: 0.4341 - val_accuracy: 0.7780
# Epoch 75/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4363 - accuracy: 0.7758 - val_loss: 0.4321 - val_accuracy: 0.7788
# Epoch 76/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4361 - accuracy: 0.7762 - val_loss: 0.4323 - val_accuracy: 0.7781
# Epoch 77/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4366 - accuracy: 0.7757 - val_loss: 0.4322 - val_accuracy: 0.7793
# Epoch 78/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4371 - accuracy: 0.7760 - val_loss: 0.4332 - val_accuracy: 0.7777
# Epoch 79/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4359 - accuracy: 0.7764 - val_loss: 0.4308 - val_accuracy: 0.7791
# Epoch 80/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4354 - accuracy: 0.7767 - val_loss: 0.4300 - val_accuracy: 0.7798
# Epoch 81/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4361 - accuracy: 0.7766 - val_loss: 0.4308 - val_accuracy: 0.7780
# Epoch 82/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4349 - accuracy: 0.7769 - val_loss: 0.4314 - val_accuracy: 0.7789
# Epoch 83/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4355 - accuracy: 0.7768 - val_loss: 0.4290 - val_accuracy: 0.7804
# Epoch 84/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4348 - accuracy: 0.7766 - val_loss: 0.4299 - val_accuracy: 0.7795
# Epoch 85/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4343 - accuracy: 0.7773 - val_loss: 0.4288 - val_accuracy: 0.7809
# Epoch 86/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4353 - accuracy: 0.7773 - val_loss: 0.4295 - val_accuracy: 0.7804
# Epoch 87/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4335 - accuracy: 0.7774 - val_loss: 0.4293 - val_accuracy: 0.7799
# Epoch 88/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4338 - accuracy: 0.7774 - val_loss: 0.4303 - val_accuracy: 0.7807
# Epoch 89/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4351 - accuracy: 0.7772 - val_loss: 0.4318 - val_accuracy: 0.7781
# Epoch 90/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4337 - accuracy: 0.7777 - val_loss: 0.4294 - val_accuracy: 0.7796
# Epoch 91/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4332 - accuracy: 0.7778 - val_loss: 0.4301 - val_accuracy: 0.7793
# Epoch 92/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4329 - accuracy: 0.7780 - val_loss: 0.4359 - val_accuracy: 0.7803
# Epoch 93/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4342 - accuracy: 0.7779 - val_loss: 0.4295 - val_accuracy: 0.7810
# Epoch 94/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4330 - accuracy: 0.7780 - val_loss: 0.4282 - val_accuracy: 0.7809
# Epoch 95/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4321 - accuracy: 0.7781 - val_loss: 0.4307 - val_accuracy: 0.7791
# Epoch 96/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4337 - accuracy: 0.7780 - val_loss: 0.4298 - val_accuracy: 0.7809
# Epoch 97/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4336 - accuracy: 0.7784 - val_loss: 0.4300 - val_accuracy: 0.7801
# Epoch 98/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4322 - accuracy: 0.7782 - val_loss: 0.4290 - val_accuracy: 0.7789
# Epoch 99/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4314 - accuracy: 0.7785 - val_loss: 0.4290 - val_accuracy: 0.7818
# Epoch 100/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4323 - accuracy: 0.7784 - val_loss: 0.4359 - val_accuracy: 0.7803
# Epoch 101/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4320 - accuracy: 0.7786 - val_loss: 0.4306 - val_accuracy: 0.7784
# Epoch 102/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4314 - accuracy: 0.7788 - val_loss: 0.4286 - val_accuracy: 0.7799
# Epoch 103/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4318 - accuracy: 0.7788 - val_loss: 0.4299 - val_accuracy: 0.7815
# Epoch 104/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4337 - accuracy: 0.7786 - val_loss: 0.4359 - val_accuracy: 0.7808
# Epoch 105/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4319 - accuracy: 0.7790 - val_loss: 0.4317 - val_accuracy: 0.7790
# Epoch 106/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4307 - accuracy: 0.7793 - val_loss: 0.4321 - val_accuracy: 0.7768
# Epoch 107/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4321 - accuracy: 0.7789 - val_loss: 0.4281 - val_accuracy: 0.7824
# Epoch 108/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4307 - accuracy: 0.7792 - val_loss: 0.4280 - val_accuracy: 0.7806
# Epoch 109/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4303 - accuracy: 0.7797 - val_loss: 0.4306 - val_accuracy: 0.7829
# Epoch 110/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4296 - accuracy: 0.7798 - val_loss: 0.4325 - val_accuracy: 0.7815
# Epoch 111/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4303 - accuracy: 0.7799 - val_loss: 0.4282 - val_accuracy: 0.7829
# Epoch 112/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4292 - accuracy: 0.7798 - val_loss: 0.4304 - val_accuracy: 0.7807
# Epoch 113/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4293 - accuracy: 0.7799 - val_loss: 0.4301 - val_accuracy: 0.7823
# Epoch 114/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4302 - accuracy: 0.7796 - val_loss: 0.4309 - val_accuracy: 0.7796
# Epoch 115/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4291 - accuracy: 0.7802 - val_loss: 0.4300 - val_accuracy: 0.7812
# Epoch 116/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4297 - accuracy: 0.7803 - val_loss: 0.4285 - val_accuracy: 0.7815
# Epoch 117/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4284 - accuracy: 0.7806 - val_loss: 0.4296 - val_accuracy: 0.7826
# Epoch 118/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4291 - accuracy: 0.7802 - val_loss: 0.4298 - val_accuracy: 0.7838
# Epoch 119/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4286 - accuracy: 0.7806 - val_loss: 0.4327 - val_accuracy: 0.7819
# Epoch 120/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4289 - accuracy: 0.7806 - val_loss: 0.4292 - val_accuracy: 0.7801
# Epoch 121/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4285 - accuracy: 0.7809 - val_loss: 0.4302 - val_accuracy: 0.7794
# Epoch 122/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4279 - accuracy: 0.7812 - val_loss: 0.4316 - val_accuracy: 0.7770
# Epoch 123/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4285 - accuracy: 0.7808 - val_loss: 0.4281 - val_accuracy: 0.7813
# Epoch 124/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4276 - accuracy: 0.7808 - val_loss: 0.4321 - val_accuracy: 0.7794
# Epoch 125/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4269 - accuracy: 0.7813 - val_loss: 0.4297 - val_accuracy: 0.7821
# Epoch 126/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4283 - accuracy: 0.7812 - val_loss: 0.4292 - val_accuracy: 0.7812
# Epoch 127/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4278 - accuracy: 0.7816 - val_loss: 0.4287 - val_accuracy: 0.7800
# Epoch 128/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4283 - accuracy: 0.7815 - val_loss: 0.4315 - val_accuracy: 0.7804
# Epoch 129/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4277 - accuracy: 0.7816 - val_loss: 0.4348 - val_accuracy: 0.7836
# Epoch 130/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4278 - accuracy: 0.7814 - val_loss: 0.4294 - val_accuracy: 0.7784
# Epoch 131/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4264 - accuracy: 0.7821 - val_loss: 0.4303 - val_accuracy: 0.7835
# Epoch 132/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4261 - accuracy: 0.7823 - val_loss: 0.4268 - val_accuracy: 0.7823
# Epoch 133/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4259 - accuracy: 0.7822 - val_loss: 0.4290 - val_accuracy: 0.7802
# Epoch 134/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4258 - accuracy: 0.7826 - val_loss: 0.4331 - val_accuracy: 0.7820
# Epoch 135/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4262 - accuracy: 0.7819 - val_loss: 0.4295 - val_accuracy: 0.7827
# Epoch 136/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4252 - accuracy: 0.7828 - val_loss: 0.4313 - val_accuracy: 0.7834
# Epoch 137/140
# 24/24 [==============================] - 59s 2s/step - loss: 0.4248 - accuracy: 0.7830 - val_loss: 0.4331 - val_accuracy: 0.7752
# Epoch 138/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4264 - accuracy: 0.7826 - val_loss: 0.4288 - val_accuracy: 0.7816
# Epoch 139/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4244 - accuracy: 0.7831 - val_loss: 0.4266 - val_accuracy: 0.7830
# Epoch 140/140
# 24/24 [==============================] - 58s 2s/step - loss: 0.4248 - accuracy: 0.7831 - val_loss: 0.4282 - val_accuracy: 0.7837

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 20s 6ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 8188.573287010193

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00356549],
#        [0.00307724],
#        [0.001667  ],
#        ...,
#        [0.04758344],
#        [0.05024222],
#        [0.05211873]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1429290055975475
# 0.23141610411882585
# 0.3780595265266404
# 0.28305956690845724

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 99s 7ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.61018203]
# [0.8234444]
# total acc [0.78341584]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3892\725781306.py in <module>
# ----> 1 tf.config.experimental.get_memory_info('GPU:0')
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\config.py in get_memory_info(device)
#     574     ValueError: Memory statistics not tracked, like '"CPU:0"'.
#     575   """
# --> 576   return context.context().get_memory_info(device)
#     577
#     578
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in get_memory_info(self, dev)
#    1628     self._initialize_physical_devices()
#    1629     self.ensure_initialized()
# -> 1630     return pywrap_tfe.TFE_GetMemoryInfo(self._context_handle, dev)
#    1631
#    1632   def reset_memory_stats(self, dev):
#
# ValueError: No matching devices found for 'GPU:0'
