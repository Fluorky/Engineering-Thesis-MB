# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1a380003040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1a30b0c2040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam()
model_gru.compile(loss='MSE', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           209664
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=80,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/80
# 24/24 [==============================] - 29s 415ms/step - loss: 0.1879 - accuracy: 0.7382 - val_loss: 0.1715 - val_accuracy: 0.7529
# Epoch 2/80
# 24/24 [==============================] - 9s 376ms/step - loss: 0.1721 - accuracy: 0.7394 - val_loss: 0.1635 - val_accuracy: 0.7536
# Epoch 3/80
# 24/24 [==============================] - 9s 387ms/step - loss: 0.1685 - accuracy: 0.7408 - val_loss: 0.1616 - val_accuracy: 0.7551
# Epoch 4/80
# 24/24 [==============================] - 9s 393ms/step - loss: 0.1645 - accuracy: 0.7480 - val_loss: 0.1628 - val_accuracy: 0.7439
# Epoch 5/80
# 24/24 [==============================] - 10s 429ms/step - loss: 0.1603 - accuracy: 0.7537 - val_loss: 0.1560 - val_accuracy: 0.7622
# Epoch 6/80
# 24/24 [==============================] - 10s 437ms/step - loss: 0.1580 - accuracy: 0.7573 - val_loss: 0.1551 - val_accuracy: 0.7636
# Epoch 7/80
# 24/24 [==============================] - 11s 446ms/step - loss: 0.1564 - accuracy: 0.7601 - val_loss: 0.1533 - val_accuracy: 0.7676
# Epoch 8/80
# 24/24 [==============================] - 9s 392ms/step - loss: 0.1546 - accuracy: 0.7635 - val_loss: 0.1542 - val_accuracy: 0.7689
# Epoch 9/80
# 24/24 [==============================] - 10s 401ms/step - loss: 0.1534 - accuracy: 0.7654 - val_loss: 0.1500 - val_accuracy: 0.7702
# Epoch 10/80
# 24/24 [==============================] - 10s 400ms/step - loss: 0.1521 - accuracy: 0.7672 - val_loss: 0.1497 - val_accuracy: 0.7726
# Epoch 11/80
# 24/24 [==============================] - 10s 407ms/step - loss: 0.1520 - accuracy: 0.7679 - val_loss: 0.1491 - val_accuracy: 0.7713
# Epoch 12/80
# 24/24 [==============================] - 10s 413ms/step - loss: 0.1506 - accuracy: 0.7693 - val_loss: 0.1485 - val_accuracy: 0.7733
# Epoch 13/80
# 24/24 [==============================] - 10s 410ms/step - loss: 0.1501 - accuracy: 0.7703 - val_loss: 0.1483 - val_accuracy: 0.7731
# Epoch 14/80
# 24/24 [==============================] - 10s 415ms/step - loss: 0.1500 - accuracy: 0.7709 - val_loss: 0.1481 - val_accuracy: 0.7745
# Epoch 15/80
# 24/24 [==============================] - 10s 420ms/step - loss: 0.1497 - accuracy: 0.7719 - val_loss: 0.1477 - val_accuracy: 0.7751
# Epoch 16/80
# 24/24 [==============================] - 10s 418ms/step - loss: 0.1483 - accuracy: 0.7735 - val_loss: 0.1462 - val_accuracy: 0.7777
# Epoch 17/80
# 24/24 [==============================] - 10s 425ms/step - loss: 0.1488 - accuracy: 0.7735 - val_loss: 0.1502 - val_accuracy: 0.7780
# Epoch 18/80
# 24/24 [==============================] - 10s 427ms/step - loss: 0.1484 - accuracy: 0.7744 - val_loss: 0.1481 - val_accuracy: 0.7735
# Epoch 19/80
# 24/24 [==============================] - 10s 422ms/step - loss: 0.1475 - accuracy: 0.7760 - val_loss: 0.1469 - val_accuracy: 0.7801
# Epoch 20/80
# 24/24 [==============================] - 10s 423ms/step - loss: 0.1478 - accuracy: 0.7764 - val_loss: 0.1453 - val_accuracy: 0.7796
# Epoch 21/80
# 24/24 [==============================] - 10s 430ms/step - loss: 0.1469 - accuracy: 0.7775 - val_loss: 0.1452 - val_accuracy: 0.7795
# Epoch 22/80
# 24/24 [==============================] - 10s 422ms/step - loss: 0.1461 - accuracy: 0.7781 - val_loss: 0.1468 - val_accuracy: 0.7779
# Epoch 23/80
# 24/24 [==============================] - 9s 369ms/step - loss: 0.1460 - accuracy: 0.7785 - val_loss: 0.1462 - val_accuracy: 0.7791
# Epoch 24/80
# 24/24 [==============================] - 8s 336ms/step - loss: 0.1457 - accuracy: 0.7791 - val_loss: 0.1474 - val_accuracy: 0.7778
# Epoch 25/80
# 24/24 [==============================] - 8s 339ms/step - loss: 0.1457 - accuracy: 0.7791 - val_loss: 0.1459 - val_accuracy: 0.7760
# Epoch 26/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1452 - accuracy: 0.7797 - val_loss: 0.1452 - val_accuracy: 0.7782
# Epoch 27/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1448 - accuracy: 0.7799 - val_loss: 0.1441 - val_accuracy: 0.7808
# Epoch 28/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1447 - accuracy: 0.7806 - val_loss: 0.1439 - val_accuracy: 0.7820
# Epoch 29/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1441 - accuracy: 0.7809 - val_loss: 0.1446 - val_accuracy: 0.7808
# Epoch 30/80
# 24/24 [==============================] - 8s 335ms/step - loss: 0.1444 - accuracy: 0.7806 - val_loss: 0.1450 - val_accuracy: 0.7798
# Epoch 31/80
# 24/24 [==============================] - 8s 335ms/step - loss: 0.1444 - accuracy: 0.7807 - val_loss: 0.1437 - val_accuracy: 0.7825
# Epoch 32/80
# 24/24 [==============================] - 8s 336ms/step - loss: 0.1445 - accuracy: 0.7807 - val_loss: 0.1478 - val_accuracy: 0.7778
# Epoch 33/80
# 24/24 [==============================] - 8s 340ms/step - loss: 0.1447 - accuracy: 0.7803 - val_loss: 0.1446 - val_accuracy: 0.7812
# Epoch 34/80
# 24/24 [==============================] - 8s 341ms/step - loss: 0.1440 - accuracy: 0.7816 - val_loss: 0.1441 - val_accuracy: 0.7836
# Epoch 35/80
# 24/24 [==============================] - 8s 349ms/step - loss: 0.1438 - accuracy: 0.7818 - val_loss: 0.1428 - val_accuracy: 0.7835
# Epoch 36/80
# 24/24 [==============================] - 9s 357ms/step - loss: 0.1432 - accuracy: 0.7825 - val_loss: 0.1435 - val_accuracy: 0.7819
# Epoch 37/80
# 24/24 [==============================] - 9s 361ms/step - loss: 0.1430 - accuracy: 0.7831 - val_loss: 0.1442 - val_accuracy: 0.7819
# Epoch 38/80
# 24/24 [==============================] - 8s 346ms/step - loss: 0.1429 - accuracy: 0.7829 - val_loss: 0.1435 - val_accuracy: 0.7845
# Epoch 39/80
# 24/24 [==============================] - 9s 356ms/step - loss: 0.1423 - accuracy: 0.7841 - val_loss: 0.1466 - val_accuracy: 0.7824
# Epoch 40/80
# 24/24 [==============================] - 9s 380ms/step - loss: 0.1426 - accuracy: 0.7835 - val_loss: 0.1434 - val_accuracy: 0.7846
# Epoch 41/80
# 24/24 [==============================] - 9s 357ms/step - loss: 0.1425 - accuracy: 0.7843 - val_loss: 0.1469 - val_accuracy: 0.7823
# Epoch 42/80
# 24/24 [==============================] - 8s 342ms/step - loss: 0.1430 - accuracy: 0.7834 - val_loss: 0.1430 - val_accuracy: 0.7833
# Epoch 43/80
# 24/24 [==============================] - 8s 343ms/step - loss: 0.1421 - accuracy: 0.7841 - val_loss: 0.1432 - val_accuracy: 0.7832
# Epoch 44/80
# 24/24 [==============================] - 8s 341ms/step - loss: 0.1418 - accuracy: 0.7845 - val_loss: 0.1433 - val_accuracy: 0.7849
# Epoch 45/80
# 24/24 [==============================] - 8s 341ms/step - loss: 0.1416 - accuracy: 0.7850 - val_loss: 0.1432 - val_accuracy: 0.7841
# Epoch 46/80
# 24/24 [==============================] - 8s 342ms/step - loss: 0.1419 - accuracy: 0.7845 - val_loss: 0.1435 - val_accuracy: 0.7808
# Epoch 47/80
# 24/24 [==============================] - 8s 341ms/step - loss: 0.1412 - accuracy: 0.7854 - val_loss: 0.1438 - val_accuracy: 0.7789
# Epoch 48/80
# 24/24 [==============================] - 8s 339ms/step - loss: 0.1413 - accuracy: 0.7854 - val_loss: 0.1435 - val_accuracy: 0.7814
# Epoch 49/80
# 24/24 [==============================] - 8s 343ms/step - loss: 0.1413 - accuracy: 0.7858 - val_loss: 0.1426 - val_accuracy: 0.7828
# Epoch 50/80
# 24/24 [==============================] - 8s 353ms/step - loss: 0.1412 - accuracy: 0.7857 - val_loss: 0.1423 - val_accuracy: 0.7843
# Epoch 51/80
# 24/24 [==============================] - 9s 357ms/step - loss: 0.1409 - accuracy: 0.7859 - val_loss: 0.1459 - val_accuracy: 0.7764
# Epoch 52/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1414 - accuracy: 0.7858 - val_loss: 0.1456 - val_accuracy: 0.7828
# Epoch 53/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1414 - accuracy: 0.7851 - val_loss: 0.1419 - val_accuracy: 0.7838
# Epoch 54/80
# 24/24 [==============================] - 8s 336ms/step - loss: 0.1407 - accuracy: 0.7864 - val_loss: 0.1445 - val_accuracy: 0.7768
# Epoch 55/80
# 24/24 [==============================] - 8s 337ms/step - loss: 0.1408 - accuracy: 0.7861 - val_loss: 0.1448 - val_accuracy: 0.7793
# Epoch 56/80
# 24/24 [==============================] - 8s 336ms/step - loss: 0.1405 - accuracy: 0.7866 - val_loss: 0.1427 - val_accuracy: 0.7835
# Epoch 57/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1411 - accuracy: 0.7861 - val_loss: 0.1435 - val_accuracy: 0.7834
# Epoch 58/80
# 24/24 [==============================] - 8s 337ms/step - loss: 0.1412 - accuracy: 0.7857 - val_loss: 0.1440 - val_accuracy: 0.7806
# Epoch 59/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1407 - accuracy: 0.7863 - val_loss: 0.1438 - val_accuracy: 0.7809
# Epoch 60/80
# 24/24 [==============================] - 8s 336ms/step - loss: 0.1399 - accuracy: 0.7875 - val_loss: 0.1434 - val_accuracy: 0.7816
# Epoch 61/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1398 - accuracy: 0.7871 - val_loss: 0.1423 - val_accuracy: 0.7863
# Epoch 62/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1399 - accuracy: 0.7874 - val_loss: 0.1424 - val_accuracy: 0.7846
# Epoch 63/80
# 24/24 [==============================] - 8s 337ms/step - loss: 0.1397 - accuracy: 0.7880 - val_loss: 0.1430 - val_accuracy: 0.7834
# Epoch 64/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1403 - accuracy: 0.7870 - val_loss: 0.1423 - val_accuracy: 0.7868
# Epoch 65/80
# 24/24 [==============================] - 8s 337ms/step - loss: 0.1397 - accuracy: 0.7877 - val_loss: 0.1435 - val_accuracy: 0.7840
# Epoch 66/80
# 24/24 [==============================] - 8s 336ms/step - loss: 0.1395 - accuracy: 0.7882 - val_loss: 0.1446 - val_accuracy: 0.7835
# Epoch 67/80
# 24/24 [==============================] - 8s 337ms/step - loss: 0.1406 - accuracy: 0.7874 - val_loss: 0.1427 - val_accuracy: 0.7860
# Epoch 68/80
# 24/24 [==============================] - 8s 336ms/step - loss: 0.1395 - accuracy: 0.7882 - val_loss: 0.1426 - val_accuracy: 0.7839
# Epoch 69/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1391 - accuracy: 0.7884 - val_loss: 0.1427 - val_accuracy: 0.7818
# Epoch 70/80
# 24/24 [==============================] - 8s 340ms/step - loss: 0.1397 - accuracy: 0.7877 - val_loss: 0.1428 - val_accuracy: 0.7848
# Epoch 71/80
# 24/24 [==============================] - 8s 339ms/step - loss: 0.1391 - accuracy: 0.7888 - val_loss: 0.1419 - val_accuracy: 0.7846
# Epoch 72/80
# 24/24 [==============================] - 8s 340ms/step - loss: 0.1388 - accuracy: 0.7892 - val_loss: 0.1428 - val_accuracy: 0.7832
# Epoch 73/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1384 - accuracy: 0.7895 - val_loss: 0.1428 - val_accuracy: 0.7817
# Epoch 74/80
# 24/24 [==============================] - 8s 336ms/step - loss: 0.1385 - accuracy: 0.7893 - val_loss: 0.1423 - val_accuracy: 0.7840
# Epoch 75/80
# 24/24 [==============================] - 8s 338ms/step - loss: 0.1385 - accuracy: 0.7899 - val_loss: 0.1426 - val_accuracy: 0.7834
# Epoch 76/80
# 24/24 [==============================] - 8s 337ms/step - loss: 0.1381 - accuracy: 0.7904 - val_loss: 0.1423 - val_accuracy: 0.7856
# Epoch 77/80
# 24/24 [==============================] - 8s 337ms/step - loss: 0.1381 - accuracy: 0.7900 - val_loss: 0.1422 - val_accuracy: 0.7848
# Epoch 78/80
# 24/24 [==============================] - 8s 335ms/step - loss: 0.1378 - accuracy: 0.7908 - val_loss: 0.1422 - val_accuracy: 0.7850
# Epoch 79/80
# 24/24 [==============================] - 8s 335ms/step - loss: 0.1376 - accuracy: 0.7907 - val_loss: 0.1433 - val_accuracy: 0.7836
# Epoch 80/80
# 24/24 [==============================] - 8s 335ms/step - loss: 0.1380 - accuracy: 0.7906 - val_loss: 0.1432 - val_accuracy: 0.7855

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 30s 10ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 746.5664157867432

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00322043],
#        [0.00619752],
#        [0.00312946],
#        ...,
#        [0.03249634],
#        [0.03333996],
#        [0.03509306]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14322946355177119
# 0.22982220675016685
# 0.3784566864936742
# 0.27416015858101767

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 131s 9ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.62425548]
# [0.82818794]
# total acc [0.78936052]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1100577024, 'peak': 9501011968}
