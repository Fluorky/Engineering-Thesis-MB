# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2966f7a1040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x296e3852040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2]),activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True,activation='relu'),
    keras.layers.GRU(units=32,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='MeanSquaredError', optimizer='sgd',metrics=['AUC'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 593s 197ms/step - loss: 0.1928 - auc: 0.5007 - val_loss: 0.1861 - val_auc: 0.5177
# Epoch 2/140
# 2971/2971 [==============================] - 564s 190ms/step - loss: 0.1927 - auc: 0.5173 - val_loss: 0.1860 - val_auc: 0.5001
# Epoch 3/140
# 2971/2971 [==============================] - 559s 188ms/step - loss: 0.1926 - auc: 0.5337 - val_loss: 0.1860 - val_auc: 0.5140
# Epoch 4/140
# 2971/2971 [==============================] - 556s 187ms/step - loss: 0.1925 - auc: 0.5520 - val_loss: 0.1860 - val_auc: 0.5410
# Epoch 5/140
# 2971/2971 [==============================] - 559s 188ms/step - loss: 0.1924 - auc: 0.5658 - val_loss: 0.1859 - val_auc: 0.5990
# Epoch 6/140
# 2971/2971 [==============================] - 561s 189ms/step - loss: 0.1923 - auc: 0.5829 - val_loss: 0.1858 - val_auc: 0.5816
# Epoch 7/140
# 2971/2971 [==============================] - 559s 188ms/step - loss: 0.1921 - auc: 0.6062 - val_loss: 0.1855 - val_auc: 0.5991
# Epoch 8/140
# 2971/2971 [==============================] - 560s 189ms/step - loss: 0.1918 - auc: 0.6205 - val_loss: 0.1851 - val_auc: 0.6446
# Epoch 9/140
# 2971/2971 [==============================] - 559s 188ms/step - loss: 0.1913 - auc: 0.6484 - val_loss: 0.1846 - val_auc: 0.6568
# Epoch 10/140
# 2971/2971 [==============================] - 565s 190ms/step - loss: 0.1903 - auc: 0.6655 - val_loss: 0.1835 - val_auc: 0.6752
# Epoch 11/140
# 2971/2971 [==============================] - 565s 190ms/step - loss: 0.1884 - auc: 0.6837 - val_loss: 0.1811 - val_auc: 0.6873
# Epoch 12/140
# 2971/2971 [==============================] - 563s 190ms/step - loss: 0.1844 - auc: 0.6897 - val_loss: 0.1761 - val_auc: 0.6961
# Epoch 13/140
# 2971/2971 [==============================] - 567s 191ms/step - loss: 0.1785 - auc: 0.7009 - val_loss: 0.1709 - val_auc: 0.7105
# Epoch 14/140
# 2971/2971 [==============================] - 566s 191ms/step - loss: 0.1737 - auc: 0.7169 - val_loss: 0.1664 - val_auc: 0.7269
# Epoch 15/140
# 2971/2971 [==============================] - 570s 192ms/step - loss: 0.1704 - auc: 0.7291 - val_loss: 0.1644 - val_auc: 0.7341
# Epoch 16/140
# 2971/2971 [==============================] - 570s 192ms/step - loss: 0.1689 - auc: 0.7343 - val_loss: 0.1633 - val_auc: 0.7370
# Epoch 17/140
# 2971/2971 [==============================] - 565s 190ms/step - loss: 0.1681 - auc: 0.7372 - val_loss: 0.1628 - val_auc: 0.7393
# Epoch 18/140
# 2971/2971 [==============================] - 567s 191ms/step - loss: 0.1674 - auc: 0.7398 - val_loss: 0.1622 - val_auc: 0.7415
# Epoch 19/140
# 2971/2971 [==============================] - 570s 192ms/step - loss: 0.1667 - auc: 0.7428 - val_loss: 0.1620 - val_auc: 0.7433
# Epoch 20/140
# 2971/2971 [==============================] - 566s 191ms/step - loss: 0.1659 - auc: 0.7462 - val_loss: 0.1618 - val_auc: 0.7450
# Epoch 21/140
# 2971/2971 [==============================] - 567s 191ms/step - loss: 0.1650 - auc: 0.7498 - val_loss: 0.1610 - val_auc: 0.7481
# Epoch 22/140
# 2971/2971 [==============================] - 568s 191ms/step - loss: 0.1640 - auc: 0.7540 - val_loss: 0.1603 - val_auc: 0.7511
# Epoch 23/140
# 2971/2971 [==============================] - 569s 192ms/step - loss: 0.1630 - auc: 0.7582 - val_loss: 0.1602 - val_auc: 0.7532
# Epoch 24/140
# 2971/2971 [==============================] - 569s 192ms/step - loss: 0.1619 - auc: 0.7627 - val_loss: 0.1590 - val_auc: 0.7574
# Epoch 25/140
# 2971/2971 [==============================] - 571s 192ms/step - loss: 0.1610 - auc: 0.7665 - val_loss: 0.1589 - val_auc: 0.7603
# Epoch 26/140
# 2971/2971 [==============================] - 573s 193ms/step - loss: 0.1600 - auc: 0.7702 - val_loss: 0.1574 - val_auc: 0.7637
# Epoch 27/140
# 2971/2971 [==============================] - 572s 193ms/step - loss: 0.1592 - auc: 0.7735 - val_loss: 0.1594 - val_auc: 0.7644
# Epoch 28/140
# 2971/2971 [==============================] - 570s 192ms/step - loss: 0.1585 - auc: 0.7764 - val_loss: 0.1593 - val_auc: 0.7722
# Epoch 29/140
# 2971/2971 [==============================] - 583s 196ms/step - loss: 0.1578 - auc: 0.7789 - val_loss: 0.1546 - val_auc: 0.7749
# Epoch 30/140
# 2971/2971 [==============================] - 570s 192ms/step - loss: 0.1572 - auc: 0.7811 - val_loss: 0.1541 - val_auc: 0.7773
# Epoch 31/140
# 2971/2971 [==============================] - 572s 192ms/step - loss: 0.1566 - auc: 0.7834 - val_loss: 0.1540 - val_auc: 0.7781
# Epoch 32/140
# 2971/2971 [==============================] - 572s 193ms/step - loss: 0.1561 - auc: 0.7850 - val_loss: 0.1529 - val_auc: 0.7813
# Epoch 33/140
# 2971/2971 [==============================] - 571s 192ms/step - loss: 0.1557 - auc: 0.7864 - val_loss: 0.1527 - val_auc: 0.7822
# Epoch 34/140
# 2971/2971 [==============================] - 573s 193ms/step - loss: 0.1551 - auc: 0.7884 - val_loss: 0.1529 - val_auc: 0.7846
# Epoch 35/140
# 2971/2971 [==============================] - 574s 193ms/step - loss: 0.1546 - auc: 0.7899 - val_loss: 0.1516 - val_auc: 0.7860
# Epoch 36/140
# 2971/2971 [==============================] - 573s 193ms/step - loss: 0.1543 - auc: 0.7912 - val_loss: 0.1516 - val_auc: 0.7870
# Epoch 37/140
# 2971/2971 [==============================] - 574s 193ms/step - loss: 0.1538 - auc: 0.7928 - val_loss: 0.1549 - val_auc: 0.7906
# Epoch 38/140
# 2971/2971 [==============================] - 578s 195ms/step - loss: 0.1535 - auc: 0.7938 - val_loss: 0.1503 - val_auc: 0.7908
# Epoch 39/140
# 2971/2971 [==============================] - 575s 193ms/step - loss: 0.1531 - auc: 0.7951 - val_loss: 0.1518 - val_auc: 0.7928
# Epoch 40/140
# 2971/2971 [==============================] - 577s 194ms/step - loss: 0.1528 - auc: 0.7960 - val_loss: 0.1501 - val_auc: 0.7916
# Epoch 41/140
# 2971/2971 [==============================] - 577s 194ms/step - loss: 0.1524 - auc: 0.7972 - val_loss: 0.1508 - val_auc: 0.7919
# Epoch 42/140
# 2971/2971 [==============================] - 575s 194ms/step - loss: 0.1521 - auc: 0.7980 - val_loss: 0.1502 - val_auc: 0.7956
# Epoch 43/140
# 2971/2971 [==============================] - 579s 195ms/step - loss: 0.1520 - auc: 0.7985 - val_loss: 0.1499 - val_auc: 0.7951
# Epoch 44/140
# 2971/2971 [==============================] - 579s 195ms/step - loss: 0.1516 - auc: 0.7998 - val_loss: 0.1489 - val_auc: 0.7980
# Epoch 45/140
# 2971/2971 [==============================] - 581s 195ms/step - loss: 0.1512 - auc: 0.8010 - val_loss: 0.1498 - val_auc: 0.7983
# Epoch 46/140
# 2971/2971 [==============================] - 581s 196ms/step - loss: 0.1511 - auc: 0.8014 - val_loss: 0.1497 - val_auc: 0.7973
# Epoch 47/140
# 2971/2971 [==============================] - 584s 197ms/step - loss: 0.1508 - auc: 0.8024 - val_loss: 0.1486 - val_auc: 0.7989
# Epoch 48/140
# 2971/2971 [==============================] - 583s 196ms/step - loss: 0.1506 - auc: 0.8031 - val_loss: 0.1486 - val_auc: 0.7994
# Epoch 49/140
# 2971/2971 [==============================] - 582s 196ms/step - loss: 0.1504 - auc: 0.8039 - val_loss: 0.1478 - val_auc: 0.7994
# Epoch 50/140
# 2971/2971 [==============================] - 586s 197ms/step - loss: 0.1501 - auc: 0.8046 - val_loss: 0.1494 - val_auc: 0.8000
# Epoch 51/140
# 2971/2971 [==============================] - 590s 198ms/step - loss: 0.1500 - auc: 0.8050 - val_loss: 0.1512 - val_auc: 0.7961
# Epoch 52/140
# 2971/2971 [==============================] - 588s 198ms/step - loss: 0.1497 - auc: 0.8061 - val_loss: 0.1521 - val_auc: 0.8026
# Epoch 53/140
# 2971/2971 [==============================] - 590s 199ms/step - loss: 0.1496 - auc: 0.8067 - val_loss: 0.1467 - val_auc: 0.8039
# Epoch 54/140
# 2971/2971 [==============================] - 594s 200ms/step - loss: 0.1494 - auc: 0.8070 - val_loss: 0.1466 - val_auc: 0.8040
# Epoch 55/140
# 2971/2971 [==============================] - 591s 199ms/step - loss: 0.1491 - auc: 0.8080 - val_loss: 0.1470 - val_auc: 0.8024
# Epoch 56/140
# 2971/2971 [==============================] - 594s 200ms/step - loss: 0.1490 - auc: 0.8082 - val_loss: 0.1482 - val_auc: 0.8034
# Epoch 57/140
# 2971/2971 [==============================] - 598s 201ms/step - loss: 0.1489 - auc: 0.8088 - val_loss: 0.1490 - val_auc: 0.8026
# Epoch 58/140
# 2971/2971 [==============================] - 593s 200ms/step - loss: 0.1487 - auc: 0.8095 - val_loss: 0.1474 - val_auc: 0.8012
# Epoch 59/140
# 2971/2971 [==============================] - 585s 197ms/step - loss: 0.1485 - auc: 0.8101 - val_loss: 0.1477 - val_auc: 0.8055
# Epoch 60/140
# 2971/2971 [==============================] - 588s 198ms/step - loss: 0.1483 - auc: 0.8106 - val_loss: 0.1475 - val_auc: 0.8044
# Epoch 61/140
# 2971/2971 [==============================] - 585s 197ms/step - loss: 0.1482 - auc: 0.8110 - val_loss: 0.1470 - val_auc: 0.8038
# Epoch 62/140
# 2971/2971 [==============================] - 587s 198ms/step - loss: 0.1480 - auc: 0.8116 - val_loss: 0.1457 - val_auc: 0.8070
# Epoch 63/140
# 2971/2971 [==============================] - 591s 199ms/step - loss: 0.1479 - auc: 0.8121 - val_loss: 0.1467 - val_auc: 0.8061
# Epoch 64/140
# 2971/2971 [==============================] - 587s 198ms/step - loss: 0.1477 - auc: 0.8125 - val_loss: 0.1460 - val_auc: 0.8071
# Epoch 65/140
# 2971/2971 [==============================] - 590s 199ms/step - loss: 0.1476 - auc: 0.8130 - val_loss: 0.1457 - val_auc: 0.8073
# Epoch 66/140
# 2971/2971 [==============================] - 591s 199ms/step - loss: 0.1474 - auc: 0.8135 - val_loss: 0.1503 - val_auc: 0.8078
# Epoch 67/140
# 2971/2971 [==============================] - 590s 199ms/step - loss: 0.1474 - auc: 0.8136 - val_loss: 0.1452 - val_auc: 0.8090
# Epoch 68/140
# 2971/2971 [==============================] - 593s 200ms/step - loss: 0.1472 - auc: 0.8143 - val_loss: 0.1465 - val_auc: 0.8045
# Epoch 69/140
# 2971/2971 [==============================] - 594s 200ms/step - loss: 0.1470 - auc: 0.8148 - val_loss: 0.1474 - val_auc: 0.8059
# Epoch 70/140
# 2971/2971 [==============================] - 593s 200ms/step - loss: 0.1469 - auc: 0.8152 - val_loss: 0.1451 - val_auc: 0.8090
# Epoch 71/140
# 2971/2971 [==============================] - 596s 201ms/step - loss: 0.1468 - auc: 0.8156 - val_loss: 0.1446 - val_auc: 0.8107
# Epoch 72/140
# 2971/2971 [==============================] - 597s 201ms/step - loss: 0.1467 - auc: 0.8159 - val_loss: 0.1455 - val_auc: 0.8085
# Epoch 73/140
# 2971/2971 [==============================] - 601s 202ms/step - loss: 0.1466 - auc: 0.8162 - val_loss: 0.1451 - val_auc: 0.8096
# Epoch 74/140
# 2971/2971 [==============================] - 601s 202ms/step - loss: 0.1464 - auc: 0.8168 - val_loss: 0.1472 - val_auc: 0.8105
# Epoch 75/140
# 2971/2971 [==============================] - 603s 203ms/step - loss: 0.1463 - auc: 0.8171 - val_loss: 0.1445 - val_auc: 0.8113
# Epoch 76/140
# 2971/2971 [==============================] - 601s 202ms/step - loss: 0.1462 - auc: 0.8176 - val_loss: 0.1490 - val_auc: 0.8113
# Epoch 77/140
# 2971/2971 [==============================] - 607s 204ms/step - loss: 0.1462 - auc: 0.8176 - val_loss: 0.1460 - val_auc: 0.8109
# Epoch 78/140
# 2971/2971 [==============================] - 605s 204ms/step - loss: 0.1460 - auc: 0.8182 - val_loss: 0.1467 - val_auc: 0.8102
# Epoch 79/140
# 2971/2971 [==============================] - 605s 204ms/step - loss: 0.1459 - auc: 0.8184 - val_loss: 0.1447 - val_auc: 0.8113
# Epoch 80/140
# 2971/2971 [==============================] - 602s 203ms/step - loss: 0.1458 - auc: 0.8188 - val_loss: 0.1440 - val_auc: 0.8130
# Epoch 81/140
# 2971/2971 [==============================] - 604s 203ms/step - loss: 0.1457 - auc: 0.8191 - val_loss: 0.1445 - val_auc: 0.8112
# Epoch 82/140
# 2971/2971 [==============================] - 605s 203ms/step - loss: 0.1456 - auc: 0.8194 - val_loss: 0.1461 - val_auc: 0.8122
# Epoch 83/140
# 2971/2971 [==============================] - 592s 199ms/step - loss: 0.1455 - auc: 0.8197 - val_loss: 0.1437 - val_auc: 0.8135
# Epoch 84/140
# 2971/2971 [==============================] - 622s 209ms/step - loss: 0.1454 - auc: 0.8200 - val_loss: 0.1452 - val_auc: 0.8135
# Epoch 85/140
# 2971/2971 [==============================] - 614s 207ms/step - loss: 0.1453 - auc: 0.8202 - val_loss: 0.1439 - val_auc: 0.8127
# Epoch 86/140
# 2971/2971 [==============================] - 621s 209ms/step - loss: 0.1452 - auc: 0.8207 - val_loss: 0.1440 - val_auc: 0.8123
# Epoch 87/140
# 2971/2971 [==============================] - 611s 206ms/step - loss: 0.1451 - auc: 0.8208 - val_loss: 0.1444 - val_auc: 0.8139
# Epoch 88/140
# 2971/2971 [==============================] - 585s 197ms/step - loss: 0.1450 - auc: 0.8211 - val_loss: 0.1448 - val_auc: 0.8135
# Epoch 89/140
# 2971/2971 [==============================] - 566s 191ms/step - loss: 0.1450 - auc: 0.8212 - val_loss: 0.1486 - val_auc: 0.8067
# Epoch 90/140
# 2971/2971 [==============================] - 567s 191ms/step - loss: 0.1449 - auc: 0.8216 - val_loss: 0.1438 - val_auc: 0.8135
# Epoch 91/140
# 2971/2971 [==============================] - 562s 189ms/step - loss: 0.1448 - auc: 0.8218 - val_loss: 0.1451 - val_auc: 0.8140
# Epoch 92/140
# 2971/2971 [==============================] - 566s 190ms/step - loss: 0.1447 - auc: 0.8222 - val_loss: 0.1432 - val_auc: 0.8155
# Epoch 93/140
# 2971/2971 [==============================] - 569s 192ms/step - loss: 0.1447 - auc: 0.8221 - val_loss: 0.1449 - val_auc: 0.8125
# Epoch 94/140
# 2971/2971 [==============================] - 580s 195ms/step - loss: 0.1446 - auc: 0.8224 - val_loss: 0.1439 - val_auc: 0.8139
# Epoch 95/140
# 2971/2971 [==============================] - 570s 192ms/step - loss: 0.1445 - auc: 0.8227 - val_loss: 0.1437 - val_auc: 0.8146
# Epoch 96/140
# 2971/2971 [==============================] - 574s 193ms/step - loss: 0.1444 - auc: 0.8232 - val_loss: 0.1455 - val_auc: 0.8074
# Epoch 97/140
# 2971/2971 [==============================] - 569s 192ms/step - loss: 0.1443 - auc: 0.8232 - val_loss: 0.1451 - val_auc: 0.8129
# Epoch 98/140
# 2971/2971 [==============================] - 576s 194ms/step - loss: 0.1443 - auc: 0.8234 - val_loss: 0.1431 - val_auc: 0.8160
# Epoch 99/140
# 2971/2971 [==============================] - 578s 194ms/step - loss: 0.1443 - auc: 0.8234 - val_loss: 0.1436 - val_auc: 0.8153
# Epoch 100/140
# 2971/2971 [==============================] - 578s 195ms/step - loss: 0.1442 - auc: 0.8237 - val_loss: 0.1437 - val_auc: 0.8144
# Epoch 101/140
# 2971/2971 [==============================] - 579s 195ms/step - loss: 0.1441 - auc: 0.8241 - val_loss: 0.1440 - val_auc: 0.8151
# Epoch 102/140
# 2971/2971 [==============================] - 580s 195ms/step - loss: 0.1441 - auc: 0.8240 - val_loss: 0.1440 - val_auc: 0.8142
# Epoch 103/140
# 2971/2971 [==============================] - 581s 196ms/step - loss: 0.1440 - auc: 0.8243 - val_loss: 0.1437 - val_auc: 0.8142
# Epoch 104/140
# 2971/2971 [==============================] - 583s 196ms/step - loss: 0.1439 - auc: 0.8245 - val_loss: 0.1460 - val_auc: 0.8142
# Epoch 105/140
# 2971/2971 [==============================] - 582s 196ms/step - loss: 0.1438 - auc: 0.8248 - val_loss: 0.1502 - val_auc: 0.8142
# Epoch 106/140
# 2971/2971 [==============================] - 584s 197ms/step - loss: 0.1438 - auc: 0.8247 - val_loss: 0.1449 - val_auc: 0.8146
# Epoch 107/140
# 2971/2971 [==============================] - 584s 197ms/step - loss: 0.1438 - auc: 0.8250 - val_loss: 0.1431 - val_auc: 0.8155
# Epoch 108/140
# 2971/2971 [==============================] - 588s 198ms/step - loss: 0.1437 - auc: 0.8251 - val_loss: 0.1467 - val_auc: 0.8159
# Epoch 109/140
# 2971/2971 [==============================] - 585s 197ms/step - loss: 0.1436 - auc: 0.8254 - val_loss: 0.1433 - val_auc: 0.8161
# Epoch 110/140
# 2971/2971 [==============================] - 589s 198ms/step - loss: 0.1436 - auc: 0.8254 - val_loss: 0.1434 - val_auc: 0.8164
# Epoch 111/140
# 2971/2971 [==============================] - 591s 199ms/step - loss: 0.1436 - auc: 0.8256 - val_loss: 0.1442 - val_auc: 0.8142
# Epoch 112/140
# 2971/2971 [==============================] - 595s 200ms/step - loss: 0.1435 - auc: 0.8258 - val_loss: 0.1440 - val_auc: 0.8165
# Epoch 113/140
# 2971/2971 [==============================] - 602s 203ms/step - loss: 0.1434 - auc: 0.8260 - val_loss: 0.1446 - val_auc: 0.8143
# Epoch 114/140
# 2971/2971 [==============================] - 595s 200ms/step - loss: 0.1434 - auc: 0.8260 - val_loss: 0.1464 - val_auc: 0.8159
# Epoch 115/140
# 2971/2971 [==============================] - 598s 201ms/step - loss: 0.1433 - auc: 0.8263 - val_loss: 0.1447 - val_auc: 0.8160
# Epoch 116/140
# 2971/2971 [==============================] - 598s 201ms/step - loss: 0.1433 - auc: 0.8263 - val_loss: 0.1432 - val_auc: 0.8156
# Epoch 117/140
# 2971/2971 [==============================] - 609s 205ms/step - loss: 0.1433 - auc: 0.8263 - val_loss: 0.1434 - val_auc: 0.8169
# Epoch 118/140
# 2971/2971 [==============================] - 605s 204ms/step - loss: 0.1433 - auc: 0.8264 - val_loss: 0.1498 - val_auc: 0.8124
# Epoch 119/140
# 2971/2971 [==============================] - 605s 204ms/step - loss: 0.1432 - auc: 0.8267 - val_loss: 0.1434 - val_auc: 0.8170
# Epoch 120/140
# 2971/2971 [==============================] - 606s 204ms/step - loss: 0.1432 - auc: 0.8267 - val_loss: 0.1497 - val_auc: 0.8162
# Epoch 121/140
# 2971/2971 [==============================] - 609s 205ms/step - loss: 0.1431 - auc: 0.8270 - val_loss: 0.1454 - val_auc: 0.8163
# Epoch 122/140
# 2971/2971 [==============================] - 607s 204ms/step - loss: 0.1430 - auc: 0.8271 - val_loss: 0.1436 - val_auc: 0.8158
# Epoch 123/140
# 2971/2971 [==============================] - 611s 206ms/step - loss: 0.1431 - auc: 0.8271 - val_loss: 0.1434 - val_auc: 0.8178
# Epoch 124/140
# 2971/2971 [==============================] - 611s 206ms/step - loss: 0.1430 - auc: 0.8273 - val_loss: 0.1437 - val_auc: 0.8175
# Epoch 125/140
# 2971/2971 [==============================] - 609s 205ms/step - loss: 0.1429 - auc: 0.8274 - val_loss: 0.1433 - val_auc: 0.8162
# Epoch 126/140
# 2971/2971 [==============================] - 614s 207ms/step - loss: 0.1429 - auc: 0.8276 - val_loss: 0.1442 - val_auc: 0.8147
# Epoch 127/140
# 2971/2971 [==============================] - 612s 206ms/step - loss: 0.1428 - auc: 0.8278 - val_loss: 0.1460 - val_auc: 0.8135
# Epoch 128/140
# 2971/2971 [==============================] - 613s 206ms/step - loss: 0.1428 - auc: 0.8278 - val_loss: 0.1427 - val_auc: 0.8177
# Epoch 129/140
# 2971/2971 [==============================] - 617s 208ms/step - loss: 0.1428 - auc: 0.8278 - val_loss: 0.1428 - val_auc: 0.8178
# Epoch 130/140
# 2971/2971 [==============================] - 618s 208ms/step - loss: 0.1427 - auc: 0.8281 - val_loss: 0.1440 - val_auc: 0.8169
# Epoch 131/140
# 2971/2971 [==============================] - 619s 208ms/step - loss: 0.1427 - auc: 0.8281 - val_loss: 0.1431 - val_auc: 0.8169
# Epoch 132/140
# 2971/2971 [==============================] - 620s 209ms/step - loss: 0.1427 - auc: 0.8282 - val_loss: 0.1428 - val_auc: 0.8174
# Epoch 133/140
# 2971/2971 [==============================] - 624s 210ms/step - loss: 0.1426 - auc: 0.8284 - val_loss: 0.1441 - val_auc: 0.8167
# Epoch 134/140
# 2971/2971 [==============================] - 631s 213ms/step - loss: 0.1426 - auc: 0.8284 - val_loss: 0.1442 - val_auc: 0.8164
# Epoch 135/140
# 2971/2971 [==============================] - 629s 212ms/step - loss: 0.1425 - auc: 0.8286 - val_loss: 0.1430 - val_auc: 0.8172
# Epoch 136/140
# 2971/2971 [==============================] - 636s 214ms/step - loss: 0.1425 - auc: 0.8288 - val_loss: 0.1444 - val_auc: 0.8138
# Epoch 137/140
# 2971/2971 [==============================] - 630s 212ms/step - loss: 0.1425 - auc: 0.8286 - val_loss: 0.1435 - val_auc: 0.8160
# Epoch 138/140
# 2971/2971 [==============================] - 634s 213ms/step - loss: 0.1425 - auc: 0.8288 - val_loss: 0.1424 - val_auc: 0.8180
# Epoch 139/140
# 2971/2971 [==============================] - 631s 212ms/step - loss: 0.1424 - auc: 0.8291 - val_loss: 0.1424 - val_auc: 0.8180
# Epoch 140/140
# 2971/2971 [==============================] - 630s 212ms/step - loss: 0.1424 - auc: 0.8290 - val_loss: 0.1454 - val_auc: 0.8159

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 91s 30ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 82442.29831385612

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00444222],
#        [0.00571438],
#        [0.00450718],
#        ...,
#        [0.07637816],
#        [0.07548021],
#        [0.07604635]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14544991232936805
# 0.2178823425829336
# 0.38137896157151624
# 0.29455520738916263

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 541s 36ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.5803195]
# [0.84191976]
# total acc [0.78004229]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
