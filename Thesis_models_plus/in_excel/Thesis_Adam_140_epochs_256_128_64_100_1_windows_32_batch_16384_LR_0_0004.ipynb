# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x27517d7a040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2758be3c040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0004)
model_gru.compile(loss='MSE', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           209664
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 16s 356ms/step - loss: 0.2029 - accuracy: 0.7393 - val_loss: 0.1860 - val_accuracy: 0.7530
# Epoch 2/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.1916 - accuracy: 0.7393 - val_loss: 0.1828 - val_accuracy: 0.7530
# Epoch 3/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.1836 - accuracy: 0.7384 - val_loss: 0.1726 - val_accuracy: 0.7531
# Epoch 4/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.1737 - accuracy: 0.7388 - val_loss: 0.1650 - val_accuracy: 0.7516
# Epoch 5/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1697 - accuracy: 0.7408 - val_loss: 0.1636 - val_accuracy: 0.7534
# Epoch 6/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1684 - accuracy: 0.7423 - val_loss: 0.1629 - val_accuracy: 0.7542
# Epoch 7/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.1676 - accuracy: 0.7445 - val_loss: 0.1617 - val_accuracy: 0.7540
# Epoch 8/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.1660 - accuracy: 0.7477 - val_loss: 0.1614 - val_accuracy: 0.7524
# Epoch 9/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.1633 - accuracy: 0.7492 - val_loss: 0.1597 - val_accuracy: 0.7522
# Epoch 10/140
# 24/24 [==============================] - 8s 332ms/step - loss: 0.1617 - accuracy: 0.7517 - val_loss: 0.1583 - val_accuracy: 0.7561
# Epoch 11/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1593 - accuracy: 0.7552 - val_loss: 0.1556 - val_accuracy: 0.7611
# Epoch 12/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1579 - accuracy: 0.7577 - val_loss: 0.1543 - val_accuracy: 0.7620
# Epoch 13/140
# 24/24 [==============================] - 7s 305ms/step - loss: 0.1566 - accuracy: 0.7589 - val_loss: 0.1530 - val_accuracy: 0.7641
# Epoch 14/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1559 - accuracy: 0.7601 - val_loss: 0.1534 - val_accuracy: 0.7658
# Epoch 15/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1561 - accuracy: 0.7602 - val_loss: 0.1531 - val_accuracy: 0.7646
# Epoch 16/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1549 - accuracy: 0.7612 - val_loss: 0.1532 - val_accuracy: 0.7665
# Epoch 17/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1553 - accuracy: 0.7616 - val_loss: 0.1519 - val_accuracy: 0.7664
# Epoch 18/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1536 - accuracy: 0.7638 - val_loss: 0.1503 - val_accuracy: 0.7685
# Epoch 19/140
# 24/24 [==============================] - 7s 305ms/step - loss: 0.1531 - accuracy: 0.7642 - val_loss: 0.1524 - val_accuracy: 0.7694
# Epoch 20/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1528 - accuracy: 0.7652 - val_loss: 0.1504 - val_accuracy: 0.7700
# Epoch 21/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1523 - accuracy: 0.7661 - val_loss: 0.1509 - val_accuracy: 0.7708
# Epoch 22/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1520 - accuracy: 0.7669 - val_loss: 0.1499 - val_accuracy: 0.7695
# Epoch 23/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1514 - accuracy: 0.7676 - val_loss: 0.1488 - val_accuracy: 0.7726
# Epoch 24/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1511 - accuracy: 0.7680 - val_loss: 0.1488 - val_accuracy: 0.7729
# Epoch 25/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1512 - accuracy: 0.7679 - val_loss: 0.1480 - val_accuracy: 0.7741
# Epoch 26/140
# 24/24 [==============================] - 7s 309ms/step - loss: 0.1508 - accuracy: 0.7688 - val_loss: 0.1498 - val_accuracy: 0.7731
# Epoch 27/140
# 24/24 [==============================] - 7s 305ms/step - loss: 0.1504 - accuracy: 0.7697 - val_loss: 0.1481 - val_accuracy: 0.7740
# Epoch 28/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1497 - accuracy: 0.7707 - val_loss: 0.1479 - val_accuracy: 0.7754
# Epoch 29/140
# 24/24 [==============================] - 7s 306ms/step - loss: 0.1502 - accuracy: 0.7706 - val_loss: 0.1480 - val_accuracy: 0.7730
# Epoch 30/140
# 24/24 [==============================] - 7s 308ms/step - loss: 0.1498 - accuracy: 0.7709 - val_loss: 0.1468 - val_accuracy: 0.7773
# Epoch 31/140
# 24/24 [==============================] - 7s 307ms/step - loss: 0.1491 - accuracy: 0.7724 - val_loss: 0.1483 - val_accuracy: 0.7723
# Epoch 32/140
# 24/24 [==============================] - 7s 307ms/step - loss: 0.1491 - accuracy: 0.7729 - val_loss: 0.1477 - val_accuracy: 0.7765
# Epoch 33/140
# 24/24 [==============================] - 7s 308ms/step - loss: 0.1488 - accuracy: 0.7731 - val_loss: 0.1471 - val_accuracy: 0.7756
# Epoch 34/140
# 24/24 [==============================] - 7s 307ms/step - loss: 0.1488 - accuracy: 0.7731 - val_loss: 0.1473 - val_accuracy: 0.7753
# Epoch 35/140
# 24/24 [==============================] - 7s 306ms/step - loss: 0.1487 - accuracy: 0.7737 - val_loss: 0.1474 - val_accuracy: 0.7756
# Epoch 36/140
# 24/24 [==============================] - 7s 306ms/step - loss: 0.1482 - accuracy: 0.7740 - val_loss: 0.1477 - val_accuracy: 0.7771
# Epoch 37/140
# 24/24 [==============================] - 7s 307ms/step - loss: 0.1481 - accuracy: 0.7744 - val_loss: 0.1459 - val_accuracy: 0.7784
# Epoch 38/140
# 24/24 [==============================] - 7s 307ms/step - loss: 0.1478 - accuracy: 0.7749 - val_loss: 0.1469 - val_accuracy: 0.7758
# Epoch 39/140
# 24/24 [==============================] - 7s 307ms/step - loss: 0.1476 - accuracy: 0.7757 - val_loss: 0.1457 - val_accuracy: 0.7783
# Epoch 40/140
# 24/24 [==============================] - 7s 306ms/step - loss: 0.1473 - accuracy: 0.7761 - val_loss: 0.1457 - val_accuracy: 0.7791
# Epoch 41/140
# 24/24 [==============================] - 7s 305ms/step - loss: 0.1470 - accuracy: 0.7765 - val_loss: 0.1472 - val_accuracy: 0.7799
# Epoch 42/140
# 24/24 [==============================] - 7s 307ms/step - loss: 0.1473 - accuracy: 0.7761 - val_loss: 0.1456 - val_accuracy: 0.7799
# Epoch 43/140
# 24/24 [==============================] - 7s 305ms/step - loss: 0.1471 - accuracy: 0.7762 - val_loss: 0.1474 - val_accuracy: 0.7752
# Epoch 44/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1472 - accuracy: 0.7760 - val_loss: 0.1465 - val_accuracy: 0.7790
# Epoch 45/140
# 24/24 [==============================] - 7s 306ms/step - loss: 0.1467 - accuracy: 0.7768 - val_loss: 0.1452 - val_accuracy: 0.7781
# Epoch 46/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1463 - accuracy: 0.7772 - val_loss: 0.1465 - val_accuracy: 0.7780
# Epoch 47/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1466 - accuracy: 0.7774 - val_loss: 0.1455 - val_accuracy: 0.7788
# Epoch 48/140
# 24/24 [==============================] - 7s 306ms/step - loss: 0.1470 - accuracy: 0.7767 - val_loss: 0.1457 - val_accuracy: 0.7801
# Epoch 49/140
# 24/24 [==============================] - 7s 307ms/step - loss: 0.1461 - accuracy: 0.7778 - val_loss: 0.1472 - val_accuracy: 0.7776
# Epoch 50/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1461 - accuracy: 0.7776 - val_loss: 0.1452 - val_accuracy: 0.7773
# Epoch 51/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1465 - accuracy: 0.7773 - val_loss: 0.1452 - val_accuracy: 0.7806
# Epoch 52/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1458 - accuracy: 0.7781 - val_loss: 0.1454 - val_accuracy: 0.7756
# Epoch 53/140
# 24/24 [==============================] - 7s 305ms/step - loss: 0.1458 - accuracy: 0.7781 - val_loss: 0.1448 - val_accuracy: 0.7812
# Epoch 54/140
# 24/24 [==============================] - 7s 305ms/step - loss: 0.1457 - accuracy: 0.7781 - val_loss: 0.1460 - val_accuracy: 0.7749
# Epoch 55/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1458 - accuracy: 0.7786 - val_loss: 0.1453 - val_accuracy: 0.7802
# Epoch 56/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1456 - accuracy: 0.7784 - val_loss: 0.1473 - val_accuracy: 0.7793
# Epoch 57/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1454 - accuracy: 0.7790 - val_loss: 0.1451 - val_accuracy: 0.7802
# Epoch 58/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1454 - accuracy: 0.7791 - val_loss: 0.1451 - val_accuracy: 0.7778
# Epoch 59/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1452 - accuracy: 0.7788 - val_loss: 0.1444 - val_accuracy: 0.7808
# Epoch 60/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1454 - accuracy: 0.7788 - val_loss: 0.1465 - val_accuracy: 0.7773
# Epoch 61/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1452 - accuracy: 0.7789 - val_loss: 0.1449 - val_accuracy: 0.7800
# Epoch 62/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1448 - accuracy: 0.7794 - val_loss: 0.1443 - val_accuracy: 0.7791
# Epoch 63/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1450 - accuracy: 0.7793 - val_loss: 0.1452 - val_accuracy: 0.7814
# Epoch 64/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1451 - accuracy: 0.7793 - val_loss: 0.1445 - val_accuracy: 0.7777
# Epoch 65/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1447 - accuracy: 0.7797 - val_loss: 0.1443 - val_accuracy: 0.7798
# Epoch 66/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1446 - accuracy: 0.7796 - val_loss: 0.1454 - val_accuracy: 0.7772
# Epoch 67/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1447 - accuracy: 0.7793 - val_loss: 0.1447 - val_accuracy: 0.7784
# Epoch 68/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1443 - accuracy: 0.7800 - val_loss: 0.1444 - val_accuracy: 0.7795
# Epoch 69/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1444 - accuracy: 0.7802 - val_loss: 0.1447 - val_accuracy: 0.7809
# Epoch 70/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1441 - accuracy: 0.7803 - val_loss: 0.1448 - val_accuracy: 0.7794
# Epoch 71/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1442 - accuracy: 0.7802 - val_loss: 0.1441 - val_accuracy: 0.7815
# Epoch 72/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1445 - accuracy: 0.7800 - val_loss: 0.1460 - val_accuracy: 0.7796
# Epoch 73/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1443 - accuracy: 0.7803 - val_loss: 0.1439 - val_accuracy: 0.7800
# Epoch 74/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1445 - accuracy: 0.7801 - val_loss: 0.1443 - val_accuracy: 0.7822
# Epoch 75/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1440 - accuracy: 0.7807 - val_loss: 0.1442 - val_accuracy: 0.7802
# Epoch 76/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1436 - accuracy: 0.7808 - val_loss: 0.1460 - val_accuracy: 0.7800
# Epoch 77/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1444 - accuracy: 0.7805 - val_loss: 0.1454 - val_accuracy: 0.7821
# Epoch 78/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1443 - accuracy: 0.7805 - val_loss: 0.1444 - val_accuracy: 0.7789
# Epoch 79/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1436 - accuracy: 0.7814 - val_loss: 0.1439 - val_accuracy: 0.7811
# Epoch 80/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1436 - accuracy: 0.7810 - val_loss: 0.1446 - val_accuracy: 0.7812
# Epoch 81/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1435 - accuracy: 0.7815 - val_loss: 0.1463 - val_accuracy: 0.7736
# Epoch 82/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1433 - accuracy: 0.7822 - val_loss: 0.1438 - val_accuracy: 0.7795
# Epoch 83/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1430 - accuracy: 0.7823 - val_loss: 0.1440 - val_accuracy: 0.7812
# Epoch 84/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1430 - accuracy: 0.7828 - val_loss: 0.1446 - val_accuracy: 0.7783
# Epoch 85/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1433 - accuracy: 0.7826 - val_loss: 0.1458 - val_accuracy: 0.7763
# Epoch 86/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1433 - accuracy: 0.7825 - val_loss: 0.1441 - val_accuracy: 0.7794
# Epoch 87/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1426 - accuracy: 0.7833 - val_loss: 0.1438 - val_accuracy: 0.7812
# Epoch 88/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1431 - accuracy: 0.7830 - val_loss: 0.1437 - val_accuracy: 0.7821
# Epoch 89/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1424 - accuracy: 0.7837 - val_loss: 0.1438 - val_accuracy: 0.7818
# Epoch 90/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1425 - accuracy: 0.7832 - val_loss: 0.1430 - val_accuracy: 0.7836
# Epoch 91/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1428 - accuracy: 0.7833 - val_loss: 0.1443 - val_accuracy: 0.7791
# Epoch 92/140
# 24/24 [==============================] - 7s 306ms/step - loss: 0.1423 - accuracy: 0.7840 - val_loss: 0.1434 - val_accuracy: 0.7839
# Epoch 93/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1420 - accuracy: 0.7843 - val_loss: 0.1441 - val_accuracy: 0.7809
# Epoch 94/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1420 - accuracy: 0.7844 - val_loss: 0.1446 - val_accuracy: 0.7824
# Epoch 95/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1419 - accuracy: 0.7844 - val_loss: 0.1432 - val_accuracy: 0.7839
# Epoch 96/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1417 - accuracy: 0.7848 - val_loss: 0.1439 - val_accuracy: 0.7820
# Epoch 97/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1419 - accuracy: 0.7845 - val_loss: 0.1441 - val_accuracy: 0.7831
# Epoch 98/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1424 - accuracy: 0.7837 - val_loss: 0.1446 - val_accuracy: 0.7822
# Epoch 99/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1421 - accuracy: 0.7844 - val_loss: 0.1436 - val_accuracy: 0.7837
# Epoch 100/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1415 - accuracy: 0.7850 - val_loss: 0.1436 - val_accuracy: 0.7817
# Epoch 101/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1414 - accuracy: 0.7854 - val_loss: 0.1436 - val_accuracy: 0.7845
# Epoch 102/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1413 - accuracy: 0.7853 - val_loss: 0.1433 - val_accuracy: 0.7815
# Epoch 103/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1413 - accuracy: 0.7853 - val_loss: 0.1430 - val_accuracy: 0.7849
# Epoch 104/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1412 - accuracy: 0.7856 - val_loss: 0.1430 - val_accuracy: 0.7830
# Epoch 105/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1411 - accuracy: 0.7861 - val_loss: 0.1449 - val_accuracy: 0.7820
# Epoch 106/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1416 - accuracy: 0.7850 - val_loss: 0.1440 - val_accuracy: 0.7828
# Epoch 107/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1414 - accuracy: 0.7853 - val_loss: 0.1437 - val_accuracy: 0.7788
# Epoch 108/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1408 - accuracy: 0.7862 - val_loss: 0.1430 - val_accuracy: 0.7834
# Epoch 109/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1407 - accuracy: 0.7859 - val_loss: 0.1437 - val_accuracy: 0.7819
# Epoch 110/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1408 - accuracy: 0.7857 - val_loss: 0.1432 - val_accuracy: 0.7843
# Epoch 111/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1408 - accuracy: 0.7860 - val_loss: 0.1425 - val_accuracy: 0.7836
# Epoch 112/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1408 - accuracy: 0.7863 - val_loss: 0.1466 - val_accuracy: 0.7814
# Epoch 113/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1414 - accuracy: 0.7855 - val_loss: 0.1429 - val_accuracy: 0.7830
# Epoch 114/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1406 - accuracy: 0.7864 - val_loss: 0.1431 - val_accuracy: 0.7841
# Epoch 115/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1404 - accuracy: 0.7867 - val_loss: 0.1420 - val_accuracy: 0.7841
# Epoch 116/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1405 - accuracy: 0.7865 - val_loss: 0.1425 - val_accuracy: 0.7841
# Epoch 117/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1401 - accuracy: 0.7869 - val_loss: 0.1440 - val_accuracy: 0.7853
# Epoch 118/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1409 - accuracy: 0.7863 - val_loss: 0.1435 - val_accuracy: 0.7835
# Epoch 119/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1403 - accuracy: 0.7869 - val_loss: 0.1439 - val_accuracy: 0.7791
# Epoch 120/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1404 - accuracy: 0.7869 - val_loss: 0.1440 - val_accuracy: 0.7830
# Epoch 121/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1402 - accuracy: 0.7868 - val_loss: 0.1424 - val_accuracy: 0.7827
# Epoch 122/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1400 - accuracy: 0.7872 - val_loss: 0.1428 - val_accuracy: 0.7824
# Epoch 123/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1399 - accuracy: 0.7876 - val_loss: 0.1425 - val_accuracy: 0.7821
# Epoch 124/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1398 - accuracy: 0.7877 - val_loss: 0.1423 - val_accuracy: 0.7851
# Epoch 125/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1397 - accuracy: 0.7880 - val_loss: 0.1443 - val_accuracy: 0.7838
# Epoch 126/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1406 - accuracy: 0.7871 - val_loss: 0.1428 - val_accuracy: 0.7848
# Epoch 127/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1398 - accuracy: 0.7876 - val_loss: 0.1441 - val_accuracy: 0.7833
# Epoch 128/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1396 - accuracy: 0.7878 - val_loss: 0.1433 - val_accuracy: 0.7805
# Epoch 129/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1403 - accuracy: 0.7871 - val_loss: 0.1439 - val_accuracy: 0.7807
# Epoch 130/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1400 - accuracy: 0.7877 - val_loss: 0.1439 - val_accuracy: 0.7804
# Epoch 131/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1393 - accuracy: 0.7886 - val_loss: 0.1420 - val_accuracy: 0.7847
# Epoch 132/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1396 - accuracy: 0.7881 - val_loss: 0.1427 - val_accuracy: 0.7820
# Epoch 133/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1392 - accuracy: 0.7889 - val_loss: 0.1424 - val_accuracy: 0.7853
# Epoch 134/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1392 - accuracy: 0.7886 - val_loss: 0.1428 - val_accuracy: 0.7843
# Epoch 135/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1392 - accuracy: 0.7888 - val_loss: 0.1425 - val_accuracy: 0.7833
# Epoch 136/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1394 - accuracy: 0.7884 - val_loss: 0.1420 - val_accuracy: 0.7852
# Epoch 137/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1393 - accuracy: 0.7887 - val_loss: 0.1423 - val_accuracy: 0.7832
# Epoch 138/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1392 - accuracy: 0.7886 - val_loss: 0.1428 - val_accuracy: 0.7855
# Epoch 139/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1391 - accuracy: 0.7890 - val_loss: 0.1436 - val_accuracy: 0.7814
# Epoch 140/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1389 - accuracy: 0.7894 - val_loss: 0.1432 - val_accuracy: 0.7828

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 28s 9ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 1055.7760331630707

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00292498],
#        [0.00436629],
#        [0.00376847],
#        ...,
#        [0.0541811 ],
#        [0.0599535 ],
#        [0.06272601]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14321168230078232
# 0.22991782062951982
# 0.37843319397323266
# 0.2863968676629436

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 124s 8ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.61438822]
# [0.83212052]
# total acc [0.78819705]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1100577024, 'peak': 9492953856}
