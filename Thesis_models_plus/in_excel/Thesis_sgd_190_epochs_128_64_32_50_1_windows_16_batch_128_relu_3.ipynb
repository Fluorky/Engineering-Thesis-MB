# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x17f3d1de040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x17f77244040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=190,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/190
# 2971/2971 [==============================] - 465s 154ms/step - loss: 0.5724 - accuracy: 0.7393 - val_loss: 0.5554 - val_accuracy: 0.7531
# Epoch 2/190
# 2971/2971 [==============================] - 462s 156ms/step - loss: 0.5595 - accuracy: 0.7393 - val_loss: 0.5291 - val_accuracy: 0.7530
# Epoch 3/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.5239 - accuracy: 0.7402 - val_loss: 0.4960 - val_accuracy: 0.7522
# Epoch 4/190
# 2971/2971 [==============================] - 435s 147ms/step - loss: 0.5073 - accuracy: 0.7366 - val_loss: 0.4929 - val_accuracy: 0.7470
# Epoch 5/190
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.5032 - accuracy: 0.7366 - val_loss: 0.4866 - val_accuracy: 0.7512
# Epoch 6/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.5005 - accuracy: 0.7380 - val_loss: 0.4877 - val_accuracy: 0.7529
# Epoch 7/190
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.4979 - accuracy: 0.7396 - val_loss: 0.4823 - val_accuracy: 0.7535
# Epoch 8/190
# 2971/2971 [==============================] - 435s 147ms/step - loss: 0.4952 - accuracy: 0.7411 - val_loss: 0.4800 - val_accuracy: 0.7545
# Epoch 9/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4917 - accuracy: 0.7439 - val_loss: 0.4780 - val_accuracy: 0.7544
# Epoch 10/190
# 2971/2971 [==============================] - 435s 147ms/step - loss: 0.4875 - accuracy: 0.7472 - val_loss: 0.4752 - val_accuracy: 0.7530
# Epoch 11/190
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.4829 - accuracy: 0.7480 - val_loss: 0.4714 - val_accuracy: 0.7544
# Epoch 12/190
# 2971/2971 [==============================] - 434s 146ms/step - loss: 0.4786 - accuracy: 0.7495 - val_loss: 0.4676 - val_accuracy: 0.7544
# Epoch 13/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4750 - accuracy: 0.7519 - val_loss: 0.4645 - val_accuracy: 0.7567
# Epoch 14/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4722 - accuracy: 0.7535 - val_loss: 0.4632 - val_accuracy: 0.7570
# Epoch 15/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4699 - accuracy: 0.7550 - val_loss: 0.4644 - val_accuracy: 0.7597
# Epoch 16/190
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.4677 - accuracy: 0.7553 - val_loss: 0.4596 - val_accuracy: 0.7597
# Epoch 17/190
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.4657 - accuracy: 0.7561 - val_loss: 0.4572 - val_accuracy: 0.7628
# Epoch 18/190
# 2971/2971 [==============================] - 434s 146ms/step - loss: 0.4637 - accuracy: 0.7568 - val_loss: 0.4555 - val_accuracy: 0.7628
# Epoch 19/190
# 2971/2971 [==============================] - 434s 146ms/step - loss: 0.4624 - accuracy: 0.7572 - val_loss: 0.4735 - val_accuracy: 0.7487
# Epoch 20/190
# 2971/2971 [==============================] - 434s 146ms/step - loss: 0.4612 - accuracy: 0.7579 - val_loss: 0.4596 - val_accuracy: 0.7563
# Epoch 21/190
# 2971/2971 [==============================] - 434s 146ms/step - loss: 0.4602 - accuracy: 0.7585 - val_loss: 0.4619 - val_accuracy: 0.7574
# Epoch 22/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4590 - accuracy: 0.7595 - val_loss: 0.4516 - val_accuracy: 0.7659
# Epoch 23/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4584 - accuracy: 0.7599 - val_loss: 0.4542 - val_accuracy: 0.7615
# Epoch 24/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4572 - accuracy: 0.7608 - val_loss: 0.4481 - val_accuracy: 0.7661
# Epoch 25/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4566 - accuracy: 0.7610 - val_loss: 0.4490 - val_accuracy: 0.7649
# Epoch 26/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4559 - accuracy: 0.7618 - val_loss: 0.4477 - val_accuracy: 0.7655
# Epoch 27/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4550 - accuracy: 0.7625 - val_loss: 0.4476 - val_accuracy: 0.7672
# Epoch 28/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4543 - accuracy: 0.7631 - val_loss: 0.4487 - val_accuracy: 0.7684
# Epoch 29/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4534 - accuracy: 0.7642 - val_loss: 0.4464 - val_accuracy: 0.7663
# Epoch 30/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4527 - accuracy: 0.7645 - val_loss: 0.4449 - val_accuracy: 0.7687
# Epoch 31/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4521 - accuracy: 0.7651 - val_loss: 0.4510 - val_accuracy: 0.7707
# Epoch 32/190
# 2971/2971 [==============================] - 434s 146ms/step - loss: 0.4513 - accuracy: 0.7656 - val_loss: 0.4424 - val_accuracy: 0.7713
# Epoch 33/190
# 2971/2971 [==============================] - 435s 147ms/step - loss: 0.4509 - accuracy: 0.7663 - val_loss: 0.4424 - val_accuracy: 0.7707
# Epoch 34/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4501 - accuracy: 0.7668 - val_loss: 0.4415 - val_accuracy: 0.7717
# Epoch 35/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4496 - accuracy: 0.7673 - val_loss: 0.4401 - val_accuracy: 0.7728
# Epoch 36/190
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.4488 - accuracy: 0.7679 - val_loss: 0.4394 - val_accuracy: 0.7733
# Epoch 37/190
# 2971/2971 [==============================] - 435s 147ms/step - loss: 0.4483 - accuracy: 0.7682 - val_loss: 0.4402 - val_accuracy: 0.7729
# Epoch 38/190
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.4476 - accuracy: 0.7688 - val_loss: 0.4428 - val_accuracy: 0.7721
# Epoch 39/190
# 2971/2971 [==============================] - 434s 146ms/step - loss: 0.4469 - accuracy: 0.7693 - val_loss: 0.4411 - val_accuracy: 0.7731
# Epoch 40/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4463 - accuracy: 0.7699 - val_loss: 0.4402 - val_accuracy: 0.7715
# Epoch 41/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4458 - accuracy: 0.7699 - val_loss: 0.4389 - val_accuracy: 0.7730
# Epoch 42/190
# 2971/2971 [==============================] - 432s 145ms/step - loss: 0.4454 - accuracy: 0.7703 - val_loss: 0.4447 - val_accuracy: 0.7691
# Epoch 43/190
# 2971/2971 [==============================] - 435s 147ms/step - loss: 0.4450 - accuracy: 0.7705 - val_loss: 0.4407 - val_accuracy: 0.7719
# Epoch 44/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4443 - accuracy: 0.7709 - val_loss: 0.4403 - val_accuracy: 0.7741
# Epoch 45/190
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.4440 - accuracy: 0.7710 - val_loss: 0.4396 - val_accuracy: 0.7747
# Epoch 46/190
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.4435 - accuracy: 0.7713 - val_loss: 0.4394 - val_accuracy: 0.7731
# Epoch 47/190
# 2971/2971 [==============================] - 433s 146ms/step - loss: 0.4431 - accuracy: 0.7719 - val_loss: 0.4415 - val_accuracy: 0.7714
# Epoch 48/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4426 - accuracy: 0.7717 - val_loss: 0.4358 - val_accuracy: 0.7759
# Epoch 49/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4422 - accuracy: 0.7725 - val_loss: 0.4365 - val_accuracy: 0.7739
# Epoch 50/190
# 2971/2971 [==============================] - 491s 165ms/step - loss: 0.4420 - accuracy: 0.7725 - val_loss: 0.4373 - val_accuracy: 0.7729
# Epoch 51/190
# 2971/2971 [==============================] - 500s 168ms/step - loss: 0.4415 - accuracy: 0.7729 - val_loss: 0.4426 - val_accuracy: 0.7715
# Epoch 52/190
# 2971/2971 [==============================] - 450s 152ms/step - loss: 0.4411 - accuracy: 0.7737 - val_loss: 0.4350 - val_accuracy: 0.7754
# Epoch 53/190
# 2971/2971 [==============================] - 450s 152ms/step - loss: 0.4408 - accuracy: 0.7735 - val_loss: 0.4365 - val_accuracy: 0.7742
# Epoch 54/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4405 - accuracy: 0.7744 - val_loss: 0.4362 - val_accuracy: 0.7738
# Epoch 55/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4402 - accuracy: 0.7740 - val_loss: 0.4388 - val_accuracy: 0.7745
# Epoch 56/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4398 - accuracy: 0.7747 - val_loss: 0.4453 - val_accuracy: 0.7714
# Epoch 57/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4392 - accuracy: 0.7750 - val_loss: 0.4346 - val_accuracy: 0.7761
# Epoch 58/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4389 - accuracy: 0.7750 - val_loss: 0.4407 - val_accuracy: 0.7762
# Epoch 59/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4389 - accuracy: 0.7751 - val_loss: 0.4371 - val_accuracy: 0.7781
# Epoch 60/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4386 - accuracy: 0.7755 - val_loss: 0.4320 - val_accuracy: 0.7793
# Epoch 61/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4383 - accuracy: 0.7759 - val_loss: 0.4391 - val_accuracy: 0.7736
# Epoch 62/190
# 2971/2971 [==============================] - 440s 148ms/step - loss: 0.4379 - accuracy: 0.7763 - val_loss: 0.4332 - val_accuracy: 0.7786
# Epoch 63/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4376 - accuracy: 0.7762 - val_loss: 0.4315 - val_accuracy: 0.7795
# Epoch 64/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4373 - accuracy: 0.7762 - val_loss: 0.4387 - val_accuracy: 0.7779
# Epoch 65/190
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4372 - accuracy: 0.7770 - val_loss: 0.4320 - val_accuracy: 0.7789
# Epoch 66/190
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4368 - accuracy: 0.7764 - val_loss: 0.4346 - val_accuracy: 0.7784
# Epoch 67/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4365 - accuracy: 0.7767 - val_loss: 0.4412 - val_accuracy: 0.7721
# Epoch 68/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4362 - accuracy: 0.7770 - val_loss: 0.4305 - val_accuracy: 0.7798
# Epoch 69/190
# 2971/2971 [==============================] - 435s 147ms/step - loss: 0.4361 - accuracy: 0.7769 - val_loss: 0.4362 - val_accuracy: 0.7771
# Epoch 70/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4359 - accuracy: 0.7773 - val_loss: 0.4307 - val_accuracy: 0.7801
# Epoch 71/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4356 - accuracy: 0.7775 - val_loss: 0.4328 - val_accuracy: 0.7786
# Epoch 72/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4350 - accuracy: 0.7778 - val_loss: 0.4322 - val_accuracy: 0.7804
# Epoch 73/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4351 - accuracy: 0.7777 - val_loss: 0.4317 - val_accuracy: 0.7806
# Epoch 74/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4347 - accuracy: 0.7782 - val_loss: 0.4305 - val_accuracy: 0.7790
# Epoch 75/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4344 - accuracy: 0.7784 - val_loss: 0.4336 - val_accuracy: 0.7753
# Epoch 76/190
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4343 - accuracy: 0.7784 - val_loss: 0.4301 - val_accuracy: 0.7802
# Epoch 77/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4340 - accuracy: 0.7782 - val_loss: 0.4308 - val_accuracy: 0.7796
# Epoch 78/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4337 - accuracy: 0.7783 - val_loss: 0.4299 - val_accuracy: 0.7800
# Epoch 79/190
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4335 - accuracy: 0.7787 - val_loss: 0.4330 - val_accuracy: 0.7774
# Epoch 80/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4331 - accuracy: 0.7784 - val_loss: 0.4308 - val_accuracy: 0.7807
# Epoch 81/190
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4330 - accuracy: 0.7789 - val_loss: 0.4276 - val_accuracy: 0.7815
# Epoch 82/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4326 - accuracy: 0.7793 - val_loss: 0.4286 - val_accuracy: 0.7814
# Epoch 83/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4324 - accuracy: 0.7792 - val_loss: 0.4299 - val_accuracy: 0.7816
# Epoch 84/190
# 2971/2971 [==============================] - 441s 148ms/step - loss: 0.4323 - accuracy: 0.7790 - val_loss: 0.4287 - val_accuracy: 0.7820
# Epoch 85/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4319 - accuracy: 0.7796 - val_loss: 0.4301 - val_accuracy: 0.7809
# Epoch 86/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4315 - accuracy: 0.7795 - val_loss: 0.4272 - val_accuracy: 0.7815
# Epoch 87/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4315 - accuracy: 0.7798 - val_loss: 0.4282 - val_accuracy: 0.7814
# Epoch 88/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4313 - accuracy: 0.7798 - val_loss: 0.4273 - val_accuracy: 0.7815
# Epoch 89/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4310 - accuracy: 0.7799 - val_loss: 0.4289 - val_accuracy: 0.7826
# Epoch 90/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4307 - accuracy: 0.7797 - val_loss: 0.4390 - val_accuracy: 0.7753
# Epoch 91/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4306 - accuracy: 0.7799 - val_loss: 0.4335 - val_accuracy: 0.7772
# Epoch 92/190
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4304 - accuracy: 0.7801 - val_loss: 0.4339 - val_accuracy: 0.7768
# Epoch 93/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4304 - accuracy: 0.7801 - val_loss: 0.4299 - val_accuracy: 0.7798
# Epoch 94/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4300 - accuracy: 0.7801 - val_loss: 0.4318 - val_accuracy: 0.7791
# Epoch 95/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4297 - accuracy: 0.7803 - val_loss: 0.4265 - val_accuracy: 0.7819
# Epoch 96/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4294 - accuracy: 0.7804 - val_loss: 0.4313 - val_accuracy: 0.7777
# Epoch 97/190
# 2971/2971 [==============================] - 435s 147ms/step - loss: 0.4294 - accuracy: 0.7805 - val_loss: 0.4293 - val_accuracy: 0.7812
# Epoch 98/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4293 - accuracy: 0.7809 - val_loss: 0.4249 - val_accuracy: 0.7836
# Epoch 99/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4289 - accuracy: 0.7813 - val_loss: 0.4283 - val_accuracy: 0.7816
# Epoch 100/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4288 - accuracy: 0.7813 - val_loss: 0.4279 - val_accuracy: 0.7818
# Epoch 101/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4286 - accuracy: 0.7812 - val_loss: 0.4266 - val_accuracy: 0.7838
# Epoch 102/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4285 - accuracy: 0.7810 - val_loss: 0.4257 - val_accuracy: 0.7833
# Epoch 103/190
# 2971/2971 [==============================] - 435s 147ms/step - loss: 0.4284 - accuracy: 0.7809 - val_loss: 0.4284 - val_accuracy: 0.7818
# Epoch 104/190
# 2971/2971 [==============================] - 434s 146ms/step - loss: 0.4283 - accuracy: 0.7814 - val_loss: 0.4290 - val_accuracy: 0.7791
# Epoch 105/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4279 - accuracy: 0.7810 - val_loss: 0.4249 - val_accuracy: 0.7824
# Epoch 106/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4278 - accuracy: 0.7814 - val_loss: 0.4282 - val_accuracy: 0.7827
# Epoch 107/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4276 - accuracy: 0.7816 - val_loss: 0.4307 - val_accuracy: 0.7825
# Epoch 108/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4276 - accuracy: 0.7819 - val_loss: 0.4245 - val_accuracy: 0.7827
# Epoch 109/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4274 - accuracy: 0.7814 - val_loss: 0.4296 - val_accuracy: 0.7783
# Epoch 110/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4273 - accuracy: 0.7817 - val_loss: 0.4282 - val_accuracy: 0.7816
# Epoch 111/190
# 2971/2971 [==============================] - 435s 147ms/step - loss: 0.4271 - accuracy: 0.7820 - val_loss: 0.4265 - val_accuracy: 0.7822
# Epoch 112/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4272 - accuracy: 0.7823 - val_loss: 0.4356 - val_accuracy: 0.7821
# Epoch 113/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4270 - accuracy: 0.7817 - val_loss: 0.4249 - val_accuracy: 0.7831
# Epoch 114/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4269 - accuracy: 0.7822 - val_loss: 0.4273 - val_accuracy: 0.7813
# Epoch 115/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4267 - accuracy: 0.7824 - val_loss: 0.4254 - val_accuracy: 0.7825
# Epoch 116/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4264 - accuracy: 0.7820 - val_loss: 0.4287 - val_accuracy: 0.7803
# Epoch 117/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4264 - accuracy: 0.7820 - val_loss: 0.4277 - val_accuracy: 0.7833
# Epoch 118/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4262 - accuracy: 0.7826 - val_loss: 0.4270 - val_accuracy: 0.7821
# Epoch 119/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4260 - accuracy: 0.7826 - val_loss: 0.4256 - val_accuracy: 0.7832
# Epoch 120/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4259 - accuracy: 0.7828 - val_loss: 0.4264 - val_accuracy: 0.7819
# Epoch 121/190
# 2971/2971 [==============================] - 435s 146ms/step - loss: 0.4257 - accuracy: 0.7824 - val_loss: 0.4283 - val_accuracy: 0.7825
# Epoch 122/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4257 - accuracy: 0.7826 - val_loss: 0.4270 - val_accuracy: 0.7827
# Epoch 123/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4255 - accuracy: 0.7827 - val_loss: 0.4307 - val_accuracy: 0.7844
# Epoch 124/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4255 - accuracy: 0.7825 - val_loss: 0.4247 - val_accuracy: 0.7836
# Epoch 125/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4251 - accuracy: 0.7832 - val_loss: 0.4346 - val_accuracy: 0.7813
# Epoch 126/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4252 - accuracy: 0.7832 - val_loss: 0.4245 - val_accuracy: 0.7826
# Epoch 127/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4250 - accuracy: 0.7831 - val_loss: 0.4254 - val_accuracy: 0.7830
# Epoch 128/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4249 - accuracy: 0.7830 - val_loss: 0.4247 - val_accuracy: 0.7828
# Epoch 129/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4247 - accuracy: 0.7834 - val_loss: 0.4243 - val_accuracy: 0.7831
# Epoch 130/190
# 2971/2971 [==============================] - 452s 152ms/step - loss: 0.4246 - accuracy: 0.7833 - val_loss: 0.4279 - val_accuracy: 0.7836
# Epoch 131/190
# 2971/2971 [==============================] - 448s 151ms/step - loss: 0.4245 - accuracy: 0.7832 - val_loss: 0.4240 - val_accuracy: 0.7824
# Epoch 132/190
# 2971/2971 [==============================] - 443s 149ms/step - loss: 0.4243 - accuracy: 0.7834 - val_loss: 0.4271 - val_accuracy: 0.7821
# Epoch 133/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4243 - accuracy: 0.7832 - val_loss: 0.4271 - val_accuracy: 0.7792
# Epoch 134/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4242 - accuracy: 0.7836 - val_loss: 0.4264 - val_accuracy: 0.7817
# Epoch 135/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4241 - accuracy: 0.7834 - val_loss: 0.4259 - val_accuracy: 0.7810
# Epoch 136/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4237 - accuracy: 0.7834 - val_loss: 0.4230 - val_accuracy: 0.7835
# Epoch 137/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4238 - accuracy: 0.7837 - val_loss: 0.4252 - val_accuracy: 0.7817
# Epoch 138/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4238 - accuracy: 0.7836 - val_loss: 0.4242 - val_accuracy: 0.7824
# Epoch 139/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4237 - accuracy: 0.7836 - val_loss: 0.4231 - val_accuracy: 0.7831
# Epoch 140/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4236 - accuracy: 0.7833 - val_loss: 0.4258 - val_accuracy: 0.7822
# Epoch 141/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4234 - accuracy: 0.7838 - val_loss: 0.4247 - val_accuracy: 0.7837
# Epoch 142/190
# 2971/2971 [==============================] - 440s 148ms/step - loss: 0.4232 - accuracy: 0.7838 - val_loss: 0.4262 - val_accuracy: 0.7814
# Epoch 143/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4232 - accuracy: 0.7837 - val_loss: 0.4282 - val_accuracy: 0.7820
# Epoch 144/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4231 - accuracy: 0.7837 - val_loss: 0.4245 - val_accuracy: 0.7843
# Epoch 145/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4231 - accuracy: 0.7837 - val_loss: 0.4257 - val_accuracy: 0.7823
# Epoch 146/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4229 - accuracy: 0.7837 - val_loss: 0.4231 - val_accuracy: 0.7843
# Epoch 147/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4226 - accuracy: 0.7840 - val_loss: 0.4231 - val_accuracy: 0.7840
# Epoch 148/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4226 - accuracy: 0.7840 - val_loss: 0.4260 - val_accuracy: 0.7824
# Epoch 149/190
# 2971/2971 [==============================] - 441s 148ms/step - loss: 0.4227 - accuracy: 0.7843 - val_loss: 0.4239 - val_accuracy: 0.7820
# Epoch 150/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4224 - accuracy: 0.7840 - val_loss: 0.4236 - val_accuracy: 0.7840
# Epoch 151/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4223 - accuracy: 0.7843 - val_loss: 0.4240 - val_accuracy: 0.7815
# Epoch 152/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4221 - accuracy: 0.7844 - val_loss: 0.4220 - val_accuracy: 0.7839
# Epoch 153/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4221 - accuracy: 0.7845 - val_loss: 0.4229 - val_accuracy: 0.7839
# Epoch 154/190
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4221 - accuracy: 0.7844 - val_loss: 0.4273 - val_accuracy: 0.7843
# Epoch 155/190
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4217 - accuracy: 0.7846 - val_loss: 0.4260 - val_accuracy: 0.7837
# Epoch 156/190
# 2971/2971 [==============================] - 440s 148ms/step - loss: 0.4217 - accuracy: 0.7843 - val_loss: 0.4256 - val_accuracy: 0.7819
# Epoch 157/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4216 - accuracy: 0.7845 - val_loss: 0.4239 - val_accuracy: 0.7833
# Epoch 158/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4215 - accuracy: 0.7842 - val_loss: 0.4284 - val_accuracy: 0.7791
# Epoch 159/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4215 - accuracy: 0.7847 - val_loss: 0.4230 - val_accuracy: 0.7827
# Epoch 160/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4214 - accuracy: 0.7852 - val_loss: 0.4261 - val_accuracy: 0.7801
# Epoch 161/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4212 - accuracy: 0.7849 - val_loss: 0.4283 - val_accuracy: 0.7786
# Epoch 162/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4211 - accuracy: 0.7850 - val_loss: 0.4275 - val_accuracy: 0.7810
# Epoch 163/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4209 - accuracy: 0.7850 - val_loss: 0.4323 - val_accuracy: 0.7850
# Epoch 164/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4208 - accuracy: 0.7850 - val_loss: 0.4255 - val_accuracy: 0.7797
# Epoch 165/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4207 - accuracy: 0.7850 - val_loss: 0.4263 - val_accuracy: 0.7848
# Epoch 166/190
# 2971/2971 [==============================] - 440s 148ms/step - loss: 0.4206 - accuracy: 0.7854 - val_loss: 0.4240 - val_accuracy: 0.7841
# Epoch 167/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4204 - accuracy: 0.7850 - val_loss: 0.4231 - val_accuracy: 0.7847
# Epoch 168/190
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4203 - accuracy: 0.7853 - val_loss: 0.4263 - val_accuracy: 0.7831
# Epoch 169/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4203 - accuracy: 0.7850 - val_loss: 0.4232 - val_accuracy: 0.7831
# Epoch 170/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4202 - accuracy: 0.7850 - val_loss: 0.4241 - val_accuracy: 0.7815
# Epoch 171/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4201 - accuracy: 0.7848 - val_loss: 0.4252 - val_accuracy: 0.7821
# Epoch 172/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4200 - accuracy: 0.7855 - val_loss: 0.4342 - val_accuracy: 0.7821
# Epoch 173/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4199 - accuracy: 0.7852 - val_loss: 0.4240 - val_accuracy: 0.7828
# Epoch 174/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4199 - accuracy: 0.7859 - val_loss: 0.4257 - val_accuracy: 0.7841
# Epoch 175/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4196 - accuracy: 0.7853 - val_loss: 0.4268 - val_accuracy: 0.7818
# Epoch 176/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4196 - accuracy: 0.7857 - val_loss: 0.4254 - val_accuracy: 0.7838
# Epoch 177/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4195 - accuracy: 0.7855 - val_loss: 0.4263 - val_accuracy: 0.7799
# Epoch 178/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4194 - accuracy: 0.7857 - val_loss: 0.4220 - val_accuracy: 0.7847
# Epoch 179/190
# 2971/2971 [==============================] - 438s 147ms/step - loss: 0.4193 - accuracy: 0.7856 - val_loss: 0.4266 - val_accuracy: 0.7794
# Epoch 180/190
# 2971/2971 [==============================] - 450s 151ms/step - loss: 0.4193 - accuracy: 0.7859 - val_loss: 0.4233 - val_accuracy: 0.7832
# Epoch 181/190
# 2971/2971 [==============================] - 465s 156ms/step - loss: 0.4190 - accuracy: 0.7856 - val_loss: 0.4242 - val_accuracy: 0.7839
# Epoch 182/190
# 2971/2971 [==============================] - 450s 151ms/step - loss: 0.4189 - accuracy: 0.7858 - val_loss: 0.4235 - val_accuracy: 0.7837
# Epoch 183/190
# 2971/2971 [==============================] - 438s 148ms/step - loss: 0.4189 - accuracy: 0.7859 - val_loss: 0.4237 - val_accuracy: 0.7826
# Epoch 184/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4189 - accuracy: 0.7855 - val_loss: 0.4250 - val_accuracy: 0.7809
# Epoch 185/190
# 2971/2971 [==============================] - 442s 149ms/step - loss: 0.4187 - accuracy: 0.7860 - val_loss: 0.4283 - val_accuracy: 0.7800
# Epoch 186/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4187 - accuracy: 0.7859 - val_loss: 0.4240 - val_accuracy: 0.7823
# Epoch 187/190
# 2971/2971 [==============================] - 440s 148ms/step - loss: 0.4185 - accuracy: 0.7858 - val_loss: 0.4255 - val_accuracy: 0.7834
# Epoch 188/190
# 2971/2971 [==============================] - 436s 147ms/step - loss: 0.4185 - accuracy: 0.7860 - val_loss: 0.4282 - val_accuracy: 0.7832
# Epoch 189/190
# 2971/2971 [==============================] - 439s 148ms/step - loss: 0.4184 - accuracy: 0.7859 - val_loss: 0.4267 - val_accuracy: 0.7810
# Epoch 190/190
# 2971/2971 [==============================] - 437s 147ms/step - loss: 0.4183 - accuracy: 0.7867 - val_loss: 0.4259 - val_accuracy: 0.7819

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 49s 16ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 83297.95506286621

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00200884],
#        [0.00257719],
#        [0.00055036],
#        ...,
#        [0.03630038],
#        [0.0382525 ],
#        [0.03984468]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14257986031452477
# 0.2332935917619552
# 0.37759748451826947
# 0.2810345755328642

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 203s 14ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.59963892]
# [0.83726079]
# total acc [0.78547971]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
