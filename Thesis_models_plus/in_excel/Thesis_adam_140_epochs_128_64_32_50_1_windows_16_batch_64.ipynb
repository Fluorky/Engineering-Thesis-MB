# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x22c99cb9040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x22cd3d21040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=64)#, shuffle=False)
# Out:
# Epoch 1/140
# 5942/5942 [==============================] - 117s 18ms/step - loss: 0.4655 - accuracy: 0.7617 - val_loss: 0.4354 - val_accuracy: 0.7780
# Epoch 2/140
# 5942/5942 [==============================] - 109s 18ms/step - loss: 0.4440 - accuracy: 0.7748 - val_loss: 0.4302 - val_accuracy: 0.7823
# Epoch 3/140
# 5942/5942 [==============================] - 108s 18ms/step - loss: 0.4362 - accuracy: 0.7795 - val_loss: 0.4239 - val_accuracy: 0.7836
# Epoch 4/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.4307 - accuracy: 0.7812 - val_loss: 0.4250 - val_accuracy: 0.7860
# Epoch 5/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4272 - accuracy: 0.7836 - val_loss: 0.4318 - val_accuracy: 0.7855
# Epoch 6/140
# 5942/5942 [==============================] - 106s 18ms/step - loss: 0.4239 - accuracy: 0.7852 - val_loss: 0.4328 - val_accuracy: 0.7744
# Epoch 7/140
# 5942/5942 [==============================] - 104s 17ms/step - loss: 0.4210 - accuracy: 0.7860 - val_loss: 0.4241 - val_accuracy: 0.7858
# Epoch 8/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.4182 - accuracy: 0.7871 - val_loss: 0.4292 - val_accuracy: 0.7828
# Epoch 9/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4154 - accuracy: 0.7884 - val_loss: 0.4289 - val_accuracy: 0.7812
# Epoch 10/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4132 - accuracy: 0.7895 - val_loss: 0.4267 - val_accuracy: 0.7840
# Epoch 11/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4108 - accuracy: 0.7909 - val_loss: 0.4511 - val_accuracy: 0.7831
# Epoch 12/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4083 - accuracy: 0.7917 - val_loss: 0.4254 - val_accuracy: 0.7842
# Epoch 13/140
# 5942/5942 [==============================] - 98s 17ms/step - loss: 0.4063 - accuracy: 0.7925 - val_loss: 0.4382 - val_accuracy: 0.7778
# Epoch 14/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4042 - accuracy: 0.7934 - val_loss: 0.4480 - val_accuracy: 0.7835
# Epoch 15/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4023 - accuracy: 0.7938 - val_loss: 0.4322 - val_accuracy: 0.7849
# Epoch 16/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4006 - accuracy: 0.7950 - val_loss: 0.4353 - val_accuracy: 0.7803
# Epoch 17/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3989 - accuracy: 0.7959 - val_loss: 0.4360 - val_accuracy: 0.7773
# Epoch 18/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3973 - accuracy: 0.7967 - val_loss: 0.4392 - val_accuracy: 0.7782
# Epoch 19/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3957 - accuracy: 0.7972 - val_loss: 0.4375 - val_accuracy: 0.7784
# Epoch 20/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3949 - accuracy: 0.7981 - val_loss: 0.4449 - val_accuracy: 0.7790
# Epoch 21/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3934 - accuracy: 0.7985 - val_loss: 0.4366 - val_accuracy: 0.7728
# Epoch 22/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3918 - accuracy: 0.7997 - val_loss: 0.4395 - val_accuracy: 0.7775
# Epoch 23/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3912 - accuracy: 0.7996 - val_loss: 0.4436 - val_accuracy: 0.7792
# Epoch 24/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3900 - accuracy: 0.8003 - val_loss: 0.4440 - val_accuracy: 0.7766
# Epoch 25/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3893 - accuracy: 0.8007 - val_loss: 0.4444 - val_accuracy: 0.7740
# Epoch 26/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3887 - accuracy: 0.8012 - val_loss: 0.4554 - val_accuracy: 0.7788
# Epoch 27/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3878 - accuracy: 0.8011 - val_loss: 0.4418 - val_accuracy: 0.7776
# Epoch 28/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3873 - accuracy: 0.8019 - val_loss: 0.4523 - val_accuracy: 0.7755
# Epoch 29/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3866 - accuracy: 0.8019 - val_loss: 0.4468 - val_accuracy: 0.7762
# Epoch 30/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3863 - accuracy: 0.8021 - val_loss: 0.4478 - val_accuracy: 0.7743
# Epoch 31/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3853 - accuracy: 0.8024 - val_loss: 0.4562 - val_accuracy: 0.7770
# Epoch 32/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3845 - accuracy: 0.8031 - val_loss: 0.4482 - val_accuracy: 0.7803
# Epoch 33/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3841 - accuracy: 0.8031 - val_loss: 0.4583 - val_accuracy: 0.7778
# Epoch 34/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3840 - accuracy: 0.8029 - val_loss: 0.4606 - val_accuracy: 0.7781
# Epoch 35/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.3838 - accuracy: 0.8031 - val_loss: 0.4583 - val_accuracy: 0.7748
# Epoch 36/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.3830 - accuracy: 0.8040 - val_loss: 0.4522 - val_accuracy: 0.7688
# Epoch 37/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3827 - accuracy: 0.8032 - val_loss: 0.4590 - val_accuracy: 0.7790
# Epoch 38/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3829 - accuracy: 0.8040 - val_loss: 0.4461 - val_accuracy: 0.7744
# Epoch 39/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3823 - accuracy: 0.8041 - val_loss: 0.4553 - val_accuracy: 0.7770
# Epoch 40/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3832 - accuracy: 0.8035 - val_loss: 0.4775 - val_accuracy: 0.7808
# Epoch 41/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3837 - accuracy: 0.8033 - val_loss: 0.4591 - val_accuracy: 0.7780
# Epoch 42/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3823 - accuracy: 0.8043 - val_loss: 0.4660 - val_accuracy: 0.7812
# Epoch 43/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3826 - accuracy: 0.8041 - val_loss: 0.4555 - val_accuracy: 0.7773
# Epoch 44/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3832 - accuracy: 0.8044 - val_loss: 0.4546 - val_accuracy: 0.7736
# Epoch 45/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3824 - accuracy: 0.8044 - val_loss: 0.4502 - val_accuracy: 0.7697
# Epoch 46/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3819 - accuracy: 0.8042 - val_loss: 0.4638 - val_accuracy: 0.7735
# Epoch 47/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.3821 - accuracy: 0.8049 - val_loss: 0.4542 - val_accuracy: 0.7720
# Epoch 48/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3818 - accuracy: 0.8047 - val_loss: 0.4592 - val_accuracy: 0.7752
# Epoch 49/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3822 - accuracy: 0.8046 - val_loss: 0.4574 - val_accuracy: 0.7774
# Epoch 50/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3824 - accuracy: 0.8048 - val_loss: 0.4614 - val_accuracy: 0.7774
# Epoch 51/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3824 - accuracy: 0.8044 - val_loss: 0.4586 - val_accuracy: 0.7755
# Epoch 52/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3822 - accuracy: 0.8050 - val_loss: 0.4591 - val_accuracy: 0.7735
# Epoch 53/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.3824 - accuracy: 0.8048 - val_loss: 0.4509 - val_accuracy: 0.7742
# Epoch 54/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3822 - accuracy: 0.8043 - val_loss: 0.4581 - val_accuracy: 0.7761
# Epoch 55/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3832 - accuracy: 0.8045 - val_loss: 0.4530 - val_accuracy: 0.7717
# Epoch 56/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3827 - accuracy: 0.8040 - val_loss: 0.4690 - val_accuracy: 0.7772
# Epoch 57/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3829 - accuracy: 0.8037 - val_loss: 0.4542 - val_accuracy: 0.7734
# Epoch 58/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3825 - accuracy: 0.8043 - val_loss: 0.4585 - val_accuracy: 0.7738
# Epoch 59/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3829 - accuracy: 0.8039 - val_loss: 0.4507 - val_accuracy: 0.7680
# Epoch 60/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3826 - accuracy: 0.8042 - val_loss: 0.4551 - val_accuracy: 0.7767
# Epoch 61/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3823 - accuracy: 0.8048 - val_loss: 0.4515 - val_accuracy: 0.7686
# Epoch 62/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3834 - accuracy: 0.8045 - val_loss: 0.4565 - val_accuracy: 0.7781
# Epoch 63/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3836 - accuracy: 0.8041 - val_loss: 0.4501 - val_accuracy: 0.7737
# Epoch 64/140
# 5942/5942 [==============================] - 98s 16ms/step - loss: 0.3835 - accuracy: 0.8046 - val_loss: 0.4662 - val_accuracy: 0.7721
# Epoch 65/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3841 - accuracy: 0.8041 - val_loss: 0.4493 - val_accuracy: 0.7702
# Epoch 66/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3847 - accuracy: 0.8032 - val_loss: 0.4594 - val_accuracy: 0.7748
# Epoch 67/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3836 - accuracy: 0.8045 - val_loss: 0.4533 - val_accuracy: 0.7725
# Epoch 68/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3852 - accuracy: 0.8036 - val_loss: 0.4564 - val_accuracy: 0.7699
# Epoch 69/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3839 - accuracy: 0.8041 - val_loss: 0.4561 - val_accuracy: 0.7721
# Epoch 70/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3849 - accuracy: 0.8036 - val_loss: 0.4584 - val_accuracy: 0.7706
# Epoch 71/140
# 5942/5942 [==============================] - 98s 17ms/step - loss: 0.3859 - accuracy: 0.8032 - val_loss: 0.4560 - val_accuracy: 0.7736
# Epoch 72/140
# 5942/5942 [==============================] - 98s 17ms/step - loss: 0.3870 - accuracy: 0.8025 - val_loss: 0.4549 - val_accuracy: 0.7752
# Epoch 73/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3867 - accuracy: 0.8025 - val_loss: 0.4600 - val_accuracy: 0.7770
# Epoch 74/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3890 - accuracy: 0.8014 - val_loss: 0.4582 - val_accuracy: 0.7695
# Epoch 75/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3899 - accuracy: 0.8016 - val_loss: 0.4657 - val_accuracy: 0.7745
# Epoch 76/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3883 - accuracy: 0.8016 - val_loss: 0.4498 - val_accuracy: 0.7682
# Epoch 77/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.3885 - accuracy: 0.8010 - val_loss: 0.4688 - val_accuracy: 0.7750
# Epoch 78/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3887 - accuracy: 0.8014 - val_loss: 0.4484 - val_accuracy: 0.7732
# Epoch 79/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3879 - accuracy: 0.8020 - val_loss: 0.4614 - val_accuracy: 0.7774
# Epoch 80/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3906 - accuracy: 0.8011 - val_loss: 0.4483 - val_accuracy: 0.7719
# Epoch 81/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3892 - accuracy: 0.8011 - val_loss: 0.4475 - val_accuracy: 0.7745
# Epoch 82/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3907 - accuracy: 0.8005 - val_loss: 0.4598 - val_accuracy: 0.7780
# Epoch 83/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3899 - accuracy: 0.8008 - val_loss: 0.4629 - val_accuracy: 0.7774
# Epoch 84/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3887 - accuracy: 0.8012 - val_loss: 0.4459 - val_accuracy: 0.7690
# Epoch 85/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3900 - accuracy: 0.8009 - val_loss: 0.4588 - val_accuracy: 0.7773
# Epoch 86/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3898 - accuracy: 0.8008 - val_loss: 0.4505 - val_accuracy: 0.7767
# Epoch 87/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3898 - accuracy: 0.8016 - val_loss: 0.4533 - val_accuracy: 0.7734
# Epoch 88/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3897 - accuracy: 0.8013 - val_loss: 0.4512 - val_accuracy: 0.7788
# Epoch 89/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3904 - accuracy: 0.8006 - val_loss: 0.4520 - val_accuracy: 0.7747
# Epoch 90/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3928 - accuracy: 0.8003 - val_loss: 0.4519 - val_accuracy: 0.7744
# Epoch 91/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3927 - accuracy: 0.7997 - val_loss: 0.4420 - val_accuracy: 0.7762
# Epoch 92/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3944 - accuracy: 0.7988 - val_loss: 0.4464 - val_accuracy: 0.7722
# Epoch 93/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3947 - accuracy: 0.7986 - val_loss: 0.4536 - val_accuracy: 0.7774
# Epoch 94/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3959 - accuracy: 0.7985 - val_loss: 0.4442 - val_accuracy: 0.7793
# Epoch 95/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.3952 - accuracy: 0.7988 - val_loss: 0.4417 - val_accuracy: 0.7766
# Epoch 96/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3974 - accuracy: 0.7975 - val_loss: 0.4428 - val_accuracy: 0.7767
# Epoch 97/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3977 - accuracy: 0.7977 - val_loss: 0.4464 - val_accuracy: 0.7736
# Epoch 98/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.3982 - accuracy: 0.7973 - val_loss: 0.4466 - val_accuracy: 0.7772
# Epoch 99/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4008 - accuracy: 0.7959 - val_loss: 0.4412 - val_accuracy: 0.7716
# Epoch 100/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4025 - accuracy: 0.7947 - val_loss: 0.4391 - val_accuracy: 0.7754
# Epoch 101/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4045 - accuracy: 0.7936 - val_loss: 0.4372 - val_accuracy: 0.7793
# Epoch 102/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4071 - accuracy: 0.7929 - val_loss: 0.4537 - val_accuracy: 0.7783
# Epoch 103/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4050 - accuracy: 0.7941 - val_loss: 0.4528 - val_accuracy: 0.7776
# Epoch 104/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.4074 - accuracy: 0.7930 - val_loss: 0.4384 - val_accuracy: 0.7737
# Epoch 105/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4105 - accuracy: 0.7907 - val_loss: 0.4368 - val_accuracy: 0.7725
# Epoch 106/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4102 - accuracy: 0.7913 - val_loss: 0.4482 - val_accuracy: 0.7703
# Epoch 107/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4100 - accuracy: 0.7911 - val_loss: 0.4383 - val_accuracy: 0.7761
# Epoch 108/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.4144 - accuracy: 0.7898 - val_loss: 0.4378 - val_accuracy: 0.7774
# Epoch 109/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4179 - accuracy: 0.7879 - val_loss: 0.4347 - val_accuracy: 0.7813
# Epoch 110/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4180 - accuracy: 0.7874 - val_loss: 0.4466 - val_accuracy: 0.7783
# Epoch 111/140
# 5942/5942 [==============================] - 98s 17ms/step - loss: 0.4188 - accuracy: 0.7871 - val_loss: 0.4389 - val_accuracy: 0.7729
# Epoch 112/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4175 - accuracy: 0.7875 - val_loss: 0.4382 - val_accuracy: 0.7776
# Epoch 113/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4258 - accuracy: 0.7841 - val_loss: 0.4439 - val_accuracy: 0.7829
# Epoch 114/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4223 - accuracy: 0.7852 - val_loss: 0.4290 - val_accuracy: 0.7825
# Epoch 115/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4217 - accuracy: 0.7854 - val_loss: 0.4310 - val_accuracy: 0.7812
# Epoch 116/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4225 - accuracy: 0.7859 - val_loss: 0.4345 - val_accuracy: 0.7804
# Epoch 117/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4228 - accuracy: 0.7844 - val_loss: 0.4289 - val_accuracy: 0.7807
# Epoch 118/140
# 5942/5942 [==============================] - 98s 17ms/step - loss: 0.4215 - accuracy: 0.7852 - val_loss: 0.4388 - val_accuracy: 0.7783
# Epoch 119/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4204 - accuracy: 0.7861 - val_loss: 0.4305 - val_accuracy: 0.7811
# Epoch 120/140
# 5942/5942 [==============================] - 98s 17ms/step - loss: 0.4209 - accuracy: 0.7860 - val_loss: 0.4337 - val_accuracy: 0.7787
# Epoch 121/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4222 - accuracy: 0.7849 - val_loss: 0.4310 - val_accuracy: 0.7792
# Epoch 122/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4213 - accuracy: 0.7853 - val_loss: 0.4300 - val_accuracy: 0.7804
# Epoch 123/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4207 - accuracy: 0.7857 - val_loss: 0.4286 - val_accuracy: 0.7781
# Epoch 124/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4244 - accuracy: 0.7838 - val_loss: 0.4305 - val_accuracy: 0.7797
# Epoch 125/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4226 - accuracy: 0.7852 - val_loss: 0.4355 - val_accuracy: 0.7816
# Epoch 126/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4236 - accuracy: 0.7845 - val_loss: 0.4327 - val_accuracy: 0.7836
# Epoch 127/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4252 - accuracy: 0.7841 - val_loss: 0.4350 - val_accuracy: 0.7803
# Epoch 128/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4272 - accuracy: 0.7824 - val_loss: 0.4253 - val_accuracy: 0.7829
# Epoch 129/140
# 5942/5942 [==============================] - 101s 17ms/step - loss: 0.4238 - accuracy: 0.7841 - val_loss: 0.4313 - val_accuracy: 0.7786
# Epoch 130/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4213 - accuracy: 0.7857 - val_loss: 0.4279 - val_accuracy: 0.7830
# Epoch 131/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4246 - accuracy: 0.7840 - val_loss: 0.4318 - val_accuracy: 0.7793
# Epoch 132/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4224 - accuracy: 0.7846 - val_loss: 0.4326 - val_accuracy: 0.7844
# Epoch 133/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.4212 - accuracy: 0.7852 - val_loss: 0.4306 - val_accuracy: 0.7792
# Epoch 134/140
# 5942/5942 [==============================] - 104s 18ms/step - loss: 0.4217 - accuracy: 0.7852 - val_loss: 0.4272 - val_accuracy: 0.7829
# Epoch 135/140
# 5942/5942 [==============================] - 102s 17ms/step - loss: 0.4230 - accuracy: 0.7851 - val_loss: 0.4288 - val_accuracy: 0.7812
# Epoch 136/140
# 5942/5942 [==============================] - 105s 18ms/step - loss: 0.4221 - accuracy: 0.7850 - val_loss: 0.4293 - val_accuracy: 0.7828
# Epoch 137/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4224 - accuracy: 0.7849 - val_loss: 0.4301 - val_accuracy: 0.7841
# Epoch 138/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4201 - accuracy: 0.7860 - val_loss: 0.4299 - val_accuracy: 0.7834
# Epoch 139/140
# 5942/5942 [==============================] - 99s 17ms/step - loss: 0.4191 - accuracy: 0.7862 - val_loss: 0.4286 - val_accuracy: 0.7845
# Epoch 140/140
# 5942/5942 [==============================] - 100s 17ms/step - loss: 0.4208 - accuracy: 0.7860 - val_loss: 0.4420 - val_accuracy: 0.7746

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 14051.078062534332

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.0028248 ],
#        [0.00262721],
#        [0.00213577],
#        ...,
#        [0.12043821],
#        [0.11903119],
#        [0.12249259]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14732388174615613
# 0.20778317518259593
# 0.38382793247255487
# 0.29815689585322336

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 74s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.5883214]
# [0.81796802]
# total acc [0.77505938]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
