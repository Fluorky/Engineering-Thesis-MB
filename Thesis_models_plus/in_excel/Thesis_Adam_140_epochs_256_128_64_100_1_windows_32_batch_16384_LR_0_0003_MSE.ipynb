# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1d41ef79040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1d493039040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0003)
model_gru.compile(loss='MSE', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           209664
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 15s 354ms/step - loss: 0.1956 - accuracy: 0.7393 - val_loss: 0.1856 - val_accuracy: 0.7530
# Epoch 2/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1878 - accuracy: 0.7392 - val_loss: 0.1787 - val_accuracy: 0.7462
# Epoch 3/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1780 - accuracy: 0.7384 - val_loss: 0.1703 - val_accuracy: 0.7438
# Epoch 4/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1716 - accuracy: 0.7390 - val_loss: 0.1646 - val_accuracy: 0.7526
# Epoch 5/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1697 - accuracy: 0.7403 - val_loss: 0.1633 - val_accuracy: 0.7535
# Epoch 6/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1688 - accuracy: 0.7413 - val_loss: 0.1655 - val_accuracy: 0.7533
# Epoch 7/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1679 - accuracy: 0.7428 - val_loss: 0.1618 - val_accuracy: 0.7544
# Epoch 8/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1666 - accuracy: 0.7457 - val_loss: 0.1610 - val_accuracy: 0.7538
# Epoch 9/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1642 - accuracy: 0.7482 - val_loss: 0.1633 - val_accuracy: 0.7499
# Epoch 10/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1622 - accuracy: 0.7507 - val_loss: 0.1594 - val_accuracy: 0.7577
# Epoch 11/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1598 - accuracy: 0.7547 - val_loss: 0.1567 - val_accuracy: 0.7609
# Epoch 12/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1583 - accuracy: 0.7568 - val_loss: 0.1572 - val_accuracy: 0.7571
# Epoch 13/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1575 - accuracy: 0.7575 - val_loss: 0.1540 - val_accuracy: 0.7631
# Epoch 14/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1565 - accuracy: 0.7588 - val_loss: 0.1524 - val_accuracy: 0.7642
# Epoch 15/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1566 - accuracy: 0.7591 - val_loss: 0.1528 - val_accuracy: 0.7646
# Epoch 16/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1551 - accuracy: 0.7606 - val_loss: 0.1516 - val_accuracy: 0.7667
# Epoch 17/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1543 - accuracy: 0.7615 - val_loss: 0.1511 - val_accuracy: 0.7671
# Epoch 18/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1538 - accuracy: 0.7620 - val_loss: 0.1516 - val_accuracy: 0.7666
# Epoch 19/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1538 - accuracy: 0.7628 - val_loss: 0.1510 - val_accuracy: 0.7680
# Epoch 20/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1534 - accuracy: 0.7638 - val_loss: 0.1504 - val_accuracy: 0.7681
# Epoch 21/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1530 - accuracy: 0.7641 - val_loss: 0.1518 - val_accuracy: 0.7680
# Epoch 22/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1526 - accuracy: 0.7651 - val_loss: 0.1501 - val_accuracy: 0.7688
# Epoch 23/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1525 - accuracy: 0.7656 - val_loss: 0.1502 - val_accuracy: 0.7705
# Epoch 24/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1526 - accuracy: 0.7657 - val_loss: 0.1509 - val_accuracy: 0.7712
# Epoch 25/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1523 - accuracy: 0.7665 - val_loss: 0.1493 - val_accuracy: 0.7701
# Epoch 26/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1515 - accuracy: 0.7665 - val_loss: 0.1487 - val_accuracy: 0.7729
# Epoch 27/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1515 - accuracy: 0.7680 - val_loss: 0.1488 - val_accuracy: 0.7726
# Epoch 28/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1511 - accuracy: 0.7679 - val_loss: 0.1492 - val_accuracy: 0.7717
# Epoch 29/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1508 - accuracy: 0.7686 - val_loss: 0.1487 - val_accuracy: 0.7734
# Epoch 30/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1505 - accuracy: 0.7689 - val_loss: 0.1480 - val_accuracy: 0.7739
# Epoch 31/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1504 - accuracy: 0.7694 - val_loss: 0.1487 - val_accuracy: 0.7739
# Epoch 32/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1504 - accuracy: 0.7696 - val_loss: 0.1479 - val_accuracy: 0.7749
# Epoch 33/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1499 - accuracy: 0.7702 - val_loss: 0.1477 - val_accuracy: 0.7749
# Epoch 34/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1499 - accuracy: 0.7705 - val_loss: 0.1477 - val_accuracy: 0.7751
# Epoch 35/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1503 - accuracy: 0.7708 - val_loss: 0.1474 - val_accuracy: 0.7757
# Epoch 36/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1494 - accuracy: 0.7715 - val_loss: 0.1471 - val_accuracy: 0.7767
# Epoch 37/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1494 - accuracy: 0.7717 - val_loss: 0.1480 - val_accuracy: 0.7756
# Epoch 38/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1491 - accuracy: 0.7722 - val_loss: 0.1474 - val_accuracy: 0.7754
# Epoch 39/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1489 - accuracy: 0.7728 - val_loss: 0.1469 - val_accuracy: 0.7766
# Epoch 40/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1489 - accuracy: 0.7727 - val_loss: 0.1468 - val_accuracy: 0.7766
# Epoch 41/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1486 - accuracy: 0.7728 - val_loss: 0.1471 - val_accuracy: 0.7771
# Epoch 42/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1487 - accuracy: 0.7733 - val_loss: 0.1471 - val_accuracy: 0.7776
# Epoch 43/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1484 - accuracy: 0.7735 - val_loss: 0.1467 - val_accuracy: 0.7764
# Epoch 44/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1483 - accuracy: 0.7739 - val_loss: 0.1471 - val_accuracy: 0.7746
# Epoch 45/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1483 - accuracy: 0.7737 - val_loss: 0.1465 - val_accuracy: 0.7776
# Epoch 46/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1479 - accuracy: 0.7743 - val_loss: 0.1462 - val_accuracy: 0.7768
# Epoch 47/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1477 - accuracy: 0.7746 - val_loss: 0.1461 - val_accuracy: 0.7776
# Epoch 48/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1478 - accuracy: 0.7746 - val_loss: 0.1464 - val_accuracy: 0.7763
# Epoch 49/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1477 - accuracy: 0.7752 - val_loss: 0.1465 - val_accuracy: 0.7765
# Epoch 50/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1477 - accuracy: 0.7754 - val_loss: 0.1465 - val_accuracy: 0.7763
# Epoch 51/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1476 - accuracy: 0.7756 - val_loss: 0.1458 - val_accuracy: 0.7783
# Epoch 52/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1471 - accuracy: 0.7761 - val_loss: 0.1458 - val_accuracy: 0.7784
# Epoch 53/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1471 - accuracy: 0.7762 - val_loss: 0.1458 - val_accuracy: 0.7783
# Epoch 54/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1472 - accuracy: 0.7763 - val_loss: 0.1464 - val_accuracy: 0.7761
# Epoch 55/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1468 - accuracy: 0.7769 - val_loss: 0.1457 - val_accuracy: 0.7789
# Epoch 56/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1467 - accuracy: 0.7772 - val_loss: 0.1463 - val_accuracy: 0.7789
# Epoch 57/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1468 - accuracy: 0.7769 - val_loss: 0.1460 - val_accuracy: 0.7782
# Epoch 58/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1468 - accuracy: 0.7767 - val_loss: 0.1459 - val_accuracy: 0.7793
# Epoch 59/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1464 - accuracy: 0.7772 - val_loss: 0.1449 - val_accuracy: 0.7791
# Epoch 60/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1462 - accuracy: 0.7776 - val_loss: 0.1470 - val_accuracy: 0.7750
# Epoch 61/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1464 - accuracy: 0.7775 - val_loss: 0.1447 - val_accuracy: 0.7803
# Epoch 62/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1460 - accuracy: 0.7777 - val_loss: 0.1452 - val_accuracy: 0.7781
# Epoch 63/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1460 - accuracy: 0.7778 - val_loss: 0.1457 - val_accuracy: 0.7796
# Epoch 64/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1458 - accuracy: 0.7782 - val_loss: 0.1456 - val_accuracy: 0.7788
# Epoch 65/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1462 - accuracy: 0.7779 - val_loss: 0.1476 - val_accuracy: 0.7771
# Epoch 66/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1462 - accuracy: 0.7776 - val_loss: 0.1454 - val_accuracy: 0.7797
# Epoch 67/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1458 - accuracy: 0.7781 - val_loss: 0.1447 - val_accuracy: 0.7792
# Epoch 68/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1457 - accuracy: 0.7782 - val_loss: 0.1458 - val_accuracy: 0.7759
# Epoch 69/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1456 - accuracy: 0.7785 - val_loss: 0.1449 - val_accuracy: 0.7794
# Epoch 70/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1456 - accuracy: 0.7783 - val_loss: 0.1449 - val_accuracy: 0.7790
# Epoch 71/140
# 24/24 [==============================] - 7s 305ms/step - loss: 0.1453 - accuracy: 0.7787 - val_loss: 0.1457 - val_accuracy: 0.7784
# Epoch 72/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1459 - accuracy: 0.7783 - val_loss: 0.1446 - val_accuracy: 0.7808
# Epoch 73/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1452 - accuracy: 0.7790 - val_loss: 0.1445 - val_accuracy: 0.7816
# Epoch 74/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1453 - accuracy: 0.7786 - val_loss: 0.1447 - val_accuracy: 0.7817
# Epoch 75/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1453 - accuracy: 0.7789 - val_loss: 0.1450 - val_accuracy: 0.7810
# Epoch 76/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1460 - accuracy: 0.7780 - val_loss: 0.1443 - val_accuracy: 0.7804
# Epoch 77/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1449 - accuracy: 0.7793 - val_loss: 0.1457 - val_accuracy: 0.7754
# Epoch 78/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1451 - accuracy: 0.7790 - val_loss: 0.1445 - val_accuracy: 0.7795
# Epoch 79/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1448 - accuracy: 0.7793 - val_loss: 0.1451 - val_accuracy: 0.7790
# Epoch 80/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1448 - accuracy: 0.7793 - val_loss: 0.1446 - val_accuracy: 0.7782
# Epoch 81/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1447 - accuracy: 0.7793 - val_loss: 0.1442 - val_accuracy: 0.7808
# Epoch 82/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1448 - accuracy: 0.7795 - val_loss: 0.1447 - val_accuracy: 0.7783
# Epoch 83/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1447 - accuracy: 0.7794 - val_loss: 0.1461 - val_accuracy: 0.7807
# Epoch 84/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1447 - accuracy: 0.7796 - val_loss: 0.1447 - val_accuracy: 0.7804
# Epoch 85/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1448 - accuracy: 0.7796 - val_loss: 0.1473 - val_accuracy: 0.7804
# Epoch 86/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1451 - accuracy: 0.7794 - val_loss: 0.1448 - val_accuracy: 0.7785
# Epoch 87/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1445 - accuracy: 0.7798 - val_loss: 0.1454 - val_accuracy: 0.7765
# Epoch 88/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1445 - accuracy: 0.7798 - val_loss: 0.1455 - val_accuracy: 0.7815
# Epoch 89/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1443 - accuracy: 0.7802 - val_loss: 0.1458 - val_accuracy: 0.7756
# Epoch 90/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1442 - accuracy: 0.7802 - val_loss: 0.1443 - val_accuracy: 0.7803
# Epoch 91/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1441 - accuracy: 0.7802 - val_loss: 0.1444 - val_accuracy: 0.7788
# Epoch 92/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1442 - accuracy: 0.7803 - val_loss: 0.1449 - val_accuracy: 0.7778
# Epoch 93/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1438 - accuracy: 0.7806 - val_loss: 0.1442 - val_accuracy: 0.7792
# Epoch 94/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1440 - accuracy: 0.7802 - val_loss: 0.1461 - val_accuracy: 0.7785
# Epoch 95/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1440 - accuracy: 0.7804 - val_loss: 0.1441 - val_accuracy: 0.7817
# Epoch 96/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1438 - accuracy: 0.7805 - val_loss: 0.1443 - val_accuracy: 0.7806
# Epoch 97/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1437 - accuracy: 0.7808 - val_loss: 0.1444 - val_accuracy: 0.7813
# Epoch 98/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1436 - accuracy: 0.7812 - val_loss: 0.1445 - val_accuracy: 0.7795
# Epoch 99/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1440 - accuracy: 0.7807 - val_loss: 0.1451 - val_accuracy: 0.7796
# Epoch 100/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1439 - accuracy: 0.7812 - val_loss: 0.1443 - val_accuracy: 0.7802
# Epoch 101/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1435 - accuracy: 0.7814 - val_loss: 0.1449 - val_accuracy: 0.7796
# Epoch 102/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1434 - accuracy: 0.7815 - val_loss: 0.1446 - val_accuracy: 0.7772
# Epoch 103/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1434 - accuracy: 0.7815 - val_loss: 0.1441 - val_accuracy: 0.7811
# Epoch 104/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.1437 - accuracy: 0.7814 - val_loss: 0.1447 - val_accuracy: 0.7787
# Epoch 105/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1432 - accuracy: 0.7819 - val_loss: 0.1457 - val_accuracy: 0.7760
# Epoch 106/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1434 - accuracy: 0.7817 - val_loss: 0.1444 - val_accuracy: 0.7792
# Epoch 107/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1434 - accuracy: 0.7819 - val_loss: 0.1445 - val_accuracy: 0.7811
# Epoch 108/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1434 - accuracy: 0.7815 - val_loss: 0.1471 - val_accuracy: 0.7727
# Epoch 109/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1434 - accuracy: 0.7815 - val_loss: 0.1444 - val_accuracy: 0.7805
# Epoch 110/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1429 - accuracy: 0.7824 - val_loss: 0.1440 - val_accuracy: 0.7812
# Epoch 111/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1429 - accuracy: 0.7823 - val_loss: 0.1433 - val_accuracy: 0.7823
# Epoch 112/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1428 - accuracy: 0.7824 - val_loss: 0.1439 - val_accuracy: 0.7823
# Epoch 113/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1428 - accuracy: 0.7824 - val_loss: 0.1451 - val_accuracy: 0.7768
# Epoch 114/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1429 - accuracy: 0.7824 - val_loss: 0.1443 - val_accuracy: 0.7833
# Epoch 115/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1426 - accuracy: 0.7828 - val_loss: 0.1443 - val_accuracy: 0.7790
# Epoch 116/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.1427 - accuracy: 0.7823 - val_loss: 0.1443 - val_accuracy: 0.7822
# Epoch 117/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1425 - accuracy: 0.7826 - val_loss: 0.1441 - val_accuracy: 0.7815
# Epoch 118/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1427 - accuracy: 0.7826 - val_loss: 0.1432 - val_accuracy: 0.7816
# Epoch 119/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1424 - accuracy: 0.7830 - val_loss: 0.1454 - val_accuracy: 0.7781
# Epoch 120/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.1425 - accuracy: 0.7831 - val_loss: 0.1437 - val_accuracy: 0.7811
# Epoch 121/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.1425 - accuracy: 0.7831 - val_loss: 0.1441 - val_accuracy: 0.7793
# Epoch 122/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1431 - accuracy: 0.7826 - val_loss: 0.1439 - val_accuracy: 0.7794
# Epoch 123/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1421 - accuracy: 0.7837 - val_loss: 0.1442 - val_accuracy: 0.7807
# Epoch 124/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1421 - accuracy: 0.7838 - val_loss: 0.1440 - val_accuracy: 0.7817
# Epoch 125/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1422 - accuracy: 0.7833 - val_loss: 0.1436 - val_accuracy: 0.7831
# Epoch 126/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1422 - accuracy: 0.7842 - val_loss: 0.1438 - val_accuracy: 0.7823
# Epoch 127/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1426 - accuracy: 0.7835 - val_loss: 0.1431 - val_accuracy: 0.7821
# Epoch 128/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1420 - accuracy: 0.7838 - val_loss: 0.1447 - val_accuracy: 0.7794
# Epoch 129/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1417 - accuracy: 0.7842 - val_loss: 0.1446 - val_accuracy: 0.7795
# Epoch 130/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1419 - accuracy: 0.7841 - val_loss: 0.1432 - val_accuracy: 0.7843
# Epoch 131/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1419 - accuracy: 0.7842 - val_loss: 0.1436 - val_accuracy: 0.7815
# Epoch 132/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1416 - accuracy: 0.7844 - val_loss: 0.1439 - val_accuracy: 0.7829
# Epoch 133/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1415 - accuracy: 0.7850 - val_loss: 0.1443 - val_accuracy: 0.7809
# Epoch 134/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1416 - accuracy: 0.7849 - val_loss: 0.1434 - val_accuracy: 0.7841
# Epoch 135/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1415 - accuracy: 0.7848 - val_loss: 0.1440 - val_accuracy: 0.7798
# Epoch 136/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1414 - accuracy: 0.7851 - val_loss: 0.1433 - val_accuracy: 0.7818
# Epoch 137/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1414 - accuracy: 0.7851 - val_loss: 0.1450 - val_accuracy: 0.7770
# Epoch 138/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.1414 - accuracy: 0.7853 - val_loss: 0.1437 - val_accuracy: 0.7802
# Epoch 139/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1414 - accuracy: 0.7851 - val_loss: 0.1430 - val_accuracy: 0.7833
# Epoch 140/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.1414 - accuracy: 0.7850 - val_loss: 0.1438 - val_accuracy: 0.7803

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 24s 8ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 1041.8080570697784

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00253496],
#        [0.00430556],
#        [0.00408747],
#        ...,
#        [0.06760075],
#        [0.06932124],
#        [0.07373396]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14383261825680468
# 0.22657890507053002
# 0.379252710282741
# 0.2868000166643062

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 116s 8ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60598386]
# [0.82691608]
# total acc [0.78360211]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1100577024, 'peak': 9492622080}
