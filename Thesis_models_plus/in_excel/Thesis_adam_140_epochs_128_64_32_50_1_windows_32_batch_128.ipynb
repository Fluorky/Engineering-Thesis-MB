# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x25afd230040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x25b712e8040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 78s 24ms/step - loss: 0.4700 - accuracy: 0.7606 - val_loss: 0.4340 - val_accuracy: 0.7805
# Epoch 2/140
# 2971/2971 [==============================] - 69s 23ms/step - loss: 0.4419 - accuracy: 0.7757 - val_loss: 0.4360 - val_accuracy: 0.7817
# Epoch 3/140
140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3499 - accuracy: 0.8213 - val_loss: 0.4881 - val_accuracy: 0.7651
# Epoch 98/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3509 - accuracy: 0.8208 - val_loss: 0.4887 - val_accuracy: 0.7646
# Epoch 99/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3504 - accuracy: 0.8214 - val_loss: 0.4922 - val_accuracy: 0.7663
# Epoch 100/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3502 - accuracy: 0.8214 - val_loss: 0.5005 - val_accuracy: 0.7664
# Epoch 101/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3503 - accuracy: 0.8212 - val_loss: 0.4951 - val_accuracy: 0.7651
# Epoch 102/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3499 - accuracy: 0.8225 - val_loss: 0.4944 - val_accuracy: 0.7649
# Epoch 103/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3496 - accuracy: 0.8218 - val_loss: 0.4879 - val_accuracy: 0.7621
# Epoch 104/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3501 - accuracy: 0.8216 - val_loss: 0.4941 - val_accuracy: 0.7618
# Epoch 105/140
# 2971/2971 [==============================] - 61s 21ms/step - loss: 0.3493 - accuracy: 0.8218 - val_loss: 0.4958 - val_accuracy: 0.7652
# Epoch 106/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3498 - accuracy: 0.8218 - val_loss: 0.4904 - val_accuracy: 0.7633
# Epoch 107/140
# 2971/2971 [==============================] - 64s 21ms/step - loss: 0.3499 - accuracy: 0.8215 - val_loss: 0.4991 - val_accuracy: 0.7644
# Epoch 108/140
# 2971/2971 [==============================] - 64s 22ms/step - loss: 0.3492 - accuracy: 0.8220 - val_loss: 0.5103 - val_accuracy: 0.7632
# Epoch 109/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3504 - accuracy: 0.8214 - val_loss: 0.5061 - val_accuracy: 0.7668
# Epoch 110/140
# 2971/2971 [==============================] - 64s 21ms/step - loss: 0.3509 - accuracy: 0.8212 - val_loss: 0.4773 - val_accuracy: 0.7641
# Epoch 111/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3525 - accuracy: 0.8205 - val_loss: 0.4941 - val_accuracy: 0.7625
# Epoch 112/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3559 - accuracy: 0.8187 - val_loss: 0.4843 - val_accuracy: 0.7645
# Epoch 113/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3498 - accuracy: 0.8220 - val_loss: 0.5106 - val_accuracy: 0.7688
# Epoch 114/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3564 - accuracy: 0.8185 - val_loss: 0.4666 - val_accuracy: 0.7671
# Epoch 115/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3536 - accuracy: 0.8196 - val_loss: 0.4908 - val_accuracy: 0.7627
# Epoch 116/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3514 - accuracy: 0.8211 - val_loss: 0.5173 - val_accuracy: 0.7706
# Epoch 117/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3512 - accuracy: 0.8219 - val_loss: 0.5004 - val_accuracy: 0.7688
# Epoch 118/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3517 - accuracy: 0.8211 - val_loss: 0.4931 - val_accuracy: 0.7653
# Epoch 119/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3526 - accuracy: 0.8206 - val_loss: 0.4902 - val_accuracy: 0.7679
# Epoch 120/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3525 - accuracy: 0.8213 - val_loss: 0.5098 - val_accuracy: 0.7677
# Epoch 121/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3534 - accuracy: 0.8201 - val_loss: 0.5030 - val_accuracy: 0.7644
# Epoch 122/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3524 - accuracy: 0.8202 - val_loss: 0.5084 - val_accuracy: 0.7697
# Epoch 123/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3512 - accuracy: 0.8216 - val_loss: 0.4836 - val_accuracy: 0.7559
# Epoch 124/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3499 - accuracy: 0.8221 - val_loss: 0.4939 - val_accuracy: 0.7659
# Epoch 125/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3516 - accuracy: 0.8210 - val_loss: 0.4972 - val_accuracy: 0.7675
# Epoch 126/140
# 2971/2971 [==============================] - 70s 24ms/step - loss: 0.3513 - accuracy: 0.8212 - val_loss: 0.4915 - val_accuracy: 0.7675
# Epoch 127/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3497 - accuracy: 0.8220 - val_loss: 0.5167 - val_accuracy: 0.7675
# Epoch 128/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3492 - accuracy: 0.8230 - val_loss: 0.5070 - val_accuracy: 0.7671
# Epoch 129/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3514 - accuracy: 0.8212 - val_loss: 0.4927 - val_accuracy: 0.7675
# Epoch 130/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3488 - accuracy: 0.8231 - val_loss: 0.5016 - val_accuracy: 0.7637
# Epoch 131/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3491 - accuracy: 0.8228 - val_loss: 0.5047 - val_accuracy: 0.7642
# Epoch 132/140
# 2971/2971 [==============================] - 64s 21ms/step - loss: 0.3480 - accuracy: 0.8229 - val_loss: 0.4878 - val_accuracy: 0.7536
# Epoch 133/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3491 - accuracy: 0.8225 - val_loss: 0.5004 - val_accuracy: 0.7647
# Epoch 134/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3494 - accuracy: 0.8227 - val_loss: 0.5110 - val_accuracy: 0.7631
# Epoch 135/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3476 - accuracy: 0.8235 - val_loss: 0.4943 - val_accuracy: 0.7639
# Epoch 136/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3472 - accuracy: 0.8228 - val_loss: 0.5038 - val_accuracy: 0.7608
# Epoch 137/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3472 - accuracy: 0.8232 - val_loss: 0.5134 - val_accuracy: 0.7621
# Epoch 138/140
# 2971/2971 [==============================] - 62s 21ms/step - loss: 0.3479 - accuracy: 0.8232 - val_loss: 0.4995 - val_accuracy: 0.7610
# Epoch 139/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3475 - accuracy: 0.8232 - val_loss: 0.5058 - val_accuracy: 0.7619
# Epoch 140/140
# 2971/2971 [==============================] - 63s 21ms/step - loss: 0.3485 - accuracy: 0.8230 - val_loss: 0.5017 - val_accuracy: 0.7665

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 19s 6ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 9271.856202363968

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[5.7872485e-06],
#        [3.9800743e-05],
#        [7.2488497e-06],
#        ...,
#        [2.9761574e-01],
#        [4.1688126e-01],
#        [1.8923518e-01]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1559937170152171
# 0.16118587787496352
# 0.3949603993000021
# 0.2726847459177755

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 90s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.65448556]
# [0.86300809]
# total acc [0.81426663]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()
