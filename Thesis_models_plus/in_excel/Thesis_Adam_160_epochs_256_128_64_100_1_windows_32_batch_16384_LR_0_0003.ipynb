# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x182efc09040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x18363cc7040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0003)
model_gru.compile(loss='BinaryCrossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           209664
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=160,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/160
# 24/24 [==============================] - 15s 348ms/step - loss: 0.5796 - accuracy: 0.7393 - val_loss: 0.5575 - val_accuracy: 0.7530
# Epoch 2/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.5588 - accuracy: 0.7388 - val_loss: 0.5316 - val_accuracy: 0.7379
# Epoch 3/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.5264 - accuracy: 0.7376 - val_loss: 0.4991 - val_accuracy: 0.7473
# Epoch 4/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.5076 - accuracy: 0.7370 - val_loss: 0.4929 - val_accuracy: 0.7528
# Epoch 5/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.5025 - accuracy: 0.7397 - val_loss: 0.4870 - val_accuracy: 0.7531
# Epoch 6/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4974 - accuracy: 0.7430 - val_loss: 0.4816 - val_accuracy: 0.7536
# Epoch 7/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4914 - accuracy: 0.7466 - val_loss: 0.4778 - val_accuracy: 0.7523
# Epoch 8/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4849 - accuracy: 0.7481 - val_loss: 0.4730 - val_accuracy: 0.7549
# Epoch 9/160
# 24/24 [==============================] - 7s 291ms/step - loss: 0.4785 - accuracy: 0.7516 - val_loss: 0.4685 - val_accuracy: 0.7568
# Epoch 10/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4731 - accuracy: 0.7548 - val_loss: 0.4617 - val_accuracy: 0.7608
# Epoch 11/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4693 - accuracy: 0.7570 - val_loss: 0.4660 - val_accuracy: 0.7628
# Epoch 12/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4677 - accuracy: 0.7575 - val_loss: 0.4616 - val_accuracy: 0.7612
# Epoch 13/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4651 - accuracy: 0.7579 - val_loss: 0.4541 - val_accuracy: 0.7637
# Epoch 14/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4617 - accuracy: 0.7594 - val_loss: 0.4548 - val_accuracy: 0.7650
# Epoch 15/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4596 - accuracy: 0.7602 - val_loss: 0.4518 - val_accuracy: 0.7635
# Epoch 16/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4613 - accuracy: 0.7604 - val_loss: 0.4536 - val_accuracy: 0.7640
# Epoch 17/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4583 - accuracy: 0.7614 - val_loss: 0.4551 - val_accuracy: 0.7652
# Epoch 18/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4577 - accuracy: 0.7619 - val_loss: 0.4475 - val_accuracy: 0.7663
# Epoch 19/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4558 - accuracy: 0.7627 - val_loss: 0.4510 - val_accuracy: 0.7672
# Epoch 20/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4550 - accuracy: 0.7632 - val_loss: 0.4487 - val_accuracy: 0.7685
# Epoch 21/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4542 - accuracy: 0.7637 - val_loss: 0.4483 - val_accuracy: 0.7669
# Epoch 22/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4531 - accuracy: 0.7646 - val_loss: 0.4459 - val_accuracy: 0.7693
# Epoch 23/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4536 - accuracy: 0.7650 - val_loss: 0.4485 - val_accuracy: 0.7702
# Epoch 24/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4530 - accuracy: 0.7654 - val_loss: 0.4484 - val_accuracy: 0.7708
# Epoch 25/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4520 - accuracy: 0.7660 - val_loss: 0.4444 - val_accuracy: 0.7707
# Epoch 26/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4512 - accuracy: 0.7667 - val_loss: 0.4424 - val_accuracy: 0.7721
# Epoch 27/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4502 - accuracy: 0.7671 - val_loss: 0.4437 - val_accuracy: 0.7720
# Epoch 28/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4503 - accuracy: 0.7675 - val_loss: 0.4462 - val_accuracy: 0.7713
# Epoch 29/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4494 - accuracy: 0.7677 - val_loss: 0.4469 - val_accuracy: 0.7724
# Epoch 30/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4492 - accuracy: 0.7680 - val_loss: 0.4438 - val_accuracy: 0.7742
# Epoch 31/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4485 - accuracy: 0.7684 - val_loss: 0.4408 - val_accuracy: 0.7737
# Epoch 32/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4481 - accuracy: 0.7688 - val_loss: 0.4417 - val_accuracy: 0.7750
# Epoch 33/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4463 - accuracy: 0.7696 - val_loss: 0.4421 - val_accuracy: 0.7756
# Epoch 34/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4465 - accuracy: 0.7697 - val_loss: 0.4404 - val_accuracy: 0.7758
# Epoch 35/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4461 - accuracy: 0.7702 - val_loss: 0.4395 - val_accuracy: 0.7749
# Epoch 36/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4459 - accuracy: 0.7699 - val_loss: 0.4395 - val_accuracy: 0.7761
# Epoch 37/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4445 - accuracy: 0.7708 - val_loss: 0.4378 - val_accuracy: 0.7757
# Epoch 38/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4448 - accuracy: 0.7709 - val_loss: 0.4386 - val_accuracy: 0.7766
# Epoch 39/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4449 - accuracy: 0.7711 - val_loss: 0.4410 - val_accuracy: 0.7750
# Epoch 40/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4436 - accuracy: 0.7717 - val_loss: 0.4414 - val_accuracy: 0.7759
# Epoch 41/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4441 - accuracy: 0.7718 - val_loss: 0.4402 - val_accuracy: 0.7765
# Epoch 42/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4434 - accuracy: 0.7721 - val_loss: 0.4382 - val_accuracy: 0.7769
# Epoch 43/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4422 - accuracy: 0.7725 - val_loss: 0.4356 - val_accuracy: 0.7772
# Epoch 44/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4424 - accuracy: 0.7725 - val_loss: 0.4387 - val_accuracy: 0.7760
# Epoch 45/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4425 - accuracy: 0.7727 - val_loss: 0.4363 - val_accuracy: 0.7767
# Epoch 46/160
# 24/24 [==============================] - 7s 297ms/step - loss: 0.4412 - accuracy: 0.7729 - val_loss: 0.4345 - val_accuracy: 0.7783
# Epoch 47/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4423 - accuracy: 0.7732 - val_loss: 0.4431 - val_accuracy: 0.7761
# Epoch 48/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4414 - accuracy: 0.7734 - val_loss: 0.4349 - val_accuracy: 0.7778
# Epoch 49/160
# 24/24 [==============================] - 7s 305ms/step - loss: 0.4394 - accuracy: 0.7742 - val_loss: 0.4353 - val_accuracy: 0.7775
# Epoch 50/160
# 24/24 [==============================] - 7s 298ms/step - loss: 0.4398 - accuracy: 0.7740 - val_loss: 0.4352 - val_accuracy: 0.7784
# Epoch 51/160
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4390 - accuracy: 0.7748 - val_loss: 0.4354 - val_accuracy: 0.7777
# Epoch 52/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4389 - accuracy: 0.7746 - val_loss: 0.4352 - val_accuracy: 0.7784
# Epoch 53/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4391 - accuracy: 0.7745 - val_loss: 0.4333 - val_accuracy: 0.7781
# Epoch 54/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4381 - accuracy: 0.7750 - val_loss: 0.4376 - val_accuracy: 0.7765
# Epoch 55/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4390 - accuracy: 0.7750 - val_loss: 0.4346 - val_accuracy: 0.7778
# Epoch 56/160
# 24/24 [==============================] - 7s 297ms/step - loss: 0.4385 - accuracy: 0.7752 - val_loss: 0.4405 - val_accuracy: 0.7785
# Epoch 57/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4379 - accuracy: 0.7753 - val_loss: 0.4373 - val_accuracy: 0.7785
# Epoch 58/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4366 - accuracy: 0.7761 - val_loss: 0.4353 - val_accuracy: 0.7793
# Epoch 59/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4365 - accuracy: 0.7762 - val_loss: 0.4377 - val_accuracy: 0.7778
# Epoch 60/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4374 - accuracy: 0.7759 - val_loss: 0.4349 - val_accuracy: 0.7775
# Epoch 61/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4361 - accuracy: 0.7761 - val_loss: 0.4406 - val_accuracy: 0.7794
# Epoch 62/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4377 - accuracy: 0.7762 - val_loss: 0.4338 - val_accuracy: 0.7780
# Epoch 63/160
# 24/24 [==============================] - 7s 298ms/step - loss: 0.4357 - accuracy: 0.7766 - val_loss: 0.4316 - val_accuracy: 0.7791
# Epoch 64/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4356 - accuracy: 0.7764 - val_loss: 0.4315 - val_accuracy: 0.7799
# Epoch 65/160
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4349 - accuracy: 0.7769 - val_loss: 0.4317 - val_accuracy: 0.7796
# Epoch 66/160
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4355 - accuracy: 0.7768 - val_loss: 0.4401 - val_accuracy: 0.7735
# Epoch 67/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4362 - accuracy: 0.7765 - val_loss: 0.4314 - val_accuracy: 0.7795
# Epoch 68/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4351 - accuracy: 0.7773 - val_loss: 0.4330 - val_accuracy: 0.7796
# Epoch 69/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4342 - accuracy: 0.7776 - val_loss: 0.4317 - val_accuracy: 0.7795
# Epoch 70/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4347 - accuracy: 0.7774 - val_loss: 0.4307 - val_accuracy: 0.7795
# Epoch 71/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4356 - accuracy: 0.7775 - val_loss: 0.4345 - val_accuracy: 0.7770
# Epoch 72/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4355 - accuracy: 0.7770 - val_loss: 0.4359 - val_accuracy: 0.7782
# Epoch 73/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4338 - accuracy: 0.7779 - val_loss: 0.4305 - val_accuracy: 0.7805
# Epoch 74/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4330 - accuracy: 0.7781 - val_loss: 0.4334 - val_accuracy: 0.7798
# Epoch 75/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4333 - accuracy: 0.7780 - val_loss: 0.4327 - val_accuracy: 0.7796
# Epoch 76/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4330 - accuracy: 0.7779 - val_loss: 0.4327 - val_accuracy: 0.7774
# Epoch 77/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4329 - accuracy: 0.7778 - val_loss: 0.4320 - val_accuracy: 0.7780
# Epoch 78/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4326 - accuracy: 0.7783 - val_loss: 0.4312 - val_accuracy: 0.7798
# Epoch 79/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4324 - accuracy: 0.7785 - val_loss: 0.4320 - val_accuracy: 0.7773
# Epoch 80/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4328 - accuracy: 0.7784 - val_loss: 0.4335 - val_accuracy: 0.7789
# Epoch 81/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4323 - accuracy: 0.7783 - val_loss: 0.4376 - val_accuracy: 0.7793
# Epoch 82/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4319 - accuracy: 0.7784 - val_loss: 0.4383 - val_accuracy: 0.7803
# Epoch 83/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4325 - accuracy: 0.7784 - val_loss: 0.4360 - val_accuracy: 0.7784
# Epoch 84/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4332 - accuracy: 0.7782 - val_loss: 0.4341 - val_accuracy: 0.7771
# Epoch 85/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4323 - accuracy: 0.7787 - val_loss: 0.4325 - val_accuracy: 0.7799
# Epoch 86/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4310 - accuracy: 0.7788 - val_loss: 0.4324 - val_accuracy: 0.7793
# Epoch 87/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4308 - accuracy: 0.7793 - val_loss: 0.4316 - val_accuracy: 0.7811
# Epoch 88/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4308 - accuracy: 0.7793 - val_loss: 0.4357 - val_accuracy: 0.7748
# Epoch 89/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4310 - accuracy: 0.7792 - val_loss: 0.4317 - val_accuracy: 0.7789
# Epoch 90/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4308 - accuracy: 0.7796 - val_loss: 0.4300 - val_accuracy: 0.7786
# Epoch 91/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4302 - accuracy: 0.7799 - val_loss: 0.4325 - val_accuracy: 0.7807
# Epoch 92/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4300 - accuracy: 0.7798 - val_loss: 0.4326 - val_accuracy: 0.7800
# Epoch 93/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4295 - accuracy: 0.7797 - val_loss: 0.4323 - val_accuracy: 0.7801
# Epoch 94/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4294 - accuracy: 0.7801 - val_loss: 0.4284 - val_accuracy: 0.7812
# Epoch 95/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4288 - accuracy: 0.7801 - val_loss: 0.4358 - val_accuracy: 0.7813
# Epoch 96/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4295 - accuracy: 0.7800 - val_loss: 0.4307 - val_accuracy: 0.7796
# Epoch 97/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4289 - accuracy: 0.7805 - val_loss: 0.4307 - val_accuracy: 0.7809
# Epoch 98/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4279 - accuracy: 0.7805 - val_loss: 0.4316 - val_accuracy: 0.7808
# Epoch 99/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4280 - accuracy: 0.7805 - val_loss: 0.4433 - val_accuracy: 0.7791
# Epoch 100/160
# 24/24 [==============================] - 7s 298ms/step - loss: 0.4294 - accuracy: 0.7803 - val_loss: 0.4333 - val_accuracy: 0.7808
# Epoch 101/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4277 - accuracy: 0.7810 - val_loss: 0.4288 - val_accuracy: 0.7829
# Epoch 102/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4276 - accuracy: 0.7810 - val_loss: 0.4319 - val_accuracy: 0.7804
# Epoch 103/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4278 - accuracy: 0.7809 - val_loss: 0.4286 - val_accuracy: 0.7820
# Epoch 104/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4271 - accuracy: 0.7809 - val_loss: 0.4327 - val_accuracy: 0.7785
# Epoch 105/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4274 - accuracy: 0.7811 - val_loss: 0.4292 - val_accuracy: 0.7806
# Epoch 106/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4277 - accuracy: 0.7813 - val_loss: 0.4291 - val_accuracy: 0.7833
# Epoch 107/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4261 - accuracy: 0.7814 - val_loss: 0.4302 - val_accuracy: 0.7799
# Epoch 108/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4271 - accuracy: 0.7819 - val_loss: 0.4278 - val_accuracy: 0.7826
# Epoch 109/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4267 - accuracy: 0.7816 - val_loss: 0.4367 - val_accuracy: 0.7817
# Epoch 110/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4270 - accuracy: 0.7815 - val_loss: 0.4274 - val_accuracy: 0.7823
# Epoch 111/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4270 - accuracy: 0.7817 - val_loss: 0.4306 - val_accuracy: 0.7831
# Epoch 112/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4256 - accuracy: 0.7823 - val_loss: 0.4293 - val_accuracy: 0.7809
# Epoch 113/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4255 - accuracy: 0.7820 - val_loss: 0.4328 - val_accuracy: 0.7794
# Epoch 114/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4255 - accuracy: 0.7824 - val_loss: 0.4298 - val_accuracy: 0.7805
# Epoch 115/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4251 - accuracy: 0.7824 - val_loss: 0.4292 - val_accuracy: 0.7834
# Epoch 116/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4248 - accuracy: 0.7824 - val_loss: 0.4268 - val_accuracy: 0.7832
# Epoch 117/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4244 - accuracy: 0.7822 - val_loss: 0.4287 - val_accuracy: 0.7809
# Epoch 118/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4247 - accuracy: 0.7824 - val_loss: 0.4283 - val_accuracy: 0.7834
# Epoch 119/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4241 - accuracy: 0.7832 - val_loss: 0.4321 - val_accuracy: 0.7784
# Epoch 120/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4245 - accuracy: 0.7824 - val_loss: 0.4294 - val_accuracy: 0.7832
# Epoch 121/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4243 - accuracy: 0.7826 - val_loss: 0.4296 - val_accuracy: 0.7835
# Epoch 122/160
# 24/24 [==============================] - 7s 292ms/step - loss: 0.4243 - accuracy: 0.7825 - val_loss: 0.4298 - val_accuracy: 0.7834
# Epoch 123/160
# 24/24 [==============================] - 7s 291ms/step - loss: 0.4237 - accuracy: 0.7830 - val_loss: 0.4269 - val_accuracy: 0.7834
# Epoch 124/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4255 - accuracy: 0.7825 - val_loss: 0.4328 - val_accuracy: 0.7831
# Epoch 125/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4239 - accuracy: 0.7829 - val_loss: 0.4324 - val_accuracy: 0.7809
# Epoch 126/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4235 - accuracy: 0.7828 - val_loss: 0.4303 - val_accuracy: 0.7803
# Epoch 127/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4247 - accuracy: 0.7830 - val_loss: 0.4276 - val_accuracy: 0.7846
# Epoch 128/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4232 - accuracy: 0.7833 - val_loss: 0.4278 - val_accuracy: 0.7835
# Epoch 129/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4230 - accuracy: 0.7831 - val_loss: 0.4306 - val_accuracy: 0.7828
# Epoch 130/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4232 - accuracy: 0.7834 - val_loss: 0.4389 - val_accuracy: 0.7833
# Epoch 131/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4235 - accuracy: 0.7835 - val_loss: 0.4282 - val_accuracy: 0.7821
# Epoch 132/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4228 - accuracy: 0.7834 - val_loss: 0.4278 - val_accuracy: 0.7819
# Epoch 133/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4228 - accuracy: 0.7836 - val_loss: 0.4285 - val_accuracy: 0.7841
# Epoch 134/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4221 - accuracy: 0.7834 - val_loss: 0.4303 - val_accuracy: 0.7806
# Epoch 135/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4243 - accuracy: 0.7836 - val_loss: 0.4349 - val_accuracy: 0.7824
# Epoch 136/160
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4235 - accuracy: 0.7836 - val_loss: 0.4284 - val_accuracy: 0.7835
# Epoch 137/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4215 - accuracy: 0.7842 - val_loss: 0.4284 - val_accuracy: 0.7832
# Epoch 138/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4211 - accuracy: 0.7844 - val_loss: 0.4295 - val_accuracy: 0.7804
# Epoch 139/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4215 - accuracy: 0.7843 - val_loss: 0.4313 - val_accuracy: 0.7819
# Epoch 140/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4215 - accuracy: 0.7841 - val_loss: 0.4326 - val_accuracy: 0.7831
# Epoch 141/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4217 - accuracy: 0.7841 - val_loss: 0.4289 - val_accuracy: 0.7801
# Epoch 142/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4221 - accuracy: 0.7840 - val_loss: 0.4237 - val_accuracy: 0.7837
# Epoch 143/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4216 - accuracy: 0.7843 - val_loss: 0.4382 - val_accuracy: 0.7826
# Epoch 144/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4221 - accuracy: 0.7843 - val_loss: 0.4244 - val_accuracy: 0.7844
# Epoch 145/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4209 - accuracy: 0.7844 - val_loss: 0.4296 - val_accuracy: 0.7835
# Epoch 146/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4212 - accuracy: 0.7845 - val_loss: 0.4262 - val_accuracy: 0.7812
# Epoch 147/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4203 - accuracy: 0.7848 - val_loss: 0.4279 - val_accuracy: 0.7821
# Epoch 148/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4204 - accuracy: 0.7850 - val_loss: 0.4304 - val_accuracy: 0.7810
# Epoch 149/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4196 - accuracy: 0.7849 - val_loss: 0.4257 - val_accuracy: 0.7817
# Epoch 150/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4200 - accuracy: 0.7847 - val_loss: 0.4275 - val_accuracy: 0.7839
# Epoch 151/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4202 - accuracy: 0.7852 - val_loss: 0.4260 - val_accuracy: 0.7830
# Epoch 152/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4199 - accuracy: 0.7849 - val_loss: 0.4251 - val_accuracy: 0.7837
# Epoch 153/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4198 - accuracy: 0.7851 - val_loss: 0.4290 - val_accuracy: 0.7843
# Epoch 154/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4196 - accuracy: 0.7851 - val_loss: 0.4306 - val_accuracy: 0.7840
# Epoch 155/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4200 - accuracy: 0.7850 - val_loss: 0.4271 - val_accuracy: 0.7818
# Epoch 156/160
# 24/24 [==============================] - 7s 294ms/step - loss: 0.4206 - accuracy: 0.7849 - val_loss: 0.4281 - val_accuracy: 0.7830
# Epoch 157/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4192 - accuracy: 0.7850 - val_loss: 0.4290 - val_accuracy: 0.7827
# Epoch 158/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4191 - accuracy: 0.7857 - val_loss: 0.4352 - val_accuracy: 0.7834
# Epoch 159/160
# 24/24 [==============================] - 7s 295ms/step - loss: 0.4193 - accuracy: 0.7849 - val_loss: 0.4295 - val_accuracy: 0.7839
# Epoch 160/160
# 24/24 [==============================] - 7s 293ms/step - loss: 0.4186 - accuracy: 0.7855 - val_loss: 0.4264 - val_accuracy: 0.7821

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 23s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 1163.0343689918518

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00057501],
#        [0.00163411],
#        [0.00089301],
#        ...,
#        [0.0681532 ],
#        [0.06737731],
#        [0.07331901]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14296756558893225
# 0.23123049237851467
# 0.3781105203362269
# 0.2898346178584819

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 110s 7ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60393218]
# [0.83098435]
# total acc [0.78455308]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1100577024, 'peak': 9507122176}
