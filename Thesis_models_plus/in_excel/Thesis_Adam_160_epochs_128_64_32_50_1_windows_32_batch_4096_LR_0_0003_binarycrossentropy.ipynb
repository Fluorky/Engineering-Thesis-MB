# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1d7d7920040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1d84b9da040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0002)
model_gru.compile(loss='BinaryCrossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=160,validation_data=(test_X, test_y),batch_size=4096)#, shuffle=False)
# Out:
# Epoch 1/160
# 93/93 [==============================] - 13s 65ms/step - loss: 0.6297 - accuracy: 0.6290 - val_loss: 0.5593 - val_accuracy: 0.7530
# Epoch 2/160
# 93/93 [==============================] - 5s 54ms/step - loss: 0.5727 - accuracy: 0.7393 - val_loss: 0.5565 - val_accuracy: 0.7530
# Epoch 3/160
# 93/93 [==============================] - 5s 53ms/step - loss: 0.5431 - accuracy: 0.7398 - val_loss: 0.5053 - val_accuracy: 0.7537
# Epoch 4/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.5115 - accuracy: 0.7401 - val_loss: 0.4920 - val_accuracy: 0.7533
# Epoch 5/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.5024 - accuracy: 0.7429 - val_loss: 0.4862 - val_accuracy: 0.7531
# Epoch 6/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4973 - accuracy: 0.7458 - val_loss: 0.4820 - val_accuracy: 0.7533
# Epoch 7/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4922 - accuracy: 0.7478 - val_loss: 0.4784 - val_accuracy: 0.7540
# Epoch 8/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4851 - accuracy: 0.7496 - val_loss: 0.4729 - val_accuracy: 0.7553
# Epoch 9/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4787 - accuracy: 0.7537 - val_loss: 0.4697 - val_accuracy: 0.7594
# Epoch 10/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4739 - accuracy: 0.7563 - val_loss: 0.4629 - val_accuracy: 0.7624
# Epoch 11/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4687 - accuracy: 0.7585 - val_loss: 0.4598 - val_accuracy: 0.7631
# Epoch 12/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4659 - accuracy: 0.7589 - val_loss: 0.4593 - val_accuracy: 0.7604
# Epoch 13/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4641 - accuracy: 0.7591 - val_loss: 0.4569 - val_accuracy: 0.7661
# Epoch 14/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4627 - accuracy: 0.7601 - val_loss: 0.4528 - val_accuracy: 0.7653
# Epoch 15/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4602 - accuracy: 0.7610 - val_loss: 0.4518 - val_accuracy: 0.7649
# Epoch 16/160
# 93/93 [==============================] - 5s 52ms/step - loss: 0.4592 - accuracy: 0.7617 - val_loss: 0.4515 - val_accuracy: 0.7672
# Epoch 17/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4582 - accuracy: 0.7623 - val_loss: 0.4532 - val_accuracy: 0.7649
# Epoch 18/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4568 - accuracy: 0.7632 - val_loss: 0.4505 - val_accuracy: 0.7672
# Epoch 19/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4562 - accuracy: 0.7635 - val_loss: 0.4485 - val_accuracy: 0.7677
# Epoch 20/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4549 - accuracy: 0.7640 - val_loss: 0.4471 - val_accuracy: 0.7683
# Epoch 21/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4544 - accuracy: 0.7646 - val_loss: 0.4451 - val_accuracy: 0.7691
# Epoch 22/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4542 - accuracy: 0.7648 - val_loss: 0.4458 - val_accuracy: 0.7689
# Epoch 23/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4527 - accuracy: 0.7655 - val_loss: 0.4450 - val_accuracy: 0.7703
# Epoch 24/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4519 - accuracy: 0.7660 - val_loss: 0.4456 - val_accuracy: 0.7709
# Epoch 25/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4512 - accuracy: 0.7665 - val_loss: 0.4445 - val_accuracy: 0.7698
# Epoch 26/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4503 - accuracy: 0.7668 - val_loss: 0.4449 - val_accuracy: 0.7730
# Epoch 27/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4494 - accuracy: 0.7674 - val_loss: 0.4419 - val_accuracy: 0.7726
# Epoch 28/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4486 - accuracy: 0.7678 - val_loss: 0.4416 - val_accuracy: 0.7724
# Epoch 29/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4483 - accuracy: 0.7684 - val_loss: 0.4438 - val_accuracy: 0.7725
# Epoch 30/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4474 - accuracy: 0.7693 - val_loss: 0.4402 - val_accuracy: 0.7738
# Epoch 31/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4471 - accuracy: 0.7689 - val_loss: 0.4445 - val_accuracy: 0.7706
# Epoch 32/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4471 - accuracy: 0.7694 - val_loss: 0.4396 - val_accuracy: 0.7734
# Epoch 33/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4457 - accuracy: 0.7700 - val_loss: 0.4386 - val_accuracy: 0.7758
# Epoch 34/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4446 - accuracy: 0.7702 - val_loss: 0.4397 - val_accuracy: 0.7735
# Epoch 35/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4445 - accuracy: 0.7708 - val_loss: 0.4381 - val_accuracy: 0.7760
# Epoch 36/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4444 - accuracy: 0.7710 - val_loss: 0.4380 - val_accuracy: 0.7760
# Epoch 37/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4439 - accuracy: 0.7713 - val_loss: 0.4397 - val_accuracy: 0.7768
# Epoch 38/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4433 - accuracy: 0.7716 - val_loss: 0.4380 - val_accuracy: 0.7751
# Epoch 39/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4421 - accuracy: 0.7720 - val_loss: 0.4379 - val_accuracy: 0.7769
# Epoch 40/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4424 - accuracy: 0.7723 - val_loss: 0.4359 - val_accuracy: 0.7778
# Epoch 41/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4416 - accuracy: 0.7728 - val_loss: 0.4369 - val_accuracy: 0.7772
# Epoch 42/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4423 - accuracy: 0.7725 - val_loss: 0.4370 - val_accuracy: 0.7764
# Epoch 43/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4409 - accuracy: 0.7735 - val_loss: 0.4371 - val_accuracy: 0.7785
# Epoch 44/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4406 - accuracy: 0.7735 - val_loss: 0.4352 - val_accuracy: 0.7762
# Epoch 45/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4400 - accuracy: 0.7738 - val_loss: 0.4350 - val_accuracy: 0.7780
# Epoch 46/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4393 - accuracy: 0.7742 - val_loss: 0.4337 - val_accuracy: 0.7781
# Epoch 47/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4390 - accuracy: 0.7746 - val_loss: 0.4398 - val_accuracy: 0.7781
# Epoch 48/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4395 - accuracy: 0.7748 - val_loss: 0.4340 - val_accuracy: 0.7772
# Epoch 49/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4385 - accuracy: 0.7746 - val_loss: 0.4342 - val_accuracy: 0.7788
# Epoch 50/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4376 - accuracy: 0.7754 - val_loss: 0.4362 - val_accuracy: 0.7781
# Epoch 51/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4384 - accuracy: 0.7751 - val_loss: 0.4369 - val_accuracy: 0.7783
# Epoch 52/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4373 - accuracy: 0.7758 - val_loss: 0.4328 - val_accuracy: 0.7788
# Epoch 53/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4375 - accuracy: 0.7759 - val_loss: 0.4341 - val_accuracy: 0.7771
# Epoch 54/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4365 - accuracy: 0.7762 - val_loss: 0.4323 - val_accuracy: 0.7792
# Epoch 55/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4362 - accuracy: 0.7768 - val_loss: 0.4340 - val_accuracy: 0.7790
# Epoch 56/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4368 - accuracy: 0.7768 - val_loss: 0.4331 - val_accuracy: 0.7787
# Epoch 57/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4354 - accuracy: 0.7772 - val_loss: 0.4328 - val_accuracy: 0.7786
# Epoch 58/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4350 - accuracy: 0.7773 - val_loss: 0.4330 - val_accuracy: 0.7795
# Epoch 59/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4350 - accuracy: 0.7772 - val_loss: 0.4325 - val_accuracy: 0.7804
# Epoch 60/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4352 - accuracy: 0.7770 - val_loss: 0.4322 - val_accuracy: 0.7800
# Epoch 61/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4347 - accuracy: 0.7779 - val_loss: 0.4338 - val_accuracy: 0.7784
# Epoch 62/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4342 - accuracy: 0.7773 - val_loss: 0.4329 - val_accuracy: 0.7786
# Epoch 63/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4340 - accuracy: 0.7778 - val_loss: 0.4303 - val_accuracy: 0.7804
# Epoch 64/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4338 - accuracy: 0.7781 - val_loss: 0.4367 - val_accuracy: 0.7800
# Epoch 65/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4336 - accuracy: 0.7783 - val_loss: 0.4310 - val_accuracy: 0.7810
# Epoch 66/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4334 - accuracy: 0.7782 - val_loss: 0.4336 - val_accuracy: 0.7804
# Epoch 67/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4334 - accuracy: 0.7782 - val_loss: 0.4294 - val_accuracy: 0.7804
# Epoch 68/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4327 - accuracy: 0.7787 - val_loss: 0.4308 - val_accuracy: 0.7794
# Epoch 69/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4324 - accuracy: 0.7789 - val_loss: 0.4290 - val_accuracy: 0.7809
# Epoch 70/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4327 - accuracy: 0.7786 - val_loss: 0.4346 - val_accuracy: 0.7808
# Epoch 71/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4322 - accuracy: 0.7788 - val_loss: 0.4328 - val_accuracy: 0.7812
# Epoch 72/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4318 - accuracy: 0.7791 - val_loss: 0.4291 - val_accuracy: 0.7806
# Epoch 73/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4319 - accuracy: 0.7791 - val_loss: 0.4314 - val_accuracy: 0.7809
# Epoch 74/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4315 - accuracy: 0.7792 - val_loss: 0.4318 - val_accuracy: 0.7813
# Epoch 75/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4309 - accuracy: 0.7794 - val_loss: 0.4307 - val_accuracy: 0.7810
# Epoch 76/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4310 - accuracy: 0.7794 - val_loss: 0.4313 - val_accuracy: 0.7812
# Epoch 77/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4309 - accuracy: 0.7798 - val_loss: 0.4309 - val_accuracy: 0.7804
# Epoch 78/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4313 - accuracy: 0.7793 - val_loss: 0.4289 - val_accuracy: 0.7810
# Epoch 79/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4306 - accuracy: 0.7798 - val_loss: 0.4294 - val_accuracy: 0.7815
# Epoch 80/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4300 - accuracy: 0.7804 - val_loss: 0.4300 - val_accuracy: 0.7811
# Epoch 81/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4303 - accuracy: 0.7798 - val_loss: 0.4316 - val_accuracy: 0.7819
# Epoch 82/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4308 - accuracy: 0.7795 - val_loss: 0.4322 - val_accuracy: 0.7767
# Epoch 83/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4301 - accuracy: 0.7804 - val_loss: 0.4294 - val_accuracy: 0.7819
# Epoch 84/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4298 - accuracy: 0.7800 - val_loss: 0.4287 - val_accuracy: 0.7812
# Epoch 85/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4297 - accuracy: 0.7802 - val_loss: 0.4304 - val_accuracy: 0.7797
# Epoch 86/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4293 - accuracy: 0.7806 - val_loss: 0.4322 - val_accuracy: 0.7807
# Epoch 87/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4292 - accuracy: 0.7805 - val_loss: 0.4279 - val_accuracy: 0.7807
# Epoch 88/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4292 - accuracy: 0.7805 - val_loss: 0.4290 - val_accuracy: 0.7819
# Epoch 89/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4292 - accuracy: 0.7808 - val_loss: 0.4290 - val_accuracy: 0.7812
# Epoch 90/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4288 - accuracy: 0.7810 - val_loss: 0.4291 - val_accuracy: 0.7823
# Epoch 91/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4285 - accuracy: 0.7808 - val_loss: 0.4295 - val_accuracy: 0.7803
# Epoch 92/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4285 - accuracy: 0.7810 - val_loss: 0.4276 - val_accuracy: 0.7820
# Epoch 93/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4288 - accuracy: 0.7811 - val_loss: 0.4347 - val_accuracy: 0.7809
# Epoch 94/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4287 - accuracy: 0.7809 - val_loss: 0.4278 - val_accuracy: 0.7808
# Epoch 95/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4279 - accuracy: 0.7814 - val_loss: 0.4297 - val_accuracy: 0.7827
# Epoch 96/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4279 - accuracy: 0.7813 - val_loss: 0.4300 - val_accuracy: 0.7825
# Epoch 97/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4278 - accuracy: 0.7811 - val_loss: 0.4326 - val_accuracy: 0.7823
# Epoch 98/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4275 - accuracy: 0.7816 - val_loss: 0.4282 - val_accuracy: 0.7830
# Epoch 99/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4280 - accuracy: 0.7809 - val_loss: 0.4279 - val_accuracy: 0.7812
# Epoch 100/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4277 - accuracy: 0.7812 - val_loss: 0.4349 - val_accuracy: 0.7822
# Epoch 101/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4271 - accuracy: 0.7815 - val_loss: 0.4291 - val_accuracy: 0.7831
# Epoch 102/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4271 - accuracy: 0.7818 - val_loss: 0.4286 - val_accuracy: 0.7814
# Epoch 103/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4263 - accuracy: 0.7821 - val_loss: 0.4299 - val_accuracy: 0.7818
# Epoch 104/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4272 - accuracy: 0.7817 - val_loss: 0.4309 - val_accuracy: 0.7814
# Epoch 105/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4262 - accuracy: 0.7819 - val_loss: 0.4289 - val_accuracy: 0.7815
# Epoch 106/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4261 - accuracy: 0.7819 - val_loss: 0.4290 - val_accuracy: 0.7810
# Epoch 107/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4267 - accuracy: 0.7816 - val_loss: 0.4272 - val_accuracy: 0.7828
# Epoch 108/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4269 - accuracy: 0.7817 - val_loss: 0.4282 - val_accuracy: 0.7829
# Epoch 109/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4258 - accuracy: 0.7821 - val_loss: 0.4293 - val_accuracy: 0.7830
# Epoch 110/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4256 - accuracy: 0.7819 - val_loss: 0.4308 - val_accuracy: 0.7804
# Epoch 111/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4253 - accuracy: 0.7825 - val_loss: 0.4304 - val_accuracy: 0.7831
# Epoch 112/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4260 - accuracy: 0.7821 - val_loss: 0.4305 - val_accuracy: 0.7789
# Epoch 113/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4260 - accuracy: 0.7821 - val_loss: 0.4321 - val_accuracy: 0.7842
# Epoch 114/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4251 - accuracy: 0.7823 - val_loss: 0.4273 - val_accuracy: 0.7813
# Epoch 115/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4250 - accuracy: 0.7827 - val_loss: 0.4279 - val_accuracy: 0.7824
# Epoch 116/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4246 - accuracy: 0.7827 - val_loss: 0.4280 - val_accuracy: 0.7836
# Epoch 117/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4251 - accuracy: 0.7827 - val_loss: 0.4332 - val_accuracy: 0.7830
# Epoch 118/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4249 - accuracy: 0.7830 - val_loss: 0.4279 - val_accuracy: 0.7816
# Epoch 119/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4242 - accuracy: 0.7829 - val_loss: 0.4290 - val_accuracy: 0.7846
# Epoch 120/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4244 - accuracy: 0.7827 - val_loss: 0.4324 - val_accuracy: 0.7837
# Epoch 121/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4242 - accuracy: 0.7830 - val_loss: 0.4261 - val_accuracy: 0.7823
# Epoch 122/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4240 - accuracy: 0.7830 - val_loss: 0.4275 - val_accuracy: 0.7840
# Epoch 123/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4247 - accuracy: 0.7829 - val_loss: 0.4286 - val_accuracy: 0.7840
# Epoch 124/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4238 - accuracy: 0.7830 - val_loss: 0.4290 - val_accuracy: 0.7814
# Epoch 125/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4236 - accuracy: 0.7829 - val_loss: 0.4298 - val_accuracy: 0.7839
# Epoch 126/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4234 - accuracy: 0.7834 - val_loss: 0.4266 - val_accuracy: 0.7842
# Epoch 127/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4236 - accuracy: 0.7833 - val_loss: 0.4285 - val_accuracy: 0.7845
# Epoch 128/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4233 - accuracy: 0.7836 - val_loss: 0.4308 - val_accuracy: 0.7809
# Epoch 129/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4233 - accuracy: 0.7835 - val_loss: 0.4277 - val_accuracy: 0.7836
# Epoch 130/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4239 - accuracy: 0.7832 - val_loss: 0.4325 - val_accuracy: 0.7833
# Epoch 131/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4229 - accuracy: 0.7837 - val_loss: 0.4277 - val_accuracy: 0.7848
# Epoch 132/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4233 - accuracy: 0.7839 - val_loss: 0.4279 - val_accuracy: 0.7814
# Epoch 133/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4228 - accuracy: 0.7838 - val_loss: 0.4298 - val_accuracy: 0.7835
# Epoch 134/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4231 - accuracy: 0.7835 - val_loss: 0.4317 - val_accuracy: 0.7841
# Epoch 135/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4227 - accuracy: 0.7836 - val_loss: 0.4275 - val_accuracy: 0.7810
# Epoch 136/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4222 - accuracy: 0.7839 - val_loss: 0.4283 - val_accuracy: 0.7795
# Epoch 137/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4225 - accuracy: 0.7836 - val_loss: 0.4293 - val_accuracy: 0.7845
# Epoch 138/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4221 - accuracy: 0.7838 - val_loss: 0.4293 - val_accuracy: 0.7827
# Epoch 139/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4223 - accuracy: 0.7837 - val_loss: 0.4368 - val_accuracy: 0.7841
# Epoch 140/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4222 - accuracy: 0.7840 - val_loss: 0.4266 - val_accuracy: 0.7843
# Epoch 141/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4232 - accuracy: 0.7834 - val_loss: 0.4279 - val_accuracy: 0.7809
# Epoch 142/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4220 - accuracy: 0.7842 - val_loss: 0.4274 - val_accuracy: 0.7849
# Epoch 143/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4214 - accuracy: 0.7843 - val_loss: 0.4294 - val_accuracy: 0.7816
# Epoch 144/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4214 - accuracy: 0.7838 - val_loss: 0.4319 - val_accuracy: 0.7829
# Epoch 145/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4210 - accuracy: 0.7843 - val_loss: 0.4269 - val_accuracy: 0.7826
# Epoch 146/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4211 - accuracy: 0.7845 - val_loss: 0.4335 - val_accuracy: 0.7840
# Epoch 147/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4215 - accuracy: 0.7844 - val_loss: 0.4257 - val_accuracy: 0.7854
# Epoch 148/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4207 - accuracy: 0.7845 - val_loss: 0.4276 - val_accuracy: 0.7841
# Epoch 149/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4204 - accuracy: 0.7847 - val_loss: 0.4284 - val_accuracy: 0.7822
# Epoch 150/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4209 - accuracy: 0.7843 - val_loss: 0.4280 - val_accuracy: 0.7829
# Epoch 151/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4207 - accuracy: 0.7843 - val_loss: 0.4310 - val_accuracy: 0.7833
# Epoch 152/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4199 - accuracy: 0.7850 - val_loss: 0.4390 - val_accuracy: 0.7840
# Epoch 153/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4204 - accuracy: 0.7847 - val_loss: 0.4269 - val_accuracy: 0.7852
# Epoch 154/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4199 - accuracy: 0.7848 - val_loss: 0.4260 - val_accuracy: 0.7845
# Epoch 155/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4213 - accuracy: 0.7846 - val_loss: 0.4295 - val_accuracy: 0.7847
# Epoch 156/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4201 - accuracy: 0.7849 - val_loss: 0.4301 - val_accuracy: 0.7844
# Epoch 157/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4200 - accuracy: 0.7846 - val_loss: 0.4324 - val_accuracy: 0.7840
# Epoch 158/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4193 - accuracy: 0.7852 - val_loss: 0.4284 - val_accuracy: 0.7825
# Epoch 159/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4191 - accuracy: 0.7853 - val_loss: 0.4283 - val_accuracy: 0.7824
# Epoch 160/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4195 - accuracy: 0.7852 - val_loss: 0.4276 - val_accuracy: 0.7844

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 21s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 769.3141138553619

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00096818],
#        [0.00293279],
#        [0.00127475],
#        ...,
#        [0.04319181],
#        [0.0438889 ],
#        [0.0457111 ]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14268132920457738
# 0.23276965130143112
# 0.3777318218055998
# 0.28243235958567336

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 96s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.61071854]
# [0.82815682]
# total acc [0.78549353]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 2023393024}
