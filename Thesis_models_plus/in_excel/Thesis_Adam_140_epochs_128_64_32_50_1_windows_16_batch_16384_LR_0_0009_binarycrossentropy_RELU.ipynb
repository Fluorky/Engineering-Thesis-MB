# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x13280005040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x132d7432040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2]),activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True,activation='relu'),
    keras.layers.GRU(units=32,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0009)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 235s 10s/step - loss: 0.5996 - accuracy: 0.7393 - val_loss: 0.5577 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.5670 - accuracy: 0.7393 - val_loss: 0.5387 - val_accuracy: 0.7531
# Epoch 3/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.5322 - accuracy: 0.7393 - val_loss: 0.5053 - val_accuracy: 0.7531
# Epoch 4/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.5097 - accuracy: 0.7393 - val_loss: 0.4932 - val_accuracy: 0.7531
# Epoch 5/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4997 - accuracy: 0.7399 - val_loss: 0.4825 - val_accuracy: 0.7545
# Epoch 6/140
# 24/24 [==============================] - 228s 9s/step - loss: 0.4924 - accuracy: 0.7453 - val_loss: 0.4773 - val_accuracy: 0.7550
# Epoch 7/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4838 - accuracy: 0.7496 - val_loss: 0.4791 - val_accuracy: 0.7472
# Epoch 8/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4763 - accuracy: 0.7548 - val_loss: 0.4685 - val_accuracy: 0.7577
# Epoch 9/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4686 - accuracy: 0.7596 - val_loss: 0.4643 - val_accuracy: 0.7642
# Epoch 10/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4635 - accuracy: 0.7628 - val_loss: 0.4535 - val_accuracy: 0.7685
# Epoch 11/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4572 - accuracy: 0.7657 - val_loss: 0.4555 - val_accuracy: 0.7649
# Epoch 12/140
# 24/24 [==============================] - 228s 10s/step - loss: 0.4553 - accuracy: 0.7666 - val_loss: 0.4537 - val_accuracy: 0.7692
# Epoch 13/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4514 - accuracy: 0.7687 - val_loss: 0.4443 - val_accuracy: 0.7739
# Epoch 14/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.4495 - accuracy: 0.7695 - val_loss: 0.4479 - val_accuracy: 0.7719
# Epoch 15/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4470 - accuracy: 0.7705 - val_loss: 0.4441 - val_accuracy: 0.7750
# Epoch 16/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4462 - accuracy: 0.7716 - val_loss: 0.4458 - val_accuracy: 0.7726
# Epoch 17/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4452 - accuracy: 0.7720 - val_loss: 0.4421 - val_accuracy: 0.7771
# Epoch 18/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4422 - accuracy: 0.7726 - val_loss: 0.4466 - val_accuracy: 0.7737
# Epoch 19/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4418 - accuracy: 0.7734 - val_loss: 0.4393 - val_accuracy: 0.7784
# Epoch 20/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4415 - accuracy: 0.7737 - val_loss: 0.4391 - val_accuracy: 0.7779
# Epoch 21/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4408 - accuracy: 0.7742 - val_loss: 0.4415 - val_accuracy: 0.7755
# Epoch 22/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.4392 - accuracy: 0.7745 - val_loss: 0.4411 - val_accuracy: 0.7769
# Epoch 23/140
# 24/24 [==============================] - 229s 10s/step - loss: 0.4413 - accuracy: 0.7745 - val_loss: 0.4431 - val_accuracy: 0.7776
# Epoch 24/140
# 24/24 [==============================] - 229s 10s/step - loss: 0.4386 - accuracy: 0.7749 - val_loss: 0.4378 - val_accuracy: 0.7785
# Epoch 25/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4379 - accuracy: 0.7755 - val_loss: 0.4379 - val_accuracy: 0.7794
# Epoch 26/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4370 - accuracy: 0.7759 - val_loss: 0.4421 - val_accuracy: 0.7734
# Epoch 27/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4363 - accuracy: 0.7760 - val_loss: 0.4399 - val_accuracy: 0.7732
# Epoch 28/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4353 - accuracy: 0.7766 - val_loss: 0.4369 - val_accuracy: 0.7780
# Epoch 29/140
# 24/24 [==============================] - 227s 10s/step - loss: 0.4345 - accuracy: 0.7770 - val_loss: 0.4361 - val_accuracy: 0.7798
# Epoch 30/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4359 - accuracy: 0.7769 - val_loss: 0.4369 - val_accuracy: 0.7791
# Epoch 31/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4345 - accuracy: 0.7775 - val_loss: 0.4366 - val_accuracy: 0.7770
# Epoch 32/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4329 - accuracy: 0.7780 - val_loss: 0.4372 - val_accuracy: 0.7800
# Epoch 33/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4347 - accuracy: 0.7781 - val_loss: 0.4334 - val_accuracy: 0.7803
# Epoch 34/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4321 - accuracy: 0.7780 - val_loss: 0.4335 - val_accuracy: 0.7800
# Epoch 35/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4308 - accuracy: 0.7786 - val_loss: 0.4353 - val_accuracy: 0.7809
# Epoch 36/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4325 - accuracy: 0.7787 - val_loss: 0.4354 - val_accuracy: 0.7796
# Epoch 37/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4310 - accuracy: 0.7791 - val_loss: 0.4343 - val_accuracy: 0.7795
# Epoch 38/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4300 - accuracy: 0.7794 - val_loss: 0.4365 - val_accuracy: 0.7817
# Epoch 39/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4304 - accuracy: 0.7795 - val_loss: 0.4327 - val_accuracy: 0.7801
# Epoch 40/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4299 - accuracy: 0.7795 - val_loss: 0.4340 - val_accuracy: 0.7764
# Epoch 41/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4297 - accuracy: 0.7796 - val_loss: 0.4345 - val_accuracy: 0.7786
# Epoch 42/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4297 - accuracy: 0.7797 - val_loss: 0.4353 - val_accuracy: 0.7762
# Epoch 43/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4287 - accuracy: 0.7800 - val_loss: 0.4412 - val_accuracy: 0.7801
# Epoch 44/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4292 - accuracy: 0.7798 - val_loss: 0.4327 - val_accuracy: 0.7792
# Epoch 45/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4291 - accuracy: 0.7803 - val_loss: 0.4389 - val_accuracy: 0.7754
# Epoch 46/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4292 - accuracy: 0.7802 - val_loss: 0.4341 - val_accuracy: 0.7800
# Epoch 47/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4265 - accuracy: 0.7807 - val_loss: 0.4337 - val_accuracy: 0.7787
# Epoch 48/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4261 - accuracy: 0.7808 - val_loss: 0.4331 - val_accuracy: 0.7807
# Epoch 49/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4292 - accuracy: 0.7800 - val_loss: 0.4325 - val_accuracy: 0.7812
# Epoch 50/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4267 - accuracy: 0.7812 - val_loss: 0.4314 - val_accuracy: 0.7802
# Epoch 51/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4254 - accuracy: 0.7817 - val_loss: 0.4346 - val_accuracy: 0.7793
# Epoch 52/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4264 - accuracy: 0.7810 - val_loss: 0.4319 - val_accuracy: 0.7802
# Epoch 53/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4257 - accuracy: 0.7817 - val_loss: 0.4321 - val_accuracy: 0.7797
# Epoch 54/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4252 - accuracy: 0.7816 - val_loss: 0.4349 - val_accuracy: 0.7786
# Epoch 55/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4247 - accuracy: 0.7818 - val_loss: 0.4371 - val_accuracy: 0.7814
# Epoch 56/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4254 - accuracy: 0.7818 - val_loss: 0.4335 - val_accuracy: 0.7767
# Epoch 57/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4256 - accuracy: 0.7815 - val_loss: 0.4349 - val_accuracy: 0.7803
# Epoch 58/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4239 - accuracy: 0.7821 - val_loss: 0.4364 - val_accuracy: 0.7796
# Epoch 59/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4240 - accuracy: 0.7822 - val_loss: 0.4322 - val_accuracy: 0.7807
# Epoch 60/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4240 - accuracy: 0.7824 - val_loss: 0.4357 - val_accuracy: 0.7766
# Epoch 61/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4251 - accuracy: 0.7823 - val_loss: 0.4313 - val_accuracy: 0.7800
# Epoch 62/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4233 - accuracy: 0.7829 - val_loss: 0.4310 - val_accuracy: 0.7792
# Epoch 63/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4258 - accuracy: 0.7821 - val_loss: 0.4354 - val_accuracy: 0.7765
# Epoch 64/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4228 - accuracy: 0.7826 - val_loss: 0.4312 - val_accuracy: 0.7803
# Epoch 65/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4231 - accuracy: 0.7828 - val_loss: 0.4310 - val_accuracy: 0.7806
# Epoch 66/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4241 - accuracy: 0.7824 - val_loss: 0.4317 - val_accuracy: 0.7815
# Epoch 67/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4254 - accuracy: 0.7822 - val_loss: 0.4362 - val_accuracy: 0.7746
# Epoch 68/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4230 - accuracy: 0.7831 - val_loss: 0.4322 - val_accuracy: 0.7819
# Epoch 69/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4225 - accuracy: 0.7833 - val_loss: 0.4314 - val_accuracy: 0.7796
# Epoch 70/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4225 - accuracy: 0.7830 - val_loss: 0.4318 - val_accuracy: 0.7811
# Epoch 71/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4212 - accuracy: 0.7834 - val_loss: 0.4362 - val_accuracy: 0.7814
# Epoch 72/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4213 - accuracy: 0.7835 - val_loss: 0.4384 - val_accuracy: 0.7813
# Epoch 73/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4216 - accuracy: 0.7837 - val_loss: 0.4483 - val_accuracy: 0.7626
# Epoch 74/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4273 - accuracy: 0.7819 - val_loss: 0.4351 - val_accuracy: 0.7766
# Epoch 75/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4227 - accuracy: 0.7836 - val_loss: 0.4326 - val_accuracy: 0.7791
# Epoch 76/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4222 - accuracy: 0.7839 - val_loss: 0.4475 - val_accuracy: 0.7812
# Epoch 77/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4250 - accuracy: 0.7828 - val_loss: 0.4341 - val_accuracy: 0.7821
# Epoch 78/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4214 - accuracy: 0.7836 - val_loss: 0.4371 - val_accuracy: 0.7819
# Epoch 79/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4223 - accuracy: 0.7834 - val_loss: 0.4376 - val_accuracy: 0.7817
# Epoch 80/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4211 - accuracy: 0.7841 - val_loss: 0.4333 - val_accuracy: 0.7793
# Epoch 81/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4204 - accuracy: 0.7844 - val_loss: 0.4317 - val_accuracy: 0.7818
# Epoch 82/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4202 - accuracy: 0.7843 - val_loss: 0.4306 - val_accuracy: 0.7815
# Epoch 83/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4195 - accuracy: 0.7844 - val_loss: 0.4328 - val_accuracy: 0.7811
# Epoch 84/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4194 - accuracy: 0.7845 - val_loss: 0.4370 - val_accuracy: 0.7820
# Epoch 85/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4194 - accuracy: 0.7843 - val_loss: 0.4319 - val_accuracy: 0.7803
# Epoch 86/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4208 - accuracy: 0.7842 - val_loss: 0.4340 - val_accuracy: 0.7808
# Epoch 87/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4192 - accuracy: 0.7844 - val_loss: 0.4339 - val_accuracy: 0.7788
# Epoch 88/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4216 - accuracy: 0.7841 - val_loss: 0.4316 - val_accuracy: 0.7821
# Epoch 89/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4193 - accuracy: 0.7847 - val_loss: 0.4319 - val_accuracy: 0.7808
# Epoch 90/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4189 - accuracy: 0.7848 - val_loss: 0.4355 - val_accuracy: 0.7762
# Epoch 91/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4193 - accuracy: 0.7846 - val_loss: 0.4370 - val_accuracy: 0.7743
# Epoch 92/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4208 - accuracy: 0.7849 - val_loss: 0.4319 - val_accuracy: 0.7799
# Epoch 93/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4205 - accuracy: 0.7847 - val_loss: 0.4309 - val_accuracy: 0.7821
# Epoch 94/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4187 - accuracy: 0.7851 - val_loss: 0.4315 - val_accuracy: 0.7813
# Epoch 95/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4183 - accuracy: 0.7850 - val_loss: 0.4314 - val_accuracy: 0.7807
# Epoch 96/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4191 - accuracy: 0.7853 - val_loss: 0.4422 - val_accuracy: 0.7819
# Epoch 97/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4194 - accuracy: 0.7851 - val_loss: 0.4382 - val_accuracy: 0.7809
# Epoch 98/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4179 - accuracy: 0.7853 - val_loss: 0.4317 - val_accuracy: 0.7807
# Epoch 99/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4175 - accuracy: 0.7852 - val_loss: 0.4355 - val_accuracy: 0.7800
# Epoch 100/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4182 - accuracy: 0.7851 - val_loss: 0.4334 - val_accuracy: 0.7788
# Epoch 101/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4179 - accuracy: 0.7851 - val_loss: 0.4310 - val_accuracy: 0.7811
# Epoch 102/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4185 - accuracy: 0.7854 - val_loss: 0.4346 - val_accuracy: 0.7818
# Epoch 103/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4186 - accuracy: 0.7852 - val_loss: 0.4332 - val_accuracy: 0.7792
# Epoch 104/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4168 - accuracy: 0.7857 - val_loss: 0.4328 - val_accuracy: 0.7815
# Epoch 105/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4166 - accuracy: 0.7856 - val_loss: 0.4324 - val_accuracy: 0.7796
# Epoch 106/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4197 - accuracy: 0.7851 - val_loss: 0.4315 - val_accuracy: 0.7809
# Epoch 107/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4175 - accuracy: 0.7851 - val_loss: 0.4343 - val_accuracy: 0.7804
# Epoch 108/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4163 - accuracy: 0.7860 - val_loss: 0.4324 - val_accuracy: 0.7811
# Epoch 109/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4169 - accuracy: 0.7860 - val_loss: 0.4347 - val_accuracy: 0.7798
# Epoch 110/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.4171 - accuracy: 0.7856 - val_loss: 0.4356 - val_accuracy: 0.7823
# Epoch 111/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4168 - accuracy: 0.7860 - val_loss: 0.4353 - val_accuracy: 0.7808
# Epoch 112/140
# 24/24 [==============================] - 233s 10s/step - loss: 0.4157 - accuracy: 0.7866 - val_loss: 0.4327 - val_accuracy: 0.7821
# Epoch 113/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4159 - accuracy: 0.7859 - val_loss: 0.4310 - val_accuracy: 0.7822
# Epoch 114/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4165 - accuracy: 0.7862 - val_loss: 0.4340 - val_accuracy: 0.7792
# Epoch 115/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4202 - accuracy: 0.7853 - val_loss: 0.4320 - val_accuracy: 0.7806
# Epoch 116/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4170 - accuracy: 0.7865 - val_loss: 0.4334 - val_accuracy: 0.7773
# Epoch 117/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4167 - accuracy: 0.7861 - val_loss: 0.4363 - val_accuracy: 0.7825
# Epoch 118/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4157 - accuracy: 0.7863 - val_loss: 0.4320 - val_accuracy: 0.7825
# Epoch 119/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4146 - accuracy: 0.7866 - val_loss: 0.4340 - val_accuracy: 0.7775
# Epoch 120/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4156 - accuracy: 0.7867 - val_loss: 0.4352 - val_accuracy: 0.7779
# Epoch 121/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4177 - accuracy: 0.7864 - val_loss: 0.4353 - val_accuracy: 0.7827
# Epoch 122/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4164 - accuracy: 0.7864 - val_loss: 0.4308 - val_accuracy: 0.7820
# Epoch 123/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4147 - accuracy: 0.7869 - val_loss: 0.4339 - val_accuracy: 0.7780
# Epoch 124/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4163 - accuracy: 0.7866 - val_loss: 0.4444 - val_accuracy: 0.7817
# Epoch 125/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4156 - accuracy: 0.7869 - val_loss: 0.4343 - val_accuracy: 0.7827
# Epoch 126/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4151 - accuracy: 0.7867 - val_loss: 0.4351 - val_accuracy: 0.7829
# Epoch 127/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4145 - accuracy: 0.7870 - val_loss: 0.4322 - val_accuracy: 0.7818
# Epoch 128/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4153 - accuracy: 0.7867 - val_loss: 0.4306 - val_accuracy: 0.7815
# Epoch 129/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.4150 - accuracy: 0.7866 - val_loss: 0.4323 - val_accuracy: 0.7818
# Epoch 130/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4149 - accuracy: 0.7872 - val_loss: 0.4311 - val_accuracy: 0.7811
# Epoch 131/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4155 - accuracy: 0.7866 - val_loss: 0.4334 - val_accuracy: 0.7821
# Epoch 132/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4146 - accuracy: 0.7870 - val_loss: 0.4334 - val_accuracy: 0.7809
# Epoch 133/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4138 - accuracy: 0.7874 - val_loss: 0.4302 - val_accuracy: 0.7821
# Epoch 134/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4144 - accuracy: 0.7867 - val_loss: 0.4324 - val_accuracy: 0.7802
# Epoch 135/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4159 - accuracy: 0.7868 - val_loss: 0.4359 - val_accuracy: 0.7766
# Epoch 136/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4157 - accuracy: 0.7867 - val_loss: 0.4439 - val_accuracy: 0.7823
# Epoch 137/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4145 - accuracy: 0.7876 - val_loss: 0.4316 - val_accuracy: 0.7805
# Epoch 138/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4142 - accuracy: 0.7873 - val_loss: 0.4307 - val_accuracy: 0.7805
# Epoch 139/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4140 - accuracy: 0.7872 - val_loss: 0.4341 - val_accuracy: 0.7772
# Epoch 140/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4139 - accuracy: 0.7876 - val_loss: 0.4382 - val_accuracy: 0.7830

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 44s 15ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 31521.941420555115

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00293188],
#        [0.00244419],
#        [0.00112421],
#        ...,
#        [0.04904239],
#        [0.05220557],
#        [0.05333088]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14409847921299712
# 0.22512739747223098
# 0.3796030547993484
# 0.2726504648043522

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 225s 15ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.63991747]
# [0.81321364]
# total acc [0.78599936]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5016\725781306.py in <module>
# ----> 1 tf.config.experimental.get_memory_info('GPU:0')
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\config.py in get_memory_info(device)
#     574     ValueError: Memory statistics not tracked, like '"CPU:0"'.
#     575   """
# --> 576   return context.context().get_memory_info(device)
#     577
#     578
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in get_memory_info(self, dev)
#    1605     self._initialize_physical_devices()
#    1606     self.ensure_initialized()
# -> 1607     return pywrap_tfe.TFE_GetMemoryInfo(self._context_handle, dev)
#    1608
#    1609   def reset_memory_stats(self, dev):
#
# ValueError: No matching devices found for 'GPU:0'
