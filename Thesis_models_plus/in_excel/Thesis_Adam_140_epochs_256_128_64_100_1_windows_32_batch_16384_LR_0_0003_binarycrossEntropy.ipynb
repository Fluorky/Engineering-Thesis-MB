# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1d5c3a61040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1d637b15040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0003)
model_gru.compile(loss='BinaryCrossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           209664
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 18s 357ms/step - loss: 0.6187 - accuracy: 0.6765 - val_loss: 0.5592 - val_accuracy: 0.7530
# Epoch 2/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.5712 - accuracy: 0.7393 - val_loss: 0.5523 - val_accuracy: 0.7530
# Epoch 3/140
# 24/24 [==============================] - 7s 305ms/step - loss: 0.5554 - accuracy: 0.7382 - val_loss: 0.5319 - val_accuracy: 0.7440
# Epoch 4/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.5294 - accuracy: 0.7386 - val_loss: 0.5022 - val_accuracy: 0.7478
# Epoch 5/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.5104 - accuracy: 0.7382 - val_loss: 0.4916 - val_accuracy: 0.7533
# Epoch 6/140
# 24/24 [==============================] - 7s 308ms/step - loss: 0.5031 - accuracy: 0.7407 - val_loss: 0.4871 - val_accuracy: 0.7529
# Epoch 7/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4983 - accuracy: 0.7426 - val_loss: 0.4828 - val_accuracy: 0.7533
# Epoch 8/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4946 - accuracy: 0.7456 - val_loss: 0.4806 - val_accuracy: 0.7532
# Epoch 9/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4898 - accuracy: 0.7481 - val_loss: 0.4789 - val_accuracy: 0.7527
# Epoch 10/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4851 - accuracy: 0.7485 - val_loss: 0.4753 - val_accuracy: 0.7498
# Epoch 11/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4797 - accuracy: 0.7511 - val_loss: 0.4728 - val_accuracy: 0.7526
# Epoch 12/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4752 - accuracy: 0.7541 - val_loss: 0.4649 - val_accuracy: 0.7594
# Epoch 13/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4721 - accuracy: 0.7568 - val_loss: 0.4681 - val_accuracy: 0.7616
# Epoch 14/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4696 - accuracy: 0.7578 - val_loss: 0.4633 - val_accuracy: 0.7631
# Epoch 15/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.4665 - accuracy: 0.7586 - val_loss: 0.4571 - val_accuracy: 0.7643
# Epoch 16/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4666 - accuracy: 0.7581 - val_loss: 0.4578 - val_accuracy: 0.7642
# Epoch 17/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4638 - accuracy: 0.7596 - val_loss: 0.4553 - val_accuracy: 0.7656
# Epoch 18/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4629 - accuracy: 0.7601 - val_loss: 0.4608 - val_accuracy: 0.7655
# Epoch 19/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4620 - accuracy: 0.7604 - val_loss: 0.4531 - val_accuracy: 0.7649
# Epoch 20/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4591 - accuracy: 0.7613 - val_loss: 0.4560 - val_accuracy: 0.7667
# Epoch 21/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4588 - accuracy: 0.7619 - val_loss: 0.4515 - val_accuracy: 0.7671
# Epoch 22/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.4586 - accuracy: 0.7619 - val_loss: 0.4483 - val_accuracy: 0.7667
# Epoch 23/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.4567 - accuracy: 0.7626 - val_loss: 0.4541 - val_accuracy: 0.7664
# Epoch 24/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4579 - accuracy: 0.7628 - val_loss: 0.4490 - val_accuracy: 0.7667
# Epoch 25/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4560 - accuracy: 0.7635 - val_loss: 0.4507 - val_accuracy: 0.7686
# Epoch 26/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4541 - accuracy: 0.7644 - val_loss: 0.4465 - val_accuracy: 0.7687
# Epoch 27/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4543 - accuracy: 0.7642 - val_loss: 0.4460 - val_accuracy: 0.7692
# Epoch 28/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4534 - accuracy: 0.7648 - val_loss: 0.4510 - val_accuracy: 0.7677
# Epoch 29/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4536 - accuracy: 0.7648 - val_loss: 0.4452 - val_accuracy: 0.7686
# Epoch 30/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4527 - accuracy: 0.7654 - val_loss: 0.4500 - val_accuracy: 0.7682
# Epoch 31/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4525 - accuracy: 0.7661 - val_loss: 0.4456 - val_accuracy: 0.7693
# Epoch 32/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4527 - accuracy: 0.7655 - val_loss: 0.4464 - val_accuracy: 0.7700
# Epoch 33/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4504 - accuracy: 0.7667 - val_loss: 0.4437 - val_accuracy: 0.7702
# Epoch 34/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4492 - accuracy: 0.7669 - val_loss: 0.4477 - val_accuracy: 0.7717
# Epoch 35/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4508 - accuracy: 0.7670 - val_loss: 0.4432 - val_accuracy: 0.7716
# Epoch 36/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4487 - accuracy: 0.7674 - val_loss: 0.4438 - val_accuracy: 0.7724
# Epoch 37/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4490 - accuracy: 0.7676 - val_loss: 0.4432 - val_accuracy: 0.7729
# Epoch 38/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4479 - accuracy: 0.7679 - val_loss: 0.4407 - val_accuracy: 0.7729
# Epoch 39/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4470 - accuracy: 0.7685 - val_loss: 0.4412 - val_accuracy: 0.7731
# Epoch 40/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4466 - accuracy: 0.7684 - val_loss: 0.4408 - val_accuracy: 0.7737
# Epoch 41/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4465 - accuracy: 0.7691 - val_loss: 0.4412 - val_accuracy: 0.7737
# Epoch 42/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4468 - accuracy: 0.7691 - val_loss: 0.4408 - val_accuracy: 0.7748
# Epoch 43/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.4457 - accuracy: 0.7697 - val_loss: 0.4397 - val_accuracy: 0.7747
# Epoch 44/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4453 - accuracy: 0.7694 - val_loss: 0.4428 - val_accuracy: 0.7755
# Epoch 45/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4457 - accuracy: 0.7696 - val_loss: 0.4385 - val_accuracy: 0.7757
# Epoch 46/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4460 - accuracy: 0.7700 - val_loss: 0.4439 - val_accuracy: 0.7733
# Epoch 47/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4457 - accuracy: 0.7701 - val_loss: 0.4383 - val_accuracy: 0.7765
# Epoch 48/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4444 - accuracy: 0.7707 - val_loss: 0.4401 - val_accuracy: 0.7760
# Epoch 49/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4437 - accuracy: 0.7715 - val_loss: 0.4384 - val_accuracy: 0.7769
# Epoch 50/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4441 - accuracy: 0.7714 - val_loss: 0.4396 - val_accuracy: 0.7746
# Epoch 51/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4441 - accuracy: 0.7715 - val_loss: 0.4420 - val_accuracy: 0.7737
# Epoch 52/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4460 - accuracy: 0.7714 - val_loss: 0.4441 - val_accuracy: 0.7745
# Epoch 53/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4437 - accuracy: 0.7715 - val_loss: 0.4373 - val_accuracy: 0.7777
# Epoch 54/140
# 24/24 [==============================] - 8s 314ms/step - loss: 0.4422 - accuracy: 0.7723 - val_loss: 0.4415 - val_accuracy: 0.7771
# Epoch 55/140
# 24/24 [==============================] - 7s 307ms/step - loss: 0.4417 - accuracy: 0.7729 - val_loss: 0.4382 - val_accuracy: 0.7747
# Epoch 56/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4416 - accuracy: 0.7728 - val_loss: 0.4369 - val_accuracy: 0.7772
# Epoch 57/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.4417 - accuracy: 0.7733 - val_loss: 0.4382 - val_accuracy: 0.7776
# Epoch 58/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4405 - accuracy: 0.7734 - val_loss: 0.4361 - val_accuracy: 0.7772
# Epoch 59/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4403 - accuracy: 0.7739 - val_loss: 0.4378 - val_accuracy: 0.7772
# Epoch 60/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4395 - accuracy: 0.7743 - val_loss: 0.4337 - val_accuracy: 0.7783
# Epoch 61/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4397 - accuracy: 0.7740 - val_loss: 0.4362 - val_accuracy: 0.7774
# Epoch 62/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4393 - accuracy: 0.7746 - val_loss: 0.4366 - val_accuracy: 0.7779
# Epoch 63/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4385 - accuracy: 0.7748 - val_loss: 0.4346 - val_accuracy: 0.7774
# Epoch 64/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4384 - accuracy: 0.7750 - val_loss: 0.4334 - val_accuracy: 0.7783
# Epoch 65/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4381 - accuracy: 0.7752 - val_loss: 0.4346 - val_accuracy: 0.7778
# Epoch 66/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4375 - accuracy: 0.7757 - val_loss: 0.4330 - val_accuracy: 0.7786
# Epoch 67/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.4377 - accuracy: 0.7757 - val_loss: 0.4344 - val_accuracy: 0.7770
# Epoch 68/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4375 - accuracy: 0.7754 - val_loss: 0.4359 - val_accuracy: 0.7763
# Epoch 69/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4369 - accuracy: 0.7759 - val_loss: 0.4323 - val_accuracy: 0.7786
# Epoch 70/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4371 - accuracy: 0.7762 - val_loss: 0.4345 - val_accuracy: 0.7791
# Epoch 71/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4361 - accuracy: 0.7765 - val_loss: 0.4339 - val_accuracy: 0.7768
# Epoch 72/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4370 - accuracy: 0.7761 - val_loss: 0.4329 - val_accuracy: 0.7790
# Epoch 73/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4369 - accuracy: 0.7766 - val_loss: 0.4352 - val_accuracy: 0.7774
# Epoch 74/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.4360 - accuracy: 0.7765 - val_loss: 0.4339 - val_accuracy: 0.7781
# Epoch 75/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4359 - accuracy: 0.7767 - val_loss: 0.4360 - val_accuracy: 0.7771
# Epoch 76/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4370 - accuracy: 0.7766 - val_loss: 0.4319 - val_accuracy: 0.7789
# Epoch 77/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4355 - accuracy: 0.7771 - val_loss: 0.4395 - val_accuracy: 0.7789
# Epoch 78/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4354 - accuracy: 0.7770 - val_loss: 0.4329 - val_accuracy: 0.7798
# Epoch 79/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4352 - accuracy: 0.7771 - val_loss: 0.4334 - val_accuracy: 0.7785
# Epoch 80/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4357 - accuracy: 0.7770 - val_loss: 0.4312 - val_accuracy: 0.7792
# Epoch 81/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4345 - accuracy: 0.7774 - val_loss: 0.4341 - val_accuracy: 0.7782
# Epoch 82/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4338 - accuracy: 0.7774 - val_loss: 0.4326 - val_accuracy: 0.7797
# Epoch 83/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4337 - accuracy: 0.7778 - val_loss: 0.4308 - val_accuracy: 0.7800
# Epoch 84/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4340 - accuracy: 0.7780 - val_loss: 0.4344 - val_accuracy: 0.7776
# Epoch 85/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4333 - accuracy: 0.7777 - val_loss: 0.4311 - val_accuracy: 0.7808
# Epoch 86/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4329 - accuracy: 0.7777 - val_loss: 0.4364 - val_accuracy: 0.7802
# Epoch 87/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4332 - accuracy: 0.7778 - val_loss: 0.4312 - val_accuracy: 0.7812
# Epoch 88/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4329 - accuracy: 0.7780 - val_loss: 0.4335 - val_accuracy: 0.7781
# Epoch 89/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4332 - accuracy: 0.7784 - val_loss: 0.4303 - val_accuracy: 0.7805
# Epoch 90/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4331 - accuracy: 0.7782 - val_loss: 0.4313 - val_accuracy: 0.7806
# Epoch 91/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4323 - accuracy: 0.7782 - val_loss: 0.4312 - val_accuracy: 0.7790
# Epoch 92/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4329 - accuracy: 0.7785 - val_loss: 0.4343 - val_accuracy: 0.7767
# Epoch 93/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4327 - accuracy: 0.7785 - val_loss: 0.4326 - val_accuracy: 0.7778
# Epoch 94/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4322 - accuracy: 0.7785 - val_loss: 0.4314 - val_accuracy: 0.7803
# Epoch 95/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4319 - accuracy: 0.7788 - val_loss: 0.4328 - val_accuracy: 0.7809
# Epoch 96/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4336 - accuracy: 0.7782 - val_loss: 0.4307 - val_accuracy: 0.7794
# Epoch 97/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4315 - accuracy: 0.7786 - val_loss: 0.4317 - val_accuracy: 0.7783
# Epoch 98/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4322 - accuracy: 0.7785 - val_loss: 0.4302 - val_accuracy: 0.7813
# Epoch 99/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4315 - accuracy: 0.7789 - val_loss: 0.4311 - val_accuracy: 0.7790
# Epoch 100/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4326 - accuracy: 0.7784 - val_loss: 0.4351 - val_accuracy: 0.7752
# Epoch 101/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4327 - accuracy: 0.7786 - val_loss: 0.4345 - val_accuracy: 0.7790
# Epoch 102/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4315 - accuracy: 0.7789 - val_loss: 0.4300 - val_accuracy: 0.7809
# Epoch 103/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4309 - accuracy: 0.7792 - val_loss: 0.4320 - val_accuracy: 0.7808
# Epoch 104/140
# 24/24 [==============================] - 7s 304ms/step - loss: 0.4305 - accuracy: 0.7793 - val_loss: 0.4311 - val_accuracy: 0.7795
# Epoch 105/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4313 - accuracy: 0.7790 - val_loss: 0.4305 - val_accuracy: 0.7786
# Epoch 106/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4313 - accuracy: 0.7791 - val_loss: 0.4302 - val_accuracy: 0.7795
# Epoch 107/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4300 - accuracy: 0.7796 - val_loss: 0.4320 - val_accuracy: 0.7781
# Epoch 108/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4296 - accuracy: 0.7793 - val_loss: 0.4304 - val_accuracy: 0.7784
# Epoch 109/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4308 - accuracy: 0.7792 - val_loss: 0.4307 - val_accuracy: 0.7788
# Epoch 110/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4293 - accuracy: 0.7795 - val_loss: 0.4320 - val_accuracy: 0.7820
# Epoch 111/140
# 24/24 [==============================] - 7s 303ms/step - loss: 0.4293 - accuracy: 0.7796 - val_loss: 0.4310 - val_accuracy: 0.7800
# Epoch 112/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4292 - accuracy: 0.7798 - val_loss: 0.4314 - val_accuracy: 0.7792
# Epoch 113/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4294 - accuracy: 0.7798 - val_loss: 0.4354 - val_accuracy: 0.7811
# Epoch 114/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4289 - accuracy: 0.7799 - val_loss: 0.4320 - val_accuracy: 0.7765
# Epoch 115/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4295 - accuracy: 0.7794 - val_loss: 0.4296 - val_accuracy: 0.7807
# Epoch 116/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4289 - accuracy: 0.7797 - val_loss: 0.4312 - val_accuracy: 0.7779
# Epoch 117/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4284 - accuracy: 0.7802 - val_loss: 0.4297 - val_accuracy: 0.7821
# Epoch 118/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4277 - accuracy: 0.7803 - val_loss: 0.4331 - val_accuracy: 0.7827
# Epoch 119/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4276 - accuracy: 0.7806 - val_loss: 0.4284 - val_accuracy: 0.7816
# Epoch 120/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4283 - accuracy: 0.7803 - val_loss: 0.4323 - val_accuracy: 0.7807
# Epoch 121/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4283 - accuracy: 0.7806 - val_loss: 0.4283 - val_accuracy: 0.7810
# Epoch 122/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4268 - accuracy: 0.7811 - val_loss: 0.4312 - val_accuracy: 0.7821
# Epoch 123/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4270 - accuracy: 0.7807 - val_loss: 0.4296 - val_accuracy: 0.7828
# Epoch 124/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4273 - accuracy: 0.7810 - val_loss: 0.4295 - val_accuracy: 0.7823
# Epoch 125/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4264 - accuracy: 0.7812 - val_loss: 0.4298 - val_accuracy: 0.7786
# Epoch 126/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.4267 - accuracy: 0.7812 - val_loss: 0.4294 - val_accuracy: 0.7809
# Epoch 127/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4263 - accuracy: 0.7812 - val_loss: 0.4295 - val_accuracy: 0.7819
# Epoch 128/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4267 - accuracy: 0.7816 - val_loss: 0.4295 - val_accuracy: 0.7785
# Epoch 129/140
# 24/24 [==============================] - 7s 301ms/step - loss: 0.4255 - accuracy: 0.7815 - val_loss: 0.4298 - val_accuracy: 0.7812
# Epoch 130/140
# 24/24 [==============================] - 7s 300ms/step - loss: 0.4252 - accuracy: 0.7817 - val_loss: 0.4283 - val_accuracy: 0.7817
# Epoch 131/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.4253 - accuracy: 0.7813 - val_loss: 0.4283 - val_accuracy: 0.7810
# Epoch 132/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4250 - accuracy: 0.7818 - val_loss: 0.4299 - val_accuracy: 0.7836
# Epoch 133/140
# 24/24 [==============================] - 7s 299ms/step - loss: 0.4249 - accuracy: 0.7817 - val_loss: 0.4324 - val_accuracy: 0.7829
# Epoch 134/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.4265 - accuracy: 0.7814 - val_loss: 0.4324 - val_accuracy: 0.7792
# Epoch 135/140
# 24/24 [==============================] - 7s 297ms/step - loss: 0.4250 - accuracy: 0.7821 - val_loss: 0.4313 - val_accuracy: 0.7805
# Epoch 136/140
# 24/24 [==============================] - 7s 302ms/step - loss: 0.4249 - accuracy: 0.7818 - val_loss: 0.4342 - val_accuracy: 0.7829
# Epoch 137/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.4250 - accuracy: 0.7820 - val_loss: 0.4331 - val_accuracy: 0.7765
# Epoch 138/140
# 24/24 [==============================] - 7s 296ms/step - loss: 0.4248 - accuracy: 0.7819 - val_loss: 0.4275 - val_accuracy: 0.7806
# Epoch 139/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.4242 - accuracy: 0.7824 - val_loss: 0.4286 - val_accuracy: 0.7800
# Epoch 140/140
# 24/24 [==============================] - 7s 298ms/step - loss: 0.4242 - accuracy: 0.7823 - val_loss: 0.4384 - val_accuracy: 0.7778

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 26s 8ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 1052.0023663043976

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00084808],
#        [0.00194191],
#        [0.00180741],
#        ...,
#        [0.02746835],
#        [0.02913039],
#        [0.029163  ]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14600085234397162
# 0.21491981131221471
# 0.3821005788322907
# 0.28520316198573414

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 115s 8ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.59483007]
# [0.82866468]
# total acc [0.78083757]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1100577024, 'peak': 9498720256}
