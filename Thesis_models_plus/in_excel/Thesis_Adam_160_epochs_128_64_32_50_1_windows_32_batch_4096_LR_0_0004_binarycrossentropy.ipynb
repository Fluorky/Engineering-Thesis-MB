# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x24fe41f3040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x250582a3040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0004)
model_gru.compile(loss='BinaryCrossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=160,validation_data=(test_X, test_y),batch_size=4096)#, shuffle=False)
# Out:
# Epoch 1/160
# 93/93 [==============================] - 13s 63ms/step - loss: 0.5425 - accuracy: 0.7384 - val_loss: 0.4923 - val_accuracy: 0.7531
# Epoch 2/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.5016 - accuracy: 0.7385 - val_loss: 0.4815 - val_accuracy: 0.7526
# Epoch 3/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4899 - accuracy: 0.7455 - val_loss: 0.4718 - val_accuracy: 0.7540
# Epoch 4/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4726 - accuracy: 0.7547 - val_loss: 0.4560 - val_accuracy: 0.7625
# Epoch 5/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4647 - accuracy: 0.7578 - val_loss: 0.4530 - val_accuracy: 0.7635
# Epoch 6/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4606 - accuracy: 0.7595 - val_loss: 0.4507 - val_accuracy: 0.7640
# Epoch 7/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4583 - accuracy: 0.7606 - val_loss: 0.4497 - val_accuracy: 0.7655
# Epoch 8/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4557 - accuracy: 0.7621 - val_loss: 0.4526 - val_accuracy: 0.7658
# Epoch 9/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4536 - accuracy: 0.7629 - val_loss: 0.4453 - val_accuracy: 0.7677
# Epoch 10/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4514 - accuracy: 0.7644 - val_loss: 0.4422 - val_accuracy: 0.7693
# Epoch 11/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4499 - accuracy: 0.7652 - val_loss: 0.4404 - val_accuracy: 0.7708
# Epoch 12/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4485 - accuracy: 0.7665 - val_loss: 0.4409 - val_accuracy: 0.7713
# Epoch 13/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4476 - accuracy: 0.7671 - val_loss: 0.4426 - val_accuracy: 0.7707
# Epoch 14/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4464 - accuracy: 0.7679 - val_loss: 0.4403 - val_accuracy: 0.7728
# Epoch 15/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4447 - accuracy: 0.7689 - val_loss: 0.4374 - val_accuracy: 0.7731
# Epoch 16/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4435 - accuracy: 0.7695 - val_loss: 0.4360 - val_accuracy: 0.7738
# Epoch 17/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4441 - accuracy: 0.7700 - val_loss: 0.4360 - val_accuracy: 0.7749
# Epoch 18/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4421 - accuracy: 0.7707 - val_loss: 0.4377 - val_accuracy: 0.7754
# Epoch 19/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4413 - accuracy: 0.7715 - val_loss: 0.4348 - val_accuracy: 0.7751
# Epoch 20/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4406 - accuracy: 0.7720 - val_loss: 0.4367 - val_accuracy: 0.7776
# Epoch 21/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4401 - accuracy: 0.7725 - val_loss: 0.4335 - val_accuracy: 0.7777
# Epoch 22/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4393 - accuracy: 0.7730 - val_loss: 0.4347 - val_accuracy: 0.7764
# Epoch 23/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4390 - accuracy: 0.7736 - val_loss: 0.4343 - val_accuracy: 0.7771
# Epoch 24/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4381 - accuracy: 0.7741 - val_loss: 0.4369 - val_accuracy: 0.7774
# Epoch 25/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4371 - accuracy: 0.7750 - val_loss: 0.4322 - val_accuracy: 0.7786
# Epoch 26/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4375 - accuracy: 0.7752 - val_loss: 0.4330 - val_accuracy: 0.7795
# Epoch 27/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4369 - accuracy: 0.7751 - val_loss: 0.4342 - val_accuracy: 0.7774
# Epoch 28/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4363 - accuracy: 0.7752 - val_loss: 0.4308 - val_accuracy: 0.7795
# Epoch 29/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4361 - accuracy: 0.7755 - val_loss: 0.4318 - val_accuracy: 0.7777
# Epoch 30/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4362 - accuracy: 0.7758 - val_loss: 0.4329 - val_accuracy: 0.7780
# Epoch 31/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4358 - accuracy: 0.7762 - val_loss: 0.4408 - val_accuracy: 0.7786
# Epoch 32/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4357 - accuracy: 0.7764 - val_loss: 0.4340 - val_accuracy: 0.7783
# Epoch 33/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4343 - accuracy: 0.7766 - val_loss: 0.4314 - val_accuracy: 0.7783
# Epoch 34/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4351 - accuracy: 0.7764 - val_loss: 0.4365 - val_accuracy: 0.7774
# Epoch 35/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4333 - accuracy: 0.7769 - val_loss: 0.4367 - val_accuracy: 0.7802
# Epoch 36/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4333 - accuracy: 0.7773 - val_loss: 0.4292 - val_accuracy: 0.7804
# Epoch 37/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4328 - accuracy: 0.7774 - val_loss: 0.4304 - val_accuracy: 0.7789
# Epoch 38/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4328 - accuracy: 0.7777 - val_loss: 0.4296 - val_accuracy: 0.7802
# Epoch 39/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4329 - accuracy: 0.7778 - val_loss: 0.4286 - val_accuracy: 0.7794
# Epoch 40/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4323 - accuracy: 0.7779 - val_loss: 0.4288 - val_accuracy: 0.7806
# Epoch 41/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4323 - accuracy: 0.7775 - val_loss: 0.4353 - val_accuracy: 0.7800
# Epoch 42/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4313 - accuracy: 0.7781 - val_loss: 0.4309 - val_accuracy: 0.7788
# Epoch 43/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4311 - accuracy: 0.7783 - val_loss: 0.4288 - val_accuracy: 0.7808
# Epoch 44/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4316 - accuracy: 0.7788 - val_loss: 0.4317 - val_accuracy: 0.7799
# Epoch 45/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4311 - accuracy: 0.7787 - val_loss: 0.4306 - val_accuracy: 0.7804
# Epoch 46/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4299 - accuracy: 0.7793 - val_loss: 0.4330 - val_accuracy: 0.7748
# Epoch 47/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4300 - accuracy: 0.7792 - val_loss: 0.4321 - val_accuracy: 0.7800
# Epoch 48/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4302 - accuracy: 0.7793 - val_loss: 0.4296 - val_accuracy: 0.7807
# Epoch 49/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4298 - accuracy: 0.7798 - val_loss: 0.4286 - val_accuracy: 0.7813
# Epoch 50/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4286 - accuracy: 0.7804 - val_loss: 0.4290 - val_accuracy: 0.7812
# Epoch 51/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4286 - accuracy: 0.7801 - val_loss: 0.4296 - val_accuracy: 0.7789
# Epoch 52/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4271 - accuracy: 0.7808 - val_loss: 0.4281 - val_accuracy: 0.7810
# Epoch 53/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4268 - accuracy: 0.7809 - val_loss: 0.4294 - val_accuracy: 0.7792
# Epoch 54/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4274 - accuracy: 0.7807 - val_loss: 0.4290 - val_accuracy: 0.7821
# Epoch 55/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4266 - accuracy: 0.7813 - val_loss: 0.4293 - val_accuracy: 0.7818
# Epoch 56/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4260 - accuracy: 0.7816 - val_loss: 0.4307 - val_accuracy: 0.7787
# Epoch 57/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4261 - accuracy: 0.7816 - val_loss: 0.4274 - val_accuracy: 0.7810
# Epoch 58/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4253 - accuracy: 0.7817 - val_loss: 0.4320 - val_accuracy: 0.7749
# Epoch 59/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4250 - accuracy: 0.7819 - val_loss: 0.4279 - val_accuracy: 0.7796
# Epoch 60/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4255 - accuracy: 0.7816 - val_loss: 0.4285 - val_accuracy: 0.7809
# Epoch 61/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4245 - accuracy: 0.7825 - val_loss: 0.4262 - val_accuracy: 0.7807
# Epoch 62/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4241 - accuracy: 0.7824 - val_loss: 0.4285 - val_accuracy: 0.7799
# Epoch 63/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4244 - accuracy: 0.7827 - val_loss: 0.4306 - val_accuracy: 0.7819
# Epoch 64/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4244 - accuracy: 0.7828 - val_loss: 0.4286 - val_accuracy: 0.7832
# Epoch 65/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4237 - accuracy: 0.7831 - val_loss: 0.4334 - val_accuracy: 0.7825
# Epoch 66/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4223 - accuracy: 0.7831 - val_loss: 0.4246 - val_accuracy: 0.7827
# Epoch 67/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4226 - accuracy: 0.7833 - val_loss: 0.4249 - val_accuracy: 0.7811
# Epoch 68/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4226 - accuracy: 0.7835 - val_loss: 0.4255 - val_accuracy: 0.7828
# Epoch 69/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4220 - accuracy: 0.7839 - val_loss: 0.4252 - val_accuracy: 0.7826
# Epoch 70/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4217 - accuracy: 0.7839 - val_loss: 0.4245 - val_accuracy: 0.7833
# Epoch 71/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4215 - accuracy: 0.7840 - val_loss: 0.4302 - val_accuracy: 0.7781
# Epoch 72/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4215 - accuracy: 0.7837 - val_loss: 0.4252 - val_accuracy: 0.7814
# Epoch 73/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4215 - accuracy: 0.7842 - val_loss: 0.4244 - val_accuracy: 0.7809
# Epoch 74/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4213 - accuracy: 0.7839 - val_loss: 0.4299 - val_accuracy: 0.7801
# Epoch 75/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4207 - accuracy: 0.7844 - val_loss: 0.4248 - val_accuracy: 0.7824
# Epoch 76/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4215 - accuracy: 0.7840 - val_loss: 0.4271 - val_accuracy: 0.7815
# Epoch 77/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4208 - accuracy: 0.7842 - val_loss: 0.4308 - val_accuracy: 0.7803
# Epoch 78/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4198 - accuracy: 0.7848 - val_loss: 0.4284 - val_accuracy: 0.7820
# Epoch 79/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4203 - accuracy: 0.7848 - val_loss: 0.4345 - val_accuracy: 0.7828
# Epoch 80/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4203 - accuracy: 0.7849 - val_loss: 0.4282 - val_accuracy: 0.7835
# Epoch 81/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4202 - accuracy: 0.7845 - val_loss: 0.4251 - val_accuracy: 0.7811
# Epoch 82/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4192 - accuracy: 0.7849 - val_loss: 0.4287 - val_accuracy: 0.7818
# Epoch 83/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4192 - accuracy: 0.7852 - val_loss: 0.4254 - val_accuracy: 0.7817
# Epoch 84/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4192 - accuracy: 0.7853 - val_loss: 0.4254 - val_accuracy: 0.7817
# Epoch 85/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4185 - accuracy: 0.7856 - val_loss: 0.4258 - val_accuracy: 0.7813
# Epoch 86/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4182 - accuracy: 0.7852 - val_loss: 0.4284 - val_accuracy: 0.7826
# Epoch 87/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4189 - accuracy: 0.7854 - val_loss: 0.4238 - val_accuracy: 0.7825
# Epoch 88/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4186 - accuracy: 0.7857 - val_loss: 0.4268 - val_accuracy: 0.7824
# Epoch 89/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4177 - accuracy: 0.7861 - val_loss: 0.4252 - val_accuracy: 0.7824
# Epoch 90/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4172 - accuracy: 0.7862 - val_loss: 0.4270 - val_accuracy: 0.7823
# Epoch 91/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4174 - accuracy: 0.7861 - val_loss: 0.4292 - val_accuracy: 0.7810
# Epoch 92/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4171 - accuracy: 0.7865 - val_loss: 0.4274 - val_accuracy: 0.7809
# Epoch 93/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4174 - accuracy: 0.7862 - val_loss: 0.4225 - val_accuracy: 0.7832
# Epoch 94/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4175 - accuracy: 0.7859 - val_loss: 0.4272 - val_accuracy: 0.7826
# Epoch 95/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4177 - accuracy: 0.7860 - val_loss: 0.4274 - val_accuracy: 0.7817
# Epoch 96/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4168 - accuracy: 0.7866 - val_loss: 0.4284 - val_accuracy: 0.7816
# Epoch 97/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4165 - accuracy: 0.7865 - val_loss: 0.4259 - val_accuracy: 0.7826
# Epoch 98/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4164 - accuracy: 0.7864 - val_loss: 0.4263 - val_accuracy: 0.7836
# Epoch 99/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4163 - accuracy: 0.7869 - val_loss: 0.4239 - val_accuracy: 0.7820
# Epoch 100/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4160 - accuracy: 0.7867 - val_loss: 0.4292 - val_accuracy: 0.7833
# Epoch 101/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4156 - accuracy: 0.7873 - val_loss: 0.4248 - val_accuracy: 0.7806
# Epoch 102/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4155 - accuracy: 0.7869 - val_loss: 0.4268 - val_accuracy: 0.7816
# Epoch 103/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4149 - accuracy: 0.7875 - val_loss: 0.4254 - val_accuracy: 0.7814
# Epoch 104/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4152 - accuracy: 0.7873 - val_loss: 0.4251 - val_accuracy: 0.7833
# Epoch 105/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4147 - accuracy: 0.7874 - val_loss: 0.4227 - val_accuracy: 0.7826
# Epoch 106/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4149 - accuracy: 0.7876 - val_loss: 0.4236 - val_accuracy: 0.7818
# Epoch 107/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4148 - accuracy: 0.7874 - val_loss: 0.4249 - val_accuracy: 0.7830
# Epoch 108/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4142 - accuracy: 0.7882 - val_loss: 0.4237 - val_accuracy: 0.7826
# Epoch 109/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4148 - accuracy: 0.7878 - val_loss: 0.4248 - val_accuracy: 0.7809
# Epoch 110/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4143 - accuracy: 0.7876 - val_loss: 0.4256 - val_accuracy: 0.7828
# Epoch 111/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4132 - accuracy: 0.7883 - val_loss: 0.4272 - val_accuracy: 0.7811
# Epoch 112/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4140 - accuracy: 0.7885 - val_loss: 0.4285 - val_accuracy: 0.7837
# Epoch 113/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4131 - accuracy: 0.7881 - val_loss: 0.4320 - val_accuracy: 0.7803
# Epoch 114/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4136 - accuracy: 0.7885 - val_loss: 0.4283 - val_accuracy: 0.7796
# Epoch 115/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4135 - accuracy: 0.7884 - val_loss: 0.4250 - val_accuracy: 0.7804
# Epoch 116/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4132 - accuracy: 0.7884 - val_loss: 0.4253 - val_accuracy: 0.7838
# Epoch 117/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4129 - accuracy: 0.7884 - val_loss: 0.4253 - val_accuracy: 0.7817
# Epoch 118/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4125 - accuracy: 0.7886 - val_loss: 0.4272 - val_accuracy: 0.7846
# Epoch 119/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4126 - accuracy: 0.7889 - val_loss: 0.4242 - val_accuracy: 0.7833
# Epoch 120/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4133 - accuracy: 0.7888 - val_loss: 0.4253 - val_accuracy: 0.7805
# Epoch 121/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4126 - accuracy: 0.7886 - val_loss: 0.4235 - val_accuracy: 0.7824
# Epoch 122/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4120 - accuracy: 0.7891 - val_loss: 0.4280 - val_accuracy: 0.7761
# Epoch 123/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4128 - accuracy: 0.7885 - val_loss: 0.4262 - val_accuracy: 0.7814
# Epoch 124/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4112 - accuracy: 0.7895 - val_loss: 0.4262 - val_accuracy: 0.7820
# Epoch 125/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4114 - accuracy: 0.7892 - val_loss: 0.4251 - val_accuracy: 0.7818
# Epoch 126/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4115 - accuracy: 0.7892 - val_loss: 0.4342 - val_accuracy: 0.7829
# Epoch 127/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4110 - accuracy: 0.7895 - val_loss: 0.4286 - val_accuracy: 0.7844
# Epoch 128/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4113 - accuracy: 0.7892 - val_loss: 0.4410 - val_accuracy: 0.7843
# Epoch 129/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4114 - accuracy: 0.7890 - val_loss: 0.4239 - val_accuracy: 0.7819
# Epoch 130/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4110 - accuracy: 0.7895 - val_loss: 0.4255 - val_accuracy: 0.7806
# Epoch 131/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4105 - accuracy: 0.7889 - val_loss: 0.4265 - val_accuracy: 0.7793
# Epoch 132/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4096 - accuracy: 0.7898 - val_loss: 0.4244 - val_accuracy: 0.7815
# Epoch 133/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4096 - accuracy: 0.7898 - val_loss: 0.4256 - val_accuracy: 0.7814
# Epoch 134/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4094 - accuracy: 0.7901 - val_loss: 0.4262 - val_accuracy: 0.7842
# Epoch 135/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4100 - accuracy: 0.7900 - val_loss: 0.4259 - val_accuracy: 0.7811
# Epoch 136/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4092 - accuracy: 0.7901 - val_loss: 0.4248 - val_accuracy: 0.7807
# Epoch 137/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4095 - accuracy: 0.7901 - val_loss: 0.4258 - val_accuracy: 0.7804
# Epoch 138/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4088 - accuracy: 0.7903 - val_loss: 0.4269 - val_accuracy: 0.7804
# Epoch 139/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4087 - accuracy: 0.7906 - val_loss: 0.4266 - val_accuracy: 0.7827
# Epoch 140/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4088 - accuracy: 0.7906 - val_loss: 0.4260 - val_accuracy: 0.7797
# Epoch 141/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4091 - accuracy: 0.7901 - val_loss: 0.4247 - val_accuracy: 0.7793
# Epoch 142/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4082 - accuracy: 0.7904 - val_loss: 0.4300 - val_accuracy: 0.7843
# Epoch 143/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4087 - accuracy: 0.7903 - val_loss: 0.4248 - val_accuracy: 0.7816
# Epoch 144/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4081 - accuracy: 0.7907 - val_loss: 0.4282 - val_accuracy: 0.7838
# Epoch 145/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4085 - accuracy: 0.7907 - val_loss: 0.4276 - val_accuracy: 0.7801
# Epoch 146/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4078 - accuracy: 0.7906 - val_loss: 0.4275 - val_accuracy: 0.7834
# Epoch 147/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4077 - accuracy: 0.7904 - val_loss: 0.4253 - val_accuracy: 0.7827
# Epoch 148/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4079 - accuracy: 0.7906 - val_loss: 0.4335 - val_accuracy: 0.7837
# Epoch 149/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4074 - accuracy: 0.7912 - val_loss: 0.4271 - val_accuracy: 0.7837
# Epoch 150/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4074 - accuracy: 0.7911 - val_loss: 0.4314 - val_accuracy: 0.7818
# Epoch 151/160
# 93/93 [==============================] - 5s 48ms/step - loss: 0.4071 - accuracy: 0.7913 - val_loss: 0.4287 - val_accuracy: 0.7804
# Epoch 152/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4067 - accuracy: 0.7914 - val_loss: 0.4271 - val_accuracy: 0.7784
# Epoch 153/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4076 - accuracy: 0.7907 - val_loss: 0.4322 - val_accuracy: 0.7827
# Epoch 154/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4073 - accuracy: 0.7910 - val_loss: 0.4288 - val_accuracy: 0.7839
# Epoch 155/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4073 - accuracy: 0.7913 - val_loss: 0.4260 - val_accuracy: 0.7795
# Epoch 156/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4069 - accuracy: 0.7910 - val_loss: 0.4269 - val_accuracy: 0.7820
# Epoch 157/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4060 - accuracy: 0.7917 - val_loss: 0.4301 - val_accuracy: 0.7844
# Epoch 158/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4058 - accuracy: 0.7917 - val_loss: 0.4246 - val_accuracy: 0.7821
# Epoch 159/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4058 - accuracy: 0.7920 - val_loss: 0.4293 - val_accuracy: 0.7814
# Epoch 160/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4056 - accuracy: 0.7915 - val_loss: 0.4285 - val_accuracy: 0.7810

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 19s 6ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 753.023517370224

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00136368],
#        [0.0068379 ],
#        [0.00085636],
#        ...,
#        [0.02359684],
#        [0.02660269],
#        [0.0288501 ]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14274265615425888
# 0.2324398821771101
# 0.3778129909813304
# 0.2770527717731334

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 90s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.61355814]
# [0.83743313]
# total acc [0.79008216]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 2023595264}
