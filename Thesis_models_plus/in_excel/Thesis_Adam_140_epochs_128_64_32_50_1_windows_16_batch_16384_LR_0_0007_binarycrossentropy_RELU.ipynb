# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1ec4b2e3040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1ec85353040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2]),activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True,activation='relu'),
    keras.layers.GRU(units=32,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 234s 9s/step - loss: 0.5736 - accuracy: 0.7393 - val_loss: 0.5537 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.5497 - accuracy: 0.7393 - val_loss: 0.5190 - val_accuracy: 0.7531
# Epoch 3/140
# 24/24 [==============================] - 228s 10s/step - loss: 0.5156 - accuracy: 0.7393 - val_loss: 0.4928 - val_accuracy: 0.7531
# Epoch 4/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.5010 - accuracy: 0.7396 - val_loss: 0.4857 - val_accuracy: 0.7535
# Epoch 5/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4960 - accuracy: 0.7410 - val_loss: 0.4818 - val_accuracy: 0.7543
# Epoch 6/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4909 - accuracy: 0.7428 - val_loss: 0.4756 - val_accuracy: 0.7548
# Epoch 7/140
# 24/24 [==============================] - 227s 10s/step - loss: 0.4866 - accuracy: 0.7455 - val_loss: 0.4723 - val_accuracy: 0.7570
# Epoch 8/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4825 - accuracy: 0.7490 - val_loss: 0.4716 - val_accuracy: 0.7579
# Epoch 9/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4761 - accuracy: 0.7548 - val_loss: 0.4667 - val_accuracy: 0.7615
# Epoch 10/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4703 - accuracy: 0.7604 - val_loss: 0.4624 - val_accuracy: 0.7645
# Epoch 11/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4663 - accuracy: 0.7631 - val_loss: 0.4580 - val_accuracy: 0.7659
# Epoch 12/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4598 - accuracy: 0.7652 - val_loss: 0.4648 - val_accuracy: 0.7699
# Epoch 13/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4576 - accuracy: 0.7665 - val_loss: 0.4514 - val_accuracy: 0.7713
# Epoch 14/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4551 - accuracy: 0.7674 - val_loss: 0.4483 - val_accuracy: 0.7730
# Epoch 15/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.4534 - accuracy: 0.7686 - val_loss: 0.4475 - val_accuracy: 0.7730
# Epoch 16/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4511 - accuracy: 0.7692 - val_loss: 0.4465 - val_accuracy: 0.7727
# Epoch 17/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4517 - accuracy: 0.7693 - val_loss: 0.4469 - val_accuracy: 0.7738
# Epoch 18/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4496 - accuracy: 0.7703 - val_loss: 0.4445 - val_accuracy: 0.7744
# Epoch 19/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4484 - accuracy: 0.7708 - val_loss: 0.4427 - val_accuracy: 0.7746
# Epoch 20/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4460 - accuracy: 0.7717 - val_loss: 0.4481 - val_accuracy: 0.7716
# Epoch 21/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4478 - accuracy: 0.7708 - val_loss: 0.4406 - val_accuracy: 0.7769
# Epoch 22/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4442 - accuracy: 0.7724 - val_loss: 0.4478 - val_accuracy: 0.7761
# Epoch 23/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.4449 - accuracy: 0.7724 - val_loss: 0.4402 - val_accuracy: 0.7765
# Epoch 24/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4429 - accuracy: 0.7731 - val_loss: 0.4554 - val_accuracy: 0.7636
# Epoch 25/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4457 - accuracy: 0.7725 - val_loss: 0.4405 - val_accuracy: 0.7769
# Epoch 26/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4411 - accuracy: 0.7740 - val_loss: 0.4381 - val_accuracy: 0.7782
# Epoch 27/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4422 - accuracy: 0.7738 - val_loss: 0.4418 - val_accuracy: 0.7774
# Epoch 28/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4427 - accuracy: 0.7736 - val_loss: 0.4426 - val_accuracy: 0.7751
# Epoch 29/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4403 - accuracy: 0.7744 - val_loss: 0.4454 - val_accuracy: 0.7776
# Epoch 30/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4404 - accuracy: 0.7748 - val_loss: 0.4410 - val_accuracy: 0.7728
# Epoch 31/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4416 - accuracy: 0.7742 - val_loss: 0.4432 - val_accuracy: 0.7725
# Epoch 32/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4393 - accuracy: 0.7752 - val_loss: 0.4476 - val_accuracy: 0.7778
# Epoch 33/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4416 - accuracy: 0.7744 - val_loss: 0.4378 - val_accuracy: 0.7786
# Epoch 34/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4381 - accuracy: 0.7757 - val_loss: 0.4379 - val_accuracy: 0.7757
# Epoch 35/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4375 - accuracy: 0.7755 - val_loss: 0.4382 - val_accuracy: 0.7759
# Epoch 36/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4369 - accuracy: 0.7760 - val_loss: 0.4356 - val_accuracy: 0.7787
# Epoch 37/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4363 - accuracy: 0.7764 - val_loss: 0.4480 - val_accuracy: 0.7781
# Epoch 38/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4393 - accuracy: 0.7756 - val_loss: 0.4369 - val_accuracy: 0.7788
# Epoch 39/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4362 - accuracy: 0.7767 - val_loss: 0.4356 - val_accuracy: 0.7782
# Epoch 40/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4357 - accuracy: 0.7768 - val_loss: 0.4425 - val_accuracy: 0.7734
# Epoch 41/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4362 - accuracy: 0.7765 - val_loss: 0.4374 - val_accuracy: 0.7760
# Epoch 42/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4361 - accuracy: 0.7767 - val_loss: 0.4368 - val_accuracy: 0.7777
# Epoch 43/140
# 24/24 [==============================] - 233s 10s/step - loss: 0.4355 - accuracy: 0.7771 - val_loss: 0.4350 - val_accuracy: 0.7794
# Epoch 44/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4345 - accuracy: 0.7777 - val_loss: 0.4348 - val_accuracy: 0.7792
# Epoch 45/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4338 - accuracy: 0.7777 - val_loss: 0.4348 - val_accuracy: 0.7784
# Epoch 46/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4333 - accuracy: 0.7777 - val_loss: 0.4352 - val_accuracy: 0.7802
# Epoch 47/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4337 - accuracy: 0.7778 - val_loss: 0.4362 - val_accuracy: 0.7777
# Epoch 48/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4343 - accuracy: 0.7776 - val_loss: 0.4373 - val_accuracy: 0.7800
# Epoch 49/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4348 - accuracy: 0.7777 - val_loss: 0.4328 - val_accuracy: 0.7800
# Epoch 50/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4320 - accuracy: 0.7787 - val_loss: 0.4343 - val_accuracy: 0.7812
# Epoch 51/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4338 - accuracy: 0.7777 - val_loss: 0.4350 - val_accuracy: 0.7795
# Epoch 52/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4322 - accuracy: 0.7785 - val_loss: 0.4482 - val_accuracy: 0.7792
# Epoch 53/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4341 - accuracy: 0.7772 - val_loss: 0.4338 - val_accuracy: 0.7808
# Epoch 54/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4325 - accuracy: 0.7783 - val_loss: 0.4327 - val_accuracy: 0.7799
# Epoch 55/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4312 - accuracy: 0.7793 - val_loss: 0.4323 - val_accuracy: 0.7811
# Epoch 56/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4318 - accuracy: 0.7788 - val_loss: 0.4315 - val_accuracy: 0.7811
# Epoch 57/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4310 - accuracy: 0.7789 - val_loss: 0.4337 - val_accuracy: 0.7793
# Epoch 58/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4308 - accuracy: 0.7792 - val_loss: 0.4320 - val_accuracy: 0.7811
# Epoch 59/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4313 - accuracy: 0.7790 - val_loss: 0.4309 - val_accuracy: 0.7813
# Epoch 60/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4301 - accuracy: 0.7795 - val_loss: 0.4373 - val_accuracy: 0.7756
# Epoch 61/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4314 - accuracy: 0.7791 - val_loss: 0.4314 - val_accuracy: 0.7808
# Epoch 62/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4304 - accuracy: 0.7792 - val_loss: 0.4321 - val_accuracy: 0.7811
# Epoch 63/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4314 - accuracy: 0.7788 - val_loss: 0.4379 - val_accuracy: 0.7740
# Epoch 64/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4329 - accuracy: 0.7787 - val_loss: 0.4327 - val_accuracy: 0.7811
# Epoch 65/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4315 - accuracy: 0.7793 - val_loss: 0.4338 - val_accuracy: 0.7817
# Epoch 66/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4326 - accuracy: 0.7787 - val_loss: 0.4410 - val_accuracy: 0.7802
# Epoch 67/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4312 - accuracy: 0.7797 - val_loss: 0.4316 - val_accuracy: 0.7818
# Epoch 68/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4302 - accuracy: 0.7797 - val_loss: 0.4323 - val_accuracy: 0.7802
# Epoch 69/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4290 - accuracy: 0.7801 - val_loss: 0.4316 - val_accuracy: 0.7802
# Epoch 70/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4291 - accuracy: 0.7801 - val_loss: 0.4318 - val_accuracy: 0.7816
# Epoch 71/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.4310 - accuracy: 0.7795 - val_loss: 0.4311 - val_accuracy: 0.7810
# Epoch 72/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4283 - accuracy: 0.7801 - val_loss: 0.4325 - val_accuracy: 0.7813
# Epoch 73/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4293 - accuracy: 0.7801 - val_loss: 0.4321 - val_accuracy: 0.7820
# Epoch 74/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4281 - accuracy: 0.7804 - val_loss: 0.4325 - val_accuracy: 0.7822
# Epoch 75/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4285 - accuracy: 0.7803 - val_loss: 0.4301 - val_accuracy: 0.7816
# Epoch 76/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4276 - accuracy: 0.7808 - val_loss: 0.4311 - val_accuracy: 0.7804
# Epoch 77/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4283 - accuracy: 0.7802 - val_loss: 0.4317 - val_accuracy: 0.7808
# Epoch 78/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4279 - accuracy: 0.7804 - val_loss: 0.4310 - val_accuracy: 0.7811
# Epoch 79/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4275 - accuracy: 0.7809 - val_loss: 0.4318 - val_accuracy: 0.7800
# Epoch 80/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4279 - accuracy: 0.7808 - val_loss: 0.4342 - val_accuracy: 0.7756
# Epoch 81/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4279 - accuracy: 0.7810 - val_loss: 0.4325 - val_accuracy: 0.7820
# Epoch 82/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4294 - accuracy: 0.7803 - val_loss: 0.4329 - val_accuracy: 0.7790
# Epoch 83/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4269 - accuracy: 0.7810 - val_loss: 0.4344 - val_accuracy: 0.7815
# Epoch 84/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4269 - accuracy: 0.7811 - val_loss: 0.4335 - val_accuracy: 0.7788
# Epoch 85/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4263 - accuracy: 0.7810 - val_loss: 0.4305 - val_accuracy: 0.7809
# Epoch 86/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4287 - accuracy: 0.7805 - val_loss: 0.4288 - val_accuracy: 0.7824
# Epoch 87/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.4259 - accuracy: 0.7816 - val_loss: 0.4342 - val_accuracy: 0.7760
# Epoch 88/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4259 - accuracy: 0.7815 - val_loss: 0.4362 - val_accuracy: 0.7809
# Epoch 89/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4264 - accuracy: 0.7819 - val_loss: 0.4321 - val_accuracy: 0.7813
# Epoch 90/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4262 - accuracy: 0.7818 - val_loss: 0.4323 - val_accuracy: 0.7811
# Epoch 91/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4254 - accuracy: 0.7820 - val_loss: 0.4308 - val_accuracy: 0.7818
# Epoch 92/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4259 - accuracy: 0.7815 - val_loss: 0.4374 - val_accuracy: 0.7815
# Epoch 93/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4266 - accuracy: 0.7819 - val_loss: 0.4327 - val_accuracy: 0.7811
# Epoch 94/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4257 - accuracy: 0.7820 - val_loss: 0.4344 - val_accuracy: 0.7817
# Epoch 95/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4257 - accuracy: 0.7821 - val_loss: 0.4387 - val_accuracy: 0.7816
# Epoch 96/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4264 - accuracy: 0.7818 - val_loss: 0.4294 - val_accuracy: 0.7813
# Epoch 97/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4257 - accuracy: 0.7820 - val_loss: 0.4384 - val_accuracy: 0.7726
# Epoch 98/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4284 - accuracy: 0.7814 - val_loss: 0.4312 - val_accuracy: 0.7818
# Epoch 99/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4259 - accuracy: 0.7819 - val_loss: 0.4311 - val_accuracy: 0.7825
# Epoch 100/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4254 - accuracy: 0.7823 - val_loss: 0.4322 - val_accuracy: 0.7814
# Epoch 101/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4237 - accuracy: 0.7822 - val_loss: 0.4303 - val_accuracy: 0.7809
# Epoch 102/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4238 - accuracy: 0.7829 - val_loss: 0.4308 - val_accuracy: 0.7795
# Epoch 103/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4234 - accuracy: 0.7826 - val_loss: 0.4310 - val_accuracy: 0.7786
# Epoch 104/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4237 - accuracy: 0.7825 - val_loss: 0.4294 - val_accuracy: 0.7803
# Epoch 105/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4241 - accuracy: 0.7824 - val_loss: 0.4426 - val_accuracy: 0.7816
# Epoch 106/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4243 - accuracy: 0.7822 - val_loss: 0.4307 - val_accuracy: 0.7796
# Epoch 107/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4229 - accuracy: 0.7826 - val_loss: 0.4335 - val_accuracy: 0.7774
# Epoch 108/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4239 - accuracy: 0.7830 - val_loss: 0.4332 - val_accuracy: 0.7796
# Epoch 109/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4237 - accuracy: 0.7825 - val_loss: 0.4444 - val_accuracy: 0.7815
# Epoch 110/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4265 - accuracy: 0.7819 - val_loss: 0.4312 - val_accuracy: 0.7793
# Epoch 111/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.4236 - accuracy: 0.7833 - val_loss: 0.4341 - val_accuracy: 0.7814
# Epoch 112/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4236 - accuracy: 0.7829 - val_loss: 0.4292 - val_accuracy: 0.7818
# Epoch 113/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4228 - accuracy: 0.7833 - val_loss: 0.4291 - val_accuracy: 0.7816
# Epoch 114/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4225 - accuracy: 0.7830 - val_loss: 0.4283 - val_accuracy: 0.7821
# Epoch 115/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4224 - accuracy: 0.7833 - val_loss: 0.4379 - val_accuracy: 0.7820
# Epoch 116/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4235 - accuracy: 0.7831 - val_loss: 0.4295 - val_accuracy: 0.7825
# Epoch 117/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4221 - accuracy: 0.7833 - val_loss: 0.4282 - val_accuracy: 0.7826
# Epoch 118/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4217 - accuracy: 0.7836 - val_loss: 0.4333 - val_accuracy: 0.7820
# Epoch 119/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4221 - accuracy: 0.7833 - val_loss: 0.4292 - val_accuracy: 0.7806
# Epoch 120/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4214 - accuracy: 0.7836 - val_loss: 0.4359 - val_accuracy: 0.7821
# Epoch 121/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4211 - accuracy: 0.7838 - val_loss: 0.4284 - val_accuracy: 0.7808
# Epoch 122/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4209 - accuracy: 0.7841 - val_loss: 0.4349 - val_accuracy: 0.7830
# Epoch 123/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4237 - accuracy: 0.7832 - val_loss: 0.4275 - val_accuracy: 0.7821
# Epoch 124/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4233 - accuracy: 0.7835 - val_loss: 0.4315 - val_accuracy: 0.7823
# Epoch 125/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4219 - accuracy: 0.7836 - val_loss: 0.4272 - val_accuracy: 0.7823
# Epoch 126/140
# 24/24 [==============================] - 226s 9s/step - loss: 0.4202 - accuracy: 0.7842 - val_loss: 0.4331 - val_accuracy: 0.7783
# Epoch 127/140
# 24/24 [==============================] - 227s 9s/step - loss: 0.4202 - accuracy: 0.7843 - val_loss: 0.4297 - val_accuracy: 0.7819
# Epoch 128/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4205 - accuracy: 0.7840 - val_loss: 0.4275 - val_accuracy: 0.7835
# Epoch 129/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4205 - accuracy: 0.7839 - val_loss: 0.4294 - val_accuracy: 0.7792
# Epoch 130/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4202 - accuracy: 0.7842 - val_loss: 0.4277 - val_accuracy: 0.7817
# Epoch 131/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4203 - accuracy: 0.7846 - val_loss: 0.4327 - val_accuracy: 0.7824
# Epoch 132/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4202 - accuracy: 0.7842 - val_loss: 0.4273 - val_accuracy: 0.7829
# Epoch 133/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4200 - accuracy: 0.7847 - val_loss: 0.4305 - val_accuracy: 0.7797
# Epoch 134/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4193 - accuracy: 0.7850 - val_loss: 0.4281 - val_accuracy: 0.7813
# Epoch 135/140
# 24/24 [==============================] - 225s 9s/step - loss: 0.4190 - accuracy: 0.7846 - val_loss: 0.4280 - val_accuracy: 0.7818
# Epoch 136/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4196 - accuracy: 0.7846 - val_loss: 0.4278 - val_accuracy: 0.7813
# Epoch 137/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4195 - accuracy: 0.7845 - val_loss: 0.4283 - val_accuracy: 0.7805
# Epoch 138/140
# 24/24 [==============================] - 224s 9s/step - loss: 0.4197 - accuracy: 0.7846 - val_loss: 0.4292 - val_accuracy: 0.7819
# Epoch 139/140
# 24/24 [==============================] - 223s 9s/step - loss: 0.4187 - accuracy: 0.7846 - val_loss: 0.4301 - val_accuracy: 0.7800
# Epoch 140/140
# 24/24 [==============================] - 222s 9s/step - loss: 0.4186 - accuracy: 0.7849 - val_loss: 0.4281 - val_accuracy: 0.7812

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 40s 13ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 31486.817220926285

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00528059],
#        [0.00367344],
#        [0.00204995],
#        ...,
#        [0.0907511 ],
#        [0.09413058],
#        [0.09831082]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1435433830571119
# 0.22811236168082716
# 0.3788711958662362
# 0.28601717011114225

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 203s 14ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60693433]
# [0.82811254]
# total acc [0.78436046]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1928\725781306.py in <module>
# ----> 1 tf.config.experimental.get_memory_info('GPU:0')
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\config.py in get_memory_info(device)
#     574     ValueError: Memory statistics not tracked, like '"CPU:0"'.
#     575   """
# --> 576   return context.context().get_memory_info(device)
#     577
#     578
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in get_memory_info(self, dev)
#    1605     self._initialize_physical_devices()
#    1606     self.ensure_initialized()
# -> 1607     return pywrap_tfe.TFE_GetMemoryInfo(self._context_handle, dev)
#    1608
#    1609   def reset_memory_stats(self, dev):
#
# ValueError: No matching devices found for 'GPU:0'
