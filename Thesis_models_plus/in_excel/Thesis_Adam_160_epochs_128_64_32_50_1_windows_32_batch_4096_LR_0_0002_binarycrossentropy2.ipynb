# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1f400009040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1f3868dd040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0002)
model_gru.compile(loss='BinaryCrossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=160,validation_data=(test_X, test_y),batch_size=4096)#, shuffle=False)
# Out:
# Epoch 1/160
# 93/93 [==============================] - 13s 62ms/step - loss: 0.6798 - accuracy: 0.5843 - val_loss: 0.5608 - val_accuracy: 0.7530
# Epoch 2/160
# 93/93 [==============================] - 4s 47ms/step - loss: 0.5739 - accuracy: 0.7393 - val_loss: 0.5595 - val_accuracy: 0.7530
# Epoch 3/160
# 93/93 [==============================] - 4s 47ms/step - loss: 0.5738 - accuracy: 0.7393 - val_loss: 0.5594 - val_accuracy: 0.7530
160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4418 - accuracy: 0.7724 - val_loss: 0.4370 - val_accuracy: 0.7772
# Epoch 51/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4412 - accuracy: 0.7728 - val_loss: 0.4356 - val_accuracy: 0.7768
# Epoch 52/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4413 - accuracy: 0.7726 - val_loss: 0.4393 - val_accuracy: 0.7770
# Epoch 53/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4404 - accuracy: 0.7729 - val_loss: 0.4353 - val_accuracy: 0.7785
# Epoch 54/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4407 - accuracy: 0.7732 - val_loss: 0.4363 - val_accuracy: 0.7771
# Epoch 55/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4398 - accuracy: 0.7734 - val_loss: 0.4347 - val_accuracy: 0.7774
# Epoch 56/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4394 - accuracy: 0.7737 - val_loss: 0.4340 - val_accuracy: 0.7784
# Epoch 57/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4395 - accuracy: 0.7740 - val_loss: 0.4352 - val_accuracy: 0.7783
# Epoch 58/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4386 - accuracy: 0.7744 - val_loss: 0.4349 - val_accuracy: 0.7768
# Epoch 59/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4384 - accuracy: 0.7743 - val_loss: 0.4371 - val_accuracy: 0.7763
# Epoch 60/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4381 - accuracy: 0.7746 - val_loss: 0.4344 - val_accuracy: 0.7766
# Epoch 61/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4398 - accuracy: 0.7746 - val_loss: 0.4370 - val_accuracy: 0.7781
# Epoch 62/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4389 - accuracy: 0.7750 - val_loss: 0.4342 - val_accuracy: 0.7771
# Epoch 63/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4373 - accuracy: 0.7753 - val_loss: 0.4351 - val_accuracy: 0.7792
# Epoch 64/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4374 - accuracy: 0.7754 - val_loss: 0.4367 - val_accuracy: 0.7756
# Epoch 65/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4379 - accuracy: 0.7752 - val_loss: 0.4358 - val_accuracy: 0.7766
# Epoch 66/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4371 - accuracy: 0.7755 - val_loss: 0.4323 - val_accuracy: 0.7786
# Epoch 67/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4366 - accuracy: 0.7758 - val_loss: 0.4327 - val_accuracy: 0.7775
# Epoch 68/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4364 - accuracy: 0.7759 - val_loss: 0.4340 - val_accuracy: 0.7785
# Epoch 69/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4370 - accuracy: 0.7761 - val_loss: 0.4340 - val_accuracy: 0.7777
# Epoch 70/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4361 - accuracy: 0.7760 - val_loss: 0.4327 - val_accuracy: 0.7772
# Epoch 71/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4360 - accuracy: 0.7759 - val_loss: 0.4334 - val_accuracy: 0.7763
# Epoch 72/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4366 - accuracy: 0.7761 - val_loss: 0.4326 - val_accuracy: 0.7782
# Epoch 73/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4357 - accuracy: 0.7763 - val_loss: 0.4328 - val_accuracy: 0.7771
# Epoch 74/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4354 - accuracy: 0.7765 - val_loss: 0.4377 - val_accuracy: 0.7785
# Epoch 75/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4352 - accuracy: 0.7764 - val_loss: 0.4316 - val_accuracy: 0.7791
# Epoch 76/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4349 - accuracy: 0.7766 - val_loss: 0.4306 - val_accuracy: 0.7800
# Epoch 77/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4351 - accuracy: 0.7766 - val_loss: 0.4321 - val_accuracy: 0.7793
# Epoch 78/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4351 - accuracy: 0.7768 - val_loss: 0.4309 - val_accuracy: 0.7792
# Epoch 79/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4348 - accuracy: 0.7769 - val_loss: 0.4319 - val_accuracy: 0.7788
# Epoch 80/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4342 - accuracy: 0.7768 - val_loss: 0.4312 - val_accuracy: 0.7790
# Epoch 81/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4343 - accuracy: 0.7769 - val_loss: 0.4365 - val_accuracy: 0.7785
# Epoch 82/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4339 - accuracy: 0.7769 - val_loss: 0.4328 - val_accuracy: 0.7785
# Epoch 83/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4339 - accuracy: 0.7773 - val_loss: 0.4369 - val_accuracy: 0.7793
# Epoch 84/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4346 - accuracy: 0.7770 - val_loss: 0.4307 - val_accuracy: 0.7787
# Epoch 85/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4333 - accuracy: 0.7771 - val_loss: 0.4325 - val_accuracy: 0.7791
# Epoch 86/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4337 - accuracy: 0.7771 - val_loss: 0.4319 - val_accuracy: 0.7794
# Epoch 87/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4335 - accuracy: 0.7775 - val_loss: 0.4363 - val_accuracy: 0.7779
# Epoch 88/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4337 - accuracy: 0.7774 - val_loss: 0.4313 - val_accuracy: 0.7777
# Epoch 89/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4330 - accuracy: 0.7775 - val_loss: 0.4319 - val_accuracy: 0.7800
# Epoch 90/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4325 - accuracy: 0.7776 - val_loss: 0.4309 - val_accuracy: 0.7802
# Epoch 91/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4328 - accuracy: 0.7774 - val_loss: 0.4315 - val_accuracy: 0.7775
# Epoch 92/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4325 - accuracy: 0.7776 - val_loss: 0.4330 - val_accuracy: 0.7789
# Epoch 93/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4325 - accuracy: 0.7778 - val_loss: 0.4328 - val_accuracy: 0.7794
# Epoch 94/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4330 - accuracy: 0.7775 - val_loss: 0.4322 - val_accuracy: 0.7775
# Epoch 95/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4322 - accuracy: 0.7779 - val_loss: 0.4314 - val_accuracy: 0.7777
# Epoch 96/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4317 - accuracy: 0.7781 - val_loss: 0.4296 - val_accuracy: 0.7777
# Epoch 97/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4320 - accuracy: 0.7779 - val_loss: 0.4300 - val_accuracy: 0.7777
# Epoch 98/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4314 - accuracy: 0.7785 - val_loss: 0.4299 - val_accuracy: 0.7795
# Epoch 99/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4327 - accuracy: 0.7783 - val_loss: 0.4294 - val_accuracy: 0.7785
# Epoch 100/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4318 - accuracy: 0.7781 - val_loss: 0.4304 - val_accuracy: 0.7779
# Epoch 101/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4312 - accuracy: 0.7782 - val_loss: 0.4318 - val_accuracy: 0.7800
# Epoch 102/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4319 - accuracy: 0.7779 - val_loss: 0.4300 - val_accuracy: 0.7789
# Epoch 103/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4312 - accuracy: 0.7782 - val_loss: 0.4308 - val_accuracy: 0.7790
# Epoch 104/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4310 - accuracy: 0.7787 - val_loss: 0.4314 - val_accuracy: 0.7803
# Epoch 105/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4304 - accuracy: 0.7784 - val_loss: 0.4320 - val_accuracy: 0.7796
# Epoch 106/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4312 - accuracy: 0.7786 - val_loss: 0.4322 - val_accuracy: 0.7791
# Epoch 107/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4317 - accuracy: 0.7785 - val_loss: 0.4353 - val_accuracy: 0.7808
# Epoch 108/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4303 - accuracy: 0.7791 - val_loss: 0.4315 - val_accuracy: 0.7785
# Epoch 109/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4300 - accuracy: 0.7788 - val_loss: 0.4291 - val_accuracy: 0.7781
# Epoch 110/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4302 - accuracy: 0.7789 - val_loss: 0.4306 - val_accuracy: 0.7776
# Epoch 111/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4310 - accuracy: 0.7785 - val_loss: 0.4341 - val_accuracy: 0.7804
# Epoch 112/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4302 - accuracy: 0.7790 - val_loss: 0.4324 - val_accuracy: 0.7802
# Epoch 113/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4299 - accuracy: 0.7788 - val_loss: 0.4327 - val_accuracy: 0.7750
# Epoch 114/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4305 - accuracy: 0.7790 - val_loss: 0.4315 - val_accuracy: 0.7805
# Epoch 115/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4304 - accuracy: 0.7791 - val_loss: 0.4305 - val_accuracy: 0.7781
# Epoch 116/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4298 - accuracy: 0.7789 - val_loss: 0.4315 - val_accuracy: 0.7814
# Epoch 117/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4294 - accuracy: 0.7792 - val_loss: 0.4308 - val_accuracy: 0.7760
# Epoch 118/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4290 - accuracy: 0.7794 - val_loss: 0.4303 - val_accuracy: 0.7808
# Epoch 119/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4302 - accuracy: 0.7793 - val_loss: 0.4292 - val_accuracy: 0.7790
# Epoch 120/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4294 - accuracy: 0.7796 - val_loss: 0.4306 - val_accuracy: 0.7806
# Epoch 121/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4289 - accuracy: 0.7797 - val_loss: 0.4309 - val_accuracy: 0.7784
# Epoch 122/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4300 - accuracy: 0.7794 - val_loss: 0.4342 - val_accuracy: 0.7815
# Epoch 123/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4290 - accuracy: 0.7796 - val_loss: 0.4321 - val_accuracy: 0.7758
# Epoch 124/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4293 - accuracy: 0.7796 - val_loss: 0.4296 - val_accuracy: 0.7788
# Epoch 125/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4283 - accuracy: 0.7798 - val_loss: 0.4279 - val_accuracy: 0.7803
# Epoch 126/160
# 93/93 [==============================] - 5s 50ms/step - loss: 0.4287 - accuracy: 0.7799 - val_loss: 0.4285 - val_accuracy: 0.7801
# Epoch 127/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4284 - accuracy: 0.7798 - val_loss: 0.4287 - val_accuracy: 0.7801
# Epoch 128/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4283 - accuracy: 0.7799 - val_loss: 0.4305 - val_accuracy: 0.7794
# Epoch 129/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4286 - accuracy: 0.7800 - val_loss: 0.4286 - val_accuracy: 0.7786
# Epoch 130/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4278 - accuracy: 0.7804 - val_loss: 0.4297 - val_accuracy: 0.7791
# Epoch 131/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4278 - accuracy: 0.7804 - val_loss: 0.4300 - val_accuracy: 0.7780
# Epoch 132/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4276 - accuracy: 0.7803 - val_loss: 0.4302 - val_accuracy: 0.7791
# Epoch 133/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4279 - accuracy: 0.7801 - val_loss: 0.4295 - val_accuracy: 0.7802
# Epoch 134/160
# 93/93 [==============================] - 5s 52ms/step - loss: 0.4274 - accuracy: 0.7806 - val_loss: 0.4284 - val_accuracy: 0.7800
# Epoch 135/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4273 - accuracy: 0.7802 - val_loss: 0.4293 - val_accuracy: 0.7803
# Epoch 136/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4246 - accuracy: 0.7820 - val_loss: 0.4304 - val_accuracy: 0.7805
# Epoch 159/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4238 - accuracy: 0.7823 - val_loss: 0.4302 - val_accuracy: 0.7804
# Epoch 160/160
# 93/93 [==============================] - 5s 51ms/step - loss: 0.4237 - accuracy: 0.7825 - val_loss: 0.4276 - val_accuracy: 0.7800

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 21s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 768.551607131958

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00058515],
#        [0.00117331],
#        [0.00075516],
#        ...,
#        [0.05336817],
#        [0.05548272],
#        [0.05840478]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14328493921379257
# 0.22952390134641
# 0.3785299713547034
# 0.28658435862366494

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 109s 7ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60186104]
# [0.82650146]
# total acc [0.78221142]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 2023541760}
