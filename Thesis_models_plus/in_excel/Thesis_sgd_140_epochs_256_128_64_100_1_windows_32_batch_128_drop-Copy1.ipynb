# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x21fe0f32040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x22054feb040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           209664
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  dropout (Dropout)           (None, 32, 128)           0
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=128)#, shuffle=False)
# Out:
# Epoch 1/140
# 2971/2971 [==============================] - 87s 27ms/step - loss: 0.5719 - accuracy: 0.7390 - val_loss: 0.5539 - val_accuracy: 0.7530
# Epoch 2/140
# 2971/2971 [==============================] - 78s 26ms/step - loss: 0.5545 - accuracy: 0.7396 - val_loss: 0.5253 - val_accuracy: 0.7499
# Epoch 3/140
# 2971/2971 [==============================] - 79s 26ms/step - loss: 0.5188 - accuracy: 0.7399 - val_loss: 0.4946 - val_accuracy: 0.7462
# Epoch 4/140
140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4395 - accuracy: 0.7743 - val_loss: 0.4377 - val_accuracy: 0.7769
# Epoch 77/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4394 - accuracy: 0.7747 - val_loss: 0.4353 - val_accuracy: 0.7773
# Epoch 78/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4393 - accuracy: 0.7739 - val_loss: 0.4331 - val_accuracy: 0.7771
# Epoch 79/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4391 - accuracy: 0.7743 - val_loss: 0.4359 - val_accuracy: 0.7775
# Epoch 80/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4390 - accuracy: 0.7745 - val_loss: 0.4330 - val_accuracy: 0.7766
# Epoch 81/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4388 - accuracy: 0.7747 - val_loss: 0.4374 - val_accuracy: 0.7769
# Epoch 82/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4386 - accuracy: 0.7745 - val_loss: 0.4376 - val_accuracy: 0.7776
# Epoch 83/140
# 2971/2971 [==============================] - 76s 25ms/step - loss: 0.4384 - accuracy: 0.7746 - val_loss: 0.4331 - val_accuracy: 0.7774
# Epoch 84/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4383 - accuracy: 0.7749 - val_loss: 0.4391 - val_accuracy: 0.7748
# Epoch 85/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4382 - accuracy: 0.7752 - val_loss: 0.4359 - val_accuracy: 0.7762
# Epoch 86/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4381 - accuracy: 0.7751 - val_loss: 0.4333 - val_accuracy: 0.7777
# Epoch 87/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4378 - accuracy: 0.7753 - val_loss: 0.4317 - val_accuracy: 0.7775
# Epoch 88/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4378 - accuracy: 0.7753 - val_loss: 0.4352 - val_accuracy: 0.7774
# Epoch 89/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4375 - accuracy: 0.7754 - val_loss: 0.4314 - val_accuracy: 0.7784
# Epoch 90/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4375 - accuracy: 0.7751 - val_loss: 0.4318 - val_accuracy: 0.7784
# Epoch 91/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4371 - accuracy: 0.7756 - val_loss: 0.4327 - val_accuracy: 0.7784
# Epoch 92/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4370 - accuracy: 0.7757 - val_loss: 0.4312 - val_accuracy: 0.7790
# Epoch 93/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4369 - accuracy: 0.7756 - val_loss: 0.4438 - val_accuracy: 0.7764
# Epoch 94/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4365 - accuracy: 0.7757 - val_loss: 0.4331 - val_accuracy: 0.7784
# Epoch 95/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4365 - accuracy: 0.7758 - val_loss: 0.4366 - val_accuracy: 0.7797
# Epoch 96/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4363 - accuracy: 0.7755 - val_loss: 0.4356 - val_accuracy: 0.7785
# Epoch 97/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4361 - accuracy: 0.7760 - val_loss: 0.4304 - val_accuracy: 0.7790
# Epoch 98/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4359 - accuracy: 0.7762 - val_loss: 0.4406 - val_accuracy: 0.7742
# Epoch 99/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4356 - accuracy: 0.7769 - val_loss: 0.4299 - val_accuracy: 0.7790
# Epoch 100/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4353 - accuracy: 0.7766 - val_loss: 0.4318 - val_accuracy: 0.7792
# Epoch 101/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4349 - accuracy: 0.7769 - val_loss: 0.4323 - val_accuracy: 0.7801
# Epoch 102/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4346 - accuracy: 0.7770 - val_loss: 0.4313 - val_accuracy: 0.7779
# Epoch 103/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4344 - accuracy: 0.7775 - val_loss: 0.4312 - val_accuracy: 0.7810
# Epoch 104/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4341 - accuracy: 0.7778 - val_loss: 0.4297 - val_accuracy: 0.7798
# Epoch 105/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4340 - accuracy: 0.7777 - val_loss: 0.4337 - val_accuracy: 0.7762
# Epoch 106/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4337 - accuracy: 0.7775 - val_loss: 0.4310 - val_accuracy: 0.7811
# Epoch 107/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4335 - accuracy: 0.7777 - val_loss: 0.4308 - val_accuracy: 0.7804
# Epoch 108/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4331 - accuracy: 0.7779 - val_loss: 0.4275 - val_accuracy: 0.7802
# Epoch 109/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4330 - accuracy: 0.7779 - val_loss: 0.4278 - val_accuracy: 0.7801
# Epoch 110/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4328 - accuracy: 0.7781 - val_loss: 0.4300 - val_accuracy: 0.7804
# Epoch 111/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4326 - accuracy: 0.7782 - val_loss: 0.4293 - val_accuracy: 0.7803
# Epoch 112/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4325 - accuracy: 0.7781 - val_loss: 0.4304 - val_accuracy: 0.7803
# Epoch 113/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4322 - accuracy: 0.7783 - val_loss: 0.4279 - val_accuracy: 0.7809
# Epoch 114/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4321 - accuracy: 0.7787 - val_loss: 0.4281 - val_accuracy: 0.7815
# Epoch 115/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4319 - accuracy: 0.7786 - val_loss: 0.4350 - val_accuracy: 0.7810
# Epoch 116/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4316 - accuracy: 0.7786 - val_loss: 0.4317 - val_accuracy: 0.7790
# Epoch 117/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4316 - accuracy: 0.7784 - val_loss: 0.4273 - val_accuracy: 0.7815
# Epoch 118/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4314 - accuracy: 0.7789 - val_loss: 0.4303 - val_accuracy: 0.7793
# Epoch 119/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4312 - accuracy: 0.7793 - val_loss: 0.4277 - val_accuracy: 0.7812
# Epoch 120/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4312 - accuracy: 0.7791 - val_loss: 0.4279 - val_accuracy: 0.7815
# Epoch 121/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4309 - accuracy: 0.7787 - val_loss: 0.4273 - val_accuracy: 0.7817
# Epoch 122/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4307 - accuracy: 0.7792 - val_loss: 0.4302 - val_accuracy: 0.7820
# Epoch 123/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4304 - accuracy: 0.7797 - val_loss: 0.4299 - val_accuracy: 0.7815
# Epoch 124/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4302 - accuracy: 0.7799 - val_loss: 0.4284 - val_accuracy: 0.7814
# Epoch 125/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4301 - accuracy: 0.7794 - val_loss: 0.4340 - val_accuracy: 0.7798
# Epoch 126/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4300 - accuracy: 0.7799 - val_loss: 0.4276 - val_accuracy: 0.7822
# Epoch 127/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4298 - accuracy: 0.7800 - val_loss: 0.4273 - val_accuracy: 0.7825
# Epoch 128/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4298 - accuracy: 0.7802 - val_loss: 0.4365 - val_accuracy: 0.7738
# Epoch 129/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4296 - accuracy: 0.7803 - val_loss: 0.4292 - val_accuracy: 0.7827
# Epoch 130/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4295 - accuracy: 0.7799 - val_loss: 0.4296 - val_accuracy: 0.7829
# Epoch 131/140
# 2971/2971 [==============================] - 76s 26ms/step - loss: 0.4293 - accuracy: 0.7802 - val_loss: 0.4288 - val_accuracy: 0.7811
# Epoch 132/140
# 2971/2971 [==============================] - 79s 27ms/step - loss: 0.4294 - accuracy: 0.7799 - val_loss: 0.4328 - val_accuracy: 0.7750
# Epoch 133/140
# 2971/2971 [==============================] - 85s 28ms/step - loss: 0.4291 - accuracy: 0.7804 - val_loss: 0.4299 - val_accuracy: 0.7812
# Epoch 134/140
# 2971/2971 [==============================] - 79s 27ms/step - loss: 0.4288 - accuracy: 0.7805 - val_loss: 0.4319 - val_accuracy: 0.7789
# Epoch 135/140
# 2971/2971 [==============================] - 86s 29ms/step - loss: 0.4289 - accuracy: 0.7806 - val_loss: 0.4282 - val_accuracy: 0.7826
# Epoch 136/140
# 2971/2971 [==============================] - 82s 28ms/step - loss: 0.4287 - accuracy: 0.7803 - val_loss: 0.4271 - val_accuracy: 0.7817
# Epoch 137/140
# 2971/2971 [==============================] - 81s 27ms/step - loss: 0.4283 - accuracy: 0.7806 - val_loss: 0.4293 - val_accuracy: 0.7830
# Epoch 138/140
# 2971/2971 [==============================] - 80s 27ms/step - loss: 0.4285 - accuracy: 0.7809 - val_loss: 0.4257 - val_accuracy: 0.7825
# Epoch 139/140
# 2971/2971 [==============================] - 79s 27ms/step - loss: 0.4279 - accuracy: 0.7808 - val_loss: 0.4267 - val_accuracy: 0.7820
# Epoch 140/140
# 2971/2971 [==============================] - 77s 26ms/step - loss: 0.4281 - accuracy: 0.7810 - val_loss: 0.4257 - val_accuracy: 0.7816

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 22s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 10905.522015810013

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00066275],
#        [0.00279264],
#        [0.00128255],
#        ...,
#        [0.07386243],
#        [0.07457624],
#        [0.07655073]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14268821305284168
# 0.23273263526482946
# 0.3777409337798085
# 0.28663711498479916

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 130s 9ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.59775058]
# [0.828874]
# total acc [0.78183482]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %% [markdown]
# ###
