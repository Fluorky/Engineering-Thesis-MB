# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=4

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475333, 4, 16)
# strides:  (512, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x228bbfcc040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475333,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x228ca7fb040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380266

# %%
training_sample
# Out:
# 380266

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380266, 4, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380266,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380266, 4, 15) (380266, 1) (95067, 4, 15) (95067, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

opt=keras.optimizers.SGD(learning_rate=0.9)
model_gru.compile(loss='MSE', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 4, 256)            209664
#
#  gru_1 (GRU)                 (None, 4, 128)            148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=4096)#, shuffle=False)
# Out:
# Epoch 1/140
# 93/93 [==============================] - 10s 34ms/step - loss: 0.1928 - accuracy: 0.7393 - val_loss: 0.1856 - val_accuracy: 0.7531
# Epoch 2/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1915 - accuracy: 0.7393 - val_loss: 0.1836 - val_accuracy: 0.7531
# Epoch 3/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1880 - accuracy: 0.7394 - val_loss: 0.1841 - val_accuracy: 0.7531
# Epoch 4/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1878 - accuracy: 0.7386 - val_loss: 0.1762 - val_accuracy: 0.7467
# Epoch 5/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1851 - accuracy: 0.7370 - val_loss: 0.1851 - val_accuracy: 0.7531
# Epoch 6/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1838 - accuracy: 0.7366 - val_loss: 0.1752 - val_accuracy: 0.7405
# Epoch 7/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1822 - accuracy: 0.7354 - val_loss: 0.1813 - val_accuracy: 0.7202
# Epoch 8/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1801 - accuracy: 0.7357 - val_loss: 0.1719 - val_accuracy: 0.7392
# Epoch 9/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1790 - accuracy: 0.7355 - val_loss: 0.1669 - val_accuracy: 0.7504
# Epoch 10/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1774 - accuracy: 0.7356 - val_loss: 0.1723 - val_accuracy: 0.7348
# Epoch 11/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1766 - accuracy: 0.7354 - val_loss: 0.1674 - val_accuracy: 0.7531
# Epoch 12/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1747 - accuracy: 0.7364 - val_loss: 0.1694 - val_accuracy: 0.7406
# Epoch 13/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1738 - accuracy: 0.7361 - val_loss: 0.1667 - val_accuracy: 0.7531
# Epoch 14/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1713 - accuracy: 0.7376 - val_loss: 0.1676 - val_accuracy: 0.7416
# Epoch 15/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1714 - accuracy: 0.7366 - val_loss: 0.1629 - val_accuracy: 0.7531
# Epoch 16/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1714 - accuracy: 0.7370 - val_loss: 0.1644 - val_accuracy: 0.7510
# Epoch 17/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1708 - accuracy: 0.7372 - val_loss: 0.1695 - val_accuracy: 0.7413
# Epoch 18/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1693 - accuracy: 0.7379 - val_loss: 0.1614 - val_accuracy: 0.7533
# Epoch 19/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1695 - accuracy: 0.7378 - val_loss: 0.1625 - val_accuracy: 0.7530
# Epoch 20/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1683 - accuracy: 0.7380 - val_loss: 0.1643 - val_accuracy: 0.7508
# Epoch 21/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1688 - accuracy: 0.7384 - val_loss: 0.1633 - val_accuracy: 0.7525
# Epoch 22/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1679 - accuracy: 0.7394 - val_loss: 0.1614 - val_accuracy: 0.7534
# Epoch 23/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1677 - accuracy: 0.7401 - val_loss: 0.1614 - val_accuracy: 0.7539
# Epoch 24/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1682 - accuracy: 0.7400 - val_loss: 0.1608 - val_accuracy: 0.7531
# Epoch 25/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1675 - accuracy: 0.7413 - val_loss: 0.1646 - val_accuracy: 0.7501
# Epoch 26/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1675 - accuracy: 0.7426 - val_loss: 0.1663 - val_accuracy: 0.7496
# Epoch 27/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1683 - accuracy: 0.7429 - val_loss: 0.1612 - val_accuracy: 0.7533
# Epoch 28/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1675 - accuracy: 0.7440 - val_loss: 0.1648 - val_accuracy: 0.7484
# Epoch 29/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1681 - accuracy: 0.7434 - val_loss: 0.1629 - val_accuracy: 0.7538
# Epoch 30/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1675 - accuracy: 0.7437 - val_loss: 0.1613 - val_accuracy: 0.7502
# Epoch 31/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1668 - accuracy: 0.7445 - val_loss: 0.1612 - val_accuracy: 0.7493
# Epoch 32/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1672 - accuracy: 0.7441 - val_loss: 0.1638 - val_accuracy: 0.7540
# Epoch 33/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1665 - accuracy: 0.7446 - val_loss: 0.1641 - val_accuracy: 0.7396
# Epoch 34/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1656 - accuracy: 0.7443 - val_loss: 0.1678 - val_accuracy: 0.7334
# Epoch 35/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1653 - accuracy: 0.7451 - val_loss: 0.1612 - val_accuracy: 0.7560
# Epoch 36/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1641 - accuracy: 0.7463 - val_loss: 0.1598 - val_accuracy: 0.7562
# Epoch 37/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1636 - accuracy: 0.7465 - val_loss: 0.1618 - val_accuracy: 0.7435
# Epoch 38/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1631 - accuracy: 0.7471 - val_loss: 0.1621 - val_accuracy: 0.7452
# Epoch 39/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1631 - accuracy: 0.7474 - val_loss: 0.1630 - val_accuracy: 0.7550
# Epoch 40/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1631 - accuracy: 0.7481 - val_loss: 0.1574 - val_accuracy: 0.7542
# Epoch 41/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1612 - accuracy: 0.7496 - val_loss: 0.1634 - val_accuracy: 0.7435
# Epoch 42/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1617 - accuracy: 0.7491 - val_loss: 0.1565 - val_accuracy: 0.7567
# Epoch 43/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1610 - accuracy: 0.7499 - val_loss: 0.1574 - val_accuracy: 0.7529
# Epoch 44/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1602 - accuracy: 0.7505 - val_loss: 0.1594 - val_accuracy: 0.7485
# Epoch 45/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1610 - accuracy: 0.7498 - val_loss: 0.1581 - val_accuracy: 0.7579
# Epoch 46/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1602 - accuracy: 0.7507 - val_loss: 0.1561 - val_accuracy: 0.7551
# Epoch 47/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1598 - accuracy: 0.7509 - val_loss: 0.1554 - val_accuracy: 0.7581
# Epoch 48/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1595 - accuracy: 0.7511 - val_loss: 0.1579 - val_accuracy: 0.7544
# Epoch 49/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1593 - accuracy: 0.7512 - val_loss: 0.1565 - val_accuracy: 0.7534
# Epoch 50/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1596 - accuracy: 0.7513 - val_loss: 0.1598 - val_accuracy: 0.7493
# Epoch 51/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1585 - accuracy: 0.7526 - val_loss: 0.1554 - val_accuracy: 0.7547
# Epoch 52/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1586 - accuracy: 0.7524 - val_loss: 0.1565 - val_accuracy: 0.7539
# Epoch 53/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1578 - accuracy: 0.7533 - val_loss: 0.1583 - val_accuracy: 0.7517
# Epoch 54/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1592 - accuracy: 0.7525 - val_loss: 0.1569 - val_accuracy: 0.7551
# Epoch 55/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1581 - accuracy: 0.7533 - val_loss: 0.1570 - val_accuracy: 0.7594
# Epoch 56/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1578 - accuracy: 0.7529 - val_loss: 0.1536 - val_accuracy: 0.7569
# Epoch 57/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1583 - accuracy: 0.7537 - val_loss: 0.1560 - val_accuracy: 0.7532
# Epoch 58/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1575 - accuracy: 0.7537 - val_loss: 0.1544 - val_accuracy: 0.7573
# Epoch 59/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1580 - accuracy: 0.7534 - val_loss: 0.1541 - val_accuracy: 0.7582
# Epoch 60/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1575 - accuracy: 0.7548 - val_loss: 0.1532 - val_accuracy: 0.7588
# Epoch 61/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1574 - accuracy: 0.7542 - val_loss: 0.1581 - val_accuracy: 0.7516
# Epoch 62/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1572 - accuracy: 0.7547 - val_loss: 0.1543 - val_accuracy: 0.7585
# Epoch 63/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1569 - accuracy: 0.7549 - val_loss: 0.1523 - val_accuracy: 0.7596
# Epoch 64/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1574 - accuracy: 0.7546 - val_loss: 0.1542 - val_accuracy: 0.7606
# Epoch 65/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1570 - accuracy: 0.7550 - val_loss: 0.1544 - val_accuracy: 0.7564
# Epoch 66/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1570 - accuracy: 0.7548 - val_loss: 0.1539 - val_accuracy: 0.7579
# Epoch 67/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1570 - accuracy: 0.7552 - val_loss: 0.1521 - val_accuracy: 0.7601
# Epoch 68/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1571 - accuracy: 0.7548 - val_loss: 0.1536 - val_accuracy: 0.7599
# Epoch 69/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1560 - accuracy: 0.7560 - val_loss: 0.1535 - val_accuracy: 0.7580
# Epoch 70/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1565 - accuracy: 0.7557 - val_loss: 0.1549 - val_accuracy: 0.7605
# Epoch 71/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1566 - accuracy: 0.7550 - val_loss: 0.1518 - val_accuracy: 0.7609
# Epoch 72/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1568 - accuracy: 0.7553 - val_loss: 0.1560 - val_accuracy: 0.7611
# Epoch 73/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1561 - accuracy: 0.7559 - val_loss: 0.1526 - val_accuracy: 0.7602
# Epoch 74/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1569 - accuracy: 0.7552 - val_loss: 0.1538 - val_accuracy: 0.7608
# Epoch 75/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1561 - accuracy: 0.7558 - val_loss: 0.1527 - val_accuracy: 0.7617
# Epoch 76/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1562 - accuracy: 0.7560 - val_loss: 0.1544 - val_accuracy: 0.7620
# Epoch 77/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1562 - accuracy: 0.7560 - val_loss: 0.1530 - val_accuracy: 0.7599
# Epoch 78/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1558 - accuracy: 0.7560 - val_loss: 0.1536 - val_accuracy: 0.7625
# Epoch 79/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1557 - accuracy: 0.7563 - val_loss: 0.1510 - val_accuracy: 0.7618
# Epoch 80/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1555 - accuracy: 0.7561 - val_loss: 0.1532 - val_accuracy: 0.7621
# Epoch 81/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1561 - accuracy: 0.7559 - val_loss: 0.1514 - val_accuracy: 0.7623
# Epoch 82/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1553 - accuracy: 0.7564 - val_loss: 0.1544 - val_accuracy: 0.7576
# Epoch 83/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1557 - accuracy: 0.7562 - val_loss: 0.1535 - val_accuracy: 0.7574
# Epoch 84/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1552 - accuracy: 0.7567 - val_loss: 0.1530 - val_accuracy: 0.7602
# Epoch 85/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1558 - accuracy: 0.7562 - val_loss: 0.1577 - val_accuracy: 0.7516
# Epoch 86/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1553 - accuracy: 0.7565 - val_loss: 0.1564 - val_accuracy: 0.7545
# Epoch 87/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1552 - accuracy: 0.7570 - val_loss: 0.1540 - val_accuracy: 0.7583
# Epoch 88/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1553 - accuracy: 0.7573 - val_loss: 0.1540 - val_accuracy: 0.7595
# Epoch 89/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1552 - accuracy: 0.7571 - val_loss: 0.1534 - val_accuracy: 0.7573
# Epoch 90/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1550 - accuracy: 0.7576 - val_loss: 0.1513 - val_accuracy: 0.7633
# Epoch 91/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1549 - accuracy: 0.7577 - val_loss: 0.1509 - val_accuracy: 0.7628
# Epoch 92/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1552 - accuracy: 0.7574 - val_loss: 0.1511 - val_accuracy: 0.7623
# Epoch 93/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1548 - accuracy: 0.7579 - val_loss: 0.1527 - val_accuracy: 0.7639
# Epoch 94/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1557 - accuracy: 0.7576 - val_loss: 0.1501 - val_accuracy: 0.7631
# Epoch 95/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1545 - accuracy: 0.7575 - val_loss: 0.1523 - val_accuracy: 0.7587
# Epoch 96/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1551 - accuracy: 0.7576 - val_loss: 0.1519 - val_accuracy: 0.7630
# Epoch 97/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1541 - accuracy: 0.7581 - val_loss: 0.1506 - val_accuracy: 0.7627
# Epoch 98/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1547 - accuracy: 0.7579 - val_loss: 0.1497 - val_accuracy: 0.7640
# Epoch 99/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1549 - accuracy: 0.7584 - val_loss: 0.1505 - val_accuracy: 0.7647
# Epoch 100/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1540 - accuracy: 0.7590 - val_loss: 0.1502 - val_accuracy: 0.7654
# Epoch 101/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1542 - accuracy: 0.7589 - val_loss: 0.1498 - val_accuracy: 0.7646
# Epoch 102/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1544 - accuracy: 0.7587 - val_loss: 0.1550 - val_accuracy: 0.7654
# Epoch 103/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1547 - accuracy: 0.7589 - val_loss: 0.1533 - val_accuracy: 0.7602
# Epoch 104/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1539 - accuracy: 0.7594 - val_loss: 0.1520 - val_accuracy: 0.7606
# Epoch 105/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1534 - accuracy: 0.7607 - val_loss: 0.1519 - val_accuracy: 0.7640
# Epoch 106/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1539 - accuracy: 0.7606 - val_loss: 0.1490 - val_accuracy: 0.7688
# Epoch 107/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1543 - accuracy: 0.7606 - val_loss: 0.1504 - val_accuracy: 0.7667
# Epoch 108/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1532 - accuracy: 0.7616 - val_loss: 0.1522 - val_accuracy: 0.7602
# Epoch 109/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1532 - accuracy: 0.7625 - val_loss: 0.1504 - val_accuracy: 0.7655
# Epoch 110/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1541 - accuracy: 0.7619 - val_loss: 0.1485 - val_accuracy: 0.7705
# Epoch 111/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1530 - accuracy: 0.7634 - val_loss: 0.1512 - val_accuracy: 0.7667
# Epoch 112/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1529 - accuracy: 0.7635 - val_loss: 0.1487 - val_accuracy: 0.7716
# Epoch 113/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1532 - accuracy: 0.7631 - val_loss: 0.1494 - val_accuracy: 0.7674
# Epoch 114/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1528 - accuracy: 0.7640 - val_loss: 0.1500 - val_accuracy: 0.7718
# Epoch 115/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1526 - accuracy: 0.7651 - val_loss: 0.1473 - val_accuracy: 0.7727
# Epoch 116/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1528 - accuracy: 0.7653 - val_loss: 0.1485 - val_accuracy: 0.7735
# Epoch 117/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1521 - accuracy: 0.7667 - val_loss: 0.1471 - val_accuracy: 0.7736
# Epoch 118/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1523 - accuracy: 0.7667 - val_loss: 0.1486 - val_accuracy: 0.7734
# Epoch 119/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1521 - accuracy: 0.7671 - val_loss: 0.1491 - val_accuracy: 0.7717
# Epoch 120/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1515 - accuracy: 0.7680 - val_loss: 0.1554 - val_accuracy: 0.7691
# Epoch 121/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1518 - accuracy: 0.7680 - val_loss: 0.1508 - val_accuracy: 0.7688
# Epoch 122/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1516 - accuracy: 0.7684 - val_loss: 0.1556 - val_accuracy: 0.7696
# Epoch 123/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1516 - accuracy: 0.7686 - val_loss: 0.1488 - val_accuracy: 0.7748
# Epoch 124/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1513 - accuracy: 0.7694 - val_loss: 0.1463 - val_accuracy: 0.7762
# Epoch 125/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1512 - accuracy: 0.7698 - val_loss: 0.1474 - val_accuracy: 0.7749
# Epoch 126/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1513 - accuracy: 0.7691 - val_loss: 0.1471 - val_accuracy: 0.7750
# Epoch 127/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1506 - accuracy: 0.7708 - val_loss: 0.1470 - val_accuracy: 0.7767
# Epoch 128/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1512 - accuracy: 0.7697 - val_loss: 0.1463 - val_accuracy: 0.7763
# Epoch 129/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1511 - accuracy: 0.7699 - val_loss: 0.1479 - val_accuracy: 0.7746
# Epoch 130/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1508 - accuracy: 0.7701 - val_loss: 0.1483 - val_accuracy: 0.7745
# Epoch 131/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1505 - accuracy: 0.7706 - val_loss: 0.1462 - val_accuracy: 0.7778
# Epoch 132/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1507 - accuracy: 0.7701 - val_loss: 0.1524 - val_accuracy: 0.7660
# Epoch 133/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1507 - accuracy: 0.7706 - val_loss: 0.1463 - val_accuracy: 0.7761
# Epoch 134/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1505 - accuracy: 0.7706 - val_loss: 0.1502 - val_accuracy: 0.7701
# Epoch 135/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.1501 - accuracy: 0.7712 - val_loss: 0.1500 - val_accuracy: 0.7737
# Epoch 136/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1503 - accuracy: 0.7706 - val_loss: 0.1487 - val_accuracy: 0.7749
# Epoch 137/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1498 - accuracy: 0.7714 - val_loss: 0.1476 - val_accuracy: 0.7749
# Epoch 138/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1502 - accuracy: 0.7711 - val_loss: 0.1475 - val_accuracy: 0.7749
# Epoch 139/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1502 - accuracy: 0.7711 - val_loss: 0.1496 - val_accuracy: 0.7719
# Epoch 140/140
# 93/93 [==============================] - 2s 19ms/step - loss: 0.1496 - accuracy: 0.7717 - val_loss: 0.1491 - val_accuracy: 0.7720

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 14s 4ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 279.3191592693329

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95067, 1)

# %%
pred_y
# Out:
# array([[0.00743829],
#        [0.00885363],
#        [0.01281302],
#        ...,
#        [0.2034588 ],
#        [0.20251828],
#        [0.20303333]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95067)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14911954306638903
# 0.19811588000045055
# 0.3861599967194803
# 0.3122059092862454

# %%
np.shape(train_X)
# Out:
# (380266, 4, 15)

# %%
np.shape(train_y)
# Out:
# (380266, 1)

# %%
np.shape(test_X)
# Out:
# (95067, 4, 15)

# %%
np.shape(test_y)
# Out:
# (95067, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14855/14855 [==============================] - 66s 4ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25793917]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.562539]
# [0.83093639]
# total acc [0.7703126]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 140273408, 'peak': 429167616}
