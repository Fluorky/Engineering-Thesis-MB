# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2d2439a4040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2d27da1e040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=204)#, shuffle=False)
# Out:
# Epoch 1/140
# 1864/1864 [==============================] - 47s 17ms/step - loss: 0.5733 - accuracy: 0.7393 - val_loss: 0.5566 - val_accuracy: 0.7531
# Epoch 2/140
# 1864/1864 [==============================] - 28s 15ms/step - loss: 0.5672 - accuracy: 0.7393 - val_loss: 0.5484 - val_accuracy: 0.7531
# Epoch 3/140
# 1864/1864 [==============================] - 28s 15ms/step - loss: 0.5493 - accuracy: 0.7394 - val_loss: 0.5234 - val_accuracy: 0.7532
# Epoch 4/140
# 1864/1864 [==============================] - 28s 15ms/step - loss: 0.5242 - accuracy: 0.7414 - val_loss: 0.5007 - val_accuracy: 0.7535
# Epoch 5/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0
140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4355 - accuracy: 0.7767 - val_loss: 0.4310 - val_accuracy: 0.7784
# Epoch 111/140
# 1864/1864 [==============================] - 28s 15ms/step - loss: 0.4355 - accuracy: 0.7763 - val_loss: 0.4332 - val_accuracy: 0.7775
# Epoch 112/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4352 - accuracy: 0.7766 - val_loss: 0.4319 - val_accuracy: 0.7780
# Epoch 113/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4350 - accuracy: 0.7770 - val_loss: 0.4339 - val_accuracy: 0.7779
# Epoch 114/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4348 - accuracy: 0.7768 - val_loss: 0.4300 - val_accuracy: 0.7794
# Epoch 115/140
# 1864/1864 [==============================] - 28s 15ms/step - loss: 0.4347 - accuracy: 0.7764 - val_loss: 0.4296 - val_accuracy: 0.7797
# Epoch 116/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4345 - accuracy: 0.7771 - val_loss: 0.4319 - val_accuracy: 0.7787
# Epoch 117/140
# 1864/1864 [==============================] - 28s 15ms/step - loss: 0.4343 - accuracy: 0.7768 - val_loss: 0.4321 - val_accuracy: 0.7794
# Epoch 118/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4343 - accuracy: 0.7768 - val_loss: 0.4302 - val_accuracy: 0.7795
# Epoch 119/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4342 - accuracy: 0.7771 - val_loss: 0.4303 - val_accuracy: 0.7785
# Epoch 120/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4339 - accuracy: 0.7776 - val_loss: 0.4329 - val_accuracy: 0.7775
# Epoch 121/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4339 - accuracy: 0.7771 - val_loss: 0.4304 - val_accuracy: 0.7795
# Epoch 122/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4337 - accuracy: 0.7775 - val_loss: 0.4296 - val_accuracy: 0.7785
# Epoch 123/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4335 - accuracy: 0.7776 - val_loss: 0.4309 - val_accuracy: 0.7792
# Epoch 124/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4334 - accuracy: 0.7774 - val_loss: 0.4318 - val_accuracy: 0.7782
# Epoch 125/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4332 - accuracy: 0.7776 - val_loss: 0.4303 - val_accuracy: 0.7789
# Epoch 126/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4331 - accuracy: 0.7775 - val_loss: 0.4292 - val_accuracy: 0.7793
# Epoch 127/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4329 - accuracy: 0.7776 - val_loss: 0.4298 - val_accuracy: 0.7794
# Epoch 128/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4330 - accuracy: 0.7776 - val_loss: 0.4282 - val_accuracy: 0.7795
# Epoch 129/140
# 1864/1864 [==============================] - 28s 15ms/step - loss: 0.4327 - accuracy: 0.7778 - val_loss: 0.4316 - val_accuracy: 0.7799
# Epoch 130/140
# 1864/1864 [==============================] - 28s 15ms/step - loss: 0.4326 - accuracy: 0.7780 - val_loss: 0.4315 - val_accuracy: 0.7798
# Epoch 131/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4325 - accuracy: 0.7777 - val_loss: 0.4282 - val_accuracy: 0.7802
# Epoch 132/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4323 - accuracy: 0.7777 - val_loss: 0.4284 - val_accuracy: 0.7796
# Epoch 133/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4321 - accuracy: 0.7781 - val_loss: 0.4326 - val_accuracy: 0.7793
# Epoch 134/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4322 - accuracy: 0.7779 - val_loss: 0.4283 - val_accuracy: 0.7795
# Epoch 135/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4320 - accuracy: 0.7779 - val_loss: 0.4304 - val_accuracy: 0.7800
# Epoch 136/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4320 - accuracy: 0.7779 - val_loss: 0.4314 - val_accuracy: 0.7805
# Epoch 137/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4318 - accuracy: 0.7782 - val_loss: 0.4346 - val_accuracy: 0.7790
# Epoch 138/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4316 - accuracy: 0.7781 - val_loss: 0.4294 - val_accuracy: 0.7805
# Epoch 139/140
# 1864/1864 [==============================] - 28s 15ms/step - loss: 0.4315 - accuracy: 0.7781 - val_loss: 0.4291 - val_accuracy: 0.7805
# Epoch 140/140
# 1864/1864 [==============================] - 27s 15ms/step - loss: 0.4315 - accuracy: 0.7785 - val_loss: 0.4298 - val_accuracy: 0.7800

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 16s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 3899.8889195919037

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00158857],
#        [0.0019215 ],
#        [0.00087732],
#        ...,
#        [0.06227688],
#        [0.06106163],
#        [0.06191434]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14387723824108972
# 0.22631709474470707
# 0.3793115319115538
# 0.29194571582695716

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 73s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60044387]
# [0.81923338]
# total acc [0.77899777]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
print("204 to podzielnik 380256")
