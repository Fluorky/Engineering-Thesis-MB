# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x17ed193d040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x17f459f8040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

opt=keras.optimizers.SGD(learning_rate=0.9)
model_gru.compile(loss='MSE', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=2048)#, shuffle=False)
# Out:
# Epoch 1/140
# 186/186 [==============================] - 16s 38ms/step - loss: 0.1891 - accuracy: 0.7393 - val_loss: 0.1954 - val_accuracy: 0.7530
# Epoch 2/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1809 - accuracy: 0.7392 - val_loss: 0.1768 - val_accuracy: 0.7530
# Epoch 3/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1766 - accuracy: 0.7393 - val_loss: 0.1677 - val_accuracy: 0.7540
# Epoch 4/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1736 - accuracy: 0.7390 - val_loss: 0.1734 - val_accuracy: 0.7432
# Epoch 5/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1716 - accuracy: 0.7385 - val_loss: 0.1648 - val_accuracy: 0.7530
# Epoch 6/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1712 - accuracy: 0.7394 - val_loss: 0.1639 - val_accuracy: 0.7530
# Epoch 7/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1700 - accuracy: 0.7392 - val_loss: 0.1626 - val_accuracy: 0.7530
# Epoch 8/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1695 - accuracy: 0.7408 - val_loss: 0.1637 - val_accuracy: 0.7531
# Epoch 9/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1684 - accuracy: 0.7436 - val_loss: 0.1608 - val_accuracy: 0.7549
# Epoch 10/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1681 - accuracy: 0.7447 - val_loss: 0.1605 - val_accuracy: 0.7513
# Epoch 11/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1662 - accuracy: 0.7464 - val_loss: 0.1592 - val_accuracy: 0.7546
# Epoch 12/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1649 - accuracy: 0.7469 - val_loss: 0.1621 - val_accuracy: 0.7555
# Epoch 13/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1635 - accuracy: 0.7478 - val_loss: 0.1720 - val_accuracy: 0.7342
# Epoch 14/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1631 - accuracy: 0.7483 - val_loss: 0.1614 - val_accuracy: 0.7513
# Epoch 15/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1616 - accuracy: 0.7499 - val_loss: 0.1560 - val_accuracy: 0.7572
# Epoch 16/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1612 - accuracy: 0.7507 - val_loss: 0.1614 - val_accuracy: 0.7477
# Epoch 17/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1607 - accuracy: 0.7514 - val_loss: 0.1574 - val_accuracy: 0.7542
# Epoch 18/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1603 - accuracy: 0.7515 - val_loss: 0.1553 - val_accuracy: 0.7559
# Epoch 19/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1592 - accuracy: 0.7536 - val_loss: 0.1549 - val_accuracy: 0.7604
# Epoch 20/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1587 - accuracy: 0.7533 - val_loss: 0.1565 - val_accuracy: 0.7557
# Epoch 21/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1597 - accuracy: 0.7532 - val_loss: 0.1536 - val_accuracy: 0.7597
# Epoch 22/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1584 - accuracy: 0.7538 - val_loss: 0.1615 - val_accuracy: 0.7594
# Epoch 23/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1582 - accuracy: 0.7546 - val_loss: 0.1557 - val_accuracy: 0.7564
# Epoch 24/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1580 - accuracy: 0.7555 - val_loss: 0.1540 - val_accuracy: 0.7592
# Epoch 25/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1573 - accuracy: 0.7560 - val_loss: 0.1555 - val_accuracy: 0.7556
# Epoch 26/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1569 - accuracy: 0.7565 - val_loss: 0.1577 - val_accuracy: 0.7514
# Epoch 27/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1570 - accuracy: 0.7569 - val_loss: 0.1528 - val_accuracy: 0.7603
# Epoch 28/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1565 - accuracy: 0.7575 - val_loss: 0.1655 - val_accuracy: 0.7403
# Epoch 29/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1564 - accuracy: 0.7574 - val_loss: 0.1530 - val_accuracy: 0.7651
# Epoch 30/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1559 - accuracy: 0.7587 - val_loss: 0.1503 - val_accuracy: 0.7671
# Epoch 31/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1554 - accuracy: 0.7599 - val_loss: 0.1525 - val_accuracy: 0.7680
# Epoch 32/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1552 - accuracy: 0.7611 - val_loss: 0.1520 - val_accuracy: 0.7700
# Epoch 33/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1546 - accuracy: 0.7625 - val_loss: 0.1496 - val_accuracy: 0.7713
# Epoch 34/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1545 - accuracy: 0.7624 - val_loss: 0.1498 - val_accuracy: 0.7697
# Epoch 35/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1536 - accuracy: 0.7645 - val_loss: 0.1568 - val_accuracy: 0.7573
# Epoch 36/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1531 - accuracy: 0.7660 - val_loss: 0.1521 - val_accuracy: 0.7699
# Epoch 37/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1533 - accuracy: 0.7665 - val_loss: 0.1502 - val_accuracy: 0.7717
# Epoch 38/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1529 - accuracy: 0.7664 - val_loss: 0.1536 - val_accuracy: 0.7693
# Epoch 39/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1526 - accuracy: 0.7678 - val_loss: 0.1511 - val_accuracy: 0.7675
# Epoch 40/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1521 - accuracy: 0.7681 - val_loss: 0.1485 - val_accuracy: 0.7732
# Epoch 41/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1519 - accuracy: 0.7690 - val_loss: 0.1479 - val_accuracy: 0.7734
# Epoch 42/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1514 - accuracy: 0.7693 - val_loss: 0.1483 - val_accuracy: 0.7720
# Epoch 43/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1512 - accuracy: 0.7698 - val_loss: 0.1524 - val_accuracy: 0.7707
# Epoch 44/140
# 186/186 [==============================] - 5s 29ms/step - loss: 0.1511 - accuracy: 0.7702 - val_loss: 0.1543 - val_accuracy: 0.7696
# Epoch 45/140
# 186/186 [==============================] - 5s 29ms/step - loss: 0.1505 - accuracy: 0.7715 - val_loss: 0.1537 - val_accuracy: 0.7677
# Epoch 46/140
# 186/186 [==============================] - 5s 29ms/step - loss: 0.1506 - accuracy: 0.7710 - val_loss: 0.1511 - val_accuracy: 0.7726
# Epoch 47/140
# 186/186 [==============================] - 5s 29ms/step - loss: 0.1506 - accuracy: 0.7714 - val_loss: 0.1515 - val_accuracy: 0.7731
# Epoch 48/140
# 186/186 [==============================] - 5s 29ms/step - loss: 0.1499 - accuracy: 0.7726 - val_loss: 0.1485 - val_accuracy: 0.7737
# Epoch 49/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1499 - accuracy: 0.7730 - val_loss: 0.1494 - val_accuracy: 0.7729
# Epoch 50/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1498 - accuracy: 0.7729 - val_loss: 0.1464 - val_accuracy: 0.7768
# Epoch 51/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1494 - accuracy: 0.7738 - val_loss: 0.1477 - val_accuracy: 0.7755
# Epoch 52/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1493 - accuracy: 0.7737 - val_loss: 0.1505 - val_accuracy: 0.7764
# Epoch 53/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1492 - accuracy: 0.7735 - val_loss: 0.1451 - val_accuracy: 0.7791
# Epoch 54/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1486 - accuracy: 0.7743 - val_loss: 0.1459 - val_accuracy: 0.7767
# Epoch 55/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1490 - accuracy: 0.7742 - val_loss: 0.1509 - val_accuracy: 0.7720
# Epoch 56/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1483 - accuracy: 0.7751 - val_loss: 0.1491 - val_accuracy: 0.7763
# Epoch 57/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1485 - accuracy: 0.7752 - val_loss: 0.1461 - val_accuracy: 0.7770
# Epoch 58/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1482 - accuracy: 0.7754 - val_loss: 0.1539 - val_accuracy: 0.7687
# Epoch 59/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1481 - accuracy: 0.7757 - val_loss: 0.1470 - val_accuracy: 0.7779
# Epoch 60/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1481 - accuracy: 0.7759 - val_loss: 0.1515 - val_accuracy: 0.7775
# Epoch 61/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1475 - accuracy: 0.7763 - val_loss: 0.1443 - val_accuracy: 0.7794
# Epoch 62/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1474 - accuracy: 0.7767 - val_loss: 0.1448 - val_accuracy: 0.7791
# Epoch 63/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1473 - accuracy: 0.7766 - val_loss: 0.1442 - val_accuracy: 0.7805
# Epoch 64/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1476 - accuracy: 0.7758 - val_loss: 0.1460 - val_accuracy: 0.7791
# Epoch 65/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1470 - accuracy: 0.7774 - val_loss: 0.1452 - val_accuracy: 0.7797
# Epoch 66/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1469 - accuracy: 0.7773 - val_loss: 0.1534 - val_accuracy: 0.7739
# Epoch 67/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1471 - accuracy: 0.7769 - val_loss: 0.1465 - val_accuracy: 0.7776
# Epoch 68/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1471 - accuracy: 0.7768 - val_loss: 0.1454 - val_accuracy: 0.7796
# Epoch 69/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1471 - accuracy: 0.7771 - val_loss: 0.1437 - val_accuracy: 0.7814
# Epoch 70/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1464 - accuracy: 0.7776 - val_loss: 0.1459 - val_accuracy: 0.7790
# Epoch 71/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1462 - accuracy: 0.7783 - val_loss: 0.1459 - val_accuracy: 0.7788
# Epoch 72/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1463 - accuracy: 0.7785 - val_loss: 0.1460 - val_accuracy: 0.7786
# Epoch 73/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1463 - accuracy: 0.7783 - val_loss: 0.1437 - val_accuracy: 0.7816
# Epoch 74/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1463 - accuracy: 0.7779 - val_loss: 0.1480 - val_accuracy: 0.7785
# Epoch 75/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1461 - accuracy: 0.7789 - val_loss: 0.1448 - val_accuracy: 0.7807
# Epoch 76/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1460 - accuracy: 0.7784 - val_loss: 0.1475 - val_accuracy: 0.7781
# Epoch 77/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1456 - accuracy: 0.7791 - val_loss: 0.1486 - val_accuracy: 0.7791
# Epoch 78/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1457 - accuracy: 0.7789 - val_loss: 0.1466 - val_accuracy: 0.7761
# Epoch 79/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1459 - accuracy: 0.7788 - val_loss: 0.1437 - val_accuracy: 0.7797
# Epoch 80/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1456 - accuracy: 0.7792 - val_loss: 0.1444 - val_accuracy: 0.7801
# Epoch 81/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1455 - accuracy: 0.7800 - val_loss: 0.1446 - val_accuracy: 0.7803
# Epoch 82/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1451 - accuracy: 0.7804 - val_loss: 0.1436 - val_accuracy: 0.7826
# Epoch 83/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1454 - accuracy: 0.7799 - val_loss: 0.1443 - val_accuracy: 0.7790
# Epoch 84/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1451 - accuracy: 0.7800 - val_loss: 0.1434 - val_accuracy: 0.7808
# Epoch 85/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1454 - accuracy: 0.7799 - val_loss: 0.1471 - val_accuracy: 0.7792
# Epoch 86/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1453 - accuracy: 0.7798 - val_loss: 0.1472 - val_accuracy: 0.7715
# Epoch 87/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1450 - accuracy: 0.7803 - val_loss: 0.1445 - val_accuracy: 0.7780
# Epoch 88/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1447 - accuracy: 0.7808 - val_loss: 0.1468 - val_accuracy: 0.7809
# Epoch 89/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1451 - accuracy: 0.7802 - val_loss: 0.1435 - val_accuracy: 0.7812
# Epoch 90/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1447 - accuracy: 0.7805 - val_loss: 0.1443 - val_accuracy: 0.7796
# Epoch 91/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1446 - accuracy: 0.7805 - val_loss: 0.1470 - val_accuracy: 0.7782
# Epoch 92/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1447 - accuracy: 0.7812 - val_loss: 0.1449 - val_accuracy: 0.7782
# Epoch 93/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1446 - accuracy: 0.7809 - val_loss: 0.1430 - val_accuracy: 0.7811
# Epoch 94/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1447 - accuracy: 0.7809 - val_loss: 0.1435 - val_accuracy: 0.7832
# Epoch 95/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1442 - accuracy: 0.7816 - val_loss: 0.1432 - val_accuracy: 0.7827
# Epoch 96/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1440 - accuracy: 0.7814 - val_loss: 0.1458 - val_accuracy: 0.7737
# Epoch 97/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1439 - accuracy: 0.7818 - val_loss: 0.1448 - val_accuracy: 0.7822
# Epoch 98/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1442 - accuracy: 0.7816 - val_loss: 0.1445 - val_accuracy: 0.7820
# Epoch 99/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1440 - accuracy: 0.7816 - val_loss: 0.1429 - val_accuracy: 0.7832
# Epoch 100/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1439 - accuracy: 0.7825 - val_loss: 0.1446 - val_accuracy: 0.7803
# Epoch 101/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1436 - accuracy: 0.7823 - val_loss: 0.1422 - val_accuracy: 0.7842
# Epoch 102/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1437 - accuracy: 0.7824 - val_loss: 0.1435 - val_accuracy: 0.7804
# Epoch 103/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1434 - accuracy: 0.7824 - val_loss: 0.1448 - val_accuracy: 0.7817
# Epoch 104/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1437 - accuracy: 0.7821 - val_loss: 0.1437 - val_accuracy: 0.7839
# Epoch 105/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1436 - accuracy: 0.7827 - val_loss: 0.1429 - val_accuracy: 0.7835
# Epoch 106/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1434 - accuracy: 0.7826 - val_loss: 0.1429 - val_accuracy: 0.7830
# Epoch 107/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1431 - accuracy: 0.7828 - val_loss: 0.1464 - val_accuracy: 0.7736
# Epoch 108/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1433 - accuracy: 0.7829 - val_loss: 0.1446 - val_accuracy: 0.7826
# Epoch 109/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1433 - accuracy: 0.7828 - val_loss: 0.1441 - val_accuracy: 0.7800
# Epoch 110/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1430 - accuracy: 0.7832 - val_loss: 0.1453 - val_accuracy: 0.7769
# Epoch 111/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1431 - accuracy: 0.7831 - val_loss: 0.1474 - val_accuracy: 0.7817
# Epoch 112/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1429 - accuracy: 0.7831 - val_loss: 0.1505 - val_accuracy: 0.7654
# Epoch 113/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1429 - accuracy: 0.7831 - val_loss: 0.1432 - val_accuracy: 0.7831
# Epoch 114/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1427 - accuracy: 0.7836 - val_loss: 0.1456 - val_accuracy: 0.7784
# Epoch 115/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1427 - accuracy: 0.7836 - val_loss: 0.1469 - val_accuracy: 0.7715
# Epoch 116/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1422 - accuracy: 0.7840 - val_loss: 0.1438 - val_accuracy: 0.7816
# Epoch 117/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1425 - accuracy: 0.7837 - val_loss: 0.1482 - val_accuracy: 0.7683
# Epoch 118/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1423 - accuracy: 0.7843 - val_loss: 0.1458 - val_accuracy: 0.7745
# Epoch 119/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1421 - accuracy: 0.7842 - val_loss: 0.1425 - val_accuracy: 0.7827
# Epoch 120/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1423 - accuracy: 0.7842 - val_loss: 0.1433 - val_accuracy: 0.7848
# Epoch 121/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1421 - accuracy: 0.7843 - val_loss: 0.1423 - val_accuracy: 0.7835
# Epoch 122/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1420 - accuracy: 0.7842 - val_loss: 0.1435 - val_accuracy: 0.7844
# Epoch 123/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1420 - accuracy: 0.7847 - val_loss: 0.1445 - val_accuracy: 0.7784
# Epoch 124/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1419 - accuracy: 0.7846 - val_loss: 0.1472 - val_accuracy: 0.7759
# Epoch 125/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1418 - accuracy: 0.7852 - val_loss: 0.1434 - val_accuracy: 0.7813
# Epoch 126/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1417 - accuracy: 0.7850 - val_loss: 0.1435 - val_accuracy: 0.7836
# Epoch 127/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1415 - accuracy: 0.7851 - val_loss: 0.1464 - val_accuracy: 0.7750
# Epoch 128/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1413 - accuracy: 0.7854 - val_loss: 0.1427 - val_accuracy: 0.7859
# Epoch 129/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1417 - accuracy: 0.7848 - val_loss: 0.1426 - val_accuracy: 0.7826
# Epoch 130/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1417 - accuracy: 0.7848 - val_loss: 0.1442 - val_accuracy: 0.7803
# Epoch 131/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1415 - accuracy: 0.7856 - val_loss: 0.1452 - val_accuracy: 0.7758
# Epoch 132/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1412 - accuracy: 0.7861 - val_loss: 0.1444 - val_accuracy: 0.7788
# Epoch 133/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1412 - accuracy: 0.7857 - val_loss: 0.1449 - val_accuracy: 0.7838
# Epoch 134/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1412 - accuracy: 0.7862 - val_loss: 0.1432 - val_accuracy: 0.7814
# Epoch 135/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1410 - accuracy: 0.7863 - val_loss: 0.1464 - val_accuracy: 0.7827
# Epoch 136/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1414 - accuracy: 0.7856 - val_loss: 0.1463 - val_accuracy: 0.7818
# Epoch 137/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1409 - accuracy: 0.7857 - val_loss: 0.1434 - val_accuracy: 0.7812
# Epoch 138/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1412 - accuracy: 0.7860 - val_loss: 0.1429 - val_accuracy: 0.7860
# Epoch 139/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1409 - accuracy: 0.7864 - val_loss: 0.1435 - val_accuracy: 0.7836
# Epoch 140/140
# 186/186 [==============================] - 6s 30ms/step - loss: 0.1408 - accuracy: 0.7867 - val_loss: 0.1428 - val_accuracy: 0.7856

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 21s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 818.2740032672882

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.000332  ],
#        [0.00098695],
#        [0.00042631],
#        ...,
#        [0.06904726],
#        [0.07639466],
#        [0.08173739]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14283825894749674
# 0.23192580395257034
# 0.3779394911192753
# 0.27242537010992196

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 97s 7ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.63425272]
# [0.81743132]
# total acc [0.78685896]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1097435136, 'peak': 1484154880}
