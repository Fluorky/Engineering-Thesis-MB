# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x25000000040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x250738f6040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

opt=keras.optimizers.SGD(learning_rate=0.01)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=2048)#, shuffle=False)
# Out:
# Epoch 1/140
# 186/186 [==============================] - 12s 30ms/step - loss: 0.5756 - accuracy: 0.7393 - val_loss: 0.5598 - val_accuracy: 0.7531
# Epoch 2/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5741 - accuracy: 0.7393 - val_loss: 0.5597 - val_accuracy: 0.7531
# Epoch 3/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5739 - accuracy: 0.7393 - val_loss: 0.5596 - val_accuracy: 0.7531
# Epoch 4/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5738 - accuracy: 0.7393 - val_loss: 0.5596 - val_accuracy: 0.7531
# Epoch 5/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5593 - val_accuracy: 0.7531
# Epoch 6/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5735 - accuracy: 0.7393 - val_loss: 0.5594 - val_accuracy: 0.7531
# Epoch 7/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5734 - accuracy: 0.7393 - val_loss: 0.5591 - val_accuracy: 0.7531
# Epoch 8/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5733 - accuracy: 0.7393 - val_loss: 0.5590 - val_accuracy: 0.7531
# Epoch 9/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5732 - accuracy: 0.7393 - val_loss: 0.5590 - val_accuracy: 0.7531
# Epoch 10/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5730 - accuracy: 0.7393 - val_loss: 0.5589 - val_accuracy: 0.7531
# Epoch 11/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5729 - accuracy: 0.7393 - val_loss: 0.5587 - val_accuracy: 0.7531
# Epoch 12/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5727 - accuracy: 0.7393 - val_loss: 0.5585 - val_accuracy: 0.7531
# Epoch 13/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5726 - accuracy: 0.7393 - val_loss: 0.5585 - val_accuracy: 0.7531
# Epoch 14/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5724 - accuracy: 0.7393 - val_loss: 0.5583 - val_accuracy: 0.7531
# Epoch 15/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5722 - accuracy: 0.7393 - val_loss: 0.5581 - val_accuracy: 0.7531
# Epoch 16/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5720 - accuracy: 0.7393 - val_loss: 0.5579 - val_accuracy: 0.7531
# Epoch 17/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5718 - accuracy: 0.7393 - val_loss: 0.5578 - val_accuracy: 0.7531
# Epoch 18/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5716 - accuracy: 0.7393 - val_loss: 0.5576 - val_accuracy: 0.7531
# Epoch 19/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5713 - accuracy: 0.7393 - val_loss: 0.5573 - val_accuracy: 0.7531
# Epoch 20/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5711 - accuracy: 0.7393 - val_loss: 0.5570 - val_accuracy: 0.7531
# Epoch 21/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5708 - accuracy: 0.7393 - val_loss: 0.5567 - val_accuracy: 0.7531
# Epoch 22/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5704 - accuracy: 0.7393 - val_loss: 0.5566 - val_accuracy: 0.7531
# Epoch 23/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5701 - accuracy: 0.7393 - val_loss: 0.5562 - val_accuracy: 0.7531
# Epoch 24/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5696 - accuracy: 0.7393 - val_loss: 0.5558 - val_accuracy: 0.7531
# Epoch 25/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5692 - accuracy: 0.7393 - val_loss: 0.5552 - val_accuracy: 0.7531
# Epoch 26/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5686 - accuracy: 0.7393 - val_loss: 0.5548 - val_accuracy: 0.7531
# Epoch 27/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5680 - accuracy: 0.7393 - val_loss: 0.5541 - val_accuracy: 0.7531
# Epoch 28/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5673 - accuracy: 0.7393 - val_loss: 0.5536 - val_accuracy: 0.7531
# Epoch 29/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5665 - accuracy: 0.7393 - val_loss: 0.5530 - val_accuracy: 0.7531
# Epoch 30/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5656 - accuracy: 0.7393 - val_loss: 0.5520 - val_accuracy: 0.7531
# Epoch 31/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5646 - accuracy: 0.7393 - val_loss: 0.5509 - val_accuracy: 0.7531
# Epoch 32/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5634 - accuracy: 0.7393 - val_loss: 0.5498 - val_accuracy: 0.7531
# Epoch 33/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5620 - accuracy: 0.7393 - val_loss: 0.5485 - val_accuracy: 0.7531
# Epoch 34/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5604 - accuracy: 0.7393 - val_loss: 0.5470 - val_accuracy: 0.7531
# Epoch 35/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5585 - accuracy: 0.7393 - val_loss: 0.5452 - val_accuracy: 0.7531
# Epoch 36/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5564 - accuracy: 0.7393 - val_loss: 0.5432 - val_accuracy: 0.7531
# Epoch 37/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5541 - accuracy: 0.7393 - val_loss: 0.5410 - val_accuracy: 0.7531
# Epoch 38/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5515 - accuracy: 0.7393 - val_loss: 0.5384 - val_accuracy: 0.7531
# Epoch 39/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5488 - accuracy: 0.7393 - val_loss: 0.5359 - val_accuracy: 0.7531
# Epoch 40/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5460 - accuracy: 0.7393 - val_loss: 0.5329 - val_accuracy: 0.7531
# Epoch 41/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5432 - accuracy: 0.7392 - val_loss: 0.5303 - val_accuracy: 0.7531
# Epoch 42/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5404 - accuracy: 0.7395 - val_loss: 0.5273 - val_accuracy: 0.7532
# Epoch 43/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5377 - accuracy: 0.7403 - val_loss: 0.5245 - val_accuracy: 0.7532
# Epoch 44/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5351 - accuracy: 0.7410 - val_loss: 0.5216 - val_accuracy: 0.7533
# Epoch 45/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5326 - accuracy: 0.7415 - val_loss: 0.5192 - val_accuracy: 0.7533
# Epoch 46/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5301 - accuracy: 0.7418 - val_loss: 0.5171 - val_accuracy: 0.7529
# Epoch 47/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5277 - accuracy: 0.7419 - val_loss: 0.5140 - val_accuracy: 0.7532
# Epoch 48/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5253 - accuracy: 0.7421 - val_loss: 0.5117 - val_accuracy: 0.7539
# Epoch 49/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5229 - accuracy: 0.7423 - val_loss: 0.5096 - val_accuracy: 0.7538
# Epoch 50/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5206 - accuracy: 0.7422 - val_loss: 0.5072 - val_accuracy: 0.7539
# Epoch 51/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5183 - accuracy: 0.7421 - val_loss: 0.5042 - val_accuracy: 0.7544
# Epoch 52/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5162 - accuracy: 0.7414 - val_loss: 0.5030 - val_accuracy: 0.7539
# Epoch 53/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5142 - accuracy: 0.7409 - val_loss: 0.5007 - val_accuracy: 0.7540
# Epoch 54/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5123 - accuracy: 0.7403 - val_loss: 0.4984 - val_accuracy: 0.7535
# Epoch 55/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5107 - accuracy: 0.7395 - val_loss: 0.4968 - val_accuracy: 0.7533
# Epoch 56/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5093 - accuracy: 0.7390 - val_loss: 0.4954 - val_accuracy: 0.7531
# Epoch 57/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5081 - accuracy: 0.7386 - val_loss: 0.4950 - val_accuracy: 0.7517
# Epoch 58/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5071 - accuracy: 0.7384 - val_loss: 0.4929 - val_accuracy: 0.7522
# Epoch 59/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5063 - accuracy: 0.7379 - val_loss: 0.4921 - val_accuracy: 0.7517
# Epoch 60/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5056 - accuracy: 0.7375 - val_loss: 0.4915 - val_accuracy: 0.7514
# Epoch 61/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5050 - accuracy: 0.7373 - val_loss: 0.4907 - val_accuracy: 0.7517
# Epoch 62/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5045 - accuracy: 0.7371 - val_loss: 0.4900 - val_accuracy: 0.7517
# Epoch 63/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5041 - accuracy: 0.7371 - val_loss: 0.4905 - val_accuracy: 0.7512
# Epoch 64/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5037 - accuracy: 0.7369 - val_loss: 0.4891 - val_accuracy: 0.7519
# Epoch 65/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5033 - accuracy: 0.7369 - val_loss: 0.4887 - val_accuracy: 0.7522
# Epoch 66/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5030 - accuracy: 0.7371 - val_loss: 0.4888 - val_accuracy: 0.7519
# Epoch 67/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5027 - accuracy: 0.7369 - val_loss: 0.4893 - val_accuracy: 0.7519
# Epoch 68/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5024 - accuracy: 0.7371 - val_loss: 0.4879 - val_accuracy: 0.7525
# Epoch 69/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5022 - accuracy: 0.7370 - val_loss: 0.4883 - val_accuracy: 0.7527
# Epoch 70/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5019 - accuracy: 0.7371 - val_loss: 0.4874 - val_accuracy: 0.7527
# Epoch 71/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5017 - accuracy: 0.7372 - val_loss: 0.4871 - val_accuracy: 0.7529
# Epoch 72/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5015 - accuracy: 0.7373 - val_loss: 0.4879 - val_accuracy: 0.7527
# Epoch 73/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5013 - accuracy: 0.7374 - val_loss: 0.4880 - val_accuracy: 0.7528
# Epoch 74/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5012 - accuracy: 0.7376 - val_loss: 0.4871 - val_accuracy: 0.7530
# Epoch 75/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.5010 - accuracy: 0.7375 - val_loss: 0.4864 - val_accuracy: 0.7533
# Epoch 76/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5008 - accuracy: 0.7377 - val_loss: 0.4873 - val_accuracy: 0.7531
# Epoch 77/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5007 - accuracy: 0.7378 - val_loss: 0.4866 - val_accuracy: 0.7531
# Epoch 78/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5005 - accuracy: 0.7379 - val_loss: 0.4861 - val_accuracy: 0.7532
# Epoch 79/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5004 - accuracy: 0.7380 - val_loss: 0.4865 - val_accuracy: 0.7532
# Epoch 80/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5002 - accuracy: 0.7380 - val_loss: 0.4858 - val_accuracy: 0.7531
# Epoch 81/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5001 - accuracy: 0.7383 - val_loss: 0.4852 - val_accuracy: 0.7531
# Epoch 82/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.5000 - accuracy: 0.7383 - val_loss: 0.4858 - val_accuracy: 0.7531
# Epoch 83/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4999 - accuracy: 0.7385 - val_loss: 0.4855 - val_accuracy: 0.7532
# Epoch 84/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4997 - accuracy: 0.7385 - val_loss: 0.4865 - val_accuracy: 0.7533
# Epoch 85/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4996 - accuracy: 0.7386 - val_loss: 0.4851 - val_accuracy: 0.7533
# Epoch 86/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4995 - accuracy: 0.7386 - val_loss: 0.4847 - val_accuracy: 0.7533
# Epoch 87/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4994 - accuracy: 0.7386 - val_loss: 0.4850 - val_accuracy: 0.7533
# Epoch 88/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4993 - accuracy: 0.7386 - val_loss: 0.4847 - val_accuracy: 0.7532
# Epoch 89/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4992 - accuracy: 0.7387 - val_loss: 0.4843 - val_accuracy: 0.7533
# Epoch 90/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4991 - accuracy: 0.7387 - val_loss: 0.4848 - val_accuracy: 0.7533
# Epoch 91/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4990 - accuracy: 0.7387 - val_loss: 0.4841 - val_accuracy: 0.7533
# Epoch 92/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4989 - accuracy: 0.7387 - val_loss: 0.4848 - val_accuracy: 0.7532
# Epoch 93/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4988 - accuracy: 0.7388 - val_loss: 0.4847 - val_accuracy: 0.7532
# Epoch 94/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4987 - accuracy: 0.7389 - val_loss: 0.4853 - val_accuracy: 0.7532
# Epoch 95/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4986 - accuracy: 0.7391 - val_loss: 0.4847 - val_accuracy: 0.7532
# Epoch 96/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4985 - accuracy: 0.7390 - val_loss: 0.4848 - val_accuracy: 0.7532
# Epoch 97/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4984 - accuracy: 0.7390 - val_loss: 0.4845 - val_accuracy: 0.7531
# Epoch 98/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4983 - accuracy: 0.7392 - val_loss: 0.4837 - val_accuracy: 0.7531
# Epoch 99/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4982 - accuracy: 0.7392 - val_loss: 0.4832 - val_accuracy: 0.7531
# Epoch 100/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4981 - accuracy: 0.7392 - val_loss: 0.4838 - val_accuracy: 0.7531
# Epoch 101/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4980 - accuracy: 0.7393 - val_loss: 0.4838 - val_accuracy: 0.7530
# Epoch 102/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4979 - accuracy: 0.7393 - val_loss: 0.4838 - val_accuracy: 0.7531
# Epoch 103/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4978 - accuracy: 0.7393 - val_loss: 0.4839 - val_accuracy: 0.7531
# Epoch 104/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4977 - accuracy: 0.7393 - val_loss: 0.4835 - val_accuracy: 0.7531
# Epoch 105/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4977 - accuracy: 0.7393 - val_loss: 0.4832 - val_accuracy: 0.7531
# Epoch 106/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4976 - accuracy: 0.7393 - val_loss: 0.4830 - val_accuracy: 0.7531
# Epoch 107/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4975 - accuracy: 0.7393 - val_loss: 0.4830 - val_accuracy: 0.7531
# Epoch 108/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4974 - accuracy: 0.7393 - val_loss: 0.4825 - val_accuracy: 0.7530
# Epoch 109/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4973 - accuracy: 0.7393 - val_loss: 0.4839 - val_accuracy: 0.7531
# Epoch 110/140
# 186/186 [==============================] - 4s 21ms/step - loss: 0.4972 - accuracy: 0.7393 - val_loss: 0.4836 - val_accuracy: 0.7531
# Epoch 111/140
# 186/186 [==============================] - 4s 23ms/step - loss: 0.4971 - accuracy: 0.7393 - val_loss: 0.4829 - val_accuracy: 0.7531
# Epoch 112/140
# 186/186 [==============================] - 4s 23ms/step - loss: 0.4970 - accuracy: 0.7393 - val_loss: 0.4827 - val_accuracy: 0.7531
# Epoch 113/140
# 186/186 [==============================] - 4s 23ms/step - loss: 0.4969 - accuracy: 0.7393 - val_loss: 0.4833 - val_accuracy: 0.7531
# Epoch 114/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4968 - accuracy: 0.7393 - val_loss: 0.4826 - val_accuracy: 0.7531
# Epoch 115/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4968 - accuracy: 0.7393 - val_loss: 0.4827 - val_accuracy: 0.7531
# Epoch 116/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4967 - accuracy: 0.7393 - val_loss: 0.4836 - val_accuracy: 0.7531
# Epoch 117/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4966 - accuracy: 0.7393 - val_loss: 0.4825 - val_accuracy: 0.7531
# Epoch 118/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4965 - accuracy: 0.7393 - val_loss: 0.4825 - val_accuracy: 0.7531
# Epoch 119/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4964 - accuracy: 0.7393 - val_loss: 0.4823 - val_accuracy: 0.7531
# Epoch 120/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4963 - accuracy: 0.7393 - val_loss: 0.4823 - val_accuracy: 0.7531
# Epoch 121/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4962 - accuracy: 0.7393 - val_loss: 0.4823 - val_accuracy: 0.7531
# Epoch 122/140
# 186/186 [==============================] - 4s 23ms/step - loss: 0.4961 - accuracy: 0.7394 - val_loss: 0.4827 - val_accuracy: 0.7531
# Epoch 123/140
# 186/186 [==============================] - 4s 23ms/step - loss: 0.4960 - accuracy: 0.7394 - val_loss: 0.4823 - val_accuracy: 0.7531
# Epoch 124/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4958 - accuracy: 0.7394 - val_loss: 0.4822 - val_accuracy: 0.7531
# Epoch 125/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4957 - accuracy: 0.7394 - val_loss: 0.4815 - val_accuracy: 0.7531
# Epoch 126/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4956 - accuracy: 0.7394 - val_loss: 0.4814 - val_accuracy: 0.7531
# Epoch 127/140
# 186/186 [==============================] - 4s 23ms/step - loss: 0.4955 - accuracy: 0.7394 - val_loss: 0.4819 - val_accuracy: 0.7531
# Epoch 128/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4954 - accuracy: 0.7395 - val_loss: 0.4816 - val_accuracy: 0.7531
# Epoch 129/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4953 - accuracy: 0.7395 - val_loss: 0.4813 - val_accuracy: 0.7531
# Epoch 130/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4952 - accuracy: 0.7396 - val_loss: 0.4812 - val_accuracy: 0.7531
# Epoch 131/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4951 - accuracy: 0.7396 - val_loss: 0.4812 - val_accuracy: 0.7531
# Epoch 132/140
# 186/186 [==============================] - 4s 23ms/step - loss: 0.4950 - accuracy: 0.7396 - val_loss: 0.4818 - val_accuracy: 0.7531
# Epoch 133/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4949 - accuracy: 0.7397 - val_loss: 0.4810 - val_accuracy: 0.7530
# Epoch 134/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4947 - accuracy: 0.7397 - val_loss: 0.4814 - val_accuracy: 0.7530
# Epoch 135/140
# 186/186 [==============================] - 4s 23ms/step - loss: 0.4946 - accuracy: 0.7397 - val_loss: 0.4803 - val_accuracy: 0.7530
# Epoch 136/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4944 - accuracy: 0.7398 - val_loss: 0.4805 - val_accuracy: 0.7530
# Epoch 137/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4943 - accuracy: 0.7398 - val_loss: 0.4810 - val_accuracy: 0.7529
# Epoch 138/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4942 - accuracy: 0.7399 - val_loss: 0.4801 - val_accuracy: 0.7530
# Epoch 139/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4940 - accuracy: 0.7400 - val_loss: 0.4801 - val_accuracy: 0.7531
# Epoch 140/140
# 186/186 [==============================] - 4s 22ms/step - loss: 0.4939 - accuracy: 0.7401 - val_loss: 0.4809 - val_accuracy: 0.7535

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 17s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 591.6182248592377

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.01305918],
#        [0.01325083],
#        [0.01332568],
#        ...,
#        [0.35331136],
#        [0.3554439 ],
#        [0.35661155]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.16211287422769602
# 0.1282571097062517
# 0.4026324306705758
# 0.3326896326931664

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 76s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.65819209]
# [0.74325023]
# total acc [0.74299684]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 549902848, 'peak': 755510784}
