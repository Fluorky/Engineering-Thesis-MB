# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1844566a040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1847f6d0040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 251s 10s/step - loss: 0.5908 - accuracy: 0.7393 - val_loss: 0.5576 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.5681 - accuracy: 0.7393 - val_loss: 0.5471 - val_accuracy: 0.7532
# Epoch 3/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.5438 - accuracy: 0.7379 - val_loss: 0.5104 - val_accuracy: 0.7531
# Epoch 4/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.5134 - accuracy: 0.7376 - val_loss: 0.4968 - val_accuracy: 0.7543
# Epoch 5/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.5029 - accuracy: 0.7423 - val_loss: 0.4856 - val_accuracy: 0.7539
# Epoch 6/140
# 24/24 [==============================] - 244s 10s/step - loss: 0.4965 - accuracy: 0.7454 - val_loss: 0.4835 - val_accuracy: 0.7531
# Epoch 7/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4922 - accuracy: 0.7472 - val_loss: 0.4834 - val_accuracy: 0.7520
# Epoch 8/140
# 24/24 [==============================] - 246s 10s/step - loss: 0.4860 - accuracy: 0.7483 - val_loss: 0.4758 - val_accuracy: 0.7518
# Epoch 9/140
# 24/24 [==============================] - 247s 10s/step - loss: 0.4790 - accuracy: 0.7515 - val_loss: 0.4697 - val_accuracy: 0.7572
# Epoch 10/140
# 24/24 [==============================] - 244s 10s/step - loss: 0.4749 - accuracy: 0.7543 - val_loss: 0.4652 - val_accuracy: 0.7571
# Epoch 11/140
# 24/24 [==============================] - 244s 10s/step - loss: 0.4702 - accuracy: 0.7572 - val_loss: 0.4629 - val_accuracy: 0.7607
# Epoch 12/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4664 - accuracy: 0.7582 - val_loss: 0.4648 - val_accuracy: 0.7583
# Epoch 13/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4680 - accuracy: 0.7575 - val_loss: 0.4579 - val_accuracy: 0.7634
# Epoch 14/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4620 - accuracy: 0.7600 - val_loss: 0.4553 - val_accuracy: 0.7663
# Epoch 15/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4606 - accuracy: 0.7610 - val_loss: 0.4601 - val_accuracy: 0.7619
# Epoch 16/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4599 - accuracy: 0.7620 - val_loss: 0.4490 - val_accuracy: 0.7685
# Epoch 17/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4566 - accuracy: 0.7633 - val_loss: 0.4499 - val_accuracy: 0.7676
# Epoch 18/140
# 24/24 [==============================] - 246s 10s/step - loss: 0.4557 - accuracy: 0.7645 - val_loss: 0.4461 - val_accuracy: 0.7703
# Epoch 19/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4562 - accuracy: 0.7653 - val_loss: 0.4488 - val_accuracy: 0.7700
# Epoch 20/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4545 - accuracy: 0.7663 - val_loss: 0.4501 - val_accuracy: 0.7723
# Epoch 21/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4530 - accuracy: 0.7662 - val_loss: 0.4474 - val_accuracy: 0.7709
# Epoch 22/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4507 - accuracy: 0.7674 - val_loss: 0.4445 - val_accuracy: 0.7721
# Epoch 23/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4502 - accuracy: 0.7676 - val_loss: 0.4459 - val_accuracy: 0.7717
# Epoch 24/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4499 - accuracy: 0.7686 - val_loss: 0.4462 - val_accuracy: 0.7729
# Epoch 25/140
# 24/24 [==============================] - 244s 10s/step - loss: 0.4488 - accuracy: 0.7695 - val_loss: 0.4436 - val_accuracy: 0.7749
# Epoch 26/140
# 24/24 [==============================] - 244s 10s/step - loss: 0.4471 - accuracy: 0.7701 - val_loss: 0.4410 - val_accuracy: 0.7752
# Epoch 27/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4464 - accuracy: 0.7706 - val_loss: 0.4396 - val_accuracy: 0.7762
# Epoch 28/140
# 24/24 [==============================] - 244s 10s/step - loss: 0.4455 - accuracy: 0.7709 - val_loss: 0.4397 - val_accuracy: 0.7764
# Epoch 29/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4457 - accuracy: 0.7713 - val_loss: 0.4389 - val_accuracy: 0.7763
# Epoch 30/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4447 - accuracy: 0.7718 - val_loss: 0.4406 - val_accuracy: 0.7752
# Epoch 31/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4434 - accuracy: 0.7727 - val_loss: 0.4393 - val_accuracy: 0.7766
# Epoch 32/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4437 - accuracy: 0.7734 - val_loss: 0.4393 - val_accuracy: 0.7778
# Epoch 33/140
# 24/24 [==============================] - 245s 10s/step - loss: 0.4449 - accuracy: 0.7729 - val_loss: 0.4398 - val_accuracy: 0.7764
# Epoch 34/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4429 - accuracy: 0.7735 - val_loss: 0.4367 - val_accuracy: 0.7775
# Epoch 35/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4423 - accuracy: 0.7738 - val_loss: 0.4383 - val_accuracy: 0.7770
# Epoch 36/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4422 - accuracy: 0.7741 - val_loss: 0.4359 - val_accuracy: 0.7768
# Epoch 37/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4412 - accuracy: 0.7741 - val_loss: 0.4362 - val_accuracy: 0.7766
# Epoch 38/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4416 - accuracy: 0.7746 - val_loss: 0.4363 - val_accuracy: 0.7772
# Epoch 39/140
# 24/24 [==============================] - 245s 10s/step - loss: 0.4401 - accuracy: 0.7745 - val_loss: 0.4408 - val_accuracy: 0.7765
# Epoch 40/140
# 24/24 [==============================] - 244s 10s/step - loss: 0.4400 - accuracy: 0.7751 - val_loss: 0.4428 - val_accuracy: 0.7773
# Epoch 41/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4405 - accuracy: 0.7751 - val_loss: 0.4379 - val_accuracy: 0.7773
# Epoch 42/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4391 - accuracy: 0.7757 - val_loss: 0.4355 - val_accuracy: 0.7773
# Epoch 43/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4393 - accuracy: 0.7753 - val_loss: 0.4355 - val_accuracy: 0.7781
# Epoch 44/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4386 - accuracy: 0.7758 - val_loss: 0.4402 - val_accuracy: 0.7742
# Epoch 45/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4406 - accuracy: 0.7756 - val_loss: 0.4337 - val_accuracy: 0.7775
# Epoch 46/140
# 24/24 [==============================] - 244s 10s/step - loss: 0.4376 - accuracy: 0.7761 - val_loss: 0.4408 - val_accuracy: 0.7773
# Epoch 47/140
# 24/24 [==============================] - 244s 10s/step - loss: 0.4385 - accuracy: 0.7758 - val_loss: 0.4340 - val_accuracy: 0.7780
# Epoch 48/140
# 24/24 [==============================] - 244s 10s/step - loss: 0.4374 - accuracy: 0.7762 - val_loss: 0.4370 - val_accuracy: 0.7776
# Epoch 49/140
# 24/24 [==============================] - 245s 10s/step - loss: 0.4371 - accuracy: 0.7762 - val_loss: 0.4346 - val_accuracy: 0.7780
# Epoch 50/140
# 24/24 [==============================] - 247s 10s/step - loss: 0.4378 - accuracy: 0.7762 - val_loss: 0.4348 - val_accuracy: 0.7774
# Epoch 51/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4370 - accuracy: 0.7764 - val_loss: 0.4322 - val_accuracy: 0.7793
# Epoch 52/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4378 - accuracy: 0.7765 - val_loss: 0.4319 - val_accuracy: 0.7793
# Epoch 53/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4368 - accuracy: 0.7768 - val_loss: 0.4354 - val_accuracy: 0.7782
# Epoch 54/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4364 - accuracy: 0.7767 - val_loss: 0.4318 - val_accuracy: 0.7792
# Epoch 55/140
# 24/24 [==============================] - 245s 10s/step - loss: 0.4363 - accuracy: 0.7771 - val_loss: 0.4396 - val_accuracy: 0.7779
# Epoch 56/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4368 - accuracy: 0.7770 - val_loss: 0.4307 - val_accuracy: 0.7800
# Epoch 57/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4371 - accuracy: 0.7769 - val_loss: 0.4331 - val_accuracy: 0.7788
# Epoch 58/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4348 - accuracy: 0.7777 - val_loss: 0.4331 - val_accuracy: 0.7805
# Epoch 59/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4348 - accuracy: 0.7775 - val_loss: 0.4382 - val_accuracy: 0.7801
# Epoch 60/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4350 - accuracy: 0.7779 - val_loss: 0.4312 - val_accuracy: 0.7800
# Epoch 61/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4350 - accuracy: 0.7780 - val_loss: 0.4325 - val_accuracy: 0.7804
# Epoch 62/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4349 - accuracy: 0.7776 - val_loss: 0.4346 - val_accuracy: 0.7802
# Epoch 63/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4348 - accuracy: 0.7780 - val_loss: 0.4333 - val_accuracy: 0.7808
# Epoch 64/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4331 - accuracy: 0.7784 - val_loss: 0.4319 - val_accuracy: 0.7783
# Epoch 65/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4336 - accuracy: 0.7785 - val_loss: 0.4355 - val_accuracy: 0.7779
# Epoch 66/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4341 - accuracy: 0.7784 - val_loss: 0.4311 - val_accuracy: 0.7783
# Epoch 67/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4337 - accuracy: 0.7787 - val_loss: 0.4325 - val_accuracy: 0.7808
# Epoch 68/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4331 - accuracy: 0.7787 - val_loss: 0.4304 - val_accuracy: 0.7815
# Epoch 69/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4328 - accuracy: 0.7790 - val_loss: 0.4331 - val_accuracy: 0.7779
# Epoch 70/140
# 24/24 [==============================] - 243s 10s/step - loss: 0.4329 - accuracy: 0.7789 - val_loss: 0.4360 - val_accuracy: 0.7808
# Epoch 71/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4323 - accuracy: 0.7791 - val_loss: 0.4315 - val_accuracy: 0.7786
# Epoch 72/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4329 - accuracy: 0.7791 - val_loss: 0.4319 - val_accuracy: 0.7813
# Epoch 73/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4313 - accuracy: 0.7795 - val_loss: 0.4333 - val_accuracy: 0.7806
# Epoch 74/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4317 - accuracy: 0.7795 - val_loss: 0.4306 - val_accuracy: 0.7793
# Epoch 75/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4305 - accuracy: 0.7797 - val_loss: 0.4307 - val_accuracy: 0.7791
# Epoch 76/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4308 - accuracy: 0.7798 - val_loss: 0.4331 - val_accuracy: 0.7806
# Epoch 77/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4311 - accuracy: 0.7799 - val_loss: 0.4368 - val_accuracy: 0.7757
# Epoch 78/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4305 - accuracy: 0.7802 - val_loss: 0.4315 - val_accuracy: 0.7801
# Epoch 79/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4301 - accuracy: 0.7799 - val_loss: 0.4319 - val_accuracy: 0.7793
# Epoch 80/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4301 - accuracy: 0.7804 - val_loss: 0.4322 - val_accuracy: 0.7761
# Epoch 81/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4309 - accuracy: 0.7804 - val_loss: 0.4291 - val_accuracy: 0.7810
# Epoch 82/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4290 - accuracy: 0.7809 - val_loss: 0.4307 - val_accuracy: 0.7821
# Epoch 83/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4288 - accuracy: 0.7809 - val_loss: 0.4353 - val_accuracy: 0.7822
# Epoch 84/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4288 - accuracy: 0.7814 - val_loss: 0.4286 - val_accuracy: 0.7808
# Epoch 85/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4277 - accuracy: 0.7818 - val_loss: 0.4294 - val_accuracy: 0.7820
# Epoch 86/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4279 - accuracy: 0.7816 - val_loss: 0.4315 - val_accuracy: 0.7830
# Epoch 87/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4276 - accuracy: 0.7820 - val_loss: 0.4270 - val_accuracy: 0.7839
# Epoch 88/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4282 - accuracy: 0.7822 - val_loss: 0.4318 - val_accuracy: 0.7825
# Epoch 89/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4259 - accuracy: 0.7824 - val_loss: 0.4305 - val_accuracy: 0.7842
# Epoch 90/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4261 - accuracy: 0.7823 - val_loss: 0.4307 - val_accuracy: 0.7787
# Epoch 91/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4260 - accuracy: 0.7825 - val_loss: 0.4268 - val_accuracy: 0.7840
# Epoch 92/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4257 - accuracy: 0.7824 - val_loss: 0.4269 - val_accuracy: 0.7830
# Epoch 93/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4256 - accuracy: 0.7828 - val_loss: 0.4330 - val_accuracy: 0.7780
# Epoch 94/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4252 - accuracy: 0.7831 - val_loss: 0.4281 - val_accuracy: 0.7813
# Epoch 95/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4246 - accuracy: 0.7830 - val_loss: 0.4325 - val_accuracy: 0.7830
# Epoch 96/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4254 - accuracy: 0.7827 - val_loss: 0.4236 - val_accuracy: 0.7851
# Epoch 97/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4244 - accuracy: 0.7831 - val_loss: 0.4320 - val_accuracy: 0.7837
# Epoch 98/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4242 - accuracy: 0.7835 - val_loss: 0.4341 - val_accuracy: 0.7825
# Epoch 99/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4241 - accuracy: 0.7834 - val_loss: 0.4324 - val_accuracy: 0.7793
# Epoch 100/140
# 24/24 [==============================] - 255s 11s/step - loss: 0.4247 - accuracy: 0.7835 - val_loss: 0.4269 - val_accuracy: 0.7815
# Epoch 101/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4232 - accuracy: 0.7836 - val_loss: 0.4265 - val_accuracy: 0.7818
# Epoch 102/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4233 - accuracy: 0.7838 - val_loss: 0.4245 - val_accuracy: 0.7861
# Epoch 103/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4228 - accuracy: 0.7843 - val_loss: 0.4375 - val_accuracy: 0.7835
# Epoch 104/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4231 - accuracy: 0.7839 - val_loss: 0.4259 - val_accuracy: 0.7851
# Epoch 105/140
# 24/24 [==============================] - 237s 10s/step - loss: 0.4229 - accuracy: 0.7842 - val_loss: 0.4358 - val_accuracy: 0.7811
# Epoch 106/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4224 - accuracy: 0.7837 - val_loss: 0.4248 - val_accuracy: 0.7840
# Epoch 107/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4230 - accuracy: 0.7841 - val_loss: 0.4257 - val_accuracy: 0.7824
# Epoch 108/140
# 24/24 [==============================] - 237s 10s/step - loss: 0.4217 - accuracy: 0.7844 - val_loss: 0.4346 - val_accuracy: 0.7818
# Epoch 109/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4219 - accuracy: 0.7844 - val_loss: 0.4272 - val_accuracy: 0.7846
# Epoch 110/140
# 24/24 [==============================] - 241s 10s/step - loss: 0.4212 - accuracy: 0.7845 - val_loss: 0.4267 - val_accuracy: 0.7852
# Epoch 111/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4211 - accuracy: 0.7846 - val_loss: 0.4278 - val_accuracy: 0.7847
# Epoch 112/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4218 - accuracy: 0.7843 - val_loss: 0.4269 - val_accuracy: 0.7852
# Epoch 113/140
# 24/24 [==============================] - 237s 10s/step - loss: 0.4230 - accuracy: 0.7843 - val_loss: 0.4244 - val_accuracy: 0.7853
# Epoch 114/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4221 - accuracy: 0.7846 - val_loss: 0.4283 - val_accuracy: 0.7847
# Epoch 115/140
# 24/24 [==============================] - 237s 10s/step - loss: 0.4210 - accuracy: 0.7847 - val_loss: 0.4295 - val_accuracy: 0.7848
# Epoch 116/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4207 - accuracy: 0.7849 - val_loss: 0.4274 - val_accuracy: 0.7852
# Epoch 117/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4200 - accuracy: 0.7849 - val_loss: 0.4282 - val_accuracy: 0.7857
# Epoch 118/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4213 - accuracy: 0.7847 - val_loss: 0.4269 - val_accuracy: 0.7847
# Epoch 119/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4210 - accuracy: 0.7850 - val_loss: 0.4303 - val_accuracy: 0.7808
# Epoch 120/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4197 - accuracy: 0.7855 - val_loss: 0.4262 - val_accuracy: 0.7804
# Epoch 121/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4199 - accuracy: 0.7848 - val_loss: 0.4238 - val_accuracy: 0.7840
# Epoch 122/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4194 - accuracy: 0.7853 - val_loss: 0.4276 - val_accuracy: 0.7813
# Epoch 123/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4199 - accuracy: 0.7852 - val_loss: 0.4267 - val_accuracy: 0.7826
# Epoch 124/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4189 - accuracy: 0.7856 - val_loss: 0.4263 - val_accuracy: 0.7813
# Epoch 125/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4192 - accuracy: 0.7858 - val_loss: 0.4255 - val_accuracy: 0.7855
# Epoch 126/140
# 24/24 [==============================] - 242s 10s/step - loss: 0.4200 - accuracy: 0.7858 - val_loss: 0.4289 - val_accuracy: 0.7821
# Epoch 127/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4197 - accuracy: 0.7859 - val_loss: 0.4257 - val_accuracy: 0.7829
# Epoch 128/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4191 - accuracy: 0.7856 - val_loss: 0.4301 - val_accuracy: 0.7844
# Epoch 129/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4186 - accuracy: 0.7860 - val_loss: 0.4301 - val_accuracy: 0.7848
# Epoch 130/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4188 - accuracy: 0.7859 - val_loss: 0.4283 - val_accuracy: 0.7817
# Epoch 131/140
# 24/24 [==============================] - 237s 10s/step - loss: 0.4194 - accuracy: 0.7859 - val_loss: 0.4279 - val_accuracy: 0.7852
# Epoch 132/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4184 - accuracy: 0.7862 - val_loss: 0.4255 - val_accuracy: 0.7821
# Epoch 133/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4181 - accuracy: 0.7863 - val_loss: 0.4262 - val_accuracy: 0.7803
# Epoch 134/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4186 - accuracy: 0.7865 - val_loss: 0.4302 - val_accuracy: 0.7846
# Epoch 135/140
# 24/24 [==============================] - 240s 10s/step - loss: 0.4176 - accuracy: 0.7865 - val_loss: 0.4259 - val_accuracy: 0.7822
# Epoch 136/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4176 - accuracy: 0.7864 - val_loss: 0.4276 - val_accuracy: 0.7791
# Epoch 137/140
# 24/24 [==============================] - 237s 10s/step - loss: 0.4185 - accuracy: 0.7861 - val_loss: 0.4287 - val_accuracy: 0.7791
# Epoch 138/140
# 24/24 [==============================] - 237s 10s/step - loss: 0.4189 - accuracy: 0.7859 - val_loss: 0.4304 - val_accuracy: 0.7841
# Epoch 139/140
# 24/24 [==============================] - 238s 10s/step - loss: 0.4178 - accuracy: 0.7868 - val_loss: 0.4257 - val_accuracy: 0.7841
# Epoch 140/140
# 24/24 [==============================] - 239s 10s/step - loss: 0.4169 - accuracy: 0.7867 - val_loss: 0.4273 - val_accuracy: 0.7838

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 47s 15ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 33827.472893714905

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00284494],
#        [0.00243129],
#        [0.00125227],
#        ...,
#        [0.05507518],
#        [0.05817939],
#        [0.0628462 ]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1427882376455544
# 0.232173067203441
# 0.37787330898801835
# 0.2833212405827246

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 238s 16ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.6087334]
# [0.83170966]
# total acc [0.78632124]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6140\725781306.py in <module>
# ----> 1 tf.config.experimental.get_memory_info('GPU:0')
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\config.py in get_memory_info(device)
#     574     ValueError: Memory statistics not tracked, like '"CPU:0"'.
#     575   """
# --> 576   return context.context().get_memory_info(device)
#     577
#     578
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in get_memory_info(self, dev)
#    1605     self._initialize_physical_devices()
#    1606     self.ensure_initialized()
# -> 1607     return pywrap_tfe.TFE_GetMemoryInfo(self._context_handle, dev)
#    1608
#    1609   def reset_memory_stats(self, dev):
#
# ValueError: No matching devices found for 'GPU:0'
