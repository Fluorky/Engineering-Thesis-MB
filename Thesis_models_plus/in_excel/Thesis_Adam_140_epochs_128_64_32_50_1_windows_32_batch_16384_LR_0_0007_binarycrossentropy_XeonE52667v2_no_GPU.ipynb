# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1711b7ab040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1718f86b040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0007)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.6092 - accuracy: 0.6977 - val_loss: 0.5600 - val_accuracy: 0.7530
# Epoch 2/140
# 24/24 [==============================] - 107s 4s/step - loss: 0.5743 - accuracy: 0.7393 - val_loss: 0.5592 - val_accuracy: 0.7530
# Epoch 3/140
# 24/24 [==============================] - 107s 4s/step - loss: 0.5725 - accuracy: 0.7393 - val_loss: 0.5562 - val_accuracy: 0.7530
# Epoch 4/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.5555 - accuracy: 0.7393 - val_loss: 0.5314 - val_accuracy: 0.7530
# Epoch 5/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.5260 - accuracy: 0.7396 - val_loss: 0.5081 - val_accuracy: 0.7537
# Epoch 6/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.5058 - accuracy: 0.7382 - val_loss: 0.4895 - val_accuracy: 0.7531
# Epoch 7/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4984 - accuracy: 0.7414 - val_loss: 0.4812 - val_accuracy: 0.7536
# Epoch 8/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4942 - accuracy: 0.7454 - val_loss: 0.4792 - val_accuracy: 0.7534
# Epoch 9/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4894 - accuracy: 0.7481 - val_loss: 0.4756 - val_accuracy: 0.7540
# Epoch 10/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4835 - accuracy: 0.7488 - val_loss: 0.4724 - val_accuracy: 0.7535
# Epoch 11/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4785 - accuracy: 0.7521 - val_loss: 0.4677 - val_accuracy: 0.7569
# Epoch 12/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4722 - accuracy: 0.7556 - val_loss: 0.4627 - val_accuracy: 0.7615
# Epoch 13/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4685 - accuracy: 0.7578 - val_loss: 0.4694 - val_accuracy: 0.7628
# Epoch 14/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4657 - accuracy: 0.7588 - val_loss: 0.4606 - val_accuracy: 0.7592
# Epoch 15/140
# 24/24 [==============================] - 110s 5s/step - loss: 0.4637 - accuracy: 0.7594 - val_loss: 0.4522 - val_accuracy: 0.7656
# Epoch 16/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4617 - accuracy: 0.7602 - val_loss: 0.4542 - val_accuracy: 0.7650
# Epoch 17/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4593 - accuracy: 0.7613 - val_loss: 0.4525 - val_accuracy: 0.7670
# Epoch 18/140
# 24/24 [==============================] - 108s 5s/step - loss: 0.4586 - accuracy: 0.7621 - val_loss: 0.4496 - val_accuracy: 0.7660
# Epoch 19/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4571 - accuracy: 0.7628 - val_loss: 0.4505 - val_accuracy: 0.7683
# Epoch 20/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4560 - accuracy: 0.7637 - val_loss: 0.4550 - val_accuracy: 0.7690
# Epoch 21/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4540 - accuracy: 0.7647 - val_loss: 0.4453 - val_accuracy: 0.7692
# Epoch 22/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4532 - accuracy: 0.7652 - val_loss: 0.4584 - val_accuracy: 0.7702
# Epoch 23/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4547 - accuracy: 0.7651 - val_loss: 0.4500 - val_accuracy: 0.7690
# Epoch 24/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4531 - accuracy: 0.7657 - val_loss: 0.4576 - val_accuracy: 0.7623
# Epoch 25/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4572 - accuracy: 0.7646 - val_loss: 0.4458 - val_accuracy: 0.7699
# Epoch 26/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4510 - accuracy: 0.7668 - val_loss: 0.4425 - val_accuracy: 0.7722
# Epoch 27/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4493 - accuracy: 0.7674 - val_loss: 0.4460 - val_accuracy: 0.7670
# Epoch 28/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4495 - accuracy: 0.7672 - val_loss: 0.4445 - val_accuracy: 0.7712
# Epoch 29/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4484 - accuracy: 0.7681 - val_loss: 0.4428 - val_accuracy: 0.7724
# Epoch 30/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4475 - accuracy: 0.7684 - val_loss: 0.4420 - val_accuracy: 0.7711
# Epoch 31/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4481 - accuracy: 0.7686 - val_loss: 0.4402 - val_accuracy: 0.7749
# Epoch 32/140
# 24/24 [==============================] - 109s 5s/step - loss: 0.4466 - accuracy: 0.7687 - val_loss: 0.4389 - val_accuracy: 0.7742
# Epoch 33/140
# 24/24 [==============================] - 110s 5s/step - loss: 0.4460 - accuracy: 0.7698 - val_loss: 0.4396 - val_accuracy: 0.7761
# Epoch 34/140
# 24/24 [==============================] - 111s 5s/step - loss: 0.4463 - accuracy: 0.7691 - val_loss: 0.4390 - val_accuracy: 0.7759
# Epoch 35/140
# 24/24 [==============================] - 110s 5s/step - loss: 0.4446 - accuracy: 0.7700 - val_loss: 0.4382 - val_accuracy: 0.7758
# Epoch 36/140
# 24/24 [==============================] - 110s 5s/step - loss: 0.4443 - accuracy: 0.7702 - val_loss: 0.4394 - val_accuracy: 0.7767
# Epoch 37/140
# 24/24 [==============================] - 110s 5s/step - loss: 0.4448 - accuracy: 0.7705 - val_loss: 0.4442 - val_accuracy: 0.7710
# Epoch 38/140
# 24/24 [==============================] - 111s 5s/step - loss: 0.4465 - accuracy: 0.7703 - val_loss: 0.4412 - val_accuracy: 0.7756
# Epoch 39/140
# 24/24 [==============================] - 110s 5s/step - loss: 0.4451 - accuracy: 0.7704 - val_loss: 0.4425 - val_accuracy: 0.7768
# Epoch 40/140
# 24/24 [==============================] - 111s 5s/step - loss: 0.4434 - accuracy: 0.7716 - val_loss: 0.4371 - val_accuracy: 0.7774
# Epoch 41/140
# 24/24 [==============================] - 111s 5s/step - loss: 0.4426 - accuracy: 0.7714 - val_loss: 0.4404 - val_accuracy: 0.7758
# Epoch 42/140
# 24/24 [==============================] - 111s 5s/step - loss: 0.4424 - accuracy: 0.7714 - val_loss: 0.4392 - val_accuracy: 0.7768
# Epoch 43/140
# 24/24 [==============================] - 111s 5s/step - loss: 0.4422 - accuracy: 0.7720 - val_loss: 0.4399 - val_accuracy: 0.7773
# Epoch 44/140
# 24/24 [==============================] - 110s 5s/step - loss: 0.4427 - accuracy: 0.7718 - val_loss: 0.4413 - val_accuracy: 0.7779
# Epoch 45/140
# 24/24 [==============================] - 111s 5s/step - loss: 0.4419 - accuracy: 0.7721 - val_loss: 0.4369 - val_accuracy: 0.7766
# Epoch 46/140
# 24/24 [==============================] - 110s 5s/step - loss: 0.4411 - accuracy: 0.7727 - val_loss: 0.4347 - val_accuracy: 0.7782
# Epoch 47/140
# 24/24 [==============================] - 110s 5s/step - loss: 0.4400 - accuracy: 0.7731 - val_loss: 0.4399 - val_accuracy: 0.7777
# Epoch 48/140
# 24/24 [==============================] - 111s 5s/step - loss: 0.4406 - accuracy: 0.7730 - val_loss: 0.4397 - val_accuracy: 0.7752
# Epoch 49/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4407 - accuracy: 0.7730 - val_loss: 0.4335 - val_accuracy: 0.7794
# Epoch 50/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4391 - accuracy: 0.7738 - val_loss: 0.4348 - val_accuracy: 0.7777
# Epoch 51/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4391 - accuracy: 0.7736 - val_loss: 0.4358 - val_accuracy: 0.7779
# Epoch 52/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4419 - accuracy: 0.7736 - val_loss: 0.4358 - val_accuracy: 0.7773
# Epoch 53/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4392 - accuracy: 0.7744 - val_loss: 0.4324 - val_accuracy: 0.7796
# Epoch 54/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4375 - accuracy: 0.7753 - val_loss: 0.4326 - val_accuracy: 0.7789
# Epoch 55/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4374 - accuracy: 0.7751 - val_loss: 0.4348 - val_accuracy: 0.7777
# Epoch 56/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4382 - accuracy: 0.7752 - val_loss: 0.4386 - val_accuracy: 0.7768
# Epoch 57/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4377 - accuracy: 0.7750 - val_loss: 0.4371 - val_accuracy: 0.7786
# Epoch 58/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4366 - accuracy: 0.7756 - val_loss: 0.4330 - val_accuracy: 0.7785
# Epoch 59/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4364 - accuracy: 0.7759 - val_loss: 0.4400 - val_accuracy: 0.7731
# Epoch 60/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4388 - accuracy: 0.7755 - val_loss: 0.4321 - val_accuracy: 0.7788
# Epoch 61/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4362 - accuracy: 0.7761 - val_loss: 0.4333 - val_accuracy: 0.7790
# Epoch 62/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4350 - accuracy: 0.7766 - val_loss: 0.4401 - val_accuracy: 0.7777
# Epoch 63/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4360 - accuracy: 0.7762 - val_loss: 0.4334 - val_accuracy: 0.7794
# Epoch 64/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4349 - accuracy: 0.7767 - val_loss: 0.4324 - val_accuracy: 0.7779
# Epoch 65/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4345 - accuracy: 0.7769 - val_loss: 0.4296 - val_accuracy: 0.7793
# Epoch 66/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4341 - accuracy: 0.7774 - val_loss: 0.4313 - val_accuracy: 0.7789
# Epoch 67/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4343 - accuracy: 0.7768 - val_loss: 0.4324 - val_accuracy: 0.7767
# Epoch 68/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4335 - accuracy: 0.7771 - val_loss: 0.4320 - val_accuracy: 0.7781
# Epoch 69/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4355 - accuracy: 0.7771 - val_loss: 0.4324 - val_accuracy: 0.7797
# Epoch 70/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4338 - accuracy: 0.7774 - val_loss: 0.4319 - val_accuracy: 0.7776
# Epoch 71/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4332 - accuracy: 0.7774 - val_loss: 0.4310 - val_accuracy: 0.7786
# Epoch 72/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4328 - accuracy: 0.7780 - val_loss: 0.4343 - val_accuracy: 0.7792
# Epoch 73/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4331 - accuracy: 0.7778 - val_loss: 0.4378 - val_accuracy: 0.7792
# Epoch 74/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4335 - accuracy: 0.7774 - val_loss: 0.4321 - val_accuracy: 0.7801
# Epoch 75/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4315 - accuracy: 0.7782 - val_loss: 0.4303 - val_accuracy: 0.7792
# Epoch 76/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4321 - accuracy: 0.7783 - val_loss: 0.4300 - val_accuracy: 0.7789
# Epoch 77/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4314 - accuracy: 0.7781 - val_loss: 0.4320 - val_accuracy: 0.7796
# Epoch 78/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4317 - accuracy: 0.7785 - val_loss: 0.4345 - val_accuracy: 0.7799
# Epoch 79/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4311 - accuracy: 0.7784 - val_loss: 0.4380 - val_accuracy: 0.7781
# Epoch 80/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4315 - accuracy: 0.7785 - val_loss: 0.4305 - val_accuracy: 0.7809
# Epoch 81/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4312 - accuracy: 0.7788 - val_loss: 0.4332 - val_accuracy: 0.7782
# Epoch 82/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4318 - accuracy: 0.7784 - val_loss: 0.4316 - val_accuracy: 0.7773
# Epoch 83/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4304 - accuracy: 0.7790 - val_loss: 0.4302 - val_accuracy: 0.7811
# Epoch 84/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4301 - accuracy: 0.7792 - val_loss: 0.4291 - val_accuracy: 0.7802
# Epoch 85/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4292 - accuracy: 0.7794 - val_loss: 0.4391 - val_accuracy: 0.7796
# Epoch 86/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4333 - accuracy: 0.7783 - val_loss: 0.4299 - val_accuracy: 0.7798
# Epoch 87/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4297 - accuracy: 0.7799 - val_loss: 0.4315 - val_accuracy: 0.7791
# Epoch 88/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4287 - accuracy: 0.7798 - val_loss: 0.4303 - val_accuracy: 0.7808
# Epoch 89/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4283 - accuracy: 0.7802 - val_loss: 0.4304 - val_accuracy: 0.7793
# Epoch 90/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4287 - accuracy: 0.7799 - val_loss: 0.4298 - val_accuracy: 0.7812
# Epoch 91/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4278 - accuracy: 0.7803 - val_loss: 0.4301 - val_accuracy: 0.7805
# Epoch 92/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4271 - accuracy: 0.7802 - val_loss: 0.4308 - val_accuracy: 0.7788
# Epoch 93/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4272 - accuracy: 0.7806 - val_loss: 0.4318 - val_accuracy: 0.7796
# Epoch 94/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4280 - accuracy: 0.7801 - val_loss: 0.4403 - val_accuracy: 0.7788
# Epoch 95/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4280 - accuracy: 0.7804 - val_loss: 0.4347 - val_accuracy: 0.7812
# Epoch 96/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4285 - accuracy: 0.7806 - val_loss: 0.4360 - val_accuracy: 0.7809
# Epoch 97/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4304 - accuracy: 0.7800 - val_loss: 0.4309 - val_accuracy: 0.7807
# Epoch 98/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4265 - accuracy: 0.7812 - val_loss: 0.4288 - val_accuracy: 0.7800
# Epoch 99/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4264 - accuracy: 0.7814 - val_loss: 0.4315 - val_accuracy: 0.7803
# Epoch 100/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4258 - accuracy: 0.7815 - val_loss: 0.4298 - val_accuracy: 0.7782
# Epoch 101/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4258 - accuracy: 0.7819 - val_loss: 0.4316 - val_accuracy: 0.7819
# Epoch 102/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4253 - accuracy: 0.7818 - val_loss: 0.4328 - val_accuracy: 0.7826
# Epoch 103/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4250 - accuracy: 0.7821 - val_loss: 0.4279 - val_accuracy: 0.7830
# Epoch 104/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4246 - accuracy: 0.7822 - val_loss: 0.4298 - val_accuracy: 0.7799
# Epoch 105/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4248 - accuracy: 0.7821 - val_loss: 0.4298 - val_accuracy: 0.7835
# Epoch 106/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4244 - accuracy: 0.7826 - val_loss: 0.4328 - val_accuracy: 0.7825
# Epoch 107/140
# 24/24 [==============================] - 116s 5s/step - loss: 0.4247 - accuracy: 0.7821 - val_loss: 0.4284 - val_accuracy: 0.7803
# Epoch 108/140
# 24/24 [==============================] - 117s 5s/step - loss: 0.4245 - accuracy: 0.7821 - val_loss: 0.4270 - val_accuracy: 0.7822
# Epoch 109/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4234 - accuracy: 0.7828 - val_loss: 0.4291 - val_accuracy: 0.7821
# Epoch 110/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4233 - accuracy: 0.7830 - val_loss: 0.4262 - val_accuracy: 0.7837
# Epoch 111/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4233 - accuracy: 0.7829 - val_loss: 0.4294 - val_accuracy: 0.7838
# Epoch 112/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4231 - accuracy: 0.7830 - val_loss: 0.4300 - val_accuracy: 0.7831
# Epoch 113/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4225 - accuracy: 0.7832 - val_loss: 0.4278 - val_accuracy: 0.7840
# Epoch 114/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4227 - accuracy: 0.7833 - val_loss: 0.4306 - val_accuracy: 0.7820
# Epoch 115/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4241 - accuracy: 0.7826 - val_loss: 0.4324 - val_accuracy: 0.7766
# Epoch 116/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4231 - accuracy: 0.7832 - val_loss: 0.4307 - val_accuracy: 0.7821
# Epoch 117/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4220 - accuracy: 0.7836 - val_loss: 0.4310 - val_accuracy: 0.7754
# Epoch 118/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4223 - accuracy: 0.7833 - val_loss: 0.4285 - val_accuracy: 0.7792
# Epoch 119/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4218 - accuracy: 0.7838 - val_loss: 0.4305 - val_accuracy: 0.7843
# Epoch 120/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4215 - accuracy: 0.7837 - val_loss: 0.4311 - val_accuracy: 0.7773
# Epoch 121/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4219 - accuracy: 0.7836 - val_loss: 0.4293 - val_accuracy: 0.7785
# Epoch 122/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4208 - accuracy: 0.7840 - val_loss: 0.4286 - val_accuracy: 0.7774
# Epoch 123/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4216 - accuracy: 0.7838 - val_loss: 0.4286 - val_accuracy: 0.7785
# Epoch 124/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4219 - accuracy: 0.7836 - val_loss: 0.4323 - val_accuracy: 0.7847
# Epoch 125/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4200 - accuracy: 0.7841 - val_loss: 0.4297 - val_accuracy: 0.7783
# Epoch 126/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4199 - accuracy: 0.7842 - val_loss: 0.4288 - val_accuracy: 0.7823
# Epoch 127/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4225 - accuracy: 0.7836 - val_loss: 0.4311 - val_accuracy: 0.7837
# Epoch 128/140
# 24/24 [==============================] - 115s 5s/step - loss: 0.4199 - accuracy: 0.7846 - val_loss: 0.4282 - val_accuracy: 0.7779
# Epoch 129/140
# 24/24 [==============================] - 116s 5s/step - loss: 0.4207 - accuracy: 0.7842 - val_loss: 0.4308 - val_accuracy: 0.7766
# Epoch 130/140
# 24/24 [==============================] - 113s 5s/step - loss: 0.4200 - accuracy: 0.7846 - val_loss: 0.4302 - val_accuracy: 0.7847
# Epoch 131/140
# 24/24 [==============================] - 114s 5s/step - loss: 0.4189 - accuracy: 0.7847 - val_loss: 0.4301 - val_accuracy: 0.7772
# Epoch 132/140
# 24/24 [==============================] - 117s 5s/step - loss: 0.4196 - accuracy: 0.7850 - val_loss: 0.4296 - val_accuracy: 0.7785
# Epoch 133/140
# 24/24 [==============================] - 124s 5s/step - loss: 0.4192 - accuracy: 0.7852 - val_loss: 0.4274 - val_accuracy: 0.7802
# Epoch 134/140
# 24/24 [==============================] - 124s 5s/step - loss: 0.4195 - accuracy: 0.7848 - val_loss: 0.4289 - val_accuracy: 0.7829
# Epoch 135/140
# 24/24 [==============================] - 134s 6s/step - loss: 0.4185 - accuracy: 0.7854 - val_loss: 0.4272 - val_accuracy: 0.7820
# Epoch 136/140
# 24/24 [==============================] - 127s 5s/step - loss: 0.4192 - accuracy: 0.7852 - val_loss: 0.4323 - val_accuracy: 0.7847
# Epoch 137/140
# 24/24 [==============================] - 123s 5s/step - loss: 0.4187 - accuracy: 0.7850 - val_loss: 0.4302 - val_accuracy: 0.7851
# Epoch 138/140
# 24/24 [==============================] - 123s 5s/step - loss: 0.4191 - accuracy: 0.7849 - val_loss: 0.4304 - val_accuracy: 0.7758
# Epoch 139/140
# 24/24 [==============================] - 123s 5s/step - loss: 0.4188 - accuracy: 0.7854 - val_loss: 0.4274 - val_accuracy: 0.7816
# Epoch 140/140
# 24/24 [==============================] - 121s 5s/step - loss: 0.4174 - accuracy: 0.7856 - val_loss: 0.4308 - val_accuracy: 0.7851

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 39s 13ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 15890.645250320435

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00189807],
#        [0.00512305],
#        [0.00201665],
#        ...,
#        [0.0401818 ],
#        [0.04378628],
#        [0.04352004]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14326416811881226
# 0.2296355923050899
# 0.3785025338340713
# 0.2775151122546729

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 195s 13ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.61926207]
# [0.82228844]
# total acc [0.78539254]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9236\725781306.py in <module>
# ----> 1 tf.config.experimental.get_memory_info('GPU:0')
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\config.py in get_memory_info(device)
#     574     ValueError: Memory statistics not tracked, like '"CPU:0"'.
#     575   """
# --> 576   return context.context().get_memory_info(device)
#     577
#     578
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in get_memory_info(self, dev)
#    1628     self._initialize_physical_devices()
#    1629     self.ensure_initialized()
# -> 1630     return pywrap_tfe.TFE_GetMemoryInfo(self._context_handle, dev)
#    1631
#    1632   def reset_memory_stats(self, dev):
#
# ValueError: No matching devices found for 'GPU:0'
