# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x19b651a2040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x19bd9254040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.003)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=32768)#, shuffle=False)
# Out:
# Epoch 1/140
# 12/12 [==============================] - 12s 420ms/step - loss: 0.5938 - accuracy: 0.7141 - val_loss: 0.5603 - val_accuracy: 0.7530
# Epoch 2/140
# 12/12 [==============================] - 4s 298ms/step - loss: 0.5694 - accuracy: 0.7393 - val_loss: 0.5446 - val_accuracy: 0.7532
# Epoch 3/140
# 12/12 [==============================] - 4s 316ms/step - loss: 0.5445 - accuracy: 0.7352 - val_loss: 0.5110 - val_accuracy: 0.7531
# Epoch 4/140
# 12/12 [==============================] - 4s 323ms/step - loss: 0.5201 - accuracy: 0.7391 - val_loss: 0.4887 - val_accuracy: 0.7528
# Epoch 5/140
# 12/12 [==============================] - 4s 320ms/step - loss: 0.5039 - accuracy: 0.7390 - val_loss: 0.4906 - val_accuracy: 0.7534
# Epoch 6/140
# 12/12 [==============================] - 4s 330ms/step - loss: 0.4954 - accuracy: 0.7421 - val_loss: 0.4822 - val_accuracy: 0.7551
# Epoch 7/140
# 12/12 [==============================] - 4s 309ms/step - loss: 0.4897 - accuracy: 0.7470 - val_loss: 0.4777 - val_accuracy: 0.7524
# Epoch 8/140
# 12/12 [==============================] - 4s 320ms/step - loss: 0.4824 - accuracy: 0.7488 - val_loss: 0.4780 - val_accuracy: 0.7512
# Epoch 9/140
# 12/12 [==============================] - 4s 333ms/step - loss: 0.4816 - accuracy: 0.7516 - val_loss: 0.4653 - val_accuracy: 0.7573
# Epoch 10/140
# 12/12 [==============================] - 4s 329ms/step - loss: 0.4738 - accuracy: 0.7552 - val_loss: 0.4815 - val_accuracy: 0.7425
# Epoch 11/140
# 12/12 [==============================] - 4s 323ms/step - loss: 0.4779 - accuracy: 0.7504 - val_loss: 0.4617 - val_accuracy: 0.7591
# Epoch 12/140
# 12/12 [==============================] - 4s 323ms/step - loss: 0.4682 - accuracy: 0.7574 - val_loss: 0.4570 - val_accuracy: 0.7616
# Epoch 13/140
# 12/12 [==============================] - 4s 339ms/step - loss: 0.4623 - accuracy: 0.7609 - val_loss: 0.4664 - val_accuracy: 0.7560
# Epoch 14/140
# 12/12 [==============================] - 4s 333ms/step - loss: 0.4623 - accuracy: 0.7612 - val_loss: 0.4503 - val_accuracy: 0.7678
# Epoch 15/140
# 12/12 [==============================] - 4s 328ms/step - loss: 0.4673 - accuracy: 0.7574 - val_loss: 0.4608 - val_accuracy: 0.7639
# Epoch 16/140
# 12/12 [==============================] - 4s 327ms/step - loss: 0.4669 - accuracy: 0.7571 - val_loss: 0.4568 - val_accuracy: 0.7633
# Epoch 17/140
# 12/12 [==============================] - 4s 336ms/step - loss: 0.4581 - accuracy: 0.7638 - val_loss: 0.4488 - val_accuracy: 0.7684
# Epoch 18/140
# 12/12 [==============================] - 4s 326ms/step - loss: 0.4526 - accuracy: 0.7655 - val_loss: 0.4434 - val_accuracy: 0.7718
# Epoch 19/140
# 12/12 [==============================] - 4s 328ms/step - loss: 0.4532 - accuracy: 0.7669 - val_loss: 0.4497 - val_accuracy: 0.7700
# Epoch 20/140
# 12/12 [==============================] - 4s 328ms/step - loss: 0.4507 - accuracy: 0.7673 - val_loss: 0.4479 - val_accuracy: 0.7731
# Epoch 21/140
# 12/12 [==============================] - 4s 332ms/step - loss: 0.4504 - accuracy: 0.7681 - val_loss: 0.4407 - val_accuracy: 0.7740
# Epoch 22/140
# 12/12 [==============================] - 4s 326ms/step - loss: 0.4486 - accuracy: 0.7686 - val_loss: 0.4452 - val_accuracy: 0.7705
# Epoch 23/140
# 12/12 [==============================] - 4s 329ms/step - loss: 0.4494 - accuracy: 0.7688 - val_loss: 0.4469 - val_accuracy: 0.7745
# Epoch 24/140
# 12/12 [==============================] - 4s 332ms/step - loss: 0.4468 - accuracy: 0.7703 - val_loss: 0.4381 - val_accuracy: 0.7751
# Epoch 25/140
# 12/12 [==============================] - 4s 330ms/step - loss: 0.4434 - accuracy: 0.7713 - val_loss: 0.4364 - val_accuracy: 0.7752
# Epoch 26/140
# 12/12 [==============================] - 4s 336ms/step - loss: 0.4445 - accuracy: 0.7719 - val_loss: 0.4391 - val_accuracy: 0.7766
# Epoch 27/140
# 12/12 [==============================] - 4s 339ms/step - loss: 0.4420 - accuracy: 0.7725 - val_loss: 0.4382 - val_accuracy: 0.7757
# Epoch 28/140
# 12/12 [==============================] - 4s 325ms/step - loss: 0.4457 - accuracy: 0.7726 - val_loss: 0.4470 - val_accuracy: 0.7699
# Epoch 29/140
# 12/12 [==============================] - 4s 318ms/step - loss: 0.4447 - accuracy: 0.7712 - val_loss: 0.4362 - val_accuracy: 0.7775
# Epoch 30/140
# 12/12 [==============================] - 4s 315ms/step - loss: 0.4401 - accuracy: 0.7742 - val_loss: 0.4325 - val_accuracy: 0.7786
# Epoch 31/140
# 12/12 [==============================] - 4s 311ms/step - loss: 0.4404 - accuracy: 0.7756 - val_loss: 0.4417 - val_accuracy: 0.7779
# Epoch 32/140
# 12/12 [==============================] - 4s 316ms/step - loss: 0.4398 - accuracy: 0.7763 - val_loss: 0.4337 - val_accuracy: 0.7807
# Epoch 33/140
# 12/12 [==============================] - 4s 315ms/step - loss: 0.4367 - accuracy: 0.7772 - val_loss: 0.4323 - val_accuracy: 0.7785
# Epoch 34/140
# 12/12 [==============================] - 4s 313ms/step - loss: 0.4357 - accuracy: 0.7786 - val_loss: 0.4384 - val_accuracy: 0.7799
# Epoch 35/140
# 12/12 [==============================] - 4s 315ms/step - loss: 0.4358 - accuracy: 0.7777 - val_loss: 0.4359 - val_accuracy: 0.7793
# Epoch 36/140
# 12/12 [==============================] - 4s 315ms/step - loss: 0.4392 - accuracy: 0.7769 - val_loss: 0.4378 - val_accuracy: 0.7779
# Epoch 37/140
# 12/12 [==============================] - 4s 312ms/step - loss: 0.4353 - accuracy: 0.7785 - val_loss: 0.4318 - val_accuracy: 0.7798
# Epoch 38/140
# 12/12 [==============================] - 4s 316ms/step - loss: 0.4329 - accuracy: 0.7796 - val_loss: 0.4300 - val_accuracy: 0.7811
# Epoch 39/140
# 12/12 [==============================] - 4s 313ms/step - loss: 0.4318 - accuracy: 0.7798 - val_loss: 0.4310 - val_accuracy: 0.7792
# Epoch 40/140
# 12/12 [==============================] - 4s 313ms/step - loss: 0.4349 - accuracy: 0.7788 - val_loss: 0.4313 - val_accuracy: 0.7819
# Epoch 41/140
# 12/12 [==============================] - 4s 312ms/step - loss: 0.4332 - accuracy: 0.7797 - val_loss: 0.4329 - val_accuracy: 0.7816
# Epoch 42/140
# 12/12 [==============================] - 4s 312ms/step - loss: 0.4299 - accuracy: 0.7808 - val_loss: 0.4304 - val_accuracy: 0.7828
# Epoch 43/140
# 12/12 [==============================] - 4s 312ms/step - loss: 0.4317 - accuracy: 0.7802 - val_loss: 0.4299 - val_accuracy: 0.7817
# Epoch 44/140
# 12/12 [==============================] - 4s 317ms/step - loss: 0.4303 - accuracy: 0.7808 - val_loss: 0.4284 - val_accuracy: 0.7830
# Epoch 45/140
# 12/12 [==============================] - 4s 310ms/step - loss: 0.4309 - accuracy: 0.7812 - val_loss: 0.4303 - val_accuracy: 0.7796
# Epoch 46/140
# 12/12 [==============================] - 4s 304ms/step - loss: 0.4290 - accuracy: 0.7813 - val_loss: 0.4314 - val_accuracy: 0.7821
# Epoch 47/140
# 12/12 [==============================] - 4s 305ms/step - loss: 0.4270 - accuracy: 0.7828 - val_loss: 0.4294 - val_accuracy: 0.7792
# Epoch 48/140
# 12/12 [==============================] - 4s 305ms/step - loss: 0.4275 - accuracy: 0.7828 - val_loss: 0.4268 - val_accuracy: 0.7834
# Epoch 49/140
# 12/12 [==============================] - 4s 304ms/step - loss: 0.4292 - accuracy: 0.7823 - val_loss: 0.4338 - val_accuracy: 0.7783
# Epoch 50/140
# 12/12 [==============================] - 4s 306ms/step - loss: 0.4262 - accuracy: 0.7830 - val_loss: 0.4262 - val_accuracy: 0.7846
# Epoch 51/140
# 12/12 [==============================] - 4s 301ms/step - loss: 0.4305 - accuracy: 0.7817 - val_loss: 0.4276 - val_accuracy: 0.7828
# Epoch 52/140
# 12/12 [==============================] - 4s 303ms/step - loss: 0.4305 - accuracy: 0.7817 - val_loss: 0.4325 - val_accuracy: 0.7784
# Epoch 53/140
# 12/12 [==============================] - 4s 314ms/step - loss: 0.4281 - accuracy: 0.7831 - val_loss: 0.4285 - val_accuracy: 0.7834
# Epoch 54/140
# 12/12 [==============================] - 4s 371ms/step - loss: 0.4260 - accuracy: 0.7834 - val_loss: 0.4304 - val_accuracy: 0.7806
# Epoch 55/140
# 12/12 [==============================] - 5s 423ms/step - loss: 0.4247 - accuracy: 0.7838 - val_loss: 0.4251 - val_accuracy: 0.7848
# Epoch 56/140
# 12/12 [==============================] - 5s 423ms/step - loss: 0.4227 - accuracy: 0.7849 - val_loss: 0.4305 - val_accuracy: 0.7848
# Epoch 57/140
# 12/12 [==============================] - 5s 432ms/step - loss: 0.4221 - accuracy: 0.7853 - val_loss: 0.4264 - val_accuracy: 0.7856
# Epoch 58/140
# 12/12 [==============================] - 5s 434ms/step - loss: 0.4213 - accuracy: 0.7855 - val_loss: 0.4265 - val_accuracy: 0.7836
# Epoch 59/140
# 12/12 [==============================] - 5s 428ms/step - loss: 0.4243 - accuracy: 0.7847 - val_loss: 0.4264 - val_accuracy: 0.7846
# Epoch 60/140
# 12/12 [==============================] - 5s 414ms/step - loss: 0.4225 - accuracy: 0.7851 - val_loss: 0.4256 - val_accuracy: 0.7814
# Epoch 61/140
# 12/12 [==============================] - 5s 413ms/step - loss: 0.4210 - accuracy: 0.7856 - val_loss: 0.4346 - val_accuracy: 0.7830
# Epoch 62/140
# 12/12 [==============================] - 5s 410ms/step - loss: 0.4211 - accuracy: 0.7860 - val_loss: 0.4253 - val_accuracy: 0.7858
# Epoch 63/140
# 12/12 [==============================] - 5s 413ms/step - loss: 0.4193 - accuracy: 0.7864 - val_loss: 0.4264 - val_accuracy: 0.7829
# Epoch 64/140
# 12/12 [==============================] - 5s 412ms/step - loss: 0.4200 - accuracy: 0.7863 - val_loss: 0.4273 - val_accuracy: 0.7839
# Epoch 65/140
# 12/12 [==============================] - 5s 413ms/step - loss: 0.4222 - accuracy: 0.7859 - val_loss: 0.4352 - val_accuracy: 0.7805
# Epoch 66/140
# 12/12 [==============================] - 5s 415ms/step - loss: 0.4223 - accuracy: 0.7856 - val_loss: 0.4313 - val_accuracy: 0.7860
# Epoch 67/140
# 12/12 [==============================] - 5s 411ms/step - loss: 0.4201 - accuracy: 0.7865 - val_loss: 0.4293 - val_accuracy: 0.7857
# Epoch 68/140
# 12/12 [==============================] - 5s 413ms/step - loss: 0.4197 - accuracy: 0.7871 - val_loss: 0.4262 - val_accuracy: 0.7843
# Epoch 69/140
# 12/12 [==============================] - 5s 411ms/step - loss: 0.4191 - accuracy: 0.7873 - val_loss: 0.4308 - val_accuracy: 0.7788
# Epoch 70/140
# 12/12 [==============================] - 5s 410ms/step - loss: 0.4179 - accuracy: 0.7877 - val_loss: 0.4267 - val_accuracy: 0.7855
# Epoch 71/140
# 12/12 [==============================] - 5s 421ms/step - loss: 0.4173 - accuracy: 0.7876 - val_loss: 0.4335 - val_accuracy: 0.7842
# Epoch 72/140
# 12/12 [==============================] - 5s 410ms/step - loss: 0.4181 - accuracy: 0.7880 - val_loss: 0.4280 - val_accuracy: 0.7817
# Epoch 73/140
# 12/12 [==============================] - 5s 399ms/step - loss: 0.4180 - accuracy: 0.7883 - val_loss: 0.4249 - val_accuracy: 0.7820
# Epoch 74/140
# 12/12 [==============================] - 5s 414ms/step - loss: 0.4160 - accuracy: 0.7885 - val_loss: 0.4248 - val_accuracy: 0.7817
# Epoch 75/140
# 12/12 [==============================] - 5s 416ms/step - loss: 0.4151 - accuracy: 0.7893 - val_loss: 0.4294 - val_accuracy: 0.7787
# Epoch 76/140
# 12/12 [==============================] - 5s 418ms/step - loss: 0.4157 - accuracy: 0.7882 - val_loss: 0.4267 - val_accuracy: 0.7788
# Epoch 77/140
# 12/12 [==============================] - 5s 416ms/step - loss: 0.4170 - accuracy: 0.7880 - val_loss: 0.4269 - val_accuracy: 0.7845
# Epoch 78/140
# 12/12 [==============================] - 5s 420ms/step - loss: 0.4152 - accuracy: 0.7891 - val_loss: 0.4346 - val_accuracy: 0.7862
# Epoch 79/140
# 12/12 [==============================] - 5s 423ms/step - loss: 0.4164 - accuracy: 0.7882 - val_loss: 0.4284 - val_accuracy: 0.7807
# Epoch 80/140
# 12/12 [==============================] - 5s 413ms/step - loss: 0.4146 - accuracy: 0.7891 - val_loss: 0.4245 - val_accuracy: 0.7833
# Epoch 81/140
# 12/12 [==============================] - 5s 415ms/step - loss: 0.4151 - accuracy: 0.7891 - val_loss: 0.4252 - val_accuracy: 0.7862
# Epoch 82/140
# 12/12 [==============================] - 5s 429ms/step - loss: 0.4147 - accuracy: 0.7892 - val_loss: 0.4247 - val_accuracy: 0.7825
# Epoch 83/140
# 12/12 [==============================] - 5s 427ms/step - loss: 0.4141 - accuracy: 0.7893 - val_loss: 0.4254 - val_accuracy: 0.7860
# Epoch 84/140
# 12/12 [==============================] - 5s 422ms/step - loss: 0.4138 - accuracy: 0.7895 - val_loss: 0.4386 - val_accuracy: 0.7831
# Epoch 85/140
# 12/12 [==============================] - 5s 413ms/step - loss: 0.4152 - accuracy: 0.7889 - val_loss: 0.4228 - val_accuracy: 0.7857
# Epoch 86/140
# 12/12 [==============================] - 5s 425ms/step - loss: 0.4160 - accuracy: 0.7881 - val_loss: 0.4273 - val_accuracy: 0.7808
# Epoch 87/140
# 12/12 [==============================] - 5s 417ms/step - loss: 0.4152 - accuracy: 0.7891 - val_loss: 0.4255 - val_accuracy: 0.7810
# Epoch 88/140
# 12/12 [==============================] - 5s 416ms/step - loss: 0.4122 - accuracy: 0.7903 - val_loss: 0.4261 - val_accuracy: 0.7868
# Epoch 89/140
# 12/12 [==============================] - 5s 414ms/step - loss: 0.4142 - accuracy: 0.7893 - val_loss: 0.4288 - val_accuracy: 0.7778
# Epoch 90/140
# 12/12 [==============================] - 5s 411ms/step - loss: 0.4117 - accuracy: 0.7908 - val_loss: 0.4245 - val_accuracy: 0.7855
# Epoch 91/140
# 12/12 [==============================] - 5s 415ms/step - loss: 0.4112 - accuracy: 0.7907 - val_loss: 0.4261 - val_accuracy: 0.7812
# Epoch 92/140
# 12/12 [==============================] - 5s 423ms/step - loss: 0.4117 - accuracy: 0.7904 - val_loss: 0.4388 - val_accuracy: 0.7845
# Epoch 93/140
# 12/12 [==============================] - 5s 417ms/step - loss: 0.4154 - accuracy: 0.7893 - val_loss: 0.4282 - val_accuracy: 0.7853
# Epoch 94/140
# 12/12 [==============================] - 5s 421ms/step - loss: 0.4112 - accuracy: 0.7906 - val_loss: 0.4292 - val_accuracy: 0.7795
# Epoch 95/140
# 12/12 [==============================] - 5s 428ms/step - loss: 0.4108 - accuracy: 0.7907 - val_loss: 0.4234 - val_accuracy: 0.7866
# Epoch 96/140
# 12/12 [==============================] - 5s 409ms/step - loss: 0.4135 - accuracy: 0.7894 - val_loss: 0.4276 - val_accuracy: 0.7810
# Epoch 97/140
# 12/12 [==============================] - 4s 322ms/step - loss: 0.4111 - accuracy: 0.7908 - val_loss: 0.4275 - val_accuracy: 0.7849
# Epoch 98/140
# 12/12 [==============================] - 4s 322ms/step - loss: 0.4087 - accuracy: 0.7919 - val_loss: 0.4291 - val_accuracy: 0.7816
# Epoch 99/140
# 12/12 [==============================] - 4s 335ms/step - loss: 0.4095 - accuracy: 0.7922 - val_loss: 0.4297 - val_accuracy: 0.7841
# Epoch 100/140
# 12/12 [==============================] - 4s 341ms/step - loss: 0.4078 - accuracy: 0.7921 - val_loss: 0.4291 - val_accuracy: 0.7853
# Epoch 101/140
# 12/12 [==============================] - 4s 350ms/step - loss: 0.4080 - accuracy: 0.7923 - val_loss: 0.4259 - val_accuracy: 0.7822
# Epoch 102/140
# 12/12 [==============================] - 4s 334ms/step - loss: 0.4077 - accuracy: 0.7923 - val_loss: 0.4293 - val_accuracy: 0.7782
# Epoch 103/140
# 12/12 [==============================] - 4s 349ms/step - loss: 0.4086 - accuracy: 0.7921 - val_loss: 0.4291 - val_accuracy: 0.7839
# Epoch 104/140
# 12/12 [==============================] - 4s 341ms/step - loss: 0.4080 - accuracy: 0.7924 - val_loss: 0.4292 - val_accuracy: 0.7783
# Epoch 105/140
# 12/12 [==============================] - 4s 340ms/step - loss: 0.4085 - accuracy: 0.7921 - val_loss: 0.4295 - val_accuracy: 0.7780
# Epoch 106/140
# 12/12 [==============================] - 4s 341ms/step - loss: 0.4091 - accuracy: 0.7920 - val_loss: 0.4285 - val_accuracy: 0.7846
# Epoch 107/140
# 12/12 [==============================] - 4s 336ms/step - loss: 0.4077 - accuracy: 0.7919 - val_loss: 0.4299 - val_accuracy: 0.7792
# Epoch 108/140
# 12/12 [==============================] - 4s 341ms/step - loss: 0.4090 - accuracy: 0.7925 - val_loss: 0.4280 - val_accuracy: 0.7818
# Epoch 109/140
# 12/12 [==============================] - 4s 346ms/step - loss: 0.4054 - accuracy: 0.7935 - val_loss: 0.4320 - val_accuracy: 0.7833
# Epoch 110/140
# 12/12 [==============================] - 4s 359ms/step - loss: 0.4057 - accuracy: 0.7937 - val_loss: 0.4449 - val_accuracy: 0.7803
# Epoch 111/140
# 12/12 [==============================] - 4s 352ms/step - loss: 0.4078 - accuracy: 0.7929 - val_loss: 0.4288 - val_accuracy: 0.7847
# Epoch 112/140
# 12/12 [==============================] - 4s 351ms/step - loss: 0.4045 - accuracy: 0.7939 - val_loss: 0.4285 - val_accuracy: 0.7854
# Epoch 113/140
# 12/12 [==============================] - 4s 340ms/step - loss: 0.4030 - accuracy: 0.7944 - val_loss: 0.4348 - val_accuracy: 0.7853
# Epoch 114/140
# 12/12 [==============================] - 4s 341ms/step - loss: 0.4049 - accuracy: 0.7940 - val_loss: 0.4312 - val_accuracy: 0.7757
# Epoch 115/140
# 12/12 [==============================] - 4s 350ms/step - loss: 0.4056 - accuracy: 0.7937 - val_loss: 0.4325 - val_accuracy: 0.7746
# Epoch 116/140
# 12/12 [==============================] - 4s 355ms/step - loss: 0.4056 - accuracy: 0.7938 - val_loss: 0.4296 - val_accuracy: 0.7845
# Epoch 117/140
# 12/12 [==============================] - 4s 350ms/step - loss: 0.4042 - accuracy: 0.7941 - val_loss: 0.4346 - val_accuracy: 0.7812
# Epoch 118/140
# 12/12 [==============================] - 4s 337ms/step - loss: 0.4019 - accuracy: 0.7952 - val_loss: 0.4290 - val_accuracy: 0.7838
# Epoch 119/140
# 12/12 [==============================] - 4s 342ms/step - loss: 0.4013 - accuracy: 0.7958 - val_loss: 0.4354 - val_accuracy: 0.7813
# Epoch 120/140
# 12/12 [==============================] - 4s 344ms/step - loss: 0.4014 - accuracy: 0.7957 - val_loss: 0.4308 - val_accuracy: 0.7794
# Epoch 121/140
# 12/12 [==============================] - 4s 359ms/step - loss: 0.4014 - accuracy: 0.7956 - val_loss: 0.4366 - val_accuracy: 0.7829
# Epoch 122/140
# 12/12 [==============================] - 4s 356ms/step - loss: 0.4031 - accuracy: 0.7949 - val_loss: 0.4330 - val_accuracy: 0.7762
# Epoch 123/140
# 12/12 [==============================] - 4s 334ms/step - loss: 0.4015 - accuracy: 0.7959 - val_loss: 0.4316 - val_accuracy: 0.7785
# Epoch 124/140
# 12/12 [==============================] - 4s 349ms/step - loss: 0.4017 - accuracy: 0.7951 - val_loss: 0.4313 - val_accuracy: 0.7778
# Epoch 125/140
# 12/12 [==============================] - 4s 343ms/step - loss: 0.4003 - accuracy: 0.7965 - val_loss: 0.4334 - val_accuracy: 0.7789
# Epoch 126/140
# 12/12 [==============================] - 4s 343ms/step - loss: 0.3996 - accuracy: 0.7968 - val_loss: 0.4360 - val_accuracy: 0.7804
# Epoch 127/140
# 12/12 [==============================] - 4s 343ms/step - loss: 0.3997 - accuracy: 0.7964 - val_loss: 0.4370 - val_accuracy: 0.7801
# Epoch 128/140
# 12/12 [==============================] - 4s 346ms/step - loss: 0.4012 - accuracy: 0.7962 - val_loss: 0.4342 - val_accuracy: 0.7787
# Epoch 129/140
# 12/12 [==============================] - 4s 343ms/step - loss: 0.4022 - accuracy: 0.7957 - val_loss: 0.4328 - val_accuracy: 0.7798
# Epoch 130/140
# 12/12 [==============================] - 4s 344ms/step - loss: 0.3988 - accuracy: 0.7969 - val_loss: 0.4375 - val_accuracy: 0.7734
# Epoch 131/140
# 12/12 [==============================] - 4s 342ms/step - loss: 0.3990 - accuracy: 0.7972 - val_loss: 0.4388 - val_accuracy: 0.7800
# Epoch 132/140
# 12/12 [==============================] - 4s 343ms/step - loss: 0.4019 - accuracy: 0.7961 - val_loss: 0.4368 - val_accuracy: 0.7714
# Epoch 133/140
# 12/12 [==============================] - 4s 344ms/step - loss: 0.3986 - accuracy: 0.7971 - val_loss: 0.4397 - val_accuracy: 0.7780
# Epoch 134/140
# 12/12 [==============================] - 4s 351ms/step - loss: 0.3961 - accuracy: 0.7985 - val_loss: 0.4393 - val_accuracy: 0.7785
# Epoch 135/140
# 12/12 [==============================] - 4s 346ms/step - loss: 0.3971 - accuracy: 0.7982 - val_loss: 0.4516 - val_accuracy: 0.7763
# Epoch 136/140
# 12/12 [==============================] - 4s 339ms/step - loss: 0.3996 - accuracy: 0.7966 - val_loss: 0.4405 - val_accuracy: 0.7792
# Epoch 137/140
# 12/12 [==============================] - 4s 340ms/step - loss: 0.3960 - accuracy: 0.7986 - val_loss: 0.4417 - val_accuracy: 0.7776
# Epoch 138/140
# 12/12 [==============================] - 4s 346ms/step - loss: 0.3941 - accuracy: 0.7992 - val_loss: 0.4433 - val_accuracy: 0.7780
# Epoch 139/140
# 12/12 [==============================] - 4s 350ms/step - loss: 0.3930 - accuracy: 0.8000 - val_loss: 0.4407 - val_accuracy: 0.7781
# Epoch 140/140
# 12/12 [==============================] - 4s 352ms/step - loss: 0.3948 - accuracy: 0.7992 - val_loss: 0.4414 - val_accuracy: 0.7686

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 21s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 629.1605429649353

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00190526],
#        [0.00213155],
#        [0.00040215],
#        ...,
#        [0.10862743],
#        [0.09183712],
#        [0.11711942]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1489656885503433
# 0.19897720460165358
# 0.3859607344670482
# 0.2927636464667302

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 96s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.59254345]
# [0.85866198]
# total acc [0.78988229]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 9512924928}
