# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2583ac2b040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x25874c9e040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
model_gru.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 128)           55680
#
#  gru_1 (GRU)                 (None, 16, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y), batch_size=233)#, shuffle=False)
# Out:
# Epoch 1/140
# 1632/1632 [==============================] - 33s 17ms/step - loss: 0.5728 - accuracy: 0.7393 - val_loss: 0.5575 - val_accuracy: 0.7531
# Epoch 2/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.5704 - accuracy: 0.7393 - val_loss: 0.5548 - val_accuracy: 0.7531
# Epoch 3/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.5647 - accuracy: 0.7393 - val_loss: 0.5468 - val_accuracy: 0.7531
# Epoch 4/140
# 1632/1632 [==============================] - 27s 16ms/step - loss: 0.5487 - accuracy: 0.7393 - val_loss: 0.5264 - val_accuracy: 0.7532
# Epoch 5/140
# 1632/1632 [==============================] - 26s 16ms/step - loss: 0.5274 - accuracy: 0.7411 - val_loss: 0.5045 - val_accuracy: 0.7540
# Epoch 6/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.5104 - accuracy: 0.7394 - val_loss: 0.4949 - val_accuracy: 0.7488
# Epoch 7/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.5037 - accuracy: 0.7369 - val_loss: 0.4869 - val_accuracy: 0.7528
# Epoch 8/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.5017 - accuracy: 0.7374 - val_loss: 0.4853 - val_accuracy: 0.7531
# Epoch 9/140
# 1632/1632 [==============================] - 26s 16ms/step - loss: 0.5006 - accuracy: 0.7380 - val_loss: 0.4882 - val_accuracy: 0.7531
# Epoch 10/140
# 1632/1632 [==============================] - 26s 16ms/step - loss: 0.4995 - accuracy: 0.7386 - val_loss: 0.4889 - val_accuracy: 0.7531
# Epoch 11/140
# 1632/1632 [==============================] - 26s 16ms/step - loss: 0.4987 - accuracy: 0.7390 - val_loss: 0.4851 - val_accuracy: 0.7532
# Epoch 12/140
# 1632/1632 [==============================] - 27s 16ms/step - loss: 0.4979 - accuracy: 0.7392 - val_loss: 0.4824 - val_accuracy: 0.7530
# Epoch 13/140
# 1632/1632 [==============================] - 26s 16ms/step - loss: 0.4970 - accuracy: 0.7394 - val_loss: 0.4837 - val_accuracy: 0.7531
# Epoch 14/140
# 1632/1632 [==============================] - 27s 16ms/step - loss: 0.4963 - accuracy: 0.7396 - val_loss: 0.4851 - val_accuracy: 0.7531
# Epoch 15/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4953 - accuracy: 0.7400 - val_loss: 0.4802 - val_accuracy: 0.7529
# Epoch 16/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4941 - accuracy: 0.7409 - val_loss: 0.4791 - val_accuracy: 0.7534
# Epoch 17/140
# 1632/1632 [==============================] - 27s 16ms/step - loss: 0.4929 - accuracy: 0.7424 - val_loss: 0.4786 - val_accuracy: 0.7550
# Epoch 18/140
# 1632/1632 [==============================] - 27s 16ms/step - loss: 0.4914 - accuracy: 0.7448 - val_loss: 0.4777 - val_accuracy: 0.7556
# Epoch 19/140
# 1632/1632 [==============================] - 26s 16ms/step - loss: 0.4897 - accuracy: 0.7461 - val_loss: 0.4782 - val_accuracy: 0.7555
# Epoch 20/140
# 1632/1632 [==============================] - 26s 16ms/step - loss: 0.4880 - accuracy: 0.7471 - val_loss: 0.4768 - val_accuracy: 0.7538
# Epoch 21/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4860 - accuracy: 0.7480 - val_loss: 0.4762 - val_accuracy: 0.7540
# Epoch 22/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4838 - accuracy: 0.7484 - val_loss: 0.4735 - val_accuracy: 0.7537
# Epoch 23/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4598 - accuracy: 0.7577 - val_loss: 0.4549 - val_accuracy: 0.7608
# Epoch 43/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4595 - accuracy: 0.7582 - val_loss: 0.4497 - val_accuracy: 0.7632
# Epoch 44/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4590 - accuracy: 0.7585 - val_loss: 0.4522 - val_accuracy: 0.7634
# Epoch 45/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4585 - accuracy: 0.7589 - val_loss: 0.4547 - val_accuracy: 0.7628
# Epoch 46/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4579 - accuracy: 0.7593 - val_loss: 0.4560 - val_accuracy: 0.7628
# Epoch 47/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4575 - accuracy: 0.7597 - val_loss: 0.4495 - val_accuracy: 0.7652
# Epoch 48/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4572 - accuracy: 0.7600 - val_loss: 0.4530 - val_accuracy: 0.7653
# Epoch 49/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4567 - accuracy: 0.7606 - val_loss: 0.4522 - val_accuracy: 0.7627
# Epoch 50/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4563 - accuracy: 0.7611 - val_loss: 0.4488 - val_accuracy: 0.7659
# Epoch 51/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4558 - accuracy: 0.7616 - val_loss: 0.4481 - val_accuracy: 0.7653
# Epoch 52/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4554 - accuracy: 0.7614 - val_loss: 0.4479 - val_accuracy: 0.7656
# Epoch 53/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4549 - accuracy: 0.7621 - val_loss: 0.4456 - val_accuracy: 0.7669
# Epoch 54/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4545 - accuracy: 0.7626 - val_loss: 0.4448 - val_accuracy: 0.7675
# Epoch 55/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4539 - accuracy: 0.7628 - val_loss: 0.4448 - val_accuracy: 0.7677
# Epoch 56/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4536 - accuracy: 0.7632 - val_loss: 0.4439 - val_accuracy: 0.7681
# Epoch 57/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4533 - accuracy: 0.7634 - val_loss: 0.4439 - val_accuracy: 0.7676
# Epoch 58/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.4528 - accuracy: 0.7638 - val_loss: 0.4452 - val_accuracy: 0.7689
# Epoch 59/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.4524 - accuracy: 0.7641 - val_loss: 0.4454 - val_accuracy: 0.7672
# Epoch 60/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.4520 - accuracy: 0.7646 - val_loss: 0.4459 - val_accuracy: 0.7683
# Epoch 61/140
# Epoch 81/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4448 - accuracy: 0.7697 - val_loss: 0.4376 - val_accuracy: 0.7749
# Epoch 82/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4445 - accuracy: 0.7699 - val_loss: 0.4395 - val_accuracy: 0.7743
# Epoch 83/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4444 - accuracy: 0.7698 - val_loss: 0.4393 - val_accuracy: 0.7747
# Epoch 84/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4441 - accuracy: 0.7702 - val_loss: 0.4423 - val_accuracy: 0.7748
# Epoch 85/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4440 - accuracy: 0.7703 - val_loss: 0.4394 - val_accuracy: 0.7734
# Epoch 86/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4437 - accuracy: 0.7707 - val_loss: 0.4384 - val_accuracy: 0.7736
# Epoch 87/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4434 - accuracy: 0.7706 - val_loss: 0.4387 - val_accuracy: 0.7751
# Epoch 88/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4432 - accuracy: 0.7710 - val_loss: 0.4394 - val_accuracy: 0.7753
# Epoch 89/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4430 - accuracy: 0.7712 - val_loss: 0.4358 - val_accuracy: 0.7750
# Epoch 90/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4427 - accuracy: 0.7711 - val_loss: 0.4351 - val_accuracy: 0.7756
# Epoch 91/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4426 - accuracy: 0.7718 - val_loss: 0.4401 - val_accuracy: 0.7736
# Epoch 92/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.4423 - accuracy: 0.7717 - val_loss: 0.4355 - val_accuracy: 0.7754
# Epoch 93/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4420 - accuracy: 0.7718 - val_loss: 0.4353 - val_accuracy: 0.7753
# Epoch 94/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4419 - accuracy: 0.7723 - val_loss: 0.4374 - val_accuracy: 0.7752
# Epoch 95/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4417 - accuracy: 0.7723 - val_loss: 0.4388 - val_accuracy: 0.7758
# Epoch 96/140
# 1632/1632 [==============================] - 32s 20ms/step - loss: 0.4413 - accuracy: 0.7727 - val_loss: 0.4373 - val_accuracy: 0.7757
# Epoch 97/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4411 - accuracy: 0.7731 - val_loss: 0.4347 - val_accuracy: 0.7750
# Epoch 98/140
# 1632/1632 [==============================] - 30s 19ms/step - loss: 0.4408 - accuracy: 0.7728 - val_loss: 0.4359 - val_accuracy: 0.7760
# Epoch 99/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.4408 - accuracy: 0.7731 - val_loss: 0.4350 - val_accuracy: 0.7755
# Epoch 100/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4403 - accuracy: 0.7731 - val_loss: 0.4346 - val_accuracy: 0.7753
# Epoch 101/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.4399 - accuracy: 0.7733 - val_loss: 0.4362 - val_accuracy: 0.7745
# Epoch 102/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4396 - accuracy: 0.7736 - val_loss: 0.4337 - val_accuracy: 0.7766
# Epoch 103/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.4393 - accuracy: 0.7743 - val_loss: 0.4331 - val_accuracy: 0.7763
# Epoch 104/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4388 - accuracy: 0.7744 - val_loss: 0.4326 - val_accuracy: 0.7772
# Epoch 105/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4382 - accuracy: 0.7746 - val_loss: 0.4337 - val_accuracy: 0.7760
# Epoch 106/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4381 - accuracy: 0.7753 - val_loss: 0.4339 - val_accuracy: 0.7768
# Epoch 107/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4377 - accuracy: 0.7752 - val_loss: 0.4320 - val_accuracy: 0.7782
# Epoch 108/140
# 1632/1632 [==============================] - 30s 18ms/step - loss: 0.4374 - accuracy: 0.7755 - val_loss: 0.4322 - val_accuracy: 0.7771
# Epoch 109/140
# 1632/1632 [==============================] - 33s 20ms/step - loss: 0.4372 - accuracy: 0.7756 - val_loss: 0.4327 - val_accuracy: 0.7772
# Epoch 110/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4370 - accuracy: 0.7756 - val_loss: 0.4326 - val_accuracy: 0.7779
# Epoch 111/140
# 1632/1632 [==============================] - 27s 16ms/step - loss: 0.4369 - accuracy: 0.7759 - val_loss: 0.4353 - val_accuracy: 0.7773
# Epoch 112/140
# 1632/1632 [==============================] - 27s 16ms/step - loss: 0.4365 - accuracy: 0.7761 - val_loss: 0.4331 - val_accuracy: 0.7768
# Epoch 113/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4363 - accuracy: 0.7759 - val_loss: 0.4352 - val_accuracy: 0.7776
# Epoch 114/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4361 - accuracy: 0.7764 - val_loss: 0.4335 - val_accuracy: 0.7760
# Epoch 115/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4359 - accuracy: 0.7762 - val_loss: 0.4309 - val_accuracy: 0.7786
# Epoch 116/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4357 - accuracy: 0.7761 - val_loss: 0.4295 - val_accuracy: 0.7788
# Epoch 117/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4356 - accuracy: 0.7762 - val_loss: 0.4287 - val_accuracy: 0.7794
# Epoch 118/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4353 - accuracy: 0.7764 - val_loss: 0.4318 - val_accuracy: 0.7786
# Epoch 119/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4353 - accuracy: 0.7767 - val_loss: 0.4321 - val_accuracy: 0.7783
# Epoch 120/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4349 - accuracy: 0.7766 - val_loss: 0.4336 - val_accuracy: 0.7774
# Epoch 121/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4348 - accuracy: 0.7767 - val_loss: 0.4323 - val_accuracy: 0.7782
# Epoch 122/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4348 - accuracy: 0.7767 - val_loss: 0.4299 - val_accuracy: 0.7791
# Epoch 123/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4347 - accuracy: 0.7771 - val_loss: 0.4300 - val_accuracy: 0.7784
# Epoch 124/140
# 1632/1632 [==============================] - 27s 16ms/step - loss: 0.4344 - accuracy: 0.7766 - val_loss: 0.4299 - val_accuracy: 0.7792
# Epoch 125/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4343 - accuracy: 0.7772 - val_loss: 0.4352 - val_accuracy: 0.7790
# Epoch 126/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4343 - accuracy: 0.7772 - val_loss: 0.4298 - val_accuracy: 0.7798
# Epoch 127/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4339 - accuracy: 0.7773 - val_loss: 0.4284 - val_accuracy: 0.7786
# Epoch 128/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4338 - accuracy: 0.7775 - val_loss: 0.4285 - val_accuracy: 0.7796
# Epoch 129/140
# 1632/1632 [==============================] - 27s 16ms/step - loss: 0.4337 - accuracy: 0.7770 - val_loss: 0.4349 - val_accuracy: 0.7789
# Epoch 130/140
# 1632/1632 [==============================] - 27s 17ms/step - loss: 0.4336 - accuracy: 0.7775 - val_loss: 0.4309 - val_accuracy: 0.7795
# Epoch 131/140
# 1632/1632 [==============================] - 31s 19ms/step - loss: 0.4334 - accuracy: 0.7779 - val_loss: 0.4309 - val_accuracy: 0.7792
# Epoch 132/140
# 1632/1632 [==============================] - 30s 18ms/step - loss: 0.4334 - accuracy: 0.7775 - val_loss: 0.4295 - val_accuracy: 0.7798
# Epoch 133/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4333 - accuracy: 0.7775 - val_loss: 0.4283 - val_accuracy: 0.7799
# Epoch 134/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4331 - accuracy: 0.7777 - val_loss: 0.4308 - val_accuracy: 0.7807
# Epoch 135/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4330 - accuracy: 0.7774 - val_loss: 0.4300 - val_accuracy: 0.7796
# Epoch 136/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4330 - accuracy: 0.7777 - val_loss: 0.4317 - val_accuracy: 0.7802
# Epoch 137/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.4328 - accuracy: 0.7778 - val_loss: 0.4286 - val_accuracy: 0.7806
# Epoch 138/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4325 - accuracy: 0.7777 - val_loss: 0.4284 - val_accuracy: 0.7808
# Epoch 139/140
# 1632/1632 [==============================] - 29s 18ms/step - loss: 0.4324 - accuracy: 0.7778 - val_loss: 0.4310 - val_accuracy: 0.7800
# Epoch 140/140
# 1632/1632 [==============================] - 28s 17ms/step - loss: 0.4323 - accuracy: 0.7779 - val_loss: 0.4302 - val_accuracy: 0.7813

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 19s 6ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 3962.0488851070404

# %%
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00193887],
#        [0.00244919],
#        [0.00132181],
#        ...,
#        [0.04843212],
#        [0.04783053],
#        [0.04810295]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14392288565464856
# 0.22607163115386153
# 0.3793716985420085
# 0.2849100106431138

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 90s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.60484499]
# [0.81599083]
# total acc [0.77889468]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
print("204 to podzielnik 380256")
# Out:
# 204 to podzielnik 380256
