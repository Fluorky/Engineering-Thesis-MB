# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x231c0e44040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x23234ef2040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0004)
model_gru.compile(loss='BinaryCrossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=160,validation_data=(test_X, test_y),batch_size=4096)#, shuffle=False)
# Out:
# Epoch 1/160
# 93/93 [==============================] - 13s 67ms/step - loss: 0.5328 - accuracy: 0.7378 - val_loss: 0.4896 - val_accuracy: 0.7525
# Epoch 2/160
# 93/93 [==============================] - 5s 56ms/step - loss: 0.4985 - accuracy: 0.7398 - val_loss: 0.4787 - val_accuracy: 0.7524
# Epoch 3/160
# 93/93 [==============================] - 5s 56ms/step - loss: 0.4856 - accuracy: 0.7479 - val_loss: 0.4684 - val_accuracy: 0.7564
# Epoch 4/160
# 93/93 [==============================] - 5s 56ms/step - loss: 0.4700 - accuracy: 0.7558 - val_loss: 0.4572 - val_accuracy: 0.7630
# Epoch 5/160
# 93/93 [==============================] - 5s 56ms/step - loss: 0.4627 - accuracy: 0.7592 - val_loss: 0.4538 - val_accuracy: 0.7653
# Epoch 6/160
# 93/93 [==============================] - 5s 52ms/step - loss: 0.4602 - accuracy: 0.7611 - val_loss: 0.4529 - val_accuracy: 0.7655
# Epoch 7/160
# 93/93 [==============================] - 4s 47ms/step - loss: 0.4564 - accuracy: 0.7627 - val_loss: 0.4472 - val_accuracy: 0.7666
# Epoch 8/160
# 93/93 [==============================] - 5s 49ms/step - loss: 0.4540 - accuracy: 0.7633 - val_loss: 0.4446 - val_accuracy: 0.7679
# Epoch 9/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4517 - accuracy: 0.7646 - val_loss: 0.4433 - val_accuracy: 0.7684
# Epoch 10/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4501 - accuracy: 0.7656 - val_loss: 0.4436 - val_accuracy: 0.7703
# Epoch 11/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4488 - accuracy: 0.7663 - val_loss: 0.4478 - val_accuracy: 0.7721
# Epoch 12/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4481 - accuracy: 0.7669 - val_loss: 0.4398 - val_accuracy: 0.7717
# Epoch 13/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4474 - accuracy: 0.7679 - val_loss: 0.4398 - val_accuracy: 0.7741
# Epoch 14/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4451 - accuracy: 0.7688 - val_loss: 0.4391 - val_accuracy: 0.7743
# Epoch 15/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4443 - accuracy: 0.7697 - val_loss: 0.4368 - val_accuracy: 0.7751
# Epoch 16/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4437 - accuracy: 0.7703 - val_loss: 0.4380 - val_accuracy: 0.7743
# Epoch 17/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4429 - accuracy: 0.7713 - val_loss: 0.4417 - val_accuracy: 0.7758
# Epoch 18/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4428 - accuracy: 0.7719 - val_loss: 0.4362 - val_accuracy: 0.7774
# Epoch 19/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4419 - accuracy: 0.7724 - val_loss: 0.4360 - val_accuracy: 0.7765
# Epoch 20/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4402 - accuracy: 0.7733 - val_loss: 0.4400 - val_accuracy: 0.7741
# Epoch 21/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4399 - accuracy: 0.7740 - val_loss: 0.4350 - val_accuracy: 0.7775
# Epoch 22/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4386 - accuracy: 0.7749 - val_loss: 0.4375 - val_accuracy: 0.7784
# Epoch 23/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4376 - accuracy: 0.7754 - val_loss: 0.4362 - val_accuracy: 0.7792
# Epoch 24/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4377 - accuracy: 0.7756 - val_loss: 0.4384 - val_accuracy: 0.7791
# Epoch 25/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4367 - accuracy: 0.7762 - val_loss: 0.4341 - val_accuracy: 0.7784
# Epoch 26/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4360 - accuracy: 0.7763 - val_loss: 0.4333 - val_accuracy: 0.7789
# Epoch 27/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4362 - accuracy: 0.7760 - val_loss: 0.4335 - val_accuracy: 0.7801
# Epoch 28/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4354 - accuracy: 0.7764 - val_loss: 0.4354 - val_accuracy: 0.7788
# Epoch 29/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4357 - accuracy: 0.7767 - val_loss: 0.4327 - val_accuracy: 0.7797
# Epoch 30/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4344 - accuracy: 0.7774 - val_loss: 0.4315 - val_accuracy: 0.7807
# Epoch 31/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4345 - accuracy: 0.7771 - val_loss: 0.4324 - val_accuracy: 0.7791
# Epoch 32/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4337 - accuracy: 0.7776 - val_loss: 0.4305 - val_accuracy: 0.7798
# Epoch 33/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4331 - accuracy: 0.7777 - val_loss: 0.4306 - val_accuracy: 0.7798
# Epoch 34/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4334 - accuracy: 0.7780 - val_loss: 0.4319 - val_accuracy: 0.7801
# Epoch 35/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4324 - accuracy: 0.7785 - val_loss: 0.4326 - val_accuracy: 0.7793
# Epoch 36/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4325 - accuracy: 0.7779 - val_loss: 0.4317 - val_accuracy: 0.7802
# Epoch 37/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4322 - accuracy: 0.7783 - val_loss: 0.4297 - val_accuracy: 0.7801
# Epoch 38/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4315 - accuracy: 0.7786 - val_loss: 0.4293 - val_accuracy: 0.7805
# Epoch 39/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4309 - accuracy: 0.7792 - val_loss: 0.4323 - val_accuracy: 0.7799
# Epoch 40/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4304 - accuracy: 0.7791 - val_loss: 0.4287 - val_accuracy: 0.7808
# Epoch 41/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4298 - accuracy: 0.7796 - val_loss: 0.4296 - val_accuracy: 0.7807
# Epoch 42/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4290 - accuracy: 0.7798 - val_loss: 0.4361 - val_accuracy: 0.7810
# Epoch 43/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4296 - accuracy: 0.7794 - val_loss: 0.4340 - val_accuracy: 0.7805
# Epoch 44/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4293 - accuracy: 0.7799 - val_loss: 0.4272 - val_accuracy: 0.7818
# Epoch 45/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4299 - accuracy: 0.7800 - val_loss: 0.4281 - val_accuracy: 0.7815
# Epoch 46/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4282 - accuracy: 0.7808 - val_loss: 0.4260 - val_accuracy: 0.7827
# Epoch 47/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4278 - accuracy: 0.7807 - val_loss: 0.4285 - val_accuracy: 0.7830
# Epoch 48/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4271 - accuracy: 0.7810 - val_loss: 0.4324 - val_accuracy: 0.7824
# Epoch 49/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4270 - accuracy: 0.7810 - val_loss: 0.4350 - val_accuracy: 0.7821
# Epoch 50/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4265 - accuracy: 0.7815 - val_loss: 0.4295 - val_accuracy: 0.7826
# Epoch 51/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4260 - accuracy: 0.7816 - val_loss: 0.4268 - val_accuracy: 0.7832
# Epoch 52/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4257 - accuracy: 0.7818 - val_loss: 0.4286 - val_accuracy: 0.7827
# Epoch 53/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4258 - accuracy: 0.7820 - val_loss: 0.4287 - val_accuracy: 0.7823
# Epoch 54/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4247 - accuracy: 0.7826 - val_loss: 0.4265 - val_accuracy: 0.7829
# Epoch 55/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4253 - accuracy: 0.7823 - val_loss: 0.4258 - val_accuracy: 0.7842
# Epoch 56/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4244 - accuracy: 0.7828 - val_loss: 0.4292 - val_accuracy: 0.7839
# Epoch 57/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4238 - accuracy: 0.7833 - val_loss: 0.4263 - val_accuracy: 0.7837
# Epoch 58/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4243 - accuracy: 0.7827 - val_loss: 0.4295 - val_accuracy: 0.7817
# Epoch 59/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4232 - accuracy: 0.7831 - val_loss: 0.4276 - val_accuracy: 0.7826
# Epoch 60/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4235 - accuracy: 0.7833 - val_loss: 0.4275 - val_accuracy: 0.7817
# Epoch 61/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4229 - accuracy: 0.7835 - val_loss: 0.4276 - val_accuracy: 0.7800
# Epoch 62/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4221 - accuracy: 0.7837 - val_loss: 0.4255 - val_accuracy: 0.7840
# Epoch 63/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4224 - accuracy: 0.7837 - val_loss: 0.4263 - val_accuracy: 0.7843
# Epoch 64/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4223 - accuracy: 0.7840 - val_loss: 0.4256 - val_accuracy: 0.7839
# Epoch 65/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4221 - accuracy: 0.7840 - val_loss: 0.4258 - val_accuracy: 0.7838
# Epoch 66/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4225 - accuracy: 0.7840 - val_loss: 0.4339 - val_accuracy: 0.7835
# Epoch 67/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4221 - accuracy: 0.7844 - val_loss: 0.4339 - val_accuracy: 0.7825
# Epoch 68/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4211 - accuracy: 0.7843 - val_loss: 0.4252 - val_accuracy: 0.7837
# Epoch 69/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4206 - accuracy: 0.7847 - val_loss: 0.4297 - val_accuracy: 0.7825
# Epoch 70/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4213 - accuracy: 0.7848 - val_loss: 0.4250 - val_accuracy: 0.7843
# Epoch 71/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4199 - accuracy: 0.7852 - val_loss: 0.4255 - val_accuracy: 0.7842
# Epoch 72/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4198 - accuracy: 0.7848 - val_loss: 0.4269 - val_accuracy: 0.7823
# Epoch 73/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4201 - accuracy: 0.7850 - val_loss: 0.4260 - val_accuracy: 0.7831
# Epoch 74/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4198 - accuracy: 0.7851 - val_loss: 0.4253 - val_accuracy: 0.7851
# Epoch 75/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4194 - accuracy: 0.7850 - val_loss: 0.4283 - val_accuracy: 0.7829
# Epoch 76/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4192 - accuracy: 0.7850 - val_loss: 0.4259 - val_accuracy: 0.7832
# Epoch 77/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4189 - accuracy: 0.7854 - val_loss: 0.4252 - val_accuracy: 0.7823
# Epoch 78/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4195 - accuracy: 0.7854 - val_loss: 0.4279 - val_accuracy: 0.7837
# Epoch 79/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4187 - accuracy: 0.7858 - val_loss: 0.4259 - val_accuracy: 0.7842
# Epoch 80/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4186 - accuracy: 0.7857 - val_loss: 0.4279 - val_accuracy: 0.7786
# Epoch 81/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4184 - accuracy: 0.7858 - val_loss: 0.4226 - val_accuracy: 0.7849
# Epoch 82/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4179 - accuracy: 0.7858 - val_loss: 0.4270 - val_accuracy: 0.7837
# Epoch 83/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4183 - accuracy: 0.7855 - val_loss: 0.4263 - val_accuracy: 0.7819
# Epoch 84/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4177 - accuracy: 0.7860 - val_loss: 0.4283 - val_accuracy: 0.7843
# Epoch 85/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4181 - accuracy: 0.7859 - val_loss: 0.4253 - val_accuracy: 0.7843
# Epoch 86/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4170 - accuracy: 0.7864 - val_loss: 0.4330 - val_accuracy: 0.7829
# Epoch 87/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4170 - accuracy: 0.7862 - val_loss: 0.4298 - val_accuracy: 0.7835
# Epoch 88/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4169 - accuracy: 0.7863 - val_loss: 0.4260 - val_accuracy: 0.7832
# Epoch 89/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4170 - accuracy: 0.7864 - val_loss: 0.4272 - val_accuracy: 0.7826
# Epoch 90/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4163 - accuracy: 0.7865 - val_loss: 0.4251 - val_accuracy: 0.7847
# Epoch 91/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4165 - accuracy: 0.7865 - val_loss: 0.4265 - val_accuracy: 0.7805
# Epoch 92/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4174 - accuracy: 0.7865 - val_loss: 0.4252 - val_accuracy: 0.7853
# Epoch 93/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4157 - accuracy: 0.7869 - val_loss: 0.4265 - val_accuracy: 0.7806
# Epoch 94/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4156 - accuracy: 0.7867 - val_loss: 0.4256 - val_accuracy: 0.7833
# Epoch 95/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4166 - accuracy: 0.7868 - val_loss: 0.4262 - val_accuracy: 0.7839
# Epoch 96/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4154 - accuracy: 0.7865 - val_loss: 0.4313 - val_accuracy: 0.7832
# Epoch 97/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4148 - accuracy: 0.7873 - val_loss: 0.4264 - val_accuracy: 0.7797
# Epoch 98/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4151 - accuracy: 0.7872 - val_loss: 0.4284 - val_accuracy: 0.7774
# Epoch 99/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4153 - accuracy: 0.7873 - val_loss: 0.4250 - val_accuracy: 0.7830
# Epoch 100/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4154 - accuracy: 0.7875 - val_loss: 0.4236 - val_accuracy: 0.7845
# Epoch 101/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4149 - accuracy: 0.7875 - val_loss: 0.4321 - val_accuracy: 0.7830
# Epoch 102/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4142 - accuracy: 0.7877 - val_loss: 0.4239 - val_accuracy: 0.7832
# Epoch 103/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4143 - accuracy: 0.7874 - val_loss: 0.4259 - val_accuracy: 0.7836
# Epoch 104/160
# 93/93 [==============================] - 4s 47ms/step - loss: 0.4138 - accuracy: 0.7877 - val_loss: 0.4291 - val_accuracy: 0.7840
# Epoch 105/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4139 - accuracy: 0.7878 - val_loss: 0.4260 - val_accuracy: 0.7851
# Epoch 106/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4138 - accuracy: 0.7876 - val_loss: 0.4261 - val_accuracy: 0.7847
# Epoch 107/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4132 - accuracy: 0.7882 - val_loss: 0.4237 - val_accuracy: 0.7840
# Epoch 108/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4128 - accuracy: 0.7883 - val_loss: 0.4259 - val_accuracy: 0.7808
# Epoch 109/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4135 - accuracy: 0.7880 - val_loss: 0.4267 - val_accuracy: 0.7839
# Epoch 110/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4128 - accuracy: 0.7886 - val_loss: 0.4261 - val_accuracy: 0.7819
# Epoch 111/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4129 - accuracy: 0.7880 - val_loss: 0.4292 - val_accuracy: 0.7830
# Epoch 112/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4125 - accuracy: 0.7886 - val_loss: 0.4264 - val_accuracy: 0.7826
# Epoch 113/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4127 - accuracy: 0.7880 - val_loss: 0.4249 - val_accuracy: 0.7843
# Epoch 114/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4128 - accuracy: 0.7887 - val_loss: 0.4244 - val_accuracy: 0.7835
# Epoch 115/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4118 - accuracy: 0.7885 - val_loss: 0.4259 - val_accuracy: 0.7833
# Epoch 116/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4116 - accuracy: 0.7889 - val_loss: 0.4270 - val_accuracy: 0.7834
# Epoch 117/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4116 - accuracy: 0.7889 - val_loss: 0.4259 - val_accuracy: 0.7839
# Epoch 118/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4111 - accuracy: 0.7889 - val_loss: 0.4289 - val_accuracy: 0.7839
# Epoch 119/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4109 - accuracy: 0.7890 - val_loss: 0.4291 - val_accuracy: 0.7843
# Epoch 120/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4116 - accuracy: 0.7890 - val_loss: 0.4328 - val_accuracy: 0.7850
# Epoch 121/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4115 - accuracy: 0.7888 - val_loss: 0.4262 - val_accuracy: 0.7797
# Epoch 122/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4106 - accuracy: 0.7893 - val_loss: 0.4249 - val_accuracy: 0.7816
# Epoch 123/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4106 - accuracy: 0.7895 - val_loss: 0.4254 - val_accuracy: 0.7838
# Epoch 124/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4101 - accuracy: 0.7896 - val_loss: 0.4256 - val_accuracy: 0.7842
# Epoch 125/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4103 - accuracy: 0.7895 - val_loss: 0.4265 - val_accuracy: 0.7841
# Epoch 126/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4098 - accuracy: 0.7898 - val_loss: 0.4280 - val_accuracy: 0.7833
# Epoch 127/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4103 - accuracy: 0.7895 - val_loss: 0.4287 - val_accuracy: 0.7837
# Epoch 128/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4098 - accuracy: 0.7900 - val_loss: 0.4242 - val_accuracy: 0.7840
# Epoch 129/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4099 - accuracy: 0.7896 - val_loss: 0.4271 - val_accuracy: 0.7823
# Epoch 130/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4094 - accuracy: 0.7897 - val_loss: 0.4280 - val_accuracy: 0.7853
# Epoch 131/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4089 - accuracy: 0.7898 - val_loss: 0.4264 - val_accuracy: 0.7859
# Epoch 132/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4086 - accuracy: 0.7902 - val_loss: 0.4248 - val_accuracy: 0.7829
# Epoch 133/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4082 - accuracy: 0.7901 - val_loss: 0.4253 - val_accuracy: 0.7839
# Epoch 134/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4086 - accuracy: 0.7904 - val_loss: 0.4275 - val_accuracy: 0.7791
# Epoch 135/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4088 - accuracy: 0.7900 - val_loss: 0.4294 - val_accuracy: 0.7843
# Epoch 136/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4083 - accuracy: 0.7904 - val_loss: 0.4306 - val_accuracy: 0.7829
# Epoch 137/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4082 - accuracy: 0.7904 - val_loss: 0.4275 - val_accuracy: 0.7837
# Epoch 138/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4081 - accuracy: 0.7904 - val_loss: 0.4261 - val_accuracy: 0.7859
# Epoch 139/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4076 - accuracy: 0.7904 - val_loss: 0.4263 - val_accuracy: 0.7829
# Epoch 140/160
# 93/93 [==============================] - 4s 47ms/step - loss: 0.4077 - accuracy: 0.7908 - val_loss: 0.4286 - val_accuracy: 0.7846
# Epoch 141/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4077 - accuracy: 0.7907 - val_loss: 0.4273 - val_accuracy: 0.7817
# Epoch 142/160
# 93/93 [==============================] - 4s 47ms/step - loss: 0.4071 - accuracy: 0.7911 - val_loss: 0.4299 - val_accuracy: 0.7836
# Epoch 143/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4069 - accuracy: 0.7909 - val_loss: 0.4259 - val_accuracy: 0.7862
# Epoch 144/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4063 - accuracy: 0.7910 - val_loss: 0.4290 - val_accuracy: 0.7859
# Epoch 145/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4067 - accuracy: 0.7911 - val_loss: 0.4284 - val_accuracy: 0.7826
# Epoch 146/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4064 - accuracy: 0.7911 - val_loss: 0.4310 - val_accuracy: 0.7803
# Epoch 147/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4067 - accuracy: 0.7909 - val_loss: 0.4320 - val_accuracy: 0.7838
# Epoch 148/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4066 - accuracy: 0.7918 - val_loss: 0.4264 - val_accuracy: 0.7836
# Epoch 149/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4064 - accuracy: 0.7911 - val_loss: 0.4288 - val_accuracy: 0.7861
# Epoch 150/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4056 - accuracy: 0.7914 - val_loss: 0.4293 - val_accuracy: 0.7830
# Epoch 151/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4056 - accuracy: 0.7917 - val_loss: 0.4279 - val_accuracy: 0.7821
# Epoch 152/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4053 - accuracy: 0.7920 - val_loss: 0.4292 - val_accuracy: 0.7821
# Epoch 153/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4054 - accuracy: 0.7915 - val_loss: 0.4246 - val_accuracy: 0.7842
# Epoch 154/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4048 - accuracy: 0.7920 - val_loss: 0.4294 - val_accuracy: 0.7826
# Epoch 155/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4048 - accuracy: 0.7919 - val_loss: 0.4291 - val_accuracy: 0.7837
# Epoch 156/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4043 - accuracy: 0.7918 - val_loss: 0.4406 - val_accuracy: 0.7848
# Epoch 157/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4044 - accuracy: 0.7921 - val_loss: 0.4313 - val_accuracy: 0.7766
# Epoch 158/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4052 - accuracy: 0.7917 - val_loss: 0.4290 - val_accuracy: 0.7837
# Epoch 159/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4044 - accuracy: 0.7922 - val_loss: 0.4300 - val_accuracy: 0.7807
# Epoch 160/160
# 93/93 [==============================] - 4s 48ms/step - loss: 0.4048 - accuracy: 0.7922 - val_loss: 0.4301 - val_accuracy: 0.7833

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 19s 6ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 746.7038021087646

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00020335],
#        [0.00039219],
#        [0.00012453],
#        ...,
#        [0.07564352],
#        [0.07722028],
#        [0.08135541]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14295372018545147
# 0.23130494229988596
# 0.37809221122029407
# 0.27599801559645554

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 90s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.62260185]
# [0.83216222]
# total acc [0.79063549]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 2023314432}
