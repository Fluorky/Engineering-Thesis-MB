# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x14c2258d040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x14c96644040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=64,return_sequences=True),
    keras.layers.GRU(units=32),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam()
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 128)           55680
#
#  gru_1 (GRU)                 (None, 32, 64)            37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=32768)#, shuffle=False)
# Out:
# Epoch 1/140
# 12/12 [==============================] - 12s 425ms/step - loss: 0.6362 - accuracy: 0.6360 - val_loss: 0.5590 - val_accuracy: 0.7530
# Epoch 2/140
# 12/12 [==============================] - 4s 310ms/step - loss: 0.5776 - accuracy: 0.7393 - val_loss: 0.5593 - val_accuracy: 0.7530
# Epoch 3/140
# 12/12 [==============================] - 4s 297ms/step - loss: 0.5742 - accuracy: 0.7393 - val_loss: 0.5616 - val_accuracy: 0.7530
# Epoch 4/140
# 12/12 [==============================] - 4s 298ms/step - loss: 0.5740 - accuracy: 0.7393 - val_loss: 0.5591 - val_accuracy: 0.7530
# Epoch 5/140
# 12/12 [==============================] - 4s 301ms/step - loss: 0.5738 - accuracy: 0.7393 - val_loss: 0.5595 - val_accuracy: 0.7530
# Epoch 6/140
# 12/12 [==============================] - 4s 300ms/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5594 - val_accuracy: 0.7530
# Epoch 7/140
# 12/12 [==============================] - 4s 294ms/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5593 - val_accuracy: 0.7530
# Epoch 8/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.5734 - accuracy: 0.7393 - val_loss: 0.5589 - val_accuracy: 0.7530
# Epoch 9/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.5726 - accuracy: 0.7393 - val_loss: 0.5573 - val_accuracy: 0.7530
# Epoch 10/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.5672 - accuracy: 0.7393 - val_loss: 0.5466 - val_accuracy: 0.7530
# Epoch 11/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.5548 - accuracy: 0.7393 - val_loss: 0.5367 - val_accuracy: 0.7530
# Epoch 12/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.5412 - accuracy: 0.7393 - val_loss: 0.5203 - val_accuracy: 0.7530
# Epoch 13/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.5261 - accuracy: 0.7393 - val_loss: 0.5043 - val_accuracy: 0.7530
# Epoch 14/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.5117 - accuracy: 0.7385 - val_loss: 0.5084 - val_accuracy: 0.7476
# Epoch 15/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.5076 - accuracy: 0.7378 - val_loss: 0.4885 - val_accuracy: 0.7536
# Epoch 16/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.5016 - accuracy: 0.7386 - val_loss: 0.4863 - val_accuracy: 0.7534
# Epoch 17/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4982 - accuracy: 0.7383 - val_loss: 0.4839 - val_accuracy: 0.7533
# Epoch 18/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4962 - accuracy: 0.7394 - val_loss: 0.4812 - val_accuracy: 0.7538
# Epoch 19/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4947 - accuracy: 0.7398 - val_loss: 0.4788 - val_accuracy: 0.7544
# Epoch 20/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4938 - accuracy: 0.7407 - val_loss: 0.4791 - val_accuracy: 0.7549
# Epoch 21/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4917 - accuracy: 0.7429 - val_loss: 0.4779 - val_accuracy: 0.7558
# Epoch 22/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4903 - accuracy: 0.7456 - val_loss: 0.4754 - val_accuracy: 0.7557
# Epoch 23/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4885 - accuracy: 0.7473 - val_loss: 0.4742 - val_accuracy: 0.7557
# Epoch 24/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4855 - accuracy: 0.7488 - val_loss: 0.4737 - val_accuracy: 0.7551
# Epoch 25/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4822 - accuracy: 0.7495 - val_loss: 0.4715 - val_accuracy: 0.7530
# Epoch 26/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4785 - accuracy: 0.7507 - val_loss: 0.4671 - val_accuracy: 0.7557
# Epoch 27/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4747 - accuracy: 0.7534 - val_loss: 0.4637 - val_accuracy: 0.7590
# Epoch 28/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4726 - accuracy: 0.7551 - val_loss: 0.4624 - val_accuracy: 0.7616
# Epoch 29/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4698 - accuracy: 0.7565 - val_loss: 0.4589 - val_accuracy: 0.7631
# Epoch 30/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4659 - accuracy: 0.7585 - val_loss: 0.4580 - val_accuracy: 0.7640
# Epoch 31/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4737 - accuracy: 0.7549 - val_loss: 0.4648 - val_accuracy: 0.7643
# Epoch 32/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4681 - accuracy: 0.7566 - val_loss: 0.4553 - val_accuracy: 0.7645
# Epoch 33/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4630 - accuracy: 0.7598 - val_loss: 0.4569 - val_accuracy: 0.7647
# Epoch 34/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4613 - accuracy: 0.7604 - val_loss: 0.4514 - val_accuracy: 0.7655
# Epoch 35/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4633 - accuracy: 0.7604 - val_loss: 0.4625 - val_accuracy: 0.7650
# Epoch 36/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4619 - accuracy: 0.7606 - val_loss: 0.4518 - val_accuracy: 0.7672
# Epoch 37/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4586 - accuracy: 0.7621 - val_loss: 0.4515 - val_accuracy: 0.7658
# Epoch 38/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4571 - accuracy: 0.7627 - val_loss: 0.4491 - val_accuracy: 0.7665
# Epoch 39/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4567 - accuracy: 0.7631 - val_loss: 0.4515 - val_accuracy: 0.7675
# Epoch 40/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4558 - accuracy: 0.7633 - val_loss: 0.4547 - val_accuracy: 0.7654
# Epoch 41/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4573 - accuracy: 0.7633 - val_loss: 0.4511 - val_accuracy: 0.7686
# Epoch 42/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4555 - accuracy: 0.7638 - val_loss: 0.4454 - val_accuracy: 0.7696
# Epoch 43/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4537 - accuracy: 0.7648 - val_loss: 0.4459 - val_accuracy: 0.7697
# Epoch 44/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4526 - accuracy: 0.7653 - val_loss: 0.4456 - val_accuracy: 0.7705
# Epoch 45/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4517 - accuracy: 0.7657 - val_loss: 0.4456 - val_accuracy: 0.7706
# Epoch 46/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4513 - accuracy: 0.7660 - val_loss: 0.4427 - val_accuracy: 0.7718
# Epoch 47/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4511 - accuracy: 0.7659 - val_loss: 0.4457 - val_accuracy: 0.7721
# Epoch 48/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4515 - accuracy: 0.7663 - val_loss: 0.4433 - val_accuracy: 0.7728
# Epoch 49/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4489 - accuracy: 0.7667 - val_loss: 0.4414 - val_accuracy: 0.7731
# Epoch 50/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4504 - accuracy: 0.7671 - val_loss: 0.4410 - val_accuracy: 0.7736
# Epoch 51/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4491 - accuracy: 0.7670 - val_loss: 0.4410 - val_accuracy: 0.7738
# Epoch 52/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4495 - accuracy: 0.7675 - val_loss: 0.4427 - val_accuracy: 0.7718
# Epoch 53/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4493 - accuracy: 0.7674 - val_loss: 0.4419 - val_accuracy: 0.7723
# Epoch 54/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4474 - accuracy: 0.7681 - val_loss: 0.4404 - val_accuracy: 0.7739
# Epoch 55/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4460 - accuracy: 0.7687 - val_loss: 0.4396 - val_accuracy: 0.7751
# Epoch 56/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4489 - accuracy: 0.7682 - val_loss: 0.4402 - val_accuracy: 0.7752
# Epoch 57/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4456 - accuracy: 0.7691 - val_loss: 0.4400 - val_accuracy: 0.7754
# Epoch 58/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4465 - accuracy: 0.7694 - val_loss: 0.4430 - val_accuracy: 0.7742
# Epoch 59/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4459 - accuracy: 0.7695 - val_loss: 0.4394 - val_accuracy: 0.7764
# Epoch 60/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4442 - accuracy: 0.7701 - val_loss: 0.4384 - val_accuracy: 0.7762
# Epoch 61/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4449 - accuracy: 0.7707 - val_loss: 0.4383 - val_accuracy: 0.7760
# Epoch 62/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4439 - accuracy: 0.7707 - val_loss: 0.4452 - val_accuracy: 0.7757
# Epoch 63/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4453 - accuracy: 0.7711 - val_loss: 0.4373 - val_accuracy: 0.7776
# Epoch 64/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4421 - accuracy: 0.7720 - val_loss: 0.4377 - val_accuracy: 0.7764
# Epoch 65/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4435 - accuracy: 0.7722 - val_loss: 0.4373 - val_accuracy: 0.7778
# Epoch 66/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4424 - accuracy: 0.7726 - val_loss: 0.4387 - val_accuracy: 0.7770
# Epoch 67/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4416 - accuracy: 0.7727 - val_loss: 0.4370 - val_accuracy: 0.7771
# Epoch 68/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4411 - accuracy: 0.7736 - val_loss: 0.4354 - val_accuracy: 0.7785
# Epoch 69/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4413 - accuracy: 0.7733 - val_loss: 0.4402 - val_accuracy: 0.7763
# Epoch 70/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4429 - accuracy: 0.7736 - val_loss: 0.4347 - val_accuracy: 0.7786
# Epoch 71/140
# 12/12 [==============================] - 3s 287ms/step - loss: 0.4404 - accuracy: 0.7747 - val_loss: 0.4385 - val_accuracy: 0.7765
# Epoch 72/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4397 - accuracy: 0.7749 - val_loss: 0.4348 - val_accuracy: 0.7787
# Epoch 73/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4385 - accuracy: 0.7753 - val_loss: 0.4340 - val_accuracy: 0.7786
# Epoch 74/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4408 - accuracy: 0.7749 - val_loss: 0.4370 - val_accuracy: 0.7781
# Epoch 75/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4388 - accuracy: 0.7754 - val_loss: 0.4395 - val_accuracy: 0.7785
# Epoch 76/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4393 - accuracy: 0.7755 - val_loss: 0.4330 - val_accuracy: 0.7793
# Epoch 77/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4387 - accuracy: 0.7760 - val_loss: 0.4329 - val_accuracy: 0.7783
# Epoch 78/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4374 - accuracy: 0.7763 - val_loss: 0.4340 - val_accuracy: 0.7786
# Epoch 79/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4366 - accuracy: 0.7766 - val_loss: 0.4384 - val_accuracy: 0.7785
# Epoch 80/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4379 - accuracy: 0.7768 - val_loss: 0.4357 - val_accuracy: 0.7778
# Epoch 81/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4370 - accuracy: 0.7768 - val_loss: 0.4322 - val_accuracy: 0.7783
# Epoch 82/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4356 - accuracy: 0.7771 - val_loss: 0.4372 - val_accuracy: 0.7792
# Epoch 83/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4357 - accuracy: 0.7770 - val_loss: 0.4343 - val_accuracy: 0.7772
# Epoch 84/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4363 - accuracy: 0.7768 - val_loss: 0.4336 - val_accuracy: 0.7801
# Epoch 85/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4358 - accuracy: 0.7771 - val_loss: 0.4337 - val_accuracy: 0.7778
# Epoch 86/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4351 - accuracy: 0.7774 - val_loss: 0.4329 - val_accuracy: 0.7783
# Epoch 87/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4345 - accuracy: 0.7775 - val_loss: 0.4393 - val_accuracy: 0.7781
# Epoch 88/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4377 - accuracy: 0.7765 - val_loss: 0.4442 - val_accuracy: 0.7795
# Epoch 89/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4388 - accuracy: 0.7772 - val_loss: 0.4340 - val_accuracy: 0.7781
# Epoch 90/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4355 - accuracy: 0.7776 - val_loss: 0.4322 - val_accuracy: 0.7788
# Epoch 91/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4339 - accuracy: 0.7779 - val_loss: 0.4304 - val_accuracy: 0.7804
# Epoch 92/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4338 - accuracy: 0.7779 - val_loss: 0.4326 - val_accuracy: 0.7783
# Epoch 93/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4344 - accuracy: 0.7781 - val_loss: 0.4316 - val_accuracy: 0.7810
# Epoch 94/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4344 - accuracy: 0.7781 - val_loss: 0.4317 - val_accuracy: 0.7789
# Epoch 95/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4348 - accuracy: 0.7777 - val_loss: 0.4330 - val_accuracy: 0.7775
# Epoch 96/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4330 - accuracy: 0.7784 - val_loss: 0.4308 - val_accuracy: 0.7807
# Epoch 97/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4334 - accuracy: 0.7783 - val_loss: 0.4345 - val_accuracy: 0.7802
# Epoch 98/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4337 - accuracy: 0.7782 - val_loss: 0.4404 - val_accuracy: 0.7803
# Epoch 99/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4338 - accuracy: 0.7783 - val_loss: 0.4327 - val_accuracy: 0.7796
# Epoch 100/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4330 - accuracy: 0.7785 - val_loss: 0.4301 - val_accuracy: 0.7809
# Epoch 101/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4317 - accuracy: 0.7790 - val_loss: 0.4304 - val_accuracy: 0.7802
# Epoch 102/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4313 - accuracy: 0.7791 - val_loss: 0.4292 - val_accuracy: 0.7814
# Epoch 103/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4319 - accuracy: 0.7791 - val_loss: 0.4360 - val_accuracy: 0.7815
# Epoch 104/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4332 - accuracy: 0.7790 - val_loss: 0.4301 - val_accuracy: 0.7817
# Epoch 105/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4307 - accuracy: 0.7796 - val_loss: 0.4281 - val_accuracy: 0.7807
# Epoch 106/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4316 - accuracy: 0.7795 - val_loss: 0.4320 - val_accuracy: 0.7815
# Epoch 107/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4314 - accuracy: 0.7797 - val_loss: 0.4320 - val_accuracy: 0.7798
# Epoch 108/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4311 - accuracy: 0.7797 - val_loss: 0.4297 - val_accuracy: 0.7801
# Epoch 109/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4309 - accuracy: 0.7797 - val_loss: 0.4305 - val_accuracy: 0.7791
# Epoch 110/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4314 - accuracy: 0.7797 - val_loss: 0.4278 - val_accuracy: 0.7817
# Epoch 111/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4306 - accuracy: 0.7799 - val_loss: 0.4368 - val_accuracy: 0.7750
# Epoch 112/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4323 - accuracy: 0.7795 - val_loss: 0.4314 - val_accuracy: 0.7832
# Epoch 113/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4304 - accuracy: 0.7803 - val_loss: 0.4330 - val_accuracy: 0.7781
# Epoch 114/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4306 - accuracy: 0.7806 - val_loss: 0.4283 - val_accuracy: 0.7830
# Epoch 115/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4290 - accuracy: 0.7808 - val_loss: 0.4294 - val_accuracy: 0.7812
# Epoch 116/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4292 - accuracy: 0.7806 - val_loss: 0.4325 - val_accuracy: 0.7830
# Epoch 117/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4298 - accuracy: 0.7807 - val_loss: 0.4324 - val_accuracy: 0.7825
# Epoch 118/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4314 - accuracy: 0.7806 - val_loss: 0.4270 - val_accuracy: 0.7831
# Epoch 119/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4300 - accuracy: 0.7808 - val_loss: 0.4278 - val_accuracy: 0.7837
# Epoch 120/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4289 - accuracy: 0.7810 - val_loss: 0.4261 - val_accuracy: 0.7839
# Epoch 121/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4279 - accuracy: 0.7813 - val_loss: 0.4281 - val_accuracy: 0.7841
# Epoch 122/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4282 - accuracy: 0.7813 - val_loss: 0.4291 - val_accuracy: 0.7813
# Epoch 123/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4288 - accuracy: 0.7814 - val_loss: 0.4273 - val_accuracy: 0.7837
# Epoch 124/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4277 - accuracy: 0.7813 - val_loss: 0.4269 - val_accuracy: 0.7823
# Epoch 125/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4276 - accuracy: 0.7815 - val_loss: 0.4278 - val_accuracy: 0.7834
# Epoch 126/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4273 - accuracy: 0.7818 - val_loss: 0.4253 - val_accuracy: 0.7831
# Epoch 127/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4267 - accuracy: 0.7818 - val_loss: 0.4260 - val_accuracy: 0.7826
# Epoch 128/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4270 - accuracy: 0.7820 - val_loss: 0.4253 - val_accuracy: 0.7837
# Epoch 129/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4278 - accuracy: 0.7820 - val_loss: 0.4279 - val_accuracy: 0.7826
# Epoch 130/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4262 - accuracy: 0.7822 - val_loss: 0.4258 - val_accuracy: 0.7833
# Epoch 131/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4268 - accuracy: 0.7822 - val_loss: 0.4286 - val_accuracy: 0.7842
# Epoch 132/140
# 12/12 [==============================] - 3s 291ms/step - loss: 0.4269 - accuracy: 0.7819 - val_loss: 0.4268 - val_accuracy: 0.7830
# Epoch 133/140
# 12/12 [==============================] - 3s 288ms/step - loss: 0.4262 - accuracy: 0.7824 - val_loss: 0.4261 - val_accuracy: 0.7831
# Epoch 134/140
# 12/12 [==============================] - 3s 292ms/step - loss: 0.4274 - accuracy: 0.7822 - val_loss: 0.4313 - val_accuracy: 0.7838
# Epoch 135/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4287 - accuracy: 0.7818 - val_loss: 0.4348 - val_accuracy: 0.7838
# Epoch 136/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4276 - accuracy: 0.7823 - val_loss: 0.4252 - val_accuracy: 0.7846
# Epoch 137/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4268 - accuracy: 0.7826 - val_loss: 0.4264 - val_accuracy: 0.7840
# Epoch 138/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4259 - accuracy: 0.7823 - val_loss: 0.4263 - val_accuracy: 0.7840
# Epoch 139/140
# 12/12 [==============================] - 3s 289ms/step - loss: 0.4263 - accuracy: 0.7825 - val_loss: 0.4268 - val_accuracy: 0.7817
# Epoch 140/140
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4262 - accuracy: 0.7826 - val_loss: 0.4268 - val_accuracy: 0.7847

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 19s 6ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 517.1837916374207

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00161419],
#        [0.00240811],
#        [0.0021959 ],
#        ...,
#        [0.05519818],
#        [0.05653206],
#        [0.05838092]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14220546884783844
# 0.23532846197040913
# 0.37710140393246805
# 0.27675940284070527

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 89s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.62302759]
# [0.81506083]
# total acc [0.78305509]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1096521472, 'peak': 9520615168}
