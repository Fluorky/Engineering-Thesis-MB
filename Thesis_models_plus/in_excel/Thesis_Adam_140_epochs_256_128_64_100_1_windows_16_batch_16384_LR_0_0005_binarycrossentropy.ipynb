# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=16

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475321, 16, 16)
# strides:  (2048, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2194bda7040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475321,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x21985e16040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380256

# %%
training_sample
# Out:
# 380256

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380256, 16, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380256,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380256, 16, 15) (380256, 1) (95065, 16, 15) (95065, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),
    keras.layers.GRU(units=128,return_sequences=True),
    keras.layers.GRU(units=64),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])
opt=keras.optimizers.Adam(learning_rate=0.0005)
model_gru.compile(loss='binary_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 256)           209664
#
#  gru_1 (GRU)                 (None, 16, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=16384)#, shuffle=False)
# Out:
# Epoch 1/140
# 24/24 [==============================] - 11s 205ms/step - loss: 0.7011 - accuracy: 0.5755 - val_loss: 0.5626 - val_accuracy: 0.7531
# Epoch 2/140
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5750 - accuracy: 0.7393 - val_loss: 0.5591 - val_accuracy: 0.7531
# Epoch 3/140
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5739 - accuracy: 0.7393 - val_loss: 0.5596 - val_accuracy: 0.7531
# Epoch 4/140
# 24/24 [==============================] - 4s 152ms/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5594 - val_accuracy: 0.7531
# Epoch 5/140
# 24/24 [==============================] - 4s 152ms/step - loss: 0.5737 - accuracy: 0.7393 - val_loss: 0.5592 - val_accuracy: 0.7531
# Epoch 6/140
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5736 - accuracy: 0.7393 - val_loss: 0.5589 - val_accuracy: 0.7531
# Epoch 7/140
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5733 - accuracy: 0.7393 - val_loss: 0.5585 - val_accuracy: 0.7531
# Epoch 8/140
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5718 - accuracy: 0.7393 - val_loss: 0.5553 - val_accuracy: 0.7531
# Epoch 9/140
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5573 - accuracy: 0.7393 - val_loss: 0.5425 - val_accuracy: 0.7531
# Epoch 10/140
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5320 - accuracy: 0.7393 - val_loss: 0.5066 - val_accuracy: 0.7531
# Epoch 11/140
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5155 - accuracy: 0.7393 - val_loss: 0.4960 - val_accuracy: 0.7531
# Epoch 12/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.5090 - accuracy: 0.7390 - val_loss: 0.4922 - val_accuracy: 0.7531
# Epoch 13/140
# 24/24 [==============================] - 4s 152ms/step - loss: 0.5077 - accuracy: 0.7392 - val_loss: 0.4940 - val_accuracy: 0.7531
# Epoch 14/140
# 24/24 [==============================] - 4s 152ms/step - loss: 0.5035 - accuracy: 0.7389 - val_loss: 0.4866 - val_accuracy: 0.7530
# Epoch 15/140
# 24/24 [==============================] - 4s 154ms/step - loss: 0.5013 - accuracy: 0.7395 - val_loss: 0.4863 - val_accuracy: 0.7531
# Epoch 16/140
# 24/24 [==============================] - 4s 158ms/step - loss: 0.4984 - accuracy: 0.7417 - val_loss: 0.4821 - val_accuracy: 0.7546
# Epoch 17/140
# 24/24 [==============================] - 4s 158ms/step - loss: 0.4948 - accuracy: 0.7460 - val_loss: 0.4814 - val_accuracy: 0.7508
# Epoch 18/140
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4897 - accuracy: 0.7480 - val_loss: 0.4767 - val_accuracy: 0.7557
# Epoch 19/140
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4858 - accuracy: 0.7482 - val_loss: 0.4727 - val_accuracy: 0.7542
# Epoch 20/140
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4803 - accuracy: 0.7510 - val_loss: 0.4704 - val_accuracy: 0.7576
# Epoch 21/140
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4745 - accuracy: 0.7534 - val_loss: 0.4648 - val_accuracy: 0.7589
# Epoch 22/140
# 24/24 [==============================] - 4s 153ms/step - loss: 0.4751 - accuracy: 0.7536 - val_loss: 0.4720 - val_accuracy: 0.7603
# Epoch 120/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4277 - accuracy: 0.7819 - val_loss: 0.4302 - val_accuracy: 0.7793
# Epoch 121/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4282 - accuracy: 0.7814 - val_loss: 0.4281 - val_accuracy: 0.7836
# Epoch 122/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4272 - accuracy: 0.7818 - val_loss: 0.4447 - val_accuracy: 0.7793
# Epoch 123/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4292 - accuracy: 0.7814 - val_loss: 0.4297 - val_accuracy: 0.7835
# Epoch 124/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4270 - accuracy: 0.7818 - val_loss: 0.4288 - val_accuracy: 0.7820
# Epoch 125/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4255 - accuracy: 0.7825 - val_loss: 0.4295 - val_accuracy: 0.7824
# Epoch 126/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4256 - accuracy: 0.7823 - val_loss: 0.4274 - val_accuracy: 0.7813
# Epoch 127/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4254 - accuracy: 0.7824 - val_loss: 0.4328 - val_accuracy: 0.7832
# Epoch 128/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4256 - accuracy: 0.7824 - val_loss: 0.4285 - val_accuracy: 0.7819
# Epoch 129/140
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4261 - accuracy: 0.7824 - val_loss: 0.4284 - val_accuracy: 0.7844
# Epoch 130/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4255 - accuracy: 0.7827 - val_loss: 0.4343 - val_accuracy: 0.7836
# Epoch 131/140
# 24/24 [==============================] - 4s 157ms/step - loss: 0.4259 - accuracy: 0.7826 - val_loss: 0.4285 - val_accuracy: 0.7813
# Epoch 132/140
# 24/24 [==============================] - 4s 156ms/step - loss: 0.4241 - accuracy: 0.7832 - val_loss: 0.4290 - val_accuracy: 0.7843
# Epoch 133/140
# 24/24 [==============================] - 4s 156ms/step - loss: 0.4242 - accuracy: 0.7830 - val_loss: 0.4272 - val_accuracy: 0.7839
# Epoch 134/140
# 24/24 [==============================] - 4s 156ms/step - loss: 0.4240 - accuracy: 0.7833 - val_loss: 0.4358 - val_accuracy: 0.7831
# Epoch 135/140
# 24/24 [==============================] - 4s 156ms/step - loss: 0.4250 - accuracy: 0.7834 - val_loss: 0.4352 - val_accuracy: 0.7831
# Epoch 136/140
# 24/24 [==============================] - 4s 156ms/step - loss: 0.4254 - accuracy: 0.7831 - val_loss: 0.4276 - val_accuracy: 0.7811
# Epoch 137/140
# 24/24 [==============================] - 4s 156ms/step - loss: 0.4237 - accuracy: 0.7835 - val_loss: 0.4318 - val_accuracy: 0.7837
# Epoch 138/140
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4240 - accuracy: 0.7837 - val_loss: 0.4348 - val_accuracy: 0.7837
# Epoch 139/140
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4242 - accuracy: 0.7835 - val_loss: 0.4248 - val_accuracy: 0.7844
# Epoch 140/140
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4232 - accuracy: 0.7836 - val_loss: 0.4267 - val_accuracy: 0.7820

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 18s 6ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 548.57692527771

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95065, 1)

# %%
pred_y
# Out:
# array([[0.00387421],
#        [0.00235047],
#        [0.00115146],
#        ...,
#        [0.05070332],
#        [0.05245459],
#        [0.05467032]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95065)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14285655768781721
# 0.23180568422173198
# 0.37796369890217923
# 0.2842290469309206

# %%
np.shape(train_X)
# Out:
# (380256, 16, 15)

# %%
np.shape(train_y)
# Out:
# (380256, 1)

# %%
np.shape(test_X)
# Out:
# (95065, 16, 15)

# %%
np.shape(test_y)
# Out:
# (95065, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 83s 6ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25794568]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.61638898]
# [0.82029916]
# total acc [0.78376297]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 553044736, 'peak': 4856984832}
