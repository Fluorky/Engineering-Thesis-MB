# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=4

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475333, 4, 16)
# strides:  (512, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1b4b34c8040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475333,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1b4c1cf8040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380266

# %%
training_sample
# Out:
# 380266

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380266, 4, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380266,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380266, 4, 15) (380266, 1) (95067, 4, 15) (95067, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

opt=keras.optimizers.SGD(learning_rate=0.9)
model_gru.compile(loss='MSE', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 4, 256)            209664
#
#  gru_1 (GRU)                 (None, 4, 128)            148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=2048)#, shuffle=False)
# Out:
# Epoch 1/140
# 186/186 [==============================] - 16s 23ms/step - loss: 0.1926 - accuracy: 0.7393 - val_loss: 0.1842 - val_accuracy: 0.7531
# Epoch 2/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1886 - accuracy: 0.7390 - val_loss: 0.1919 - val_accuracy: 0.7276
# Epoch 3/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1869 - accuracy: 0.7358 - val_loss: 0.1785 - val_accuracy: 0.7530
# Epoch 4/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1828 - accuracy: 0.7356 - val_loss: 0.1668 - val_accuracy: 0.7530
# Epoch 5/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1801 - accuracy: 0.7351 - val_loss: 0.1767 - val_accuracy: 0.7531
# Epoch 6/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1769 - accuracy: 0.7349 - val_loss: 0.1638 - val_accuracy: 0.7530
# Epoch 7/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1750 - accuracy: 0.7350 - val_loss: 0.1627 - val_accuracy: 0.7530
# Epoch 8/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1715 - accuracy: 0.7368 - val_loss: 0.1654 - val_accuracy: 0.7484
# Epoch 9/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1711 - accuracy: 0.7368 - val_loss: 0.1623 - val_accuracy: 0.7530
# Epoch 10/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1712 - accuracy: 0.7367 - val_loss: 0.1641 - val_accuracy: 0.7478
# Epoch 11/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1696 - accuracy: 0.7368 - val_loss: 0.1625 - val_accuracy: 0.7531
# Epoch 12/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1689 - accuracy: 0.7379 - val_loss: 0.1614 - val_accuracy: 0.7531
# Epoch 13/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1684 - accuracy: 0.7385 - val_loss: 0.1611 - val_accuracy: 0.7538
# Epoch 14/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1681 - accuracy: 0.7397 - val_loss: 0.1608 - val_accuracy: 0.7536
# Epoch 15/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1673 - accuracy: 0.7417 - val_loss: 0.1607 - val_accuracy: 0.7538
# Epoch 16/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1675 - accuracy: 0.7429 - val_loss: 0.1678 - val_accuracy: 0.7441
# Epoch 17/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1673 - accuracy: 0.7440 - val_loss: 0.1622 - val_accuracy: 0.7544
# Epoch 18/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1676 - accuracy: 0.7432 - val_loss: 0.1596 - val_accuracy: 0.7552
# Epoch 19/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1646 - accuracy: 0.7457 - val_loss: 0.1589 - val_accuracy: 0.7541
# Epoch 20/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1645 - accuracy: 0.7452 - val_loss: 0.1661 - val_accuracy: 0.7541
# Epoch 21/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1636 - accuracy: 0.7469 - val_loss: 0.1655 - val_accuracy: 0.7369
# Epoch 22/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1627 - accuracy: 0.7474 - val_loss: 0.1588 - val_accuracy: 0.7516
# Epoch 23/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1614 - accuracy: 0.7495 - val_loss: 0.1586 - val_accuracy: 0.7570
# Epoch 24/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1607 - accuracy: 0.7505 - val_loss: 0.1567 - val_accuracy: 0.7576
# Epoch 25/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1598 - accuracy: 0.7514 - val_loss: 0.1560 - val_accuracy: 0.7585
# Epoch 26/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1594 - accuracy: 0.7522 - val_loss: 0.1605 - val_accuracy: 0.7465
# Epoch 27/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1590 - accuracy: 0.7517 - val_loss: 0.1556 - val_accuracy: 0.7549
# Epoch 28/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1588 - accuracy: 0.7527 - val_loss: 0.1589 - val_accuracy: 0.7522
# Epoch 29/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1585 - accuracy: 0.7532 - val_loss: 0.1604 - val_accuracy: 0.7466
# Epoch 30/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1582 - accuracy: 0.7532 - val_loss: 0.1554 - val_accuracy: 0.7567
# Epoch 31/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1580 - accuracy: 0.7535 - val_loss: 0.1548 - val_accuracy: 0.7599
# Epoch 32/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1578 - accuracy: 0.7538 - val_loss: 0.1543 - val_accuracy: 0.7570
# Epoch 33/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1575 - accuracy: 0.7547 - val_loss: 0.1556 - val_accuracy: 0.7564
# Epoch 34/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1574 - accuracy: 0.7543 - val_loss: 0.1531 - val_accuracy: 0.7581
# Epoch 35/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1570 - accuracy: 0.7550 - val_loss: 0.1579 - val_accuracy: 0.7583
# Epoch 36/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1570 - accuracy: 0.7551 - val_loss: 0.1532 - val_accuracy: 0.7590
# Epoch 37/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1568 - accuracy: 0.7552 - val_loss: 0.1529 - val_accuracy: 0.7612
# Epoch 38/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1570 - accuracy: 0.7554 - val_loss: 0.1537 - val_accuracy: 0.7587
# Epoch 39/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1565 - accuracy: 0.7560 - val_loss: 0.1538 - val_accuracy: 0.7609
# Epoch 40/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1560 - accuracy: 0.7558 - val_loss: 0.1525 - val_accuracy: 0.7587
# Epoch 41/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1561 - accuracy: 0.7566 - val_loss: 0.1586 - val_accuracy: 0.7622
# Epoch 42/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1560 - accuracy: 0.7564 - val_loss: 0.1537 - val_accuracy: 0.7625
# Epoch 43/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1556 - accuracy: 0.7566 - val_loss: 0.1594 - val_accuracy: 0.7485
# Epoch 44/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1557 - accuracy: 0.7566 - val_loss: 0.1515 - val_accuracy: 0.7611
# Epoch 45/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1557 - accuracy: 0.7566 - val_loss: 0.1549 - val_accuracy: 0.7630
# Epoch 46/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1553 - accuracy: 0.7569 - val_loss: 0.1512 - val_accuracy: 0.7619
# Epoch 47/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1552 - accuracy: 0.7576 - val_loss: 0.1515 - val_accuracy: 0.7605
# Epoch 48/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1553 - accuracy: 0.7571 - val_loss: 0.1515 - val_accuracy: 0.7628
# Epoch 49/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1549 - accuracy: 0.7576 - val_loss: 0.1503 - val_accuracy: 0.7630
# Epoch 50/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1550 - accuracy: 0.7580 - val_loss: 0.1523 - val_accuracy: 0.7619
# Epoch 51/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1546 - accuracy: 0.7579 - val_loss: 0.1500 - val_accuracy: 0.7632
# Epoch 52/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1544 - accuracy: 0.7587 - val_loss: 0.1566 - val_accuracy: 0.7542
# Epoch 53/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1545 - accuracy: 0.7585 - val_loss: 0.1509 - val_accuracy: 0.7630
# Epoch 54/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1546 - accuracy: 0.7588 - val_loss: 0.1502 - val_accuracy: 0.7649
# Epoch 55/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1543 - accuracy: 0.7587 - val_loss: 0.1527 - val_accuracy: 0.7608
# Epoch 56/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1543 - accuracy: 0.7597 - val_loss: 0.1543 - val_accuracy: 0.7603
# Epoch 57/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1540 - accuracy: 0.7611 - val_loss: 0.1512 - val_accuracy: 0.7666
# Epoch 58/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1536 - accuracy: 0.7616 - val_loss: 0.1496 - val_accuracy: 0.7705
# Epoch 59/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1531 - accuracy: 0.7633 - val_loss: 0.1488 - val_accuracy: 0.7711
# Epoch 60/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1530 - accuracy: 0.7638 - val_loss: 0.1478 - val_accuracy: 0.7717
# Epoch 61/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1527 - accuracy: 0.7648 - val_loss: 0.1498 - val_accuracy: 0.7694
# Epoch 62/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1524 - accuracy: 0.7658 - val_loss: 0.1482 - val_accuracy: 0.7730
# Epoch 63/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1521 - accuracy: 0.7669 - val_loss: 0.1491 - val_accuracy: 0.7729
# Epoch 64/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1519 - accuracy: 0.7683 - val_loss: 0.1479 - val_accuracy: 0.7734
# Epoch 65/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1512 - accuracy: 0.7694 - val_loss: 0.1492 - val_accuracy: 0.7717
# Epoch 66/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1510 - accuracy: 0.7703 - val_loss: 0.1494 - val_accuracy: 0.7742
140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1449 - accuracy: 0.7799 - val_loss: 0.1441 - val_accuracy: 0.7806
# Epoch 117/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1452 - accuracy: 0.7795 - val_loss: 0.1447 - val_accuracy: 0.7799
# Epoch 118/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1449 - accuracy: 0.7800 - val_loss: 0.1437 - val_accuracy: 0.7804
# Epoch 119/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1450 - accuracy: 0.7798 - val_loss: 0.1448 - val_accuracy: 0.7811
# Epoch 120/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1447 - accuracy: 0.7805 - val_loss: 0.1460 - val_accuracy: 0.7761
# Epoch 121/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1450 - accuracy: 0.7796 - val_loss: 0.1433 - val_accuracy: 0.7826
# Epoch 122/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1447 - accuracy: 0.7804 - val_loss: 0.1449 - val_accuracy: 0.7810
# Epoch 123/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1449 - accuracy: 0.7803 - val_loss: 0.1459 - val_accuracy: 0.7795
# Epoch 124/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1446 - accuracy: 0.7805 - val_loss: 0.1445 - val_accuracy: 0.7832
# Epoch 125/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1447 - accuracy: 0.7803 - val_loss: 0.1423 - val_accuracy: 0.7831
# Epoch 126/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1444 - accuracy: 0.7805 - val_loss: 0.1438 - val_accuracy: 0.7798
# Epoch 127/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1447 - accuracy: 0.7808 - val_loss: 0.1455 - val_accuracy: 0.7792
# Epoch 128/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1447 - accuracy: 0.7803 - val_loss: 0.1435 - val_accuracy: 0.7827
# Epoch 129/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1446 - accuracy: 0.7808 - val_loss: 0.1438 - val_accuracy: 0.7809
# Epoch 130/140
# 186/186 [==============================] - 3s 16ms/step - loss: 0.1443 - accuracy: 0.7807 - val_loss: 0.1436 - val_accuracy: 0.7824
# Epoch 131/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1443 - accuracy: 0.7805 - val_loss: 0.1427 - val_accuracy: 0.7840
# Epoch 132/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1442 - accuracy: 0.7814 - val_loss: 0.1425 - val_accuracy: 0.7826
# Epoch 133/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1442 - accuracy: 0.7812 - val_loss: 0.1441 - val_accuracy: 0.7818
# Epoch 134/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1443 - accuracy: 0.7816 - val_loss: 0.1421 - val_accuracy: 0.7834
# Epoch 135/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1441 - accuracy: 0.7813 - val_loss: 0.1427 - val_accuracy: 0.7832
# Epoch 136/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1440 - accuracy: 0.7812 - val_loss: 0.1435 - val_accuracy: 0.7830
# Epoch 137/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1441 - accuracy: 0.7813 - val_loss: 0.1424 - val_accuracy: 0.7836
# Epoch 138/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1444 - accuracy: 0.7809 - val_loss: 0.1454 - val_accuracy: 0.7814
# Epoch 139/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1441 - accuracy: 0.7814 - val_loss: 0.1421 - val_accuracy: 0.7834
# Epoch 140/140
# 186/186 [==============================] - 3s 15ms/step - loss: 0.1438 - accuracy: 0.7814 - val_loss: 0.1430 - val_accuracy: 0.7815

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 15s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 438.4386284351349

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95067, 1)

# %%
pred_y
# Out:
# array([[0.00179885],
#        [0.0008846 ],
#        [0.00348437],
#        ...,
#        [0.09455326],
#        [0.09713946],
#        [0.10114725]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95067)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1430280066775199
# 0.23087286272845464
# 0.37819043705191685
# 0.2947267110494952

# %%
np.shape(train_X)
# Out:
# (380266, 4, 15)

# %%
np.shape(train_y)
# Out:
# (380266, 1)

# %%
np.shape(test_X)
# Out:
# (95067, 4, 15)

# %%
np.shape(test_y)
# Out:
# (95067, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14855/14855 [==============================] - 71s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25793917]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.5981737]
# [0.83006707]
# total acc [0.78241149]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 140273408, 'peak': 285507328}
