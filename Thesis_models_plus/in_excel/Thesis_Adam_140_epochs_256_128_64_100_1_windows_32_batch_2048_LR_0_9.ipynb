# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2f654fcb040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x2f6c908c040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

#opt=keras.optimizers.SGD(learning_rate=0.9)
opt=keras.optimizers.Adam(learning_rate=0.0001)
model_gru.compile(loss='MSE', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           209664
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=2048)#, shuffle=False)
# Out:
# Epoch 1/140
# 186/186 [==============================] - 18s 59ms/step - loss: 0.1785 - accuracy: 0.7396 - val_loss: 0.1645 - val_accuracy: 0.7532
# Epoch 2/140
# 186/186 [==============================] - 10s 52ms/step - loss: 0.1687 - accuracy: 0.7423 - val_loss: 0.1630 - val_accuracy: 0.7535
# Epoch 3/140
# 186/186 [==============================] - 10s 52ms/step - loss: 0.1633 - accuracy: 0.7503 - val_loss: 0.1575 - val_accuracy: 0.7595
# Epoch 4/140
140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1426 - accuracy: 0.7830 - val_loss: 0.1469 - val_accuracy: 0.7769
# Epoch 74/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1426 - accuracy: 0.7830 - val_loss: 0.1442 - val_accuracy: 0.7832
# Epoch 75/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1422 - accuracy: 0.7833 - val_loss: 0.1442 - val_accuracy: 0.7824
# Epoch 76/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1422 - accuracy: 0.7835 - val_loss: 0.1430 - val_accuracy: 0.7843
# Epoch 77/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1421 - accuracy: 0.7837 - val_loss: 0.1443 - val_accuracy: 0.7788
# Epoch 78/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1420 - accuracy: 0.7837 - val_loss: 0.1448 - val_accuracy: 0.7822
# Epoch 79/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1419 - accuracy: 0.7838 - val_loss: 0.1434 - val_accuracy: 0.7832
# Epoch 80/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1421 - accuracy: 0.7840 - val_loss: 0.1438 - val_accuracy: 0.7804
# Epoch 81/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1418 - accuracy: 0.7838 - val_loss: 0.1445 - val_accuracy: 0.7799
# Epoch 82/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1418 - accuracy: 0.7842 - val_loss: 0.1439 - val_accuracy: 0.7829
# Epoch 83/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1417 - accuracy: 0.7842 - val_loss: 0.1446 - val_accuracy: 0.7780
# Epoch 84/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1415 - accuracy: 0.7845 - val_loss: 0.1446 - val_accuracy: 0.7799
# Epoch 85/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1415 - accuracy: 0.7846 - val_loss: 0.1435 - val_accuracy: 0.7824
# Epoch 86/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1414 - accuracy: 0.7847 - val_loss: 0.1440 - val_accuracy: 0.7850
# Epoch 87/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1414 - accuracy: 0.7847 - val_loss: 0.1434 - val_accuracy: 0.7824
# Epoch 88/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1414 - accuracy: 0.7846 - val_loss: 0.1426 - val_accuracy: 0.7845
# Epoch 89/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1412 - accuracy: 0.7849 - val_loss: 0.1433 - val_accuracy: 0.7840
# Epoch 90/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1413 - accuracy: 0.7847 - val_loss: 0.1433 - val_accuracy: 0.7835
# Epoch 91/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1411 - accuracy: 0.7852 - val_loss: 0.1440 - val_accuracy: 0.7833
# Epoch 92/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1410 - accuracy: 0.7848 - val_loss: 0.1428 - val_accuracy: 0.7851
# Epoch 93/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1410 - accuracy: 0.7854 - val_loss: 0.1433 - val_accuracy: 0.7806
# Epoch 94/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1409 - accuracy: 0.7852 - val_loss: 0.1435 - val_accuracy: 0.7844
# Epoch 95/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1411 - accuracy: 0.7853 - val_loss: 0.1433 - val_accuracy: 0.7844
# Epoch 96/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1408 - accuracy: 0.7855 - val_loss: 0.1430 - val_accuracy: 0.7852
# Epoch 97/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1407 - accuracy: 0.7850 - val_loss: 0.1443 - val_accuracy: 0.7833
# Epoch 98/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1408 - accuracy: 0.7854 - val_loss: 0.1435 - val_accuracy: 0.7836
# Epoch 99/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1407 - accuracy: 0.7853 - val_loss: 0.1424 - val_accuracy: 0.7842
# Epoch 100/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1405 - accuracy: 0.7857 - val_loss: 0.1428 - val_accuracy: 0.7833
# Epoch 101/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1405 - accuracy: 0.7856 - val_loss: 0.1431 - val_accuracy: 0.7844
# Epoch 102/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1405 - accuracy: 0.7859 - val_loss: 0.1431 - val_accuracy: 0.7832
# Epoch 103/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1403 - accuracy: 0.7857 - val_loss: 0.1429 - val_accuracy: 0.7837
# Epoch 104/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1405 - accuracy: 0.7856 - val_loss: 0.1433 - val_accuracy: 0.7824
# Epoch 105/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1404 - accuracy: 0.7859 - val_loss: 0.1436 - val_accuracy: 0.7806
# Epoch 106/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1404 - accuracy: 0.7860 - val_loss: 0.1427 - val_accuracy: 0.7840
# Epoch 107/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1401 - accuracy: 0.7859 - val_loss: 0.1430 - val_accuracy: 0.7845
# Epoch 108/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1402 - accuracy: 0.7863 - val_loss: 0.1421 - val_accuracy: 0.7846
# Epoch 109/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1401 - accuracy: 0.7862 - val_loss: 0.1427 - val_accuracy: 0.7846
# Epoch 110/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1400 - accuracy: 0.7864 - val_loss: 0.1431 - val_accuracy: 0.7812
# Epoch 111/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1399 - accuracy: 0.7864 - val_loss: 0.1431 - val_accuracy: 0.7813
# Epoch 112/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1399 - accuracy: 0.7868 - val_loss: 0.1425 - val_accuracy: 0.7843
# Epoch 113/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1398 - accuracy: 0.7863 - val_loss: 0.1423 - val_accuracy: 0.7855
# Epoch 114/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1398 - accuracy: 0.7867 - val_loss: 0.1439 - val_accuracy: 0.7805
# Epoch 115/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1398 - accuracy: 0.7869 - val_loss: 0.1425 - val_accuracy: 0.7847
# Epoch 116/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1397 - accuracy: 0.7872 - val_loss: 0.1416 - val_accuracy: 0.7850
# Epoch 117/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1396 - accuracy: 0.7873 - val_loss: 0.1437 - val_accuracy: 0.7796
# Epoch 118/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1397 - accuracy: 0.7872 - val_loss: 0.1416 - val_accuracy: 0.7847
# Epoch 119/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1396 - accuracy: 0.7872 - val_loss: 0.1441 - val_accuracy: 0.7832
# Epoch 120/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1395 - accuracy: 0.7872 - val_loss: 0.1419 - val_accuracy: 0.7852
# Epoch 121/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1395 - accuracy: 0.7869 - val_loss: 0.1423 - val_accuracy: 0.7845
# Epoch 122/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1395 - accuracy: 0.7876 - val_loss: 0.1441 - val_accuracy: 0.7819
# Epoch 123/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1394 - accuracy: 0.7876 - val_loss: 0.1435 - val_accuracy: 0.7828
# Epoch 124/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1392 - accuracy: 0.7875 - val_loss: 0.1428 - val_accuracy: 0.7834
# Epoch 125/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1392 - accuracy: 0.7877 - val_loss: 0.1438 - val_accuracy: 0.7811
# Epoch 126/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1392 - accuracy: 0.7878 - val_loss: 0.1436 - val_accuracy: 0.7845
# Epoch 127/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1392 - accuracy: 0.7879 - val_loss: 0.1432 - val_accuracy: 0.7866
# Epoch 128/140
# 186/186 [==============================] - 10s 52ms/step - loss: 0.1390 - accuracy: 0.7877 - val_loss: 0.1430 - val_accuracy: 0.7851
# Epoch 129/140
# 186/186 [==============================] - 10s 51ms/step - loss: 0.1392 - accuracy: 0.7880 - val_loss: 0.1425 - val_accuracy: 0.7845
# Epoch 130/140
# 186/186 [==============================] - 10s 51ms/step - loss: 0.1390 - accuracy: 0.7881 - val_loss: 0.1424 - val_accuracy: 0.7841
# Epoch 131/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1391 - accuracy: 0.7879 - val_loss: 0.1442 - val_accuracy: 0.7812
# Epoch 132/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1390 - accuracy: 0.7882 - val_loss: 0.1430 - val_accuracy: 0.7859
# Epoch 133/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1387 - accuracy: 0.7882 - val_loss: 0.1441 - val_accuracy: 0.7837
# Epoch 134/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1389 - accuracy: 0.7884 - val_loss: 0.1424 - val_accuracy: 0.7842
# Epoch 135/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1389 - accuracy: 0.7884 - val_loss: 0.1435 - val_accuracy: 0.7825
# Epoch 136/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1387 - accuracy: 0.7886 - val_loss: 0.1433 - val_accuracy: 0.7816
# Epoch 137/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1387 - accuracy: 0.7886 - val_loss: 0.1431 - val_accuracy: 0.7840
# Epoch 138/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1386 - accuracy: 0.7883 - val_loss: 0.1446 - val_accuracy: 0.7835
# Epoch 139/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1386 - accuracy: 0.7887 - val_loss: 0.1444 - val_accuracy: 0.7816
# Epoch 140/140
# 186/186 [==============================] - 10s 51ms/step - loss: 0.1386 - accuracy: 0.7884 - val_loss: 0.1425 - val_accuracy: 0.7847

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 22s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 1365.6624348163605

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00180605],
#        [0.0038006 ],
#        [0.00226814],
#        ...,
#        [0.04665947],
#        [0.04679733],
#        [0.04752697]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14248086075842792
# 0.2338476162790476
# 0.3774663703675175
# 0.27546000910555396

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 106s 7ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.63308061]
# [0.8207575]
# total acc [0.78820757]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1100577024, 'peak': 2037621504}
