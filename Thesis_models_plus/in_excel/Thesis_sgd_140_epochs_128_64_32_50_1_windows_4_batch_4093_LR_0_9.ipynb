# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=4

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475333, 4, 16)
# strides:  (512, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x241bc205040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475333,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x241caa2e040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380266

# %%
training_sample
# Out:
# 380266

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380266, 4, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380266,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380266, 4, 15) (380266, 1) (95067, 4, 15) (95067, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(128,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=64,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=32),#,activation='relu'),
    keras.layers.Dense(units=50,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

opt=keras.optimizers.SGD(learning_rate=0.9)
model_gru.compile(loss='MSE', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 4, 128)            55680
#
#  gru_1 (GRU)                 (None, 4, 64)             37248
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 50)                1650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 104,037
# Trainable params: 104,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=4096)#, shuffle=False)
# Out:
# Epoch 1/140
# 93/93 [==============================] - 13s 29ms/step - loss: 0.1950 - accuracy: 0.7345 - val_loss: 0.1857 - val_accuracy: 0.7531
# Epoch 2/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1914 - accuracy: 0.7393 - val_loss: 0.1839 - val_accuracy: 0.7531
# Epoch 3/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1877 - accuracy: 0.7393 - val_loss: 0.1781 - val_accuracy: 0.7531
# Epoch 4/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1816 - accuracy: 0.7393 - val_loss: 0.1790 - val_accuracy: 0.7530
# Epoch 5/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1812 - accuracy: 0.7382 - val_loss: 0.1701 - val_accuracy: 0.7522
# Epoch 6/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1786 - accuracy: 0.7380 - val_loss: 0.1667 - val_accuracy: 0.7531
# Epoch 7/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1774 - accuracy: 0.7381 - val_loss: 0.1672 - val_accuracy: 0.7525
# Epoch 8/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1754 - accuracy: 0.7377 - val_loss: 0.1638 - val_accuracy: 0.7541
# Epoch 9/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1730 - accuracy: 0.7382 - val_loss: 0.1716 - val_accuracy: 0.7413
# Epoch 10/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1726 - accuracy: 0.7384 - val_loss: 0.1670 - val_accuracy: 0.7473
# Epoch 11/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1721 - accuracy: 0.7384 - val_loss: 0.1622 - val_accuracy: 0.7535
# Epoch 12/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1710 - accuracy: 0.7379 - val_loss: 0.1700 - val_accuracy: 0.7419
# Epoch 13/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1708 - accuracy: 0.7386 - val_loss: 0.1728 - val_accuracy: 0.7389
# Epoch 14/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1694 - accuracy: 0.7382 - val_loss: 0.1653 - val_accuracy: 0.7475
# Epoch 15/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1697 - accuracy: 0.7385 - val_loss: 0.1635 - val_accuracy: 0.7531
# Epoch 16/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1683 - accuracy: 0.7395 - val_loss: 0.1655 - val_accuracy: 0.7499
# Epoch 17/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1700 - accuracy: 0.7392 - val_loss: 0.1633 - val_accuracy: 0.7531
# Epoch 18/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1683 - accuracy: 0.7402 - val_loss: 0.1620 - val_accuracy: 0.7537
# Epoch 19/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1682 - accuracy: 0.7411 - val_loss: 0.1693 - val_accuracy: 0.7455
# Epoch 20/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1687 - accuracy: 0.7420 - val_loss: 0.1607 - val_accuracy: 0.7537
# Epoch 21/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1679 - accuracy: 0.7426 - val_loss: 0.1623 - val_accuracy: 0.7547
# Epoch 22/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1673 - accuracy: 0.7436 - val_loss: 0.1602 - val_accuracy: 0.7551
# Epoch 23/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1675 - accuracy: 0.7438 - val_loss: 0.1642 - val_accuracy: 0.7534
# Epoch 24/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1668 - accuracy: 0.7447 - val_loss: 0.1658 - val_accuracy: 0.7440
# Epoch 25/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1666 - accuracy: 0.7447 - val_loss: 0.1632 - val_accuracy: 0.7548
# Epoch 26/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1666 - accuracy: 0.7445 - val_loss: 0.1630 - val_accuracy: 0.7443
# Epoch 27/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1648 - accuracy: 0.7459 - val_loss: 0.1608 - val_accuracy: 0.7557
# Epoch 28/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1646 - accuracy: 0.7458 - val_loss: 0.1639 - val_accuracy: 0.7411
# Epoch 29/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1644 - accuracy: 0.7458 - val_loss: 0.1616 - val_accuracy: 0.7561
# Epoch 30/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1646 - accuracy: 0.7459 - val_loss: 0.1600 - val_accuracy: 0.7484
# Epoch 31/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1622 - accuracy: 0.7478 - val_loss: 0.1581 - val_accuracy: 0.7509
# Epoch 32/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1635 - accuracy: 0.7470 - val_loss: 0.1618 - val_accuracy: 0.7457
# Epoch 33/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1628 - accuracy: 0.7485 - val_loss: 0.1627 - val_accuracy: 0.7428
# Epoch 34/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1623 - accuracy: 0.7484 - val_loss: 0.1596 - val_accuracy: 0.7572
# Epoch 35/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1618 - accuracy: 0.7489 - val_loss: 0.1559 - val_accuracy: 0.7566
# Epoch 36/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1601 - accuracy: 0.7505 - val_loss: 0.1573 - val_accuracy: 0.7523
# Epoch 37/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1620 - accuracy: 0.7487 - val_loss: 0.1574 - val_accuracy: 0.7568
# Epoch 38/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1607 - accuracy: 0.7499 - val_loss: 0.1617 - val_accuracy: 0.7488
# Epoch 39/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1603 - accuracy: 0.7504 - val_loss: 0.1566 - val_accuracy: 0.7578
# Epoch 40/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1596 - accuracy: 0.7508 - val_loss: 0.1560 - val_accuracy: 0.7571
# Epoch 41/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1593 - accuracy: 0.7516 - val_loss: 0.1555 - val_accuracy: 0.7580
# Epoch 42/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1600 - accuracy: 0.7510 - val_loss: 0.1559 - val_accuracy: 0.7588
# Epoch 43/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.1586 - accuracy: 0.7522 - val_loss: 0.1560 - val_accuracy: 0.7541
# Epoch 44/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.1590 - accuracy: 0.7524 - val_loss: 0.1558 - val_accuracy: 0.7549
# Epoch 45/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1586 - accuracy: 0.7527 - val_loss: 0.1543 - val_accuracy: 0.7562
# Epoch 46/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1579 - accuracy: 0.7532 - val_loss: 0.1549 - val_accuracy: 0.7557
# Epoch 47/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1588 - accuracy: 0.7529 - val_loss: 0.1559 - val_accuracy: 0.7596
# Epoch 48/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1585 - accuracy: 0.7532 - val_loss: 0.1573 - val_accuracy: 0.7521
# Epoch 49/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1587 - accuracy: 0.7531 - val_loss: 0.1563 - val_accuracy: 0.7566
# Epoch 50/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1581 - accuracy: 0.7533 - val_loss: 0.1561 - val_accuracy: 0.7604
# Epoch 51/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1588 - accuracy: 0.7531 - val_loss: 0.1534 - val_accuracy: 0.7583
# Epoch 52/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1586 - accuracy: 0.7534 - val_loss: 0.1532 - val_accuracy: 0.7597
# Epoch 53/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1576 - accuracy: 0.7536 - val_loss: 0.1589 - val_accuracy: 0.7489
# Epoch 54/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1576 - accuracy: 0.7541 - val_loss: 0.1543 - val_accuracy: 0.7562
# Epoch 55/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1575 - accuracy: 0.7548 - val_loss: 0.1551 - val_accuracy: 0.7600
# Epoch 56/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1574 - accuracy: 0.7545 - val_loss: 0.1545 - val_accuracy: 0.7557
# Epoch 57/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1571 - accuracy: 0.7545 - val_loss: 0.1558 - val_accuracy: 0.7608
# Epoch 58/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1570 - accuracy: 0.7547 - val_loss: 0.1532 - val_accuracy: 0.7600
# Epoch 59/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1569 - accuracy: 0.7556 - val_loss: 0.1557 - val_accuracy: 0.7545
# Epoch 60/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1568 - accuracy: 0.7554 - val_loss: 0.1528 - val_accuracy: 0.7601
# Epoch 61/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1565 - accuracy: 0.7558 - val_loss: 0.1574 - val_accuracy: 0.7614
# Epoch 62/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1569 - accuracy: 0.7559 - val_loss: 0.1596 - val_accuracy: 0.7603
# Epoch 63/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1573 - accuracy: 0.7548 - val_loss: 0.1533 - val_accuracy: 0.7582
# Epoch 64/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1569 - accuracy: 0.7553 - val_loss: 0.1525 - val_accuracy: 0.7603
# Epoch 65/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1564 - accuracy: 0.7559 - val_loss: 0.1512 - val_accuracy: 0.7619
# Epoch 66/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1566 - accuracy: 0.7560 - val_loss: 0.1520 - val_accuracy: 0.7621
# Epoch 67/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1560 - accuracy: 0.7567 - val_loss: 0.1529 - val_accuracy: 0.7623
# Epoch 68/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1562 - accuracy: 0.7564 - val_loss: 0.1520 - val_accuracy: 0.7608
# Epoch 69/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1559 - accuracy: 0.7566 - val_loss: 0.1556 - val_accuracy: 0.7627
# Epoch 70/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1562 - accuracy: 0.7560 - val_loss: 0.1536 - val_accuracy: 0.7576
# Epoch 71/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.1554 - accuracy: 0.7571 - val_loss: 0.1522 - val_accuracy: 0.7610
# Epoch 72/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.1558 - accuracy: 0.7571 - val_loss: 0.1575 - val_accuracy: 0.7561
# Epoch 73/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1558 - accuracy: 0.7570 - val_loss: 0.1534 - val_accuracy: 0.7576
# Epoch 74/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1555 - accuracy: 0.7573 - val_loss: 0.1580 - val_accuracy: 0.7626
# Epoch 75/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1552 - accuracy: 0.7572 - val_loss: 0.1560 - val_accuracy: 0.7547
# Epoch 76/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1560 - accuracy: 0.7570 - val_loss: 0.1523 - val_accuracy: 0.7626
# Epoch 77/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1555 - accuracy: 0.7569 - val_loss: 0.1508 - val_accuracy: 0.7629
# Epoch 78/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1553 - accuracy: 0.7571 - val_loss: 0.1573 - val_accuracy: 0.7628
# Epoch 79/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1554 - accuracy: 0.7577 - val_loss: 0.1548 - val_accuracy: 0.7560
# Epoch 80/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1559 - accuracy: 0.7575 - val_loss: 0.1509 - val_accuracy: 0.7612
# Epoch 81/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1548 - accuracy: 0.7581 - val_loss: 0.1513 - val_accuracy: 0.7615
# Epoch 82/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1548 - accuracy: 0.7582 - val_loss: 0.1520 - val_accuracy: 0.7621
# Epoch 83/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1546 - accuracy: 0.7584 - val_loss: 0.1541 - val_accuracy: 0.7563
# Epoch 84/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1548 - accuracy: 0.7585 - val_loss: 0.1533 - val_accuracy: 0.7609
# Epoch 85/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1554 - accuracy: 0.7578 - val_loss: 0.1507 - val_accuracy: 0.7636
# Epoch 86/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1547 - accuracy: 0.7587 - val_loss: 0.1528 - val_accuracy: 0.7606
# Epoch 87/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1546 - accuracy: 0.7587 - val_loss: 0.1534 - val_accuracy: 0.7588
# Epoch 88/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1543 - accuracy: 0.7589 - val_loss: 0.1539 - val_accuracy: 0.7639
# Epoch 89/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1543 - accuracy: 0.7593 - val_loss: 0.1520 - val_accuracy: 0.7631
# Epoch 90/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1541 - accuracy: 0.7590 - val_loss: 0.1496 - val_accuracy: 0.7654
# Epoch 91/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1547 - accuracy: 0.7591 - val_loss: 0.1496 - val_accuracy: 0.7652
# Epoch 92/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1542 - accuracy: 0.7594 - val_loss: 0.1501 - val_accuracy: 0.7647
# Epoch 93/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1541 - accuracy: 0.7597 - val_loss: 0.1562 - val_accuracy: 0.7654
# Epoch 94/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1542 - accuracy: 0.7593 - val_loss: 0.1528 - val_accuracy: 0.7657
# Epoch 95/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1540 - accuracy: 0.7602 - val_loss: 0.1491 - val_accuracy: 0.7672
# Epoch 96/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1540 - accuracy: 0.7607 - val_loss: 0.1505 - val_accuracy: 0.7644
# Epoch 97/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1541 - accuracy: 0.7606 - val_loss: 0.1532 - val_accuracy: 0.7610
# Epoch 98/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1534 - accuracy: 0.7612 - val_loss: 0.1495 - val_accuracy: 0.7671
# Epoch 99/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1535 - accuracy: 0.7617 - val_loss: 0.1497 - val_accuracy: 0.7689
# Epoch 100/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1536 - accuracy: 0.7618 - val_loss: 0.1521 - val_accuracy: 0.7630
# Epoch 101/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1531 - accuracy: 0.7626 - val_loss: 0.1529 - val_accuracy: 0.7685
# Epoch 102/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1531 - accuracy: 0.7623 - val_loss: 0.1497 - val_accuracy: 0.7687
# Epoch 103/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1533 - accuracy: 0.7626 - val_loss: 0.1492 - val_accuracy: 0.7686
# Epoch 104/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1525 - accuracy: 0.7639 - val_loss: 0.1542 - val_accuracy: 0.7593
# Epoch 105/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1529 - accuracy: 0.7637 - val_loss: 0.1517 - val_accuracy: 0.7630
# Epoch 106/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1526 - accuracy: 0.7641 - val_loss: 0.1490 - val_accuracy: 0.7716
# Epoch 107/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1527 - accuracy: 0.7638 - val_loss: 0.1515 - val_accuracy: 0.7635
# Epoch 108/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1520 - accuracy: 0.7651 - val_loss: 0.1483 - val_accuracy: 0.7716
# Epoch 109/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1521 - accuracy: 0.7657 - val_loss: 0.1484 - val_accuracy: 0.7734
# Epoch 110/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1518 - accuracy: 0.7658 - val_loss: 0.1473 - val_accuracy: 0.7744
# Epoch 111/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1522 - accuracy: 0.7659 - val_loss: 0.1507 - val_accuracy: 0.7688
# Epoch 112/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1523 - accuracy: 0.7653 - val_loss: 0.1493 - val_accuracy: 0.7715
# Epoch 113/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1518 - accuracy: 0.7664 - val_loss: 0.1520 - val_accuracy: 0.7652
# Epoch 114/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1520 - accuracy: 0.7665 - val_loss: 0.1491 - val_accuracy: 0.7746
# Epoch 115/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1515 - accuracy: 0.7672 - val_loss: 0.1492 - val_accuracy: 0.7703
# Epoch 116/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1514 - accuracy: 0.7674 - val_loss: 0.1467 - val_accuracy: 0.7762
# Epoch 117/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1513 - accuracy: 0.7681 - val_loss: 0.1485 - val_accuracy: 0.7719
# Epoch 118/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1515 - accuracy: 0.7673 - val_loss: 0.1520 - val_accuracy: 0.7735
# Epoch 119/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1510 - accuracy: 0.7685 - val_loss: 0.1479 - val_accuracy: 0.7730
# Epoch 120/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1511 - accuracy: 0.7689 - val_loss: 0.1468 - val_accuracy: 0.7767
# Epoch 121/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1505 - accuracy: 0.7695 - val_loss: 0.1484 - val_accuracy: 0.7731
# Epoch 122/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1507 - accuracy: 0.7693 - val_loss: 0.1469 - val_accuracy: 0.7785
# Epoch 123/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1506 - accuracy: 0.7700 - val_loss: 0.1494 - val_accuracy: 0.7756
# Epoch 124/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1501 - accuracy: 0.7706 - val_loss: 0.1516 - val_accuracy: 0.7745
# Epoch 125/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1502 - accuracy: 0.7714 - val_loss: 0.1481 - val_accuracy: 0.7768
# Epoch 126/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1498 - accuracy: 0.7713 - val_loss: 0.1462 - val_accuracy: 0.7770
# Epoch 127/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1499 - accuracy: 0.7714 - val_loss: 0.1468 - val_accuracy: 0.7779
# Epoch 128/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1497 - accuracy: 0.7722 - val_loss: 0.1461 - val_accuracy: 0.7778
# Epoch 129/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1502 - accuracy: 0.7719 - val_loss: 0.1491 - val_accuracy: 0.7751
# Epoch 130/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1496 - accuracy: 0.7721 - val_loss: 0.1486 - val_accuracy: 0.7769
# Epoch 131/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1500 - accuracy: 0.7724 - val_loss: 0.1474 - val_accuracy: 0.7755
# Epoch 132/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1500 - accuracy: 0.7717 - val_loss: 0.1462 - val_accuracy: 0.7790
# Epoch 133/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1496 - accuracy: 0.7733 - val_loss: 0.1461 - val_accuracy: 0.7781
# Epoch 134/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1494 - accuracy: 0.7729 - val_loss: 0.1473 - val_accuracy: 0.7758
# Epoch 135/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1492 - accuracy: 0.7737 - val_loss: 0.1462 - val_accuracy: 0.7776
# Epoch 136/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1495 - accuracy: 0.7734 - val_loss: 0.1455 - val_accuracy: 0.7786
# Epoch 137/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1490 - accuracy: 0.7737 - val_loss: 0.1474 - val_accuracy: 0.7761
# Epoch 138/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1488 - accuracy: 0.7736 - val_loss: 0.1459 - val_accuracy: 0.7781
# Epoch 139/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1490 - accuracy: 0.7739 - val_loss: 0.1452 - val_accuracy: 0.7792
# Epoch 140/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1487 - accuracy: 0.7740 - val_loss: 0.1453 - val_accuracy: 0.7786

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 15s 5ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 224.60162711143494

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95067, 1)

# %%
pred_y
# Out:
# array([[0.005369  ],
#        [0.0065785 ],
#        [0.01203659],
#        ...,
#        [0.11068629],
#        [0.11050238],
#        [0.1118399 ]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95067)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.14532131118088154
# 0.2185407134624765
# 0.3812103240743639
# 0.29259918270651847

# %%
np.shape(train_X)
# Out:
# (380266, 4, 15)

# %%
np.shape(train_y)
# Out:
# (380266, 1)

# %%
np.shape(test_X)
# Out:
# (95067, 4, 15)

# %%
np.shape(test_y)
# Out:
# (95067, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14855/14855 [==============================] - 69s 5ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25793917]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.6083681]
# [0.80798408]
# total acc [0.77637782]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 139228672, 'peak': 278203392}
