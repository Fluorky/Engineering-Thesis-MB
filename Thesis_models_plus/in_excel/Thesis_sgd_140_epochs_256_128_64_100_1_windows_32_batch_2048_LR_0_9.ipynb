# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from pandas import *
from sklearn.preprocessing import *
from sklearn.metrics import *
from tensorflow import keras
import tensorflow as tf
import time as t

# %%
w=32

# %%
dataFromSensors=np.load("DataWithLabels/dataFromSensors_"+str(w)+".npy")

# %%
np.info(dataFromSensors)
# Out:
# class:  ndarray
# shape:  (475305, 32, 16)
# strides:  (4096, 128, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x1feed15f040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
labels=np.load("DataWithLabels/labels_"+str(w)+".npy")

# %%
np.info(labels)
# Out:
# class:  ndarray
# shape:  (475305,)
# strides:  (8,)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  True
# data pointer: 0x1ff61210040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
#values = reframed_df.values
#training_sample =int( len(dataset) *0.8)
training_sample_labels =int( len(labels) *0.8)
training_sample =int( len(dataFromSensors) *0.8)
#testDataset=DataFrame.to_numpy(dataset)
#testDataset=DataFrame.to_numpy(reframed_df)

# %%
training_sample_labels
# Out:
# 380244

# %%
training_sample
# Out:
# 380244

# %%
train_labels = labels[:training_sample]
train = dataFromSensors[:training_sample, : ,:]
test_labels = labels[training_sample:]
test = dataFromSensors[training_sample:, : , :]
# split into input and outputs
#train_X, train_y = train[:,:, 1:], train[:,:,0]
#test_X, test_y = test[:,:, 1:], test[:,:,0]
train_X, train_y = train[:,:, 1:], train_labels[:]
test_X, test_y = test[:,:, 1:], test_labels[:]

# %%
train_X.shape
# Out:
# (380244, 32, 15)

# %%
train_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#print(train_X)

# %%
train_y.shape
# Out:
# (380244,)

# %%
#print(test_y)

# %%
train_y=train_y.reshape(train_y.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
#print(train_X)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (380244, 32, 15) (380244, 1) (95061, 32, 15) (95061, 1)

# %%
model_gru =  keras.models.Sequential([
    keras.layers.GRU(256,return_sequences=True,input_shape=(train_X.shape[1],train_X.shape[2])),#,activation='relu'),
    keras.layers.GRU(units=128,return_sequences=True),#,activation='relu'),
    keras.layers.GRU(units=64),#,activation='relu'),
    keras.layers.Dense(units=100,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='sigmoid')
                        ])

opt=keras.optimizers.SGD(learning_rate=0.9)
model_gru.compile(loss='MSE', optimizer=opt,metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32, 256)           209664
#
#  gru_1 (GRU)                 (None, 32, 128)           148224
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense (Dense)               (None, 100)               6500
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 401,737
# Trainable params: 401,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
 start = t.time()

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=140,validation_data=(test_X, test_y),batch_size=2048)#, shuffle=False)
# Out:
# Epoch 1/140
# 186/186 [==============================] - 18s 57ms/step - loss: 0.1916 - accuracy: 0.7393 - val_loss: 0.1965 - val_accuracy: 0.7227
# Epoch 2/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1887 - accuracy: 0.7356 - val_loss: 0.1738 - val_accuracy: 0.7530
# Epoch 3/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1832 - accuracy: 0.7357 - val_loss: 0.1715 - val_accuracy: 0.7485
# Epoch 4/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1792 - accuracy: 0.7360 - val_loss: 0.1728 - val_accuracy: 0.7374
# Epoch 5/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1761 - accuracy: 0.7359 - val_loss: 0.1686 - val_accuracy: 0.7529
# Epoch 6/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1744 - accuracy: 0.7374 - val_loss: 0.1690 - val_accuracy: 0.7480
# Epoch 7/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1722 - accuracy: 0.7386 - val_loss: 0.1646 - val_accuracy: 0.7539
# Epoch 8/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1708 - accuracy: 0.7397 - val_loss: 0.1632 - val_accuracy: 0.7549
# Epoch 9/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1696 - accuracy: 0.7429 - val_loss: 0.1608 - val_accuracy: 0.7551
# Epoch 10/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1694 - accuracy: 0.7433 - val_loss: 0.1689 - val_accuracy: 0.7352
# Epoch 11/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1679 - accuracy: 0.7444 - val_loss: 0.1593 - val_accuracy: 0.7541
# Epoch 12/140
# 186/186 [==============================] - 11s 60ms/step - loss: 0.1657 - accuracy: 0.7461 - val_loss: 0.1638 - val_accuracy: 0.7546
# Epoch 13/140
# 186/186 [==============================] - 11s 57ms/step - loss: 0.1640 - accuracy: 0.7470 - val_loss: 0.1591 - val_accuracy: 0.7514
# Epoch 14/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1633 - accuracy: 0.7491 - val_loss: 0.1592 - val_accuracy: 0.7532
# Epoch 15/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1618 - accuracy: 0.7499 - val_loss: 0.1610 - val_accuracy: 0.7450
# Epoch 16/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1616 - accuracy: 0.7500 - val_loss: 0.1572 - val_accuracy: 0.7551
# Epoch 17/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1603 - accuracy: 0.7527 - val_loss: 0.1591 - val_accuracy: 0.7591
# Epoch 18/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1605 - accuracy: 0.7520 - val_loss: 0.1617 - val_accuracy: 0.7446
# Epoch 19/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1596 - accuracy: 0.7532 - val_loss: 0.1580 - val_accuracy: 0.7521
# Epoch 20/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1590 - accuracy: 0.7537 - val_loss: 0.1537 - val_accuracy: 0.7614
# Epoch 21/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1589 - accuracy: 0.7536 - val_loss: 0.1526 - val_accuracy: 0.7619
# Epoch 22/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1586 - accuracy: 0.7546 - val_loss: 0.1570 - val_accuracy: 0.7551
# Epoch 23/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1582 - accuracy: 0.7544 - val_loss: 0.1525 - val_accuracy: 0.7610
# Epoch 24/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1577 - accuracy: 0.7556 - val_loss: 0.1522 - val_accuracy: 0.7625
# Epoch 25/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1576 - accuracy: 0.7559 - val_loss: 0.1534 - val_accuracy: 0.7630
# Epoch 26/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1570 - accuracy: 0.7566 - val_loss: 0.1538 - val_accuracy: 0.7602
# Epoch 27/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1570 - accuracy: 0.7571 - val_loss: 0.1519 - val_accuracy: 0.7636
# Epoch 28/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1564 - accuracy: 0.7577 - val_loss: 0.1527 - val_accuracy: 0.7624
# Epoch 29/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1563 - accuracy: 0.7590 - val_loss: 0.1525 - val_accuracy: 0.7655
# Epoch 30/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1557 - accuracy: 0.7597 - val_loss: 0.1520 - val_accuracy: 0.7644
# Epoch 31/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1551 - accuracy: 0.7616 - val_loss: 0.1530 - val_accuracy: 0.7694
# Epoch 32/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1549 - accuracy: 0.7626 - val_loss: 0.1506 - val_accuracy: 0.7686
# Epoch 33/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1548 - accuracy: 0.7626 - val_loss: 0.1493 - val_accuracy: 0.7716
# Epoch 34/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1542 - accuracy: 0.7641 - val_loss: 0.1521 - val_accuracy: 0.7660
# Epoch 35/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1536 - accuracy: 0.7652 - val_loss: 0.1493 - val_accuracy: 0.7710
# Epoch 36/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1533 - accuracy: 0.7661 - val_loss: 0.1568 - val_accuracy: 0.7563
# Epoch 37/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1532 - accuracy: 0.7661 - val_loss: 0.1503 - val_accuracy: 0.7718
# Epoch 38/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1530 - accuracy: 0.7669 - val_loss: 0.1533 - val_accuracy: 0.7627
# Epoch 39/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1525 - accuracy: 0.7682 - val_loss: 0.1481 - val_accuracy: 0.7728
# Epoch 40/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1520 - accuracy: 0.7687 - val_loss: 0.1483 - val_accuracy: 0.7727
# Epoch 41/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1521 - accuracy: 0.7684 - val_loss: 0.1542 - val_accuracy: 0.7630
# Epoch 42/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1516 - accuracy: 0.7694 - val_loss: 0.1493 - val_accuracy: 0.7719
# Epoch 43/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1514 - accuracy: 0.7695 - val_loss: 0.1533 - val_accuracy: 0.7700
# Epoch 44/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1514 - accuracy: 0.7697 - val_loss: 0.1491 - val_accuracy: 0.7716
# Epoch 45/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1511 - accuracy: 0.7703 - val_loss: 0.1463 - val_accuracy: 0.7761
# Epoch 46/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1507 - accuracy: 0.7709 - val_loss: 0.1521 - val_accuracy: 0.7658
# Epoch 47/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1509 - accuracy: 0.7705 - val_loss: 0.1546 - val_accuracy: 0.7641
# Epoch 48/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1509 - accuracy: 0.7706 - val_loss: 0.1483 - val_accuracy: 0.7738
# Epoch 49/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1503 - accuracy: 0.7711 - val_loss: 0.1479 - val_accuracy: 0.7736
# Epoch 50/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1501 - accuracy: 0.7718 - val_loss: 0.1506 - val_accuracy: 0.7697
# Epoch 51/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1499 - accuracy: 0.7719 - val_loss: 0.1529 - val_accuracy: 0.7724
# Epoch 52/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1498 - accuracy: 0.7726 - val_loss: 0.1517 - val_accuracy: 0.7684
# Epoch 53/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1499 - accuracy: 0.7728 - val_loss: 0.1466 - val_accuracy: 0.7753
# Epoch 54/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1495 - accuracy: 0.7731 - val_loss: 0.1475 - val_accuracy: 0.7752
# Epoch 55/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1490 - accuracy: 0.7743 - val_loss: 0.1534 - val_accuracy: 0.7744
# Epoch 56/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1489 - accuracy: 0.7740 - val_loss: 0.1473 - val_accuracy: 0.7763
# Epoch 57/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1486 - accuracy: 0.7745 - val_loss: 0.1467 - val_accuracy: 0.7758
# Epoch 58/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1485 - accuracy: 0.7745 - val_loss: 0.1446 - val_accuracy: 0.7795
# Epoch 59/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1484 - accuracy: 0.7748 - val_loss: 0.1457 - val_accuracy: 0.7782
# Epoch 60/140
# 186/186 [==============================] - 10s 51ms/step - loss: 0.1482 - accuracy: 0.7753 - val_loss: 0.1488 - val_accuracy: 0.7729
# Epoch 61/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1480 - accuracy: 0.7757 - val_loss: 0.1458 - val_accuracy: 0.7772
# Epoch 62/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1479 - accuracy: 0.7755 - val_loss: 0.1452 - val_accuracy: 0.7788
# Epoch 63/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1477 - accuracy: 0.7761 - val_loss: 0.1487 - val_accuracy: 0.7739
# Epoch 64/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1479 - accuracy: 0.7757 - val_loss: 0.1466 - val_accuracy: 0.7776
# Epoch 65/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1473 - accuracy: 0.7762 - val_loss: 0.1463 - val_accuracy: 0.7768
# Epoch 66/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1473 - accuracy: 0.7769 - val_loss: 0.1491 - val_accuracy: 0.7770
# Epoch 67/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1471 - accuracy: 0.7772 - val_loss: 0.1450 - val_accuracy: 0.7799
# Epoch 68/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1471 - accuracy: 0.7773 - val_loss: 0.1483 - val_accuracy: 0.7742
# Epoch 69/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1468 - accuracy: 0.7771 - val_loss: 0.1450 - val_accuracy: 0.7795
# Epoch 70/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1470 - accuracy: 0.7774 - val_loss: 0.1461 - val_accuracy: 0.7784
# Epoch 71/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1466 - accuracy: 0.7775 - val_loss: 0.1438 - val_accuracy: 0.7807
# Epoch 72/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1468 - accuracy: 0.7777 - val_loss: 0.1463 - val_accuracy: 0.7807
# Epoch 73/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1470 - accuracy: 0.7772 - val_loss: 0.1435 - val_accuracy: 0.7816
# Epoch 74/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1460 - accuracy: 0.7788 - val_loss: 0.1443 - val_accuracy: 0.7807
# Epoch 75/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1461 - accuracy: 0.7783 - val_loss: 0.1460 - val_accuracy: 0.7800
# Epoch 76/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1460 - accuracy: 0.7783 - val_loss: 0.1450 - val_accuracy: 0.7792
# Epoch 77/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1460 - accuracy: 0.7796 - val_loss: 0.1481 - val_accuracy: 0.7713
# Epoch 78/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1461 - accuracy: 0.7784 - val_loss: 0.1438 - val_accuracy: 0.7812
# Epoch 79/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1463 - accuracy: 0.7785 - val_loss: 0.1432 - val_accuracy: 0.7817
# Epoch 80/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1452 - accuracy: 0.7796 - val_loss: 0.1448 - val_accuracy: 0.7807
# Epoch 81/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1458 - accuracy: 0.7790 - val_loss: 0.1451 - val_accuracy: 0.7822
# Epoch 82/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1459 - accuracy: 0.7786 - val_loss: 0.1514 - val_accuracy: 0.7771
# Epoch 83/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1454 - accuracy: 0.7796 - val_loss: 0.1431 - val_accuracy: 0.7829
# Epoch 84/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1453 - accuracy: 0.7796 - val_loss: 0.1456 - val_accuracy: 0.7779
# Epoch 85/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1454 - accuracy: 0.7799 - val_loss: 0.1438 - val_accuracy: 0.7826
# Epoch 86/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1453 - accuracy: 0.7797 - val_loss: 0.1440 - val_accuracy: 0.7820
# Epoch 87/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1452 - accuracy: 0.7799 - val_loss: 0.1515 - val_accuracy: 0.7716
# Epoch 88/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1454 - accuracy: 0.7798 - val_loss: 0.1436 - val_accuracy: 0.7823
# Epoch 89/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1449 - accuracy: 0.7803 - val_loss: 0.1461 - val_accuracy: 0.7753
# Epoch 90/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1450 - accuracy: 0.7804 - val_loss: 0.1461 - val_accuracy: 0.7804
# Epoch 91/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1448 - accuracy: 0.7803 - val_loss: 0.1453 - val_accuracy: 0.7823
# Epoch 92/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1445 - accuracy: 0.7812 - val_loss: 0.1437 - val_accuracy: 0.7830
# Epoch 93/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1450 - accuracy: 0.7804 - val_loss: 0.1440 - val_accuracy: 0.7811
# Epoch 94/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1444 - accuracy: 0.7812 - val_loss: 0.1427 - val_accuracy: 0.7832
# Epoch 95/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1443 - accuracy: 0.7813 - val_loss: 0.1435 - val_accuracy: 0.7819
# Epoch 96/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1444 - accuracy: 0.7813 - val_loss: 0.1440 - val_accuracy: 0.7824
# Epoch 97/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1441 - accuracy: 0.7816 - val_loss: 0.1461 - val_accuracy: 0.7809
# Epoch 98/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1443 - accuracy: 0.7814 - val_loss: 0.1430 - val_accuracy: 0.7836
# Epoch 99/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1445 - accuracy: 0.7812 - val_loss: 0.1433 - val_accuracy: 0.7820
# Epoch 100/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1442 - accuracy: 0.7814 - val_loss: 0.1441 - val_accuracy: 0.7824
# Epoch 101/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1442 - accuracy: 0.7824 - val_loss: 0.1423 - val_accuracy: 0.7836
# Epoch 102/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1438 - accuracy: 0.7821 - val_loss: 0.1450 - val_accuracy: 0.7832
# Epoch 103/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1441 - accuracy: 0.7814 - val_loss: 0.1434 - val_accuracy: 0.7836
# Epoch 104/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1435 - accuracy: 0.7825 - val_loss: 0.1433 - val_accuracy: 0.7810
# Epoch 105/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1438 - accuracy: 0.7822 - val_loss: 0.1481 - val_accuracy: 0.7728
# Epoch 106/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1437 - accuracy: 0.7819 - val_loss: 0.1432 - val_accuracy: 0.7822
# Epoch 107/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1432 - accuracy: 0.7832 - val_loss: 0.1442 - val_accuracy: 0.7828
# Epoch 108/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1434 - accuracy: 0.7826 - val_loss: 0.1428 - val_accuracy: 0.7815
# Epoch 109/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1438 - accuracy: 0.7822 - val_loss: 0.1432 - val_accuracy: 0.7810
# Epoch 110/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1434 - accuracy: 0.7826 - val_loss: 0.1444 - val_accuracy: 0.7821
# Epoch 111/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1434 - accuracy: 0.7822 - val_loss: 0.1427 - val_accuracy: 0.7825
# Epoch 112/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1432 - accuracy: 0.7831 - val_loss: 0.1429 - val_accuracy: 0.7827
# Epoch 113/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1433 - accuracy: 0.7830 - val_loss: 0.1459 - val_accuracy: 0.7818
# Epoch 114/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1431 - accuracy: 0.7826 - val_loss: 0.1420 - val_accuracy: 0.7845
# Epoch 115/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1430 - accuracy: 0.7831 - val_loss: 0.1422 - val_accuracy: 0.7841
# Epoch 116/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1432 - accuracy: 0.7832 - val_loss: 0.1449 - val_accuracy: 0.7806
# Epoch 117/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1426 - accuracy: 0.7836 - val_loss: 0.1436 - val_accuracy: 0.7819
# Epoch 118/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1430 - accuracy: 0.7831 - val_loss: 0.1422 - val_accuracy: 0.7849
# Epoch 119/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1426 - accuracy: 0.7840 - val_loss: 0.1443 - val_accuracy: 0.7821
# Epoch 120/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1428 - accuracy: 0.7836 - val_loss: 0.1423 - val_accuracy: 0.7838
# Epoch 121/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1426 - accuracy: 0.7836 - val_loss: 0.1446 - val_accuracy: 0.7813
# Epoch 122/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1425 - accuracy: 0.7840 - val_loss: 0.1453 - val_accuracy: 0.7783
# Epoch 123/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1426 - accuracy: 0.7835 - val_loss: 0.1427 - val_accuracy: 0.7845
# Epoch 124/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1424 - accuracy: 0.7840 - val_loss: 0.1428 - val_accuracy: 0.7816
# Epoch 125/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1426 - accuracy: 0.7841 - val_loss: 0.1452 - val_accuracy: 0.7819
# Epoch 126/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1425 - accuracy: 0.7837 - val_loss: 0.1425 - val_accuracy: 0.7823
# Epoch 127/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1423 - accuracy: 0.7845 - val_loss: 0.1429 - val_accuracy: 0.7836
# Epoch 128/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1424 - accuracy: 0.7840 - val_loss: 0.1426 - val_accuracy: 0.7832
# Epoch 129/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1418 - accuracy: 0.7845 - val_loss: 0.1500 - val_accuracy: 0.7816
# Epoch 130/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1421 - accuracy: 0.7850 - val_loss: 0.1436 - val_accuracy: 0.7812
# Epoch 131/140
# 186/186 [==============================] - 9s 51ms/step - loss: 0.1420 - accuracy: 0.7848 - val_loss: 0.1440 - val_accuracy: 0.7791
# Epoch 132/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1420 - accuracy: 0.7844 - val_loss: 0.1492 - val_accuracy: 0.7702
# Epoch 133/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1416 - accuracy: 0.7849 - val_loss: 0.1429 - val_accuracy: 0.7813
# Epoch 134/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1417 - accuracy: 0.7850 - val_loss: 0.1455 - val_accuracy: 0.7831
# Epoch 135/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1418 - accuracy: 0.7848 - val_loss: 0.1460 - val_accuracy: 0.7763
# Epoch 136/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1417 - accuracy: 0.7849 - val_loss: 0.1460 - val_accuracy: 0.7758
# Epoch 137/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1415 - accuracy: 0.7856 - val_loss: 0.1444 - val_accuracy: 0.7796
# Epoch 138/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1415 - accuracy: 0.7854 - val_loss: 0.1444 - val_accuracy: 0.7836
# Epoch 139/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1414 - accuracy: 0.7858 - val_loss: 0.1439 - val_accuracy: 0.7794
# Epoch 140/140
# 186/186 [==============================] - 9s 50ms/step - loss: 0.1414 - accuracy: 0.7851 - val_loss: 0.1426 - val_accuracy: 0.7820

# %%
pred_y =  model_gru.predict(test_X)
# Out:
# 2971/2971 [==============================] - 22s 7ms/step

# %%
stop=t.time()-start
print(stop)
# Out:
# 1350.441722869873

# %%
#plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
#plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.plot(gru_history.history['loss'], label='GRU train', color='brown')
plt.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(gru_history.history['accuracy'], label='GRU accuracy', color='green')
plt.plot(gru_history.history['val_accuracy'], label='GRU val_accuracy', color='yellow')
plt.legend()
plt.show()

# %%
print(test_y)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
np.shape(pred_y)
# Out:
# (95061, 1)

# %%
pred_y
# Out:
# array([[0.00150608],
#        [0.00455997],
#        [0.00300765],
#        ...,
#        [0.09607509],
#        [0.10177894],
#        [0.10675801]], dtype=float32)

# %%
pred_y=np.reshape(pred_y,95061)

# %%
plt.rcParams['figure.figsize'] = (15,5)

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)


plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.1426183373629571
# 0.2331083729329222
# 0.3776484309022839
# 0.28260230198319314

# %%
np.shape(train_X)
# Out:
# (380244, 32, 15)

# %%
np.shape(train_y)
# Out:
# (380244, 1)

# %%
np.shape(test_X)
# Out:
# (95061, 32, 15)

# %%
np.shape(test_y)
# Out:
# (95061, 1)

# %%
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 14854/14854 [==============================] - 113s 8ms/step

# %%
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()

# %%
print(sum(tes)/len(tes))
# Out:
# [0.25795437]

# %%
#print(fp[1000:1010])
_fp = np.where(fp>0.5,1,0)
_all = sum(_fp)
_w = (_fp*tes)
print(sum(_w)/_all)
      
_all_z = sum(1-_fp)      
_w_z = (1-_fp)*(1-tes)
print(sum(_w_z)/_all_z)
print('total acc', (sum(_w)+sum(_w_z))/len(_w))
# Out:
# [0.62907847]
# [0.81628114]
# total acc [0.78507695]

# %%
plt.plot(tes[:8000], label = 'Actual')
plt.plot(fp[:8000], label = 'Predicted')
plt.legend()
plt.show()

# %%
#over very small part of data
plt.plot(tes[2000:2020], label = 'Actual')
plt.plot(fp[2000:2020], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:50], label = 'Actual')
plt.plot(fp[:50], label = 'Predicted')
plt.legend()
plt.show()

# %%
plt.plot(tes[:5], label = 'Actual')
plt.plot(fp[:5], label = 'Predicted')
plt.legend()
plt.show()

# %%
tf.config.experimental.get_memory_info('GPU:0')
# Out:
# {'current': 1098479872, 'peak': 2042199552}
